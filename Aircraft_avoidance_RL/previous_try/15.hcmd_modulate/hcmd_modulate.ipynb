# %%
import math, random

import gym
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd 
import torch.nn.functional as F

from common.layers import NoisyLinear
from common.replay_buffer import ReplayBuffer
import gym_Aircraft

from itertools import count
import time
import itertools
import matplotlib
import matplotlib.pyplot as plt

# %%
USE_CUDA = torch.cuda.is_available()
Variable = lambda *args, **kwargs: autograd.Variable(*args, **kwargs).cuda() if USE_CUDA else autograd.Variable(*args, **kwargs)

# %%
env_id = "acav-v0"
env = gym.make(env_id)
# Out:
# /home/jupyter-kunwoopark/.local/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
class RainbowDQN(nn.Module):
    def __init__(self, num_inputs, num_actions, num_atoms, Vmin, Vmax):
        super(RainbowDQN, self).__init__()
        
        self.num_inputs   = num_inputs
        self.num_actions  = num_actions
        self.num_atoms    = num_atoms
        self.Vmin         = Vmin
        self.Vmax         = Vmax
        
        self.linear1 = nn.Linear(num_inputs, 32)
        self.linear2 = nn.Linear(32, 64)
        
        self.noisy_value1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_value2 = NoisyLinear(64, self.num_atoms, use_cuda=USE_CUDA)
        
        self.noisy_advantage1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_advantage2 = NoisyLinear(64, self.num_atoms * self.num_actions, use_cuda=USE_CUDA)
        
    def forward(self, x):
        batch_size = x.size(0)
        
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        
        value = F.relu(self.noisy_value1(x))
        value = self.noisy_value2(value)
        
        advantage = F.relu(self.noisy_advantage1(x))
        advantage = self.noisy_advantage2(advantage)
        
        value     = value.view(batch_size, 1, self.num_atoms)
        advantage = advantage.view(batch_size, self.num_actions, self.num_atoms)
        
        x = value + advantage - advantage.mean(1, keepdim=True)
        x = F.softmax(x.view(-1, self.num_atoms)).view(-1, self.num_actions, self.num_atoms)
        
        return x
        
    def reset_noise(self):
        self.noisy_value1.reset_noise()
        self.noisy_value2.reset_noise()
        self.noisy_advantage1.reset_noise()
        self.noisy_advantage2.reset_noise()
    
    def act(self, state):
        state = Variable(torch.FloatTensor(state).unsqueeze(0), volatile=True)
        dist = self.forward(state).data.cpu()
        dist = dist * torch.linspace(self.Vmin, self.Vmax, self.num_atoms)
        action = dist.sum(2).max(1)[1].numpy()[0]
        return action

# %%
num_atoms = 51
Vmin = -10
Vmax = 10

current_model = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)
target_model  = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)

if USE_CUDA:
    current_model = current_model.cuda()
    target_model  = target_model.cuda()
    
optimizer = optim.Adam(current_model.parameters(), 0.001)

replay_buffer = ReplayBuffer(10000)

# %%
def update_target(current_model, target_model):
    target_model.load_state_dict(current_model.state_dict())
    
update_target(current_model, target_model)

# %%
def projection_distribution(next_state, rewards, dones):
    batch_size  = next_state.size(0)
    
    delta_z = float(Vmax - Vmin) / (num_atoms - 1)
    support = torch.linspace(Vmin, Vmax, num_atoms)
    
    next_dist   = target_model(next_state).data.cpu() * support
    next_action = next_dist.sum(2).max(1)[1]
    next_action = next_action.unsqueeze(1).unsqueeze(1).expand(next_dist.size(0), 1, next_dist.size(2))
    next_dist   = next_dist.gather(1, next_action).squeeze(1)
        
    rewards = rewards.unsqueeze(1).expand_as(next_dist)
    dones   = dones.unsqueeze(1).expand_as(next_dist)
    support = support.unsqueeze(0).expand_as(next_dist)
    
    Tz = rewards + (1 - dones) * 0.99 * support
    Tz = Tz.clamp(min=Vmin, max=Vmax)
    b  = (Tz - Vmin) / delta_z
    l  = b.floor().long()
    u  = b.ceil().long()
        
    offset = torch.linspace(0, (batch_size - 1) * num_atoms, batch_size).long()\
                    .unsqueeze(1).expand(batch_size, num_atoms)

    proj_dist = torch.zeros(next_dist.size())    
    proj_dist.view(-1).index_add_(0, (l + offset).view(-1), (next_dist * (u.float() - b)).view(-1))
    proj_dist.view(-1).index_add_(0, (u + offset).view(-1), (next_dist * (b - l.float())).view(-1))
        
    return proj_dist

# %%
def compute_td_loss(batch_size):
    state, action, reward, next_state, done = replay_buffer.sample(batch_size) 

    state      = Variable(torch.FloatTensor(np.float32(state)))
    next_state = Variable(torch.FloatTensor(np.float32(next_state)), volatile=True)
    action     = Variable(torch.LongTensor(action))
    reward     = torch.FloatTensor(reward)
    done       = torch.FloatTensor(np.float32(done))

    proj_dist = projection_distribution(next_state, reward, done)
    
    dist = current_model(state)
    action = action.unsqueeze(1).unsqueeze(1).expand(batch_size, 1, num_atoms)
    dist = dist.gather(1, action).squeeze(1)
    dist.data.clamp_(0.01, 0.99)
    loss = -(Variable(proj_dist) * dist.log()).sum(1)
    loss  = loss.mean()
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    current_model.reset_noise()
    target_model.reset_noise()
    
    return loss

# %%
num_episodes = 1000
batch_size = 128
gamma=0.99
TARGET_UPDATE=10
hcmd_coef=0.001

losses = []
total_res=[]
reward_list=[]
for i_episode in range(num_episodes):
    total_reward=0
    
    # 환경과 상태 초기화
    res_list=np.zeros(11)
    state = env.reset(hcmd_coef)

    for t in count():
        # 행동 선택과 수행
        
        action = current_model.act(state)
        
        next_state, reward, done, res = env.step(action)
        
        # 메모리에 변이 저장
        replay_buffer.push(state, action, reward, next_state, done)
        

        # 새로운 상태 관찰
        if not done:
            next_state = next_state
        else:
            next_state = None

        

        # 다음 상태로 이동
        state = next_state

     
        # Data save
        
        cmd_list,r_list,elev_list,azim_list,Pm_list,Pt_list,h_list=res
        Pm_list=Pm_list.tolist()
        Pt_list=Pt_list.tolist()
        merged_data=itertools.chain([cmd_list],[r_list],[elev_list],[azim_list],Pm_list,Pt_list,[h_list])
        merged_data=np.array(list(merged_data))
        res_list=np.vstack([res_list,merged_data])
        
        total_reward+=reward
        
        if done:
            res_list=np.delete(res_list,0,0)
            
            total_res.append(res_list)
            reward_list.append(total_reward)
            
            now = time.localtime()
            print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))
            print("episode : {} | final step : {} | total reward : {}".format(i_episode, t, total_reward))
            break
        if len(replay_buffer) > batch_size:
            loss = compute_td_loss(batch_size)
            losses.append(loss.item())
            
        
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        update_target(current_model, target_model)

print('Complete')
env.close()
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 2020/11/27 02:10:49
# episode : 0 | final step : 98 | total reward : -202
# 2020/11/27 02:10:50
# episode : 1 | final step : 98 | total reward : -202
# 2020/11/27 02:10:52
# episode : 2 | final step : 98 | total reward : -202
# 2020/11/27 02:10:53
# episode : 3 | final step : 98 | total reward : -202
# 2020/11/27 02:10:55
# episode : 4 | final step : 98 | total reward : -202
# 2020/11/27 02:10:57
# episode : 5 | final step : 98 | total reward : -202
# 2020/11/27 02:10:58
# episode : 6 | final step : 98 | total reward : -202
# 2020/11/27 02:11:00
# episode : 7 | final step : 98 | total reward : -202
# 2020/11/27 02:11:02
# episode : 8 | final step : 98 | total reward : -202
# 2020/11/27 02:11:03
# episode : 9 | final step : 99 | total reward : -201
# 2020/11/27 02:11:05
# episode : 10 | final step : 98 | total reward : -202
# 2020/11/27 02:11:07
# episode : 11 | final step : 98 | total reward : -202
# 2020/11/27 02:11:08
# episode : 12 | final step : 98 | total reward : -202
# 2020/11/27 02:11:10
# episode : 13 | final step : 98 | total reward : -202
# 2020/11/27 02:11:12
# episode : 14 | final step : 99 | total reward : -201
# 2020/11/27 02:11:13
# episode : 15 | final step : 98 | total reward : -202
# 2020/11/27 02:11:15
# episode : 16 | final step : 98 | total reward : -202
# 2020/11/27 02:11:17
# episode : 17 | final step : 98 | total reward : -202
# 2020/11/27 02:11:18
# episode : 18 | final step : 100 | total reward : 101
# 2020/11/27 02:11:20
# episode : 19 | final step : 98 | total reward : -202
# 2020/11/27 02:11:22
# episode : 20 | final step : 99 | total reward : -201
# 2020/11/27 02:11:23
# episode : 21 | final step : 98 | total reward : -202
# 2020/11/27 02:11:25
# episode : 22 | final step : 100 | total reward : 101
# 2020/11/27 02:11:27
# episode : 23 | final step : 100 | total reward : 101
# 2020/11/27 02:11:29
# episode : 24 | final step : 100 | total reward : 101
# 2020/11/27 02:11:30
# episode : 25 | final step : 100 | total reward : 101
# 2020/11/27 02:11:32
# episode : 26 | final step : 100 | total reward : 101
# 2020/11/27 02:11:34
# episode : 27 | final step : 100 | total reward : 101
# 2020/11/27 02:11:35
# episode : 28 | final step : 100 | total reward : 101
# 2020/11/27 02:11:37
# episode : 29 | final step : 100 | total reward : 101
# 2020/11/27 02:11:39
# episode : 30 | final step : 100 | total reward : 101
# 2020/11/27 02:11:40
# episode : 31 | final step : 100 | total reward : 101
# 2020/11/27 02:11:42
# episode : 32 | final step : 100 | total reward : 101
# 2020/11/27 02:11:44
# episode : 33 | final step : 98 | total reward : -202
# 2020/11/27 02:11:45
# episode : 34 | final step : 98 | total reward : -202
# 2020/11/27 02:11:47
# episode : 35 | final step : 98 | total reward : -202
# 2020/11/27 02:11:49
# episode : 36 | final step : 98 | total reward : -202
# 2020/11/27 02:11:50
# episode : 37 | final step : 98 | total reward : -202
# 2020/11/27 02:11:52
# episode : 38 | final step : 98 | total reward : -202
# 2020/11/27 02:11:54
# episode : 39 | final step : 100 | total reward : 101
# 2020/11/27 02:11:56
# episode : 40 | final step : 100 | total reward : -200
# 2020/11/27 02:11:57
# episode : 41 | final step : 98 | total reward : -202
# 2020/11/27 02:11:59
# episode : 42 | final step : 98 | total reward : -202
# 2020/11/27 02:12:01
# episode : 43 | final step : 98 | total reward : -202
# 2020/11/27 02:12:02
# episode : 44 | final step : 100 | total reward : 101
# 2020/11/27 02:12:04
# episode : 45 | final step : 98 | total reward : -202
# 2020/11/27 02:12:06
# episode : 46 | final step : 98 | total reward : -202
# 2020/11/27 02:12:07
# episode : 47 | final step : 98 | total reward : -202
# 2020/11/27 02:12:09
# episode : 48 | final step : 98 | total reward : -202
# 2020/11/27 02:12:11
# episode : 49 | final step : 98 | total reward : -202
# 2020/11/27 02:12:12
# episode : 50 | final step : 98 | total reward : -202
# 2020/11/27 02:12:14
# episode : 51 | final step : 98 | total reward : -202
# 2020/11/27 02:12:16
# episode : 52 | final step : 98 | total reward : -202
# 2020/11/27 02:12:17
# episode : 53 | final step : 100 | total reward : -200
# 2020/11/27 02:12:19
# episode : 54 | final step : 99 | total reward : -201
# 2020/11/27 02:12:21
# episode : 55 | final step : 99 | total reward : -201
# 2020/11/27 02:12:22
# episode : 56 | final step : 98 | total reward : -202
# 2020/11/27 02:12:24
# episode : 57 | final step : 100 | total reward : 101
# 2020/11/27 02:12:26
# episode : 58 | final step : 98 | total reward : -202
# 2020/11/27 02:12:28
# episode : 59 | final step : 98 | total reward : -202
# 2020/11/27 02:12:29
# episode : 60 | final step : 99 | total reward : -201
# 2020/11/27 02:12:31
# episode : 61 | final step : 98 | total reward : -202
# 2020/11/27 02:12:33
# episode : 62 | final step : 98 | total reward : -202
# 2020/11/27 02:12:34
# episode : 63 | final step : 99 | total reward : -201
# 2020/11/27 02:12:36
# episode : 64 | final step : 98 | total reward : -202
# 2020/11/27 02:12:38
# episode : 65 | final step : 98 | total reward : -202
# 2020/11/27 02:12:40
# episode : 66 | final step : 100 | total reward : 101
# 2020/11/27 02:12:42
# episode : 67 | final step : 98 | total reward : -202
# 2020/11/27 02:12:43
# episode : 68 | final step : 98 | total reward : -202
# 2020/11/27 02:12:45
# episode : 69 | final step : 99 | total reward : -201
# 2020/11/27 02:12:47
# episode : 70 | final step : 98 | total reward : -202
# 2020/11/27 02:12:49
# episode : 71 | final step : 98 | total reward : -202
# 2020/11/27 02:12:50
# episode : 72 | final step : 98 | total reward : -202
# 2020/11/27 02:12:52
# episode : 73 | final step : 98 | total reward : -202
# 2020/11/27 02:12:54
# episode : 74 | final step : 100 | total reward : -200
# 2020/11/27 02:12:56
# episode : 75 | final step : 98 | total reward : -202
# 2020/11/27 02:12:57
# episode : 76 | final step : 98 | total reward : -202
# 2020/11/27 02:12:59
# episode : 77 | final step : 98 | total reward : -202
# 2020/11/27 02:13:01
# episode : 78 | final step : 99 | total reward : -201
# 2020/11/27 02:13:03
# episode : 79 | final step : 98 | total reward : -202
# 2020/11/27 02:13:04
# episode : 80 | final step : 98 | total reward : -202
# 2020/11/27 02:13:06
# episode : 81 | final step : 99 | total reward : -201
# 2020/11/27 02:13:08
# episode : 82 | final step : 98 | total reward : -202
# 2020/11/27 02:13:09
# episode : 83 | final step : 98 | total reward : -202
# 2020/11/27 02:13:11
# episode : 84 | final step : 98 | total reward : -202
# 2020/11/27 02:13:13
# episode : 85 | final step : 98 | total reward : -202
# 2020/11/27 02:13:15
# episode : 86 | final step : 98 | total reward : -202
# 2020/11/27 02:13:16
# episode : 87 | final step : 98 | total reward : -202
# 2020/11/27 02:13:18
# episode : 88 | final step : 100 | total reward : 101
# 2020/11/27 02:13:20
# episode : 89 | final step : 98 | total reward : -202
# 2020/11/27 02:13:21
# episode : 90 | final step : 98 | total reward : -202
# 2020/11/27 02:13:23
# episode : 91 | final step : 98 | total reward : -202
# 2020/11/27 02:13:25
# episode : 92 | final step : 99 | total reward : -201
# 2020/11/27 02:13:27
# episode : 93 | final step : 98 | total reward : -202
# 2020/11/27 02:13:28
# episode : 94 | final step : 98 | total reward : -202
# 2020/11/27 02:13:30
# episode : 95 | final step : 99 | total reward : -201
# 2020/11/27 02:13:32
# episode : 96 | final step : 98 | total reward : -202
# 2020/11/27 02:13:34
# episode : 97 | final step : 98 | total reward : -202
# 2020/11/27 02:13:35
# episode : 98 | final step : 98 | total reward : -202
# 2020/11/27 02:13:37
# episode : 99 | final step : 98 | total reward : -202
# 2020/11/27 02:13:39
# episode : 100 | final step : 99 | total reward : -201
# 2020/11/27 02:13:40
# episode : 101 | final step : 98 | total reward : -202
# 2020/11/27 02:13:42
# episode : 102 | final step : 98 | total reward : -202
# 2020/11/27 02:13:44
# episode : 103 | final step : 98 | total reward : -202
# 2020/11/27 02:13:45
# episode : 104 | final step : 98 | total reward : -202
# 2020/11/27 02:13:47
# episode : 105 | final step : 98 | total reward : -202
# 2020/11/27 02:13:49
# episode : 106 | final step : 98 | total reward : -202
# 2020/11/27 02:13:50
# episode : 107 | final step : 98 | total reward : -202
# 2020/11/27 02:13:52
# episode : 108 | final step : 98 | total reward : -202
# 2020/11/27 02:13:54
# episode : 109 | final step : 98 | total reward : -202
# 2020/11/27 02:13:55
# episode : 110 | final step : 98 | total reward : -202
# 2020/11/27 02:13:57
# episode : 111 | final step : 100 | total reward : 101
# 2020/11/27 02:13:59
# episode : 112 | final step : 98 | total reward : -202
# 2020/11/27 02:14:01
# episode : 113 | final step : 98 | total reward : -202
# 2020/11/27 02:14:02
# episode : 114 | final step : 98 | total reward : -202
# 2020/11/27 02:14:04
# episode : 115 | final step : 98 | total reward : -202
# 2020/11/27 02:14:06
# episode : 116 | final step : 98 | total reward : -202
# 2020/11/27 02:14:07
# episode : 117 | final step : 98 | total reward : -202
# 2020/11/27 02:14:09
# episode : 118 | final step : 98 | total reward : -202
# 2020/11/27 02:14:11
# episode : 119 | final step : 98 | total reward : -202
# 2020/11/27 02:14:12
# episode : 120 | final step : 98 | total reward : -202
# 2020/11/27 02:14:14
# episode : 121 | final step : 98 | total reward : -202
# 2020/11/27 02:14:16
# episode : 122 | final step : 99 | total reward : -201
# 2020/11/27 02:14:18
# episode : 123 | final step : 98 | total reward : -202
# 2020/11/27 02:14:19
# episode : 124 | final step : 98 | total reward : -202
# 2020/11/27 02:14:21
# episode : 125 | final step : 98 | total reward : -202
# 2020/11/27 02:14:23
# episode : 126 | final step : 98 | total reward : -202
# 2020/11/27 02:14:24
# episode : 127 | final step : 98 | total reward : -202
# 2020/11/27 02:14:26
# episode : 128 | final step : 98 | total reward : -202
# 2020/11/27 02:14:28
# episode : 129 | final step : 98 | total reward : -202
# 2020/11/27 02:14:29
# episode : 130 | final step : 98 | total reward : -202
# 2020/11/27 02:14:31
# episode : 131 | final step : 98 | total reward : -202
# 2020/11/27 02:14:33
# episode : 132 | final step : 98 | total reward : -202
# 2020/11/27 02:14:34
# episode : 133 | final step : 98 | total reward : -202
# 2020/11/27 02:14:36
# episode : 134 | final step : 98 | total reward : -202
# 2020/11/27 02:14:38
# episode : 135 | final step : 98 | total reward : -202
# 2020/11/27 02:14:39
# episode : 136 | final step : 99 | total reward : -201
# 2020/11/27 02:14:41
# episode : 137 | final step : 98 | total reward : -202
# 2020/11/27 02:14:43
# episode : 138 | final step : 98 | total reward : -202
# 2020/11/27 02:14:45
# episode : 139 | final step : 98 | total reward : -202
# 2020/11/27 02:14:46
# episode : 140 | final step : 99 | total reward : -201
# 2020/11/27 02:14:48
# episode : 141 | final step : 98 | total reward : -202
# 2020/11/27 02:14:50
# episode : 142 | final step : 98 | total reward : -202
# 2020/11/27 02:14:51
# episode : 143 | final step : 98 | total reward : -202
# 2020/11/27 02:14:53
# episode : 144 | final step : 98 | total reward : -202
# 2020/11/27 02:14:55
# episode : 145 | final step : 98 | total reward : -202
# 2020/11/27 02:14:57
# episode : 146 | final step : 98 | total reward : -202
# 2020/11/27 02:14:58
# episode : 147 | final step : 98 | total reward : -202
# 2020/11/27 02:15:00
# episode : 148 | final step : 98 | total reward : -202
# 2020/11/27 02:15:02
# episode : 149 | final step : 98 | total reward : -202
# 2020/11/27 02:15:04
# episode : 150 | final step : 98 | total reward : -202
# 2020/11/27 02:15:05
# episode : 151 | final step : 98 | total reward : -202
# 2020/11/27 02:15:07
# episode : 152 | final step : 98 | total reward : -202
# 2020/11/27 02:15:09
# episode : 153 | final step : 98 | total reward : -202
# 2020/11/27 02:15:11
# episode : 154 | final step : 99 | total reward : -201
# 2020/11/27 02:15:12
# episode : 155 | final step : 98 | total reward : -202
# 2020/11/27 02:15:14
# episode : 156 | final step : 98 | total reward : -202
# 2020/11/27 02:15:16
# episode : 157 | final step : 98 | total reward : -202
# 2020/11/27 02:15:18
# episode : 158 | final step : 98 | total reward : -202
# 2020/11/27 02:15:19
# episode : 159 | final step : 98 | total reward : -202
# 2020/11/27 02:15:21
# episode : 160 | final step : 98 | total reward : -202
# 2020/11/27 02:15:23
# episode : 161 | final step : 98 | total reward : -202
# 2020/11/27 02:15:24
# episode : 162 | final step : 99 | total reward : -201
# 2020/11/27 02:15:26
# episode : 163 | final step : 98 | total reward : -202
# 2020/11/27 02:15:28
# episode : 164 | final step : 98 | total reward : -202
# 2020/11/27 02:15:29
# episode : 165 | final step : 98 | total reward : -202
# 2020/11/27 02:15:31
# episode : 166 | final step : 98 | total reward : -202
# 2020/11/27 02:15:32
# episode : 167 | final step : 98 | total reward : -202
# 2020/11/27 02:15:34
# episode : 168 | final step : 98 | total reward : -202
# 2020/11/27 02:15:36
# episode : 169 | final step : 98 | total reward : -202
# 2020/11/27 02:15:37
# episode : 170 | final step : 98 | total reward : -202
# 2020/11/27 02:15:39
# episode : 171 | final step : 100 | total reward : 101
# 2020/11/27 02:15:41
# episode : 172 | final step : 98 | total reward : -202
# 2020/11/27 02:15:43
# episode : 173 | final step : 98 | total reward : -202
# 2020/11/27 02:15:44
# episode : 174 | final step : 98 | total reward : -202
# 2020/11/27 02:15:46
# episode : 175 | final step : 99 | total reward : -201
# 2020/11/27 02:15:48
# episode : 176 | final step : 98 | total reward : -202
# 2020/11/27 02:15:50
# episode : 177 | final step : 98 | total reward : -202
# 2020/11/27 02:15:51
# episode : 178 | final step : 99 | total reward : -201
# 2020/11/27 02:15:53
# episode : 179 | final step : 100 | total reward : 101
# 2020/11/27 02:15:55
# episode : 180 | final step : 98 | total reward : -202
# 2020/11/27 02:15:57
# episode : 181 | final step : 98 | total reward : -202
# 2020/11/27 02:15:59
# episode : 182 | final step : 98 | total reward : -202
# 2020/11/27 02:16:01
# episode : 183 | final step : 98 | total reward : -202
# 2020/11/27 02:16:03
# episode : 184 | final step : 98 | total reward : -202
# 2020/11/27 02:16:05
# episode : 185 | final step : 98 | total reward : -202
# 2020/11/27 02:16:06
# episode : 186 | final step : 98 | total reward : -202
# 2020/11/27 02:16:08
# episode : 187 | final step : 98 | total reward : -202
# 2020/11/27 02:16:10
# episode : 188 | final step : 98 | total reward : -202
# 2020/11/27 02:16:11
# episode : 189 | final step : 98 | total reward : -202
# 2020/11/27 02:16:13
# episode : 190 | final step : 98 | total reward : -202
# 2020/11/27 02:16:15
# episode : 191 | final step : 98 | total reward : -202
# 2020/11/27 02:16:16
# episode : 192 | final step : 98 | total reward : -202
# 2020/11/27 02:16:18
# episode : 193 | final step : 98 | total reward : -202
# 2020/11/27 02:16:20
# episode : 194 | final step : 98 | total reward : -202
# 2020/11/27 02:16:22
# episode : 195 | final step : 98 | total reward : -202
# 2020/11/27 02:16:23
# episode : 196 | final step : 98 | total reward : -202
# 2020/11/27 02:16:25
# episode : 197 | final step : 98 | total reward : -202
# 2020/11/27 02:16:27
# episode : 198 | final step : 98 | total reward : -202
# 2020/11/27 02:16:28
# episode : 199 | final step : 98 | total reward : -202
# 2020/11/27 02:16:30
# episode : 200 | final step : 98 | total reward : -202
# 2020/11/27 02:16:32
# episode : 201 | final step : 98 | total reward : -202
# 2020/11/27 02:16:34
# episode : 202 | final step : 98 | total reward : -202
# 2020/11/27 02:16:35
# episode : 203 | final step : 98 | total reward : -202
# 2020/11/27 02:16:37
# episode : 204 | final step : 98 | total reward : -202
# 2020/11/27 02:16:39
# episode : 205 | final step : 98 | total reward : -202
# 2020/11/27 02:16:40
# episode : 206 | final step : 98 | total reward : -202
# 2020/11/27 02:16:42
# episode : 207 | final step : 98 | total reward : -202
# 2020/11/27 02:16:44
# episode : 208 | final step : 98 | total reward : -202
# 2020/11/27 02:16:46
# episode : 209 | final step : 99 | total reward : -201
# 2020/11/27 02:16:47
# episode : 210 | final step : 99 | total reward : -201
# 2020/11/27 02:16:49
# episode : 211 | final step : 98 | total reward : -202
# 2020/11/27 02:16:51
# episode : 212 | final step : 98 | total reward : -202
# 2020/11/27 02:16:52
# episode : 213 | final step : 98 | total reward : -202
# 2020/11/27 02:16:54
# episode : 214 | final step : 98 | total reward : -202
# 2020/11/27 02:16:56
# episode : 215 | final step : 98 | total reward : -202
# 2020/11/27 02:16:57
# episode : 216 | final step : 98 | total reward : -202
# 2020/11/27 02:16:59
# episode : 217 | final step : 98 | total reward : -202
# 2020/11/27 02:17:01
# episode : 218 | final step : 98 | total reward : -202
# 2020/11/27 02:17:03
# episode : 219 | final step : 100 | total reward : 101
# 2020/11/27 02:17:04
# episode : 220 | final step : 100 | total reward : -200
# 2020/11/27 02:17:06
# episode : 221 | final step : 98 | total reward : -202
# 2020/11/27 02:17:07
# episode : 222 | final step : 98 | total reward : -202
# 2020/11/27 02:17:09
# episode : 223 | final step : 98 | total reward : -202
# 2020/11/27 02:17:11
# episode : 224 | final step : 98 | total reward : -202
# 2020/11/27 02:17:12
# episode : 225 | final step : 98 | total reward : -202
# 2020/11/27 02:17:14
# episode : 226 | final step : 100 | total reward : 101
# 2020/11/27 02:17:16
# episode : 227 | final step : 98 | total reward : -202
# 2020/11/27 02:17:17
# episode : 228 | final step : 98 | total reward : -202
# 2020/11/27 02:17:19
# episode : 229 | final step : 98 | total reward : -202
# 2020/11/27 02:17:21
# episode : 230 | final step : 100 | total reward : 101
# 2020/11/27 02:17:23
# episode : 231 | final step : 98 | total reward : -202
# 2020/11/27 02:17:24
# episode : 232 | final step : 98 | total reward : -202
# 2020/11/27 02:17:26
# episode : 233 | final step : 98 | total reward : -202
# 2020/11/27 02:17:28
# episode : 234 | final step : 98 | total reward : -202
# 2020/11/27 02:17:30
# episode : 235 | final step : 98 | total reward : -202
# 2020/11/27 02:17:31
# episode : 236 | final step : 98 | total reward : -202
# 2020/11/27 02:17:33
# episode : 237 | final step : 98 | total reward : -202
# 2020/11/27 02:17:35
# episode : 238 | final step : 98 | total reward : -202
# 2020/11/27 02:17:36
# episode : 239 | final step : 98 | total reward : -202
# 2020/11/27 02:17:38
# episode : 240 | final step : 98 | total reward : -202
# 2020/11/27 02:17:40
# episode : 241 | final step : 98 | total reward : -202
# 2020/11/27 02:17:42
# episode : 242 | final step : 98 | total reward : -202
# 2020/11/27 02:17:43
# episode : 243 | final step : 98 | total reward : -202
# 2020/11/27 02:17:45
# episode : 244 | final step : 98 | total reward : -202
# 2020/11/27 02:17:47
# episode : 245 | final step : 98 | total reward : -202
# 2020/11/27 02:17:48
# episode : 246 | final step : 98 | total reward : -202
# 2020/11/27 02:17:50
# episode : 247 | final step : 98 | total reward : -202
# 2020/11/27 02:17:52
# episode : 248 | final step : 98 | total reward : -202
# 2020/11/27 02:17:54
# episode : 249 | final step : 99 | total reward : -201
# 2020/11/27 02:17:55
# episode : 250 | final step : 98 | total reward : -202
# 2020/11/27 02:17:57
# episode : 251 | final step : 98 | total reward : -202
# 2020/11/27 02:17:59
# episode : 252 | final step : 98 | total reward : -202
# 2020/11/27 02:18:00
# episode : 253 | final step : 99 | total reward : -201
# 2020/11/27 02:18:02
# episode : 254 | final step : 99 | total reward : -201
# 2020/11/27 02:18:04
# episode : 255 | final step : 98 | total reward : -202
# 2020/11/27 02:18:06
# episode : 256 | final step : 98 | total reward : -202
# 2020/11/27 02:18:07
# episode : 257 | final step : 98 | total reward : -202
# 2020/11/27 02:18:09
# episode : 258 | final step : 98 | total reward : -202
# 2020/11/27 02:18:11
# episode : 259 | final step : 100 | total reward : 101
# 2020/11/27 02:18:12
# episode : 260 | final step : 98 | total reward : -202
# 2020/11/27 02:18:14
# episode : 261 | final step : 98 | total reward : -202
# 2020/11/27 02:18:16
# episode : 262 | final step : 98 | total reward : -202
# 2020/11/27 02:18:17
# episode : 263 | final step : 99 | total reward : -201
# 2020/11/27 02:18:19
# episode : 264 | final step : 100 | total reward : 101
# 2020/11/27 02:18:21
# episode : 265 | final step : 98 | total reward : -202
# 2020/11/27 02:18:22
# episode : 266 | final step : 98 | total reward : -202
# 2020/11/27 02:18:24
# episode : 267 | final step : 98 | total reward : -202
# 2020/11/27 02:18:26
# episode : 268 | final step : 99 | total reward : -201
# 2020/11/27 02:18:28
# episode : 269 | final step : 98 | total reward : -202
# 2020/11/27 02:18:29
# episode : 270 | final step : 98 | total reward : -202
# 2020/11/27 02:18:31
# episode : 271 | final step : 99 | total reward : -201
# 2020/11/27 02:18:33
# episode : 272 | final step : 99 | total reward : -201
# 2020/11/27 02:18:34
# episode : 273 | final step : 98 | total reward : -202
# 2020/11/27 02:18:36
# episode : 274 | final step : 99 | total reward : -201
# 2020/11/27 02:18:38
# episode : 275 | final step : 98 | total reward : -202
# 2020/11/27 02:18:40
# episode : 276 | final step : 98 | total reward : -202
# 2020/11/27 02:18:41
# episode : 277 | final step : 98 | total reward : -202
# 2020/11/27 02:18:43
# episode : 278 | final step : 98 | total reward : -202
# 2020/11/27 02:18:45
# episode : 279 | final step : 100 | total reward : 101
# 2020/11/27 02:18:46
# episode : 280 | final step : 98 | total reward : -202
# 2020/11/27 02:18:48
# episode : 281 | final step : 99 | total reward : -201
# 2020/11/27 02:18:50
# episode : 282 | final step : 98 | total reward : -202
# 2020/11/27 02:18:51
# episode : 283 | final step : 98 | total reward : -202
# 2020/11/27 02:18:53
# episode : 284 | final step : 98 | total reward : -202
# 2020/11/27 02:18:55
# episode : 285 | final step : 98 | total reward : -202
# 2020/11/27 02:18:57
# episode : 286 | final step : 98 | total reward : -202
# 2020/11/27 02:18:58
# episode : 287 | final step : 99 | total reward : -201
# 2020/11/27 02:19:00
# episode : 288 | final step : 99 | total reward : -201
# 2020/11/27 02:19:02
# episode : 289 | final step : 98 | total reward : -202
# 2020/11/27 02:19:04
# episode : 290 | final step : 98 | total reward : -202
# 2020/11/27 02:19:06
# episode : 291 | final step : 100 | total reward : 101
# 2020/11/27 02:19:08
# episode : 292 | final step : 98 | total reward : -202
# 2020/11/27 02:19:10
# episode : 293 | final step : 98 | total reward : -202
# 2020/11/27 02:19:11
# episode : 294 | final step : 98 | total reward : -202
# 2020/11/27 02:19:13
# episode : 295 | final step : 98 | total reward : -202
# 2020/11/27 02:19:15
# episode : 296 | final step : 98 | total reward : -202
# 2020/11/27 02:19:17
# episode : 297 | final step : 100 | total reward : -200
# 2020/11/27 02:19:19
# episode : 298 | final step : 100 | total reward : 101
# 2020/11/27 02:19:21
# episode : 299 | final step : 98 | total reward : -202
# 2020/11/27 02:19:23
# episode : 300 | final step : 98 | total reward : -202
# 2020/11/27 02:19:25
# episode : 301 | final step : 98 | total reward : -202
# 2020/11/27 02:19:27
# episode : 302 | final step : 98 | total reward : -202
# 2020/11/27 02:19:29
# episode : 303 | final step : 98 | total reward : -202
# 2020/11/27 02:19:31
# episode : 304 | final step : 98 | total reward : -202
# 2020/11/27 02:19:33
# episode : 305 | final step : 98 | total reward : -202
# 2020/11/27 02:19:35
# episode : 306 | final step : 98 | total reward : -202
# 2020/11/27 02:19:37
# episode : 307 | final step : 100 | total reward : 101
# 2020/11/27 02:19:39
# episode : 308 | final step : 98 | total reward : -202
# 2020/11/27 02:19:41
# episode : 309 | final step : 98 | total reward : -202
# 2020/11/27 02:19:42
# episode : 310 | final step : 98 | total reward : -202
# 2020/11/27 02:19:44
# episode : 311 | final step : 98 | total reward : -202
# 2020/11/27 02:19:46
# episode : 312 | final step : 98 | total reward : -202
# 2020/11/27 02:19:47
# episode : 313 | final step : 98 | total reward : -202
# 2020/11/27 02:19:49
# episode : 314 | final step : 98 | total reward : -202
# 2020/11/27 02:19:51
# episode : 315 | final step : 98 | total reward : -202
# 2020/11/27 02:19:53
# episode : 316 | final step : 98 | total reward : -202
# 2020/11/27 02:19:54
# episode : 317 | final step : 98 | total reward : -202
# 2020/11/27 02:19:56
# episode : 318 | final step : 98 | total reward : -202
# 2020/11/27 02:19:58
# episode : 319 | final step : 98 | total reward : -202
# 2020/11/27 02:19:59
# episode : 320 | final step : 98 | total reward : -202
# 2020/11/27 02:20:01
# episode : 321 | final step : 98 | total reward : -202
# 2020/11/27 02:20:03
# episode : 322 | final step : 98 | total reward : -202
# 2020/11/27 02:20:05
# episode : 323 | final step : 98 | total reward : -202
# 2020/11/27 02:20:06
# episode : 324 | final step : 98 | total reward : -202
# 2020/11/27 02:20:08
# episode : 325 | final step : 98 | total reward : -202
# 2020/11/27 02:20:10
# episode : 326 | final step : 98 | total reward : -202
# 2020/11/27 02:20:12
# episode : 327 | final step : 98 | total reward : -202
# 2020/11/27 02:20:13
# episode : 328 | final step : 98 | total reward : -202
# 2020/11/27 02:20:15
# episode : 329 | final step : 98 | total reward : -202
# 2020/11/27 02:20:17
# episode : 330 | final step : 98 | total reward : -202
# 2020/11/27 02:20:18
# episode : 331 | final step : 99 | total reward : -201
# 2020/11/27 02:20:20
# episode : 332 | final step : 98 | total reward : -202
# 2020/11/27 02:20:22
# episode : 333 | final step : 99 | total reward : -201
# 2020/11/27 02:20:23
# episode : 334 | final step : 98 | total reward : -202
# 2020/11/27 02:20:25
# episode : 335 | final step : 98 | total reward : -202
# 2020/11/27 02:20:27
# episode : 336 | final step : 98 | total reward : -202
# 2020/11/27 02:20:28
# episode : 337 | final step : 98 | total reward : -202
# 2020/11/27 02:20:30
# episode : 338 | final step : 98 | total reward : -202
# 2020/11/27 02:20:32
# episode : 339 | final step : 98 | total reward : -202
# 2020/11/27 02:20:33
# episode : 340 | final step : 98 | total reward : -202
# 2020/11/27 02:20:35
# episode : 341 | final step : 98 | total reward : -202
# 2020/11/27 02:20:37
# episode : 342 | final step : 99 | total reward : -201
# 2020/11/27 02:20:39
# episode : 343 | final step : 98 | total reward : -202
# 2020/11/27 02:20:40
# episode : 344 | final step : 98 | total reward : -202
# 2020/11/27 02:20:42
# episode : 345 | final step : 98 | total reward : -202
# 2020/11/27 02:20:44
# episode : 346 | final step : 98 | total reward : -202
# 2020/11/27 02:20:46
# episode : 347 | final step : 98 | total reward : -202
# 2020/11/27 02:20:47
# episode : 348 | final step : 100 | total reward : 101
# 2020/11/27 02:20:49
# episode : 349 | final step : 98 | total reward : -202
# 2020/11/27 02:20:51
# episode : 350 | final step : 98 | total reward : -202
# 2020/11/27 02:20:52
# episode : 351 | final step : 98 | total reward : -202
# 2020/11/27 02:20:54
# episode : 352 | final step : 98 | total reward : -202
# 2020/11/27 02:20:56
# episode : 353 | final step : 98 | total reward : -202
# 2020/11/27 02:20:58
# episode : 354 | final step : 98 | total reward : -202
# 2020/11/27 02:20:59
# episode : 355 | final step : 100 | total reward : 101
# 2020/11/27 02:21:01
# episode : 356 | final step : 100 | total reward : 101
# 2020/11/27 02:21:03
# episode : 357 | final step : 100 | total reward : 101
# 2020/11/27 02:21:05
# episode : 358 | final step : 98 | total reward : -202
# 2020/11/27 02:21:06
# episode : 359 | final step : 98 | total reward : -202
# 2020/11/27 02:21:08
# episode : 360 | final step : 100 | total reward : -200
# 2020/11/27 02:21:10
# episode : 361 | final step : 98 | total reward : -202
# 2020/11/27 02:21:11
# episode : 362 | final step : 98 | total reward : -202
# 2020/11/27 02:21:13
# episode : 363 | final step : 98 | total reward : -202
# 2020/11/27 02:21:15
# episode : 364 | final step : 98 | total reward : -202
# 2020/11/27 02:21:16
# episode : 365 | final step : 99 | total reward : -201
# 2020/11/27 02:21:18
# episode : 366 | final step : 98 | total reward : -202
# 2020/11/27 02:21:20
# episode : 367 | final step : 98 | total reward : -202
# 2020/11/27 02:21:21
# episode : 368 | final step : 98 | total reward : -202
# 2020/11/27 02:21:23
# episode : 369 | final step : 100 | total reward : 101
# 2020/11/27 02:21:25
# episode : 370 | final step : 98 | total reward : -202
# 2020/11/27 02:21:27
# episode : 371 | final step : 98 | total reward : -202
# 2020/11/27 02:21:28
# episode : 372 | final step : 98 | total reward : -202
# 2020/11/27 02:21:30
# episode : 373 | final step : 98 | total reward : -202
# 2020/11/27 02:21:32
# episode : 374 | final step : 98 | total reward : -202
# 2020/11/27 02:21:34
# episode : 375 | final step : 98 | total reward : -202
# 2020/11/27 02:21:35
# episode : 376 | final step : 100 | total reward : 101
# 2020/11/27 02:21:37
# episode : 377 | final step : 98 | total reward : -202
# 2020/11/27 02:21:39
# episode : 378 | final step : 99 | total reward : -201
# 2020/11/27 02:21:41
# episode : 379 | final step : 98 | total reward : -202
# 2020/11/27 02:21:42
# episode : 380 | final step : 98 | total reward : -202
# 2020/11/27 02:21:44
# episode : 381 | final step : 98 | total reward : -202
# 2020/11/27 02:21:46
# episode : 382 | final step : 100 | total reward : 101
# 2020/11/27 02:21:48
# episode : 383 | final step : 100 | total reward : 101
# 2020/11/27 02:21:49
# episode : 384 | final step : 100 | total reward : -200
# 2020/11/27 02:21:51
# episode : 385 | final step : 98 | total reward : -202
# 2020/11/27 02:21:53
# episode : 386 | final step : 98 | total reward : -202
# 2020/11/27 02:21:54
# episode : 387 | final step : 99 | total reward : -201
# 2020/11/27 02:21:56
# episode : 388 | final step : 98 | total reward : -202
# 2020/11/27 02:21:58
# episode : 389 | final step : 98 | total reward : -202
# 2020/11/27 02:22:00
# episode : 390 | final step : 98 | total reward : -202
# 2020/11/27 02:22:01
# episode : 391 | final step : 98 | total reward : -202
# 2020/11/27 02:22:03
# episode : 392 | final step : 98 | total reward : -202
# 2020/11/27 02:22:05
# episode : 393 | final step : 98 | total reward : -202
# 2020/11/27 02:22:07
# episode : 394 | final step : 100 | total reward : 101
# 2020/11/27 02:22:09
# episode : 395 | final step : 100 | total reward : 101
# 2020/11/27 02:22:10
# episode : 396 | final step : 98 | total reward : -202
# 2020/11/27 02:22:12
# episode : 397 | final step : 98 | total reward : -202
# 2020/11/27 02:22:14
# episode : 398 | final step : 98 | total reward : -202
# 2020/11/27 02:22:16
# episode : 399 | final step : 98 | total reward : -202
# 2020/11/27 02:22:17
# episode : 400 | final step : 99 | total reward : -201
# 2020/11/27 02:22:19
# episode : 401 | final step : 98 | total reward : -202
# 2020/11/27 02:22:21
# episode : 402 | final step : 100 | total reward : 101
# 2020/11/27 02:22:22
# episode : 403 | final step : 99 | total reward : -201
# 2020/11/27 02:22:24
# episode : 404 | final step : 99 | total reward : -201
# 2020/11/27 02:22:26
# episode : 405 | final step : 98 | total reward : -202
# 2020/11/27 02:22:28
# episode : 406 | final step : 98 | total reward : -202
# 2020/11/27 02:22:29
# episode : 407 | final step : 98 | total reward : -202
# 2020/11/27 02:22:31
# episode : 408 | final step : 98 | total reward : -202
# 2020/11/27 02:22:32
# episode : 409 | final step : 98 | total reward : -202
# 2020/11/27 02:22:34
# episode : 410 | final step : 98 | total reward : -202
# 2020/11/27 02:22:36
# episode : 411 | final step : 99 | total reward : -201
# 2020/11/27 02:22:38
# episode : 412 | final step : 98 | total reward : -202
# 2020/11/27 02:22:39
# episode : 413 | final step : 99 | total reward : -201
# 2020/11/27 02:22:41
# episode : 414 | final step : 98 | total reward : -202
# 2020/11/27 02:22:43
# episode : 415 | final step : 98 | total reward : -202
# 2020/11/27 02:22:45
# episode : 416 | final step : 98 | total reward : -202
# 2020/11/27 02:22:46
# episode : 417 | final step : 98 | total reward : -202
# 2020/11/27 02:22:48
# episode : 418 | final step : 98 | total reward : -202
# 2020/11/27 02:22:50
# episode : 419 | final step : 98 | total reward : -202
# 2020/11/27 02:22:51
# episode : 420 | final step : 98 | total reward : -202
# 2020/11/27 02:22:53
# episode : 421 | final step : 99 | total reward : -201
# 2020/11/27 02:22:55
# episode : 422 | final step : 100 | total reward : 101
# 2020/11/27 02:22:57
# episode : 423 | final step : 99 | total reward : -201
# 2020/11/27 02:22:58
# episode : 424 | final step : 98 | total reward : -202
# 2020/11/27 02:23:00
# episode : 425 | final step : 98 | total reward : -202
# 2020/11/27 02:23:02
# episode : 426 | final step : 98 | total reward : -202
# 2020/11/27 02:23:04
# episode : 427 | final step : 99 | total reward : -201
# 2020/11/27 02:23:05
# episode : 428 | final step : 98 | total reward : -202
# 2020/11/27 02:23:07
# episode : 429 | final step : 98 | total reward : -202
# 2020/11/27 02:23:09
# episode : 430 | final step : 98 | total reward : -202
# 2020/11/27 02:23:11
# episode : 431 | final step : 98 | total reward : -202
# 2020/11/27 02:23:12
# episode : 432 | final step : 99 | total reward : -201
# 2020/11/27 02:23:14
# episode : 433 | final step : 98 | total reward : -202
# 2020/11/27 02:23:16
# episode : 434 | final step : 98 | total reward : -202
# 2020/11/27 02:23:17
# episode : 435 | final step : 98 | total reward : -202
# 2020/11/27 02:23:19
# episode : 436 | final step : 100 | total reward : 101
# 2020/11/27 02:23:21
# episode : 437 | final step : 98 | total reward : -202
# 2020/11/27 02:23:23
# episode : 438 | final step : 98 | total reward : -202
# 2020/11/27 02:23:24
# episode : 439 | final step : 98 | total reward : -202
# 2020/11/27 02:23:26
# episode : 440 | final step : 98 | total reward : -202
# 2020/11/27 02:23:28
# episode : 441 | final step : 98 | total reward : -202
# 2020/11/27 02:23:30
# episode : 442 | final step : 98 | total reward : -202
# 2020/11/27 02:23:32
# episode : 443 | final step : 99 | total reward : -201
# 2020/11/27 02:23:34
# episode : 444 | final step : 98 | total reward : -202
# 2020/11/27 02:23:36
# episode : 445 | final step : 98 | total reward : -202
# 2020/11/27 02:23:38
# episode : 446 | final step : 98 | total reward : -202
# 2020/11/27 02:23:39
# episode : 447 | final step : 100 | total reward : 101
# 2020/11/27 02:23:41
# episode : 448 | final step : 98 | total reward : -202
# 2020/11/27 02:23:43
# episode : 449 | final step : 98 | total reward : -202
# 2020/11/27 02:23:45
# episode : 450 | final step : 98 | total reward : -202
# 2020/11/27 02:23:46
# episode : 451 | final step : 98 | total reward : -202
# 2020/11/27 02:23:48
# episode : 452 | final step : 100 | total reward : 101
# 2020/11/27 02:23:50
# episode : 453 | final step : 98 | total reward : -202
# 2020/11/27 02:23:52
# episode : 454 | final step : 98 | total reward : -202
# 2020/11/27 02:23:53
# episode : 455 | final step : 98 | total reward : -202
# 2020/11/27 02:23:55
# episode : 456 | final step : 98 | total reward : -202
# 2020/11/27 02:23:57
# episode : 457 | final step : 98 | total reward : -202
# 2020/11/27 02:23:58
# episode : 458 | final step : 98 | total reward : -202
# 2020/11/27 02:24:00
# episode : 459 | final step : 98 | total reward : -202
# 2020/11/27 02:24:02
# episode : 460 | final step : 99 | total reward : -201
# 2020/11/27 02:24:04
# episode : 461 | final step : 98 | total reward : -202
# 2020/11/27 02:24:05
# episode : 462 | final step : 98 | total reward : -202
# 2020/11/27 02:24:07
# episode : 463 | final step : 99 | total reward : -201
# 2020/11/27 02:24:09
# episode : 464 | final step : 98 | total reward : -202
# 2020/11/27 02:24:11
# episode : 465 | final step : 98 | total reward : -202
# 2020/11/27 02:24:12
# episode : 466 | final step : 98 | total reward : -202
# 2020/11/27 02:24:14
# episode : 467 | final step : 98 | total reward : -202
# 2020/11/27 02:24:16
# episode : 468 | final step : 98 | total reward : -202
# 2020/11/27 02:24:17
# episode : 469 | final step : 100 | total reward : 101
# 2020/11/27 02:24:19
# episode : 470 | final step : 99 | total reward : -201
# 2020/11/27 02:24:21
# episode : 471 | final step : 100 | total reward : 101
# 2020/11/27 02:24:23
# episode : 472 | final step : 98 | total reward : -202
# 2020/11/27 02:24:24
# episode : 473 | final step : 98 | total reward : -202
# 2020/11/27 02:24:26
# episode : 474 | final step : 98 | total reward : -202
# 2020/11/27 02:24:28
# episode : 475 | final step : 98 | total reward : -202
# 2020/11/27 02:24:29
# episode : 476 | final step : 98 | total reward : -202
# 2020/11/27 02:24:31
# episode : 477 | final step : 99 | total reward : -201
# 2020/11/27 02:24:33
# episode : 478 | final step : 98 | total reward : -202
# 2020/11/27 02:24:34
# episode : 479 | final step : 98 | total reward : -202
# 2020/11/27 02:24:36
# episode : 480 | final step : 98 | total reward : -202
# 2020/11/27 02:24:38
# episode : 481 | final step : 99 | total reward : -201
# 2020/11/27 02:24:39
# episode : 482 | final step : 98 | total reward : -202
# 2020/11/27 02:24:41
# episode : 483 | final step : 98 | total reward : -202
# 2020/11/27 02:24:43
# episode : 484 | final step : 98 | total reward : -202
# 2020/11/27 02:24:45
# episode : 485 | final step : 98 | total reward : -202
# 2020/11/27 02:24:46
# episode : 486 | final step : 98 | total reward : -202
# 2020/11/27 02:24:48
# episode : 487 | final step : 98 | total reward : -202
# 2020/11/27 02:24:50
# episode : 488 | final step : 98 | total reward : -202
# 2020/11/27 02:24:51
# episode : 489 | final step : 98 | total reward : -202
# 2020/11/27 02:24:53
# episode : 490 | final step : 98 | total reward : -202
# 2020/11/27 02:24:55
# episode : 491 | final step : 98 | total reward : -202
# 2020/11/27 02:24:56
# episode : 492 | final step : 98 | total reward : -202
# 2020/11/27 02:24:58
# episode : 493 | final step : 99 | total reward : -201
# 2020/11/27 02:25:00
# episode : 494 | final step : 98 | total reward : -202
# 2020/11/27 02:25:02
# episode : 495 | final step : 99 | total reward : -201
# 2020/11/27 02:25:03
# episode : 496 | final step : 98 | total reward : -202
# 2020/11/27 02:25:05
# episode : 497 | final step : 98 | total reward : -202
# 2020/11/27 02:25:07
# episode : 498 | final step : 98 | total reward : -202
# 2020/11/27 02:25:09
# episode : 499 | final step : 98 | total reward : -202
# 2020/11/27 02:25:10
# episode : 500 | final step : 98 | total reward : -202
# 2020/11/27 02:25:12
# episode : 501 | final step : 99 | total reward : -201
# 2020/11/27 02:25:14
# episode : 502 | final step : 98 | total reward : -202
# 2020/11/27 02:25:16
# episode : 503 | final step : 98 | total reward : -202
# 2020/11/27 02:25:18
# episode : 504 | final step : 100 | total reward : 101
# 2020/11/27 02:25:19
# episode : 505 | final step : 99 | total reward : -201
# 2020/11/27 02:25:21
# episode : 506 | final step : 98 | total reward : -202
# 2020/11/27 02:25:23
# episode : 507 | final step : 98 | total reward : -202
# 2020/11/27 02:25:24
# episode : 508 | final step : 98 | total reward : -202
# 2020/11/27 02:25:26
# episode : 509 | final step : 99 | total reward : -201
# 2020/11/27 02:25:28
# episode : 510 | final step : 98 | total reward : -202
# 2020/11/27 02:25:29
# episode : 511 | final step : 98 | total reward : -202
# 2020/11/27 02:25:31
# episode : 512 | final step : 98 | total reward : -202
# 2020/11/27 02:25:33
# episode : 513 | final step : 98 | total reward : -202
# 2020/11/27 02:25:35
# episode : 514 | final step : 100 | total reward : 101
# 2020/11/27 02:25:36
# episode : 515 | final step : 98 | total reward : -202
# 2020/11/27 02:25:38
# episode : 516 | final step : 98 | total reward : -202
# 2020/11/27 02:25:39
# episode : 517 | final step : 98 | total reward : -202
# 2020/11/27 02:25:41
# episode : 518 | final step : 98 | total reward : -202
# 2020/11/27 02:25:43
# episode : 519 | final step : 98 | total reward : -202
# 2020/11/27 02:25:45
# episode : 520 | final step : 98 | total reward : -202
# 2020/11/27 02:25:46
# episode : 521 | final step : 98 | total reward : -202
# 2020/11/27 02:25:48
# episode : 522 | final step : 98 | total reward : -202
# 2020/11/27 02:25:50
# episode : 523 | final step : 98 | total reward : -202
# 2020/11/27 02:25:51
# episode : 524 | final step : 98 | total reward : -202
# 2020/11/27 02:25:53
# episode : 525 | final step : 98 | total reward : -202
# 2020/11/27 02:25:55
# episode : 526 | final step : 98 | total reward : -202
# 2020/11/27 02:25:57
# episode : 527 | final step : 98 | total reward : -202
# 2020/11/27 02:25:58
# episode : 528 | final step : 98 | total reward : -202
# 2020/11/27 02:26:00
# episode : 529 | final step : 99 | total reward : -201
# 2020/11/27 02:26:02
# episode : 530 | final step : 98 | total reward : -202
# 2020/11/27 02:26:03
# episode : 531 | final step : 99 | total reward : -201
# 2020/11/27 02:26:05
# episode : 532 | final step : 98 | total reward : -202
# 2020/11/27 02:26:07
# episode : 533 | final step : 98 | total reward : -202
# 2020/11/27 02:26:08
# episode : 534 | final step : 98 | total reward : -202
# 2020/11/27 02:26:10
# episode : 535 | final step : 98 | total reward : -202
# 2020/11/27 02:26:12
# episode : 536 | final step : 98 | total reward : -202
# 2020/11/27 02:26:13
# episode : 537 | final step : 98 | total reward : -202
# 2020/11/27 02:26:15
# episode : 538 | final step : 98 | total reward : -202
# 2020/11/27 02:26:17
# episode : 539 | final step : 100 | total reward : 101
# 2020/11/27 02:26:19
# episode : 540 | final step : 98 | total reward : -202
# 2020/11/27 02:26:20
# episode : 541 | final step : 100 | total reward : 101
# 2020/11/27 02:26:22
# episode : 542 | final step : 98 | total reward : -202
# 2020/11/27 02:26:24
# episode : 543 | final step : 98 | total reward : -202
# 2020/11/27 02:26:25
# episode : 544 | final step : 98 | total reward : -202
# 2020/11/27 02:26:27
# episode : 545 | final step : 98 | total reward : -202
# 2020/11/27 02:26:29
# episode : 546 | final step : 98 | total reward : -202
# 2020/11/27 02:26:30
# episode : 547 | final step : 98 | total reward : -202
# 2020/11/27 02:26:32
# episode : 548 | final step : 98 | total reward : -202
# 2020/11/27 02:26:34
# episode : 549 | final step : 98 | total reward : -202
# 2020/11/27 02:26:36
# episode : 550 | final step : 98 | total reward : -202
# 2020/11/27 02:26:37
# episode : 551 | final step : 98 | total reward : -202
# 2020/11/27 02:26:39
# episode : 552 | final step : 98 | total reward : -202
# 2020/11/27 02:26:40
# episode : 553 | final step : 98 | total reward : -202
# 2020/11/27 02:26:42
# episode : 554 | final step : 98 | total reward : -202
# 2020/11/27 02:26:44
# episode : 555 | final step : 99 | total reward : -201
# 2020/11/27 02:26:46
# episode : 556 | final step : 98 | total reward : -202
# 2020/11/27 02:26:47
# episode : 557 | final step : 98 | total reward : -202
# 2020/11/27 02:26:49
# episode : 558 | final step : 98 | total reward : -202
# 2020/11/27 02:26:51
# episode : 559 | final step : 98 | total reward : -202
# 2020/11/27 02:26:53
# episode : 560 | final step : 98 | total reward : -202
# 2020/11/27 02:26:54
# episode : 561 | final step : 98 | total reward : -202
# 2020/11/27 02:26:56
# episode : 562 | final step : 98 | total reward : -202
# 2020/11/27 02:26:58
# episode : 563 | final step : 98 | total reward : -202
# 2020/11/27 02:27:00
# episode : 564 | final step : 98 | total reward : -202
# 2020/11/27 02:27:01
# episode : 565 | final step : 98 | total reward : -202
# 2020/11/27 02:27:03
# episode : 566 | final step : 98 | total reward : -202
# 2020/11/27 02:27:05
# episode : 567 | final step : 98 | total reward : -202
# 2020/11/27 02:27:06
# episode : 568 | final step : 98 | total reward : -202
# 2020/11/27 02:27:08
# episode : 569 | final step : 98 | total reward : -202
# 2020/11/27 02:27:09
# episode : 570 | final step : 98 | total reward : -202
# 2020/11/27 02:27:11
# episode : 571 | final step : 100 | total reward : 101
# 2020/11/27 02:27:13
# episode : 572 | final step : 98 | total reward : -202
# 2020/11/27 02:27:15
# episode : 573 | final step : 99 | total reward : -201
# 2020/11/27 02:27:17
# episode : 574 | final step : 98 | total reward : -202
# 2020/11/27 02:27:18
# episode : 575 | final step : 98 | total reward : -202
# 2020/11/27 02:27:20
# episode : 576 | final step : 98 | total reward : -202
# 2020/11/27 02:27:22
# episode : 577 | final step : 98 | total reward : -202
# 2020/11/27 02:27:24
# episode : 578 | final step : 98 | total reward : -202
# 2020/11/27 02:27:25
# episode : 579 | final step : 98 | total reward : -202
# 2020/11/27 02:27:27
# episode : 580 | final step : 98 | total reward : -202
# 2020/11/27 02:27:29
# episode : 581 | final step : 98 | total reward : -202
# 2020/11/27 02:27:31
# episode : 582 | final step : 100 | total reward : 101
# 2020/11/27 02:27:32
# episode : 583 | final step : 99 | total reward : -201
# 2020/11/27 02:27:34
# episode : 584 | final step : 98 | total reward : -202
# 2020/11/27 02:27:36
# episode : 585 | final step : 98 | total reward : -202
# 2020/11/27 02:27:37
# episode : 586 | final step : 100 | total reward : 101
# 2020/11/27 02:27:39
# episode : 587 | final step : 98 | total reward : -202
# 2020/11/27 02:27:41
# episode : 588 | final step : 98 | total reward : -202
# 2020/11/27 02:27:42
# episode : 589 | final step : 98 | total reward : -202
# 2020/11/27 02:27:44
# episode : 590 | final step : 98 | total reward : -202
# 2020/11/27 02:27:46
# episode : 591 | final step : 98 | total reward : -202
# 2020/11/27 02:27:47
# episode : 592 | final step : 98 | total reward : -202
# 2020/11/27 02:27:49
# episode : 593 | final step : 100 | total reward : -200
# 2020/11/27 02:27:51
# episode : 594 | final step : 98 | total reward : -202
# 2020/11/27 02:27:53
# episode : 595 | final step : 98 | total reward : -202
# 2020/11/27 02:27:54
# episode : 596 | final step : 98 | total reward : -202
# 2020/11/27 02:27:56
# episode : 597 | final step : 99 | total reward : -201
# 2020/11/27 02:27:57
# episode : 598 | final step : 100 | total reward : -200
# 2020/11/27 02:27:59
# episode : 599 | final step : 98 | total reward : -202
# 2020/11/27 02:28:01
# episode : 600 | final step : 98 | total reward : -202
# 2020/11/27 02:28:03
# episode : 601 | final step : 98 | total reward : -202
# 2020/11/27 02:28:04
# episode : 602 | final step : 98 | total reward : -202
# 2020/11/27 02:28:06
# episode : 603 | final step : 98 | total reward : -202
# 2020/11/27 02:28:08
# episode : 604 | final step : 99 | total reward : -201
# 2020/11/27 02:28:09
# episode : 605 | final step : 98 | total reward : -202
# 2020/11/27 02:28:11
# episode : 606 | final step : 98 | total reward : -202
# 2020/11/27 02:28:13
# episode : 607 | final step : 98 | total reward : -202
# 2020/11/27 02:28:15
# episode : 608 | final step : 98 | total reward : -202
# 2020/11/27 02:28:16
# episode : 609 | final step : 98 | total reward : -202
# 2020/11/27 02:28:18
# episode : 610 | final step : 98 | total reward : -202
# 2020/11/27 02:28:20
# episode : 611 | final step : 99 | total reward : -201
# 2020/11/27 02:28:22
# episode : 612 | final step : 98 | total reward : -202
# 2020/11/27 02:28:23
# episode : 613 | final step : 98 | total reward : -202
# 2020/11/27 02:28:25
# episode : 614 | final step : 98 | total reward : -202
# 2020/11/27 02:28:26
# episode : 615 | final step : 98 | total reward : -202
# 2020/11/27 02:28:28
# episode : 616 | final step : 98 | total reward : -202
# 2020/11/27 02:28:30
# episode : 617 | final step : 98 | total reward : -202
# 2020/11/27 02:28:32
# episode : 618 | final step : 98 | total reward : -202
# 2020/11/27 02:28:33
# episode : 619 | final step : 98 | total reward : -202
# 2020/11/27 02:28:35
# episode : 620 | final step : 98 | total reward : -202
# 2020/11/27 02:28:37
# episode : 621 | final step : 98 | total reward : -202
# 2020/11/27 02:28:39
# episode : 622 | final step : 98 | total reward : -202
# 2020/11/27 02:28:40
# episode : 623 | final step : 98 | total reward : -202
# 2020/11/27 02:28:42
# episode : 624 | final step : 98 | total reward : -202
# 2020/11/27 02:28:44
# episode : 625 | final step : 98 | total reward : -202
# 2020/11/27 02:28:46
# episode : 626 | final step : 98 | total reward : -202
# 2020/11/27 02:28:47
# episode : 627 | final step : 98 | total reward : -202
# 2020/11/27 02:28:49
# episode : 628 | final step : 98 | total reward : -202
# 2020/11/27 02:28:51
# episode : 629 | final step : 98 | total reward : -202
# 2020/11/27 02:28:52
# episode : 630 | final step : 98 | total reward : -202
# 2020/11/27 02:28:54
# episode : 631 | final step : 99 | total reward : -201
# 2020/11/27 02:28:55
# episode : 632 | final step : 99 | total reward : -201
# 2020/11/27 02:28:57
# episode : 633 | final step : 98 | total reward : -202
# 2020/11/27 02:28:59
# episode : 634 | final step : 98 | total reward : -202
# 2020/11/27 02:29:00
# episode : 635 | final step : 98 | total reward : -202
# 2020/11/27 02:29:02
# episode : 636 | final step : 98 | total reward : -202
# 2020/11/27 02:29:03
# episode : 637 | final step : 99 | total reward : -201
# 2020/11/27 02:29:05
# episode : 638 | final step : 98 | total reward : -202
# 2020/11/27 02:29:07
# episode : 639 | final step : 98 | total reward : -202
# 2020/11/27 02:29:09
# episode : 640 | final step : 98 | total reward : -202
# 2020/11/27 02:29:10
# episode : 641 | final step : 98 | total reward : -202
# 2020/11/27 02:29:12
# episode : 642 | final step : 98 | total reward : -202
# 2020/11/27 02:29:14
# episode : 643 | final step : 99 | total reward : -201
# 2020/11/27 02:29:15
# episode : 644 | final step : 98 | total reward : -202
# ...
# 2020/11/27 02:33:22
# episode : 784 | final step : 98 | total reward : -202
# 2020/11/27 02:33:24
# episode : 785 | final step : 99 | total reward : -201
# 2020/11/27 02:33:26
# episode : 786 | final step : 99 | total reward : -201
# 2020/11/27 02:33:27
# episode : 787 | final step : 98 | total reward : -202
# 2020/11/27 02:33:29
# episode : 788 | final step : 98 | total reward : -202
# 2020/11/27 02:33:31
# episode : 789 | final step : 98 | total reward : -202
# 2020/11/27 02:33:32
# episode : 790 | final step : 98 | total reward : -202
# 2020/11/27 02:33:34
# episode : 791 | final step : 99 | total reward : -201
# 2020/11/27 02:33:35
# episode : 792 | final step : 98 | total reward : -202
# 2020/11/27 02:33:37
# episode : 793 | final step : 99 | total reward : -201
# 2020/11/27 02:33:39
# episode : 794 | final step : 98 | total reward : -202
# 2020/11/27 02:33:40
# episode : 795 | final step : 99 | total reward : -201
# 2020/11/27 02:33:42
# episode : 796 | final step : 98 | total reward : -202
# 2020/11/27 02:33:44
# episode : 797 | final step : 98 | total reward : -202
# 2020/11/27 02:33:45
# episode : 798 | final step : 98 | total reward : -202
# 2020/11/27 02:33:47
# episode : 799 | final step : 99 | total reward : -201
# 2020/11/27 02:33:49
# episode : 800 | final step : 98 | total reward : -202
# 2020/11/27 02:33:50
# episode : 801 | final step : 98 | total reward : -202
# 2020/11/27 02:33:52
# episode : 802 | final step : 100 | total reward : 101
# 2020/11/27 02:33:54
# episode : 803 | final step : 98 | total reward : -202
# 2020/11/27 02:33:56
# episode : 804 | final step : 98 | total reward : -202
# 2020/11/27 02:33:57
# episode : 805 | final step : 98 | total reward : -202
# 2020/11/27 02:33:59
# episode : 806 | final step : 100 | total reward : 101
# 2020/11/27 02:34:01
# episode : 807 | final step : 100 | total reward : -200
# 2020/11/27 02:34:03
# episode : 808 | final step : 98 | total reward : -202
# 2020/11/27 02:34:04
# episode : 809 | final step : 98 | total reward : -202
# 2020/11/27 02:34:06
# episode : 810 | final step : 99 | total reward : -201
# 2020/11/27 02:34:08
# episode : 811 | final step : 98 | total reward : -202
# 2020/11/27 02:34:10
# episode : 812 | final step : 98 | total reward : -202
# 2020/11/27 02:34:11
# episode : 813 | final step : 98 | total reward : -202
# 2020/11/27 02:34:13
# episode : 814 | final step : 98 | total reward : -202
# 2020/11/27 02:34:15
# episode : 815 | final step : 98 | total reward : -202
# 2020/11/27 02:34:17
# episode : 816 | final step : 98 | total reward : -202
# 2020/11/27 02:34:18
# episode : 817 | final step : 98 | total reward : -202
# 2020/11/27 02:34:20
# episode : 818 | final step : 98 | total reward : -202
# 2020/11/27 02:34:22
# episode : 819 | final step : 98 | total reward : -202
# 2020/11/27 02:34:23
# episode : 820 | final step : 98 | total reward : -202
# 2020/11/27 02:34:25
# episode : 821 | final step : 98 | total reward : -202
# 2020/11/27 02:34:27
# episode : 822 | final step : 100 | total reward : 101
# 2020/11/27 02:34:29
# episode : 823 | final step : 98 | total reward : -202
# 2020/11/27 02:34:30
# episode : 824 | final step : 98 | total reward : -202
# 2020/11/27 02:34:32
# episode : 825 | final step : 98 | total reward : -202
# 2020/11/27 02:34:34
# episode : 826 | final step : 98 | total reward : -202
# 2020/11/27 02:34:35
# episode : 827 | final step : 98 | total reward : -202
# 2020/11/27 02:34:37
# episode : 828 | final step : 98 | total reward : -202
# 2020/11/27 02:34:38
# episode : 829 | final step : 98 | total reward : -202
# 2020/11/27 02:34:40
# episode : 830 | final step : 98 | total reward : -202
# 2020/11/27 02:34:42
# episode : 831 | final step : 98 | total reward : -202
# 2020/11/27 02:34:43
# episode : 832 | final step : 98 | total reward : -202
# 2020/11/27 02:34:45
# episode : 833 | final step : 98 | total reward : -202
# 2020/11/27 02:34:47
# episode : 834 | final step : 98 | total reward : -202
# 2020/11/27 02:34:48
# episode : 835 | final step : 98 | total reward : -202
# 2020/11/27 02:34:50
# episode : 836 | final step : 98 | total reward : -202
# 2020/11/27 02:34:52
# episode : 837 | final step : 98 | total reward : -202
# 2020/11/27 02:34:53
# episode : 838 | final step : 99 | total reward : -201
# 2020/11/27 02:34:55
# episode : 839 | final step : 98 | total reward : -202
# 2020/11/27 02:34:57
# episode : 840 | final step : 98 | total reward : -202
# 2020/11/27 02:34:59
# episode : 841 | final step : 98 | total reward : -202
# 2020/11/27 02:35:00
# episode : 842 | final step : 98 | total reward : -202
# 2020/11/27 02:35:02
# episode : 843 | final step : 98 | total reward : -202
# 2020/11/27 02:35:04
# episode : 844 | final step : 98 | total reward : -202
# 2020/11/27 02:35:06
# episode : 845 | final step : 98 | total reward : -202
# 2020/11/27 02:35:08
# episode : 846 | final step : 98 | total reward : -202
# 2020/11/27 02:35:09
# episode : 847 | final step : 98 | total reward : -202
# 2020/11/27 02:35:11
# episode : 848 | final step : 98 | total reward : -202
# 2020/11/27 02:35:13
# episode : 849 | final step : 98 | total reward : -202
# 2020/11/27 02:35:15
# episode : 850 | final step : 98 | total reward : -202
# 2020/11/27 02:35:16
# episode : 851 | final step : 98 | total reward : -202
# 2020/11/27 02:35:18
# episode : 852 | final step : 98 | total reward : -202
# 2020/11/27 02:35:20
# episode : 853 | final step : 100 | total reward : 101
# 2020/11/27 02:35:21
# episode : 854 | final step : 98 | total reward : -202
# 2020/11/27 02:35:23
# episode : 855 | final step : 98 | total reward : -202
# 2020/11/27 02:35:25
# episode : 856 | final step : 100 | total reward : 101
# 2020/11/27 02:35:26
# episode : 857 | final step : 98 | total reward : -202
# 2020/11/27 02:35:28
# episode : 858 | final step : 99 | total reward : -201
# 2020/11/27 02:35:30
# episode : 859 | final step : 99 | total reward : -201
# 2020/11/27 02:35:31
# episode : 860 | final step : 98 | total reward : -202
# 2020/11/27 02:35:33
# episode : 861 | final step : 98 | total reward : -202
# 2020/11/27 02:35:35
# episode : 862 | final step : 100 | total reward : 101
# 2020/11/27 02:35:36
# episode : 863 | final step : 98 | total reward : -202
# 2020/11/27 02:35:38
# episode : 864 | final step : 98 | total reward : -202
# 2020/11/27 02:35:40
# episode : 865 | final step : 98 | total reward : -202
# 2020/11/27 02:35:42
# episode : 866 | final step : 98 | total reward : -202
# 2020/11/27 02:35:43
# episode : 867 | final step : 98 | total reward : -202
# 2020/11/27 02:35:45
# episode : 868 | final step : 98 | total reward : -202
# 2020/11/27 02:35:47
# episode : 869 | final step : 100 | total reward : 101
# 2020/11/27 02:35:49
# episode : 870 | final step : 98 | total reward : -202
# 2020/11/27 02:35:50
# episode : 871 | final step : 99 | total reward : -201
# 2020/11/27 02:35:52
# episode : 872 | final step : 98 | total reward : -202
# 2020/11/27 02:35:54
# episode : 873 | final step : 98 | total reward : -202
# 2020/11/27 02:35:55
# episode : 874 | final step : 98 | total reward : -202
# 2020/11/27 02:35:57
# episode : 875 | final step : 98 | total reward : -202
# 2020/11/27 02:35:59
# episode : 876 | final step : 98 | total reward : -202
# 2020/11/27 02:36:00
# episode : 877 | final step : 99 | total reward : -201
# 2020/11/27 02:36:02
# episode : 878 | final step : 98 | total reward : -202
# 2020/11/27 02:36:03
# episode : 879 | final step : 98 | total reward : -202
# 2020/11/27 02:36:05
# episode : 880 | final step : 98 | total reward : -202
# 2020/11/27 02:36:07
# episode : 881 | final step : 98 | total reward : -202
# 2020/11/27 02:36:08
# episode : 882 | final step : 98 | total reward : -202
# 2020/11/27 02:36:10
# episode : 883 | final step : 98 | total reward : -202
# 2020/11/27 02:36:11
# episode : 884 | final step : 100 | total reward : 101
# 2020/11/27 02:36:13
# episode : 885 | final step : 98 | total reward : -202
# 2020/11/27 02:36:15
# episode : 886 | final step : 98 | total reward : -202
# 2020/11/27 02:36:16
# episode : 887 | final step : 98 | total reward : -202
# 2020/11/27 02:36:18
# episode : 888 | final step : 98 | total reward : -202
# 2020/11/27 02:36:20
# episode : 889 | final step : 98 | total reward : -202
# 2020/11/27 02:36:22
# episode : 890 | final step : 99 | total reward : -201
# 2020/11/27 02:36:23
# episode : 891 | final step : 98 | total reward : -202
# 2020/11/27 02:36:25
# episode : 892 | final step : 98 | total reward : -202
# 2020/11/27 02:36:27
# episode : 893 | final step : 98 | total reward : -202
# 2020/11/27 02:36:28
# episode : 894 | final step : 98 | total reward : -202
# 2020/11/27 02:36:30
# episode : 895 | final step : 100 | total reward : 101
# 2020/11/27 02:36:32
# episode : 896 | final step : 98 | total reward : -202
# 2020/11/27 02:36:34
# episode : 897 | final step : 98 | total reward : -202
# 2020/11/27 02:36:35
# episode : 898 | final step : 98 | total reward : -202
# 2020/11/27 02:36:37
# episode : 899 | final step : 98 | total reward : -202
# 2020/11/27 02:36:39
# episode : 900 | final step : 98 | total reward : -202
# 2020/11/27 02:36:40
# episode : 901 | final step : 98 | total reward : -202
# 2020/11/27 02:36:42
# episode : 902 | final step : 98 | total reward : -202
# 2020/11/27 02:36:44
# episode : 903 | final step : 98 | total reward : -202
# 2020/11/27 02:36:46
# episode : 904 | final step : 98 | total reward : -202
# 2020/11/27 02:36:47
# episode : 905 | final step : 98 | total reward : -202
# 2020/11/27 02:36:49
# episode : 906 | final step : 98 | total reward : -202
# 2020/11/27 02:36:51
# episode : 907 | final step : 98 | total reward : -202
# 2020/11/27 02:36:53
# episode : 908 | final step : 98 | total reward : -202
# 2020/11/27 02:36:54
# episode : 909 | final step : 100 | total reward : 101
# 2020/11/27 02:36:56
# episode : 910 | final step : 98 | total reward : -202
# 2020/11/27 02:36:58
# episode : 911 | final step : 100 | total reward : -200
# 2020/11/27 02:37:00
# episode : 912 | final step : 99 | total reward : -201
# 2020/11/27 02:37:02
# episode : 913 | final step : 98 | total reward : -202
# 2020/11/27 02:37:03
# episode : 914 | final step : 98 | total reward : -202
# 2020/11/27 02:37:05
# episode : 915 | final step : 99 | total reward : -201
# 2020/11/27 02:37:07
# episode : 916 | final step : 99 | total reward : -201
# 2020/11/27 02:37:09
# episode : 917 | final step : 98 | total reward : -202
# 2020/11/27 02:37:10
# episode : 918 | final step : 98 | total reward : -202
# 2020/11/27 02:37:12
# episode : 919 | final step : 99 | total reward : -201
# 2020/11/27 02:37:13
# episode : 920 | final step : 98 | total reward : -202
# 2020/11/27 02:37:15
# episode : 921 | final step : 100 | total reward : 101
# 2020/11/27 02:37:17
# episode : 922 | final step : 98 | total reward : -202
# 2020/11/27 02:37:18
# episode : 923 | final step : 99 | total reward : -201
# 2020/11/27 02:37:20
# episode : 924 | final step : 98 | total reward : -202
# 2020/11/27 02:37:21
# episode : 925 | final step : 98 | total reward : -202
# 2020/11/27 02:37:23
# episode : 926 | final step : 98 | total reward : -202
# 2020/11/27 02:37:25
# episode : 927 | final step : 98 | total reward : -202
# 2020/11/27 02:37:26
# episode : 928 | final step : 98 | total reward : -202
# 2020/11/27 02:37:28
# episode : 929 | final step : 98 | total reward : -202
# 2020/11/27 02:37:30
# episode : 930 | final step : 98 | total reward : -202
# 2020/11/27 02:37:31
# episode : 931 | final step : 98 | total reward : -202
# 2020/11/27 02:37:33
# episode : 932 | final step : 98 | total reward : -202
# 2020/11/27 02:37:34
# episode : 933 | final step : 99 | total reward : -201
# 2020/11/27 02:37:36
# episode : 934 | final step : 98 | total reward : -202
# 2020/11/27 02:37:38
# episode : 935 | final step : 98 | total reward : -202
# 2020/11/27 02:37:40
# episode : 936 | final step : 100 | total reward : 101
# 2020/11/27 02:37:41
# episode : 937 | final step : 98 | total reward : -202
# 2020/11/27 02:37:43
# episode : 938 | final step : 100 | total reward : 101
# 2020/11/27 02:37:45
# episode : 939 | final step : 98 | total reward : -202
# 2020/11/27 02:37:47
# episode : 940 | final step : 98 | total reward : -202
# 2020/11/27 02:37:49
# episode : 941 | final step : 98 | total reward : -202
# 2020/11/27 02:37:51
# episode : 942 | final step : 98 | total reward : -202
# 2020/11/27 02:37:53
# episode : 943 | final step : 98 | total reward : -202
# 2020/11/27 02:37:55
# episode : 944 | final step : 98 | total reward : -202
# 2020/11/27 02:37:56
# episode : 945 | final step : 98 | total reward : -202
# 2020/11/27 02:37:58
# episode : 946 | final step : 100 | total reward : 101
# 2020/11/27 02:38:00
# episode : 947 | final step : 98 | total reward : -202
# 2020/11/27 02:38:02
# episode : 948 | final step : 98 | total reward : -202
# 2020/11/27 02:38:04
# episode : 949 | final step : 98 | total reward : -202
# 2020/11/27 02:38:06
# episode : 950 | final step : 98 | total reward : -202
# 2020/11/27 02:38:07
# episode : 951 | final step : 98 | total reward : -202
# 2020/11/27 02:38:09
# episode : 952 | final step : 98 | total reward : -202
# 2020/11/27 02:38:11
# episode : 953 | final step : 98 | total reward : -202
# 2020/11/27 02:38:13
# episode : 954 | final step : 98 | total reward : -202
# 2020/11/27 02:38:14
# episode : 955 | final step : 98 | total reward : -202
# 2020/11/27 02:38:16
# episode : 956 | final step : 98 | total reward : -202
# 2020/11/27 02:38:18
# episode : 957 | final step : 98 | total reward : -202
# 2020/11/27 02:38:20
# episode : 958 | final step : 98 | total reward : -202
# 2020/11/27 02:38:21
# episode : 959 | final step : 98 | total reward : -202
# 2020/11/27 02:38:23
# episode : 960 | final step : 98 | total reward : -202
# 2020/11/27 02:38:25
# episode : 961 | final step : 98 | total reward : -202
# 2020/11/27 02:38:27
# episode : 962 | final step : 99 | total reward : -201
# 2020/11/27 02:38:28
# episode : 963 | final step : 98 | total reward : -202
# 2020/11/27 02:38:30
# episode : 964 | final step : 98 | total reward : -202
# 2020/11/27 02:38:32
# episode : 965 | final step : 98 | total reward : -202
# 2020/11/27 02:38:33
# episode : 966 | final step : 98 | total reward : -202
# 2020/11/27 02:38:35
# episode : 967 | final step : 100 | total reward : 101
# 2020/11/27 02:38:36
# episode : 968 | final step : 98 | total reward : -202
# 2020/11/27 02:38:38
# episode : 969 | final step : 98 | total reward : -202
# 2020/11/27 02:38:40
# episode : 970 | final step : 98 | total reward : -202
# 2020/11/27 02:38:41
# episode : 971 | final step : 100 | total reward : 101
# 2020/11/27 02:38:43
# episode : 972 | final step : 98 | total reward : -202
# 2020/11/27 02:38:45
# episode : 973 | final step : 98 | total reward : -202
# 2020/11/27 02:38:46
# episode : 974 | final step : 98 | total reward : -202
# 2020/11/27 02:38:48
# episode : 975 | final step : 98 | total reward : -202
# 2020/11/27 02:38:50
# episode : 976 | final step : 98 | total reward : -202
# 2020/11/27 02:38:51
# episode : 977 | final step : 98 | total reward : -202
# 2020/11/27 02:38:53
# episode : 978 | final step : 100 | total reward : 101
# 2020/11/27 02:38:54
# episode : 979 | final step : 98 | total reward : -202
# 2020/11/27 02:38:56
# episode : 980 | final step : 98 | total reward : -202
# 2020/11/27 02:38:58
# episode : 981 | final step : 98 | total reward : -202
# 2020/11/27 02:38:59
# episode : 982 | final step : 98 | total reward : -202
# 2020/11/27 02:39:01
# episode : 983 | final step : 98 | total reward : -202
# 2020/11/27 02:39:03
# episode : 984 | final step : 98 | total reward : -202
# 2020/11/27 02:39:05
# episode : 985 | final step : 98 | total reward : -202
# 2020/11/27 02:39:06
# episode : 986 | final step : 98 | total reward : -202
# 2020/11/27 02:39:08
# episode : 987 | final step : 99 | total reward : -201
# 2020/11/27 02:39:10
# episode : 988 | final step : 98 | total reward : -202
# 2020/11/27 02:39:12
# episode : 989 | final step : 98 | total reward : -202
# 2020/11/27 02:39:13
# episode : 990 | final step : 98 | total reward : -202
# 2020/11/27 02:39:15
# episode : 991 | final step : 98 | total reward : -202
# 2020/11/27 02:39:17
# episode : 992 | final step : 100 | total reward : 101
# 2020/11/27 02:39:19
# episode : 993 | final step : 98 | total reward : -202
# 2020/11/27 02:39:20
# episode : 994 | final step : 98 | total reward : -202
# 2020/11/27 02:39:22
# episode : 995 | final step : 98 | total reward : -202
# 2020/11/27 02:39:24
# episode : 996 | final step : 98 | total reward : -202
# 2020/11/27 02:39:25
# episode : 997 | final step : 98 | total reward : -202
# 2020/11/27 02:39:27
# episode : 998 | final step : 98 | total reward : -202
# 2020/11/27 02:39:29
# episode : 999 | final step : 99 | total reward : -201
# Complete

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(reward_list)

# %%
def moving_average(data,n):
    len_data=len(data)-n
    res_data=np.zeros(len_data)

    for i in range(len_data):
        res_data[i]=sum(data[i:i+n])/n
    return res_data

# %%
average_number=100
filtered_data=moving_average(reward_list,average_number)
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(filtered_data)

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[992]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()
