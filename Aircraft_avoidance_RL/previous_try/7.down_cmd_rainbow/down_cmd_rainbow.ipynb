# %%
import math, random

import gym
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd 
import torch.nn.functional as F

from common.layers import NoisyLinear
from common.replay_buffer import ReplayBuffer
import gym_Aircraft

from itertools import count
import time
import itertools
import matplotlib
import matplotlib.pyplot as plt

# %%
USE_CUDA = torch.cuda.is_available()
Variable = lambda *args, **kwargs: autograd.Variable(*args, **kwargs).cuda() if USE_CUDA else autograd.Variable(*args, **kwargs)

# %%
env_id = "acav-v0"
env = gym.make(env_id)
# Out:
# /home/jupyter-kunwoopark/.local/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
class RainbowDQN(nn.Module):
    def __init__(self, num_inputs, num_actions, num_atoms, Vmin, Vmax):
        super(RainbowDQN, self).__init__()
        
        self.num_inputs   = num_inputs
        self.num_actions  = num_actions
        self.num_atoms    = num_atoms
        self.Vmin         = Vmin
        self.Vmax         = Vmax
        
        self.linear1 = nn.Linear(num_inputs, 32)
        self.linear2 = nn.Linear(32, 64)
        
        self.noisy_value1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_value2 = NoisyLinear(64, self.num_atoms, use_cuda=USE_CUDA)
        
        self.noisy_advantage1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_advantage2 = NoisyLinear(64, self.num_atoms * self.num_actions, use_cuda=USE_CUDA)
        
    def forward(self, x):
        batch_size = x.size(0)
        
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        
        value = F.relu(self.noisy_value1(x))
        value = self.noisy_value2(value)
        
        advantage = F.relu(self.noisy_advantage1(x))
        advantage = self.noisy_advantage2(advantage)
        
        value     = value.view(batch_size, 1, self.num_atoms)
        advantage = advantage.view(batch_size, self.num_actions, self.num_atoms)
        
        x = value + advantage - advantage.mean(1, keepdim=True)
        x = F.softmax(x.view(-1, self.num_atoms)).view(-1, self.num_actions, self.num_atoms)
        
        return x
        
    def reset_noise(self):
        self.noisy_value1.reset_noise()
        self.noisy_value2.reset_noise()
        self.noisy_advantage1.reset_noise()
        self.noisy_advantage2.reset_noise()
    
    def act(self, state):
        state = Variable(torch.FloatTensor(state).unsqueeze(0), volatile=True)
        dist = self.forward(state).data.cpu()
        dist = dist * torch.linspace(self.Vmin, self.Vmax, self.num_atoms)
        action = dist.sum(2).max(1)[1].numpy()[0]
        return action

# %%
num_atoms = 51
Vmin = -10
Vmax = 10

current_model = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)
target_model  = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)

if USE_CUDA:
    current_model = current_model.cuda()
    target_model  = target_model.cuda()
    
optimizer = optim.Adam(current_model.parameters(), 0.001)

replay_buffer = ReplayBuffer(10000)

# %%
def update_target(current_model, target_model):
    target_model.load_state_dict(current_model.state_dict())
    
update_target(current_model, target_model)

# %%
def projection_distribution(next_state, rewards, dones):
    batch_size  = next_state.size(0)
    
    delta_z = float(Vmax - Vmin) / (num_atoms - 1)
    support = torch.linspace(Vmin, Vmax, num_atoms)
    
    next_dist   = target_model(next_state).data.cpu() * support
    next_action = next_dist.sum(2).max(1)[1]
    next_action = next_action.unsqueeze(1).unsqueeze(1).expand(next_dist.size(0), 1, next_dist.size(2))
    next_dist   = next_dist.gather(1, next_action).squeeze(1)
        
    rewards = rewards.unsqueeze(1).expand_as(next_dist)
    dones   = dones.unsqueeze(1).expand_as(next_dist)
    support = support.unsqueeze(0).expand_as(next_dist)
    
    Tz = rewards + (1 - dones) * 0.99 * support
    Tz = Tz.clamp(min=Vmin, max=Vmax)
    b  = (Tz - Vmin) / delta_z
    l  = b.floor().long()
    u  = b.ceil().long()
        
    offset = torch.linspace(0, (batch_size - 1) * num_atoms, batch_size).long()\
                    .unsqueeze(1).expand(batch_size, num_atoms)

    proj_dist = torch.zeros(next_dist.size())    
    proj_dist.view(-1).index_add_(0, (l + offset).view(-1), (next_dist * (u.float() - b)).view(-1))
    proj_dist.view(-1).index_add_(0, (u + offset).view(-1), (next_dist * (b - l.float())).view(-1))
        
    return proj_dist

# %%
def compute_td_loss(batch_size):
    state, action, reward, next_state, done = replay_buffer.sample(batch_size) 

    state      = Variable(torch.FloatTensor(np.float32(state)))
    next_state = Variable(torch.FloatTensor(np.float32(next_state)), volatile=True)
    action     = Variable(torch.LongTensor(action))
    reward     = torch.FloatTensor(reward)
    done       = torch.FloatTensor(np.float32(done))

    proj_dist = projection_distribution(next_state, reward, done)
    
    dist = current_model(state)
    action = action.unsqueeze(1).unsqueeze(1).expand(batch_size, 1, num_atoms)
    dist = dist.gather(1, action).squeeze(1)
    dist.data.clamp_(0.01, 0.99)
    loss = -(Variable(proj_dist) * dist.log()).sum(1)
    loss  = loss.mean()
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    current_model.reset_noise()
    target_model.reset_noise()
    
    return loss

# %%
num_episodes = 1000
batch_size = 32
gamma=0.99
TARGET_UPDATE=10

losses = []
total_res=[]
reward_list=[]
for i_episode in range(num_episodes):
    total_reward=0
    
    # 환경과 상태 초기화
    res_list=np.zeros(11)
    state = env.reset()

    for t in count():
        # 행동 선택과 수행
        
        action = current_model.act(state)
        
        next_state, reward, done, res = env.step(action)
        
        # 메모리에 변이 저장
        replay_buffer.push(state, action, reward, next_state, done)
        

        # 새로운 상태 관찰
        if not done:
            next_state = next_state
        else:
            next_state = None

        

        # 다음 상태로 이동
        state = next_state

     
        # Data save
        
        cmd_list,r_list,elev_list,azim_list,Pm_list,Pt_list,h_list=res
        Pm_list=Pm_list.tolist()
        Pt_list=Pt_list.tolist()
        merged_data=itertools.chain([cmd_list],[r_list],[elev_list],[azim_list],Pm_list,Pt_list,[h_list])
        merged_data=np.array(list(merged_data))
        res_list=np.vstack([res_list,merged_data])
        
        total_reward+=reward
        
        if done:
            res_list=np.delete(res_list,0,0)
            
            total_res.append(res_list)
            reward_list.append(total_reward)
            
            now = time.localtime()
            print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))
            print("episode : {} | final step : {} | total reward : {}".format(i_episode, t, total_reward))
            break
        if len(replay_buffer) > batch_size:
            loss = compute_td_loss(batch_size)
            losses.append(loss.item())
            
        
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        update_target(current_model, target_model)

print('Complete')
env.close()
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 2020/10/02 20:31:15
# episode : 0 | final step : 201 | total reward : 202
# 2020/10/02 20:31:18
# episode : 1 | final step : 201 | total reward : 202
# 2020/10/02 20:31:19
# episode : 2 | final step : 98 | total reward : -2
# 2020/10/02 20:31:20
# episode : 3 | final step : 98 | total reward : -2
# 2020/10/02 20:31:22
# episode : 4 | final step : 98 | total reward : -2
# 2020/10/02 20:31:23
# episode : 5 | final step : 99 | total reward : -1
# 2020/10/02 20:31:25
# episode : 6 | final step : 98 | total reward : -2
# 2020/10/02 20:31:26
# episode : 7 | final step : 98 | total reward : -2
# 2020/10/02 20:31:28
# episode : 8 | final step : 99 | total reward : -1
# 2020/10/02 20:31:29
# episode : 9 | final step : 99 | total reward : -1
# 2020/10/02 20:31:30
# episode : 10 | final step : 99 | total reward : -1
# 2020/10/02 20:31:31
# episode : 11 | final step : 98 | total reward : -2
# 2020/10/02 20:31:33
# episode : 12 | final step : 98 | total reward : -2
# 2020/10/02 20:31:34
# episode : 13 | final step : 99 | total reward : -1
# 2020/10/02 20:31:36
# episode : 14 | final step : 98 | total reward : -2
# 2020/10/02 20:31:39
# episode : 15 | final step : 201 | total reward : 202
# 2020/10/02 20:31:40
# episode : 16 | final step : 98 | total reward : -2
# 2020/10/02 20:31:41
# episode : 17 | final step : 99 | total reward : -1
# 2020/10/02 20:31:44
# episode : 18 | final step : 201 | total reward : 202
# 2020/10/02 20:31:45
# episode : 19 | final step : 98 | total reward : -2
# 2020/10/02 20:31:46
# episode : 20 | final step : 98 | total reward : -2
# 2020/10/02 20:31:48
# episode : 21 | final step : 98 | total reward : -2
# 2020/10/02 20:31:49
# episode : 22 | final step : 99 | total reward : -1
# 2020/10/02 20:31:51
# episode : 23 | final step : 98 | total reward : -2
# 2020/10/02 20:31:53
# episode : 24 | final step : 201 | total reward : 202
# 2020/10/02 20:31:56
# episode : 25 | final step : 201 | total reward : 202
# 2020/10/02 20:31:58
# episode : 26 | final step : 201 | total reward : 202
# 2020/10/02 20:32:01
# episode : 27 | final step : 201 | total reward : 202
# 2020/10/02 20:32:04
# episode : 28 | final step : 201 | total reward : 202
# 2020/10/02 20:32:07
# episode : 29 | final step : 201 | total reward : 202
# 2020/10/02 20:32:10
# episode : 30 | final step : 201 | total reward : 202
# 2020/10/02 20:32:12
# episode : 31 | final step : 201 | total reward : 202
# 2020/10/02 20:32:15
# episode : 32 | final step : 201 | total reward : 202
# 2020/10/02 20:32:17
# episode : 33 | final step : 201 | total reward : 202
# 2020/10/02 20:32:20
# episode : 34 | final step : 201 | total reward : 202
# 2020/10/02 20:32:22
# episode : 35 | final step : 201 | total reward : 202
# 2020/10/02 20:32:25
# episode : 36 | final step : 201 | total reward : 202
# 2020/10/02 20:32:28
# episode : 37 | final step : 201 | total reward : 202
# 2020/10/02 20:32:31
# episode : 38 | final step : 201 | total reward : 202
# 2020/10/02 20:32:34
# episode : 39 | final step : 201 | total reward : 202
# 2020/10/02 20:32:36
# episode : 40 | final step : 201 | total reward : 202
# 2020/10/02 20:32:39
# episode : 41 | final step : 201 | total reward : 202
# 2020/10/02 20:32:41
# episode : 42 | final step : 201 | total reward : 202
# 2020/10/02 20:32:44
# episode : 43 | final step : 201 | total reward : 202
# 2020/10/02 20:32:46
# episode : 44 | final step : 201 | total reward : 202
# 2020/10/02 20:32:49
# episode : 45 | final step : 201 | total reward : 202
# 2020/10/02 20:32:51
# episode : 46 | final step : 201 | total reward : 202
# 2020/10/02 20:32:54
# episode : 47 | final step : 201 | total reward : 202
# 2020/10/02 20:32:56
# episode : 48 | final step : 201 | total reward : 202
# 2020/10/02 20:32:59
# episode : 49 | final step : 201 | total reward : 202
# 2020/10/02 20:33:02
# episode : 50 | final step : 201 | total reward : 202
# 2020/10/02 20:33:05
# episode : 51 | final step : 201 | total reward : 202
# 2020/10/02 20:33:07
# episode : 52 | final step : 201 | total reward : 202
# 2020/10/02 20:33:10
# episode : 53 | final step : 201 | total reward : 202
# 2020/10/02 20:33:12
# episode : 54 | final step : 201 | total reward : 202
# 2020/10/02 20:33:15
# episode : 55 | final step : 201 | total reward : 202
# 2020/10/02 20:33:17
# episode : 56 | final step : 201 | total reward : 202
# 2020/10/02 20:33:20
# episode : 57 | final step : 201 | total reward : 202
# 2020/10/02 20:33:22
# episode : 58 | final step : 201 | total reward : 202
# 2020/10/02 20:33:25
# episode : 59 | final step : 201 | total reward : 202
# 2020/10/02 20:33:27
# episode : 60 | final step : 201 | total reward : 202
# 2020/10/02 20:33:30
# episode : 61 | final step : 201 | total reward : 202
# 2020/10/02 20:33:32
# episode : 62 | final step : 201 | total reward : 202
# 2020/10/02 20:33:35
# episode : 63 | final step : 201 | total reward : 202
# 2020/10/02 20:33:37
# episode : 64 | final step : 201 | total reward : 202
# 2020/10/02 20:33:40
# episode : 65 | final step : 201 | total reward : 202
# 2020/10/02 20:33:42
# episode : 66 | final step : 201 | total reward : 202
# 2020/10/02 20:33:45
# episode : 67 | final step : 201 | total reward : 202
# 2020/10/02 20:33:47
# episode : 68 | final step : 201 | total reward : 202
# 2020/10/02 20:33:50
# episode : 69 | final step : 201 | total reward : 202
# 2020/10/02 20:33:52
# episode : 70 | final step : 201 | total reward : 202
# 2020/10/02 20:33:55
# episode : 71 | final step : 201 | total reward : 202
# 2020/10/02 20:33:57
# episode : 72 | final step : 201 | total reward : 202
# 2020/10/02 20:34:00
# episode : 73 | final step : 201 | total reward : 202
# 2020/10/02 20:34:03
# episode : 74 | final step : 201 | total reward : 202
# 2020/10/02 20:34:06
# episode : 75 | final step : 201 | total reward : 202
# 2020/10/02 20:34:09
# episode : 76 | final step : 201 | total reward : 202
# 2020/10/02 20:34:12
# episode : 77 | final step : 201 | total reward : 202
# 2020/10/02 20:34:14
# episode : 78 | final step : 201 | total reward : 202
# 2020/10/02 20:34:17
# episode : 79 | final step : 201 | total reward : 202
# 2020/10/02 20:34:19
# episode : 80 | final step : 201 | total reward : 202
# 2020/10/02 20:34:22
# episode : 81 | final step : 201 | total reward : 202
# 2020/10/02 20:34:24
# episode : 82 | final step : 201 | total reward : 202
# 2020/10/02 20:34:27
# episode : 83 | final step : 201 | total reward : 202
# 2020/10/02 20:34:29
# episode : 84 | final step : 201 | total reward : 202
# 2020/10/02 20:34:32
# episode : 85 | final step : 201 | total reward : 202
# 2020/10/02 20:34:34
# episode : 86 | final step : 201 | total reward : 202
# 2020/10/02 20:34:37
# episode : 87 | final step : 201 | total reward : 202
# 2020/10/02 20:34:40
# episode : 88 | final step : 201 | total reward : 202
# 2020/10/02 20:34:42
# episode : 89 | final step : 201 | total reward : 202
# 2020/10/02 20:34:45
# episode : 90 | final step : 201 | total reward : 202
# 2020/10/02 20:34:47
# episode : 91 | final step : 201 | total reward : 202
# 2020/10/02 20:34:50
# episode : 92 | final step : 201 | total reward : 202
# 2020/10/02 20:34:52
# episode : 93 | final step : 201 | total reward : 202
# 2020/10/02 20:34:55
# episode : 94 | final step : 201 | total reward : 202
# 2020/10/02 20:34:56
# episode : 95 | final step : 99 | total reward : -1
# 2020/10/02 20:34:59
# episode : 96 | final step : 201 | total reward : 202
# 2020/10/02 20:35:01
# episode : 97 | final step : 201 | total reward : 202
# 2020/10/02 20:35:04
# episode : 98 | final step : 201 | total reward : 202
# 2020/10/02 20:35:06
# episode : 99 | final step : 201 | total reward : 202
# 2020/10/02 20:35:09
# episode : 100 | final step : 201 | total reward : 202
# 2020/10/02 20:35:11
# episode : 101 | final step : 201 | total reward : 202
# 2020/10/02 20:35:14
# episode : 102 | final step : 201 | total reward : 202
# 2020/10/02 20:35:18
# episode : 103 | final step : 201 | total reward : 202
# 2020/10/02 20:35:20
# episode : 104 | final step : 201 | total reward : 202
# 2020/10/02 20:35:23
# episode : 105 | final step : 201 | total reward : 202
# 2020/10/02 20:35:25
# episode : 106 | final step : 201 | total reward : 202
# 2020/10/02 20:35:28
# episode : 107 | final step : 201 | total reward : 202
# 2020/10/02 20:35:30
# episode : 108 | final step : 201 | total reward : 202
# 2020/10/02 20:35:33
# episode : 109 | final step : 201 | total reward : 202
# 2020/10/02 20:35:35
# episode : 110 | final step : 201 | total reward : 202
# 2020/10/02 20:35:38
# episode : 111 | final step : 201 | total reward : 202
# 2020/10/02 20:35:41
# episode : 112 | final step : 201 | total reward : 202
# 2020/10/02 20:35:43
# episode : 113 | final step : 201 | total reward : 202
# 2020/10/02 20:35:46
# episode : 114 | final step : 201 | total reward : 202
# 2020/10/02 20:35:48
# episode : 115 | final step : 201 | total reward : 202
# 2020/10/02 20:35:51
# episode : 116 | final step : 201 | total reward : 202
# 2020/10/02 20:35:52
# episode : 117 | final step : 99 | total reward : -1
# 2020/10/02 20:35:53
# episode : 118 | final step : 98 | total reward : -2
# 2020/10/02 20:35:55
# episode : 119 | final step : 98 | total reward : -2
# 2020/10/02 20:35:57
# episode : 120 | final step : 201 | total reward : 202
# 2020/10/02 20:35:59
# episode : 121 | final step : 98 | total reward : -2
# 2020/10/02 20:36:00
# episode : 122 | final step : 99 | total reward : -1
# 2020/10/02 20:36:01
# episode : 123 | final step : 99 | total reward : -1
# 2020/10/02 20:36:03
# episode : 124 | final step : 98 | total reward : -2
# 2020/10/02 20:36:04
# episode : 125 | final step : 98 | total reward : -2
# 2020/10/02 20:36:05
# episode : 126 | final step : 98 | total reward : -2
# 2020/10/02 20:36:08
# episode : 127 | final step : 201 | total reward : 202
# 2020/10/02 20:36:09
# episode : 128 | final step : 99 | total reward : -1
# 2020/10/02 20:36:12
# episode : 129 | final step : 201 | total reward : 202
# 2020/10/02 20:36:14
# episode : 130 | final step : 201 | total reward : 202
# 2020/10/02 20:36:17
# episode : 131 | final step : 201 | total reward : 202
# 2020/10/02 20:36:19
# episode : 132 | final step : 201 | total reward : 202
# 2020/10/02 20:36:21
# episode : 133 | final step : 98 | total reward : -2
# 2020/10/02 20:36:24
# episode : 134 | final step : 201 | total reward : 202
# 2020/10/02 20:36:27
# episode : 135 | final step : 201 | total reward : 202
# 2020/10/02 20:36:30
# episode : 136 | final step : 201 | total reward : 202
# 2020/10/02 20:36:32
# episode : 137 | final step : 201 | total reward : 202
# 2020/10/02 20:36:34
# episode : 138 | final step : 98 | total reward : -2
# 2020/10/02 20:36:35
# episode : 139 | final step : 98 | total reward : -2
# 2020/10/02 20:36:37
# episode : 140 | final step : 98 | total reward : -2
# 2020/10/02 20:36:38
# episode : 141 | final step : 98 | total reward : -2
# 2020/10/02 20:36:41
# episode : 142 | final step : 201 | total reward : 202
# 2020/10/02 20:36:44
# episode : 143 | final step : 201 | total reward : 202
# 2020/10/02 20:36:45
# episode : 144 | final step : 98 | total reward : -2
# 2020/10/02 20:36:46
# episode : 145 | final step : 98 | total reward : -2
# 2020/10/02 20:36:48
# episode : 146 | final step : 99 | total reward : -1
# 2020/10/02 20:36:50
# episode : 147 | final step : 100 | total reward : 0
# 2020/10/02 20:36:51
# episode : 148 | final step : 100 | total reward : 0
# 2020/10/02 20:36:52
# episode : 149 | final step : 98 | total reward : -2
# 2020/10/02 20:36:54
# episode : 150 | final step : 99 | total reward : -1
# 2020/10/02 20:36:55
# episode : 151 | final step : 98 | total reward : -2
# 2020/10/02 20:36:56
# episode : 152 | final step : 99 | total reward : -1
# 2020/10/02 20:36:58
# episode : 153 | final step : 99 | total reward : -1
# 2020/10/02 20:36:59
# episode : 154 | final step : 98 | total reward : -2
# 2020/10/02 20:37:02
# episode : 155 | final step : 201 | total reward : 202
# 2020/10/02 20:37:05
# episode : 156 | final step : 201 | total reward : 202
# 2020/10/02 20:37:06
# episode : 157 | final step : 98 | total reward : -2
# 2020/10/02 20:37:09
# episode : 158 | final step : 201 | total reward : 202
# 2020/10/02 20:37:12
# episode : 159 | final step : 201 | total reward : 202
# 2020/10/02 20:37:13
# episode : 160 | final step : 98 | total reward : -2
# 2020/10/02 20:37:15
# episode : 161 | final step : 98 | total reward : -2
# 2020/10/02 20:37:16
# episode : 162 | final step : 98 | total reward : -2
# 2020/10/02 20:37:17
# episode : 163 | final step : 98 | total reward : -2
# 2020/10/02 20:37:19
# episode : 164 | final step : 98 | total reward : -2
# 2020/10/02 20:37:21
# episode : 165 | final step : 99 | total reward : -1
# 2020/10/02 20:37:22
# episode : 166 | final step : 99 | total reward : -1
# 2020/10/02 20:37:23
# episode : 167 | final step : 98 | total reward : -2
# 2020/10/02 20:37:25
# episode : 168 | final step : 98 | total reward : -2
# 2020/10/02 20:37:26
# episode : 169 | final step : 98 | total reward : -2
# 2020/10/02 20:37:28
# episode : 170 | final step : 201 | total reward : 202
# 2020/10/02 20:37:30
# episode : 171 | final step : 98 | total reward : -2
# 2020/10/02 20:37:34
# episode : 172 | final step : 201 | total reward : 202
# 2020/10/02 20:37:37
# episode : 173 | final step : 201 | total reward : 202
# 2020/10/02 20:37:38
# episode : 174 | final step : 99 | total reward : -1
# 2020/10/02 20:37:39
# episode : 175 | final step : 99 | total reward : -1
# 2020/10/02 20:37:41
# episode : 176 | final step : 98 | total reward : -2
# 2020/10/02 20:37:42
# episode : 177 | final step : 98 | total reward : -2
# 2020/10/02 20:37:43
# episode : 178 | final step : 98 | total reward : -2
# 2020/10/02 20:37:45
# episode : 179 | final step : 99 | total reward : -1
# 2020/10/02 20:37:48
# episode : 180 | final step : 201 | total reward : 202
# 2020/10/02 20:37:49
# episode : 181 | final step : 99 | total reward : -1
# 2020/10/02 20:37:52
# episode : 182 | final step : 201 | total reward : 202
# 2020/10/02 20:37:54
# episode : 183 | final step : 98 | total reward : -2
# 2020/10/02 20:37:55
# episode : 184 | final step : 99 | total reward : -1
# 2020/10/02 20:37:56
# episode : 185 | final step : 98 | total reward : -2
# 2020/10/02 20:37:57
# episode : 186 | final step : 98 | total reward : -2
# 2020/10/02 20:38:00
# episode : 187 | final step : 201 | total reward : 202
# 2020/10/02 20:38:03
# episode : 188 | final step : 201 | total reward : 202
# 2020/10/02 20:38:05
# episode : 189 | final step : 98 | total reward : -2
# 2020/10/02 20:38:08
# episode : 190 | final step : 201 | total reward : 202
# 2020/10/02 20:38:09
# episode : 191 | final step : 100 | total reward : 0
# 2020/10/02 20:38:10
# episode : 192 | final step : 99 | total reward : -1
# 2020/10/02 20:38:11
# episode : 193 | final step : 98 | total reward : -2
# 2020/10/02 20:38:13
# episode : 194 | final step : 98 | total reward : -2
# 2020/10/02 20:38:16
# episode : 195 | final step : 201 | total reward : 202
# 2020/10/02 20:38:19
# episode : 196 | final step : 201 | total reward : 202
# 2020/10/02 20:38:21
# episode : 197 | final step : 201 | total reward : 202
# 2020/10/02 20:38:24
# episode : 198 | final step : 201 | total reward : 202
# 2020/10/02 20:38:25
# episode : 199 | final step : 99 | total reward : -1
# 2020/10/02 20:38:27
# episode : 200 | final step : 101 | total reward : 1
# 2020/10/02 20:38:31
# episode : 201 | final step : 201 | total reward : 202
# 2020/10/02 20:38:32
# episode : 202 | final step : 99 | total reward : -1
# 2020/10/02 20:38:34
# episode : 203 | final step : 201 | total reward : 202
# 2020/10/02 20:38:36
# episode : 204 | final step : 98 | total reward : -2
# 2020/10/02 20:38:38
# episode : 205 | final step : 201 | total reward : 202
# 2020/10/02 20:38:40
# episode : 206 | final step : 98 | total reward : -2
# 2020/10/02 20:38:41
# episode : 207 | final step : 98 | total reward : -2
# 2020/10/02 20:38:42
# episode : 208 | final step : 99 | total reward : -1
# 2020/10/02 20:38:44
# episode : 209 | final step : 100 | total reward : 0
# 2020/10/02 20:38:45
# episode : 210 | final step : 99 | total reward : -1
# 2020/10/02 20:38:47
# episode : 211 | final step : 99 | total reward : -1
# 2020/10/02 20:38:50
# episode : 212 | final step : 201 | total reward : 202
# 2020/10/02 20:38:51
# episode : 213 | final step : 98 | total reward : -2
# 2020/10/02 20:38:52
# episode : 214 | final step : 98 | total reward : -2
# 2020/10/02 20:38:53
# episode : 215 | final step : 98 | total reward : -2
# 2020/10/02 20:38:54
# episode : 216 | final step : 98 | total reward : -2
# 2020/10/02 20:38:56
# episode : 217 | final step : 98 | total reward : -2
# 2020/10/02 20:38:57
# episode : 218 | final step : 98 | total reward : -2
# 2020/10/02 20:38:58
# episode : 219 | final step : 98 | total reward : -2
# 2020/10/02 20:38:59
# episode : 220 | final step : 99 | total reward : -1
# 2020/10/02 20:39:01
# episode : 221 | final step : 98 | total reward : -2
# 2020/10/02 20:39:02
# episode : 222 | final step : 99 | total reward : -1
# 2020/10/02 20:39:03
# episode : 223 | final step : 98 | total reward : -2
# 2020/10/02 20:39:04
# episode : 224 | final step : 97 | total reward : -3
# 2020/10/02 20:39:06
# episode : 225 | final step : 98 | total reward : -2
# 2020/10/02 20:39:08
# episode : 226 | final step : 99 | total reward : -1
# 2020/10/02 20:39:11
# episode : 227 | final step : 201 | total reward : 202
# 2020/10/02 20:39:12
# episode : 228 | final step : 100 | total reward : 0
# 2020/10/02 20:39:15
# episode : 229 | final step : 201 | total reward : 202
# 2020/10/02 20:39:17
# episode : 230 | final step : 201 | total reward : 202
# 2020/10/02 20:39:18
# episode : 231 | final step : 99 | total reward : -1
# 2020/10/02 20:39:20
# episode : 232 | final step : 98 | total reward : -2
# 2020/10/02 20:39:21
# episode : 233 | final step : 98 | total reward : -2
# 2020/10/02 20:39:22
# episode : 234 | final step : 99 | total reward : -1
# 2020/10/02 20:39:23
# episode : 235 | final step : 99 | total reward : -1
# 2020/10/02 20:39:26
# episode : 236 | final step : 201 | total reward : 202
# 2020/10/02 20:39:29
# episode : 237 | final step : 201 | total reward : 202
# 2020/10/02 20:39:30
# episode : 238 | final step : 99 | total reward : -1
# 2020/10/02 20:39:31
# episode : 239 | final step : 100 | total reward : 0
# 2020/10/02 20:39:32
# episode : 240 | final step : 98 | total reward : -2
# 2020/10/02 20:39:35
# episode : 241 | final step : 201 | total reward : 202
# 2020/10/02 20:39:36
# episode : 242 | final step : 99 | total reward : -1
# 2020/10/02 20:39:38
# episode : 243 | final step : 98 | total reward : -2
# 2020/10/02 20:39:40
# episode : 244 | final step : 201 | total reward : 202
# 2020/10/02 20:39:43
# episode : 245 | final step : 201 | total reward : 202
# 2020/10/02 20:39:46
# episode : 246 | final step : 201 | total reward : 202
# 2020/10/02 20:39:47
# episode : 247 | final step : 98 | total reward : -2
# 2020/10/02 20:39:49
# episode : 248 | final step : 98 | total reward : -2
# 2020/10/02 20:39:50
# episode : 249 | final step : 98 | total reward : -2
# 2020/10/02 20:39:51
# episode : 250 | final step : 99 | total reward : -1
# 2020/10/02 20:39:54
# episode : 251 | final step : 201 | total reward : 202
# 2020/10/02 20:39:56
# episode : 252 | final step : 99 | total reward : -1
# 2020/10/02 20:39:57
# episode : 253 | final step : 99 | total reward : -1
# 2020/10/02 20:39:59
# episode : 254 | final step : 98 | total reward : -2
# 2020/10/02 20:40:01
# episode : 255 | final step : 201 | total reward : 202
# 2020/10/02 20:40:03
# episode : 256 | final step : 99 | total reward : -1
# 2020/10/02 20:40:06
# episode : 257 | final step : 201 | total reward : 202
# 2020/10/02 20:40:08
# episode : 258 | final step : 99 | total reward : -1
# 2020/10/02 20:40:09
# episode : 259 | final step : 98 | total reward : -2
# 2020/10/02 20:40:12
# episode : 260 | final step : 201 | total reward : 202
# 2020/10/02 20:40:15
# episode : 261 | final step : 201 | total reward : 202
# 2020/10/02 20:40:18
# episode : 262 | final step : 201 | total reward : 202
# 2020/10/02 20:40:19
# episode : 263 | final step : 98 | total reward : -2
# 2020/10/02 20:40:21
# episode : 264 | final step : 98 | total reward : -2
# 2020/10/02 20:40:22
# episode : 265 | final step : 98 | total reward : -2
# 2020/10/02 20:40:25
# episode : 266 | final step : 201 | total reward : 202
# 2020/10/02 20:40:28
# episode : 267 | final step : 201 | total reward : 202
# 2020/10/02 20:40:29
# episode : 268 | final step : 98 | total reward : -2
# 2020/10/02 20:40:32
# episode : 269 | final step : 201 | total reward : 202
# 2020/10/02 20:40:35
# episode : 270 | final step : 201 | total reward : 202
# 2020/10/02 20:40:38
# episode : 271 | final step : 201 | total reward : 202
# 2020/10/02 20:40:40
# episode : 272 | final step : 98 | total reward : -2
# 2020/10/02 20:40:41
# episode : 273 | final step : 98 | total reward : -2
# 2020/10/02 20:40:43
# episode : 274 | final step : 99 | total reward : -1
# 2020/10/02 20:40:44
# episode : 275 | final step : 98 | total reward : -2
# 2020/10/02 20:40:47
# episode : 276 | final step : 201 | total reward : 202
# 2020/10/02 20:40:48
# episode : 277 | final step : 98 | total reward : -2
# 2020/10/02 20:40:50
# episode : 278 | final step : 100 | total reward : 0
# 2020/10/02 20:40:52
# episode : 279 | final step : 98 | total reward : -2
# 2020/10/02 20:40:54
# episode : 280 | final step : 201 | total reward : 202
# 2020/10/02 20:40:56
# episode : 281 | final step : 98 | total reward : -2
# 2020/10/02 20:40:59
# episode : 282 | final step : 201 | total reward : 202
# 2020/10/02 20:41:00
# episode : 283 | final step : 98 | total reward : -2
# 2020/10/02 20:41:02
# episode : 284 | final step : 98 | total reward : -2
# 2020/10/02 20:41:05
# episode : 285 | final step : 201 | total reward : 202
# 2020/10/02 20:41:07
# episode : 286 | final step : 201 | total reward : 202
# 2020/10/02 20:41:09
# episode : 287 | final step : 99 | total reward : -1
# 2020/10/02 20:41:10
# episode : 288 | final step : 98 | total reward : -2
# 2020/10/02 20:41:12
# episode : 289 | final step : 98 | total reward : -2
# 2020/10/02 20:41:13
# episode : 290 | final step : 98 | total reward : -2
# 2020/10/02 20:41:15
# episode : 291 | final step : 98 | total reward : -2
# 2020/10/02 20:41:17
# episode : 292 | final step : 201 | total reward : 202
# 2020/10/02 20:41:19
# episode : 293 | final step : 99 | total reward : -1
# 2020/10/02 20:41:22
# episode : 294 | final step : 201 | total reward : 202
# 2020/10/02 20:41:25
# episode : 295 | final step : 201 | total reward : 202
# 2020/10/02 20:41:28
# episode : 296 | final step : 201 | total reward : 202
# 2020/10/02 20:41:30
# episode : 297 | final step : 201 | total reward : 202
# 2020/10/02 20:41:33
# episode : 298 | final step : 201 | total reward : 202
# 2020/10/02 20:41:35
# episode : 299 | final step : 98 | total reward : -2
# 2020/10/02 20:41:36
# episode : 300 | final step : 98 | total reward : -2
# 2020/10/02 20:41:39
# episode : 301 | final step : 201 | total reward : 202
# 2020/10/02 20:41:41
# episode : 302 | final step : 98 | total reward : -2
# 2020/10/02 20:41:42
# episode : 303 | final step : 98 | total reward : -2
# 2020/10/02 20:41:43
# episode : 304 | final step : 98 | total reward : -2
# 2020/10/02 20:41:47
# episode : 305 | final step : 201 | total reward : 202
# 2020/10/02 20:41:48
# episode : 306 | final step : 99 | total reward : -1
# 2020/10/02 20:41:49
# episode : 307 | final step : 98 | total reward : -2
# 2020/10/02 20:41:51
# episode : 308 | final step : 98 | total reward : -2
# 2020/10/02 20:41:52
# episode : 309 | final step : 98 | total reward : -2
# 2020/10/02 20:41:53
# episode : 310 | final step : 98 | total reward : -2
# 2020/10/02 20:41:54
# episode : 311 | final step : 99 | total reward : -1
# 2020/10/02 20:41:56
# episode : 312 | final step : 98 | total reward : -2
# 2020/10/02 20:41:57
# episode : 313 | final step : 100 | total reward : 0
# 2020/10/02 20:41:59
# episode : 314 | final step : 99 | total reward : -1
# 2020/10/02 20:42:00
# episode : 315 | final step : 99 | total reward : -1
# 2020/10/02 20:42:03
# episode : 316 | final step : 201 | total reward : 202
# 2020/10/02 20:42:04
# episode : 317 | final step : 98 | total reward : -2
# 2020/10/02 20:42:07
# episode : 318 | final step : 201 | total reward : 202
# 2020/10/02 20:42:11
# episode : 319 | final step : 201 | total reward : 202
# 2020/10/02 20:42:12
# episode : 320 | final step : 99 | total reward : -1
# 2020/10/02 20:42:14
# episode : 321 | final step : 100 | total reward : 0
# 2020/10/02 20:42:15
# episode : 322 | final step : 98 | total reward : -2
# 2020/10/02 20:42:16
# episode : 323 | final step : 100 | total reward : 0
# 2020/10/02 20:42:20
# episode : 324 | final step : 201 | total reward : 202
# 2020/10/02 20:42:22
# episode : 325 | final step : 98 | total reward : -2
# 2020/10/02 20:42:23
# episode : 326 | final step : 98 | total reward : -2
# 2020/10/02 20:42:24
# episode : 327 | final step : 98 | total reward : -2
# 2020/10/02 20:42:27
# episode : 328 | final step : 201 | total reward : 202
# 2020/10/02 20:42:30
# episode : 329 | final step : 201 | total reward : 202
# 2020/10/02 20:42:31
# episode : 330 | final step : 99 | total reward : -1
# 2020/10/02 20:42:32
# episode : 331 | final step : 98 | total reward : -2
# 2020/10/02 20:42:35
# episode : 332 | final step : 201 | total reward : 202
# 2020/10/02 20:42:37
# episode : 333 | final step : 97 | total reward : -3
# 2020/10/02 20:42:38
# episode : 334 | final step : 97 | total reward : -3
# 2020/10/02 20:42:41
# episode : 335 | final step : 201 | total reward : 202
# 2020/10/02 20:42:42
# episode : 336 | final step : 99 | total reward : -1
# 2020/10/02 20:42:45
# episode : 337 | final step : 201 | total reward : 202
# 2020/10/02 20:42:47
# episode : 338 | final step : 98 | total reward : -2
# 2020/10/02 20:42:48
# episode : 339 | final step : 100 | total reward : 0
# 2020/10/02 20:42:49
# episode : 340 | final step : 98 | total reward : -2
# 2020/10/02 20:42:50
# episode : 341 | final step : 98 | total reward : -2
# 2020/10/02 20:42:52
# episode : 342 | final step : 99 | total reward : -1
# 2020/10/02 20:42:55
# episode : 343 | final step : 201 | total reward : 202
# 2020/10/02 20:42:57
# episode : 344 | final step : 98 | total reward : -2
# 2020/10/02 20:42:58
# episode : 345 | final step : 99 | total reward : -1
# 2020/10/02 20:43:00
# episode : 346 | final step : 201 | total reward : 202
# 2020/10/02 20:43:02
# episode : 347 | final step : 98 | total reward : -2
# 2020/10/02 20:43:04
# episode : 348 | final step : 99 | total reward : -1
# 2020/10/02 20:43:05
# episode : 349 | final step : 98 | total reward : -2
# 2020/10/02 20:43:07
# episode : 350 | final step : 99 | total reward : -1
# 2020/10/02 20:43:08
# episode : 351 | final step : 98 | total reward : -2
# 2020/10/02 20:43:09
# episode : 352 | final step : 98 | total reward : -2
# 2020/10/02 20:43:12
# episode : 353 | final step : 201 | total reward : 202
# 2020/10/02 20:43:14
# episode : 354 | final step : 98 | total reward : -2
# 2020/10/02 20:43:15
# episode : 355 | final step : 99 | total reward : -1
# 2020/10/02 20:43:17
# episode : 356 | final step : 98 | total reward : -2
# 2020/10/02 20:43:18
# episode : 357 | final step : 100 | total reward : 0
# 2020/10/02 20:43:19
# episode : 358 | final step : 98 | total reward : -2
# 2020/10/02 20:43:21
# episode : 359 | final step : 98 | total reward : -2
# 2020/10/02 20:43:22
# episode : 360 | final step : 98 | total reward : -2
# 2020/10/02 20:43:25
# episode : 361 | final step : 201 | total reward : 202
# 2020/10/02 20:43:27
# episode : 362 | final step : 99 | total reward : -1
# 2020/10/02 20:43:28
# episode : 363 | final step : 98 | total reward : -2
# 2020/10/02 20:43:29
# episode : 364 | final step : 98 | total reward : -2
# 2020/10/02 20:43:31
# episode : 365 | final step : 98 | total reward : -2
# 2020/10/02 20:43:32
# episode : 366 | final step : 98 | total reward : -2
# 2020/10/02 20:43:33
# episode : 367 | final step : 98 | total reward : -2
# 2020/10/02 20:43:35
# episode : 368 | final step : 99 | total reward : -1
# 2020/10/02 20:43:36
# episode : 369 | final step : 98 | total reward : -2
# 2020/10/02 20:43:38
# episode : 370 | final step : 98 | total reward : -2
# 2020/10/02 20:43:39
# episode : 371 | final step : 98 | total reward : -2
# 2020/10/02 20:43:42
# episode : 372 | final step : 201 | total reward : 202
# 2020/10/02 20:43:43
# episode : 373 | final step : 98 | total reward : -2
# 2020/10/02 20:43:45
# episode : 374 | final step : 98 | total reward : -2
# 2020/10/02 20:43:48
# episode : 375 | final step : 201 | total reward : 202
# 2020/10/02 20:43:49
# episode : 376 | final step : 99 | total reward : -1
# 2020/10/02 20:43:51
# episode : 377 | final step : 99 | total reward : -1
# 2020/10/02 20:43:52
# episode : 378 | final step : 98 | total reward : -2
# 2020/10/02 20:43:53
# episode : 379 | final step : 99 | total reward : -1
# 2020/10/02 20:43:54
# episode : 380 | final step : 99 | total reward : -1
# 2020/10/02 20:43:57
# episode : 381 | final step : 201 | total reward : 202
# 2020/10/02 20:43:59
# episode : 382 | final step : 98 | total reward : -2
# 2020/10/02 20:44:00
# episode : 383 | final step : 98 | total reward : -2
# 2020/10/02 20:44:02
# episode : 384 | final step : 98 | total reward : -2
# 2020/10/02 20:44:03
# episode : 385 | final step : 98 | total reward : -2
# 2020/10/02 20:44:06
# episode : 386 | final step : 201 | total reward : 202
# 2020/10/02 20:44:07
# episode : 387 | final step : 99 | total reward : -1
# 2020/10/02 20:44:09
# episode : 388 | final step : 99 | total reward : -1
# 2020/10/02 20:44:10
# episode : 389 | final step : 98 | total reward : -2
# 2020/10/02 20:44:13
# episode : 390 | final step : 201 | total reward : 202
# 2020/10/02 20:44:14
# episode : 391 | final step : 99 | total reward : -1
# 2020/10/02 20:44:16
# episode : 392 | final step : 99 | total reward : -1
# 2020/10/02 20:44:17
# episode : 393 | final step : 98 | total reward : -2
# 2020/10/02 20:44:19
# episode : 394 | final step : 98 | total reward : -2
# 2020/10/02 20:44:20
# episode : 395 | final step : 99 | total reward : -1
# 2020/10/02 20:44:22
# episode : 396 | final step : 98 | total reward : -2
# 2020/10/02 20:44:23
# episode : 397 | final step : 98 | total reward : -2
# 2020/10/02 20:44:26
# episode : 398 | final step : 201 | total reward : 202
# 2020/10/02 20:44:27
# episode : 399 | final step : 98 | total reward : -2
# 2020/10/02 20:44:29
# episode : 400 | final step : 100 | total reward : 0
# 2020/10/02 20:44:31
# episode : 401 | final step : 98 | total reward : -2
# 2020/10/02 20:44:38
# episode : 402 | final step : 201 | total reward : 202
# 2020/10/02 20:44:42
# episode : 403 | final step : 98 | total reward : -2
# 2020/10/02 20:44:50
# episode : 404 | final step : 201 | total reward : 202
# 2020/10/02 20:44:55
# episode : 405 | final step : 201 | total reward : 202
# 2020/10/02 20:44:58
# episode : 406 | final step : 201 | total reward : 202
# 2020/10/02 20:45:00
# episode : 407 | final step : 201 | total reward : 202
# 2020/10/02 20:45:02
# episode : 408 | final step : 98 | total reward : -2
# 2020/10/02 20:45:03
# episode : 409 | final step : 99 | total reward : -1
# 2020/10/02 20:45:05
# episode : 410 | final step : 98 | total reward : -2
# 2020/10/02 20:45:08
# episode : 411 | final step : 201 | total reward : 202
# 2020/10/02 20:45:09
# episode : 412 | final step : 98 | total reward : -2
# 2020/10/02 20:45:10
# episode : 413 | final step : 99 | total reward : -1
# 2020/10/02 20:45:12
# episode : 414 | final step : 98 | total reward : -2
# 2020/10/02 20:45:13
# episode : 415 | final step : 99 | total reward : -1
# 2020/10/02 20:45:15
# episode : 416 | final step : 98 | total reward : -2
# 2020/10/02 20:45:17
# episode : 417 | final step : 201 | total reward : 202
# 2020/10/02 20:45:21
# episode : 418 | final step : 201 | total reward : 202
# 2020/10/02 20:45:22
# episode : 419 | final step : 98 | total reward : -2
# 2020/10/02 20:45:24
# episode : 420 | final step : 201 | total reward : 202
# 2020/10/02 20:45:26
# episode : 421 | final step : 98 | total reward : -2
# 2020/10/02 20:45:28
# episode : 422 | final step : 100 | total reward : 0
# 2020/10/02 20:45:31
# episode : 423 | final step : 201 | total reward : 202
# 2020/10/02 20:45:32
# episode : 424 | final step : 99 | total reward : -1
# 2020/10/02 20:45:33
# episode : 425 | final step : 98 | total reward : -2
# 2020/10/02 20:45:35
# episode : 426 | final step : 98 | total reward : -2
# 2020/10/02 20:45:37
# episode : 427 | final step : 99 | total reward : -1
# 2020/10/02 20:45:40
# episode : 428 | final step : 99 | total reward : -1
# 2020/10/02 20:45:44
# episode : 429 | final step : 99 | total reward : -1
# 2020/10/02 20:45:52
# episode : 430 | final step : 201 | total reward : 202
# 2020/10/02 20:45:59
# episode : 431 | final step : 201 | total reward : 202
# 2020/10/02 20:46:04
# episode : 432 | final step : 99 | total reward : -1
# 2020/10/02 20:46:08
# episode : 433 | final step : 98 | total reward : -2
# 2020/10/02 20:46:11
# episode : 434 | final step : 98 | total reward : -2
# 2020/10/02 20:46:15
# episode : 435 | final step : 99 | total reward : -1
# 2020/10/02 20:46:19
# episode : 436 | final step : 99 | total reward : -1
# 2020/10/02 20:46:23
# episode : 437 | final step : 98 | total reward : -2
# 2020/10/02 20:46:27
# episode : 438 | final step : 99 | total reward : -1
# 2020/10/02 20:46:34
# episode : 439 | final step : 201 | total reward : 202
# 2020/10/02 20:46:36
# episode : 440 | final step : 98 | total reward : -2
# 2020/10/02 20:46:37
# episode : 441 | final step : 98 | total reward : -2
# 2020/10/02 20:46:39
# episode : 442 | final step : 98 | total reward : -2
# 2020/10/02 20:46:40
# episode : 443 | final step : 101 | total reward : 1
# 2020/10/02 20:46:43
# episode : 444 | final step : 201 | total reward : 202
# 2020/10/02 20:46:44
# episode : 445 | final step : 98 | total reward : -2
# 2020/10/02 20:46:47
# episode : 446 | final step : 201 | total reward : 202
# 2020/10/02 20:46:49
# episode : 447 | final step : 98 | total reward : -2
# 2020/10/02 20:46:50
# episode : 448 | final step : 99 | total reward : -1
# 2020/10/02 20:46:51
# episode : 449 | final step : 100 | total reward : 0
# 2020/10/02 20:46:54
# episode : 450 | final step : 201 | total reward : 202
# 2020/10/02 20:46:56
# episode : 451 | final step : 99 | total reward : -1
# 2020/10/02 20:46:57
# episode : 452 | final step : 98 | total reward : -2
# 2020/10/02 20:46:58
# episode : 453 | final step : 99 | total reward : -1
# 2020/10/02 20:47:00
# episode : 454 | final step : 98 | total reward : -2
# 2020/10/02 20:47:01
# episode : 455 | final step : 100 | total reward : 0
# 2020/10/02 20:47:02
# episode : 456 | final step : 99 | total reward : -1
# 2020/10/02 20:47:04
# episode : 457 | final step : 99 | total reward : -1
# 2020/10/02 20:47:07
# episode : 458 | final step : 201 | total reward : 202
# 2020/10/02 20:47:10
# episode : 459 | final step : 201 | total reward : 202
# 2020/10/02 20:47:11
# episode : 460 | final step : 98 | total reward : -2
# 2020/10/02 20:47:12
# episode : 461 | final step : 99 | total reward : -1
# 2020/10/02 20:47:13
# episode : 462 | final step : 99 | total reward : -1
# 2020/10/02 20:47:15
# episode : 463 | final step : 100 | total reward : 0
# 2020/10/02 20:47:18
# episode : 464 | final step : 201 | total reward : 202
# 2020/10/02 20:47:20
# episode : 465 | final step : 98 | total reward : -2
# 2020/10/02 20:47:21
# episode : 466 | final step : 98 | total reward : -2
# 2020/10/02 20:47:25
# episode : 467 | final step : 98 | total reward : -2
# 2020/10/02 20:47:29
# episode : 468 | final step : 99 | total reward : -1
# 2020/10/02 20:47:32
# episode : 469 | final step : 99 | total reward : -1
# 2020/10/02 20:47:36
# episode : 470 | final step : 98 | total reward : -2
# 2020/10/02 20:47:39
# episode : 471 | final step : 98 | total reward : -2
# 2020/10/02 20:47:44
# episode : 472 | final step : 98 | total reward : -2
# 2020/10/02 20:47:47
# episode : 473 | final step : 98 | total reward : -2
# 2020/10/02 20:47:50
# episode : 474 | final step : 98 | total reward : -2
# 2020/10/02 20:47:54
# episode : 475 | final step : 98 | total reward : -2
# 2020/10/02 20:48:01
# episode : 476 | final step : 201 | total reward : 202
# 2020/10/02 20:48:08
# episode : 477 | final step : 201 | total reward : 202
# 2020/10/02 20:48:12
# episode : 478 | final step : 100 | total reward : 0
# 2020/10/02 20:48:16
# episode : 479 | final step : 98 | total reward : -2
# 2020/10/02 20:48:23
# episode : 480 | final step : 201 | total reward : 202
# 2020/10/02 20:48:31
# episode : 481 | final step : 201 | total reward : 202
# 2020/10/02 20:48:35
# episode : 482 | final step : 98 | total reward : -2
# 2020/10/02 20:48:39
# episode : 483 | final step : 98 | total reward : -2
# 2020/10/02 20:48:42
# episode : 484 | final step : 98 | total reward : -2
# 2020/10/02 20:48:46
# episode : 485 | final step : 98 | total reward : -2
# 2020/10/02 20:48:50
# episode : 486 | final step : 99 | total reward : -1
# 2020/10/02 20:48:54
# episode : 487 | final step : 98 | total reward : -2
# 2020/10/02 20:48:58
# episode : 488 | final step : 99 | total reward : -1
# 2020/10/02 20:49:02
# episode : 489 | final step : 99 | total reward : -1
# 2020/10/02 20:49:06
# episode : 490 | final step : 99 | total reward : -1
# 2020/10/02 20:49:09
# episode : 491 | final step : 98 | total reward : -2
# 2020/10/02 20:49:13
# episode : 492 | final step : 99 | total reward : -1
# 2020/10/02 20:49:17
# episode : 493 | final step : 98 | total reward : -2
# 2020/10/02 20:49:21
# episode : 494 | final step : 99 | total reward : -1
# 2020/10/02 20:49:29
# episode : 495 | final step : 201 | total reward : 202
# 2020/10/02 20:49:32
# episode : 496 | final step : 98 | total reward : -2
# 2020/10/02 20:49:36
# episode : 497 | final step : 98 | total reward : -2
# 2020/10/02 20:49:40
# episode : 498 | final step : 98 | total reward : -2
# 2020/10/02 20:49:43
# episode : 499 | final step : 98 | total reward : -2
# 2020/10/02 20:49:51
# episode : 500 | final step : 201 | total reward : 202
# 2020/10/02 20:49:55
# episode : 501 | final step : 98 | total reward : -2
# 2020/10/02 20:49:59
# episode : 502 | final step : 99 | total reward : -1
# 2020/10/02 20:50:07
# episode : 503 | final step : 201 | total reward : 202
# 2020/10/02 20:50:15
# episode : 504 | final step : 201 | total reward : 202
# 2020/10/02 20:50:22
# episode : 505 | final step : 201 | total reward : 202
# 2020/10/02 20:50:26
# episode : 506 | final step : 98 | total reward : -2
# 2020/10/02 20:50:29
# episode : 507 | final step : 99 | total reward : -1
# 2020/10/02 20:50:34
# episode : 508 | final step : 98 | total reward : -2
# 2020/10/02 20:50:41
# episode : 509 | final step : 201 | total reward : 202
# 2020/10/02 20:50:46
# episode : 510 | final step : 100 | total reward : 0
# 2020/10/02 20:50:49
# episode : 511 | final step : 99 | total reward : -1
# 2020/10/02 20:50:53
# episode : 512 | final step : 98 | total reward : -2
# 2020/10/02 20:50:56
# episode : 513 | final step : 99 | total reward : -1
# 2020/10/02 20:51:00
# episode : 514 | final step : 98 | total reward : -2
# 2020/10/02 20:51:03
# episode : 515 | final step : 98 | total reward : -2
# 2020/10/02 20:51:07
# episode : 516 | final step : 98 | total reward : -2
# 2020/10/02 20:51:10
# episode : 517 | final step : 98 | total reward : -2
# 2020/10/02 20:51:14
# episode : 518 | final step : 98 | total reward : -2
# 2020/10/02 20:51:17
# episode : 519 | final step : 98 | total reward : -2
# 2020/10/02 20:51:24
# episode : 520 | final step : 201 | total reward : 202
# 2020/10/02 20:51:28
# episode : 521 | final step : 98 | total reward : -2
# 2020/10/02 20:51:35
# episode : 522 | final step : 201 | total reward : 202
# 2020/10/02 20:51:40
# episode : 523 | final step : 98 | total reward : -2
# 2020/10/02 20:51:44
# episode : 524 | final step : 99 | total reward : -1
# 2020/10/02 20:51:48
# episode : 525 | final step : 98 | total reward : -2
# 2020/10/02 20:51:51
# episode : 526 | final step : 99 | total reward : -1
# 2020/10/02 20:51:55
# episode : 527 | final step : 99 | total reward : -1
# 2020/10/02 20:51:58
# episode : 528 | final step : 98 | total reward : -2
# 2020/10/02 20:52:02
# episode : 529 | final step : 98 | total reward : -2
# 2020/10/02 20:52:10
# episode : 530 | final step : 201 | total reward : 202
# 2020/10/02 20:52:14
# episode : 531 | final step : 98 | total reward : -2
# 2020/10/02 20:52:17
# episode : 532 | final step : 98 | total reward : -2
# 2020/10/02 20:52:21
# episode : 533 | final step : 99 | total reward : -1
# 2020/10/02 20:52:30
# episode : 534 | final step : 201 | total reward : 202
# 2020/10/02 20:52:33
# episode : 535 | final step : 98 | total reward : -2
# 2020/10/02 20:52:41
# episode : 536 | final step : 201 | total reward : 202
# 2020/10/02 20:52:44
# episode : 537 | final step : 99 | total reward : -1
# 2020/10/02 20:52:48
# episode : 538 | final step : 99 | total reward : -1
# 2020/10/02 20:52:52
# episode : 539 | final step : 98 | total reward : -2
# 2020/10/02 20:52:59
# episode : 540 | final step : 201 | total reward : 202
# 2020/10/02 20:53:03
# episode : 541 | final step : 99 | total reward : -1
# 2020/10/02 20:53:07
# episode : 542 | final step : 98 | total reward : -2
# 2020/10/02 20:53:14
# episode : 543 | final step : 201 | total reward : 202
# 2020/10/02 20:53:17
# episode : 544 | final step : 99 | total reward : -1
# 2020/10/02 20:53:20
# episode : 545 | final step : 98 | total reward : -2
# 2020/10/02 20:53:25
# episode : 546 | final step : 98 | total reward : -2
# 2020/10/02 20:53:28
# episode : 547 | final step : 98 | total reward : -2
# 2020/10/02 20:53:36
# episode : 548 | final step : 201 | total reward : 202
# 2020/10/02 20:53:39
# episode : 549 | final step : 98 | total reward : -2
# 2020/10/02 20:53:42
# episode : 550 | final step : 99 | total reward : -1
# 2020/10/02 20:53:50
# episode : 551 | final step : 201 | total reward : 202
# 2020/10/02 20:53:52
# episode : 552 | final step : 99 | total reward : -1
# 2020/10/02 20:53:56
# episode : 553 | final step : 98 | total reward : -2
# 2020/10/02 20:54:00
# episode : 554 | final step : 98 | total reward : -2
# 2020/10/02 20:54:03
# episode : 555 | final step : 99 | total reward : -1
# 2020/10/02 20:54:06
# episode : 556 | final step : 98 | total reward : -2
# 2020/10/02 20:54:14
# episode : 557 | final step : 201 | total reward : 202
# 2020/10/02 20:54:17
# episode : 558 | final step : 100 | total reward : 0
# 2020/10/02 20:54:20
# episode : 559 | final step : 98 | total reward : -2
# 2020/10/02 20:54:26
# episode : 560 | final step : 201 | total reward : 202
# 2020/10/02 20:54:29
# episode : 561 | final step : 99 | total reward : -1
# 2020/10/02 20:54:33
# episode : 562 | final step : 99 | total reward : -1
# 2020/10/02 20:54:36
# episode : 563 | final step : 98 | total reward : -2
# 2020/10/02 20:54:39
# episode : 564 | final step : 98 | total reward : -2
# 2020/10/02 20:54:42
# episode : 565 | final step : 98 | total reward : -2
# 2020/10/02 20:54:44
# episode : 566 | final step : 98 | total reward : -2
# 2020/10/02 20:54:47
# episode : 567 | final step : 100 | total reward : 0
# 2020/10/02 20:54:51
# episode : 568 | final step : 98 | total reward : -2
# 2020/10/02 20:54:55
# episode : 569 | final step : 99 | total reward : -1
# 2020/10/02 20:54:58
# episode : 570 | final step : 98 | total reward : -2
# 2020/10/02 20:55:04
# episode : 571 | final step : 201 | total reward : 202
# 2020/10/02 20:55:10
# episode : 572 | final step : 201 | total reward : 202
# 2020/10/02 20:55:16
# episode : 573 | final step : 201 | total reward : 202
# 2020/10/02 20:55:19
# episode : 574 | final step : 98 | total reward : -2
# 2020/10/02 20:55:22
# episode : 575 | final step : 100 | total reward : 0
# 2020/10/02 20:55:26
# episode : 576 | final step : 98 | total reward : -2
# 2020/10/02 20:55:30
# episode : 577 | final step : 98 | total reward : -2
# 2020/10/02 20:55:33
# episode : 578 | final step : 98 | total reward : -2
# 2020/10/02 20:55:36
# episode : 579 | final step : 98 | total reward : -2
# 2020/10/02 20:55:44
# episode : 580 | final step : 201 | total reward : 202
# 2020/10/02 20:55:47
# episode : 581 | final step : 98 | total reward : -2
# 2020/10/02 20:55:54
# episode : 582 | final step : 201 | total reward : 202
# 2020/10/02 20:55:57
# episode : 583 | final step : 98 | total reward : -2
# 2020/10/02 20:56:01
# episode : 584 | final step : 98 | total reward : -2
# 2020/10/02 20:56:05
# episode : 585 | final step : 98 | total reward : -2
# 2020/10/02 20:56:08
# episode : 586 | final step : 98 | total reward : -2
# 2020/10/02 20:56:16
# episode : 587 | final step : 201 | total reward : 202
# 2020/10/02 20:56:19
# episode : 588 | final step : 98 | total reward : -2
# 2020/10/02 20:56:22
# episode : 589 | final step : 98 | total reward : -2
# 2020/10/02 20:56:26
# episode : 590 | final step : 98 | total reward : -2
# 2020/10/02 20:56:30
# episode : 591 | final step : 98 | total reward : -2
# 2020/10/02 20:56:33
# episode : 592 | final step : 98 | total reward : -2
# 2020/10/02 20:56:40
# episode : 593 | final step : 201 | total reward : 202
# 2020/10/02 20:56:44
# episode : 594 | final step : 98 | total reward : -2
# 2020/10/02 20:56:47
# episode : 595 | final step : 99 | total reward : -1
# 2020/10/02 20:56:51
# episode : 596 | final step : 98 | total reward : -2
# 2020/10/02 20:56:57
# episode : 597 | final step : 201 | total reward : 202
# 2020/10/02 20:57:01
# episode : 598 | final step : 98 | total reward : -2
# 2020/10/02 20:57:08
# episode : 599 | final step : 201 | total reward : 202
# 2020/10/02 20:57:15
# episode : 600 | final step : 201 | total reward : 202
# 2020/10/02 20:57:18
# episode : 601 | final step : 98 | total reward : -2
# 2020/10/02 20:57:23
# episode : 602 | final step : 99 | total reward : -1
# 2020/10/02 20:57:26
# episode : 603 | final step : 98 | total reward : -2
# 2020/10/02 20:57:29
# episode : 604 | final step : 98 | total reward : -2
# 2020/10/02 20:57:33
# episode : 605 | final step : 98 | total reward : -2
# 2020/10/02 20:57:38
# episode : 606 | final step : 98 | total reward : -2
# 2020/10/02 20:57:41
# episode : 607 | final step : 99 | total reward : -1
# 2020/10/02 20:57:44
# episode : 608 | final step : 98 | total reward : -2
# 2020/10/02 20:57:48
# episode : 609 | final step : 98 | total reward : -2
# 2020/10/02 20:57:51
# episode : 610 | final step : 99 | total reward : -1
# 2020/10/02 20:57:54
# episode : 611 | final step : 98 | total reward : -2
# 2020/10/02 20:57:59
# episode : 612 | final step : 98 | total reward : -2
# 2020/10/02 20:58:02
# episode : 613 | final step : 98 | total reward : -2
# 2020/10/02 20:58:09
# episode : 614 | final step : 201 | total reward : 202
# 2020/10/02 20:58:13
# episode : 615 | final step : 99 | total reward : -1
# 2020/10/02 20:58:16
# episode : 616 | final step : 98 | total reward : -2
# 2020/10/02 20:58:20
# episode : 617 | final step : 98 | total reward : -2
# 2020/10/02 20:58:23
# episode : 618 | final step : 98 | total reward : -2
# 2020/10/02 20:58:26
# episode : 619 | final step : 98 | total reward : -2
# 2020/10/02 20:58:34
# episode : 620 | final step : 201 | total reward : 202
# 2020/10/02 20:58:37
# episode : 621 | final step : 100 | total reward : 0
# 2020/10/02 20:58:42
# episode : 622 | final step : 98 | total reward : -2
# 2020/10/02 20:58:45
# episode : 623 | final step : 99 | total reward : -1
# 2020/10/02 20:58:48
# episode : 624 | final step : 99 | total reward : -1
# 2020/10/02 20:58:56
# episode : 625 | final step : 201 | total reward : 202
# 2020/10/02 20:58:59
# episode : 626 | final step : 99 | total reward : -1
# 2020/10/02 20:59:03
# episode : 627 | final step : 98 | total reward : -2
# 2020/10/02 20:59:06
# episode : 628 | final step : 99 | total reward : -1
# 2020/10/02 20:59:09
# episode : 629 | final step : 98 | total reward : -2
# 2020/10/02 20:59:16
# episode : 630 | final step : 201 | total reward : 202
# 2020/10/02 20:59:20
# episode : 631 | final step : 98 | total reward : -2
# 2020/10/02 20:59:23
# episode : 632 | final step : 99 | total reward : -1
# 2020/10/02 20:59:27
# episode : 633 | final step : 100 | total reward : 0
# 2020/10/02 20:59:30
# episode : 634 | final step : 98 | total reward : -2
# 2020/10/02 20:59:33
# episode : 635 | final step : 99 | total reward : -1
# 2020/10/02 20:59:40
# episode : 636 | final step : 201 | total reward : 202
# 2020/10/02 20:59:43
# episode : 637 | final step : 98 | total reward : -2
# 2020/10/02 20:59:47
# episode : 638 | final step : 97 | total reward : -3
# 2020/10/02 20:59:51
# episode : 639 | final step : 98 | total reward : -2
# 2020/10/02 20:59:54
# episode : 640 | final step : 99 | total reward : -1
# 2020/10/02 20:59:57
# episode : 641 | final step : 98 | total reward : -2
# 2020/10/02 21:00:01
# episode : 642 | final step : 98 | total reward : -2
# 2020/10/02 21:00:04
# episode : 643 | final step : 99 | total reward : -1
# 2020/10/02 21:00:07
# episode : 644 | final step : 98 | total reward : -2
# 2020/10/02 21:00:11
# episode : 645 | final step : 98 | total reward : -2
# 2020/10/02 21:00:15
# episode : 646 | final step : 99 | total reward : -1
# 2020/10/02 21:00:18
# episode : 647 | final step : 98 | total reward : -2
# 2020/10/02 21:00:21
# episode : 648 | final step : 99 | total reward : -1
# 2020/10/02 21:00:25
# episode : 649 | final step : 98 | total reward : -2
# 2020/10/02 21:00:28
# episode : 650 | final step : 99 | total reward : -1
# 2020/10/02 21:00:32
# episode : 651 | final step : 98 | total reward : -2
# 2020/10/02 21:00:36
# episode : 652 | final step : 98 | total reward : -2
# 2020/10/02 21:00:39
# episode : 653 | final step : 100 | total reward : 0
# 2020/10/02 21:00:47
# episode : 654 | final step : 201 | total reward : 202
# 2020/10/02 21:00:49
# episode : 655 | final step : 98 | total reward : -2
# 2020/10/02 21:00:57
# ...
# 2020/10/02 21:10:06
# episode : 779 | final step : 99 | total reward : -1
# 2020/10/02 21:10:10
# episode : 780 | final step : 98 | total reward : -2
# 2020/10/02 21:10:13
# episode : 781 | final step : 98 | total reward : -2
# 2020/10/02 21:10:16
# episode : 782 | final step : 98 | total reward : -2
# 2020/10/02 21:10:19
# episode : 783 | final step : 98 | total reward : -2
# 2020/10/02 21:10:22
# episode : 784 | final step : 98 | total reward : -2
# 2020/10/02 21:10:26
# episode : 785 | final step : 99 | total reward : -1
# 2020/10/02 21:10:29
# episode : 786 | final step : 98 | total reward : -2
# 2020/10/02 21:10:32
# episode : 787 | final step : 98 | total reward : -2
# 2020/10/02 21:10:39
# episode : 788 | final step : 201 | total reward : 202
# 2020/10/02 21:10:43
# episode : 789 | final step : 98 | total reward : -2
# 2020/10/02 21:10:47
# episode : 790 | final step : 98 | total reward : -2
# 2020/10/02 21:10:50
# episode : 791 | final step : 98 | total reward : -2
# 2020/10/02 21:10:53
# episode : 792 | final step : 99 | total reward : -1
# 2020/10/02 21:10:57
# episode : 793 | final step : 97 | total reward : -3
# 2020/10/02 21:11:00
# episode : 794 | final step : 98 | total reward : -2
# 2020/10/02 21:11:04
# episode : 795 | final step : 98 | total reward : -2
# 2020/10/02 21:11:11
# episode : 796 | final step : 201 | total reward : 202
# 2020/10/02 21:11:14
# episode : 797 | final step : 99 | total reward : -1
# 2020/10/02 21:11:18
# episode : 798 | final step : 100 | total reward : 0
# 2020/10/02 21:11:21
# episode : 799 | final step : 99 | total reward : -1
# 2020/10/02 21:11:28
# episode : 800 | final step : 201 | total reward : 202
# 2020/10/02 21:11:32
# episode : 801 | final step : 98 | total reward : -2
# 2020/10/02 21:11:36
# episode : 802 | final step : 98 | total reward : -2
# 2020/10/02 21:11:39
# episode : 803 | final step : 99 | total reward : -1
# 2020/10/02 21:11:42
# episode : 804 | final step : 98 | total reward : -2
# 2020/10/02 21:11:47
# episode : 805 | final step : 99 | total reward : -1
# 2020/10/02 21:11:54
# episode : 806 | final step : 201 | total reward : 202
# 2020/10/02 21:11:58
# episode : 807 | final step : 98 | total reward : -2
# 2020/10/02 21:12:01
# episode : 808 | final step : 100 | total reward : 0
# 2020/10/02 21:12:04
# episode : 809 | final step : 99 | total reward : -1
# 2020/10/02 21:12:08
# episode : 810 | final step : 98 | total reward : -2
# 2020/10/02 21:12:12
# episode : 811 | final step : 98 | total reward : -2
# 2020/10/02 21:12:15
# episode : 812 | final step : 98 | total reward : -2
# 2020/10/02 21:12:19
# episode : 813 | final step : 98 | total reward : -2
# 2020/10/02 21:12:23
# episode : 814 | final step : 98 | total reward : -2
# 2020/10/02 21:12:26
# episode : 815 | final step : 99 | total reward : -1
# 2020/10/02 21:12:30
# episode : 816 | final step : 98 | total reward : -2
# 2020/10/02 21:12:34
# episode : 817 | final step : 98 | total reward : -2
# 2020/10/02 21:12:40
# episode : 818 | final step : 201 | total reward : 202
# 2020/10/02 21:12:44
# episode : 819 | final step : 99 | total reward : -1
# 2020/10/02 21:12:47
# episode : 820 | final step : 100 | total reward : 0
# 2020/10/02 21:12:50
# episode : 821 | final step : 99 | total reward : -1
# 2020/10/02 21:12:54
# episode : 822 | final step : 99 | total reward : -1
# 2020/10/02 21:13:01
# episode : 823 | final step : 201 | total reward : 202
# 2020/10/02 21:13:05
# episode : 824 | final step : 98 | total reward : -2
# 2020/10/02 21:13:11
# episode : 825 | final step : 201 | total reward : 202
# 2020/10/02 21:13:14
# episode : 826 | final step : 98 | total reward : -2
# 2020/10/02 21:13:18
# episode : 827 | final step : 97 | total reward : -3
# 2020/10/02 21:13:21
# episode : 828 | final step : 98 | total reward : -2
# 2020/10/02 21:13:25
# episode : 829 | final step : 98 | total reward : -2
# 2020/10/02 21:13:32
# episode : 830 | final step : 201 | total reward : 202
# 2020/10/02 21:13:39
# episode : 831 | final step : 201 | total reward : 202
# 2020/10/02 21:13:42
# episode : 832 | final step : 98 | total reward : -2
# 2020/10/02 21:13:45
# episode : 833 | final step : 98 | total reward : -2
# 2020/10/02 21:13:53
# episode : 834 | final step : 201 | total reward : 202
# 2020/10/02 21:13:56
# episode : 835 | final step : 99 | total reward : -1
# 2020/10/02 21:14:04
# episode : 836 | final step : 201 | total reward : 202
# 2020/10/02 21:14:07
# episode : 837 | final step : 98 | total reward : -2
# 2020/10/02 21:14:10
# episode : 838 | final step : 98 | total reward : -2
# 2020/10/02 21:14:13
# episode : 839 | final step : 98 | total reward : -2
# 2020/10/02 21:14:17
# episode : 840 | final step : 99 | total reward : -1
# 2020/10/02 21:14:21
# episode : 841 | final step : 98 | total reward : -2
# 2020/10/02 21:14:24
# episode : 842 | final step : 98 | total reward : -2
# 2020/10/02 21:14:27
# episode : 843 | final step : 98 | total reward : -2
# 2020/10/02 21:14:31
# episode : 844 | final step : 98 | total reward : -2
# 2020/10/02 21:14:38
# episode : 845 | final step : 201 | total reward : 202
# 2020/10/02 21:14:41
# episode : 846 | final step : 99 | total reward : -1
# 2020/10/02 21:14:45
# episode : 847 | final step : 100 | total reward : 0
# 2020/10/02 21:14:48
# episode : 848 | final step : 98 | total reward : -2
# 2020/10/02 21:14:51
# episode : 849 | final step : 98 | total reward : -2
# 2020/10/02 21:14:55
# episode : 850 | final step : 99 | total reward : -1
# 2020/10/02 21:15:01
# episode : 851 | final step : 201 | total reward : 202
# 2020/10/02 21:15:05
# episode : 852 | final step : 99 | total reward : -1
# 2020/10/02 21:15:12
# episode : 853 | final step : 201 | total reward : 202
# 2020/10/02 21:15:16
# episode : 854 | final step : 98 | total reward : -2
# 2020/10/02 21:15:20
# episode : 855 | final step : 98 | total reward : -2
# 2020/10/02 21:15:23
# episode : 856 | final step : 98 | total reward : -2
# 2020/10/02 21:15:26
# episode : 857 | final step : 98 | total reward : -2
# 2020/10/02 21:15:30
# episode : 858 | final step : 99 | total reward : -1
# 2020/10/02 21:15:33
# episode : 859 | final step : 98 | total reward : -2
# 2020/10/02 21:15:40
# episode : 860 | final step : 201 | total reward : 202
# 2020/10/02 21:15:44
# episode : 861 | final step : 98 | total reward : -2
# 2020/10/02 21:15:47
# episode : 862 | final step : 99 | total reward : -1
# 2020/10/02 21:15:54
# episode : 863 | final step : 201 | total reward : 202
# 2020/10/02 21:15:57
# episode : 864 | final step : 99 | total reward : -1
# 2020/10/02 21:16:01
# episode : 865 | final step : 98 | total reward : -2
# 2020/10/02 21:16:04
# episode : 866 | final step : 99 | total reward : -1
# 2020/10/02 21:16:07
# episode : 867 | final step : 98 | total reward : -2
# 2020/10/02 21:16:11
# episode : 868 | final step : 98 | total reward : -2
# 2020/10/02 21:16:14
# episode : 869 | final step : 99 | total reward : -1
# 2020/10/02 21:16:17
# episode : 870 | final step : 98 | total reward : -2
# 2020/10/02 21:16:20
# episode : 871 | final step : 99 | total reward : -1
# 2020/10/02 21:16:24
# episode : 872 | final step : 98 | total reward : -2
# 2020/10/02 21:16:27
# episode : 873 | final step : 99 | total reward : -1
# 2020/10/02 21:16:34
# episode : 874 | final step : 201 | total reward : 202
# 2020/10/02 21:16:38
# episode : 875 | final step : 98 | total reward : -2
# 2020/10/02 21:16:41
# episode : 876 | final step : 98 | total reward : -2
# 2020/10/02 21:16:44
# episode : 877 | final step : 98 | total reward : -2
# 2020/10/02 21:16:48
# episode : 878 | final step : 99 | total reward : -1
# 2020/10/02 21:16:51
# episode : 879 | final step : 98 | total reward : -2
# 2020/10/02 21:16:55
# episode : 880 | final step : 98 | total reward : -2
# 2020/10/02 21:16:58
# episode : 881 | final step : 98 | total reward : -2
# 2020/10/02 21:17:02
# episode : 882 | final step : 98 | total reward : -2
# 2020/10/02 21:17:05
# episode : 883 | final step : 99 | total reward : -1
# 2020/10/02 21:17:09
# episode : 884 | final step : 98 | total reward : -2
# 2020/10/02 21:17:13
# episode : 885 | final step : 98 | total reward : -2
# 2020/10/02 21:17:19
# episode : 886 | final step : 201 | total reward : 202
# 2020/10/02 21:17:24
# episode : 887 | final step : 99 | total reward : -1
# 2020/10/02 21:17:30
# episode : 888 | final step : 201 | total reward : 202
# 2020/10/02 21:17:34
# episode : 889 | final step : 98 | total reward : -2
# 2020/10/02 21:17:37
# episode : 890 | final step : 98 | total reward : -2
# 2020/10/02 21:17:40
# episode : 891 | final step : 99 | total reward : -1
# 2020/10/02 21:17:44
# episode : 892 | final step : 99 | total reward : -1
# 2020/10/02 21:17:47
# episode : 893 | final step : 98 | total reward : -2
# 2020/10/02 21:17:50
# episode : 894 | final step : 99 | total reward : -1
# 2020/10/02 21:17:53
# episode : 895 | final step : 98 | total reward : -2
# 2020/10/02 21:17:58
# episode : 896 | final step : 101 | total reward : 1
# 2020/10/02 21:18:01
# episode : 897 | final step : 99 | total reward : -1
# 2020/10/02 21:18:05
# episode : 898 | final step : 98 | total reward : -2
# 2020/10/02 21:18:09
# episode : 899 | final step : 99 | total reward : -1
# 2020/10/02 21:18:12
# episode : 900 | final step : 98 | total reward : -2
# 2020/10/02 21:18:16
# episode : 901 | final step : 99 | total reward : -1
# 2020/10/02 21:18:20
# episode : 902 | final step : 99 | total reward : -1
# 2020/10/02 21:18:23
# episode : 903 | final step : 98 | total reward : -2
# 2020/10/02 21:18:26
# episode : 904 | final step : 99 | total reward : -1
# 2020/10/02 21:18:34
# episode : 905 | final step : 201 | total reward : 202
# 2020/10/02 21:18:37
# episode : 906 | final step : 98 | total reward : -2
# 2020/10/02 21:18:41
# episode : 907 | final step : 99 | total reward : -1
# 2020/10/02 21:18:48
# episode : 908 | final step : 201 | total reward : 202
# 2020/10/02 21:18:52
# episode : 909 | final step : 99 | total reward : -1
# 2020/10/02 21:18:56
# episode : 910 | final step : 99 | total reward : -1
# 2020/10/02 21:18:59
# episode : 911 | final step : 98 | total reward : -2
# 2020/10/02 21:19:02
# episode : 912 | final step : 99 | total reward : -1
# 2020/10/02 21:19:06
# episode : 913 | final step : 97 | total reward : -3
# 2020/10/02 21:19:09
# episode : 914 | final step : 99 | total reward : -1
# 2020/10/02 21:19:13
# episode : 915 | final step : 97 | total reward : -3
# 2020/10/02 21:19:19
# episode : 916 | final step : 201 | total reward : 202
# 2020/10/02 21:19:23
# episode : 917 | final step : 99 | total reward : -1
# 2020/10/02 21:19:27
# episode : 918 | final step : 98 | total reward : -2
# 2020/10/02 21:19:30
# episode : 919 | final step : 98 | total reward : -2
# 2020/10/02 21:19:33
# episode : 920 | final step : 98 | total reward : -2
# 2020/10/02 21:19:42
# episode : 921 | final step : 201 | total reward : 202
# 2020/10/02 21:19:49
# episode : 922 | final step : 201 | total reward : 202
# 2020/10/02 21:19:55
# episode : 923 | final step : 201 | total reward : 202
# 2020/10/02 21:19:59
# episode : 924 | final step : 98 | total reward : -2
# 2020/10/02 21:20:04
# episode : 925 | final step : 99 | total reward : -1
# 2020/10/02 21:20:10
# episode : 926 | final step : 201 | total reward : 202
# 2020/10/02 21:20:14
# episode : 927 | final step : 98 | total reward : -2
# 2020/10/02 21:20:21
# episode : 928 | final step : 201 | total reward : 202
# 2020/10/02 21:20:25
# episode : 929 | final step : 99 | total reward : -1
# 2020/10/02 21:20:28
# episode : 930 | final step : 99 | total reward : -1
# 2020/10/02 21:20:31
# episode : 931 | final step : 98 | total reward : -2
# 2020/10/02 21:20:35
# episode : 932 | final step : 98 | total reward : -2
# 2020/10/02 21:20:39
# episode : 933 | final step : 99 | total reward : -1
# 2020/10/02 21:20:46
# episode : 934 | final step : 201 | total reward : 202
# 2020/10/02 21:20:50
# episode : 935 | final step : 98 | total reward : -2
# 2020/10/02 21:20:53
# episode : 936 | final step : 98 | total reward : -2
# 2020/10/02 21:20:57
# episode : 937 | final step : 99 | total reward : -1
# 2020/10/02 21:21:01
# episode : 938 | final step : 99 | total reward : -1
# 2020/10/02 21:21:04
# episode : 939 | final step : 98 | total reward : -2
# 2020/10/02 21:21:07
# episode : 940 | final step : 99 | total reward : -1
# 2020/10/02 21:21:11
# episode : 941 | final step : 98 | total reward : -2
# 2020/10/02 21:21:14
# episode : 942 | final step : 99 | total reward : -1
# 2020/10/02 21:21:17
# episode : 943 | final step : 99 | total reward : -1
# 2020/10/02 21:21:25
# episode : 944 | final step : 201 | total reward : 202
# 2020/10/02 21:21:28
# episode : 945 | final step : 98 | total reward : -2
# 2020/10/02 21:21:32
# episode : 946 | final step : 98 | total reward : -2
# 2020/10/02 21:21:36
# episode : 947 | final step : 98 | total reward : -2
# 2020/10/02 21:21:39
# episode : 948 | final step : 99 | total reward : -1
# 2020/10/02 21:21:42
# episode : 949 | final step : 99 | total reward : -1
# 2020/10/02 21:21:46
# episode : 950 | final step : 98 | total reward : -2
# 2020/10/02 21:21:49
# episode : 951 | final step : 99 | total reward : -1
# 2020/10/02 21:21:53
# episode : 952 | final step : 98 | total reward : -2
# 2020/10/02 21:21:57
# episode : 953 | final step : 98 | total reward : -2
# 2020/10/02 21:22:00
# episode : 954 | final step : 98 | total reward : -2
# 2020/10/02 21:22:03
# episode : 955 | final step : 99 | total reward : -1
# 2020/10/02 21:22:07
# episode : 956 | final step : 99 | total reward : -1
# 2020/10/02 21:22:10
# episode : 957 | final step : 98 | total reward : -2
# 2020/10/02 21:22:13
# episode : 958 | final step : 100 | total reward : 0
# 2020/10/02 21:22:18
# episode : 959 | final step : 98 | total reward : -2
# 2020/10/02 21:22:22
# episode : 960 | final step : 99 | total reward : -1
# 2020/10/02 21:22:25
# episode : 961 | final step : 99 | total reward : -1
# 2020/10/02 21:22:29
# episode : 962 | final step : 99 | total reward : -1
# 2020/10/02 21:22:33
# episode : 963 | final step : 99 | total reward : -1
# 2020/10/02 21:22:36
# episode : 964 | final step : 98 | total reward : -2
# 2020/10/02 21:22:39
# episode : 965 | final step : 98 | total reward : -2
# 2020/10/02 21:22:43
# episode : 966 | final step : 98 | total reward : -2
# 2020/10/02 21:22:46
# episode : 967 | final step : 98 | total reward : -2
# 2020/10/02 21:22:50
# episode : 968 | final step : 98 | total reward : -2
# 2020/10/02 21:22:54
# episode : 969 | final step : 98 | total reward : -2
# 2020/10/02 21:22:57
# episode : 970 | final step : 98 | total reward : -2
# 2020/10/02 21:23:00
# episode : 971 | final step : 98 | total reward : -2
# 2020/10/02 21:23:04
# episode : 972 | final step : 99 | total reward : -1
# 2020/10/02 21:23:08
# episode : 973 | final step : 99 | total reward : -1
# 2020/10/02 21:23:11
# episode : 974 | final step : 98 | total reward : -2
# 2020/10/02 21:23:15
# episode : 975 | final step : 98 | total reward : -2
# 2020/10/02 21:23:19
# episode : 976 | final step : 98 | total reward : -2
# 2020/10/02 21:23:22
# episode : 977 | final step : 100 | total reward : 0
# 2020/10/02 21:23:25
# episode : 978 | final step : 98 | total reward : -2
# 2020/10/02 21:23:29
# episode : 979 | final step : 98 | total reward : -2
# 2020/10/02 21:23:36
# episode : 980 | final step : 201 | total reward : 202
# 2020/10/02 21:23:43
# episode : 981 | final step : 201 | total reward : 202
# 2020/10/02 21:23:47
# episode : 982 | final step : 98 | total reward : -2
# 2020/10/02 21:23:51
# episode : 983 | final step : 98 | total reward : -2
# 2020/10/02 21:23:57
# episode : 984 | final step : 201 | total reward : 202
# 2020/10/02 21:24:04
# episode : 985 | final step : 201 | total reward : 202
# 2020/10/02 21:24:07
# episode : 986 | final step : 101 | total reward : 1
# 2020/10/02 21:24:11
# episode : 987 | final step : 98 | total reward : -2
# 2020/10/02 21:24:15
# episode : 988 | final step : 98 | total reward : -2
# 2020/10/02 21:24:18
# episode : 989 | final step : 98 | total reward : -2
# 2020/10/02 21:24:22
# episode : 990 | final step : 98 | total reward : -2
# 2020/10/02 21:24:25
# episode : 991 | final step : 98 | total reward : -2
# 2020/10/02 21:24:32
# episode : 992 | final step : 201 | total reward : 202
# 2020/10/02 21:24:36
# episode : 993 | final step : 99 | total reward : -1
# 2020/10/02 21:24:40
# episode : 994 | final step : 99 | total reward : -1
# 2020/10/02 21:24:47
# episode : 995 | final step : 201 | total reward : 202
# 2020/10/02 21:24:50
# episode : 996 | final step : 99 | total reward : -1
# 2020/10/02 21:24:53
# episode : 997 | final step : 99 | total reward : -1
# 2020/10/02 21:24:57
# episode : 998 | final step : 100 | total reward : 0
# 2020/10/02 21:25:00
# episode : 999 | final step : 99 | total reward : -1
# Complete

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(reward_list)

# %%
def moving_average(data,n):
    len_data=len(data)-n
    res_data=np.zeros(len_data)

    for i in range(len_data):
        res_data[i]=sum(data[i:i+n])/n
    return res_data

# %%
average_number=10
filtered_data=moving_average(reward_list,average_number)
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(filtered_data)

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[999]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()
