# %%
import math, random

import gym
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd 
import torch.nn.functional as F

from common.layers import NoisyLinear
from common.replay_buffer import ReplayBuffer
import gym_Aircraft

from itertools import count
import time
import itertools
import matplotlib
import matplotlib.pyplot as plt

# %%
USE_CUDA = torch.cuda.is_available()
Variable = lambda *args, **kwargs: autograd.Variable(*args, **kwargs).cuda() if USE_CUDA else autograd.Variable(*args, **kwargs)

# %%
env_id = "acav-v0"
env = gym.make(env_id)
# Out:
# /home/jupyter-kunwoopark/.local/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
class RainbowDQN(nn.Module):
    def __init__(self, num_inputs, num_actions, num_atoms, Vmin, Vmax):
        super(RainbowDQN, self).__init__()
        
        self.num_inputs   = num_inputs
        self.num_actions  = num_actions
        self.num_atoms    = num_atoms
        self.Vmin         = Vmin
        self.Vmax         = Vmax
        
        self.linear1 = nn.Linear(num_inputs, 32)
        self.linear2 = nn.Linear(32, 64)
        
        self.noisy_value1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_value2 = NoisyLinear(64, self.num_atoms, use_cuda=USE_CUDA)
        
        self.noisy_advantage1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_advantage2 = NoisyLinear(64, self.num_atoms * self.num_actions, use_cuda=USE_CUDA)
        
    def forward(self, x):
        batch_size = x.size(0)
        
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        
        value = F.relu(self.noisy_value1(x))
        value = self.noisy_value2(value)
        
        advantage = F.relu(self.noisy_advantage1(x))
        advantage = self.noisy_advantage2(advantage)
        
        value     = value.view(batch_size, 1, self.num_atoms)
        advantage = advantage.view(batch_size, self.num_actions, self.num_atoms)
        
        x = value + advantage - advantage.mean(1, keepdim=True)
        x = F.softmax(x.view(-1, self.num_atoms)).view(-1, self.num_actions, self.num_atoms)
        
        return x
        
    def reset_noise(self):
        self.noisy_value1.reset_noise()
        self.noisy_value2.reset_noise()
        self.noisy_advantage1.reset_noise()
        self.noisy_advantage2.reset_noise()
    
    def act(self, state):
        state = Variable(torch.FloatTensor(state).unsqueeze(0), volatile=True)
        dist = self.forward(state).data.cpu()
        dist = dist * torch.linspace(self.Vmin, self.Vmax, self.num_atoms)
        action = dist.sum(2).max(1)[1].numpy()[0]
        return action

# %%
num_atoms = 51
Vmin = -10
Vmax = 10

current_model = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)
target_model  = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)

if USE_CUDA:
    current_model = current_model.cuda()
    target_model  = target_model.cuda()
    
optimizer = optim.Adam(current_model.parameters(), 0.001)

replay_buffer = ReplayBuffer(10000)

# %%
def update_target(current_model, target_model):
    target_model.load_state_dict(current_model.state_dict())
    
update_target(current_model, target_model)

# %%
def projection_distribution(next_state, rewards, dones):
    batch_size  = next_state.size(0)
    
    delta_z = float(Vmax - Vmin) / (num_atoms - 1)
    support = torch.linspace(Vmin, Vmax, num_atoms)
    
    next_dist   = target_model(next_state).data.cpu() * support
    next_action = next_dist.sum(2).max(1)[1]
    next_action = next_action.unsqueeze(1).unsqueeze(1).expand(next_dist.size(0), 1, next_dist.size(2))
    next_dist   = next_dist.gather(1, next_action).squeeze(1)
        
    rewards = rewards.unsqueeze(1).expand_as(next_dist)
    dones   = dones.unsqueeze(1).expand_as(next_dist)
    support = support.unsqueeze(0).expand_as(next_dist)
    
    Tz = rewards + (1 - dones) * 0.99 * support
    Tz = Tz.clamp(min=Vmin, max=Vmax)
    b  = (Tz - Vmin) / delta_z
    l  = b.floor().long()
    u  = b.ceil().long()
        
    offset = torch.linspace(0, (batch_size - 1) * num_atoms, batch_size).long()\
                    .unsqueeze(1).expand(batch_size, num_atoms)

    proj_dist = torch.zeros(next_dist.size())    
    proj_dist.view(-1).index_add_(0, (l + offset).view(-1), (next_dist * (u.float() - b)).view(-1))
    proj_dist.view(-1).index_add_(0, (u + offset).view(-1), (next_dist * (b - l.float())).view(-1))
        
    return proj_dist

# %%
def compute_td_loss(batch_size):
    state, action, reward, next_state, done = replay_buffer.sample(batch_size) 

    state      = Variable(torch.FloatTensor(np.float32(state)))
    next_state = Variable(torch.FloatTensor(np.float32(next_state)), volatile=True)
    action     = Variable(torch.LongTensor(action))
    reward     = torch.FloatTensor(reward)
    done       = torch.FloatTensor(np.float32(done))

    proj_dist = projection_distribution(next_state, reward, done)
    
    dist = current_model(state)
    action = action.unsqueeze(1).unsqueeze(1).expand(batch_size, 1, num_atoms)
    dist = dist.gather(1, action).squeeze(1)
    dist.data.clamp_(0.01, 0.99)
    loss = -(Variable(proj_dist) * dist.log()).sum(1)
    loss  = loss.mean()
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    current_model.reset_noise()
    target_model.reset_noise()
    
    return loss

# %%
num_episodes = 50000
batch_size = 32
gamma=0.99
TARGET_UPDATE=10

losses = []
total_res=[]
reward_list=[]
for i_episode in range(num_episodes):
    total_reward=0
    
    # 환경과 상태 초기화
    res_list=np.zeros(11)
    state = env.reset()

    for t in count():
        # 행동 선택과 수행
        
        action = current_model.act(state)
        
        next_state, reward, done, res = env.step(action)
        
        # 메모리에 변이 저장
        replay_buffer.push(state, action, reward, next_state, done)
        

        # 새로운 상태 관찰
        if not done:
            next_state = next_state
        else:
            next_state = None

        

        # 다음 상태로 이동
        state = next_state

     
        # Data save
        
        cmd_list,r_list,elev_list,azim_list,Pm_list,Pt_list,h_list=res
        Pm_list=Pm_list.tolist()
        Pt_list=Pt_list.tolist()
        merged_data=itertools.chain([cmd_list],[r_list],[elev_list],[azim_list],Pm_list,Pt_list,[h_list])
        merged_data=np.array(list(merged_data))
        res_list=np.vstack([res_list,merged_data])
        
        total_reward+=reward
        
        if done:
            res_list=np.delete(res_list,0,0)
            
            total_res.append(res_list)
            reward_list.append(total_reward)
            
            now = time.localtime()
            print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))
            print("episode : {} | final step : {} | total reward : {}".format(i_episode, t, total_reward))
            break
        if len(replay_buffer) > batch_size:
            loss = compute_td_loss(batch_size)
            losses.append(loss.item())
            
        
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        update_target(current_model, target_model)

print('Complete')
env.close()
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 2020/10/05 11:47:07
# episode : 0 | final step : 97 | total reward : 15.0
# 2020/10/05 11:47:08
# episode : 1 | final step : 98 | total reward : 3.0
# 2020/10/05 11:47:09
# episode : 2 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:10
# episode : 3 | final step : 97 | total reward : 5.0
# 2020/10/05 11:47:11
# episode : 4 | final step : 98 | total reward : 3.0
# 2020/10/05 11:47:12
# episode : 5 | final step : 100 | total reward : 1.0
# 2020/10/05 11:47:13
# episode : 6 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:14
# episode : 7 | final step : 98 | total reward : 3.0
# 2020/10/05 11:47:15
# episode : 8 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:16
# episode : 9 | final step : 95 | total reward : 6.0
# 2020/10/05 11:47:17
# episode : 10 | final step : 100 | total reward : 1.0
# 2020/10/05 11:47:18
# episode : 11 | final step : 100 | total reward : 1.0
# 2020/10/05 11:47:19
# episode : 12 | final step : 96 | total reward : 5.0
# 2020/10/05 11:47:20
# episode : 13 | final step : 93 | total reward : 8.0
# 2020/10/05 11:47:21
# episode : 14 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:22
# episode : 15 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:23
# episode : 16 | final step : 98 | total reward : 3.0
# 2020/10/05 11:47:24
# episode : 17 | final step : 100 | total reward : 1.0
# 2020/10/05 11:47:25
# episode : 18 | final step : 96 | total reward : 5.0
# 2020/10/05 11:47:26
# episode : 19 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:27
# episode : 20 | final step : 98 | total reward : 3.0
# 2020/10/05 11:47:28
# episode : 21 | final step : 97 | total reward : 4.0
# 2020/10/05 11:47:29
# episode : 22 | final step : 100 | total reward : 1.0
# 2020/10/05 11:47:30
# episode : 23 | final step : 100 | total reward : 1.0
# 2020/10/05 11:47:31
# episode : 24 | final step : 100 | total reward : 1.0
# 2020/10/05 11:47:32
# episode : 25 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:34
# episode : 26 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:35
# episode : 27 | final step : 100 | total reward : 1.0
# 2020/10/05 11:47:36
# episode : 28 | final step : 100 | total reward : 1.0
# 2020/10/05 11:47:37
# episode : 29 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:38
# episode : 30 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:40
# episode : 31 | final step : 100 | total reward : 1.0
# 2020/10/05 11:47:41
# episode : 32 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:42
# episode : 33 | final step : 97 | total reward : 4.0
# 2020/10/05 11:47:43
# episode : 34 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:44
# episode : 35 | final step : 94 | total reward : 7.0
# 2020/10/05 11:47:45
# episode : 36 | final step : 98 | total reward : 3.0
# 2020/10/05 11:47:46
# episode : 37 | final step : 96 | total reward : 5.0
# 2020/10/05 11:47:47
# episode : 38 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:48
# episode : 39 | final step : 99 | total reward : 2.0
# 2020/10/05 11:47:50
# episode : 40 | final step : 98 | total reward : 3.0
# 2020/10/05 11:47:51
# episode : 41 | final step : 98 | total reward : 3.0
# 2020/10/05 11:47:52
# episode : 42 | final step : 100 | total reward : 1.0
# 2020/10/05 11:47:53
# episode : 43 | final step : 100 | total reward : 1.0
# 2020/10/05 11:47:54
# episode : 44 | final step : 91 | total reward : 10.0
# 2020/10/05 11:47:55
# episode : 45 | final step : 92 | total reward : 9.0
# 2020/10/05 11:47:56
# episode : 46 | final step : 98 | total reward : 3.0
# 2020/10/05 11:47:57
# episode : 47 | final step : 98 | total reward : 3.0
# 2020/10/05 11:47:58
# episode : 48 | final step : 100 | total reward : 1.0
# 2020/10/05 11:47:59
# episode : 49 | final step : 96 | total reward : 5.0
# 2020/10/05 11:48:00
# episode : 50 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:01
# episode : 51 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:02
# episode : 52 | final step : 94 | total reward : 7.0
# 2020/10/05 11:48:03
# episode : 53 | final step : 100 | total reward : 1.0
# 2020/10/05 11:48:04
# episode : 54 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:05
# episode : 55 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:06
# episode : 56 | final step : 95 | total reward : 6.0
# 2020/10/05 11:48:07
# episode : 57 | final step : 100 | total reward : 1.0
# 2020/10/05 11:48:08
# episode : 58 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:09
# episode : 59 | final step : 100 | total reward : 1.0
# 2020/10/05 11:48:10
# episode : 60 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:11
# episode : 61 | final step : 100 | total reward : 1.0
# 2020/10/05 11:48:12
# episode : 62 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:13
# episode : 63 | final step : 100 | total reward : 1.0
# 2020/10/05 11:48:14
# episode : 64 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:15
# episode : 65 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:16
# episode : 66 | final step : 100 | total reward : 1.0
# 2020/10/05 11:48:18
# episode : 67 | final step : 95 | total reward : 6.0
# 2020/10/05 11:48:19
# episode : 68 | final step : 98 | total reward : 3.0
# 2020/10/05 11:48:20
# episode : 69 | final step : 98 | total reward : 3.0
# 2020/10/05 11:48:21
# episode : 70 | final step : 97 | total reward : 4.0
# 2020/10/05 11:48:22
# episode : 71 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:24
# episode : 72 | final step : 97 | total reward : 4.0
# 2020/10/05 11:48:25
# episode : 73 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:26
# episode : 74 | final step : 97 | total reward : 4.0
# 2020/10/05 11:48:27
# episode : 75 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:28
# episode : 76 | final step : 100 | total reward : 1.0
# 2020/10/05 11:48:29
# episode : 77 | final step : 94 | total reward : 7.0
# 2020/10/05 11:48:30
# episode : 78 | final step : 94 | total reward : 7.0
# 2020/10/05 11:48:31
# episode : 79 | final step : 93 | total reward : 8.0
# 2020/10/05 11:48:32
# episode : 80 | final step : 100 | total reward : 1.0
# 2020/10/05 11:48:33
# episode : 81 | final step : 94 | total reward : 7.0
# 2020/10/05 11:48:34
# episode : 82 | final step : 98 | total reward : 3.0
# 2020/10/05 11:48:35
# episode : 83 | final step : 93 | total reward : 8.0
# 2020/10/05 11:48:36
# episode : 84 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:37
# episode : 85 | final step : 96 | total reward : 5.0
# 2020/10/05 11:48:38
# episode : 86 | final step : 100 | total reward : 1.0
# 2020/10/05 11:48:39
# episode : 87 | final step : 100 | total reward : 1.0
# 2020/10/05 11:48:40
# episode : 88 | final step : 97 | total reward : 4.0
# 2020/10/05 11:48:41
# episode : 89 | final step : 98 | total reward : 3.0
# 2020/10/05 11:48:42
# episode : 90 | final step : 92 | total reward : 9.0
# 2020/10/05 11:48:43
# episode : 91 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:44
# episode : 92 | final step : 98 | total reward : 3.0
# 2020/10/05 11:48:45
# episode : 93 | final step : 100 | total reward : 1.0
# 2020/10/05 11:48:46
# episode : 94 | final step : 94 | total reward : 7.0
# 2020/10/05 11:48:47
# episode : 95 | final step : 97 | total reward : 4.0
# 2020/10/05 11:48:48
# episode : 96 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:49
# episode : 97 | final step : 97 | total reward : 4.0
# 2020/10/05 11:48:50
# episode : 98 | final step : 94 | total reward : 7.0
# 2020/10/05 11:48:51
# episode : 99 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:52
# episode : 100 | final step : 96 | total reward : 5.0
# 2020/10/05 11:48:54
# episode : 101 | final step : 95 | total reward : 6.0
# 2020/10/05 11:48:55
# episode : 102 | final step : 94 | total reward : 7.0
# 2020/10/05 11:48:56
# episode : 103 | final step : 96 | total reward : 5.0
# 2020/10/05 11:48:58
# episode : 104 | final step : 99 | total reward : 2.0
# 2020/10/05 11:48:59
# episode : 105 | final step : 98 | total reward : 3.0
# 2020/10/05 11:49:00
# episode : 106 | final step : 97 | total reward : 4.0
# 2020/10/05 11:49:01
# episode : 107 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:03
# episode : 108 | final step : 97 | total reward : 4.0
# 2020/10/05 11:49:04
# episode : 109 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:05
# episode : 110 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:06
# episode : 111 | final step : 92 | total reward : 9.0
# 2020/10/05 11:49:07
# episode : 112 | final step : 96 | total reward : 5.0
# 2020/10/05 11:49:07
# episode : 113 | final step : 97 | total reward : 4.0
# 2020/10/05 11:49:08
# episode : 114 | final step : 98 | total reward : 3.0
# 2020/10/05 11:49:09
# episode : 115 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:10
# episode : 116 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:12
# episode : 117 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:13
# episode : 118 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:14
# episode : 119 | final step : 97 | total reward : 4.0
# 2020/10/05 11:49:15
# episode : 120 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:16
# episode : 121 | final step : 97 | total reward : 4.0
# 2020/10/05 11:49:17
# episode : 122 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:19
# episode : 123 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:20
# episode : 124 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:21
# episode : 125 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:23
# episode : 126 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:24
# episode : 127 | final step : 97 | total reward : 4.0
# 2020/10/05 11:49:25
# episode : 128 | final step : 95 | total reward : 6.0
# 2020/10/05 11:49:26
# episode : 129 | final step : 95 | total reward : 6.0
# 2020/10/05 11:49:27
# episode : 130 | final step : 97 | total reward : 4.0
# 2020/10/05 11:49:28
# episode : 131 | final step : 96 | total reward : 5.0
# 2020/10/05 11:49:29
# episode : 132 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:30
# episode : 133 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:31
# episode : 134 | final step : 98 | total reward : 3.0
# 2020/10/05 11:49:32
# episode : 135 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:33
# episode : 136 | final step : 97 | total reward : 4.0
# 2020/10/05 11:49:34
# episode : 137 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:35
# episode : 138 | final step : 98 | total reward : 3.0
# 2020/10/05 11:49:36
# episode : 139 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:37
# episode : 140 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:38
# episode : 141 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:39
# episode : 142 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:40
# episode : 143 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:41
# episode : 144 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:42
# episode : 145 | final step : 97 | total reward : 4.0
# 2020/10/05 11:49:43
# episode : 146 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:44
# episode : 147 | final step : 97 | total reward : 4.0
# 2020/10/05 11:49:45
# episode : 148 | final step : 98 | total reward : 3.0
# 2020/10/05 11:49:46
# episode : 149 | final step : 92 | total reward : 9.0
# 2020/10/05 11:49:48
# episode : 150 | final step : 93 | total reward : 8.0
# 2020/10/05 11:49:49
# episode : 151 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:50
# episode : 152 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:50
# episode : 153 | final step : 93 | total reward : 8.0
# 2020/10/05 11:49:51
# episode : 154 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:52
# episode : 155 | final step : 98 | total reward : 3.0
# 2020/10/05 11:49:54
# episode : 156 | final step : 99 | total reward : 2.0
# 2020/10/05 11:49:55
# episode : 157 | final step : 98 | total reward : 3.0
# 2020/10/05 11:49:56
# episode : 158 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:57
# episode : 159 | final step : 100 | total reward : 1.0
# 2020/10/05 11:49:58
# episode : 160 | final step : 93 | total reward : 8.0
# 2020/10/05 11:49:59
# episode : 161 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:00
# episode : 162 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:01
# episode : 163 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:02
# episode : 164 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:03
# episode : 165 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:04
# episode : 166 | final step : 95 | total reward : 6.0
# 2020/10/05 11:50:05
# episode : 167 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:06
# episode : 168 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:07
# episode : 169 | final step : 97 | total reward : 4.0
# 2020/10/05 11:50:09
# episode : 170 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:10
# episode : 171 | final step : 97 | total reward : 4.0
# 2020/10/05 11:50:11
# episode : 172 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:12
# episode : 173 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:13
# episode : 174 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:14
# episode : 175 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:15
# episode : 176 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:16
# episode : 177 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:17
# episode : 178 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:18
# episode : 179 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:19
# episode : 180 | final step : 95 | total reward : 6.0
# 2020/10/05 11:50:20
# episode : 181 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:21
# episode : 182 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:22
# episode : 183 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:23
# episode : 184 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:24
# episode : 185 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:25
# episode : 186 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:26
# episode : 187 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:28
# episode : 188 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:29
# episode : 189 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:30
# episode : 190 | final step : 95 | total reward : 6.0
# 2020/10/05 11:50:31
# episode : 191 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:32
# episode : 192 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:33
# episode : 193 | final step : 95 | total reward : 6.0
# 2020/10/05 11:50:34
# episode : 194 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:35
# episode : 195 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:36
# episode : 196 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:38
# episode : 197 | final step : 91 | total reward : 10.0
# 2020/10/05 11:50:39
# episode : 198 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:40
# episode : 199 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:41
# episode : 200 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:42
# episode : 201 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:43
# episode : 202 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:44
# episode : 203 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:45
# episode : 204 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:46
# episode : 205 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:47
# episode : 206 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:48
# episode : 207 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:49
# episode : 208 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:50
# episode : 209 | final step : 97 | total reward : 4.0
# 2020/10/05 11:50:51
# episode : 210 | final step : 100 | total reward : 1.0
# 2020/10/05 11:50:52
# episode : 211 | final step : 94 | total reward : 7.0
# 2020/10/05 11:50:53
# episode : 212 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:54
# episode : 213 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:55
# episode : 214 | final step : 99 | total reward : 2.0
# 2020/10/05 11:50:56
# episode : 215 | final step : 96 | total reward : 5.0
# 2020/10/05 11:50:57
# episode : 216 | final step : 95 | total reward : 6.0
# 2020/10/05 11:50:58
# episode : 217 | final step : 98 | total reward : 3.0
# 2020/10/05 11:50:59
# episode : 218 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:00
# episode : 219 | final step : 99 | total reward : 2.0
# 2020/10/05 11:51:01
# episode : 220 | final step : 92 | total reward : 9.0
# 2020/10/05 11:51:02
# episode : 221 | final step : 98 | total reward : 3.0
# 2020/10/05 11:51:04
# episode : 222 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:05
# episode : 223 | final step : 91 | total reward : 10.0
# 2020/10/05 11:51:06
# episode : 224 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:07
# episode : 225 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:08
# episode : 226 | final step : 97 | total reward : 4.0
# 2020/10/05 11:51:09
# episode : 227 | final step : 97 | total reward : 4.0
# 2020/10/05 11:51:10
# episode : 228 | final step : 97 | total reward : 4.0
# 2020/10/05 11:51:11
# episode : 229 | final step : 99 | total reward : 2.0
# 2020/10/05 11:51:12
# episode : 230 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:13
# episode : 231 | final step : 97 | total reward : 4.0
# 2020/10/05 11:51:14
# episode : 232 | final step : 99 | total reward : 2.0
# 2020/10/05 11:51:15
# episode : 233 | final step : 95 | total reward : 6.0
# 2020/10/05 11:51:16
# episode : 234 | final step : 94 | total reward : 7.0
# 2020/10/05 11:51:17
# episode : 235 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:19
# episode : 236 | final step : 99 | total reward : 2.0
# 2020/10/05 11:51:20
# episode : 237 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:21
# episode : 238 | final step : 98 | total reward : 3.0
# 2020/10/05 11:51:22
# episode : 239 | final step : 95 | total reward : 6.0
# 2020/10/05 11:51:23
# episode : 240 | final step : 97 | total reward : 4.0
# 2020/10/05 11:51:24
# episode : 241 | final step : 99 | total reward : 2.0
# 2020/10/05 11:51:25
# episode : 242 | final step : 94 | total reward : 7.0
# 2020/10/05 11:51:26
# episode : 243 | final step : 99 | total reward : 2.0
# 2020/10/05 11:51:27
# episode : 244 | final step : 98 | total reward : 3.0
# 2020/10/05 11:51:28
# episode : 245 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:29
# episode : 246 | final step : 99 | total reward : 2.0
# 2020/10/05 11:51:30
# episode : 247 | final step : 96 | total reward : 5.0
# 2020/10/05 11:51:31
# episode : 248 | final step : 95 | total reward : 6.0
# 2020/10/05 11:51:32
# episode : 249 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:33
# episode : 250 | final step : 98 | total reward : 3.0
# 2020/10/05 11:51:34
# episode : 251 | final step : 99 | total reward : 2.0
# 2020/10/05 11:51:35
# episode : 252 | final step : 99 | total reward : 2.0
# 2020/10/05 11:51:36
# episode : 253 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:37
# episode : 254 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:38
# episode : 255 | final step : 97 | total reward : 4.0
# 2020/10/05 11:51:39
# episode : 256 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:40
# episode : 257 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:41
# episode : 258 | final step : 98 | total reward : 3.0
# 2020/10/05 11:51:42
# episode : 259 | final step : 97 | total reward : 4.0
# 2020/10/05 11:51:44
# episode : 260 | final step : 97 | total reward : 4.0
# 2020/10/05 11:51:45
# episode : 261 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:46
# episode : 262 | final step : 99 | total reward : 2.0
# 2020/10/05 11:51:49
# episode : 263 | final step : 100 | total reward : 1.0
# 2020/10/05 11:51:53
# episode : 264 | final step : 97 | total reward : 4.0
# 2020/10/05 11:51:58
# episode : 265 | final step : 100 | total reward : 1.0
# 2020/10/05 11:52:03
# episode : 266 | final step : 99 | total reward : 2.0
# 2020/10/05 11:52:08
# episode : 267 | final step : 99 | total reward : 2.0
# 2020/10/05 11:52:13
# episode : 268 | final step : 98 | total reward : 3.0
# 2020/10/05 11:52:18
# episode : 269 | final step : 97 | total reward : 4.0
# 2020/10/05 11:52:24
# episode : 270 | final step : 100 | total reward : 1.0
# 2020/10/05 11:52:30
# episode : 271 | final step : 96 | total reward : 5.0
# 2020/10/05 11:52:34
# episode : 272 | final step : 99 | total reward : 2.0
# 2020/10/05 11:52:39
# episode : 273 | final step : 100 | total reward : 1.0
# 2020/10/05 11:52:44
# episode : 274 | final step : 99 | total reward : 2.0
# 2020/10/05 11:52:49
# episode : 275 | final step : 94 | total reward : 7.0
# 2020/10/05 11:52:54
# episode : 276 | final step : 99 | total reward : 2.0
# 2020/10/05 11:52:59
# episode : 277 | final step : 98 | total reward : 3.0
# 2020/10/05 11:53:04
# episode : 278 | final step : 100 | total reward : 1.0
# 2020/10/05 11:53:08
# episode : 279 | final step : 93 | total reward : 8.0
# 2020/10/05 11:53:13
# episode : 280 | final step : 95 | total reward : 6.0
# 2020/10/05 11:53:18
# episode : 281 | final step : 94 | total reward : 7.0
# 2020/10/05 11:53:23
# episode : 282 | final step : 97 | total reward : 4.0
# 2020/10/05 11:53:28
# episode : 283 | final step : 97 | total reward : 4.0
# 2020/10/05 11:53:33
# episode : 284 | final step : 100 | total reward : 1.0
# 2020/10/05 11:53:39
# episode : 285 | final step : 100 | total reward : 1.0
# 2020/10/05 11:53:44
# episode : 286 | final step : 99 | total reward : 2.0
# 2020/10/05 11:53:49
# episode : 287 | final step : 94 | total reward : 7.0
# 2020/10/05 11:53:54
# episode : 288 | final step : 99 | total reward : 2.0
# 2020/10/05 11:53:59
# episode : 289 | final step : 100 | total reward : 1.0
# 2020/10/05 11:54:05
# episode : 290 | final step : 97 | total reward : 4.0
# 2020/10/05 11:54:12
# episode : 291 | final step : 100 | total reward : 1.0
# 2020/10/05 11:54:19
# episode : 292 | final step : 94 | total reward : 7.0
# 2020/10/05 11:54:26
# episode : 293 | final step : 99 | total reward : 2.0
# 2020/10/05 11:54:34
# episode : 294 | final step : 100 | total reward : 1.0
# 2020/10/05 11:54:41
# episode : 295 | final step : 99 | total reward : 2.0
# 2020/10/05 11:54:49
# episode : 296 | final step : 99 | total reward : 2.0
# 2020/10/05 11:54:56
# episode : 297 | final step : 99 | total reward : 2.0
# 2020/10/05 11:55:05
# episode : 298 | final step : 98 | total reward : 3.0
# 2020/10/05 11:55:13
# episode : 299 | final step : 99 | total reward : 2.0
# 2020/10/05 11:55:20
# episode : 300 | final step : 94 | total reward : 7.0
# 2020/10/05 11:55:28
# episode : 301 | final step : 93 | total reward : 8.0
# 2020/10/05 11:55:35
# episode : 302 | final step : 94 | total reward : 7.0
# 2020/10/05 11:55:42
# episode : 303 | final step : 94 | total reward : 7.0
# 2020/10/05 11:55:51
# episode : 304 | final step : 100 | total reward : 1.0
# 2020/10/05 11:55:59
# episode : 305 | final step : 94 | total reward : 7.0
# 2020/10/05 11:56:07
# episode : 306 | final step : 98 | total reward : 3.0
# 2020/10/05 11:56:15
# episode : 307 | final step : 100 | total reward : 1.0
# 2020/10/05 11:56:22
# episode : 308 | final step : 98 | total reward : 3.0
# 2020/10/05 11:56:30
# episode : 309 | final step : 99 | total reward : 2.0
# 2020/10/05 11:56:38
# episode : 310 | final step : 93 | total reward : 8.0
# 2020/10/05 11:56:46
# episode : 311 | final step : 97 | total reward : 4.0
# 2020/10/05 11:56:53
# episode : 312 | final step : 100 | total reward : 1.0
# 2020/10/05 11:57:01
# episode : 313 | final step : 100 | total reward : 1.0
# 2020/10/05 11:57:09
# episode : 314 | final step : 98 | total reward : 3.0
# 2020/10/05 11:57:16
# episode : 315 | final step : 99 | total reward : 2.0
# 2020/10/05 11:57:24
# episode : 316 | final step : 95 | total reward : 6.0
# 2020/10/05 11:57:31
# episode : 317 | final step : 99 | total reward : 2.0
# 2020/10/05 11:57:39
# episode : 318 | final step : 92 | total reward : 9.0
# 2020/10/05 11:57:46
# episode : 319 | final step : 92 | total reward : 9.0
# 2020/10/05 11:57:53
# episode : 320 | final step : 98 | total reward : 3.0
# 2020/10/05 11:58:00
# episode : 321 | final step : 100 | total reward : 1.0
# 2020/10/05 11:58:08
# episode : 322 | final step : 97 | total reward : 4.0
# 2020/10/05 11:58:15
# episode : 323 | final step : 99 | total reward : 2.0
# 2020/10/05 11:58:24
# episode : 324 | final step : 94 | total reward : 7.0
# 2020/10/05 11:58:32
# episode : 325 | final step : 98 | total reward : 3.0
# 2020/10/05 11:58:40
# episode : 326 | final step : 98 | total reward : 3.0
# 2020/10/05 11:58:48
# episode : 327 | final step : 99 | total reward : 2.0
# 2020/10/05 11:58:55
# episode : 328 | final step : 100 | total reward : 1.0
# 2020/10/05 11:59:03
# episode : 329 | final step : 98 | total reward : 3.0
# 2020/10/05 11:59:11
# episode : 330 | final step : 99 | total reward : 3.0
# 2020/10/05 11:59:19
# episode : 331 | final step : 95 | total reward : 6.0
# 2020/10/05 11:59:27
# episode : 332 | final step : 100 | total reward : 1.0
# 2020/10/05 11:59:35
# episode : 333 | final step : 99 | total reward : 2.0
# 2020/10/05 11:59:42
# episode : 334 | final step : 93 | total reward : 8.0
# 2020/10/05 11:59:50
# episode : 335 | final step : 99 | total reward : 2.0
# 2020/10/05 11:59:57
# episode : 336 | final step : 98 | total reward : 3.0
# 2020/10/05 12:00:06
# episode : 337 | final step : 99 | total reward : 2.0
# 2020/10/05 12:00:14
# episode : 338 | final step : 99 | total reward : 2.0
# 2020/10/05 12:00:21
# episode : 339 | final step : 99 | total reward : 2.0
# 2020/10/05 12:00:29
# episode : 340 | final step : 99 | total reward : 2.0
# 2020/10/05 12:00:37
# episode : 341 | final step : 99 | total reward : 2.0
# 2020/10/05 12:00:45
# episode : 342 | final step : 99 | total reward : 2.0
# 2020/10/05 12:00:54
# episode : 343 | final step : 100 | total reward : 1.0
# 2020/10/05 12:01:01
# episode : 344 | final step : 100 | total reward : 1.0
# 2020/10/05 12:01:09
# episode : 345 | final step : 100 | total reward : 1.0
# 2020/10/05 12:01:17
# episode : 346 | final step : 96 | total reward : 5.0
# 2020/10/05 12:01:25
# episode : 347 | final step : 100 | total reward : 1.0
# 2020/10/05 12:01:33
# episode : 348 | final step : 99 | total reward : 2.0
# 2020/10/05 12:01:42
# episode : 349 | final step : 98 | total reward : 3.0
# 2020/10/05 12:01:49
# episode : 350 | final step : 97 | total reward : 4.0
# 2020/10/05 12:01:57
# episode : 351 | final step : 98 | total reward : 3.0
# 2020/10/05 12:02:05
# episode : 352 | final step : 100 | total reward : 1.0
# 2020/10/05 12:02:12
# episode : 353 | final step : 100 | total reward : 1.0
# 2020/10/05 12:02:20
# episode : 354 | final step : 100 | total reward : 1.0
# 2020/10/05 12:02:28
# episode : 355 | final step : 97 | total reward : 4.0
# 2020/10/05 12:02:36
# episode : 356 | final step : 100 | total reward : 1.0
# 2020/10/05 12:02:44
# episode : 357 | final step : 96 | total reward : 5.0
# 2020/10/05 12:02:52
# episode : 358 | final step : 99 | total reward : 2.0
# 2020/10/05 12:03:00
# episode : 359 | final step : 98 | total reward : 3.0
# 2020/10/05 12:03:08
# episode : 360 | final step : 97 | total reward : 4.0
# 2020/10/05 12:03:15
# episode : 361 | final step : 96 | total reward : 5.0
# 2020/10/05 12:03:23
# episode : 362 | final step : 99 | total reward : 2.0
# 2020/10/05 12:03:31
# episode : 363 | final step : 99 | total reward : 2.0
# 2020/10/05 12:03:39
# episode : 364 | final step : 99 | total reward : 2.0
# 2020/10/05 12:03:47
# episode : 365 | final step : 98 | total reward : 3.0
# 2020/10/05 12:03:54
# episode : 366 | final step : 99 | total reward : 2.0
# 2020/10/05 12:04:02
# episode : 367 | final step : 100 | total reward : 1.0
# 2020/10/05 12:04:10
# episode : 368 | final step : 96 | total reward : 5.0
# 2020/10/05 12:04:18
# episode : 369 | final step : 97 | total reward : 4.0
# 2020/10/05 12:04:25
# episode : 370 | final step : 99 | total reward : 2.0
# 2020/10/05 12:04:34
# episode : 371 | final step : 100 | total reward : 1.0
# 2020/10/05 12:04:41
# episode : 372 | final step : 94 | total reward : 7.0
# 2020/10/05 12:04:48
# episode : 373 | final step : 99 | total reward : 2.0
# 2020/10/05 12:04:57
# episode : 374 | final step : 100 | total reward : 1.0
# 2020/10/05 12:05:04
# episode : 375 | final step : 95 | total reward : 6.0
# 2020/10/05 12:05:12
# episode : 376 | final step : 99 | total reward : 2.0
# 2020/10/05 12:05:20
# episode : 377 | final step : 99 | total reward : 2.0
# 2020/10/05 12:05:27
# episode : 378 | final step : 100 | total reward : 1.0
# 2020/10/05 12:05:35
# episode : 379 | final step : 91 | total reward : 10.0
# 2020/10/05 12:05:42
# episode : 380 | final step : 96 | total reward : 5.0
# 2020/10/05 12:05:50
# episode : 381 | final step : 100 | total reward : 1.0
# 2020/10/05 12:05:58
# episode : 382 | final step : 98 | total reward : 3.0
# 2020/10/05 12:06:06
# episode : 383 | final step : 95 | total reward : 6.0
# 2020/10/05 12:06:13
# episode : 384 | final step : 97 | total reward : 4.0
# 2020/10/05 12:06:21
# episode : 385 | final step : 98 | total reward : 3.0
# 2020/10/05 12:06:29
# episode : 386 | final step : 100 | total reward : 1.0
# 2020/10/05 12:06:37
# episode : 387 | final step : 95 | total reward : 6.0
# 2020/10/05 12:06:45
# episode : 388 | final step : 98 | total reward : 3.0
# 2020/10/05 12:06:52
# episode : 389 | final step : 98 | total reward : 3.0
# 2020/10/05 12:07:00
# episode : 390 | final step : 98 | total reward : 3.0
# 2020/10/05 12:07:07
# episode : 391 | final step : 98 | total reward : 3.0
# 2020/10/05 12:07:15
# episode : 392 | final step : 97 | total reward : 4.0
# 2020/10/05 12:07:24
# episode : 393 | final step : 100 | total reward : 1.0
# 2020/10/05 12:07:32
# episode : 394 | final step : 98 | total reward : 3.0
# 2020/10/05 12:07:39
# episode : 395 | final step : 98 | total reward : 3.0
# 2020/10/05 12:07:46
# episode : 396 | final step : 91 | total reward : 10.0
# 2020/10/05 12:07:54
# episode : 397 | final step : 100 | total reward : 1.0
# 2020/10/05 12:08:02
# episode : 398 | final step : 100 | total reward : 1.0
# 2020/10/05 12:08:10
# episode : 399 | final step : 96 | total reward : 5.0
# 2020/10/05 12:08:17
# episode : 400 | final step : 96 | total reward : 5.0
# 2020/10/05 12:08:25
# episode : 401 | final step : 98 | total reward : 3.0
# 2020/10/05 12:08:32
# episode : 402 | final step : 97 | total reward : 4.0
# 2020/10/05 12:08:40
# episode : 403 | final step : 99 | total reward : 2.0
# 2020/10/05 12:08:48
# episode : 404 | final step : 99 | total reward : 2.0
# 2020/10/05 12:08:56
# episode : 405 | final step : 100 | total reward : 1.0
# 2020/10/05 12:09:04
# episode : 406 | final step : 99 | total reward : 2.0
# 2020/10/05 12:09:12
# episode : 407 | final step : 97 | total reward : 4.0
# 2020/10/05 12:09:21
# episode : 408 | final step : 99 | total reward : 2.0
# 2020/10/05 12:09:29
# episode : 409 | final step : 100 | total reward : 1.0
# 2020/10/05 12:09:37
# episode : 410 | final step : 97 | total reward : 4.0
# 2020/10/05 12:09:45
# episode : 411 | final step : 96 | total reward : 5.0
# 2020/10/05 12:09:53
# episode : 412 | final step : 99 | total reward : 2.0
# 2020/10/05 12:10:01
# episode : 413 | final step : 94 | total reward : 7.0
# 2020/10/05 12:10:08
# episode : 414 | final step : 100 | total reward : 1.0
# 2020/10/05 12:10:17
# episode : 415 | final step : 100 | total reward : 1.0
# 2020/10/05 12:10:25
# episode : 416 | final step : 99 | total reward : 2.0
# 2020/10/05 12:10:33
# episode : 417 | final step : 97 | total reward : 4.0
# 2020/10/05 12:10:41
# episode : 418 | final step : 100 | total reward : 1.0
# 2020/10/05 12:10:48
# episode : 419 | final step : 99 | total reward : 2.0
# 2020/10/05 12:10:56
# episode : 420 | final step : 100 | total reward : 1.0
# 2020/10/05 12:11:04
# episode : 421 | final step : 98 | total reward : 3.0
# 2020/10/05 12:11:12
# episode : 422 | final step : 98 | total reward : 3.0
# 2020/10/05 12:11:20
# episode : 423 | final step : 100 | total reward : 1.0
# 2020/10/05 12:11:28
# episode : 424 | final step : 99 | total reward : 2.0
# 2020/10/05 12:11:36
# episode : 425 | final step : 100 | total reward : 1.0
# 2020/10/05 12:11:43
# episode : 426 | final step : 97 | total reward : 4.0
# 2020/10/05 12:11:51
# episode : 427 | final step : 95 | total reward : 6.0
# 2020/10/05 12:11:59
# episode : 428 | final step : 97 | total reward : 4.0
# 2020/10/05 12:12:07
# episode : 429 | final step : 97 | total reward : 4.0
# 2020/10/05 12:12:15
# episode : 430 | final step : 100 | total reward : 1.0
# 2020/10/05 12:12:23
# episode : 431 | final step : 97 | total reward : 4.0
# 2020/10/05 12:12:30
# episode : 432 | final step : 98 | total reward : 3.0
# 2020/10/05 12:12:38
# episode : 433 | final step : 97 | total reward : 4.0
# 2020/10/05 12:12:46
# episode : 434 | final step : 99 | total reward : 2.0
# 2020/10/05 12:12:53
# episode : 435 | final step : 99 | total reward : 2.0
# 2020/10/05 12:13:02
# episode : 436 | final step : 99 | total reward : 2.0
# 2020/10/05 12:13:09
# episode : 437 | final step : 97 | total reward : 4.0
# 2020/10/05 12:13:17
# episode : 438 | final step : 100 | total reward : 1.0
# 2020/10/05 12:13:24
# episode : 439 | final step : 100 | total reward : 1.0
# 2020/10/05 12:13:32
# episode : 440 | final step : 99 | total reward : 2.0
# 2020/10/05 12:13:40
# episode : 441 | final step : 98 | total reward : 3.0
# 2020/10/05 12:13:48
# episode : 442 | final step : 99 | total reward : 2.0
# 2020/10/05 12:13:56
# episode : 443 | final step : 100 | total reward : 1.0
# 2020/10/05 12:14:04
# episode : 444 | final step : 99 | total reward : 2.0
# 2020/10/05 12:14:12
# episode : 445 | final step : 97 | total reward : 4.0
# 2020/10/05 12:14:19
# episode : 446 | final step : 97 | total reward : 4.0
# 2020/10/05 12:14:26
# episode : 447 | final step : 96 | total reward : 5.0
# 2020/10/05 12:14:34
# episode : 448 | final step : 96 | total reward : 5.0
# 2020/10/05 12:14:41
# episode : 449 | final step : 100 | total reward : 1.0
# 2020/10/05 12:14:49
# episode : 450 | final step : 99 | total reward : 2.0
# 2020/10/05 12:14:56
# episode : 451 | final step : 97 | total reward : 4.0
# 2020/10/05 12:15:03
# episode : 452 | final step : 99 | total reward : 2.0
# 2020/10/05 12:15:11
# episode : 453 | final step : 99 | total reward : 2.0
# 2020/10/05 12:15:19
# episode : 454 | final step : 98 | total reward : 3.0
# 2020/10/05 12:15:27
# episode : 455 | final step : 100 | total reward : 1.0
# 2020/10/05 12:15:35
# episode : 456 | final step : 99 | total reward : 2.0
# 2020/10/05 12:15:43
# episode : 457 | final step : 98 | total reward : 3.0
# 2020/10/05 12:15:51
# episode : 458 | final step : 97 | total reward : 4.0
# 2020/10/05 12:15:59
# episode : 459 | final step : 94 | total reward : 7.0
# 2020/10/05 12:16:06
# episode : 460 | final step : 97 | total reward : 4.0
# 2020/10/05 12:16:14
# episode : 461 | final step : 99 | total reward : 2.0
# 2020/10/05 12:16:22
# episode : 462 | final step : 100 | total reward : 1.0
# 2020/10/05 12:16:29
# episode : 463 | final step : 99 | total reward : 2.0
# 2020/10/05 12:16:37
# episode : 464 | final step : 99 | total reward : 2.0
# 2020/10/05 12:16:45
# episode : 465 | final step : 97 | total reward : 4.0
# 2020/10/05 12:16:53
# episode : 466 | final step : 100 | total reward : 1.0
# 2020/10/05 12:17:00
# episode : 467 | final step : 97 | total reward : 4.0
# 2020/10/05 12:17:08
# episode : 468 | final step : 99 | total reward : 2.0
# 2020/10/05 12:17:16
# episode : 469 | final step : 98 | total reward : 3.0
# 2020/10/05 12:17:24
# episode : 470 | final step : 94 | total reward : 7.0
# 2020/10/05 12:17:32
# episode : 471 | final step : 99 | total reward : 2.0
# 2020/10/05 12:17:39
# episode : 472 | final step : 98 | total reward : 3.0
# 2020/10/05 12:17:47
# episode : 473 | final step : 99 | total reward : 2.0
# 2020/10/05 12:17:55
# episode : 474 | final step : 98 | total reward : 3.0
# 2020/10/05 12:18:03
# episode : 475 | final step : 100 | total reward : 1.0
# 2020/10/05 12:18:11
# episode : 476 | final step : 99 | total reward : 2.0
# 2020/10/05 12:18:19
# episode : 477 | final step : 99 | total reward : 2.0
# 2020/10/05 12:18:26
# episode : 478 | final step : 98 | total reward : 3.0
# 2020/10/05 12:18:34
# episode : 479 | final step : 100 | total reward : 1.0
# 2020/10/05 12:18:42
# episode : 480 | final step : 98 | total reward : 3.0
# 2020/10/05 12:18:49
# episode : 481 | final step : 97 | total reward : 4.0
# 2020/10/05 12:18:58
# episode : 482 | final step : 99 | total reward : 2.0
# 2020/10/05 12:19:05
# episode : 483 | final step : 93 | total reward : 8.0
# 2020/10/05 12:19:13
# episode : 484 | final step : 98 | total reward : 3.0
# 2020/10/05 12:19:21
# episode : 485 | final step : 99 | total reward : 2.0
# 2020/10/05 12:19:29
# episode : 486 | final step : 100 | total reward : 1.0
# 2020/10/05 12:19:37
# episode : 487 | final step : 98 | total reward : 3.0
# 2020/10/05 12:19:44
# episode : 488 | final step : 100 | total reward : 1.0
# 2020/10/05 12:19:53
# episode : 489 | final step : 100 | total reward : 1.0
# 2020/10/05 12:20:01
# episode : 490 | final step : 99 | total reward : 2.0
# 2020/10/05 12:20:07
# episode : 491 | final step : 93 | total reward : 8.0
# 2020/10/05 12:20:16
# episode : 492 | final step : 100 | total reward : 1.0
# 2020/10/05 12:20:24
# episode : 493 | final step : 100 | total reward : 1.0
# 2020/10/05 12:20:32
# episode : 494 | final step : 99 | total reward : 2.0
# 2020/10/05 12:20:39
# episode : 495 | final step : 97 | total reward : 4.0
# 2020/10/05 12:20:48
# episode : 496 | final step : 100 | total reward : 1.0
# 2020/10/05 12:20:55
# episode : 497 | final step : 99 | total reward : 2.0
# 2020/10/05 12:21:03
# episode : 498 | final step : 100 | total reward : 1.0
# 2020/10/05 12:21:11
# episode : 499 | final step : 100 | total reward : 1.0
# 2020/10/05 12:21:19
# episode : 500 | final step : 96 | total reward : 5.0
# 2020/10/05 12:21:27
# episode : 501 | final step : 100 | total reward : 1.0
# 2020/10/05 12:21:35
# episode : 502 | final step : 100 | total reward : 1.0
# 2020/10/05 12:21:43
# episode : 503 | final step : 99 | total reward : 2.0
# 2020/10/05 12:21:50
# episode : 504 | final step : 100 | total reward : 1.0
# 2020/10/05 12:21:58
# episode : 505 | final step : 95 | total reward : 6.0
# 2020/10/05 12:22:06
# episode : 506 | final step : 100 | total reward : 1.0
# 2020/10/05 12:22:13
# episode : 507 | final step : 100 | total reward : 1.0
# 2020/10/05 12:22:22
# episode : 508 | final step : 97 | total reward : 4.0
# 2020/10/05 12:22:30
# episode : 509 | final step : 100 | total reward : 1.0
# 2020/10/05 12:22:37
# episode : 510 | final step : 99 | total reward : 2.0
# 2020/10/05 12:22:46
# episode : 511 | final step : 100 | total reward : 1.0
# 2020/10/05 12:22:54
# episode : 512 | final step : 93 | total reward : 8.0
# 2020/10/05 12:23:01
# episode : 513 | final step : 95 | total reward : 6.0
# 2020/10/05 12:23:10
# episode : 514 | final step : 99 | total reward : 2.0
# 2020/10/05 12:23:17
# episode : 515 | final step : 96 | total reward : 5.0
# 2020/10/05 12:23:24
# episode : 516 | final step : 100 | total reward : 1.0
# 2020/10/05 12:23:32
# episode : 517 | final step : 98 | total reward : 3.0
# 2020/10/05 12:23:39
# episode : 518 | final step : 94 | total reward : 7.0
# 2020/10/05 12:23:47
# episode : 519 | final step : 97 | total reward : 4.0
# 2020/10/05 12:23:54
# episode : 520 | final step : 93 | total reward : 8.0
# 2020/10/05 12:24:01
# episode : 521 | final step : 98 | total reward : 3.0
# 2020/10/05 12:24:10
# episode : 522 | final step : 100 | total reward : 1.0
# 2020/10/05 12:24:17
# episode : 523 | final step : 98 | total reward : 3.0
# 2020/10/05 12:24:24
# episode : 524 | final step : 98 | total reward : 3.0
# 2020/10/05 12:24:33
# episode : 525 | final step : 100 | total reward : 1.0
# 2020/10/05 12:24:42
# episode : 526 | final step : 100 | total reward : 1.0
# 2020/10/05 12:24:50
# episode : 527 | final step : 96 | total reward : 5.0
# 2020/10/05 12:24:59
# episode : 528 | final step : 100 | total reward : 1.0
# 2020/10/05 12:25:07
# episode : 529 | final step : 100 | total reward : 1.0
# 2020/10/05 12:25:14
# episode : 530 | final step : 93 | total reward : 8.0
# 2020/10/05 12:25:22
# episode : 531 | final step : 99 | total reward : 2.0
# 2020/10/05 12:25:30
# episode : 532 | final step : 98 | total reward : 3.0
# 2020/10/05 12:25:38
# episode : 533 | final step : 97 | total reward : 4.0
# 2020/10/05 12:25:47
# episode : 534 | final step : 100 | total reward : 1.0
# 2020/10/05 12:25:55
# episode : 535 | final step : 99 | total reward : 2.0
# 2020/10/05 12:26:02
# episode : 536 | final step : 95 | total reward : 6.0
# 2020/10/05 12:26:09
# episode : 537 | final step : 96 | total reward : 5.0
# 2020/10/05 12:26:18
# episode : 538 | final step : 98 | total reward : 3.0
# 2020/10/05 12:26:26
# episode : 539 | final step : 100 | total reward : 1.0
# 2020/10/05 12:26:34
# episode : 540 | final step : 96 | total reward : 5.0
# 2020/10/05 12:26:41
# episode : 541 | final step : 100 | total reward : 1.0
# 2020/10/05 12:26:49
# episode : 542 | final step : 92 | total reward : 9.0
# 2020/10/05 12:26:57
# episode : 543 | final step : 99 | total reward : 2.0
# 2020/10/05 12:27:06
# episode : 544 | final step : 98 | total reward : 3.0
# 2020/10/05 12:27:13
# episode : 545 | final step : 97 | total reward : 4.0
# 2020/10/05 12:27:21
# episode : 546 | final step : 100 | total reward : 1.0
# 2020/10/05 12:27:29
# episode : 547 | final step : 99 | total reward : 2.0
# 2020/10/05 12:27:37
# episode : 548 | final step : 100 | total reward : 1.0
# 2020/10/05 12:27:44
# episode : 549 | final step : 96 | total reward : 5.0
# 2020/10/05 12:27:52
# episode : 550 | final step : 96 | total reward : 5.0
# 2020/10/05 12:28:00
# episode : 551 | final step : 98 | total reward : 3.0
# 2020/10/05 12:28:07
# episode : 552 | final step : 96 | total reward : 5.0
# 2020/10/05 12:28:15
# episode : 553 | final step : 99 | total reward : 2.0
# 2020/10/05 12:28:23
# episode : 554 | final step : 100 | total reward : 1.0
# 2020/10/05 12:28:31
# episode : 555 | final step : 98 | total reward : 3.0
# 2020/10/05 12:28:39
# episode : 556 | final step : 96 | total reward : 5.0
# 2020/10/05 12:28:46
# episode : 557 | final step : 93 | total reward : 8.0
# 2020/10/05 12:28:55
# episode : 558 | final step : 100 | total reward : 1.0
# 2020/10/05 12:29:03
# episode : 559 | final step : 100 | total reward : 1.0
# 2020/10/05 12:29:10
# episode : 560 | final step : 94 | total reward : 7.0
# 2020/10/05 12:29:18
# episode : 561 | final step : 96 | total reward : 5.0
# 2020/10/05 12:29:25
# episode : 562 | final step : 97 | total reward : 4.0
# 2020/10/05 12:29:32
# episode : 563 | final step : 99 | total reward : 2.0
# 2020/10/05 12:29:40
# episode : 564 | final step : 99 | total reward : 2.0
# 2020/10/05 12:29:48
# episode : 565 | final step : 98 | total reward : 3.0
# 2020/10/05 12:29:55
# episode : 566 | final step : 95 | total reward : 6.0
# 2020/10/05 12:30:03
# episode : 567 | final step : 99 | total reward : 2.0
# 2020/10/05 12:30:11
# episode : 568 | final step : 98 | total reward : 3.0
# 2020/10/05 12:30:19
# episode : 569 | final step : 100 | total reward : 1.0
# 2020/10/05 12:30:27
# episode : 570 | final step : 99 | total reward : 2.0
# 2020/10/05 12:30:35
# episode : 571 | final step : 99 | total reward : 2.0
# 2020/10/05 12:30:42
# episode : 572 | final step : 99 | total reward : 2.0
# 2020/10/05 12:30:51
# episode : 573 | final step : 99 | total reward : 2.0
# 2020/10/05 12:30:59
# episode : 574 | final step : 95 | total reward : 6.0
# 2020/10/05 12:31:06
# episode : 575 | final step : 100 | total reward : 1.0
# 2020/10/05 12:31:14
# episode : 576 | final step : 98 | total reward : 3.0
# 2020/10/05 12:31:22
# episode : 577 | final step : 96 | total reward : 5.0
# 2020/10/05 12:31:30
# episode : 578 | final step : 100 | total reward : 1.0
# 2020/10/05 12:31:38
# episode : 579 | final step : 100 | total reward : 1.0
# 2020/10/05 12:31:46
# episode : 580 | final step : 99 | total reward : 2.0
# 2020/10/05 12:31:54
# episode : 581 | final step : 97 | total reward : 4.0
# 2020/10/05 12:32:00
# episode : 582 | final step : 91 | total reward : 10.0
# 2020/10/05 12:32:08
# episode : 583 | final step : 100 | total reward : 1.0
# 2020/10/05 12:32:16
# episode : 584 | final step : 99 | total reward : 2.0
# 2020/10/05 12:32:24
# episode : 585 | final step : 98 | total reward : 3.0
# 2020/10/05 12:32:32
# episode : 586 | final step : 99 | total reward : 2.0
# 2020/10/05 12:32:40
# episode : 587 | final step : 99 | total reward : 2.0
# 2020/10/05 12:32:48
# episode : 588 | final step : 95 | total reward : 6.0
# 2020/10/05 12:32:55
# episode : 589 | final step : 99 | total reward : 2.0
# 2020/10/05 12:33:03
# episode : 590 | final step : 100 | total reward : 1.0
# 2020/10/05 12:33:11
# episode : 591 | final step : 100 | total reward : 1.0
# 2020/10/05 12:33:19
# episode : 592 | final step : 99 | total reward : 2.0
# 2020/10/05 12:33:27
# episode : 593 | final step : 99 | total reward : 2.0
# 2020/10/05 12:33:35
# episode : 594 | final step : 98 | total reward : 3.0
# 2020/10/05 12:33:42
# episode : 595 | final step : 100 | total reward : 1.0
# 2020/10/05 12:33:50
# episode : 596 | final step : 99 | total reward : 2.0
# 2020/10/05 12:33:59
# episode : 597 | final step : 100 | total reward : 1.0
# 2020/10/05 12:34:06
# episode : 598 | final step : 97 | total reward : 4.0
# 2020/10/05 12:34:14
# episode : 599 | final step : 97 | total reward : 4.0
# 2020/10/05 12:34:22
# episode : 600 | final step : 99 | total reward : 2.0
# 2020/10/05 12:34:30
# episode : 601 | final step : 100 | total reward : 1.0
# 2020/10/05 12:34:37
# episode : 602 | final step : 99 | total reward : 2.0
# 2020/10/05 12:34:45
# episode : 603 | final step : 99 | total reward : 2.0
# 2020/10/05 12:34:53
# episode : 604 | final step : 98 | total reward : 3.0
# 2020/10/05 12:35:01
# episode : 605 | final step : 98 | total reward : 3.0
# 2020/10/05 12:35:09
# episode : 606 | final step : 100 | total reward : 1.0
# 2020/10/05 12:35:16
# episode : 607 | final step : 100 | total reward : 1.0
# 2020/10/05 12:35:25
# episode : 608 | final step : 100 | total reward : 1.0
# 2020/10/05 12:35:32
# episode : 609 | final step : 100 | total reward : 1.0
# 2020/10/05 12:35:40
# episode : 610 | final step : 99 | total reward : 2.0
# 2020/10/05 12:35:48
# episode : 611 | final step : 100 | total reward : 1.0
# 2020/10/05 12:35:56
# episode : 612 | final step : 98 | total reward : 3.0
# 2020/10/05 12:36:03
# episode : 613 | final step : 98 | total reward : 3.0
# 2020/10/05 12:36:11
# episode : 614 | final step : 100 | total reward : 1.0
# 2020/10/05 12:36:19
# episode : 615 | final step : 100 | total reward : 1.0
# 2020/10/05 12:36:27
# episode : 616 | final step : 99 | total reward : 2.0
# 2020/10/05 12:36:35
# episode : 617 | final step : 98 | total reward : 3.0
# 2020/10/05 12:36:42
# episode : 618 | final step : 97 | total reward : 4.0
# 2020/10/05 12:36:50
# episode : 619 | final step : 99 | total reward : 2.0
# 2020/10/05 12:36:58
# episode : 620 | final step : 95 | total reward : 6.0
# 2020/10/05 12:37:06
# episode : 621 | final step : 100 | total reward : 1.0
# 2020/10/05 12:37:14
# episode : 622 | final step : 100 | total reward : 1.0
# 2020/10/05 12:37:22
# episode : 623 | final step : 100 | total reward : 1.0
# 2020/10/05 12:37:30
# episode : 624 | final step : 99 | total reward : 2.0
# 2020/10/05 12:37:37
# episode : 625 | final step : 90 | total reward : 11.0
# 2020/10/05 12:37:45
# episode : 626 | final step : 93 | total reward : 8.0
# 2020/10/05 12:37:53
# episode : 627 | final step : 96 | total reward : 5.0
# 2020/10/05 12:38:00
# episode : 628 | final step : 97 | total reward : 4.0
# 2020/10/05 12:38:08
# episode : 629 | final step : 95 | total reward : 6.0
# 2020/10/05 12:38:16
# episode : 630 | final step : 100 | total reward : 1.0
# 2020/10/05 12:38:24
# episode : 631 | final step : 100 | total reward : 1.0
# 2020/10/05 12:38:32
# episode : 632 | final step : 100 | total reward : 1.0
# 2020/10/05 12:38:40
# episode : 633 | final step : 98 | total reward : 3.0
# 2020/10/05 12:38:48
# episode : 634 | final step : 99 | total reward : 2.0
# 2020/10/05 12:38:55
# episode : 635 | final step : 98 | total reward : 3.0
# 2020/10/05 12:39:03
# episode : 636 | final step : 99 | total reward : 2.0
# 2020/10/05 12:39:10
# episode : 637 | final step : 100 | total reward : 1.0
# 2020/10/05 12:39:18
# episode : 638 | final step : 94 | total reward : 7.0
# 2020/10/05 12:39:26
# episode : 639 | final step : 99 | total reward : 2.0
# 2020/10/05 12:39:34
# episode : 640 | final step : 99 | total reward : 2.0
# 2020/10/05 12:39:42
# episode : 641 | final step : 99 | total reward : 2.0
# 2020/10/05 12:39:50
# episode : 642 | final step : 100 | total reward : 1.0
# 2020/10/05 12:39:58
# episode : 643 | final step : 100 | total reward : 1.0
# 2020/10/05 12:40:06
# episode : 644 | final step : 98 | total reward : 3.0
# 2020/10/05 12:40:14
# episode : 645 | final step : 99 | total reward : 2.0
# 2020/10/05 12:40:21
# episode : 646 | final step : 100 | total reward : 1.0
# 2020/10/05 12:40:29
# episode : 647 | final step : 98 | total reward : 3.0
# 2020/10/05 12:40:37
# episode : 648 | final step : 94 | total reward : 7.0
# 2020/10/05 12:40:44
# episode : 649 | final step : 99 | total reward : 2.0
# 2020/10/05 12:40:52
# episode : 650 | final step : 97 | total reward : 4.0
# 2020/10/05 12:41:00
# ...
# 2020/10/05 17:08:42
# episode : 2592 | final step : 98 | total reward : 3.0
# 2020/10/05 17:08:52
# episode : 2593 | final step : 100 | total reward : 1.0
# 2020/10/05 17:09:01
# episode : 2594 | final step : 96 | total reward : 5.0
# 2020/10/05 17:09:10
# episode : 2595 | final step : 99 | total reward : 2.0
# 2020/10/05 17:09:19
# episode : 2596 | final step : 100 | total reward : 1.0
# 2020/10/05 17:09:30
# episode : 2597 | final step : 99 | total reward : 2.0
# 2020/10/05 17:09:39
# episode : 2598 | final step : 100 | total reward : 1.0
# 2020/10/05 17:09:48
# episode : 2599 | final step : 97 | total reward : 4.0
# 2020/10/05 17:09:57
# episode : 2600 | final step : 99 | total reward : 2.0
# 2020/10/05 17:10:07
# episode : 2601 | final step : 100 | total reward : 1.0
# 2020/10/05 17:10:16
# episode : 2602 | final step : 98 | total reward : 3.0
# 2020/10/05 17:10:25
# episode : 2603 | final step : 98 | total reward : 3.0
# 2020/10/05 17:10:34
# episode : 2604 | final step : 100 | total reward : 1.0
# 2020/10/05 17:10:43
# episode : 2605 | final step : 98 | total reward : 3.0
# 2020/10/05 17:10:53
# episode : 2606 | final step : 100 | total reward : 1.0
# 2020/10/05 17:11:02
# episode : 2607 | final step : 99 | total reward : 2.0
# 2020/10/05 17:11:11
# episode : 2608 | final step : 99 | total reward : 2.0
# 2020/10/05 17:11:20
# episode : 2609 | final step : 100 | total reward : 1.0
# 2020/10/05 17:11:30
# episode : 2610 | final step : 100 | total reward : 1.0
# 2020/10/05 17:11:39
# episode : 2611 | final step : 99 | total reward : 2.0
# 2020/10/05 17:11:48
# episode : 2612 | final step : 96 | total reward : 5.0
# 2020/10/05 17:11:57
# episode : 2613 | final step : 97 | total reward : 4.0
# 2020/10/05 17:12:07
# episode : 2614 | final step : 98 | total reward : 3.0
# 2020/10/05 17:12:16
# episode : 2615 | final step : 99 | total reward : 2.0
# 2020/10/05 17:12:24
# episode : 2616 | final step : 98 | total reward : 3.0
# 2020/10/05 17:12:33
# episode : 2617 | final step : 93 | total reward : 8.0
# 2020/10/05 17:12:42
# episode : 2618 | final step : 99 | total reward : 2.0
# 2020/10/05 17:12:50
# episode : 2619 | final step : 97 | total reward : 4.0
# 2020/10/05 17:13:00
# episode : 2620 | final step : 97 | total reward : 4.0
# 2020/10/05 17:13:08
# episode : 2621 | final step : 99 | total reward : 2.0
# 2020/10/05 17:13:18
# episode : 2622 | final step : 95 | total reward : 6.0
# 2020/10/05 17:13:27
# episode : 2623 | final step : 99 | total reward : 2.0
# 2020/10/05 17:13:37
# episode : 2624 | final step : 99 | total reward : 2.0
# 2020/10/05 17:13:46
# episode : 2625 | final step : 99 | total reward : 2.0
# 2020/10/05 17:13:55
# episode : 2626 | final step : 97 | total reward : 4.0
# 2020/10/05 17:14:04
# episode : 2627 | final step : 98 | total reward : 3.0
# 2020/10/05 17:14:14
# episode : 2628 | final step : 100 | total reward : 1.0
# 2020/10/05 17:14:23
# episode : 2629 | final step : 95 | total reward : 6.0
# 2020/10/05 17:14:32
# episode : 2630 | final step : 99 | total reward : 2.0
# 2020/10/05 17:14:41
# episode : 2631 | final step : 99 | total reward : 2.0
# 2020/10/05 17:14:51
# episode : 2632 | final step : 97 | total reward : 4.0
# 2020/10/05 17:15:00
# episode : 2633 | final step : 98 | total reward : 3.0
# 2020/10/05 17:15:10
# episode : 2634 | final step : 100 | total reward : 1.0
# 2020/10/05 17:15:18
# episode : 2635 | final step : 95 | total reward : 6.0
# 2020/10/05 17:15:28
# episode : 2636 | final step : 100 | total reward : 1.0
# 2020/10/05 17:15:37
# episode : 2637 | final step : 99 | total reward : 2.0
# 2020/10/05 17:15:46
# episode : 2638 | final step : 97 | total reward : 4.0
# 2020/10/05 17:15:55
# episode : 2639 | final step : 96 | total reward : 5.0
# 2020/10/05 17:16:04
# episode : 2640 | final step : 97 | total reward : 4.0
# 2020/10/05 17:16:14
# episode : 2641 | final step : 100 | total reward : 1.0
# 2020/10/05 17:16:23
# episode : 2642 | final step : 100 | total reward : 1.0
# 2020/10/05 17:16:32
# episode : 2643 | final step : 99 | total reward : 2.0
# 2020/10/05 17:16:41
# episode : 2644 | final step : 99 | total reward : 2.0
# 2020/10/05 17:16:49
# episode : 2645 | final step : 99 | total reward : 2.0
# 2020/10/05 17:16:58
# episode : 2646 | final step : 99 | total reward : 2.0
# 2020/10/05 17:17:07
# episode : 2647 | final step : 96 | total reward : 5.0
# 2020/10/05 17:17:15
# episode : 2648 | final step : 98 | total reward : 3.0
# 2020/10/05 17:17:25
# episode : 2649 | final step : 99 | total reward : 2.0
# 2020/10/05 17:17:34
# episode : 2650 | final step : 99 | total reward : 2.0
# 2020/10/05 17:17:43
# episode : 2651 | final step : 96 | total reward : 5.0
# 2020/10/05 17:17:51
# episode : 2652 | final step : 92 | total reward : 9.0
# 2020/10/05 17:18:01
# episode : 2653 | final step : 99 | total reward : 2.0
# 2020/10/05 17:18:09
# episode : 2654 | final step : 95 | total reward : 6.0
# 2020/10/05 17:18:18
# episode : 2655 | final step : 98 | total reward : 3.0
# 2020/10/05 17:18:27
# episode : 2656 | final step : 100 | total reward : 1.0
# 2020/10/05 17:18:36
# episode : 2657 | final step : 91 | total reward : 10.0
# 2020/10/05 17:18:44
# episode : 2658 | final step : 96 | total reward : 5.0
# 2020/10/05 17:18:53
# episode : 2659 | final step : 100 | total reward : 1.0
# 2020/10/05 17:19:02
# episode : 2660 | final step : 96 | total reward : 5.0
# 2020/10/05 17:19:11
# episode : 2661 | final step : 94 | total reward : 7.0
# 2020/10/05 17:19:21
# episode : 2662 | final step : 98 | total reward : 3.0
# 2020/10/05 17:19:30
# episode : 2663 | final step : 100 | total reward : 1.0
# 2020/10/05 17:19:40
# episode : 2664 | final step : 94 | total reward : 7.0
# 2020/10/05 17:19:50
# episode : 2665 | final step : 99 | total reward : 2.0
# 2020/10/05 17:19:59
# episode : 2666 | final step : 98 | total reward : 3.0
# 2020/10/05 17:20:08
# episode : 2667 | final step : 99 | total reward : 2.0
# 2020/10/05 17:20:18
# episode : 2668 | final step : 99 | total reward : 2.0
# 2020/10/05 17:20:28
# episode : 2669 | final step : 99 | total reward : 2.0
# 2020/10/05 17:20:37
# episode : 2670 | final step : 99 | total reward : 2.0
# 2020/10/05 17:20:46
# episode : 2671 | final step : 92 | total reward : 9.0
# 2020/10/05 17:20:56
# episode : 2672 | final step : 99 | total reward : 2.0
# 2020/10/05 17:21:04
# episode : 2673 | final step : 94 | total reward : 7.0
# 2020/10/05 17:21:14
# episode : 2674 | final step : 100 | total reward : 1.0
# 2020/10/05 17:21:23
# episode : 2675 | final step : 96 | total reward : 5.0
# 2020/10/05 17:21:33
# episode : 2676 | final step : 99 | total reward : 2.0
# 2020/10/05 17:21:42
# episode : 2677 | final step : 99 | total reward : 2.0
# 2020/10/05 17:21:51
# episode : 2678 | final step : 94 | total reward : 7.0
# 2020/10/05 17:22:00
# episode : 2679 | final step : 99 | total reward : 2.0
# 2020/10/05 17:22:10
# episode : 2680 | final step : 98 | total reward : 3.0
# 2020/10/05 17:22:20
# episode : 2681 | final step : 97 | total reward : 4.0
# 2020/10/05 17:22:29
# episode : 2682 | final step : 100 | total reward : 1.0
# 2020/10/05 17:22:38
# episode : 2683 | final step : 100 | total reward : 1.0
# 2020/10/05 17:22:47
# episode : 2684 | final step : 94 | total reward : 7.0
# 2020/10/05 17:22:55
# episode : 2685 | final step : 95 | total reward : 6.0
# 2020/10/05 17:23:04
# episode : 2686 | final step : 96 | total reward : 5.0
# 2020/10/05 17:23:13
# episode : 2687 | final step : 99 | total reward : 2.0
# 2020/10/05 17:23:22
# episode : 2688 | final step : 99 | total reward : 2.0
# 2020/10/05 17:23:31
# episode : 2689 | final step : 99 | total reward : 2.0
# 2020/10/05 17:23:40
# episode : 2690 | final step : 99 | total reward : 2.0
# 2020/10/05 17:23:49
# episode : 2691 | final step : 99 | total reward : 2.0
# 2020/10/05 17:23:58
# episode : 2692 | final step : 96 | total reward : 5.0
# 2020/10/05 17:24:07
# episode : 2693 | final step : 96 | total reward : 5.0
# 2020/10/05 17:24:16
# episode : 2694 | final step : 97 | total reward : 4.0
# 2020/10/05 17:24:25
# episode : 2695 | final step : 94 | total reward : 7.0
# 2020/10/05 17:24:35
# episode : 2696 | final step : 100 | total reward : 1.0
# 2020/10/05 17:24:44
# episode : 2697 | final step : 98 | total reward : 3.0
# 2020/10/05 17:24:53
# episode : 2698 | final step : 97 | total reward : 4.0
# 2020/10/05 17:25:02
# episode : 2699 | final step : 97 | total reward : 4.0
# 2020/10/05 17:25:12
# episode : 2700 | final step : 100 | total reward : 1.0
# 2020/10/05 17:25:21
# episode : 2701 | final step : 99 | total reward : 2.0
# 2020/10/05 17:25:30
# episode : 2702 | final step : 96 | total reward : 5.0
# 2020/10/05 17:25:40
# episode : 2703 | final step : 100 | total reward : 1.0
# 2020/10/05 17:25:49
# episode : 2704 | final step : 98 | total reward : 3.0
# 2020/10/05 17:25:58
# episode : 2705 | final step : 100 | total reward : 1.0
# 2020/10/05 17:26:07
# episode : 2706 | final step : 99 | total reward : 2.0
# 2020/10/05 17:26:16
# episode : 2707 | final step : 100 | total reward : 1.0
# 2020/10/05 17:26:25
# episode : 2708 | final step : 97 | total reward : 4.0
# 2020/10/05 17:26:34
# episode : 2709 | final step : 96 | total reward : 5.0
# 2020/10/05 17:26:43
# episode : 2710 | final step : 94 | total reward : 7.0
# 2020/10/05 17:26:52
# episode : 2711 | final step : 93 | total reward : 8.0
# 2020/10/05 17:27:01
# episode : 2712 | final step : 95 | total reward : 6.0
# 2020/10/05 17:27:10
# episode : 2713 | final step : 99 | total reward : 2.0
# 2020/10/05 17:27:20
# episode : 2714 | final step : 99 | total reward : 2.0
# 2020/10/05 17:27:29
# episode : 2715 | final step : 99 | total reward : 2.0
# 2020/10/05 17:27:38
# episode : 2716 | final step : 99 | total reward : 2.0
# 2020/10/05 17:27:47
# episode : 2717 | final step : 99 | total reward : 2.0
# 2020/10/05 17:27:56
# episode : 2718 | final step : 99 | total reward : 2.0
# 2020/10/05 17:28:05
# episode : 2719 | final step : 99 | total reward : 2.0
# 2020/10/05 17:28:13
# episode : 2720 | final step : 98 | total reward : 3.0
# 2020/10/05 17:28:22
# episode : 2721 | final step : 96 | total reward : 5.0
# 2020/10/05 17:28:32
# episode : 2722 | final step : 97 | total reward : 4.0
# 2020/10/05 17:28:40
# episode : 2723 | final step : 96 | total reward : 5.0
# 2020/10/05 17:28:48
# episode : 2724 | final step : 98 | total reward : 3.0
# 2020/10/05 17:28:57
# episode : 2725 | final step : 97 | total reward : 4.0
# 2020/10/05 17:29:05
# episode : 2726 | final step : 99 | total reward : 2.0
# 2020/10/05 17:29:14
# episode : 2727 | final step : 99 | total reward : 2.0
# 2020/10/05 17:29:22
# episode : 2728 | final step : 99 | total reward : 2.0
# 2020/10/05 17:29:31
# episode : 2729 | final step : 97 | total reward : 4.0
# 2020/10/05 17:29:40
# episode : 2730 | final step : 99 | total reward : 2.0
# 2020/10/05 17:29:48
# episode : 2731 | final step : 98 | total reward : 3.0
# 2020/10/05 17:29:56
# episode : 2732 | final step : 97 | total reward : 4.0
# 2020/10/05 17:30:06
# episode : 2733 | final step : 100 | total reward : 1.0
# 2020/10/05 17:30:15
# episode : 2734 | final step : 100 | total reward : 1.0
# 2020/10/05 17:30:23
# episode : 2735 | final step : 100 | total reward : 1.0
# 2020/10/05 17:30:32
# episode : 2736 | final step : 98 | total reward : 3.0
# 2020/10/05 17:30:41
# episode : 2737 | final step : 98 | total reward : 3.0
# 2020/10/05 17:30:49
# episode : 2738 | final step : 100 | total reward : 1.0
# 2020/10/05 17:30:57
# episode : 2739 | final step : 96 | total reward : 5.0
# 2020/10/05 17:31:06
# episode : 2740 | final step : 98 | total reward : 3.0
# 2020/10/05 17:31:14
# episode : 2741 | final step : 99 | total reward : 2.0
# 2020/10/05 17:31:23
# episode : 2742 | final step : 94 | total reward : 7.0
# 2020/10/05 17:31:31
# episode : 2743 | final step : 99 | total reward : 2.0
# 2020/10/05 17:31:40
# episode : 2744 | final step : 99 | total reward : 2.0
# 2020/10/05 17:31:48
# episode : 2745 | final step : 99 | total reward : 2.0
# 2020/10/05 17:31:58
# episode : 2746 | final step : 97 | total reward : 4.0
# 2020/10/05 17:32:06
# episode : 2747 | final step : 97 | total reward : 4.0
# 2020/10/05 17:32:14
# episode : 2748 | final step : 99 | total reward : 2.0
# 2020/10/05 17:32:22
# episode : 2749 | final step : 100 | total reward : 1.0
# 2020/10/05 17:32:31
# episode : 2750 | final step : 99 | total reward : 2.0
# 2020/10/05 17:32:39
# episode : 2751 | final step : 99 | total reward : 2.0
# 2020/10/05 17:32:47
# episode : 2752 | final step : 99 | total reward : 2.0
# 2020/10/05 17:32:56
# episode : 2753 | final step : 96 | total reward : 5.0
# 2020/10/05 17:33:04
# episode : 2754 | final step : 91 | total reward : 10.0
# 2020/10/05 17:33:12
# episode : 2755 | final step : 98 | total reward : 3.0
# 2020/10/05 17:33:21
# episode : 2756 | final step : 97 | total reward : 4.0
# 2020/10/05 17:33:30
# episode : 2757 | final step : 96 | total reward : 5.0
# 2020/10/05 17:33:39
# episode : 2758 | final step : 98 | total reward : 3.0
# 2020/10/05 17:33:47
# episode : 2759 | final step : 99 | total reward : 2.0
# 2020/10/05 17:33:55
# episode : 2760 | final step : 93 | total reward : 8.0
# 2020/10/05 17:34:03
# episode : 2761 | final step : 100 | total reward : 1.0
# 2020/10/05 17:34:11
# episode : 2762 | final step : 97 | total reward : 4.0
# 2020/10/05 17:34:19
# episode : 2763 | final step : 99 | total reward : 2.0
# 2020/10/05 17:34:28
# episode : 2764 | final step : 98 | total reward : 3.0
# 2020/10/05 17:34:37
# episode : 2765 | final step : 99 | total reward : 2.0
# 2020/10/05 17:34:45
# episode : 2766 | final step : 99 | total reward : 2.0
# 2020/10/05 17:34:53
# episode : 2767 | final step : 100 | total reward : 1.0
# 2020/10/05 17:35:01
# episode : 2768 | final step : 98 | total reward : 3.0
# 2020/10/05 17:35:10
# episode : 2769 | final step : 100 | total reward : 1.0
# 2020/10/05 17:35:19
# episode : 2770 | final step : 100 | total reward : 1.0
# 2020/10/05 17:35:27
# episode : 2771 | final step : 100 | total reward : 1.0
# 2020/10/05 17:35:36
# episode : 2772 | final step : 99 | total reward : 2.0
# 2020/10/05 17:35:46
# episode : 2773 | final step : 100 | total reward : 1.0
# 2020/10/05 17:35:56
# episode : 2774 | final step : 94 | total reward : 7.0
# 2020/10/05 17:36:06
# episode : 2775 | final step : 98 | total reward : 3.0
# 2020/10/05 17:36:15
# episode : 2776 | final step : 99 | total reward : 2.0
# 2020/10/05 17:36:24
# episode : 2777 | final step : 100 | total reward : 1.0
# 2020/10/05 17:36:32
# episode : 2778 | final step : 90 | total reward : 11.0
# 2020/10/05 17:36:41
# episode : 2779 | final step : 97 | total reward : 4.0
# 2020/10/05 17:36:50
# episode : 2780 | final step : 100 | total reward : 1.0
# 2020/10/05 17:36:59
# episode : 2781 | final step : 100 | total reward : 1.0
# 2020/10/05 17:37:08
# episode : 2782 | final step : 97 | total reward : 4.0
# 2020/10/05 17:37:16
# episode : 2783 | final step : 100 | total reward : 1.0
# 2020/10/05 17:37:24
# episode : 2784 | final step : 99 | total reward : 2.0
# 2020/10/05 17:37:33
# episode : 2785 | final step : 99 | total reward : 2.0
# 2020/10/05 17:37:42
# episode : 2786 | final step : 100 | total reward : 1.0
# 2020/10/05 17:37:51
# episode : 2787 | final step : 96 | total reward : 5.0
# 2020/10/05 17:37:59
# episode : 2788 | final step : 91 | total reward : 10.0
# 2020/10/05 17:38:07
# episode : 2789 | final step : 99 | total reward : 2.0
# 2020/10/05 17:38:15
# episode : 2790 | final step : 100 | total reward : 1.0
# 2020/10/05 17:38:24
# episode : 2791 | final step : 99 | total reward : 2.0
# 2020/10/05 17:38:33
# episode : 2792 | final step : 96 | total reward : 5.0
# 2020/10/05 17:38:41
# episode : 2793 | final step : 99 | total reward : 2.0
# 2020/10/05 17:38:50
# episode : 2794 | final step : 100 | total reward : 1.0
# 2020/10/05 17:38:59
# episode : 2795 | final step : 100 | total reward : 1.0
# 2020/10/05 17:39:09
# episode : 2796 | final step : 100 | total reward : 1.0
# 2020/10/05 17:39:17
# episode : 2797 | final step : 97 | total reward : 4.0
# 2020/10/05 17:39:26
# episode : 2798 | final step : 96 | total reward : 5.0
# 2020/10/05 17:39:35
# episode : 2799 | final step : 100 | total reward : 1.0
# 2020/10/05 17:39:43
# episode : 2800 | final step : 99 | total reward : 2.0
# 2020/10/05 17:39:52
# episode : 2801 | final step : 99 | total reward : 2.0
# 2020/10/05 17:40:00
# episode : 2802 | final step : 94 | total reward : 7.0
# 2020/10/05 17:40:09
# episode : 2803 | final step : 99 | total reward : 2.0
# 2020/10/05 17:40:17
# episode : 2804 | final step : 100 | total reward : 1.0
# 2020/10/05 17:40:26
# episode : 2805 | final step : 100 | total reward : 1.0
# 2020/10/05 17:40:34
# episode : 2806 | final step : 98 | total reward : 3.0

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(reward_list)

# %%
def moving_average(data,n):
    len_data=len(data)-n
    res_data=np.zeros(len_data)

    for i in range(len_data):
        res_data[i]=sum(data[i:i+n])/n
    return res_data

# %%
average_number=100
filtered_data=moving_average(reward_list,average_number)
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(filtered_data)

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[99]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[9996]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[49999]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()
