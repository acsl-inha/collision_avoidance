# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
import time
import itertools
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
import gym_Aircraft

# %%
env = gym.make("acav-v0")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# /home/jupyter-kunwoopark/.local/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """transition 저장"""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
class DQN(nn.Module):
    def __init__(self, num_inputs, num_actions):
        super(DQN, self).__init__()
        
        self.layers = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 40),
            nn.ReLU(),
            nn.Linear(40, 40),
            nn.ReLU(),
            nn.Linear(40, 40),
            nn.ReLU(),
            nn.Linear(40, 40),
            nn.ReLU(),
            nn.Linear(40, 40),
            nn.ReLU(),
            nn.Linear(40, 40),
            nn.ReLU(),
            nn.Linear(40, 40),
            nn.ReLU(),
            nn.Linear(40, env.action_space.n)
        )
        
    def forward(self, x):
        return self.layers(x)

# %%
BATCH_SIZE = 128
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10

# %%
policy_net = nn.DataParallel(DQN(env.observation_space.shape[0], env.action_space.n).to(device))
target_net = nn.DataParallel(DQN(env.observation_space.shape[0], env.action_space.n).to(device))
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
# Out:
# DataParallel(
#   (module): DQN(
#     (layers): Sequential(
#       (0): Linear(in_features=5, out_features=40, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=40, out_features=40, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=40, out_features=40, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=40, out_features=40, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=40, out_features=40, bias=True)
#       (9): ReLU()
#       (10): Linear(in_features=40, out_features=40, bias=True)
#       (11): ReLU()
#       (12): Linear(in_features=40, out_features=40, bias=True)
#       (13): ReLU()
#       (14): Linear(in_features=40, out_features=3, bias=True)
#     )
#   )
# )

# %%
n_actions = env.action_space.n

# %%
optimizer = optim.Adam(policy_net.parameters())
memory = ReplayMemory(10000)

# %%
steps_done = 0

# %%
def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max (1)은 각 행의 가장 큰 열 값을 반환합니다.
            # 최대 결과의 두번째 열은 최대 요소의 주소값이므로,
            # 기대 보상이 더 큰 행동을 선택할 수 있습니다.
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(n_actions)]], device=device, dtype=torch.long)

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)

    batch = Transition(*zip(*transitions))

    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    state_action_values = policy_net(state_batch).gather(1, action_batch)

    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    # 기대 Q 값 계산
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Huber 손실 계산
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    # 모델 최적화
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
num_episodes = 10000
total_res=[]
reward_list=[]
for i_episode in range(num_episodes):
    total_reward=0
    
    # 환경과 상태 초기화
    res_list=np.zeros(11)
    state = env.reset()
    state=torch.from_numpy(state.astype(np.float32)).unsqueeze(0).to(device)
    for t in count():
        # 행동 선택과 수행
        
        action = select_action(state)
        next_state, reward, done, res = env.step(action.item())
        reward = torch.tensor([reward], dtype=torch.float32).to(device)
        
        next_state=torch.from_numpy(next_state.astype(np.float32)).unsqueeze(0).to(device)

        # 새로운 상태 관찰
        if not done:
            next_state = next_state
        else:
            next_state = None

        # 메모리에 변이 저장
        memory.push(state, action, next_state, reward)

        # 다음 상태로 이동
        state = next_state

        # 최적화 한단계 수행(목표 네트워크에서)
        optimize_model()
        
        # Data save
        
        cmd_list,r_list,elev_list,azim_list,Pm_list,Pt_list,h_list=res
        Pm_list=Pm_list.tolist()
        Pt_list=Pt_list.tolist()
        merged_data=itertools.chain([cmd_list],[r_list],[elev_list],[azim_list],Pm_list,Pt_list,[h_list])
        merged_data=np.array(list(merged_data))
        res_list=np.vstack([res_list,merged_data])
        
        total_reward+=reward
        
        if done:
            res_list=np.delete(res_list,0,0)
            
            total_res.append(res_list)
            reward_list.append(total_reward)
            
            now = time.localtime()
            print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))
            print("episode : {} | final step : {} | total reward : {}".format(i_episode, t, total_reward.item()))
            break
            
        
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

print('Complete')
env.close()
# Out:
# 2020/10/02 01:11:03
# episode : 0 | final step : 98 | total reward : -2.0
# 2020/10/02 01:11:15
# episode : 1 | final step : 98 | total reward : -2.0
# 2020/10/02 01:11:19
# episode : 2 | final step : 98 | total reward : -2.0
# 2020/10/02 01:11:26
# episode : 3 | final step : 201 | total reward : 202.0
# 2020/10/02 01:11:29
# episode : 4 | final step : 98 | total reward : -2.0
# 2020/10/02 01:11:36
# episode : 5 | final step : 201 | total reward : 202.0
# 2020/10/02 01:11:40
# episode : 6 | final step : 98 | total reward : -2.0
# 2020/10/02 01:11:43
# episode : 7 | final step : 100 | total reward : 0.0
# 2020/10/02 01:11:47
# episode : 8 | final step : 97 | total reward : -3.0
# 2020/10/02 01:11:50
# episode : 9 | final step : 98 | total reward : -2.0
# 2020/10/02 01:11:53
# episode : 10 | final step : 98 | total reward : -2.0
# 2020/10/02 01:12:00
# episode : 11 | final step : 201 | total reward : 202.0
# 2020/10/02 01:12:08
# episode : 12 | final step : 201 | total reward : 202.0
# 2020/10/02 01:12:11
# episode : 13 | final step : 98 | total reward : -2.0
# 2020/10/02 01:12:18
# episode : 14 | final step : 201 | total reward : 202.0
# 2020/10/02 01:12:22
# episode : 15 | final step : 98 | total reward : -2.0
# 2020/10/02 01:12:25
# episode : 16 | final step : 100 | total reward : 0.0
# 2020/10/02 01:12:29
# episode : 17 | final step : 98 | total reward : -2.0
# 2020/10/02 01:12:36
# episode : 18 | final step : 201 | total reward : 202.0
# 2020/10/02 01:12:39
# episode : 19 | final step : 98 | total reward : -2.0
# 2020/10/02 01:12:46
# episode : 20 | final step : 201 | total reward : 202.0
# 2020/10/02 01:12:49
# episode : 21 | final step : 99 | total reward : -1.0
# 2020/10/02 01:12:53
# episode : 22 | final step : 99 | total reward : -1.0
# 2020/10/02 01:12:56
# episode : 23 | final step : 99 | total reward : -1.0
# 2020/10/02 01:13:03
# episode : 24 | final step : 201 | total reward : 202.0
# 2020/10/02 01:13:11
# episode : 25 | final step : 201 | total reward : 202.0
# 2020/10/02 01:13:14
# episode : 26 | final step : 98 | total reward : -2.0
# 2020/10/02 01:13:18
# episode : 27 | final step : 99 | total reward : -1.0
# 2020/10/02 01:13:21
# episode : 28 | final step : 98 | total reward : -2.0
# 2020/10/02 01:13:25
# episode : 29 | final step : 98 | total reward : -2.0
# 2020/10/02 01:13:28
# episode : 30 | final step : 98 | total reward : -2.0
# 2020/10/02 01:13:31
# episode : 31 | final step : 99 | total reward : -1.0
# 2020/10/02 01:13:39
# episode : 32 | final step : 201 | total reward : 202.0
# 2020/10/02 01:13:42
# episode : 33 | final step : 98 | total reward : -2.0
# 2020/10/02 01:13:46
# episode : 34 | final step : 99 | total reward : -1.0
# 2020/10/02 01:13:49
# episode : 35 | final step : 98 | total reward : -2.0
# 2020/10/02 01:13:53
# episode : 36 | final step : 100 | total reward : 0.0
# 2020/10/02 01:13:56
# episode : 37 | final step : 98 | total reward : -2.0
# 2020/10/02 01:14:00
# episode : 38 | final step : 100 | total reward : 0.0
# 2020/10/02 01:14:07
# episode : 39 | final step : 201 | total reward : 202.0
# 2020/10/02 01:14:11
# episode : 40 | final step : 100 | total reward : 0.0
# 2020/10/02 01:14:14
# episode : 41 | final step : 98 | total reward : -2.0
# 2020/10/02 01:14:18
# episode : 42 | final step : 98 | total reward : -2.0
# 2020/10/02 01:14:25
# episode : 43 | final step : 201 | total reward : 202.0
# 2020/10/02 01:14:32
# episode : 44 | final step : 201 | total reward : 202.0
# 2020/10/02 01:14:35
# episode : 45 | final step : 98 | total reward : -2.0
# 2020/10/02 01:14:39
# episode : 46 | final step : 98 | total reward : -2.0
# 2020/10/02 01:14:46
# episode : 47 | final step : 201 | total reward : 202.0
# 2020/10/02 01:14:49
# episode : 48 | final step : 99 | total reward : -1.0
# 2020/10/02 01:14:53
# episode : 49 | final step : 99 | total reward : -1.0
# 2020/10/02 01:15:00
# episode : 50 | final step : 201 | total reward : 202.0
# 2020/10/02 01:15:08
# episode : 51 | final step : 201 | total reward : 202.0
# 2020/10/02 01:15:11
# episode : 52 | final step : 98 | total reward : -2.0
# 2020/10/02 01:15:18
# episode : 53 | final step : 201 | total reward : 202.0
# 2020/10/02 01:15:22
# episode : 54 | final step : 98 | total reward : -2.0
# 2020/10/02 01:15:25
# episode : 55 | final step : 98 | total reward : -2.0
# 2020/10/02 01:15:29
# episode : 56 | final step : 98 | total reward : -2.0
# 2020/10/02 01:15:32
# episode : 57 | final step : 98 | total reward : -2.0
# 2020/10/02 01:15:36
# episode : 58 | final step : 98 | total reward : -2.0
# 2020/10/02 01:15:39
# episode : 59 | final step : 98 | total reward : -2.0
# 2020/10/02 01:15:46
# episode : 60 | final step : 201 | total reward : 202.0
# 2020/10/02 01:15:49
# episode : 61 | final step : 99 | total reward : -1.0
# 2020/10/02 01:15:53
# episode : 62 | final step : 98 | total reward : -2.0
# 2020/10/02 01:15:56
# episode : 63 | final step : 98 | total reward : -2.0
# 2020/10/02 01:16:00
# episode : 64 | final step : 98 | total reward : -2.0
# 2020/10/02 01:16:03
# episode : 65 | final step : 98 | total reward : -2.0
# 2020/10/02 01:16:10
# episode : 66 | final step : 201 | total reward : 202.0
# 2020/10/02 01:16:13
# episode : 67 | final step : 99 | total reward : -1.0
# 2020/10/02 01:16:17
# episode : 68 | final step : 98 | total reward : -2.0
# 2020/10/02 01:16:24
# episode : 69 | final step : 201 | total reward : 202.0
# 2020/10/02 01:16:31
# episode : 70 | final step : 201 | total reward : 202.0
# 2020/10/02 01:16:38
# episode : 71 | final step : 201 | total reward : 202.0
# 2020/10/02 01:16:45
# episode : 72 | final step : 201 | total reward : 202.0
# 2020/10/02 01:16:48
# episode : 73 | final step : 98 | total reward : -2.0
# 2020/10/02 01:16:55
# episode : 74 | final step : 201 | total reward : 202.0
# 2020/10/02 01:16:59
# episode : 75 | final step : 99 | total reward : -1.0
# 2020/10/02 01:17:02
# episode : 76 | final step : 98 | total reward : -2.0
# 2020/10/02 01:17:09
# episode : 77 | final step : 201 | total reward : 202.0
# 2020/10/02 01:17:16
# episode : 78 | final step : 201 | total reward : 202.0
# 2020/10/02 01:17:20
# episode : 79 | final step : 98 | total reward : -2.0
# 2020/10/02 01:17:23
# episode : 80 | final step : 98 | total reward : -2.0
# 2020/10/02 01:17:27
# episode : 81 | final step : 98 | total reward : -2.0
# 2020/10/02 01:17:34
# episode : 82 | final step : 201 | total reward : 202.0
# 2020/10/02 01:17:41
# episode : 83 | final step : 201 | total reward : 202.0
# 2020/10/02 01:17:48
# episode : 84 | final step : 201 | total reward : 202.0
# 2020/10/02 01:17:51
# episode : 85 | final step : 99 | total reward : -1.0
# 2020/10/02 01:17:55
# episode : 86 | final step : 98 | total reward : -2.0
# 2020/10/02 01:17:58
# episode : 87 | final step : 98 | total reward : -2.0
# 2020/10/02 01:18:01
# episode : 88 | final step : 98 | total reward : -2.0
# 2020/10/02 01:18:05
# episode : 89 | final step : 98 | total reward : -2.0
# 2020/10/02 01:18:12
# episode : 90 | final step : 201 | total reward : 202.0
# 2020/10/02 01:18:19
# episode : 91 | final step : 201 | total reward : 202.0
# 2020/10/02 01:18:23
# episode : 92 | final step : 98 | total reward : -2.0
# 2020/10/02 01:18:30
# episode : 93 | final step : 201 | total reward : 202.0
# 2020/10/02 01:18:33
# episode : 94 | final step : 100 | total reward : 0.0
# 2020/10/02 01:18:41
# episode : 95 | final step : 201 | total reward : 202.0
# 2020/10/02 01:18:44
# episode : 96 | final step : 98 | total reward : -2.0
# 2020/10/02 01:18:48
# episode : 97 | final step : 98 | total reward : -2.0
# 2020/10/02 01:18:51
# episode : 98 | final step : 98 | total reward : -2.0
# 2020/10/02 01:18:58
# episode : 99 | final step : 201 | total reward : 202.0
# 2020/10/02 01:19:02
# episode : 100 | final step : 99 | total reward : -1.0
# 2020/10/02 01:19:05
# episode : 101 | final step : 99 | total reward : -1.0
# 2020/10/02 01:19:08
# episode : 102 | final step : 100 | total reward : 0.0
# 2020/10/02 01:19:12
# episode : 103 | final step : 98 | total reward : -2.0
# 2020/10/02 01:19:15
# episode : 104 | final step : 98 | total reward : -2.0
# 2020/10/02 01:19:19
# episode : 105 | final step : 98 | total reward : -2.0
# 2020/10/02 01:19:26
# episode : 106 | final step : 201 | total reward : 202.0
# 2020/10/02 01:19:33
# episode : 107 | final step : 201 | total reward : 202.0
# 2020/10/02 01:19:37
# episode : 108 | final step : 98 | total reward : -2.0
# 2020/10/02 01:19:40
# episode : 109 | final step : 98 | total reward : -2.0
# 2020/10/02 01:19:44
# episode : 110 | final step : 98 | total reward : -2.0
# 2020/10/02 01:19:47
# episode : 111 | final step : 98 | total reward : -2.0
# 2020/10/02 01:19:51
# episode : 112 | final step : 99 | total reward : -1.0
# 2020/10/02 01:19:54
# episode : 113 | final step : 100 | total reward : 0.0
# 2020/10/02 01:19:58
# episode : 114 | final step : 98 | total reward : -2.0
# 2020/10/02 01:20:01
# episode : 115 | final step : 98 | total reward : -2.0
# 2020/10/02 01:20:08
# episode : 116 | final step : 201 | total reward : 202.0
# 2020/10/02 01:20:11
# episode : 117 | final step : 98 | total reward : -2.0
# 2020/10/02 01:20:15
# episode : 118 | final step : 99 | total reward : -1.0
# 2020/10/02 01:20:18
# episode : 119 | final step : 98 | total reward : -2.0
# 2020/10/02 01:20:22
# episode : 120 | final step : 98 | total reward : -2.0
# 2020/10/02 01:20:25
# episode : 121 | final step : 98 | total reward : -2.0
# 2020/10/02 01:20:29
# episode : 122 | final step : 98 | total reward : -2.0
# 2020/10/02 01:20:32
# episode : 123 | final step : 98 | total reward : -2.0
# 2020/10/02 01:20:39
# episode : 124 | final step : 201 | total reward : 202.0
# 2020/10/02 01:20:43
# episode : 125 | final step : 98 | total reward : -2.0
# 2020/10/02 01:20:50
# episode : 126 | final step : 201 | total reward : 202.0
# 2020/10/02 01:20:57
# episode : 127 | final step : 201 | total reward : 202.0
# 2020/10/02 01:21:00
# episode : 128 | final step : 98 | total reward : -2.0
# 2020/10/02 01:21:04
# episode : 129 | final step : 98 | total reward : -2.0
# 2020/10/02 01:21:07
# episode : 130 | final step : 98 | total reward : -2.0
# 2020/10/02 01:21:10
# episode : 131 | final step : 98 | total reward : -2.0
# 2020/10/02 01:21:18
# episode : 132 | final step : 201 | total reward : 202.0
# 2020/10/02 01:21:21
# episode : 133 | final step : 99 | total reward : -1.0
# 2020/10/02 01:21:24
# episode : 134 | final step : 99 | total reward : -1.0
# 2020/10/02 01:21:28
# episode : 135 | final step : 98 | total reward : -2.0
# 2020/10/02 01:21:31
# episode : 136 | final step : 98 | total reward : -2.0
# 2020/10/02 01:21:38
# episode : 137 | final step : 201 | total reward : 202.0
# 2020/10/02 01:21:42
# episode : 138 | final step : 98 | total reward : -2.0
# 2020/10/02 01:21:45
# episode : 139 | final step : 98 | total reward : -2.0
# 2020/10/02 01:21:49
# episode : 140 | final step : 98 | total reward : -2.0
# 2020/10/02 01:21:56
# episode : 141 | final step : 201 | total reward : 202.0
# 2020/10/02 01:21:59
# episode : 142 | final step : 98 | total reward : -2.0
# 2020/10/02 01:22:03
# episode : 143 | final step : 98 | total reward : -2.0
# 2020/10/02 01:22:06
# episode : 144 | final step : 98 | total reward : -2.0
# 2020/10/02 01:22:10
# episode : 145 | final step : 98 | total reward : -2.0
# 2020/10/02 01:22:17
# episode : 146 | final step : 201 | total reward : 202.0
# 2020/10/02 01:22:20
# episode : 147 | final step : 98 | total reward : -2.0
# 2020/10/02 01:22:24
# episode : 148 | final step : 99 | total reward : -1.0
# 2020/10/02 01:22:27
# episode : 149 | final step : 99 | total reward : -1.0
# 2020/10/02 01:22:31
# episode : 150 | final step : 99 | total reward : -1.0
# 2020/10/02 01:22:38
# episode : 151 | final step : 201 | total reward : 202.0
# 2020/10/02 01:22:41
# episode : 152 | final step : 98 | total reward : -2.0
# 2020/10/02 01:22:45
# episode : 153 | final step : 99 | total reward : -1.0
# 2020/10/02 01:22:48
# episode : 154 | final step : 98 | total reward : -2.0
# 2020/10/02 01:22:55
# episode : 155 | final step : 201 | total reward : 202.0
# 2020/10/02 01:22:59
# episode : 156 | final step : 98 | total reward : -2.0
# 2020/10/02 01:23:02
# episode : 157 | final step : 98 | total reward : -2.0
# 2020/10/02 01:23:09
# episode : 158 | final step : 201 | total reward : 202.0
# 2020/10/02 01:23:13
# episode : 159 | final step : 98 | total reward : -2.0
# 2020/10/02 01:23:16
# episode : 160 | final step : 98 | total reward : -2.0
# 2020/10/02 01:23:20
# episode : 161 | final step : 98 | total reward : -2.0
# 2020/10/02 01:23:23
# episode : 162 | final step : 99 | total reward : -1.0
# 2020/10/02 01:23:26
# episode : 163 | final step : 98 | total reward : -2.0
# 2020/10/02 01:23:30
# episode : 164 | final step : 98 | total reward : -2.0
# 2020/10/02 01:23:33
# episode : 165 | final step : 98 | total reward : -2.0
# 2020/10/02 01:23:37
# episode : 166 | final step : 98 | total reward : -2.0
# 2020/10/02 01:23:44
# episode : 167 | final step : 201 | total reward : 202.0
# 2020/10/02 01:23:47
# episode : 168 | final step : 99 | total reward : -1.0
# 2020/10/02 01:23:54
# episode : 169 | final step : 201 | total reward : 202.0
# 2020/10/02 01:23:58
# episode : 170 | final step : 100 | total reward : 0.0
# 2020/10/02 01:24:05
# episode : 171 | final step : 201 | total reward : 202.0
# 2020/10/02 01:24:08
# episode : 172 | final step : 98 | total reward : -2.0
# 2020/10/02 01:24:12
# episode : 173 | final step : 98 | total reward : -2.0
# 2020/10/02 01:24:15
# episode : 174 | final step : 97 | total reward : -3.0
# 2020/10/02 01:24:19
# episode : 175 | final step : 98 | total reward : -2.0
# 2020/10/02 01:24:22
# episode : 176 | final step : 98 | total reward : -2.0
# 2020/10/02 01:24:29
# episode : 177 | final step : 201 | total reward : 202.0
# 2020/10/02 01:24:32
# episode : 178 | final step : 99 | total reward : -1.0
# 2020/10/02 01:24:36
# episode : 179 | final step : 98 | total reward : -2.0
# 2020/10/02 01:24:39
# episode : 180 | final step : 100 | total reward : 0.0
# 2020/10/02 01:24:43
# episode : 181 | final step : 98 | total reward : -2.0
# 2020/10/02 01:24:46
# episode : 182 | final step : 98 | total reward : -2.0
# 2020/10/02 01:24:49
# episode : 183 | final step : 98 | total reward : -2.0
# 2020/10/02 01:24:57
# episode : 184 | final step : 201 | total reward : 202.0
# 2020/10/02 01:25:00
# episode : 185 | final step : 99 | total reward : -1.0
# 2020/10/02 01:25:03
# episode : 186 | final step : 99 | total reward : -1.0
# 2020/10/02 01:25:10
# episode : 187 | final step : 201 | total reward : 202.0
# 2020/10/02 01:25:14
# episode : 188 | final step : 98 | total reward : -2.0
# 2020/10/02 01:25:17
# episode : 189 | final step : 98 | total reward : -2.0
# 2020/10/02 01:25:21
# episode : 190 | final step : 99 | total reward : -1.0
# 2020/10/02 01:25:28
# episode : 191 | final step : 201 | total reward : 202.0
# 2020/10/02 01:25:31
# episode : 192 | final step : 99 | total reward : -1.0
# 2020/10/02 01:25:39
# episode : 193 | final step : 201 | total reward : 202.0
# 2020/10/02 01:25:46
# episode : 194 | final step : 201 | total reward : 202.0
# 2020/10/02 01:25:49
# episode : 195 | final step : 98 | total reward : -2.0
# 2020/10/02 01:25:53
# episode : 196 | final step : 99 | total reward : -1.0
# 2020/10/02 01:25:57
# episode : 197 | final step : 98 | total reward : -2.0
# 2020/10/02 01:26:00
# episode : 198 | final step : 100 | total reward : 0.0
# 2020/10/02 01:26:07
# episode : 199 | final step : 201 | total reward : 202.0
# 2020/10/02 01:26:10
# episode : 200 | final step : 99 | total reward : -1.0
# 2020/10/02 01:26:14
# episode : 201 | final step : 98 | total reward : -2.0
# 2020/10/02 01:26:17
# episode : 202 | final step : 98 | total reward : -2.0
# 2020/10/02 01:26:21
# episode : 203 | final step : 99 | total reward : -1.0
# 2020/10/02 01:26:24
# episode : 204 | final step : 99 | total reward : -1.0
# 2020/10/02 01:26:31
# episode : 205 | final step : 201 | total reward : 202.0
# 2020/10/02 01:26:38
# episode : 206 | final step : 201 | total reward : 202.0
# 2020/10/02 01:26:42
# episode : 207 | final step : 98 | total reward : -2.0
# 2020/10/02 01:26:45
# episode : 208 | final step : 99 | total reward : -1.0
# 2020/10/02 01:26:49
# episode : 209 | final step : 100 | total reward : 0.0
# 2020/10/02 01:26:52
# episode : 210 | final step : 98 | total reward : -2.0
# 2020/10/02 01:26:59
# episode : 211 | final step : 201 | total reward : 202.0
# 2020/10/02 01:27:03
# episode : 212 | final step : 98 | total reward : -2.0
# 2020/10/02 01:27:09
# episode : 213 | final step : 201 | total reward : 202.0
# 2020/10/02 01:27:13
# episode : 214 | final step : 99 | total reward : -1.0
# 2020/10/02 01:27:20
# episode : 215 | final step : 201 | total reward : 202.0
# 2020/10/02 01:27:27
# episode : 216 | final step : 201 | total reward : 202.0
# 2020/10/02 01:27:31
# episode : 217 | final step : 98 | total reward : -2.0
# 2020/10/02 01:27:38
# episode : 218 | final step : 201 | total reward : 202.0
# 2020/10/02 01:27:41
# episode : 219 | final step : 98 | total reward : -2.0
# 2020/10/02 01:27:45
# episode : 220 | final step : 99 | total reward : -1.0
# 2020/10/02 01:27:48
# episode : 221 | final step : 99 | total reward : -1.0
# 2020/10/02 01:27:52
# episode : 222 | final step : 98 | total reward : -2.0
# 2020/10/02 01:27:55
# episode : 223 | final step : 99 | total reward : -1.0
# 2020/10/02 01:27:58
# episode : 224 | final step : 98 | total reward : -2.0
# 2020/10/02 01:28:02
# episode : 225 | final step : 101 | total reward : 1.0
# 2020/10/02 01:28:06
# episode : 226 | final step : 98 | total reward : -2.0
# 2020/10/02 01:28:09
# episode : 227 | final step : 99 | total reward : -1.0
# 2020/10/02 01:28:13
# episode : 228 | final step : 98 | total reward : -2.0
# 2020/10/02 01:28:20
# episode : 229 | final step : 201 | total reward : 202.0
# 2020/10/02 01:28:27
# episode : 230 | final step : 201 | total reward : 202.0
# 2020/10/02 01:28:30
# episode : 231 | final step : 98 | total reward : -2.0
# 2020/10/02 01:28:37
# episode : 232 | final step : 201 | total reward : 202.0
# 2020/10/02 01:28:41
# episode : 233 | final step : 98 | total reward : -2.0
# 2020/10/02 01:28:48
# episode : 234 | final step : 201 | total reward : 202.0
# 2020/10/02 01:28:52
# episode : 235 | final step : 98 | total reward : -2.0
# 2020/10/02 01:28:58
# episode : 236 | final step : 201 | total reward : 202.0
# 2020/10/02 01:29:02
# episode : 237 | final step : 99 | total reward : -1.0
# 2020/10/02 01:29:09
# episode : 238 | final step : 201 | total reward : 202.0
# 2020/10/02 01:29:17
# episode : 239 | final step : 201 | total reward : 202.0
# 2020/10/02 01:29:20
# episode : 240 | final step : 98 | total reward : -2.0
# 2020/10/02 01:29:24
# episode : 241 | final step : 97 | total reward : -3.0
# 2020/10/02 01:29:27
# episode : 242 | final step : 99 | total reward : -1.0
# 2020/10/02 01:29:34
# episode : 243 | final step : 201 | total reward : 202.0
# 2020/10/02 01:29:37
# episode : 244 | final step : 98 | total reward : -2.0
# 2020/10/02 01:29:45
# episode : 245 | final step : 201 | total reward : 202.0
# 2020/10/02 01:29:48
# episode : 246 | final step : 100 | total reward : 0.0
# 2020/10/02 01:29:52
# episode : 247 | final step : 98 | total reward : -2.0
# 2020/10/02 01:29:55
# episode : 248 | final step : 98 | total reward : -2.0
# 2020/10/02 01:29:59
# episode : 249 | final step : 98 | total reward : -2.0
# 2020/10/02 01:30:02
# episode : 250 | final step : 99 | total reward : -1.0
# 2020/10/02 01:30:09
# episode : 251 | final step : 201 | total reward : 202.0
# 2020/10/02 01:30:13
# episode : 252 | final step : 98 | total reward : -2.0
# 2020/10/02 01:30:20
# episode : 253 | final step : 201 | total reward : 202.0
# 2020/10/02 01:30:23
# episode : 254 | final step : 99 | total reward : -1.0
# 2020/10/02 01:30:31
# episode : 255 | final step : 201 | total reward : 202.0
# 2020/10/02 01:30:34
# episode : 256 | final step : 99 | total reward : -1.0
# 2020/10/02 01:30:41
# episode : 257 | final step : 201 | total reward : 202.0
# 2020/10/02 01:30:45
# episode : 258 | final step : 100 | total reward : 0.0
# 2020/10/02 01:30:48
# episode : 259 | final step : 99 | total reward : -1.0
# 2020/10/02 01:30:55
# episode : 260 | final step : 201 | total reward : 202.0
# 2020/10/02 01:30:59
# episode : 261 | final step : 98 | total reward : -2.0
# 2020/10/02 01:31:02
# episode : 262 | final step : 99 | total reward : -1.0
# 2020/10/02 01:31:06
# episode : 263 | final step : 98 | total reward : -2.0
# 2020/10/02 01:31:10
# episode : 264 | final step : 98 | total reward : -2.0
# 2020/10/02 01:31:13
# episode : 265 | final step : 99 | total reward : -1.0
# 2020/10/02 01:31:17
# episode : 266 | final step : 98 | total reward : -2.0
# 2020/10/02 01:31:24
# episode : 267 | final step : 201 | total reward : 202.0
# 2020/10/02 01:31:31
# episode : 268 | final step : 201 | total reward : 202.0
# 2020/10/02 01:31:38
# episode : 269 | final step : 201 | total reward : 202.0
# 2020/10/02 01:31:42
# episode : 270 | final step : 98 | total reward : -2.0
# 2020/10/02 01:31:45
# episode : 271 | final step : 98 | total reward : -2.0
# 2020/10/02 01:31:52
# episode : 272 | final step : 201 | total reward : 202.0
# 2020/10/02 01:31:56
# episode : 273 | final step : 98 | total reward : -2.0
# 2020/10/02 01:32:03
# episode : 274 | final step : 201 | total reward : 202.0
# 2020/10/02 01:32:06
# episode : 275 | final step : 100 | total reward : 0.0
# 2020/10/02 01:32:14
# episode : 276 | final step : 201 | total reward : 202.0
# 2020/10/02 01:32:17
# episode : 277 | final step : 99 | total reward : -1.0
# 2020/10/02 01:32:21
# episode : 278 | final step : 98 | total reward : -2.0
# 2020/10/02 01:32:24
# episode : 279 | final step : 98 | total reward : -2.0
# 2020/10/02 01:32:28
# episode : 280 | final step : 98 | total reward : -2.0
# 2020/10/02 01:32:31
# episode : 281 | final step : 99 | total reward : -1.0
# 2020/10/02 01:32:35
# episode : 282 | final step : 98 | total reward : -2.0
# 2020/10/02 01:32:42
# episode : 283 | final step : 201 | total reward : 202.0
# 2020/10/02 01:32:45
# episode : 284 | final step : 98 | total reward : -2.0
# 2020/10/02 01:32:49
# episode : 285 | final step : 98 | total reward : -2.0
# 2020/10/02 01:32:56
# episode : 286 | final step : 201 | total reward : 202.0
# 2020/10/02 01:33:00
# episode : 287 | final step : 98 | total reward : -2.0
# 2020/10/02 01:33:03
# episode : 288 | final step : 98 | total reward : -2.0
# 2020/10/02 01:33:06
# episode : 289 | final step : 99 | total reward : -1.0
# 2020/10/02 01:33:10
# episode : 290 | final step : 97 | total reward : -3.0
# 2020/10/02 01:33:13
# episode : 291 | final step : 99 | total reward : -1.0
# 2020/10/02 01:33:20
# episode : 292 | final step : 201 | total reward : 202.0
# 2020/10/02 01:33:23
# episode : 293 | final step : 98 | total reward : -2.0
# 2020/10/02 01:33:30
# episode : 294 | final step : 201 | total reward : 202.0
# 2020/10/02 01:33:34
# episode : 295 | final step : 98 | total reward : -2.0
# 2020/10/02 01:33:41
# episode : 296 | final step : 201 | total reward : 202.0
# 2020/10/02 01:33:48
# episode : 297 | final step : 201 | total reward : 202.0
# 2020/10/02 01:33:52
# episode : 298 | final step : 99 | total reward : -1.0
# 2020/10/02 01:33:55
# episode : 299 | final step : 98 | total reward : -2.0
# 2020/10/02 01:33:59
# episode : 300 | final step : 99 | total reward : -1.0
# 2020/10/02 01:34:02
# episode : 301 | final step : 100 | total reward : 0.0
# 2020/10/02 01:34:06
# episode : 302 | final step : 98 | total reward : -2.0
# 2020/10/02 01:34:09
# episode : 303 | final step : 98 | total reward : -2.0
# 2020/10/02 01:34:13
# episode : 304 | final step : 98 | total reward : -2.0
# 2020/10/02 01:34:17
# episode : 305 | final step : 98 | total reward : -2.0
# 2020/10/02 01:34:20
# episode : 306 | final step : 98 | total reward : -2.0
# 2020/10/02 01:34:27
# episode : 307 | final step : 201 | total reward : 202.0
# 2020/10/02 01:34:31
# episode : 308 | final step : 99 | total reward : -1.0
# 2020/10/02 01:34:34
# episode : 309 | final step : 100 | total reward : 0.0
# 2020/10/02 01:34:38
# episode : 310 | final step : 100 | total reward : 0.0
# 2020/10/02 01:34:41
# episode : 311 | final step : 98 | total reward : -2.0
# 2020/10/02 01:34:48
# episode : 312 | final step : 201 | total reward : 202.0
# 2020/10/02 01:34:52
# episode : 313 | final step : 98 | total reward : -2.0
# 2020/10/02 01:34:56
# episode : 314 | final step : 98 | total reward : -2.0
# 2020/10/02 01:35:03
# episode : 315 | final step : 201 | total reward : 202.0
# 2020/10/02 01:35:06
# episode : 316 | final step : 98 | total reward : -2.0
# 2020/10/02 01:35:13
# episode : 317 | final step : 201 | total reward : 202.0
# 2020/10/02 01:35:20
# episode : 318 | final step : 201 | total reward : 202.0
# 2020/10/02 01:35:27
# episode : 319 | final step : 201 | total reward : 202.0
# 2020/10/02 01:35:30
# episode : 320 | final step : 98 | total reward : -2.0
# 2020/10/02 01:35:34
# episode : 321 | final step : 98 | total reward : -2.0
# 2020/10/02 01:35:41
# episode : 322 | final step : 201 | total reward : 202.0
# 2020/10/02 01:35:44
# episode : 323 | final step : 98 | total reward : -2.0
# 2020/10/02 01:35:52
# episode : 324 | final step : 201 | total reward : 202.0
# 2020/10/02 01:35:59
# episode : 325 | final step : 201 | total reward : 202.0
# 2020/10/02 01:36:02
# episode : 326 | final step : 98 | total reward : -2.0
# 2020/10/02 01:36:06
# episode : 327 | final step : 99 | total reward : -1.0
# 2020/10/02 01:36:13
# episode : 328 | final step : 201 | total reward : 202.0
# 2020/10/02 01:36:16
# episode : 329 | final step : 99 | total reward : -1.0
# 2020/10/02 01:36:20
# episode : 330 | final step : 99 | total reward : -1.0
# 2020/10/02 01:36:23
# episode : 331 | final step : 98 | total reward : -2.0
# 2020/10/02 01:36:27
# episode : 332 | final step : 98 | total reward : -2.0
# 2020/10/02 01:36:30
# episode : 333 | final step : 100 | total reward : 0.0
# 2020/10/02 01:36:37
# episode : 334 | final step : 201 | total reward : 202.0
# 2020/10/02 01:36:41
# episode : 335 | final step : 98 | total reward : -2.0
# 2020/10/02 01:36:44
# episode : 336 | final step : 98 | total reward : -2.0
# 2020/10/02 01:36:48
# episode : 337 | final step : 97 | total reward : -3.0
# 2020/10/02 01:36:54
# episode : 338 | final step : 201 | total reward : 202.0
# 2020/10/02 01:36:58
# episode : 339 | final step : 99 | total reward : -1.0
# 2020/10/02 01:37:05
# episode : 340 | final step : 201 | total reward : 202.0
# 2020/10/02 01:37:12
# episode : 341 | final step : 201 | total reward : 202.0
# 2020/10/02 01:37:16
# episode : 342 | final step : 98 | total reward : -2.0
# 2020/10/02 01:37:19
# episode : 343 | final step : 98 | total reward : -2.0
# 2020/10/02 01:37:26
# episode : 344 | final step : 201 | total reward : 202.0
# 2020/10/02 01:37:33
# episode : 345 | final step : 201 | total reward : 202.0
# 2020/10/02 01:37:36
# episode : 346 | final step : 100 | total reward : 0.0
# 2020/10/02 01:37:40
# episode : 347 | final step : 99 | total reward : -1.0
# 2020/10/02 01:37:43
# episode : 348 | final step : 98 | total reward : -2.0
# 2020/10/02 01:37:47
# episode : 349 | final step : 98 | total reward : -2.0
# 2020/10/02 01:37:50
# episode : 350 | final step : 98 | total reward : -2.0
# 2020/10/02 01:37:54
# episode : 351 | final step : 98 | total reward : -2.0
# 2020/10/02 01:37:57
# episode : 352 | final step : 98 | total reward : -2.0
# 2020/10/02 01:38:00
# episode : 353 | final step : 98 | total reward : -2.0
# 2020/10/02 01:38:04
# episode : 354 | final step : 98 | total reward : -2.0
# 2020/10/02 01:38:07
# episode : 355 | final step : 98 | total reward : -2.0
# 2020/10/02 01:38:11
# episode : 356 | final step : 99 | total reward : -1.0
# 2020/10/02 01:38:18
# episode : 357 | final step : 201 | total reward : 202.0
# 2020/10/02 01:38:21
# episode : 358 | final step : 99 | total reward : -1.0
# 2020/10/02 01:38:24
# episode : 359 | final step : 98 | total reward : -2.0
# 2020/10/02 01:38:28
# episode : 360 | final step : 98 | total reward : -2.0
# 2020/10/02 01:38:31
# episode : 361 | final step : 98 | total reward : -2.0
# 2020/10/02 01:38:35
# episode : 362 | final step : 98 | total reward : -2.0
# 2020/10/02 01:38:38
# episode : 363 | final step : 99 | total reward : -1.0
# 2020/10/02 01:38:42
# episode : 364 | final step : 98 | total reward : -2.0
# 2020/10/02 01:38:45
# episode : 365 | final step : 99 | total reward : -1.0
# 2020/10/02 01:38:49
# episode : 366 | final step : 98 | total reward : -2.0
# 2020/10/02 01:38:52
# episode : 367 | final step : 100 | total reward : 0.0
# 2020/10/02 01:38:56
# episode : 368 | final step : 99 | total reward : -1.0
# 2020/10/02 01:38:59
# episode : 369 | final step : 99 | total reward : -1.0
# 2020/10/02 01:39:03
# episode : 370 | final step : 98 | total reward : -2.0
# 2020/10/02 01:39:06
# episode : 371 | final step : 98 | total reward : -2.0
# 2020/10/02 01:39:13
# episode : 372 | final step : 201 | total reward : 202.0
# 2020/10/02 01:39:17
# episode : 373 | final step : 98 | total reward : -2.0
# 2020/10/02 01:39:20
# episode : 374 | final step : 98 | total reward : -2.0
# 2020/10/02 01:39:24
# episode : 375 | final step : 100 | total reward : 0.0
# 2020/10/02 01:39:27
# episode : 376 | final step : 98 | total reward : -2.0
# 2020/10/02 01:39:35
# episode : 377 | final step : 201 | total reward : 202.0
# 2020/10/02 01:39:39
# episode : 378 | final step : 98 | total reward : -2.0
# 2020/10/02 01:39:42
# episode : 379 | final step : 98 | total reward : -2.0
# 2020/10/02 01:39:49
# episode : 380 | final step : 201 | total reward : 202.0
# 2020/10/02 01:39:57
# episode : 381 | final step : 201 | total reward : 202.0
# 2020/10/02 01:40:00
# episode : 382 | final step : 98 | total reward : -2.0
# 2020/10/02 01:40:07
# episode : 383 | final step : 201 | total reward : 202.0
# 2020/10/02 01:40:11
# episode : 384 | final step : 100 | total reward : 0.0
# 2020/10/02 01:40:14
# episode : 385 | final step : 98 | total reward : -2.0
# 2020/10/02 01:40:18
# episode : 386 | final step : 98 | total reward : -2.0
# 2020/10/02 01:40:21
# episode : 387 | final step : 98 | total reward : -2.0
# 2020/10/02 01:40:25
# episode : 388 | final step : 98 | total reward : -2.0
# 2020/10/02 01:40:28
# episode : 389 | final step : 98 | total reward : -2.0
# 2020/10/02 01:40:32
# episode : 390 | final step : 98 | total reward : -2.0
# 2020/10/02 01:40:39
# episode : 391 | final step : 201 | total reward : 202.0
# 2020/10/02 01:40:42
# episode : 392 | final step : 98 | total reward : -2.0
# 2020/10/02 01:40:46
# episode : 393 | final step : 98 | total reward : -2.0
# 2020/10/02 01:40:49
# episode : 394 | final step : 99 | total reward : -1.0
# 2020/10/02 01:40:56
# episode : 395 | final step : 201 | total reward : 202.0
# 2020/10/02 01:41:00
# episode : 396 | final step : 98 | total reward : -2.0
# 2020/10/02 01:41:07
# episode : 397 | final step : 201 | total reward : 202.0
# 2020/10/02 01:41:14
# episode : 398 | final step : 201 | total reward : 202.0
# 2020/10/02 01:41:17
# episode : 399 | final step : 98 | total reward : -2.0
# 2020/10/02 01:41:21
# episode : 400 | final step : 99 | total reward : -1.0
# 2020/10/02 01:41:24
# episode : 401 | final step : 100 | total reward : 0.0
# 2020/10/02 01:41:31
# episode : 402 | final step : 201 | total reward : 202.0
# 2020/10/02 01:41:35
# episode : 403 | final step : 98 | total reward : -2.0
# 2020/10/02 01:41:38
# episode : 404 | final step : 98 | total reward : -2.0
# 2020/10/02 01:41:42
# episode : 405 | final step : 98 | total reward : -2.0
# 2020/10/02 01:41:45
# episode : 406 | final step : 98 | total reward : -2.0
# 2020/10/02 01:41:49
# episode : 407 | final step : 99 | total reward : -1.0
# 2020/10/02 01:41:52
# episode : 408 | final step : 98 | total reward : -2.0
# 2020/10/02 01:41:59
# episode : 409 | final step : 201 | total reward : 202.0
# 2020/10/02 01:42:03
# episode : 410 | final step : 98 | total reward : -2.0
# 2020/10/02 01:42:06
# episode : 411 | final step : 98 | total reward : -2.0
# 2020/10/02 01:42:10
# episode : 412 | final step : 100 | total reward : 0.0
# 2020/10/02 01:42:14
# episode : 413 | final step : 99 | total reward : -1.0
# 2020/10/02 01:42:17
# episode : 414 | final step : 99 | total reward : -1.0
# 2020/10/02 01:42:21
# episode : 415 | final step : 98 | total reward : -2.0
# 2020/10/02 01:42:24
# episode : 416 | final step : 99 | total reward : -1.0
# 2020/10/02 01:42:31
# episode : 417 | final step : 201 | total reward : 202.0
# 2020/10/02 01:42:38
# episode : 418 | final step : 201 | total reward : 202.0
# 2020/10/02 01:42:42
# episode : 419 | final step : 98 | total reward : -2.0
# 2020/10/02 01:42:45
# episode : 420 | final step : 98 | total reward : -2.0
# 2020/10/02 01:42:48
# episode : 421 | final step : 99 | total reward : -1.0
# 2020/10/02 01:42:56
# episode : 422 | final step : 201 | total reward : 202.0
# 2020/10/02 01:42:59
# episode : 423 | final step : 99 | total reward : -1.0
# 2020/10/02 01:43:03
# episode : 424 | final step : 98 | total reward : -2.0
# 2020/10/02 01:43:06
# episode : 425 | final step : 98 | total reward : -2.0
# 2020/10/02 01:43:13
# episode : 426 | final step : 201 | total reward : 202.0
# 2020/10/02 01:43:16
# episode : 427 | final step : 98 | total reward : -2.0
# 2020/10/02 01:43:24
# episode : 428 | final step : 201 | total reward : 202.0
# 2020/10/02 01:43:31
# episode : 429 | final step : 201 | total reward : 202.0
# 2020/10/02 01:43:34
# episode : 430 | final step : 98 | total reward : -2.0
# 2020/10/02 01:43:38
# episode : 431 | final step : 98 | total reward : -2.0
# 2020/10/02 01:43:42
# episode : 432 | final step : 98 | total reward : -2.0
# 2020/10/02 01:43:48
# episode : 433 | final step : 201 | total reward : 202.0
# 2020/10/02 01:43:52
# episode : 434 | final step : 98 | total reward : -2.0
# 2020/10/02 01:43:59
# episode : 435 | final step : 201 | total reward : 202.0
# 2020/10/02 01:44:07
# episode : 436 | final step : 201 | total reward : 202.0
# 2020/10/02 01:44:14
# episode : 437 | final step : 201 | total reward : 202.0
# 2020/10/02 01:44:17
# episode : 438 | final step : 99 | total reward : -1.0
# 2020/10/02 01:44:21
# episode : 439 | final step : 100 | total reward : 0.0
# 2020/10/02 01:44:24
# episode : 440 | final step : 98 | total reward : -2.0
# 2020/10/02 01:44:27
# episode : 441 | final step : 98 | total reward : -2.0
# 2020/10/02 01:44:35
# episode : 442 | final step : 201 | total reward : 202.0
# 2020/10/02 01:44:38
# episode : 443 | final step : 98 | total reward : -2.0
# 2020/10/02 01:44:42
# episode : 444 | final step : 98 | total reward : -2.0
# 2020/10/02 01:44:45
# episode : 445 | final step : 98 | total reward : -2.0
# 2020/10/02 01:44:52
# episode : 446 | final step : 201 | total reward : 202.0
# 2020/10/02 01:44:56
# episode : 447 | final step : 99 | total reward : -1.0
# 2020/10/02 01:44:59
# episode : 448 | final step : 98 | total reward : -2.0
# 2020/10/02 01:45:07
# episode : 449 | final step : 201 | total reward : 202.0
# 2020/10/02 01:45:14
# episode : 450 | final step : 201 | total reward : 202.0
# 2020/10/02 01:45:17
# episode : 451 | final step : 98 | total reward : -2.0
# 2020/10/02 01:45:24
# episode : 452 | final step : 201 | total reward : 202.0
# 2020/10/02 01:45:28
# episode : 453 | final step : 99 | total reward : -1.0
# 2020/10/02 01:45:35
# episode : 454 | final step : 201 | total reward : 202.0
# 2020/10/02 01:45:42
# episode : 455 | final step : 201 | total reward : 202.0
# 2020/10/02 01:45:46
# episode : 456 | final step : 98 | total reward : -2.0
# 2020/10/02 01:45:53
# episode : 457 | final step : 201 | total reward : 202.0
# 2020/10/02 01:45:56
# episode : 458 | final step : 99 | total reward : -1.0
# 2020/10/02 01:46:00
# episode : 459 | final step : 99 | total reward : -1.0
# 2020/10/02 01:46:03
# episode : 460 | final step : 98 | total reward : -2.0
# 2020/10/02 01:46:10
# episode : 461 | final step : 201 | total reward : 202.0
# 2020/10/02 01:46:14
# episode : 462 | final step : 99 | total reward : -1.0
# 2020/10/02 01:46:17
# episode : 463 | final step : 98 | total reward : -2.0
# 2020/10/02 01:46:21
# episode : 464 | final step : 98 | total reward : -2.0
# 2020/10/02 01:46:24
# episode : 465 | final step : 98 | total reward : -2.0
# 2020/10/02 01:46:28
# episode : 466 | final step : 98 | total reward : -2.0
# 2020/10/02 01:46:31
# episode : 467 | final step : 99 | total reward : -1.0
# 2020/10/02 01:46:35
# episode : 468 | final step : 99 | total reward : -1.0
# 2020/10/02 01:46:38
# episode : 469 | final step : 99 | total reward : -1.0
# 2020/10/02 01:46:45
# episode : 470 | final step : 201 | total reward : 202.0
# 2020/10/02 01:46:49
# episode : 471 | final step : 99 | total reward : -1.0
# 2020/10/02 01:46:56
# episode : 472 | final step : 201 | total reward : 202.0
# 2020/10/02 01:47:03
# episode : 473 | final step : 201 | total reward : 202.0
# 2020/10/02 01:47:10
# episode : 474 | final step : 201 | total reward : 202.0
# 2020/10/02 01:47:17
# episode : 475 | final step : 201 | total reward : 202.0
# 2020/10/02 01:47:20
# episode : 476 | final step : 99 | total reward : -1.0
# 2020/10/02 01:47:27
# episode : 477 | final step : 201 | total reward : 202.0
# 2020/10/02 01:47:31
# episode : 478 | final step : 98 | total reward : -2.0
# 2020/10/02 01:47:34
# episode : 479 | final step : 98 | total reward : -2.0
# 2020/10/02 01:47:37
# episode : 480 | final step : 100 | total reward : 0.0
# 2020/10/02 01:47:41
# episode : 481 | final step : 98 | total reward : -2.0
# 2020/10/02 01:47:48
# episode : 482 | final step : 201 | total reward : 202.0
# 2020/10/02 01:47:55
# episode : 483 | final step : 201 | total reward : 202.0
# 2020/10/02 01:47:59
# episode : 484 | final step : 98 | total reward : -2.0
# 2020/10/02 01:48:02
# episode : 485 | final step : 98 | total reward : -2.0
# 2020/10/02 01:48:05
# episode : 486 | final step : 98 | total reward : -2.0
# 2020/10/02 01:48:09
# episode : 487 | final step : 98 | total reward : -2.0
# 2020/10/02 01:48:12
# episode : 488 | final step : 98 | total reward : -2.0
# 2020/10/02 01:48:16
# episode : 489 | final step : 99 | total reward : -1.0
# 2020/10/02 01:48:19
# episode : 490 | final step : 98 | total reward : -2.0
# 2020/10/02 01:48:23
# episode : 491 | final step : 99 | total reward : -1.0
# 2020/10/02 01:48:26
# episode : 492 | final step : 98 | total reward : -2.0
# 2020/10/02 01:48:30
# episode : 493 | final step : 100 | total reward : 0.0
# 2020/10/02 01:48:33
# episode : 494 | final step : 97 | total reward : -3.0
# 2020/10/02 01:48:40
# episode : 495 | final step : 201 | total reward : 202.0
# 2020/10/02 01:48:44
# episode : 496 | final step : 98 | total reward : -2.0
# 2020/10/02 01:48:47
# episode : 497 | final step : 98 | total reward : -2.0
# 2020/10/02 01:48:54
# episode : 498 | final step : 201 | total reward : 202.0
# 2020/10/02 01:49:01
# episode : 499 | final step : 201 | total reward : 202.0
# 2020/10/02 01:49:05
# episode : 500 | final step : 99 | total reward : -1.0
# 2020/10/02 01:49:12
# episode : 501 | final step : 201 | total reward : 202.0
# 2020/10/02 01:49:19
# episode : 502 | final step : 201 | total reward : 202.0
# 2020/10/02 01:49:22
# episode : 503 | final step : 98 | total reward : -2.0
# 2020/10/02 01:49:25
# episode : 504 | final step : 99 | total reward : -1.0
# 2020/10/02 01:49:29
# episode : 505 | final step : 98 | total reward : -2.0
# 2020/10/02 01:49:32
# episode : 506 | final step : 97 | total reward : -3.0
# 2020/10/02 01:49:39
# episode : 507 | final step : 201 | total reward : 202.0
# 2020/10/02 01:49:46
# episode : 508 | final step : 201 | total reward : 202.0
# 2020/10/02 01:49:53
# episode : 509 | final step : 201 | total reward : 202.0
# 2020/10/02 01:50:00
# episode : 510 | final step : 201 | total reward : 202.0
# 2020/10/02 01:50:08
# episode : 511 | final step : 201 | total reward : 202.0
# 2020/10/02 01:50:11
# episode : 512 | final step : 98 | total reward : -2.0
# 2020/10/02 01:50:18
# episode : 513 | final step : 201 | total reward : 202.0
# 2020/10/02 01:50:22
# episode : 514 | final step : 98 | total reward : -2.0
# 2020/10/02 01:50:25
# episode : 515 | final step : 98 | total reward : -2.0
# 2020/10/02 01:50:28
# episode : 516 | final step : 99 | total reward : -1.0
# 2020/10/02 01:50:36
# episode : 517 | final step : 201 | total reward : 202.0
# 2020/10/02 01:50:43
# episode : 518 | final step : 201 | total reward : 202.0
# 2020/10/02 01:50:47
# episode : 519 | final step : 98 | total reward : -2.0
# 2020/10/02 01:50:50
# episode : 520 | final step : 99 | total reward : -1.0
# 2020/10/02 01:50:57
# episode : 521 | final step : 201 | total reward : 202.0
# 2020/10/02 01:51:01
# episode : 522 | final step : 99 | total reward : -1.0
# 2020/10/02 01:51:07
# episode : 523 | final step : 201 | total reward : 202.0
# 2020/10/02 01:51:11
# episode : 524 | final step : 98 | total reward : -2.0
# 2020/10/02 01:51:18
# episode : 525 | final step : 201 | total reward : 202.0
# 2020/10/02 01:51:25
# episode : 526 | final step : 201 | total reward : 202.0
# 2020/10/02 01:51:32
# episode : 527 | final step : 201 | total reward : 202.0
# 2020/10/02 01:51:36
# episode : 528 | final step : 98 | total reward : -2.0
# 2020/10/02 01:51:39
# episode : 529 | final step : 100 | total reward : 0.0
# 2020/10/02 01:51:46
# episode : 530 | final step : 201 | total reward : 202.0
# 2020/10/02 01:51:50
# episode : 531 | final step : 98 | total reward : -2.0
# 2020/10/02 01:51:54
# episode : 532 | final step : 99 | total reward : -1.0
# 2020/10/02 01:51:57
# episode : 533 | final step : 99 | total reward : -1.0
# 2020/10/02 01:52:04
# episode : 534 | final step : 201 | total reward : 202.0
# 2020/10/02 01:52:07
# episode : 535 | final step : 98 | total reward : -2.0
# 2020/10/02 01:52:14
# episode : 536 | final step : 201 | total reward : 202.0
# 2020/10/02 01:52:21
# episode : 537 | final step : 201 | total reward : 202.0
# 2020/10/02 01:52:25
# episode : 538 | final step : 100 | total reward : 0.0
# 2020/10/02 01:52:29
# episode : 539 | final step : 98 | total reward : -2.0
# 2020/10/02 01:52:35
# episode : 540 | final step : 201 | total reward : 202.0
# 2020/10/02 01:52:39
# episode : 541 | final step : 99 | total reward : -1.0
# 2020/10/02 01:52:42
# episode : 542 | final step : 98 | total reward : -2.0
# 2020/10/02 01:52:46
# episode : 543 | final step : 98 | total reward : -2.0
# 2020/10/02 01:52:49
# episode : 544 | final step : 98 | total reward : -2.0
# 2020/10/02 01:52:53
# episode : 545 | final step : 99 | total reward : -1.0
# 2020/10/02 01:52:56
# episode : 546 | final step : 98 | total reward : -2.0
# 2020/10/02 01:53:00
# episode : 547 | final step : 98 | total reward : -2.0
# 2020/10/02 01:53:07
# episode : 548 | final step : 201 | total reward : 202.0
# 2020/10/02 01:53:14
# episode : 549 | final step : 201 | total reward : 202.0
# 2020/10/02 01:53:17
# episode : 550 | final step : 98 | total reward : -2.0
# 2020/10/02 01:53:21
# episode : 551 | final step : 98 | total reward : -2.0
# 2020/10/02 01:53:24
# episode : 552 | final step : 98 | total reward : -2.0
# 2020/10/02 01:53:28
# episode : 553 | final step : 98 | total reward : -2.0
# 2020/10/02 01:53:31
# episode : 554 | final step : 98 | total reward : -2.0
# 2020/10/02 01:53:39
# episode : 555 | final step : 201 | total reward : 202.0
# 2020/10/02 01:53:42
# episode : 556 | final step : 98 | total reward : -2.0
# 2020/10/02 01:53:49
# episode : 557 | final step : 201 | total reward : 202.0
# 2020/10/02 01:53:53
# episode : 558 | final step : 100 | total reward : 0.0
# 2020/10/02 01:53:56
# episode : 559 | final step : 99 | total reward : -1.0
# 2020/10/02 01:54:04
# episode : 560 | final step : 201 | total reward : 202.0
# 2020/10/02 01:54:07
# episode : 561 | final step : 99 | total reward : -1.0
# 2020/10/02 01:54:11
# episode : 562 | final step : 99 | total reward : -1.0
# 2020/10/02 01:54:14
# episode : 563 | final step : 98 | total reward : -2.0
# 2020/10/02 01:54:18
# episode : 564 | final step : 98 | total reward : -2.0
# 2020/10/02 01:54:25
# episode : 565 | final step : 201 | total reward : 202.0
# 2020/10/02 01:54:31
# episode : 566 | final step : 201 | total reward : 202.0
# 2020/10/02 01:54:35
# episode : 567 | final step : 100 | total reward : 0.0
# 2020/10/02 01:54:42
# episode : 568 | final step : 201 | total reward : 202.0
# 2020/10/02 01:54:49
# episode : 569 | final step : 201 | total reward : 202.0
# 2020/10/02 01:54:56
# episode : 570 | final step : 201 | total reward : 202.0
# 2020/10/02 01:55:00
# episode : 571 | final step : 99 | total reward : -1.0
# 2020/10/02 01:55:03
# episode : 572 | final step : 98 | total reward : -2.0
# 2020/10/02 01:55:10
# episode : 573 | final step : 201 | total reward : 202.0
# 2020/10/02 01:55:13
# episode : 574 | final step : 99 | total reward : -1.0
# 2020/10/02 01:55:17
# episode : 575 | final step : 99 | total reward : -1.0
# 2020/10/02 01:55:21
# episode : 576 | final step : 99 | total reward : -1.0
# 2020/10/02 01:55:24
# episode : 577 | final step : 98 | total reward : -2.0
# 2020/10/02 01:55:31
# episode : 578 | final step : 201 | total reward : 202.0
# 2020/10/02 01:55:38
# episode : 579 | final step : 201 | total reward : 202.0
# 2020/10/02 01:55:42
# episode : 580 | final step : 99 | total reward : -1.0
# 2020/10/02 01:55:45
# episode : 581 | final step : 98 | total reward : -2.0
# 2020/10/02 01:55:52
# episode : 582 | final step : 201 | total reward : 202.0
# 2020/10/02 01:55:59
# episode : 583 | final step : 201 | total reward : 202.0
# 2020/10/02 01:56:03
# episode : 584 | final step : 98 | total reward : -2.0
# 2020/10/02 01:56:07
# episode : 585 | final step : 99 | total reward : -1.0
# 2020/10/02 01:56:10
# episode : 586 | final step : 98 | total reward : -2.0
# 2020/10/02 01:56:13
# episode : 587 | final step : 98 | total reward : -2.0
# 2020/10/02 01:56:20
# episode : 588 | final step : 201 | total reward : 202.0
# 2020/10/02 01:56:27
# episode : 589 | final step : 201 | total reward : 202.0
# 2020/10/02 01:56:34
# episode : 590 | final step : 201 | total reward : 202.0
# 2020/10/02 01:56:38
# episode : 591 | final step : 98 | total reward : -2.0
# 2020/10/02 01:56:41
# episode : 592 | final step : 99 | total reward : -1.0
# 2020/10/02 01:56:44
# episode : 593 | final step : 98 | total reward : -2.0
# 2020/10/02 01:56:48
# episode : 594 | final step : 100 | total reward : 0.0
# 2020/10/02 01:56:51
# episode : 595 | final step : 99 | total reward : -1.0
# 2020/10/02 01:56:58
# episode : 596 | final step : 201 | total reward : 202.0
# 2020/10/02 01:57:02
# episode : 597 | final step : 98 | total reward : -2.0
# 2020/10/02 01:57:05
# episode : 598 | final step : 98 | total reward : -2.0
# 2020/10/02 01:57:08
# episode : 599 | final step : 98 | total reward : -2.0
# 2020/10/02 01:57:12
# episode : 600 | final step : 99 | total reward : -1.0
# 2020/10/02 01:57:16
# episode : 601 | final step : 98 | total reward : -2.0
# 2020/10/02 01:57:19
# episode : 602 | final step : 98 | total reward : -2.0
# 2020/10/02 01:57:23
# episode : 603 | final step : 98 | total reward : -2.0
# 2020/10/02 01:57:26
# episode : 604 | final step : 98 | total reward : -2.0
# 2020/10/02 01:57:30
# episode : 605 | final step : 98 | total reward : -2.0
# 2020/10/02 01:57:33
# episode : 606 | final step : 100 | total reward : 0.0
# 2020/10/02 01:57:37
# episode : 607 | final step : 99 | total reward : -1.0
# 2020/10/02 01:57:40
# episode : 608 | final step : 98 | total reward : -2.0
# 2020/10/02 01:57:48
# episode : 609 | final step : 201 | total reward : 202.0
# 2020/10/02 01:57:54
# episode : 610 | final step : 201 | total reward : 202.0
# 2020/10/02 01:57:58
# episode : 611 | final step : 98 | total reward : -2.0
# 2020/10/02 01:58:01
# episode : 612 | final step : 97 | total reward : -3.0
# 2020/10/02 01:58:08
# episode : 613 | final step : 201 | total reward : 202.0
# 2020/10/02 01:58:12
# episode : 614 | final step : 99 | total reward : -1.0
# 2020/10/02 01:58:19
# episode : 615 | final step : 201 | total reward : 202.0
# 2020/10/02 01:58:23
# episode : 616 | final step : 99 | total reward : -1.0
# 2020/10/02 01:58:26
# episode : 617 | final step : 98 | total reward : -2.0
# 2020/10/02 01:58:30
# episode : 618 | final step : 99 | total reward : -1.0
# 2020/10/02 01:58:37
# episode : 619 | final step : 201 | total reward : 202.0
# 2020/10/02 01:58:40
# episode : 620 | final step : 98 | total reward : -2.0
# 2020/10/02 01:58:43
# episode : 621 | final step : 98 | total reward : -2.0
# 2020/10/02 01:58:47
# episode : 622 | final step : 98 | total reward : -2.0
# 2020/10/02 01:58:54
# episode : 623 | final step : 201 | total reward : 202.0
# 2020/10/02 01:58:57
# episode : 624 | final step : 98 | total reward : -2.0
# 2020/10/02 01:59:01
# episode : 625 | final step : 99 | total reward : -1.0
# 2020/10/02 01:59:04
# episode : 626 | final step : 98 | total reward : -2.0
# 2020/10/02 01:59:08
# episode : 627 | final step : 98 | total reward : -2.0
# 2020/10/02 01:59:11
# episode : 628 | final step : 99 | total reward : -1.0
# 2020/10/02 01:59:18
# episode : 629 | final step : 201 | total reward : 202.0
# 2020/10/02 01:59:25
# episode : 630 | final step : 201 | total reward : 202.0
# 2020/10/02 01:59:32
# episode : 631 | final step : 201 | total reward : 202.0
# 2020/10/02 01:59:39
# episode : 632 | final step : 201 | total reward : 202.0
# 2020/10/02 01:59:42
# episode : 633 | final step : 98 | total reward : -2.0
# 2020/10/02 01:59:46
# episode : 634 | final step : 98 | total reward : -2.0
# 2020/10/02 01:59:49
# episode : 635 | final step : 98 | total reward : -2.0
# 2020/10/02 01:59:53
# episode : 636 | final step : 98 | total reward : -2.0
# 2020/10/02 01:59:56
# episode : 637 | final step : 98 | total reward : -2.0
# 2020/10/02 02:00:00
# episode : 638 | final step : 99 | total reward : -1.0
# 2020/10/02 02:00:03
# episode : 639 | final step : 98 | total reward : -2.0
# 2020/10/02 02:00:07
# episode : 640 | final step : 98 | total reward : -2.0
# 2020/10/02 02:00:10
# episode : 641 | final step : 98 | total reward : -2.0
# 2020/10/02 02:00:14
# episode : 642 | final step : 98 | total reward : -2.0
# 2020/10/02 02:00:21
# episode : 643 | final step : 201 | total reward : 202.0
# 2020/10/02 02:00:25
# ...
# 2020/10/02 14:11:32
# episode : 9789 | final step : 201 | total reward : 202.0
# 2020/10/02 14:11:35
# episode : 9790 | final step : 98 | total reward : -2.0
# 2020/10/02 14:11:38
# episode : 9791 | final step : 98 | total reward : -2.0
# 2020/10/02 14:11:41
# episode : 9792 | final step : 98 | total reward : -2.0
# 2020/10/02 14:11:44
# episode : 9793 | final step : 98 | total reward : -2.0
# 2020/10/02 14:11:47
# episode : 9794 | final step : 98 | total reward : -2.0
# 2020/10/02 14:11:49
# episode : 9795 | final step : 99 | total reward : -1.0
# 2020/10/02 14:11:52
# episode : 9796 | final step : 98 | total reward : -2.0
# 2020/10/02 14:11:55
# episode : 9797 | final step : 98 | total reward : -2.0
# 2020/10/02 14:11:58
# episode : 9798 | final step : 98 | total reward : -2.0
# 2020/10/02 14:12:01
# episode : 9799 | final step : 100 | total reward : 0.0
# 2020/10/02 14:12:07
# episode : 9800 | final step : 201 | total reward : 202.0
# 2020/10/02 14:12:09
# episode : 9801 | final step : 99 | total reward : -1.0
# 2020/10/02 14:12:12
# episode : 9802 | final step : 98 | total reward : -2.0
# 2020/10/02 14:12:18
# episode : 9803 | final step : 201 | total reward : 202.0
# 2020/10/02 14:12:21
# episode : 9804 | final step : 98 | total reward : -2.0
# 2020/10/02 14:12:24
# episode : 9805 | final step : 99 | total reward : -1.0
# 2020/10/02 14:12:29
# episode : 9806 | final step : 201 | total reward : 202.0
# 2020/10/02 14:12:35
# episode : 9807 | final step : 201 | total reward : 202.0
# 2020/10/02 14:12:38
# episode : 9808 | final step : 98 | total reward : -2.0
# 2020/10/02 14:12:41
# episode : 9809 | final step : 99 | total reward : -1.0
# 2020/10/02 14:12:46
# episode : 9810 | final step : 201 | total reward : 202.0
# 2020/10/02 14:12:49
# episode : 9811 | final step : 99 | total reward : -1.0
# 2020/10/02 14:12:52
# episode : 9812 | final step : 98 | total reward : -2.0
# 2020/10/02 14:12:55
# episode : 9813 | final step : 98 | total reward : -2.0
# 2020/10/02 14:12:57
# episode : 9814 | final step : 98 | total reward : -2.0
# 2020/10/02 14:13:00
# episode : 9815 | final step : 98 | total reward : -2.0
# 2020/10/02 14:13:02
# episode : 9816 | final step : 98 | total reward : -2.0
# 2020/10/02 14:13:05
# episode : 9817 | final step : 98 | total reward : -2.0
# 2020/10/02 14:13:08
# episode : 9818 | final step : 99 | total reward : -1.0
# 2020/10/02 14:13:11
# episode : 9819 | final step : 98 | total reward : -2.0
# 2020/10/02 14:13:17
# episode : 9820 | final step : 201 | total reward : 202.0
# 2020/10/02 14:13:19
# episode : 9821 | final step : 98 | total reward : -2.0
# 2020/10/02 14:13:22
# episode : 9822 | final step : 98 | total reward : -2.0
# 2020/10/02 14:13:24
# episode : 9823 | final step : 98 | total reward : -2.0
# 2020/10/02 14:13:27
# episode : 9824 | final step : 98 | total reward : -2.0
# 2020/10/02 14:13:30
# episode : 9825 | final step : 98 | total reward : -2.0
# 2020/10/02 14:13:33
# episode : 9826 | final step : 99 | total reward : -1.0
# 2020/10/02 14:13:35
# episode : 9827 | final step : 98 | total reward : -2.0
# 2020/10/02 14:13:41
# episode : 9828 | final step : 201 | total reward : 202.0
# 2020/10/02 14:13:47
# episode : 9829 | final step : 201 | total reward : 202.0
# 2020/10/02 14:13:50
# episode : 9830 | final step : 99 | total reward : -1.0
# 2020/10/02 14:13:53
# episode : 9831 | final step : 98 | total reward : -2.0
# 2020/10/02 14:13:56
# episode : 9832 | final step : 98 | total reward : -2.0
# 2020/10/02 14:13:59
# episode : 9833 | final step : 98 | total reward : -2.0
# 2020/10/02 14:14:02
# episode : 9834 | final step : 99 | total reward : -1.0
# 2020/10/02 14:14:05
# episode : 9835 | final step : 99 | total reward : -1.0
# 2020/10/02 14:14:07
# episode : 9836 | final step : 98 | total reward : -2.0
# 2020/10/02 14:14:10
# episode : 9837 | final step : 98 | total reward : -2.0
# 2020/10/02 14:14:13
# episode : 9838 | final step : 98 | total reward : -2.0
# 2020/10/02 14:14:16
# episode : 9839 | final step : 99 | total reward : -1.0
# 2020/10/02 14:14:19
# episode : 9840 | final step : 98 | total reward : -2.0
# 2020/10/02 14:14:22
# episode : 9841 | final step : 99 | total reward : -1.0
# 2020/10/02 14:14:25
# episode : 9842 | final step : 98 | total reward : -2.0
# 2020/10/02 14:14:27
# episode : 9843 | final step : 98 | total reward : -2.0
# 2020/10/02 14:14:30
# episode : 9844 | final step : 98 | total reward : -2.0
# 2020/10/02 14:14:36
# episode : 9845 | final step : 201 | total reward : 202.0
# 2020/10/02 14:14:42
# episode : 9846 | final step : 201 | total reward : 202.0
# 2020/10/02 14:14:44
# episode : 9847 | final step : 98 | total reward : -2.0
# 2020/10/02 14:14:47
# episode : 9848 | final step : 98 | total reward : -2.0
# 2020/10/02 14:14:50
# episode : 9849 | final step : 98 | total reward : -2.0
# 2020/10/02 14:14:53
# episode : 9850 | final step : 99 | total reward : -1.0
# 2020/10/02 14:14:56
# episode : 9851 | final step : 100 | total reward : 0.0
# 2020/10/02 14:14:59
# episode : 9852 | final step : 98 | total reward : -2.0
# 2020/10/02 14:15:04
# episode : 9853 | final step : 201 | total reward : 202.0
# 2020/10/02 14:15:10
# episode : 9854 | final step : 201 | total reward : 202.0
# 2020/10/02 14:15:13
# episode : 9855 | final step : 98 | total reward : -2.0
# 2020/10/02 14:15:16
# episode : 9856 | final step : 99 | total reward : -1.0
# 2020/10/02 14:15:22
# episode : 9857 | final step : 201 | total reward : 202.0
# 2020/10/02 14:15:25
# episode : 9858 | final step : 98 | total reward : -2.0
# 2020/10/02 14:15:28
# episode : 9859 | final step : 98 | total reward : -2.0
# 2020/10/02 14:15:31
# episode : 9860 | final step : 99 | total reward : -1.0
# 2020/10/02 14:15:34
# episode : 9861 | final step : 98 | total reward : -2.0
# 2020/10/02 14:15:37
# episode : 9862 | final step : 98 | total reward : -2.0
# 2020/10/02 14:15:40
# episode : 9863 | final step : 99 | total reward : -1.0
# 2020/10/02 14:15:43
# episode : 9864 | final step : 99 | total reward : -1.0
# 2020/10/02 14:15:46
# episode : 9865 | final step : 98 | total reward : -2.0
# 2020/10/02 14:15:49
# episode : 9866 | final step : 99 | total reward : -1.0
# 2020/10/02 14:15:52
# episode : 9867 | final step : 98 | total reward : -2.0
# 2020/10/02 14:15:54
# episode : 9868 | final step : 98 | total reward : -2.0
# 2020/10/02 14:16:00
# episode : 9869 | final step : 201 | total reward : 202.0
# 2020/10/02 14:16:03
# episode : 9870 | final step : 98 | total reward : -2.0
# 2020/10/02 14:16:06
# episode : 9871 | final step : 98 | total reward : -2.0
# 2020/10/02 14:16:12
# episode : 9872 | final step : 201 | total reward : 202.0
# 2020/10/02 14:16:15
# episode : 9873 | final step : 99 | total reward : -1.0
# 2020/10/02 14:16:18
# episode : 9874 | final step : 98 | total reward : -2.0
# 2020/10/02 14:16:24
# episode : 9875 | final step : 201 | total reward : 202.0
# 2020/10/02 14:16:27
# episode : 9876 | final step : 98 | total reward : -2.0
# 2020/10/02 14:16:30
# episode : 9877 | final step : 99 | total reward : -1.0
# 2020/10/02 14:16:32
# episode : 9878 | final step : 98 | total reward : -2.0
# 2020/10/02 14:16:38
# episode : 9879 | final step : 201 | total reward : 202.0
# 2020/10/02 14:16:41
# episode : 9880 | final step : 98 | total reward : -2.0
# 2020/10/02 14:16:44
# episode : 9881 | final step : 98 | total reward : -2.0
# 2020/10/02 14:16:47
# episode : 9882 | final step : 98 | total reward : -2.0
# 2020/10/02 14:16:49
# episode : 9883 | final step : 98 | total reward : -2.0
# 2020/10/02 14:16:55
# episode : 9884 | final step : 201 | total reward : 202.0
# 2020/10/02 14:16:58
# episode : 9885 | final step : 99 | total reward : -1.0
# 2020/10/02 14:17:01
# episode : 9886 | final step : 98 | total reward : -2.0
# 2020/10/02 14:17:03
# episode : 9887 | final step : 98 | total reward : -2.0
# 2020/10/02 14:17:06
# episode : 9888 | final step : 99 | total reward : -1.0
# 2020/10/02 14:17:09
# episode : 9889 | final step : 98 | total reward : -2.0
# 2020/10/02 14:17:12
# episode : 9890 | final step : 98 | total reward : -2.0
# 2020/10/02 14:17:15
# episode : 9891 | final step : 99 | total reward : -1.0
# 2020/10/02 14:17:18
# episode : 9892 | final step : 99 | total reward : -1.0
# 2020/10/02 14:17:23
# episode : 9893 | final step : 201 | total reward : 202.0
# 2020/10/02 14:17:26
# episode : 9894 | final step : 98 | total reward : -2.0
# 2020/10/02 14:17:29
# episode : 9895 | final step : 99 | total reward : -1.0
# 2020/10/02 14:17:35
# episode : 9896 | final step : 201 | total reward : 202.0
# 2020/10/02 14:17:38
# episode : 9897 | final step : 99 | total reward : -1.0
# 2020/10/02 14:17:41
# episode : 9898 | final step : 98 | total reward : -2.0
# 2020/10/02 14:17:47
# episode : 9899 | final step : 201 | total reward : 202.0
# 2020/10/02 14:17:50
# episode : 9900 | final step : 99 | total reward : -1.0
# 2020/10/02 14:17:53
# episode : 9901 | final step : 98 | total reward : -2.0
# 2020/10/02 14:17:59
# episode : 9902 | final step : 201 | total reward : 202.0
# 2020/10/02 14:18:02
# episode : 9903 | final step : 99 | total reward : -1.0
# 2020/10/02 14:18:08
# episode : 9904 | final step : 201 | total reward : 202.0
# 2020/10/02 14:18:11
# episode : 9905 | final step : 98 | total reward : -2.0
# 2020/10/02 14:18:13
# episode : 9906 | final step : 99 | total reward : -1.0
# 2020/10/02 14:18:16
# episode : 9907 | final step : 98 | total reward : -2.0
# 2020/10/02 14:18:19
# episode : 9908 | final step : 98 | total reward : -2.0
# 2020/10/02 14:18:22
# episode : 9909 | final step : 99 | total reward : -1.0
# 2020/10/02 14:18:25
# episode : 9910 | final step : 98 | total reward : -2.0
# 2020/10/02 14:18:28
# episode : 9911 | final step : 98 | total reward : -2.0
# 2020/10/02 14:18:30
# episode : 9912 | final step : 99 | total reward : -1.0
# 2020/10/02 14:18:33
# episode : 9913 | final step : 99 | total reward : -1.0
# 2020/10/02 14:18:36
# episode : 9914 | final step : 100 | total reward : 0.0
# 2020/10/02 14:18:39
# episode : 9915 | final step : 98 | total reward : -2.0
# 2020/10/02 14:18:42
# episode : 9916 | final step : 98 | total reward : -2.0
# 2020/10/02 14:18:45
# episode : 9917 | final step : 98 | total reward : -2.0
# 2020/10/02 14:18:48
# episode : 9918 | final step : 98 | total reward : -2.0
# 2020/10/02 14:18:51
# episode : 9919 | final step : 98 | total reward : -2.0
# 2020/10/02 14:18:57
# episode : 9920 | final step : 201 | total reward : 202.0
# 2020/10/02 14:19:03
# episode : 9921 | final step : 201 | total reward : 202.0
# 2020/10/02 14:19:09
# episode : 9922 | final step : 201 | total reward : 202.0
# 2020/10/02 14:19:11
# episode : 9923 | final step : 98 | total reward : -2.0
# 2020/10/02 14:19:14
# episode : 9924 | final step : 98 | total reward : -2.0
# 2020/10/02 14:19:17
# episode : 9925 | final step : 98 | total reward : -2.0
# 2020/10/02 14:19:20
# episode : 9926 | final step : 98 | total reward : -2.0
# 2020/10/02 14:19:23
# episode : 9927 | final step : 98 | total reward : -2.0
# 2020/10/02 14:19:26
# episode : 9928 | final step : 98 | total reward : -2.0
# 2020/10/02 14:19:29
# episode : 9929 | final step : 98 | total reward : -2.0
# 2020/10/02 14:19:35
# episode : 9930 | final step : 201 | total reward : 202.0
# 2020/10/02 14:19:37
# episode : 9931 | final step : 100 | total reward : 0.0
# 2020/10/02 14:19:40
# episode : 9932 | final step : 99 | total reward : -1.0
# 2020/10/02 14:19:43
# episode : 9933 | final step : 98 | total reward : -2.0
# 2020/10/02 14:19:49
# episode : 9934 | final step : 201 | total reward : 202.0
# 2020/10/02 14:19:52
# episode : 9935 | final step : 98 | total reward : -2.0
# 2020/10/02 14:19:55
# episode : 9936 | final step : 98 | total reward : -2.0
# 2020/10/02 14:19:58
# episode : 9937 | final step : 98 | total reward : -2.0
# 2020/10/02 14:20:01
# episode : 9938 | final step : 98 | total reward : -2.0
# 2020/10/02 14:20:04
# episode : 9939 | final step : 99 | total reward : -1.0
# 2020/10/02 14:20:07
# episode : 9940 | final step : 98 | total reward : -2.0
# 2020/10/02 14:20:10
# episode : 9941 | final step : 99 | total reward : -1.0
# 2020/10/02 14:20:13
# episode : 9942 | final step : 98 | total reward : -2.0
# 2020/10/02 14:20:19
# episode : 9943 | final step : 201 | total reward : 202.0
# 2020/10/02 14:20:24
# episode : 9944 | final step : 201 | total reward : 202.0
# 2020/10/02 14:20:27
# episode : 9945 | final step : 98 | total reward : -2.0
# 2020/10/02 14:20:30
# episode : 9946 | final step : 99 | total reward : -1.0
# 2020/10/02 14:20:33
# episode : 9947 | final step : 98 | total reward : -2.0
# 2020/10/02 14:20:39
# episode : 9948 | final step : 201 | total reward : 202.0
# 2020/10/02 14:20:45
# episode : 9949 | final step : 201 | total reward : 202.0
# 2020/10/02 14:20:51
# episode : 9950 | final step : 201 | total reward : 202.0
# 2020/10/02 14:20:57
# episode : 9951 | final step : 201 | total reward : 202.0
# 2020/10/02 14:21:00
# episode : 9952 | final step : 98 | total reward : -2.0
# 2020/10/02 14:21:03
# episode : 9953 | final step : 99 | total reward : -1.0
# 2020/10/02 14:21:06
# episode : 9954 | final step : 99 | total reward : -1.0
# 2020/10/02 14:21:09
# episode : 9955 | final step : 99 | total reward : -1.0
# 2020/10/02 14:21:14
# episode : 9956 | final step : 201 | total reward : 202.0
# 2020/10/02 14:21:17
# episode : 9957 | final step : 99 | total reward : -1.0
# 2020/10/02 14:21:23
# episode : 9958 | final step : 201 | total reward : 202.0
# 2020/10/02 14:21:29
# episode : 9959 | final step : 201 | total reward : 202.0
# 2020/10/02 14:21:35
# episode : 9960 | final step : 201 | total reward : 202.0
# 2020/10/02 14:21:41
# episode : 9961 | final step : 201 | total reward : 202.0
# 2020/10/02 14:21:46
# episode : 9962 | final step : 201 | total reward : 202.0
# 2020/10/02 14:21:52
# episode : 9963 | final step : 201 | total reward : 202.0
# 2020/10/02 14:21:55
# episode : 9964 | final step : 100 | total reward : 0.0
# 2020/10/02 14:22:01
# episode : 9965 | final step : 201 | total reward : 202.0
# 2020/10/02 14:22:06
# episode : 9966 | final step : 201 | total reward : 202.0
# 2020/10/02 14:22:12
# episode : 9967 | final step : 201 | total reward : 202.0
# 2020/10/02 14:22:17
# episode : 9968 | final step : 201 | total reward : 202.0
# 2020/10/02 14:22:23
# episode : 9969 | final step : 201 | total reward : 202.0
# 2020/10/02 14:22:28
# episode : 9970 | final step : 201 | total reward : 202.0
# 2020/10/02 14:22:34
# episode : 9971 | final step : 201 | total reward : 202.0
# 2020/10/02 14:22:39
# episode : 9972 | final step : 201 | total reward : 202.0
# 2020/10/02 14:22:45
# episode : 9973 | final step : 201 | total reward : 202.0
# 2020/10/02 14:22:51
# episode : 9974 | final step : 201 | total reward : 202.0
# 2020/10/02 14:22:57
# episode : 9975 | final step : 201 | total reward : 202.0
# 2020/10/02 14:23:02
# episode : 9976 | final step : 201 | total reward : 202.0
# 2020/10/02 14:23:08
# episode : 9977 | final step : 201 | total reward : 202.0
# 2020/10/02 14:23:14
# episode : 9978 | final step : 201 | total reward : 202.0
# 2020/10/02 14:23:20
# episode : 9979 | final step : 201 | total reward : 202.0
# 2020/10/02 14:23:22
# episode : 9980 | final step : 99 | total reward : -1.0
# 2020/10/02 14:23:28
# episode : 9981 | final step : 201 | total reward : 202.0
# 2020/10/02 14:23:33
# episode : 9982 | final step : 201 | total reward : 202.0
# 2020/10/02 14:23:39
# episode : 9983 | final step : 201 | total reward : 202.0
# 2020/10/02 14:23:44
# episode : 9984 | final step : 201 | total reward : 202.0
# 2020/10/02 14:23:50
# episode : 9985 | final step : 201 | total reward : 202.0
# 2020/10/02 14:23:55
# episode : 9986 | final step : 201 | total reward : 202.0
# 2020/10/02 14:23:58
# episode : 9987 | final step : 100 | total reward : 0.0
# 2020/10/02 14:24:04
# episode : 9988 | final step : 201 | total reward : 202.0
# 2020/10/02 14:24:09
# episode : 9989 | final step : 201 | total reward : 202.0
# 2020/10/02 14:24:15
# episode : 9990 | final step : 201 | total reward : 202.0
# 2020/10/02 14:24:21
# episode : 9991 | final step : 201 | total reward : 202.0
# 2020/10/02 14:24:26
# episode : 9992 | final step : 201 | total reward : 202.0
# 2020/10/02 14:24:32
# episode : 9993 | final step : 201 | total reward : 202.0
# 2020/10/02 14:24:37
# episode : 9994 | final step : 201 | total reward : 202.0
# 2020/10/02 14:24:43
# episode : 9995 | final step : 201 | total reward : 202.0
# 2020/10/02 14:24:49
# episode : 9996 | final step : 201 | total reward : 202.0
# 2020/10/02 14:24:54
# episode : 9997 | final step : 201 | total reward : 202.0
# 2020/10/02 14:25:00
# episode : 9998 | final step : 201 | total reward : 202.0
# 2020/10/02 14:25:06
# episode : 9999 | final step : 201 | total reward : 202.0
# Complete

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(reward_list)

# %%
def moving_average(data,n):
    len_data=len(data)-n
    res_data=np.zeros(len_data)

    for i in range(len_data):
        res_data[i]=sum(data[i:i+n])/n
    return res_data

# %%
average_number=200
filtered_data=moving_average(reward_list,average_number)

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(filtered_data)

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[0]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[10]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[100]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[1000]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[9999]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()
