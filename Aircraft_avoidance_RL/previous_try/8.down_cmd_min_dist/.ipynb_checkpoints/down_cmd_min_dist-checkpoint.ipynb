# %%
import math, random

import gym
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd 
import torch.nn.functional as F

from common.layers import NoisyLinear
from common.replay_buffer import ReplayBuffer
import gym_Aircraft

from itertools import count
import time
import itertools
import matplotlib
import matplotlib.pyplot as plt

# %%
USE_CUDA = torch.cuda.is_available()
Variable = lambda *args, **kwargs: autograd.Variable(*args, **kwargs).cuda() if USE_CUDA else autograd.Variable(*args, **kwargs)

# %%
env_id = "acav-v0"
env = gym.make(env_id)
# Out:
# /home/jupyter-kunwoopark/.local/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
class RainbowDQN(nn.Module):
    def __init__(self, num_inputs, num_actions, num_atoms, Vmin, Vmax):
        super(RainbowDQN, self).__init__()
        
        self.num_inputs   = num_inputs
        self.num_actions  = num_actions
        self.num_atoms    = num_atoms
        self.Vmin         = Vmin
        self.Vmax         = Vmax
        
        self.linear1 = nn.Linear(num_inputs, 32)
        self.linear2 = nn.Linear(32, 64)
        
        self.noisy_value1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_value2 = NoisyLinear(64, self.num_atoms, use_cuda=USE_CUDA)
        
        self.noisy_advantage1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_advantage2 = NoisyLinear(64, self.num_atoms * self.num_actions, use_cuda=USE_CUDA)
        
    def forward(self, x):
        batch_size = x.size(0)
        
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        
        value = F.relu(self.noisy_value1(x))
        value = self.noisy_value2(value)
        
        advantage = F.relu(self.noisy_advantage1(x))
        advantage = self.noisy_advantage2(advantage)
        
        value     = value.view(batch_size, 1, self.num_atoms)
        advantage = advantage.view(batch_size, self.num_actions, self.num_atoms)
        
        x = value + advantage - advantage.mean(1, keepdim=True)
        x = F.softmax(x.view(-1, self.num_atoms)).view(-1, self.num_actions, self.num_atoms)
        
        return x
        
    def reset_noise(self):
        self.noisy_value1.reset_noise()
        self.noisy_value2.reset_noise()
        self.noisy_advantage1.reset_noise()
        self.noisy_advantage2.reset_noise()
    
    def act(self, state):
        state = Variable(torch.FloatTensor(state).unsqueeze(0), volatile=True)
        dist = self.forward(state).data.cpu()
        dist = dist * torch.linspace(self.Vmin, self.Vmax, self.num_atoms)
        action = dist.sum(2).max(1)[1].numpy()[0]
        return action

# %%
num_atoms = 51
Vmin = -10
Vmax = 10

current_model = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)
target_model  = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)

if USE_CUDA:
    current_model = current_model.cuda()
    target_model  = target_model.cuda()
    
optimizer = optim.Adam(current_model.parameters(), 0.001)

replay_buffer = ReplayBuffer(10000)

# %%
def update_target(current_model, target_model):
    target_model.load_state_dict(current_model.state_dict())
    
update_target(current_model, target_model)

# %%
def projection_distribution(next_state, rewards, dones):
    batch_size  = next_state.size(0)
    
    delta_z = float(Vmax - Vmin) / (num_atoms - 1)
    support = torch.linspace(Vmin, Vmax, num_atoms)
    
    next_dist   = target_model(next_state).data.cpu() * support
    next_action = next_dist.sum(2).max(1)[1]
    next_action = next_action.unsqueeze(1).unsqueeze(1).expand(next_dist.size(0), 1, next_dist.size(2))
    next_dist   = next_dist.gather(1, next_action).squeeze(1)
        
    rewards = rewards.unsqueeze(1).expand_as(next_dist)
    dones   = dones.unsqueeze(1).expand_as(next_dist)
    support = support.unsqueeze(0).expand_as(next_dist)
    
    Tz = rewards + (1 - dones) * 0.99 * support
    Tz = Tz.clamp(min=Vmin, max=Vmax)
    b  = (Tz - Vmin) / delta_z
    l  = b.floor().long()
    u  = b.ceil().long()
        
    offset = torch.linspace(0, (batch_size - 1) * num_atoms, batch_size).long()\
                    .unsqueeze(1).expand(batch_size, num_atoms)

    proj_dist = torch.zeros(next_dist.size())    
    proj_dist.view(-1).index_add_(0, (l + offset).view(-1), (next_dist * (u.float() - b)).view(-1))
    proj_dist.view(-1).index_add_(0, (u + offset).view(-1), (next_dist * (b - l.float())).view(-1))
        
    return proj_dist

# %%
def compute_td_loss(batch_size):
    state, action, reward, next_state, done = replay_buffer.sample(batch_size) 

    state      = Variable(torch.FloatTensor(np.float32(state)))
    next_state = Variable(torch.FloatTensor(np.float32(next_state)), volatile=True)
    action     = Variable(torch.LongTensor(action))
    reward     = torch.FloatTensor(reward)
    done       = torch.FloatTensor(np.float32(done))

    proj_dist = projection_distribution(next_state, reward, done)
    
    dist = current_model(state)
    action = action.unsqueeze(1).unsqueeze(1).expand(batch_size, 1, num_atoms)
    dist = dist.gather(1, action).squeeze(1)
    dist.data.clamp_(0.01, 0.99)
    loss = -(Variable(proj_dist) * dist.log()).sum(1)
    loss  = loss.mean()
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    current_model.reset_noise()
    target_model.reset_noise()
    
    return loss

# %%
num_episodes = 1000
batch_size = 32
gamma=0.99
TARGET_UPDATE=10

losses = []
total_res=[]
reward_list=[]
for i_episode in range(num_episodes):
    total_reward=0
    
    # 환경과 상태 초기화
    res_list=np.zeros(11)
    state = env.reset()

    for t in count():
        # 행동 선택과 수행
        
        action = current_model.act(state)
        
        next_state, reward, done, res = env.step(action)
        
        # 메모리에 변이 저장
        replay_buffer.push(state, action, reward, next_state, done)
        

        # 새로운 상태 관찰
        if not done:
            next_state = next_state
        else:
            next_state = None

        

        # 다음 상태로 이동
        state = next_state

     
        # Data save
        
        cmd_list,r_list,elev_list,azim_list,Pm_list,Pt_list,h_list=res
        Pm_list=Pm_list.tolist()
        Pt_list=Pt_list.tolist()
        merged_data=itertools.chain([cmd_list],[r_list],[elev_list],[azim_list],Pm_list,Pt_list,[h_list])
        merged_data=np.array(list(merged_data))
        res_list=np.vstack([res_list,merged_data])
        
        total_reward+=reward
        
        if done:
            res_list=np.delete(res_list,0,0)
            
            total_res.append(res_list)
            reward_list.append(total_reward)
            
            now = time.localtime()
            print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))
            print("episode : {} | final step : {} | total reward : {}".format(i_episode, t, total_reward))
            break
        if len(replay_buffer) > batch_size:
            loss = compute_td_loss(batch_size)
            losses.append(loss.item())
            
        
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        update_target(current_model, target_model)

print('Complete')
env.close()
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 2020/10/02 20:06:28
# episode : 0 | final step : 98 | total reward : -1
# 2020/10/02 20:06:29
# episode : 1 | final step : 99 | total reward : 0
# 2020/10/02 20:06:30
# episode : 2 | final step : 98 | total reward : -1
# 2020/10/02 20:06:31
# episode : 3 | final step : 99 | total reward : -1
# 2020/10/02 20:06:32
# episode : 4 | final step : 93 | total reward : 0
# 2020/10/02 20:06:33
# episode : 5 | final step : 99 | total reward : 0
# 2020/10/02 20:06:33
# episode : 6 | final step : 88 | total reward : 0
# 2020/10/02 20:06:34
# episode : 7 | final step : 96 | total reward : 0
# 2020/10/02 20:06:35
# episode : 8 | final step : 99 | total reward : -1
# 2020/10/02 20:06:36
# episode : 9 | final step : 99 | total reward : -1
# 2020/10/02 20:06:37
# episode : 10 | final step : 99 | total reward : 0
# 2020/10/02 20:06:38
# episode : 11 | final step : 97 | total reward : 0
# 2020/10/02 20:06:39
# episode : 12 | final step : 99 | total reward : -1
# 2020/10/02 20:06:40
# episode : 13 | final step : 100 | total reward : 0
# 2020/10/02 20:06:41
# episode : 14 | final step : 100 | total reward : 0
# 2020/10/02 20:06:42
# episode : 15 | final step : 99 | total reward : 0
# 2020/10/02 20:06:43
# episode : 16 | final step : 98 | total reward : 0
# 2020/10/02 20:06:44
# episode : 17 | final step : 99 | total reward : -1
# 2020/10/02 20:06:44
# episode : 18 | final step : 97 | total reward : 0
# 2020/10/02 20:06:45
# episode : 19 | final step : 99 | total reward : 0
# 2020/10/02 20:06:46
# episode : 20 | final step : 98 | total reward : -1
# 2020/10/02 20:06:47
# episode : 21 | final step : 94 | total reward : 0
# 2020/10/02 20:06:48
# episode : 22 | final step : 99 | total reward : -1
# 2020/10/02 20:06:49
# episode : 23 | final step : 98 | total reward : 0
# 2020/10/02 20:06:49
# episode : 24 | final step : 96 | total reward : 0
# 2020/10/02 20:06:50
# episode : 25 | final step : 95 | total reward : 0
# 2020/10/02 20:06:51
# episode : 26 | final step : 98 | total reward : -1
# 2020/10/02 20:06:52
# episode : 27 | final step : 98 | total reward : -1
# 2020/10/02 20:06:53
# episode : 28 | final step : 97 | total reward : 0
# 2020/10/02 20:06:54
# episode : 29 | final step : 100 | total reward : 0
# 2020/10/02 20:06:55
# episode : 30 | final step : 97 | total reward : 0
# 2020/10/02 20:06:55
# episode : 31 | final step : 100 | total reward : 0
# 2020/10/02 20:06:56
# episode : 32 | final step : 101 | total reward : 0
# 2020/10/02 20:06:57
# episode : 33 | final step : 99 | total reward : 0
# 2020/10/02 20:06:58
# episode : 34 | final step : 98 | total reward : 0
# 2020/10/02 20:06:59
# episode : 35 | final step : 93 | total reward : 0
# 2020/10/02 20:07:00
# episode : 36 | final step : 99 | total reward : 0
# 2020/10/02 20:07:01
# episode : 37 | final step : 100 | total reward : 0
# 2020/10/02 20:07:02
# episode : 38 | final step : 99 | total reward : 0
# 2020/10/02 20:07:03
# episode : 39 | final step : 96 | total reward : 0
# 2020/10/02 20:07:03
# episode : 40 | final step : 96 | total reward : 0
# 2020/10/02 20:07:04
# episode : 41 | final step : 93 | total reward : 0
# 2020/10/02 20:07:05
# episode : 42 | final step : 100 | total reward : 0
# 2020/10/02 20:07:06
# episode : 43 | final step : 100 | total reward : 0
# 2020/10/02 20:07:07
# episode : 44 | final step : 92 | total reward : 0
# 2020/10/02 20:07:08
# episode : 45 | final step : 100 | total reward : 0
# 2020/10/02 20:07:09
# episode : 46 | final step : 100 | total reward : 0
# 2020/10/02 20:07:10
# episode : 47 | final step : 100 | total reward : 0
# 2020/10/02 20:07:11
# episode : 48 | final step : 99 | total reward : 0
# 2020/10/02 20:07:12
# episode : 49 | final step : 100 | total reward : 0
# 2020/10/02 20:07:13
# episode : 50 | final step : 99 | total reward : 0
# 2020/10/02 20:07:13
# episode : 51 | final step : 99 | total reward : -1
# 2020/10/02 20:07:14
# episode : 52 | final step : 101 | total reward : 0
# 2020/10/02 20:07:15
# episode : 53 | final step : 99 | total reward : 0
# 2020/10/02 20:07:16
# episode : 54 | final step : 98 | total reward : -1
# 2020/10/02 20:07:17
# episode : 55 | final step : 97 | total reward : 0
# 2020/10/02 20:07:18
# episode : 56 | final step : 99 | total reward : -1
# 2020/10/02 20:07:19
# episode : 57 | final step : 98 | total reward : 0
# 2020/10/02 20:07:20
# episode : 58 | final step : 100 | total reward : 0
# 2020/10/02 20:07:21
# episode : 59 | final step : 98 | total reward : -1
# 2020/10/02 20:07:22
# episode : 60 | final step : 100 | total reward : 0
# 2020/10/02 20:07:23
# episode : 61 | final step : 99 | total reward : 0
# 2020/10/02 20:07:24
# episode : 62 | final step : 98 | total reward : 0
# 2020/10/02 20:07:24
# episode : 63 | final step : 99 | total reward : 0
# 2020/10/02 20:07:25
# episode : 64 | final step : 96 | total reward : 0
# 2020/10/02 20:07:26
# episode : 65 | final step : 100 | total reward : 0
# 2020/10/02 20:07:27
# episode : 66 | final step : 99 | total reward : 0
# 2020/10/02 20:07:28
# episode : 67 | final step : 100 | total reward : 0
# 2020/10/02 20:07:29
# episode : 68 | final step : 99 | total reward : -1
# 2020/10/02 20:07:30
# episode : 69 | final step : 98 | total reward : -1
# 2020/10/02 20:07:31
# episode : 70 | final step : 95 | total reward : 0
# 2020/10/02 20:07:32
# episode : 71 | final step : 100 | total reward : 0
# 2020/10/02 20:07:33
# episode : 72 | final step : 98 | total reward : -1
# 2020/10/02 20:07:33
# episode : 73 | final step : 98 | total reward : -1
# 2020/10/02 20:07:34
# episode : 74 | final step : 100 | total reward : 0
# 2020/10/02 20:07:35
# episode : 75 | final step : 99 | total reward : -1
# 2020/10/02 20:07:36
# episode : 76 | final step : 99 | total reward : -1
# 2020/10/02 20:07:37
# episode : 77 | final step : 98 | total reward : -1
# 2020/10/02 20:07:38
# episode : 78 | final step : 98 | total reward : -1
# 2020/10/02 20:07:39
# episode : 79 | final step : 97 | total reward : 0
# 2020/10/02 20:07:40
# episode : 80 | final step : 96 | total reward : 0
# 2020/10/02 20:07:41
# episode : 81 | final step : 98 | total reward : -1
# 2020/10/02 20:07:42
# episode : 82 | final step : 98 | total reward : -1
# 2020/10/02 20:07:42
# episode : 83 | final step : 98 | total reward : 0
# 2020/10/02 20:07:43
# episode : 84 | final step : 98 | total reward : 0
# 2020/10/02 20:07:44
# episode : 85 | final step : 97 | total reward : 0
# 2020/10/02 20:07:45
# episode : 86 | final step : 96 | total reward : 0
# 2020/10/02 20:07:46
# episode : 87 | final step : 96 | total reward : 0
# 2020/10/02 20:07:47
# episode : 88 | final step : 99 | total reward : -1
# 2020/10/02 20:07:48
# episode : 89 | final step : 97 | total reward : 0
# 2020/10/02 20:07:48
# episode : 90 | final step : 98 | total reward : -1
# 2020/10/02 20:07:49
# episode : 91 | final step : 100 | total reward : 0
# 2020/10/02 20:07:50
# episode : 92 | final step : 97 | total reward : 0
# 2020/10/02 20:07:51
# episode : 93 | final step : 98 | total reward : 0
# 2020/10/02 20:07:52
# episode : 94 | final step : 100 | total reward : 0
# 2020/10/02 20:07:53
# episode : 95 | final step : 99 | total reward : -1
# 2020/10/02 20:07:54
# episode : 96 | final step : 99 | total reward : 0
# 2020/10/02 20:07:55
# episode : 97 | final step : 98 | total reward : 0
# 2020/10/02 20:07:56
# episode : 98 | final step : 99 | total reward : 0
# 2020/10/02 20:07:57
# episode : 99 | final step : 101 | total reward : 0
# 2020/10/02 20:07:58
# episode : 100 | final step : 101 | total reward : 0
# 2020/10/02 20:07:59
# episode : 101 | final step : 98 | total reward : -1
# 2020/10/02 20:07:59
# episode : 102 | final step : 99 | total reward : -1
# 2020/10/02 20:08:00
# episode : 103 | final step : 95 | total reward : 0
# 2020/10/02 20:08:01
# episode : 104 | final step : 95 | total reward : 0
# 2020/10/02 20:08:02
# episode : 105 | final step : 97 | total reward : 0
# 2020/10/02 20:08:03
# episode : 106 | final step : 95 | total reward : 0
# 2020/10/02 20:08:04
# episode : 107 | final step : 99 | total reward : 0
# 2020/10/02 20:08:05
# episode : 108 | final step : 100 | total reward : 0
# 2020/10/02 20:08:06
# episode : 109 | final step : 99 | total reward : 0
# 2020/10/02 20:08:07
# episode : 110 | final step : 98 | total reward : 0
# 2020/10/02 20:08:08
# episode : 111 | final step : 97 | total reward : 0
# 2020/10/02 20:08:09
# episode : 112 | final step : 100 | total reward : 0
# 2020/10/02 20:08:09
# episode : 113 | final step : 100 | total reward : 0
# 2020/10/02 20:08:10
# episode : 114 | final step : 100 | total reward : 0
# 2020/10/02 20:08:11
# episode : 115 | final step : 99 | total reward : 0
# 2020/10/02 20:08:12
# episode : 116 | final step : 99 | total reward : 0
# 2020/10/02 20:08:13
# episode : 117 | final step : 99 | total reward : 0
# 2020/10/02 20:08:14
# episode : 118 | final step : 100 | total reward : 0
# 2020/10/02 20:08:15
# episode : 119 | final step : 94 | total reward : 0
# 2020/10/02 20:08:16
# episode : 120 | final step : 94 | total reward : 0
# 2020/10/02 20:08:17
# episode : 121 | final step : 98 | total reward : -1
# 2020/10/02 20:08:18
# episode : 122 | final step : 98 | total reward : -1
# 2020/10/02 20:08:18
# episode : 123 | final step : 100 | total reward : 0
# 2020/10/02 20:08:19
# episode : 124 | final step : 95 | total reward : 0
# 2020/10/02 20:08:20
# episode : 125 | final step : 98 | total reward : 0
# 2020/10/02 20:08:21
# episode : 126 | final step : 100 | total reward : 0
# 2020/10/02 20:08:22
# episode : 127 | final step : 100 | total reward : 0
# 2020/10/02 20:08:23
# episode : 128 | final step : 87 | total reward : 0
# 2020/10/02 20:08:24
# episode : 129 | final step : 100 | total reward : 0
# 2020/10/02 20:08:24
# episode : 130 | final step : 98 | total reward : 0
# 2020/10/02 20:08:25
# episode : 131 | final step : 100 | total reward : 0
# 2020/10/02 20:08:26
# episode : 132 | final step : 98 | total reward : 0
# 2020/10/02 20:08:27
# episode : 133 | final step : 98 | total reward : -1
# 2020/10/02 20:08:28
# episode : 134 | final step : 98 | total reward : -1
# 2020/10/02 20:08:29
# episode : 135 | final step : 92 | total reward : 0
# 2020/10/02 20:08:30
# episode : 136 | final step : 98 | total reward : 0
# 2020/10/02 20:08:31
# episode : 137 | final step : 98 | total reward : 0
# 2020/10/02 20:08:32
# episode : 138 | final step : 98 | total reward : 0
# 2020/10/02 20:08:33
# episode : 139 | final step : 98 | total reward : -1
# 2020/10/02 20:08:34
# episode : 140 | final step : 100 | total reward : 0
# 2020/10/02 20:08:34
# episode : 141 | final step : 95 | total reward : 0
# 2020/10/02 20:08:35
# episode : 142 | final step : 99 | total reward : -1
# 2020/10/02 20:08:36
# episode : 143 | final step : 99 | total reward : -1
# 2020/10/02 20:08:37
# episode : 144 | final step : 95 | total reward : 0
# 2020/10/02 20:08:38
# episode : 145 | final step : 99 | total reward : 0
# 2020/10/02 20:08:39
# episode : 146 | final step : 99 | total reward : 0
# 2020/10/02 20:08:40
# episode : 147 | final step : 100 | total reward : 0
# 2020/10/02 20:08:41
# episode : 148 | final step : 99 | total reward : 0
# 2020/10/02 20:08:42
# episode : 149 | final step : 101 | total reward : 0
# 2020/10/02 20:08:43
# episode : 150 | final step : 100 | total reward : 0
# 2020/10/02 20:08:44
# episode : 151 | final step : 99 | total reward : 0
# 2020/10/02 20:08:44
# episode : 152 | final step : 95 | total reward : 0
# 2020/10/02 20:08:45
# episode : 153 | final step : 101 | total reward : 0
# 2020/10/02 20:08:46
# episode : 154 | final step : 97 | total reward : 0
# 2020/10/02 20:08:47
# episode : 155 | final step : 98 | total reward : -1
# 2020/10/02 20:08:48
# episode : 156 | final step : 97 | total reward : 0
# 2020/10/02 20:08:49
# episode : 157 | final step : 98 | total reward : -1
# 2020/10/02 20:08:50
# episode : 158 | final step : 99 | total reward : 0
# 2020/10/02 20:08:51
# episode : 159 | final step : 97 | total reward : 0
# 2020/10/02 20:08:51
# episode : 160 | final step : 98 | total reward : 0
# 2020/10/02 20:08:52
# episode : 161 | final step : 99 | total reward : -1
# 2020/10/02 20:08:53
# episode : 162 | final step : 97 | total reward : 0
# 2020/10/02 20:08:54
# episode : 163 | final step : 100 | total reward : 0
# 2020/10/02 20:08:55
# episode : 164 | final step : 98 | total reward : 0
# 2020/10/02 20:08:56
# episode : 165 | final step : 99 | total reward : 0
# 2020/10/02 20:08:57
# episode : 166 | final step : 98 | total reward : -1
# 2020/10/02 20:08:58
# episode : 167 | final step : 97 | total reward : 0
# 2020/10/02 20:08:59
# episode : 168 | final step : 100 | total reward : 0
# 2020/10/02 20:09:00
# episode : 169 | final step : 101 | total reward : 0
# 2020/10/02 20:09:01
# episode : 170 | final step : 100 | total reward : 0
# 2020/10/02 20:09:02
# episode : 171 | final step : 100 | total reward : 0
# 2020/10/02 20:09:03
# episode : 172 | final step : 98 | total reward : -1
# 2020/10/02 20:09:03
# episode : 173 | final step : 100 | total reward : 0
# 2020/10/02 20:09:04
# episode : 174 | final step : 98 | total reward : 0
# 2020/10/02 20:09:05
# episode : 175 | final step : 100 | total reward : 0
# 2020/10/02 20:09:06
# episode : 176 | final step : 98 | total reward : 0
# 2020/10/02 20:09:07
# episode : 177 | final step : 99 | total reward : 0
# 2020/10/02 20:09:08
# episode : 178 | final step : 98 | total reward : -1
# 2020/10/02 20:09:09
# episode : 179 | final step : 97 | total reward : -1
# 2020/10/02 20:09:10
# episode : 180 | final step : 98 | total reward : -1
# 2020/10/02 20:09:11
# episode : 181 | final step : 98 | total reward : -1
# 2020/10/02 20:09:12
# episode : 182 | final step : 100 | total reward : 0
# 2020/10/02 20:09:13
# episode : 183 | final step : 96 | total reward : 0
# 2020/10/02 20:09:13
# episode : 184 | final step : 98 | total reward : -1
# 2020/10/02 20:09:14
# episode : 185 | final step : 98 | total reward : 0
# 2020/10/02 20:09:15
# episode : 186 | final step : 96 | total reward : 0
# 2020/10/02 20:09:16
# episode : 187 | final step : 98 | total reward : 0
# 2020/10/02 20:09:17
# episode : 188 | final step : 99 | total reward : 0
# 2020/10/02 20:09:18
# episode : 189 | final step : 99 | total reward : -1
# 2020/10/02 20:09:19
# episode : 190 | final step : 98 | total reward : 0
# 2020/10/02 20:09:20
# episode : 191 | final step : 94 | total reward : 0
# 2020/10/02 20:09:21
# episode : 192 | final step : 92 | total reward : 0
# 2020/10/02 20:09:21
# episode : 193 | final step : 98 | total reward : -1
# 2020/10/02 20:09:22
# episode : 194 | final step : 100 | total reward : 0
# 2020/10/02 20:09:23
# episode : 195 | final step : 95 | total reward : 0
# 2020/10/02 20:09:24
# episode : 196 | final step : 100 | total reward : 0
# 2020/10/02 20:09:25
# episode : 197 | final step : 98 | total reward : 0
# 2020/10/02 20:09:26
# episode : 198 | final step : 98 | total reward : 0
# 2020/10/02 20:09:27
# episode : 199 | final step : 99 | total reward : 0
# 2020/10/02 20:09:28
# episode : 200 | final step : 98 | total reward : 0
# 2020/10/02 20:09:28
# episode : 201 | final step : 98 | total reward : 0
# 2020/10/02 20:09:29
# episode : 202 | final step : 100 | total reward : 0
# 2020/10/02 20:09:30
# episode : 203 | final step : 100 | total reward : 0
# 2020/10/02 20:09:31
# episode : 204 | final step : 98 | total reward : -1
# 2020/10/02 20:09:32
# episode : 205 | final step : 99 | total reward : 0
# 2020/10/02 20:09:33
# episode : 206 | final step : 99 | total reward : 0
# 2020/10/02 20:09:34
# episode : 207 | final step : 100 | total reward : 0
# 2020/10/02 20:09:35
# episode : 208 | final step : 99 | total reward : -1
# 2020/10/02 20:09:36
# episode : 209 | final step : 97 | total reward : 0
# 2020/10/02 20:09:37
# episode : 210 | final step : 95 | total reward : 0
# 2020/10/02 20:09:38
# episode : 211 | final step : 99 | total reward : 0
# 2020/10/02 20:09:39
# episode : 212 | final step : 98 | total reward : -1
# 2020/10/02 20:09:39
# episode : 213 | final step : 97 | total reward : 0
# 2020/10/02 20:09:40
# episode : 214 | final step : 99 | total reward : 0
# 2020/10/02 20:09:41
# episode : 215 | final step : 98 | total reward : -1
# 2020/10/02 20:09:42
# episode : 216 | final step : 99 | total reward : 0
# 2020/10/02 20:09:43
# episode : 217 | final step : 99 | total reward : -1
# 2020/10/02 20:09:44
# episode : 218 | final step : 98 | total reward : -1
# 2020/10/02 20:09:45
# episode : 219 | final step : 96 | total reward : 0
# 2020/10/02 20:09:46
# episode : 220 | final step : 98 | total reward : -1
# 2020/10/02 20:09:47
# episode : 221 | final step : 101 | total reward : 0
# 2020/10/02 20:09:47
# episode : 222 | final step : 100 | total reward : 0
# 2020/10/02 20:09:48
# episode : 223 | final step : 97 | total reward : 0
# 2020/10/02 20:09:49
# episode : 224 | final step : 100 | total reward : 0
# 2020/10/02 20:09:50
# episode : 225 | final step : 97 | total reward : 0
# 2020/10/02 20:09:51
# episode : 226 | final step : 99 | total reward : 0
# 2020/10/02 20:09:52
# episode : 227 | final step : 101 | total reward : 0
# 2020/10/02 20:09:53
# episode : 228 | final step : 98 | total reward : 0
# 2020/10/02 20:09:54
# episode : 229 | final step : 94 | total reward : 0
# 2020/10/02 20:09:55
# episode : 230 | final step : 101 | total reward : 0
# 2020/10/02 20:09:56
# episode : 231 | final step : 98 | total reward : 0
# 2020/10/02 20:09:57
# episode : 232 | final step : 98 | total reward : -1
# 2020/10/02 20:09:58
# episode : 233 | final step : 100 | total reward : 0
# 2020/10/02 20:09:58
# episode : 234 | final step : 97 | total reward : 0
# 2020/10/02 20:09:59
# episode : 235 | final step : 99 | total reward : 0
# 2020/10/02 20:10:00
# episode : 236 | final step : 100 | total reward : 0
# 2020/10/02 20:10:01
# episode : 237 | final step : 99 | total reward : 0
# 2020/10/02 20:10:02
# episode : 238 | final step : 97 | total reward : 0
# 2020/10/02 20:10:03
# episode : 239 | final step : 99 | total reward : 0
# 2020/10/02 20:10:04
# episode : 240 | final step : 98 | total reward : -1
# 2020/10/02 20:10:05
# episode : 241 | final step : 98 | total reward : -1
# 2020/10/02 20:10:06
# episode : 242 | final step : 98 | total reward : -1
# 2020/10/02 20:10:07
# episode : 243 | final step : 98 | total reward : -1
# 2020/10/02 20:10:08
# episode : 244 | final step : 100 | total reward : 0
# 2020/10/02 20:10:09
# episode : 245 | final step : 99 | total reward : 0
# 2020/10/02 20:10:09
# episode : 246 | final step : 99 | total reward : -1
# 2020/10/02 20:10:10
# episode : 247 | final step : 98 | total reward : -1
# 2020/10/02 20:10:11
# episode : 248 | final step : 91 | total reward : 0
# 2020/10/02 20:10:12
# episode : 249 | final step : 98 | total reward : 0
# 2020/10/02 20:10:13
# episode : 250 | final step : 100 | total reward : -1
# 2020/10/02 20:10:14
# episode : 251 | final step : 98 | total reward : -1
# 2020/10/02 20:10:15
# episode : 252 | final step : 100 | total reward : 0
# 2020/10/02 20:10:16
# episode : 253 | final step : 98 | total reward : 0
# 2020/10/02 20:10:17
# episode : 254 | final step : 100 | total reward : 0
# 2020/10/02 20:10:18
# episode : 255 | final step : 99 | total reward : 0
# 2020/10/02 20:10:19
# episode : 256 | final step : 99 | total reward : 0
# 2020/10/02 20:10:19
# episode : 257 | final step : 99 | total reward : -1
# 2020/10/02 20:10:20
# episode : 258 | final step : 99 | total reward : 0
# 2020/10/02 20:10:21
# episode : 259 | final step : 99 | total reward : 0
# 2020/10/02 20:10:22
# episode : 260 | final step : 99 | total reward : 0
# 2020/10/02 20:10:23
# episode : 261 | final step : 100 | total reward : 0
# 2020/10/02 20:10:24
# episode : 262 | final step : 98 | total reward : 0
# 2020/10/02 20:10:25
# episode : 263 | final step : 99 | total reward : 0
# 2020/10/02 20:10:26
# episode : 264 | final step : 98 | total reward : -1
# 2020/10/02 20:10:27
# episode : 265 | final step : 97 | total reward : 0
# 2020/10/02 20:10:27
# episode : 266 | final step : 98 | total reward : -1
# 2020/10/02 20:10:28
# episode : 267 | final step : 100 | total reward : 0
# 2020/10/02 20:10:29
# episode : 268 | final step : 98 | total reward : -1
# 2020/10/02 20:10:30
# episode : 269 | final step : 100 | total reward : 0
# 2020/10/02 20:10:31
# episode : 270 | final step : 98 | total reward : -1
# 2020/10/02 20:10:32
# episode : 271 | final step : 95 | total reward : 0
# 2020/10/02 20:10:33
# episode : 272 | final step : 98 | total reward : -1
# 2020/10/02 20:10:34
# episode : 273 | final step : 100 | total reward : 0
# 2020/10/02 20:10:35
# episode : 274 | final step : 99 | total reward : -1
# 2020/10/02 20:10:36
# episode : 275 | final step : 99 | total reward : 0
# 2020/10/02 20:10:37
# episode : 276 | final step : 100 | total reward : 0
# 2020/10/02 20:10:37
# episode : 277 | final step : 102 | total reward : 0
# 2020/10/02 20:10:38
# episode : 278 | final step : 98 | total reward : -1
# 2020/10/02 20:10:39
# episode : 279 | final step : 98 | total reward : -1
# 2020/10/02 20:10:40
# episode : 280 | final step : 98 | total reward : 0
# 2020/10/02 20:10:41
# episode : 281 | final step : 93 | total reward : 0
# 2020/10/02 20:10:42
# episode : 282 | final step : 96 | total reward : 0
# 2020/10/02 20:10:43
# episode : 283 | final step : 98 | total reward : 0
# 2020/10/02 20:10:44
# episode : 284 | final step : 100 | total reward : 0
# 2020/10/02 20:10:45
# episode : 285 | final step : 98 | total reward : 0
# 2020/10/02 20:10:45
# episode : 286 | final step : 98 | total reward : -1
# 2020/10/02 20:10:46
# episode : 287 | final step : 99 | total reward : 0
# 2020/10/02 20:10:47
# episode : 288 | final step : 99 | total reward : -1
# 2020/10/02 20:10:48
# episode : 289 | final step : 98 | total reward : -1
# 2020/10/02 20:10:49
# episode : 290 | final step : 99 | total reward : 0
# 2020/10/02 20:10:50
# episode : 291 | final step : 99 | total reward : 0
# 2020/10/02 20:10:51
# episode : 292 | final step : 99 | total reward : 0
# 2020/10/02 20:10:52
# episode : 293 | final step : 90 | total reward : 0
# 2020/10/02 20:10:53
# episode : 294 | final step : 100 | total reward : 0
# 2020/10/02 20:10:53
# episode : 295 | final step : 101 | total reward : 0
# 2020/10/02 20:10:54
# episode : 296 | final step : 99 | total reward : 0
# 2020/10/02 20:10:55
# episode : 297 | final step : 98 | total reward : -1
# 2020/10/02 20:10:56
# episode : 298 | final step : 99 | total reward : 0
# 2020/10/02 20:10:57
# episode : 299 | final step : 101 | total reward : 0
# 2020/10/02 20:10:58
# episode : 300 | final step : 98 | total reward : -1
# 2020/10/02 20:10:59
# episode : 301 | final step : 99 | total reward : 0
# 2020/10/02 20:10:59
# episode : 302 | final step : 96 | total reward : 0
# 2020/10/02 20:11:00
# episode : 303 | final step : 98 | total reward : 0
# 2020/10/02 20:11:01
# episode : 304 | final step : 99 | total reward : -1
# 2020/10/02 20:11:02
# episode : 305 | final step : 99 | total reward : -1
# 2020/10/02 20:11:03
# episode : 306 | final step : 98 | total reward : 0
# 2020/10/02 20:11:04
# episode : 307 | final step : 93 | total reward : 0
# 2020/10/02 20:11:05
# episode : 308 | final step : 99 | total reward : 0
# 2020/10/02 20:11:06
# episode : 309 | final step : 94 | total reward : 0
# 2020/10/02 20:11:06
# episode : 310 | final step : 98 | total reward : -1
# 2020/10/02 20:11:07
# episode : 311 | final step : 98 | total reward : 0
# 2020/10/02 20:11:08
# episode : 312 | final step : 98 | total reward : -1
# 2020/10/02 20:11:09
# episode : 313 | final step : 99 | total reward : -1
# 2020/10/02 20:11:10
# episode : 314 | final step : 99 | total reward : 0
# 2020/10/02 20:11:11
# episode : 315 | final step : 99 | total reward : -1
# 2020/10/02 20:11:12
# episode : 316 | final step : 98 | total reward : 0
# 2020/10/02 20:11:13
# episode : 317 | final step : 97 | total reward : 0
# 2020/10/02 20:11:14
# episode : 318 | final step : 99 | total reward : -1
# 2020/10/02 20:11:15
# episode : 319 | final step : 98 | total reward : 0
# 2020/10/02 20:11:15
# episode : 320 | final step : 97 | total reward : 0
# 2020/10/02 20:11:16
# episode : 321 | final step : 98 | total reward : 0
# 2020/10/02 20:11:17
# episode : 322 | final step : 99 | total reward : -1
# 2020/10/02 20:11:18
# episode : 323 | final step : 98 | total reward : 0
# 2020/10/02 20:11:19
# episode : 324 | final step : 99 | total reward : 0
# 2020/10/02 20:11:20
# episode : 325 | final step : 100 | total reward : 0
# 2020/10/02 20:11:21
# episode : 326 | final step : 98 | total reward : 0
# 2020/10/02 20:11:22
# episode : 327 | final step : 98 | total reward : -1
# 2020/10/02 20:11:23
# episode : 328 | final step : 95 | total reward : 0
# 2020/10/02 20:11:24
# episode : 329 | final step : 99 | total reward : 0
# 2020/10/02 20:11:25
# episode : 330 | final step : 97 | total reward : 0
# 2020/10/02 20:11:26
# episode : 331 | final step : 101 | total reward : 0
# 2020/10/02 20:11:26
# episode : 332 | final step : 97 | total reward : 0
# 2020/10/02 20:11:27
# episode : 333 | final step : 98 | total reward : -1
# 2020/10/02 20:11:28
# episode : 334 | final step : 98 | total reward : -1
# 2020/10/02 20:11:29
# episode : 335 | final step : 97 | total reward : 0
# 2020/10/02 20:11:30
# episode : 336 | final step : 98 | total reward : 0
# 2020/10/02 20:11:31
# episode : 337 | final step : 98 | total reward : 0
# 2020/10/02 20:11:32
# episode : 338 | final step : 97 | total reward : 0
# 2020/10/02 20:11:33
# episode : 339 | final step : 98 | total reward : 0
# 2020/10/02 20:11:34
# episode : 340 | final step : 90 | total reward : 0
# 2020/10/02 20:11:35
# episode : 341 | final step : 96 | total reward : 0
# 2020/10/02 20:11:36
# episode : 342 | final step : 99 | total reward : 0
# 2020/10/02 20:11:36
# episode : 343 | final step : 100 | total reward : 0
# 2020/10/02 20:11:37
# episode : 344 | final step : 99 | total reward : 0
# 2020/10/02 20:11:38
# episode : 345 | final step : 100 | total reward : 0
# 2020/10/02 20:11:39
# episode : 346 | final step : 98 | total reward : 0
# 2020/10/02 20:11:40
# episode : 347 | final step : 100 | total reward : 0
# 2020/10/02 20:11:41
# episode : 348 | final step : 100 | total reward : 0
# 2020/10/02 20:11:42
# episode : 349 | final step : 98 | total reward : -1
# 2020/10/02 20:11:43
# episode : 350 | final step : 100 | total reward : 0
# 2020/10/02 20:11:44
# episode : 351 | final step : 99 | total reward : -1
# 2020/10/02 20:11:45
# episode : 352 | final step : 96 | total reward : 0
# 2020/10/02 20:11:46
# episode : 353 | final step : 99 | total reward : 0
# 2020/10/02 20:11:47
# episode : 354 | final step : 99 | total reward : 0
# 2020/10/02 20:11:47
# episode : 355 | final step : 100 | total reward : 0
# 2020/10/02 20:11:48
# episode : 356 | final step : 99 | total reward : 0
# 2020/10/02 20:11:49
# episode : 357 | final step : 99 | total reward : 0
# 2020/10/02 20:11:50
# episode : 358 | final step : 99 | total reward : 0
# 2020/10/02 20:11:51
# episode : 359 | final step : 99 | total reward : 0
# 2020/10/02 20:11:52
# episode : 360 | final step : 96 | total reward : 0
# 2020/10/02 20:11:53
# episode : 361 | final step : 98 | total reward : 0
# 2020/10/02 20:11:54
# episode : 362 | final step : 98 | total reward : -1
# 2020/10/02 20:11:55
# episode : 363 | final step : 99 | total reward : 0
# 2020/10/02 20:11:56
# episode : 364 | final step : 95 | total reward : 0
# 2020/10/02 20:11:57
# episode : 365 | final step : 100 | total reward : 0
# 2020/10/02 20:11:58
# episode : 366 | final step : 99 | total reward : 0
# 2020/10/02 20:11:58
# episode : 367 | final step : 98 | total reward : 0
# 2020/10/02 20:11:59
# episode : 368 | final step : 99 | total reward : 0
# 2020/10/02 20:12:00
# episode : 369 | final step : 98 | total reward : -1
# 2020/10/02 20:12:01
# episode : 370 | final step : 98 | total reward : -1
# 2020/10/02 20:12:02
# episode : 371 | final step : 96 | total reward : 0
# 2020/10/02 20:12:03
# episode : 372 | final step : 98 | total reward : -1
# 2020/10/02 20:12:04
# episode : 373 | final step : 101 | total reward : 0
# 2020/10/02 20:12:05
# episode : 374 | final step : 98 | total reward : -1
# 2020/10/02 20:12:06
# episode : 375 | final step : 98 | total reward : 0
# 2020/10/02 20:12:07
# episode : 376 | final step : 98 | total reward : 0
# 2020/10/02 20:12:08
# episode : 377 | final step : 99 | total reward : 0
# 2020/10/02 20:12:09
# episode : 378 | final step : 101 | total reward : 0
# 2020/10/02 20:12:09
# episode : 379 | final step : 97 | total reward : 0
# 2020/10/02 20:12:10
# episode : 380 | final step : 99 | total reward : 0
# 2020/10/02 20:12:11
# episode : 381 | final step : 100 | total reward : 0
# 2020/10/02 20:12:12
# episode : 382 | final step : 99 | total reward : -1
# 2020/10/02 20:12:13
# episode : 383 | final step : 96 | total reward : 0
# 2020/10/02 20:12:14
# episode : 384 | final step : 96 | total reward : 0
# 2020/10/02 20:12:15
# episode : 385 | final step : 100 | total reward : 0
# 2020/10/02 20:12:16
# episode : 386 | final step : 100 | total reward : 0
# 2020/10/02 20:12:17
# episode : 387 | final step : 98 | total reward : -1
# 2020/10/02 20:12:18
# episode : 388 | final step : 99 | total reward : 0
# 2020/10/02 20:12:19
# episode : 389 | final step : 99 | total reward : 0
# 2020/10/02 20:12:19
# episode : 390 | final step : 101 | total reward : 0
# 2020/10/02 20:12:20
# episode : 391 | final step : 99 | total reward : 0
# 2020/10/02 20:12:21
# episode : 392 | final step : 100 | total reward : 0
# 2020/10/02 20:12:22
# episode : 393 | final step : 96 | total reward : 0
# 2020/10/02 20:12:23
# episode : 394 | final step : 100 | total reward : -1
# 2020/10/02 20:12:24
# episode : 395 | final step : 99 | total reward : 0
# 2020/10/02 20:12:25
# episode : 396 | final step : 98 | total reward : -1
# 2020/10/02 20:12:26
# episode : 397 | final step : 95 | total reward : 0
# 2020/10/02 20:12:26
# episode : 398 | final step : 97 | total reward : -1
# 2020/10/02 20:12:27
# episode : 399 | final step : 97 | total reward : 0
# 2020/10/02 20:12:28
# episode : 400 | final step : 97 | total reward : 0
# 2020/10/02 20:12:29
# episode : 401 | final step : 98 | total reward : 0
# 2020/10/02 20:12:30
# episode : 402 | final step : 97 | total reward : 0
# 2020/10/02 20:12:31
# episode : 403 | final step : 99 | total reward : 0
# 2020/10/02 20:12:32
# episode : 404 | final step : 101 | total reward : 0
# 2020/10/02 20:12:33
# episode : 405 | final step : 98 | total reward : 0
# 2020/10/02 20:12:34
# episode : 406 | final step : 98 | total reward : -1
# 2020/10/02 20:12:34
# episode : 407 | final step : 97 | total reward : 0
# 2020/10/02 20:12:35
# episode : 408 | final step : 98 | total reward : -1
# 2020/10/02 20:12:36
# episode : 409 | final step : 100 | total reward : 0
# 2020/10/02 20:12:37
# episode : 410 | final step : 100 | total reward : 0
# 2020/10/02 20:12:38
# episode : 411 | final step : 100 | total reward : 0
# 2020/10/02 20:12:39
# episode : 412 | final step : 97 | total reward : 0
# 2020/10/02 20:12:40
# episode : 413 | final step : 96 | total reward : 0
# 2020/10/02 20:12:41
# episode : 414 | final step : 99 | total reward : 0
# 2020/10/02 20:12:41
# episode : 415 | final step : 98 | total reward : -1
# 2020/10/02 20:12:42
# episode : 416 | final step : 100 | total reward : 0
# 2020/10/02 20:12:43
# episode : 417 | final step : 97 | total reward : 0
# 2020/10/02 20:12:44
# episode : 418 | final step : 96 | total reward : 0
# 2020/10/02 20:12:45
# episode : 419 | final step : 97 | total reward : 0
# 2020/10/02 20:12:46
# episode : 420 | final step : 98 | total reward : 0
# 2020/10/02 20:12:47
# episode : 421 | final step : 98 | total reward : 0
# 2020/10/02 20:12:48
# episode : 422 | final step : 100 | total reward : 0
# 2020/10/02 20:12:49
# episode : 423 | final step : 98 | total reward : -1
# 2020/10/02 20:12:50
# episode : 424 | final step : 98 | total reward : -1
# 2020/10/02 20:12:50
# episode : 425 | final step : 95 | total reward : 0
# 2020/10/02 20:12:51
# episode : 426 | final step : 100 | total reward : 0
# 2020/10/02 20:12:52
# episode : 427 | final step : 100 | total reward : 0
# 2020/10/02 20:12:53
# episode : 428 | final step : 99 | total reward : 0
# 2020/10/02 20:12:54
# episode : 429 | final step : 98 | total reward : 0
# 2020/10/02 20:12:55
# episode : 430 | final step : 97 | total reward : 0
# 2020/10/02 20:12:56
# episode : 431 | final step : 97 | total reward : 0
# 2020/10/02 20:12:56
# episode : 432 | final step : 99 | total reward : -1
# 2020/10/02 20:12:57
# episode : 433 | final step : 98 | total reward : 0
# 2020/10/02 20:12:58
# episode : 434 | final step : 100 | total reward : 0
# 2020/10/02 20:12:59
# episode : 435 | final step : 98 | total reward : 0
# 2020/10/02 20:13:00
# episode : 436 | final step : 99 | total reward : 0
# 2020/10/02 20:13:01
# episode : 437 | final step : 98 | total reward : 0
# 2020/10/02 20:13:02
# episode : 438 | final step : 99 | total reward : -1
# 2020/10/02 20:13:03
# episode : 439 | final step : 98 | total reward : 0
# 2020/10/02 20:13:03
# episode : 440 | final step : 99 | total reward : -1
# 2020/10/02 20:13:04
# episode : 441 | final step : 100 | total reward : 0
# 2020/10/02 20:13:05
# episode : 442 | final step : 99 | total reward : -1
# 2020/10/02 20:13:06
# episode : 443 | final step : 100 | total reward : 0
# 2020/10/02 20:13:07
# episode : 444 | final step : 100 | total reward : 0
# 2020/10/02 20:13:08
# episode : 445 | final step : 97 | total reward : 0
# 2020/10/02 20:13:09
# episode : 446 | final step : 100 | total reward : 0
# 2020/10/02 20:13:10
# episode : 447 | final step : 100 | total reward : -1
# 2020/10/02 20:13:11
# episode : 448 | final step : 100 | total reward : 0
# 2020/10/02 20:13:12
# episode : 449 | final step : 99 | total reward : 0
# 2020/10/02 20:13:13
# episode : 450 | final step : 99 | total reward : -1
# 2020/10/02 20:13:14
# episode : 451 | final step : 100 | total reward : 0
# 2020/10/02 20:13:15
# episode : 452 | final step : 97 | total reward : 0
# 2020/10/02 20:13:16
# episode : 453 | final step : 99 | total reward : 0
# 2020/10/02 20:13:16
# episode : 454 | final step : 98 | total reward : 0
# 2020/10/02 20:13:17
# episode : 455 | final step : 98 | total reward : 0
# 2020/10/02 20:13:18
# episode : 456 | final step : 99 | total reward : 0
# 2020/10/02 20:13:19
# episode : 457 | final step : 99 | total reward : -1
# 2020/10/02 20:13:20
# episode : 458 | final step : 98 | total reward : 0
# 2020/10/02 20:13:21
# episode : 459 | final step : 102 | total reward : 0
# 2020/10/02 20:13:22
# episode : 460 | final step : 99 | total reward : 0
# 2020/10/02 20:13:23
# episode : 461 | final step : 100 | total reward : 0
# 2020/10/02 20:13:24
# episode : 462 | final step : 98 | total reward : -1
# 2020/10/02 20:13:24
# episode : 463 | final step : 99 | total reward : -1
# 2020/10/02 20:13:25
# episode : 464 | final step : 99 | total reward : 0
# 2020/10/02 20:13:26
# episode : 465 | final step : 97 | total reward : 0
# 2020/10/02 20:13:27
# episode : 466 | final step : 98 | total reward : 0
# 2020/10/02 20:13:28
# episode : 467 | final step : 100 | total reward : 0
# 2020/10/02 20:13:29
# episode : 468 | final step : 99 | total reward : 0
# 2020/10/02 20:13:30
# episode : 469 | final step : 99 | total reward : 0
# 2020/10/02 20:13:31
# episode : 470 | final step : 98 | total reward : 0
# 2020/10/02 20:13:31
# episode : 471 | final step : 101 | total reward : 0
# 2020/10/02 20:13:32
# episode : 472 | final step : 94 | total reward : 0
# 2020/10/02 20:13:33
# episode : 473 | final step : 99 | total reward : -1
# 2020/10/02 20:13:34
# episode : 474 | final step : 100 | total reward : 0
# 2020/10/02 20:13:35
# episode : 475 | final step : 100 | total reward : 0
# 2020/10/02 20:13:36
# episode : 476 | final step : 100 | total reward : 0
# 2020/10/02 20:13:36
# episode : 477 | final step : 100 | total reward : 0
# 2020/10/02 20:13:37
# episode : 478 | final step : 99 | total reward : -1
# 2020/10/02 20:13:38
# episode : 479 | final step : 100 | total reward : 0
# 2020/10/02 20:13:39
# episode : 480 | final step : 100 | total reward : 0
# 2020/10/02 20:13:40
# episode : 481 | final step : 98 | total reward : 0
# 2020/10/02 20:13:41
# episode : 482 | final step : 96 | total reward : 0
# 2020/10/02 20:13:42
# episode : 483 | final step : 100 | total reward : 0
# 2020/10/02 20:13:43
# episode : 484 | final step : 98 | total reward : -1
# 2020/10/02 20:13:44
# episode : 485 | final step : 100 | total reward : 0
# 2020/10/02 20:13:45
# episode : 486 | final step : 99 | total reward : 0
# 2020/10/02 20:13:46
# episode : 487 | final step : 100 | total reward : 0
# 2020/10/02 20:13:47
# episode : 488 | final step : 97 | total reward : 0
# 2020/10/02 20:13:48
# episode : 489 | final step : 100 | total reward : 0
# 2020/10/02 20:13:48
# episode : 490 | final step : 98 | total reward : -1
# 2020/10/02 20:13:49
# episode : 491 | final step : 98 | total reward : 0
# 2020/10/02 20:13:50
# episode : 492 | final step : 99 | total reward : 0
# 2020/10/02 20:13:51
# episode : 493 | final step : 99 | total reward : 0
# 2020/10/02 20:13:52
# episode : 494 | final step : 100 | total reward : 0
# 2020/10/02 20:13:53
# episode : 495 | final step : 99 | total reward : 0
# 2020/10/02 20:13:54
# episode : 496 | final step : 100 | total reward : 0
# 2020/10/02 20:13:54
# episode : 497 | final step : 98 | total reward : 0
# 2020/10/02 20:13:55
# episode : 498 | final step : 96 | total reward : 0
# 2020/10/02 20:13:56
# episode : 499 | final step : 98 | total reward : 0
# 2020/10/02 20:13:57
# episode : 500 | final step : 98 | total reward : 0
# 2020/10/02 20:13:58
# episode : 501 | final step : 99 | total reward : 0
# 2020/10/02 20:13:59
# episode : 502 | final step : 99 | total reward : -1
# 2020/10/02 20:13:59
# episode : 503 | final step : 98 | total reward : -1
# 2020/10/02 20:14:00
# episode : 504 | final step : 100 | total reward : 0
# 2020/10/02 20:14:01
# episode : 505 | final step : 96 | total reward : 0
# 2020/10/02 20:14:02
# episode : 506 | final step : 96 | total reward : 0
# 2020/10/02 20:14:03
# episode : 507 | final step : 99 | total reward : 0
# 2020/10/02 20:14:04
# episode : 508 | final step : 100 | total reward : 0
# 2020/10/02 20:14:05
# episode : 509 | final step : 100 | total reward : 0
# 2020/10/02 20:14:06
# episode : 510 | final step : 100 | total reward : 0
# 2020/10/02 20:14:06
# episode : 511 | final step : 98 | total reward : -1
# 2020/10/02 20:14:07
# episode : 512 | final step : 99 | total reward : -1
# 2020/10/02 20:14:08
# episode : 513 | final step : 98 | total reward : -1
# 2020/10/02 20:14:09
# episode : 514 | final step : 93 | total reward : 0
# 2020/10/02 20:14:10
# episode : 515 | final step : 96 | total reward : 0
# 2020/10/02 20:14:11
# episode : 516 | final step : 100 | total reward : 0
# 2020/10/02 20:14:12
# episode : 517 | final step : 99 | total reward : 0
# 2020/10/02 20:14:12
# episode : 518 | final step : 99 | total reward : 0
# 2020/10/02 20:14:13
# episode : 519 | final step : 100 | total reward : 0
# 2020/10/02 20:14:14
# episode : 520 | final step : 98 | total reward : 0
# 2020/10/02 20:14:15
# episode : 521 | final step : 98 | total reward : 0
# 2020/10/02 20:14:16
# episode : 522 | final step : 98 | total reward : 0
# 2020/10/02 20:14:17
# episode : 523 | final step : 98 | total reward : -1
# 2020/10/02 20:14:17
# episode : 524 | final step : 99 | total reward : 0
# 2020/10/02 20:14:18
# episode : 525 | final step : 98 | total reward : -1
# 2020/10/02 20:14:19
# episode : 526 | final step : 97 | total reward : 0
# 2020/10/02 20:14:20
# episode : 527 | final step : 98 | total reward : -1
# 2020/10/02 20:14:21
# episode : 528 | final step : 99 | total reward : -1
# 2020/10/02 20:14:22
# episode : 529 | final step : 100 | total reward : 0
# 2020/10/02 20:14:23
# episode : 530 | final step : 101 | total reward : 0
# 2020/10/02 20:14:24
# episode : 531 | final step : 100 | total reward : 0
# 2020/10/02 20:14:24
# episode : 532 | final step : 98 | total reward : -1
# 2020/10/02 20:14:25
# episode : 533 | final step : 98 | total reward : 0
# 2020/10/02 20:14:26
# episode : 534 | final step : 98 | total reward : 0
# 2020/10/02 20:14:27
# episode : 535 | final step : 98 | total reward : 0
# 2020/10/02 20:14:28
# episode : 536 | final step : 96 | total reward : 0
# 2020/10/02 20:14:29
# episode : 537 | final step : 99 | total reward : 0
# 2020/10/02 20:14:30
# episode : 538 | final step : 98 | total reward : 0
# 2020/10/02 20:14:30
# episode : 539 | final step : 98 | total reward : -1
# 2020/10/02 20:14:31
# episode : 540 | final step : 96 | total reward : 0
# 2020/10/02 20:14:32
# episode : 541 | final step : 100 | total reward : 0
# 2020/10/02 20:14:33
# episode : 542 | final step : 100 | total reward : 0
# 2020/10/02 20:14:34
# episode : 543 | final step : 100 | total reward : 0
# 2020/10/02 20:14:35
# episode : 544 | final step : 100 | total reward : 0
# 2020/10/02 20:14:36
# episode : 545 | final step : 100 | total reward : 0
# 2020/10/02 20:14:37
# episode : 546 | final step : 99 | total reward : 0
# 2020/10/02 20:14:38
# episode : 547 | final step : 99 | total reward : 0
# 2020/10/02 20:14:38
# episode : 548 | final step : 100 | total reward : 0
# 2020/10/02 20:14:39
# episode : 549 | final step : 99 | total reward : -1
# 2020/10/02 20:14:40
# episode : 550 | final step : 97 | total reward : 0
# 2020/10/02 20:14:41
# episode : 551 | final step : 88 | total reward : 0
# 2020/10/02 20:14:42
# episode : 552 | final step : 98 | total reward : 0
# 2020/10/02 20:14:43
# episode : 553 | final step : 98 | total reward : 0
# 2020/10/02 20:14:44
# episode : 554 | final step : 100 | total reward : 0
# 2020/10/02 20:14:45
# episode : 555 | final step : 97 | total reward : 0
# 2020/10/02 20:14:45
# episode : 556 | final step : 98 | total reward : 0
# 2020/10/02 20:14:46
# episode : 557 | final step : 98 | total reward : 0
# 2020/10/02 20:14:47
# episode : 558 | final step : 100 | total reward : 0
# 2020/10/02 20:14:48
# episode : 559 | final step : 98 | total reward : -1
# 2020/10/02 20:14:49
# episode : 560 | final step : 98 | total reward : -1
# 2020/10/02 20:14:50
# episode : 561 | final step : 100 | total reward : 0
# 2020/10/02 20:14:51
# episode : 562 | final step : 100 | total reward : 0
# 2020/10/02 20:14:52
# episode : 563 | final step : 95 | total reward : 0
# 2020/10/02 20:14:53
# episode : 564 | final step : 99 | total reward : 0
# 2020/10/02 20:14:54
# episode : 565 | final step : 95 | total reward : 0
# 2020/10/02 20:14:55
# episode : 566 | final step : 99 | total reward : 0
# 2020/10/02 20:14:56
# episode : 567 | final step : 99 | total reward : -1
# 2020/10/02 20:14:56
# episode : 568 | final step : 94 | total reward : 0
# 2020/10/02 20:14:57
# episode : 569 | final step : 99 | total reward : 0
# 2020/10/02 20:14:58
# episode : 570 | final step : 99 | total reward : 0
# 2020/10/02 20:14:59
# episode : 571 | final step : 102 | total reward : 0
# 2020/10/02 20:15:00
# episode : 572 | final step : 99 | total reward : 0
# 2020/10/02 20:15:01
# episode : 573 | final step : 100 | total reward : 0
# 2020/10/02 20:15:02
# episode : 574 | final step : 99 | total reward : -1
# 2020/10/02 20:15:03
# episode : 575 | final step : 98 | total reward : -1
# 2020/10/02 20:15:04
# episode : 576 | final step : 99 | total reward : 0
# 2020/10/02 20:15:05
# episode : 577 | final step : 98 | total reward : -1
# 2020/10/02 20:15:06
# episode : 578 | final step : 97 | total reward : 0
# 2020/10/02 20:15:07
# episode : 579 | final step : 96 | total reward : 0
# 2020/10/02 20:15:07
# episode : 580 | final step : 100 | total reward : 0
# 2020/10/02 20:15:08
# episode : 581 | final step : 100 | total reward : 0
# 2020/10/02 20:15:09
# episode : 582 | final step : 98 | total reward : -1
# 2020/10/02 20:15:10
# episode : 583 | final step : 97 | total reward : 0
# 2020/10/02 20:15:11
# episode : 584 | final step : 100 | total reward : 0
# 2020/10/02 20:15:12
# episode : 585 | final step : 99 | total reward : 0
# 2020/10/02 20:15:13
# episode : 586 | final step : 100 | total reward : 0
# 2020/10/02 20:15:14
# episode : 587 | final step : 100 | total reward : 0
# 2020/10/02 20:15:15
# episode : 588 | final step : 99 | total reward : 0
# 2020/10/02 20:15:16
# episode : 589 | final step : 99 | total reward : 0
# 2020/10/02 20:15:17
# episode : 590 | final step : 98 | total reward : -1
# 2020/10/02 20:15:18
# episode : 591 | final step : 98 | total reward : -1
# 2020/10/02 20:15:19
# episode : 592 | final step : 96 | total reward : 0
# 2020/10/02 20:15:20
# episode : 593 | final step : 97 | total reward : 0
# 2020/10/02 20:15:20
# episode : 594 | final step : 98 | total reward : 0
# 2020/10/02 20:15:21
# episode : 595 | final step : 99 | total reward : 0
# 2020/10/02 20:15:22
# episode : 596 | final step : 101 | total reward : 0
# 2020/10/02 20:15:23
# episode : 597 | final step : 99 | total reward : 0
# 2020/10/02 20:15:24
# episode : 598 | final step : 100 | total reward : 0
# 2020/10/02 20:15:25
# episode : 599 | final step : 99 | total reward : 0
# 2020/10/02 20:15:26
# episode : 600 | final step : 95 | total reward : 0
# 2020/10/02 20:15:27
# episode : 601 | final step : 95 | total reward : 0
# 2020/10/02 20:15:28
# episode : 602 | final step : 93 | total reward : 0
# 2020/10/02 20:15:29
# episode : 603 | final step : 100 | total reward : 0
# 2020/10/02 20:15:30
# episode : 604 | final step : 99 | total reward : 0
# 2020/10/02 20:15:31
# episode : 605 | final step : 100 | total reward : 0
# 2020/10/02 20:15:31
# episode : 606 | final step : 86 | total reward : 0
# 2020/10/02 20:15:32
# episode : 607 | final step : 100 | total reward : 0
# 2020/10/02 20:15:33
# episode : 608 | final step : 100 | total reward : 0
# 2020/10/02 20:15:34
# episode : 609 | final step : 99 | total reward : 0
# 2020/10/02 20:15:35
# episode : 610 | final step : 100 | total reward : -1
# 2020/10/02 20:15:36
# episode : 611 | final step : 98 | total reward : 0
# 2020/10/02 20:15:37
# episode : 612 | final step : 100 | total reward : 0
# 2020/10/02 20:15:38
# episode : 613 | final step : 98 | total reward : -1
# 2020/10/02 20:15:39
# episode : 614 | final step : 98 | total reward : 0
# 2020/10/02 20:15:40
# episode : 615 | final step : 99 | total reward : -1
# 2020/10/02 20:15:40
# episode : 616 | final step : 95 | total reward : 0
# 2020/10/02 20:15:41
# episode : 617 | final step : 100 | total reward : 0
# 2020/10/02 20:15:42
# episode : 618 | final step : 95 | total reward : 0
# 2020/10/02 20:15:43
# episode : 619 | final step : 94 | total reward : 0
# 2020/10/02 20:15:44
# episode : 620 | final step : 100 | total reward : 0
# 2020/10/02 20:15:45
# episode : 621 | final step : 100 | total reward : 0
# 2020/10/02 20:15:46
# episode : 622 | final step : 99 | total reward : 0
# 2020/10/02 20:15:46
# episode : 623 | final step : 99 | total reward : 0
# 2020/10/02 20:15:47
# episode : 624 | final step : 99 | total reward : 0
# 2020/10/02 20:15:48
# episode : 625 | final step : 98 | total reward : -1
# 2020/10/02 20:15:49
# episode : 626 | final step : 98 | total reward : -1
# 2020/10/02 20:15:50
# episode : 627 | final step : 100 | total reward : 0
# 2020/10/02 20:15:51
# episode : 628 | final step : 98 | total reward : 0
# 2020/10/02 20:15:52
# episode : 629 | final step : 96 | total reward : 0
# 2020/10/02 20:15:53
# episode : 630 | final step : 100 | total reward : 0
# 2020/10/02 20:15:54
# episode : 631 | final step : 100 | total reward : 0
# 2020/10/02 20:15:55
# episode : 632 | final step : 97 | total reward : 0
# 2020/10/02 20:15:56
# episode : 633 | final step : 99 | total reward : -1
# 2020/10/02 20:15:56
# episode : 634 | final step : 97 | total reward : 0
# 2020/10/02 20:15:57
# episode : 635 | final step : 98 | total reward : 0
# 2020/10/02 20:15:58
# episode : 636 | final step : 98 | total reward : -1
# 2020/10/02 20:15:59
# episode : 637 | final step : 100 | total reward : 0
# 2020/10/02 20:16:00
# episode : 638 | final step : 97 | total reward : -1
# 2020/10/02 20:16:01
# episode : 639 | final step : 98 | total reward : -1
# 2020/10/02 20:16:02
# episode : 640 | final step : 100 | total reward : 0
# 2020/10/02 20:16:03
# episode : 641 | final step : 99 | total reward : 0
# 2020/10/02 20:16:03
# episode : 642 | final step : 98 | total reward : -1
# 2020/10/02 20:16:04
# episode : 643 | final step : 98 | total reward : -1
# 2020/10/02 20:16:05
# episode : 644 | final step : 100 | total reward : 0
# 2020/10/02 20:16:06
# episode : 645 | final step : 97 | total reward : 0
# 2020/10/02 20:16:07
# episode : 646 | final step : 99 | total reward : 0
# 2020/10/02 20:16:08
# episode : 647 | final step : 99 | total reward : 0
# 2020/10/02 20:16:09
# episode : 648 | final step : 99 | total reward : -1
# 2020/10/02 20:16:10
# episode : 649 | final step : 99 | total reward : 0
# 2020/10/02 20:16:11
# episode : 650 | final step : 99 | total reward : 0
# 2020/10/02 20:16:12
# episode : 651 | final step : 101 | total reward : 0
# 2020/10/02 20:16:13
# episode : 652 | final step : 98 | total reward : -1
# 2020/10/02 20:16:13
# episode : 653 | final step : 96 | total reward : 0
# 2020/10/02 20:16:14
# episode : 654 | final step : 100 | total reward : 0
# 2020/10/02 20:16:15
# episode : 655 | final step : 97 | total reward : 0
# 2020/10/02 20:16:16
# episode : 656 | final step : 99 | total reward : 0
# 2020/10/02 20:16:17
# episode : 657 | final step : 99 | total reward : -1
# 2020/10/02 20:16:18
# episode : 658 | final step : 99 | total reward : -1
# 2020/10/02 20:16:19
# episode : 659 | final step : 98 | total reward : -1
# 2020/10/02 20:16:20
# episode : 660 | final step : 92 | total reward : 0
# 2020/10/02 20:16:21
# episode : 661 | final step : 98 | total reward : -1
# 2020/10/02 20:16:21
# episode : 662 | final step : 94 | total reward : 0
# 2020/10/02 20:16:22
# episode : 663 | final step : 98 | total reward : 0
# 2020/10/02 20:16:23
# episode : 664 | final step : 98 | total reward : -1
# 2020/10/02 20:16:24
# episode : 665 | final step : 99 | total reward : 0
# 2020/10/02 20:16:25
# episode : 666 | final step : 100 | total reward : -1
# 2020/10/02 20:16:26
# episode : 667 | final step : 98 | total reward : 0
# ...
# 2020/10/02 20:18:06
# episode : 777 | final step : 98 | total reward : 0
# 2020/10/02 20:18:07
# episode : 778 | final step : 100 | total reward : 0
# 2020/10/02 20:18:08
# episode : 779 | final step : 98 | total reward : 0
# 2020/10/02 20:18:08
# episode : 780 | final step : 91 | total reward : 0
# 2020/10/02 20:18:09
# episode : 781 | final step : 99 | total reward : -1
# 2020/10/02 20:18:10
# episode : 782 | final step : 98 | total reward : 0
# 2020/10/02 20:18:11
# episode : 783 | final step : 100 | total reward : 0
# 2020/10/02 20:18:12
# episode : 784 | final step : 98 | total reward : 0
# 2020/10/02 20:18:13
# episode : 785 | final step : 98 | total reward : 0
# 2020/10/02 20:18:14
# episode : 786 | final step : 94 | total reward : 0
# 2020/10/02 20:18:15
# episode : 787 | final step : 100 | total reward : -1
# 2020/10/02 20:18:16
# episode : 788 | final step : 99 | total reward : 0
# 2020/10/02 20:18:17
# episode : 789 | final step : 98 | total reward : -1
# 2020/10/02 20:18:18
# episode : 790 | final step : 97 | total reward : 0
# 2020/10/02 20:18:19
# episode : 791 | final step : 99 | total reward : -1
# 2020/10/02 20:18:19
# episode : 792 | final step : 95 | total reward : 0
# 2020/10/02 20:18:20
# episode : 793 | final step : 98 | total reward : -1
# 2020/10/02 20:18:21
# episode : 794 | final step : 99 | total reward : -1
# 2020/10/02 20:18:22
# episode : 795 | final step : 99 | total reward : 0
# 2020/10/02 20:18:23
# episode : 796 | final step : 98 | total reward : -1
# 2020/10/02 20:18:24
# episode : 797 | final step : 95 | total reward : 0
# 2020/10/02 20:18:25
# episode : 798 | final step : 100 | total reward : 0
# 2020/10/02 20:18:26
# episode : 799 | final step : 100 | total reward : 0
# 2020/10/02 20:18:27
# episode : 800 | final step : 92 | total reward : 0
# 2020/10/02 20:18:28
# episode : 801 | final step : 99 | total reward : -1
# 2020/10/02 20:18:28
# episode : 802 | final step : 95 | total reward : 0
# 2020/10/02 20:18:29
# episode : 803 | final step : 99 | total reward : -1
# 2020/10/02 20:18:30
# episode : 804 | final step : 99 | total reward : 0
# 2020/10/02 20:18:31
# episode : 805 | final step : 97 | total reward : 0
# 2020/10/02 20:18:32
# episode : 806 | final step : 97 | total reward : 0
# 2020/10/02 20:18:33
# episode : 807 | final step : 100 | total reward : 0
# 2020/10/02 20:18:34
# episode : 808 | final step : 98 | total reward : -1
# 2020/10/02 20:18:35
# episode : 809 | final step : 98 | total reward : 0
# 2020/10/02 20:18:36
# episode : 810 | final step : 97 | total reward : 0
# 2020/10/02 20:18:37
# episode : 811 | final step : 98 | total reward : -1
# 2020/10/02 20:18:38
# episode : 812 | final step : 99 | total reward : -1
# 2020/10/02 20:18:39
# episode : 813 | final step : 100 | total reward : 0
# 2020/10/02 20:18:39
# episode : 814 | final step : 98 | total reward : -1
# 2020/10/02 20:18:40
# episode : 815 | final step : 100 | total reward : 0
# 2020/10/02 20:18:41
# episode : 816 | final step : 99 | total reward : -1
# 2020/10/02 20:18:42
# episode : 817 | final step : 98 | total reward : -1
# 2020/10/02 20:18:43
# episode : 818 | final step : 95 | total reward : 0
# 2020/10/02 20:18:44
# episode : 819 | final step : 100 | total reward : 0
# 2020/10/02 20:18:45
# episode : 820 | final step : 100 | total reward : 0
# 2020/10/02 20:18:46
# episode : 821 | final step : 102 | total reward : 0
# 2020/10/02 20:18:46
# episode : 822 | final step : 98 | total reward : 0
# 2020/10/02 20:18:47
# episode : 823 | final step : 99 | total reward : 0
# 2020/10/02 20:18:48
# episode : 824 | final step : 98 | total reward : 0
# 2020/10/02 20:18:49
# episode : 825 | final step : 98 | total reward : 0
# 2020/10/02 20:18:50
# episode : 826 | final step : 98 | total reward : -1
# 2020/10/02 20:18:51
# episode : 827 | final step : 98 | total reward : -1
# 2020/10/02 20:18:52
# episode : 828 | final step : 98 | total reward : 0
# 2020/10/02 20:18:53
# episode : 829 | final step : 99 | total reward : -1
# 2020/10/02 20:18:54
# episode : 830 | final step : 99 | total reward : 0
# 2020/10/02 20:18:55
# episode : 831 | final step : 99 | total reward : 0
# 2020/10/02 20:18:56
# episode : 832 | final step : 100 | total reward : -1
# 2020/10/02 20:18:56
# episode : 833 | final step : 99 | total reward : -1
# 2020/10/02 20:18:57
# episode : 834 | final step : 97 | total reward : 0
# 2020/10/02 20:18:58
# episode : 835 | final step : 98 | total reward : 0
# 2020/10/02 20:18:59
# episode : 836 | final step : 100 | total reward : 0
# 2020/10/02 20:19:00
# episode : 837 | final step : 99 | total reward : 0
# 2020/10/02 20:19:01
# episode : 838 | final step : 98 | total reward : 0
# 2020/10/02 20:19:02
# episode : 839 | final step : 98 | total reward : -1
# 2020/10/02 20:19:03
# episode : 840 | final step : 99 | total reward : 0
# 2020/10/02 20:19:04
# episode : 841 | final step : 100 | total reward : 0
# 2020/10/02 20:19:05
# episode : 842 | final step : 97 | total reward : 0
# 2020/10/02 20:19:06
# episode : 843 | final step : 93 | total reward : 0
# 2020/10/02 20:19:07
# episode : 844 | final step : 100 | total reward : -1
# 2020/10/02 20:19:08
# episode : 845 | final step : 99 | total reward : 0
# 2020/10/02 20:19:09
# episode : 846 | final step : 98 | total reward : -1
# 2020/10/02 20:19:09
# episode : 847 | final step : 98 | total reward : -1
# 2020/10/02 20:19:10
# episode : 848 | final step : 99 | total reward : -1
# 2020/10/02 20:19:11
# episode : 849 | final step : 99 | total reward : -1
# 2020/10/02 20:19:12
# episode : 850 | final step : 98 | total reward : 0
# 2020/10/02 20:19:13
# episode : 851 | final step : 99 | total reward : 0
# 2020/10/02 20:19:14
# episode : 852 | final step : 101 | total reward : 0
# 2020/10/02 20:19:15
# episode : 853 | final step : 95 | total reward : 0
# 2020/10/02 20:19:15
# episode : 854 | final step : 98 | total reward : -1
# 2020/10/02 20:19:16
# episode : 855 | final step : 95 | total reward : 0
# 2020/10/02 20:19:17
# episode : 856 | final step : 98 | total reward : -1
# 2020/10/02 20:19:18
# episode : 857 | final step : 100 | total reward : 0
# 2020/10/02 20:19:19
# episode : 858 | final step : 99 | total reward : -1
# 2020/10/02 20:19:20
# episode : 859 | final step : 99 | total reward : 0
# 2020/10/02 20:19:21
# episode : 860 | final step : 94 | total reward : 0
# 2020/10/02 20:19:21
# episode : 861 | final step : 96 | total reward : 0
# 2020/10/02 20:19:22
# episode : 862 | final step : 98 | total reward : -1
# 2020/10/02 20:19:23
# episode : 863 | final step : 90 | total reward : 0
# 2020/10/02 20:19:24
# episode : 864 | final step : 100 | total reward : 0
# 2020/10/02 20:19:25
# episode : 865 | final step : 98 | total reward : 0
# 2020/10/02 20:19:26
# episode : 866 | final step : 98 | total reward : -1
# 2020/10/02 20:19:27
# episode : 867 | final step : 99 | total reward : 0
# 2020/10/02 20:19:28
# episode : 868 | final step : 98 | total reward : -1
# 2020/10/02 20:19:29
# episode : 869 | final step : 98 | total reward : 0
# 2020/10/02 20:19:30
# episode : 870 | final step : 100 | total reward : 0
# 2020/10/02 20:19:31
# episode : 871 | final step : 97 | total reward : 0
# 2020/10/02 20:19:32
# episode : 872 | final step : 100 | total reward : 0
# 2020/10/02 20:19:33
# episode : 873 | final step : 99 | total reward : -1
# 2020/10/02 20:19:34
# episode : 874 | final step : 98 | total reward : -1
# 2020/10/02 20:19:34
# episode : 875 | final step : 98 | total reward : -1
# 2020/10/02 20:19:35
# episode : 876 | final step : 100 | total reward : 0
# 2020/10/02 20:19:36
# episode : 877 | final step : 99 | total reward : 0
# 2020/10/02 20:19:37
# episode : 878 | final step : 98 | total reward : 0
# 2020/10/02 20:19:38
# episode : 879 | final step : 99 | total reward : 0
# 2020/10/02 20:19:39
# episode : 880 | final step : 98 | total reward : 0
# 2020/10/02 20:19:40
# episode : 881 | final step : 99 | total reward : 0
# 2020/10/02 20:19:41
# episode : 882 | final step : 99 | total reward : 0
# 2020/10/02 20:19:42
# episode : 883 | final step : 99 | total reward : -1
# 2020/10/02 20:19:43
# episode : 884 | final step : 100 | total reward : 0
# 2020/10/02 20:19:44
# episode : 885 | final step : 102 | total reward : 0
# 2020/10/02 20:19:45
# episode : 886 | final step : 96 | total reward : 0
# 2020/10/02 20:19:45
# episode : 887 | final step : 93 | total reward : 0
# 2020/10/02 20:19:46
# episode : 888 | final step : 99 | total reward : 0
# 2020/10/02 20:19:47
# episode : 889 | final step : 100 | total reward : 0
# 2020/10/02 20:19:48
# episode : 890 | final step : 100 | total reward : 0
# 2020/10/02 20:19:49
# episode : 891 | final step : 99 | total reward : 0
# 2020/10/02 20:19:50
# episode : 892 | final step : 95 | total reward : 0
# 2020/10/02 20:19:51
# episode : 893 | final step : 98 | total reward : -1
# 2020/10/02 20:19:52
# episode : 894 | final step : 98 | total reward : 0
# 2020/10/02 20:19:53
# episode : 895 | final step : 99 | total reward : 0
# 2020/10/02 20:19:54
# episode : 896 | final step : 97 | total reward : 0
# 2020/10/02 20:19:55
# episode : 897 | final step : 94 | total reward : 0
# 2020/10/02 20:19:56
# episode : 898 | final step : 101 | total reward : 0
# 2020/10/02 20:19:56
# episode : 899 | final step : 99 | total reward : 0
# 2020/10/02 20:19:57
# episode : 900 | final step : 98 | total reward : 0
# 2020/10/02 20:19:58
# episode : 901 | final step : 98 | total reward : 0
# 2020/10/02 20:19:59
# episode : 902 | final step : 100 | total reward : -1
# 2020/10/02 20:20:00
# episode : 903 | final step : 96 | total reward : 0
# 2020/10/02 20:20:01
# episode : 904 | final step : 98 | total reward : 0
# 2020/10/02 20:20:02
# episode : 905 | final step : 99 | total reward : 0
# 2020/10/02 20:20:03
# episode : 906 | final step : 99 | total reward : 0
# 2020/10/02 20:20:03
# episode : 907 | final step : 99 | total reward : -1
# 2020/10/02 20:20:04
# episode : 908 | final step : 98 | total reward : 0
# 2020/10/02 20:20:05
# episode : 909 | final step : 98 | total reward : -1
# 2020/10/02 20:20:06
# episode : 910 | final step : 98 | total reward : 0
# 2020/10/02 20:20:07
# episode : 911 | final step : 98 | total reward : 0
# 2020/10/02 20:20:08
# episode : 912 | final step : 97 | total reward : 0
# 2020/10/02 20:20:09
# episode : 913 | final step : 97 | total reward : 0
# 2020/10/02 20:20:10
# episode : 914 | final step : 99 | total reward : 0
# 2020/10/02 20:20:11
# episode : 915 | final step : 98 | total reward : -1
# 2020/10/02 20:20:12
# episode : 916 | final step : 96 | total reward : 0
# 2020/10/02 20:20:12
# episode : 917 | final step : 100 | total reward : -1
# 2020/10/02 20:20:13
# episode : 918 | final step : 100 | total reward : -1
# 2020/10/02 20:20:14
# episode : 919 | final step : 100 | total reward : 0
# 2020/10/02 20:20:15
# episode : 920 | final step : 96 | total reward : 0
# 2020/10/02 20:20:16
# episode : 921 | final step : 98 | total reward : -1
# 2020/10/02 20:20:17
# episode : 922 | final step : 98 | total reward : -1
# 2020/10/02 20:20:18
# episode : 923 | final step : 101 | total reward : 0
# 2020/10/02 20:20:19
# episode : 924 | final step : 99 | total reward : 0
# 2020/10/02 20:20:20
# episode : 925 | final step : 100 | total reward : 0
# 2020/10/02 20:20:21
# episode : 926 | final step : 99 | total reward : 0
# 2020/10/02 20:20:22
# episode : 927 | final step : 100 | total reward : 0
# 2020/10/02 20:20:23
# episode : 928 | final step : 98 | total reward : 0
# 2020/10/02 20:20:23
# episode : 929 | final step : 96 | total reward : 0
# 2020/10/02 20:20:24
# episode : 930 | final step : 99 | total reward : 0
# 2020/10/02 20:20:25
# episode : 931 | final step : 100 | total reward : 0
# 2020/10/02 20:20:26
# episode : 932 | final step : 100 | total reward : 0
# 2020/10/02 20:20:27
# episode : 933 | final step : 99 | total reward : 0
# 2020/10/02 20:20:28
# episode : 934 | final step : 98 | total reward : -1
# 2020/10/02 20:20:29
# episode : 935 | final step : 99 | total reward : 0
# 2020/10/02 20:20:30
# episode : 936 | final step : 99 | total reward : 0
# 2020/10/02 20:20:31
# episode : 937 | final step : 96 | total reward : 0
# 2020/10/02 20:20:32
# episode : 938 | final step : 95 | total reward : 0
# 2020/10/02 20:20:32
# episode : 939 | final step : 97 | total reward : 0
# 2020/10/02 20:20:33
# episode : 940 | final step : 95 | total reward : 0
# 2020/10/02 20:20:34
# episode : 941 | final step : 92 | total reward : 0
# 2020/10/02 20:20:35
# episode : 942 | final step : 99 | total reward : -1
# 2020/10/02 20:20:36
# episode : 943 | final step : 98 | total reward : 0
# 2020/10/02 20:20:37
# episode : 944 | final step : 99 | total reward : 0
# 2020/10/02 20:20:38
# episode : 945 | final step : 98 | total reward : 0
# 2020/10/02 20:20:39
# episode : 946 | final step : 100 | total reward : 0
# 2020/10/02 20:20:40
# episode : 947 | final step : 98 | total reward : -1
# 2020/10/02 20:20:41
# episode : 948 | final step : 99 | total reward : 0
# 2020/10/02 20:20:42
# episode : 949 | final step : 100 | total reward : 0
# 2020/10/02 20:20:42
# episode : 950 | final step : 98 | total reward : 0
# 2020/10/02 20:20:43
# episode : 951 | final step : 101 | total reward : 0
# 2020/10/02 20:20:44
# episode : 952 | final step : 99 | total reward : 0
# 2020/10/02 20:20:45
# episode : 953 | final step : 99 | total reward : 0
# 2020/10/02 20:20:46
# episode : 954 | final step : 96 | total reward : 0
# 2020/10/02 20:20:47
# episode : 955 | final step : 99 | total reward : 0
# 2020/10/02 20:20:48
# episode : 956 | final step : 97 | total reward : 0
# 2020/10/02 20:20:49
# episode : 957 | final step : 99 | total reward : 0
# 2020/10/02 20:20:50
# episode : 958 | final step : 100 | total reward : 0
# 2020/10/02 20:20:51
# episode : 959 | final step : 98 | total reward : -1
# 2020/10/02 20:20:52
# episode : 960 | final step : 98 | total reward : -1
# 2020/10/02 20:20:53
# episode : 961 | final step : 99 | total reward : 0
# 2020/10/02 20:20:53
# episode : 962 | final step : 97 | total reward : 0
# 2020/10/02 20:20:54
# episode : 963 | final step : 98 | total reward : -1
# 2020/10/02 20:20:55
# episode : 964 | final step : 97 | total reward : 0
# 2020/10/02 20:20:56
# episode : 965 | final step : 93 | total reward : 0
# 2020/10/02 20:20:57
# episode : 966 | final step : 99 | total reward : 0
# 2020/10/02 20:20:58
# episode : 967 | final step : 96 | total reward : 0
# 2020/10/02 20:20:59
# episode : 968 | final step : 100 | total reward : 0
# 2020/10/02 20:21:00
# episode : 969 | final step : 98 | total reward : 0
# 2020/10/02 20:21:01
# episode : 970 | final step : 98 | total reward : -1
# 2020/10/02 20:21:02
# episode : 971 | final step : 98 | total reward : 0
# 2020/10/02 20:21:03
# episode : 972 | final step : 100 | total reward : 0
# 2020/10/02 20:21:03
# episode : 973 | final step : 99 | total reward : 0
# 2020/10/02 20:21:04
# episode : 974 | final step : 98 | total reward : -1
# 2020/10/02 20:21:05
# episode : 975 | final step : 97 | total reward : -1
# 2020/10/02 20:21:06
# episode : 976 | final step : 95 | total reward : 0
# 2020/10/02 20:21:07
# episode : 977 | final step : 94 | total reward : 0
# 2020/10/02 20:21:08
# episode : 978 | final step : 93 | total reward : 0
# 2020/10/02 20:21:09
# episode : 979 | final step : 103 | total reward : 0
# 2020/10/02 20:21:10
# episode : 980 | final step : 100 | total reward : 0
# 2020/10/02 20:21:11
# episode : 981 | final step : 100 | total reward : 0
# 2020/10/02 20:21:12
# episode : 982 | final step : 100 | total reward : 0
# 2020/10/02 20:21:13
# episode : 983 | final step : 96 | total reward : 0
# 2020/10/02 20:21:14
# episode : 984 | final step : 99 | total reward : 0
# 2020/10/02 20:21:14
# episode : 985 | final step : 99 | total reward : -1
# 2020/10/02 20:21:15
# episode : 986 | final step : 100 | total reward : 0
# 2020/10/02 20:21:16
# episode : 987 | final step : 98 | total reward : -1
# 2020/10/02 20:21:17
# episode : 988 | final step : 101 | total reward : 0
# 2020/10/02 20:21:18
# episode : 989 | final step : 99 | total reward : -1
# 2020/10/02 20:21:19
# episode : 990 | final step : 97 | total reward : 0
# 2020/10/02 20:21:20
# episode : 991 | final step : 96 | total reward : 0
# 2020/10/02 20:21:21
# episode : 992 | final step : 98 | total reward : -1
# 2020/10/02 20:21:22
# episode : 993 | final step : 99 | total reward : 0
# 2020/10/02 20:21:23
# episode : 994 | final step : 97 | total reward : 0
# 2020/10/02 20:21:24
# episode : 995 | final step : 100 | total reward : 0
# 2020/10/02 20:21:25
# episode : 996 | final step : 99 | total reward : 0
# 2020/10/02 20:21:25
# episode : 997 | final step : 94 | total reward : 0
# 2020/10/02 20:21:26
# episode : 998 | final step : 99 | total reward : 0
# 2020/10/02 20:21:27
# episode : 999 | final step : 99 | total reward : -1
# Complete

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(reward_list)

# %%
def moving_average(data,n):
    len_data=len(data)-n
    res_data=np.zeros(len_data)

    for i in range(len_data):
        res_data[i]=sum(data[i:i+n])/n
    return res_data

# %%
average_number=10
filtered_data=moving_average(reward_list,average_number)
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(filtered_data)

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[998]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()
