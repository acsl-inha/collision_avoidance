# %%
import math, random

import gym
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd 
import torch.nn.functional as F

from common.layers import NoisyLinear
from common.replay_buffer import ReplayBuffer
import gym_Aircraft

from itertools import count
import time
import itertools
import matplotlib
import matplotlib.pyplot as plt

# %%
USE_CUDA = torch.cuda.is_available()
Variable = lambda *args, **kwargs: autograd.Variable(*args, **kwargs).cuda() if USE_CUDA else autograd.Variable(*args, **kwargs)

# %%
env_id = "acav-v0"
env = gym.make(env_id)
# Out:
# /home/jupyter-kunwoopark/.local/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
class RainbowDQN(nn.Module):
    def __init__(self, num_inputs, num_actions, num_atoms, Vmin, Vmax):
        super(RainbowDQN, self).__init__()
        
        self.num_inputs   = num_inputs
        self.num_actions  = num_actions
        self.num_atoms    = num_atoms
        self.Vmin         = Vmin
        self.Vmax         = Vmax
        
        self.linear1 = nn.Linear(num_inputs, 32)
        self.linear2 = nn.Linear(32, 64)
        
        self.noisy_value1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_value2 = NoisyLinear(64, self.num_atoms, use_cuda=USE_CUDA)
        
        self.noisy_advantage1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_advantage2 = NoisyLinear(64, self.num_atoms * self.num_actions, use_cuda=USE_CUDA)
        
    def forward(self, x):
        batch_size = x.size(0)
        
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        
        value = F.relu(self.noisy_value1(x))
        value = self.noisy_value2(value)
        
        advantage = F.relu(self.noisy_advantage1(x))
        advantage = self.noisy_advantage2(advantage)
        
        value     = value.view(batch_size, 1, self.num_atoms)
        advantage = advantage.view(batch_size, self.num_actions, self.num_atoms)
        
        x = value + advantage - advantage.mean(1, keepdim=True)
        x = F.softmax(x.view(-1, self.num_atoms)).view(-1, self.num_actions, self.num_atoms)
        
        return x
        
    def reset_noise(self):
        self.noisy_value1.reset_noise()
        self.noisy_value2.reset_noise()
        self.noisy_advantage1.reset_noise()
        self.noisy_advantage2.reset_noise()
    
    def act(self, state):
        state = Variable(torch.FloatTensor(state).unsqueeze(0), volatile=True)
        dist = self.forward(state).data.cpu()
        dist = dist * torch.linspace(self.Vmin, self.Vmax, self.num_atoms)
        action = dist.sum(2).max(1)[1].numpy()[0]
        return action

# %%
num_atoms = 51
Vmin = -10
Vmax = 10

current_model = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)
target_model  = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)

if USE_CUDA:
    current_model = current_model.cuda()
    target_model  = target_model.cuda()
    
optimizer = optim.Adam(current_model.parameters(), 0.001)

replay_buffer = ReplayBuffer(10000)

# %%
def update_target(current_model, target_model):
    target_model.load_state_dict(current_model.state_dict())
    
update_target(current_model, target_model)

# %%
def projection_distribution(next_state, rewards, dones):
    batch_size  = next_state.size(0)
    
    delta_z = float(Vmax - Vmin) / (num_atoms - 1)
    support = torch.linspace(Vmin, Vmax, num_atoms)
    
    next_dist   = target_model(next_state).data.cpu() * support
    next_action = next_dist.sum(2).max(1)[1]
    next_action = next_action.unsqueeze(1).unsqueeze(1).expand(next_dist.size(0), 1, next_dist.size(2))
    next_dist   = next_dist.gather(1, next_action).squeeze(1)
        
    rewards = rewards.unsqueeze(1).expand_as(next_dist)
    dones   = dones.unsqueeze(1).expand_as(next_dist)
    support = support.unsqueeze(0).expand_as(next_dist)
    
    Tz = rewards + (1 - dones) * 0.99 * support
    Tz = Tz.clamp(min=Vmin, max=Vmax)
    b  = (Tz - Vmin) / delta_z
    l  = b.floor().long()
    u  = b.ceil().long()
        
    offset = torch.linspace(0, (batch_size - 1) * num_atoms, batch_size).long()\
                    .unsqueeze(1).expand(batch_size, num_atoms)

    proj_dist = torch.zeros(next_dist.size())    
    proj_dist.view(-1).index_add_(0, (l + offset).view(-1), (next_dist * (u.float() - b)).view(-1))
    proj_dist.view(-1).index_add_(0, (u + offset).view(-1), (next_dist * (b - l.float())).view(-1))
        
    return proj_dist

# %%
def compute_td_loss(batch_size):
    state, action, reward, next_state, done = replay_buffer.sample(batch_size) 

    state      = Variable(torch.FloatTensor(np.float32(state)))
    next_state = Variable(torch.FloatTensor(np.float32(next_state)), volatile=True)
    action     = Variable(torch.LongTensor(action))
    reward     = torch.FloatTensor(reward)
    done       = torch.FloatTensor(np.float32(done))

    proj_dist = projection_distribution(next_state, reward, done)
    
    dist = current_model(state)
    action = action.unsqueeze(1).unsqueeze(1).expand(batch_size, 1, num_atoms)
    dist = dist.gather(1, action).squeeze(1)
    dist.data.clamp_(0.01, 0.99)
    loss = -(Variable(proj_dist) * dist.log()).sum(1)
    loss  = loss.mean()
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    current_model.reset_noise()
    target_model.reset_noise()
    
    return loss

# %%
num_episodes = 1000
batch_size = 32
gamma=0.99
TARGET_UPDATE=10

losses = []
total_res=[]
reward_list=[]
for i_episode in range(num_episodes):
    total_reward=0
    
    # 환경과 상태 초기화
    res_list=np.zeros(11)
    state = env.reset()

    for t in count():
        # 행동 선택과 수행
        
        action = current_model.act(state)
        
        next_state, reward, done, res = env.step(action)
        
        # 메모리에 변이 저장
        replay_buffer.push(state, action, reward, next_state, done)
        

        # 새로운 상태 관찰
        if not done:
            next_state = next_state
        else:
            next_state = None

        

        # 다음 상태로 이동
        state = next_state

     
        # Data save
        
        cmd_list,r_list,elev_list,azim_list,Pm_list,Pt_list,h_list=res
        Pm_list=Pm_list.tolist()
        Pt_list=Pt_list.tolist()
        merged_data=itertools.chain([cmd_list],[r_list],[elev_list],[azim_list],Pm_list,Pt_list,[h_list])
        merged_data=np.array(list(merged_data))
        res_list=np.vstack([res_list,merged_data])
        
        total_reward+=reward
        
        if done:
            res_list=np.delete(res_list,0,0)
            
            total_res.append(res_list)
            reward_list.append(total_reward)
            
            now = time.localtime()
            print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))
            print("episode : {} | final step : {} | total reward : {}".format(i_episode, t, total_reward))
            break
        if len(replay_buffer) > batch_size:
            loss = compute_td_loss(batch_size)
            losses.append(loss.item())
            
        
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        update_target(current_model, target_model)

print('Complete')
env.close()
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 2020/10/06 16:13:13
# episode : 0 | final step : 99 | total reward : 22.0
# 2020/10/06 16:13:14
# episode : 1 | final step : 99 | total reward : -82.0
# 2020/10/06 16:13:15
# episode : 2 | final step : 98 | total reward : -52.0
# 2020/10/06 16:13:16
# episode : 3 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:17
# episode : 4 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:17
# episode : 5 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:18
# episode : 6 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:19
# episode : 7 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:20
# episode : 8 | final step : 100 | total reward : 99.0
# 2020/10/06 16:13:21
# episode : 9 | final step : 97 | total reward : -51.0
# 2020/10/06 16:13:22
# episode : 10 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:22
# episode : 11 | final step : 101 | total reward : 99.0
# 2020/10/06 16:13:23
# episode : 12 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:24
# episode : 13 | final step : 102 | total reward : 99.0
# 2020/10/06 16:13:25
# episode : 14 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:26
# episode : 15 | final step : 97 | total reward : -51.0
# 2020/10/06 16:13:27
# episode : 16 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:28
# episode : 17 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:29
# episode : 18 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:29
# episode : 19 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:30
# episode : 20 | final step : 97 | total reward : -51.0
# 2020/10/06 16:13:31
# episode : 21 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:32
# episode : 22 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:32
# episode : 23 | final step : 101 | total reward : 99.0
# 2020/10/06 16:13:33
# episode : 24 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:34
# episode : 25 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:35
# episode : 26 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:35
# episode : 27 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:36
# episode : 28 | final step : 99 | total reward : -51.0
# 2020/10/06 16:13:37
# episode : 29 | final step : 101 | total reward : 99.0
# 2020/10/06 16:13:38
# episode : 30 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:38
# episode : 31 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:39
# episode : 32 | final step : 98 | total reward : 99.0
# 2020/10/06 16:13:40
# episode : 33 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:41
# episode : 34 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:42
# episode : 35 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:43
# episode : 36 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:44
# episode : 37 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:45
# episode : 38 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:46
# episode : 39 | final step : 101 | total reward : 99.0
# 2020/10/06 16:13:46
# episode : 40 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:47
# episode : 41 | final step : 100 | total reward : -51.0
# 2020/10/06 16:13:48
# episode : 42 | final step : 97 | total reward : -51.0
# 2020/10/06 16:13:49
# episode : 43 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:51
# episode : 44 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:52
# episode : 45 | final step : 97 | total reward : -51.0
# 2020/10/06 16:13:53
# episode : 46 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:54
# episode : 47 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:55
# episode : 48 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:56
# episode : 49 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:57
# episode : 50 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:58
# episode : 51 | final step : 98 | total reward : -51.0
# 2020/10/06 16:13:59
# episode : 52 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:00
# episode : 53 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:01
# episode : 54 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:03
# episode : 55 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:04
# episode : 56 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:05
# episode : 57 | final step : 97 | total reward : -51.0
# 2020/10/06 16:14:06
# episode : 58 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:07
# episode : 59 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:08
# episode : 60 | final step : 101 | total reward : 99.0
# 2020/10/06 16:14:09
# episode : 61 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:11
# episode : 62 | final step : 99 | total reward : -51.0
# 2020/10/06 16:14:12
# episode : 63 | final step : 99 | total reward : -51.0
# 2020/10/06 16:14:13
# episode : 64 | final step : 99 | total reward : -51.0
# 2020/10/06 16:14:14
# episode : 65 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:15
# episode : 66 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:16
# episode : 67 | final step : 99 | total reward : 99.0
# 2020/10/06 16:14:17
# episode : 68 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:18
# episode : 69 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:19
# episode : 70 | final step : 98 | total reward : 99.0
# 2020/10/06 16:14:21
# episode : 71 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:22
# episode : 72 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:23
# episode : 73 | final step : 100 | total reward : -51.0
# 2020/10/06 16:14:24
# episode : 74 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:25
# episode : 75 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:26
# episode : 76 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:27
# episode : 77 | final step : 98 | total reward : 99.0
# 2020/10/06 16:14:28
# episode : 78 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:29
# episode : 79 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:31
# episode : 80 | final step : 99 | total reward : -51.0
# 2020/10/06 16:14:32
# episode : 81 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:33
# episode : 82 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:34
# episode : 83 | final step : 97 | total reward : -51.0
# 2020/10/06 16:14:35
# episode : 84 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:36
# episode : 85 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:38
# episode : 86 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:39
# episode : 87 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:40
# episode : 88 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:41
# episode : 89 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:42
# episode : 90 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:43
# episode : 91 | final step : 101 | total reward : 99.0
# 2020/10/06 16:14:44
# episode : 92 | final step : 97 | total reward : -51.0
# 2020/10/06 16:14:45
# episode : 93 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:46
# episode : 94 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:47
# episode : 95 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:48
# episode : 96 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:49
# episode : 97 | final step : 99 | total reward : 99.0
# 2020/10/06 16:14:50
# episode : 98 | final step : 100 | total reward : 99.0
# 2020/10/06 16:14:51
# episode : 99 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:52
# episode : 100 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:53
# episode : 101 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:55
# episode : 102 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:56
# episode : 103 | final step : 97 | total reward : -51.0
# 2020/10/06 16:14:57
# episode : 104 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:58
# episode : 105 | final step : 98 | total reward : -51.0
# 2020/10/06 16:14:59
# episode : 106 | final step : 101 | total reward : 99.0
# 2020/10/06 16:15:00
# episode : 107 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:01
# episode : 108 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:02
# episode : 109 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:03
# episode : 110 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:04
# episode : 111 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:04
# episode : 112 | final step : 100 | total reward : 99.0
# 2020/10/06 16:15:05
# episode : 113 | final step : 98 | total reward : 99.0
# 2020/10/06 16:15:06
# episode : 114 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:07
# episode : 115 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:08
# episode : 116 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:10
# episode : 117 | final step : 99 | total reward : 99.0
# 2020/10/06 16:15:11
# episode : 118 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:12
# episode : 119 | final step : 99 | total reward : -51.0
# 2020/10/06 16:15:13
# episode : 120 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:14
# episode : 121 | final step : 101 | total reward : 99.0
# 2020/10/06 16:15:15
# episode : 122 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:16
# episode : 123 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:18
# episode : 124 | final step : 97 | total reward : -51.0
# 2020/10/06 16:15:19
# episode : 125 | final step : 98 | total reward : 99.0
# 2020/10/06 16:15:20
# episode : 126 | final step : 99 | total reward : -51.0
# 2020/10/06 16:15:21
# episode : 127 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:23
# episode : 128 | final step : 99 | total reward : -51.0
# 2020/10/06 16:15:24
# episode : 129 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:25
# episode : 130 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:26
# episode : 131 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:27
# episode : 132 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:28
# episode : 133 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:29
# episode : 134 | final step : 101 | total reward : 99.0
# 2020/10/06 16:15:30
# episode : 135 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:31
# episode : 136 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:32
# episode : 137 | final step : 97 | total reward : -51.0
# 2020/10/06 16:15:33
# episode : 138 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:34
# episode : 139 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:35
# episode : 140 | final step : 101 | total reward : 99.0
# 2020/10/06 16:15:36
# episode : 141 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:37
# episode : 142 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:38
# episode : 143 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:39
# episode : 144 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:40
# episode : 145 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:41
# episode : 146 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:42
# episode : 147 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:44
# episode : 148 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:45
# episode : 149 | final step : 99 | total reward : 99.0
# 2020/10/06 16:15:46
# episode : 150 | final step : 97 | total reward : -51.0
# 2020/10/06 16:15:47
# episode : 151 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:48
# episode : 152 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:49
# episode : 153 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:50
# episode : 154 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:51
# episode : 155 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:52
# episode : 156 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:53
# episode : 157 | final step : 100 | total reward : 99.0
# 2020/10/06 16:15:54
# episode : 158 | final step : 100 | total reward : 99.0
# 2020/10/06 16:15:55
# episode : 159 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:56
# episode : 160 | final step : 99 | total reward : -51.0
# 2020/10/06 16:15:57
# episode : 161 | final step : 98 | total reward : -51.0
# 2020/10/06 16:15:58
# episode : 162 | final step : 97 | total reward : 99.0
# 2020/10/06 16:15:59
# episode : 163 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:01
# episode : 164 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:01
# episode : 165 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:03
# episode : 166 | final step : 99 | total reward : -51.0
# 2020/10/06 16:16:04
# episode : 167 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:05
# episode : 168 | final step : 101 | total reward : 99.0
# 2020/10/06 16:16:06
# episode : 169 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:07
# episode : 170 | final step : 99 | total reward : -51.0
# 2020/10/06 16:16:08
# episode : 171 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:09
# episode : 172 | final step : 98 | total reward : 99.0
# 2020/10/06 16:16:10
# episode : 173 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:11
# episode : 174 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:12
# episode : 175 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:13
# episode : 176 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:14
# episode : 177 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:15
# episode : 178 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:15
# episode : 179 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:16
# episode : 180 | final step : 99 | total reward : -51.0
# 2020/10/06 16:16:18
# episode : 181 | final step : 97 | total reward : -51.0
# 2020/10/06 16:16:19
# episode : 182 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:20
# episode : 183 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:21
# episode : 184 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:22
# episode : 185 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:23
# episode : 186 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:24
# episode : 187 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:25
# episode : 188 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:26
# episode : 189 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:28
# episode : 190 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:29
# episode : 191 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:30
# episode : 192 | final step : 97 | total reward : -51.0
# 2020/10/06 16:16:31
# episode : 193 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:32
# episode : 194 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:33
# episode : 195 | final step : 99 | total reward : -51.0
# 2020/10/06 16:16:35
# episode : 196 | final step : 100 | total reward : 99.0
# 2020/10/06 16:16:35
# episode : 197 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:36
# episode : 198 | final step : 99 | total reward : -51.0
# 2020/10/06 16:16:38
# episode : 199 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:39
# episode : 200 | final step : 102 | total reward : 99.0
# 2020/10/06 16:16:40
# episode : 201 | final step : 102 | total reward : 99.0
# 2020/10/06 16:16:41
# episode : 202 | final step : 97 | total reward : 99.0
# 2020/10/06 16:16:42
# episode : 203 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:43
# episode : 204 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:44
# episode : 205 | final step : 97 | total reward : -51.0
# 2020/10/06 16:16:45
# episode : 206 | final step : 102 | total reward : 99.0
# 2020/10/06 16:16:46
# episode : 207 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:47
# episode : 208 | final step : 97 | total reward : -51.0
# 2020/10/06 16:16:48
# episode : 209 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:49
# episode : 210 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:51
# episode : 211 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:52
# episode : 212 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:53
# episode : 213 | final step : 102 | total reward : 99.0
# 2020/10/06 16:16:54
# episode : 214 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:55
# episode : 215 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:56
# episode : 216 | final step : 98 | total reward : -51.0
# 2020/10/06 16:16:58
# episode : 217 | final step : 99 | total reward : 99.0
# 2020/10/06 16:16:59
# episode : 218 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:00
# episode : 219 | final step : 99 | total reward : 99.0
# 2020/10/06 16:17:01
# episode : 220 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:02
# episode : 221 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:03
# episode : 222 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:04
# episode : 223 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:05
# episode : 224 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:06
# episode : 225 | final step : 97 | total reward : -51.0
# 2020/10/06 16:17:07
# episode : 226 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:08
# episode : 227 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:09
# episode : 228 | final step : 98 | total reward : 99.0
# 2020/10/06 16:17:10
# episode : 229 | final step : 99 | total reward : -51.0
# 2020/10/06 16:17:11
# episode : 230 | final step : 97 | total reward : -51.0
# 2020/10/06 16:17:12
# episode : 231 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:13
# episode : 232 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:14
# episode : 233 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:15
# episode : 234 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:16
# episode : 235 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:17
# episode : 236 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:17
# episode : 237 | final step : 99 | total reward : -51.0
# 2020/10/06 16:17:18
# episode : 238 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:19
# episode : 239 | final step : 99 | total reward : 99.0
# 2020/10/06 16:17:20
# episode : 240 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:22
# episode : 241 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:23
# episode : 242 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:24
# episode : 243 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:25
# episode : 244 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:26
# episode : 245 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:27
# episode : 246 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:28
# episode : 247 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:29
# episode : 248 | final step : 99 | total reward : -51.0
# 2020/10/06 16:17:30
# episode : 249 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:31
# episode : 250 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:32
# episode : 251 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:33
# episode : 252 | final step : 100 | total reward : -51.0
# 2020/10/06 16:17:34
# episode : 253 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:35
# episode : 254 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:36
# episode : 255 | final step : 101 | total reward : 99.0
# 2020/10/06 16:17:38
# episode : 256 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:39
# episode : 257 | final step : 97 | total reward : -51.0
# 2020/10/06 16:17:41
# episode : 258 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:42
# episode : 259 | final step : 97 | total reward : -51.0
# 2020/10/06 16:17:43
# episode : 260 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:44
# episode : 261 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:45
# episode : 262 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:46
# episode : 263 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:47
# episode : 264 | final step : 102 | total reward : 99.0
# 2020/10/06 16:17:48
# episode : 265 | final step : 99 | total reward : 99.0
# 2020/10/06 16:17:49
# episode : 266 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:50
# episode : 267 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:51
# episode : 268 | final step : 102 | total reward : 99.0
# 2020/10/06 16:17:52
# episode : 269 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:53
# episode : 270 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:55
# episode : 271 | final step : 97 | total reward : -51.0
# 2020/10/06 16:17:56
# episode : 272 | final step : 100 | total reward : 99.0
# 2020/10/06 16:17:57
# episode : 273 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:58
# episode : 274 | final step : 98 | total reward : -51.0
# 2020/10/06 16:17:59
# episode : 275 | final step : 100 | total reward : 99.0
# 2020/10/06 16:18:00
# episode : 276 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:02
# episode : 277 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:03
# episode : 278 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:04
# episode : 279 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:04
# episode : 280 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:05
# episode : 281 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:06
# episode : 282 | final step : 99 | total reward : -51.0
# 2020/10/06 16:18:07
# episode : 283 | final step : 98 | total reward : -52.0
# 2020/10/06 16:18:09
# episode : 284 | final step : 99 | total reward : -51.0
# 2020/10/06 16:18:10
# episode : 285 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:11
# episode : 286 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:12
# episode : 287 | final step : 99 | total reward : -51.0
# 2020/10/06 16:18:13
# episode : 288 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:14
# episode : 289 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:14
# episode : 290 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:15
# episode : 291 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:17
# episode : 292 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:17
# episode : 293 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:19
# episode : 294 | final step : 100 | total reward : -51.0
# 2020/10/06 16:18:20
# episode : 295 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:20
# episode : 296 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:21
# episode : 297 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:22
# episode : 298 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:23
# episode : 299 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:25
# episode : 300 | final step : 99 | total reward : -51.0
# 2020/10/06 16:18:25
# episode : 301 | final step : 99 | total reward : -51.0
# 2020/10/06 16:18:27
# episode : 302 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:28
# episode : 303 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:29
# episode : 304 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:30
# episode : 305 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:31
# episode : 306 | final step : 100 | total reward : -51.0
# 2020/10/06 16:18:32
# episode : 307 | final step : 99 | total reward : -51.0
# 2020/10/06 16:18:33
# episode : 308 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:34
# episode : 309 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:35
# episode : 310 | final step : 100 | total reward : 99.0
# 2020/10/06 16:18:36
# episode : 311 | final step : 103 | total reward : 99.0
# 2020/10/06 16:18:37
# episode : 312 | final step : 100 | total reward : -51.0
# 2020/10/06 16:18:38
# episode : 313 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:39
# episode : 314 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:40
# episode : 315 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:41
# episode : 316 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:42
# episode : 317 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:43
# episode : 318 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:44
# episode : 319 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:45
# episode : 320 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:46
# episode : 321 | final step : 99 | total reward : 99.0
# 2020/10/06 16:18:47
# episode : 322 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:48
# episode : 323 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:49
# episode : 324 | final step : 99 | total reward : 99.0
# 2020/10/06 16:18:51
# episode : 325 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:52
# episode : 326 | final step : 99 | total reward : -51.0
# 2020/10/06 16:18:53
# episode : 327 | final step : 99 | total reward : -51.0
# 2020/10/06 16:18:54
# episode : 328 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:55
# episode : 329 | final step : 99 | total reward : 99.0
# 2020/10/06 16:18:56
# episode : 330 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:57
# episode : 331 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:58
# episode : 332 | final step : 98 | total reward : -51.0
# 2020/10/06 16:18:59
# episode : 333 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:00
# episode : 334 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:01
# episode : 335 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:02
# episode : 336 | final step : 103 | total reward : 99.0
# 2020/10/06 16:19:03
# episode : 337 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:04
# episode : 338 | final step : 96 | total reward : 99.0
# 2020/10/06 16:19:05
# episode : 339 | final step : 99 | total reward : 99.0
# 2020/10/06 16:19:06
# episode : 340 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:07
# episode : 341 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:08
# episode : 342 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:09
# episode : 343 | final step : 97 | total reward : -51.0
# 2020/10/06 16:19:10
# episode : 344 | final step : 100 | total reward : 99.0
# 2020/10/06 16:19:11
# episode : 345 | final step : 99 | total reward : 99.0
# 2020/10/06 16:19:12
# episode : 346 | final step : 100 | total reward : -51.0
# 2020/10/06 16:19:13
# episode : 347 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:14
# episode : 348 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:15
# episode : 349 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:16
# episode : 350 | final step : 100 | total reward : 99.0
# 2020/10/06 16:19:17
# episode : 351 | final step : 99 | total reward : 99.0
# 2020/10/06 16:19:18
# episode : 352 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:19
# episode : 353 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:20
# episode : 354 | final step : 97 | total reward : -51.0
# 2020/10/06 16:19:21
# episode : 355 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:22
# episode : 356 | final step : 104 | total reward : 99.0
# 2020/10/06 16:19:23
# episode : 357 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:24
# episode : 358 | final step : 103 | total reward : 99.0
# 2020/10/06 16:19:25
# episode : 359 | final step : 100 | total reward : -51.0
# 2020/10/06 16:19:26
# episode : 360 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:27
# episode : 361 | final step : 99 | total reward : -51.0
# 2020/10/06 16:19:29
# episode : 362 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:30
# episode : 363 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:31
# episode : 364 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:32
# episode : 365 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:33
# episode : 366 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:34
# episode : 367 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:35
# episode : 368 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:36
# episode : 369 | final step : 97 | total reward : -51.0
# 2020/10/06 16:19:37
# episode : 370 | final step : 99 | total reward : -51.0
# 2020/10/06 16:19:39
# episode : 371 | final step : 100 | total reward : 99.0
# 2020/10/06 16:19:39
# episode : 372 | final step : 98 | total reward : 99.0
# 2020/10/06 16:19:41
# episode : 373 | final step : 101 | total reward : 99.0
# 2020/10/06 16:19:41
# episode : 374 | final step : 103 | total reward : 98.0
# 2020/10/06 16:19:43
# episode : 375 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:43
# episode : 376 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:44
# episode : 377 | final step : 97 | total reward : -51.0
# 2020/10/06 16:19:45
# episode : 378 | final step : 101 | total reward : 99.0
# 2020/10/06 16:19:46
# episode : 379 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:47
# episode : 380 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:48
# episode : 381 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:49
# episode : 382 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:50
# episode : 383 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:51
# episode : 384 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:53
# episode : 385 | final step : 104 | total reward : 99.0
# 2020/10/06 16:19:54
# episode : 386 | final step : 99 | total reward : -51.0
# 2020/10/06 16:19:55
# episode : 387 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:56
# episode : 388 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:57
# episode : 389 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:58
# episode : 390 | final step : 98 | total reward : -51.0
# 2020/10/06 16:19:59
# episode : 391 | final step : 99 | total reward : 99.0
# 2020/10/06 16:20:01
# episode : 392 | final step : 102 | total reward : 99.0
# 2020/10/06 16:20:02
# episode : 393 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:03
# episode : 394 | final step : 101 | total reward : 99.0
# 2020/10/06 16:20:04
# episode : 395 | final step : 98 | total reward : 99.0
# 2020/10/06 16:20:05
# episode : 396 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:06
# episode : 397 | final step : 100 | total reward : 99.0
# 2020/10/06 16:20:07
# episode : 398 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:08
# episode : 399 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:09
# episode : 400 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:10
# episode : 401 | final step : 99 | total reward : -51.0
# 2020/10/06 16:20:11
# episode : 402 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:12
# episode : 403 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:13
# episode : 404 | final step : 99 | total reward : -51.0
# 2020/10/06 16:20:14
# episode : 405 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:15
# episode : 406 | final step : 99 | total reward : -51.0
# 2020/10/06 16:20:16
# episode : 407 | final step : 100 | total reward : 99.0
# 2020/10/06 16:20:17
# episode : 408 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:18
# episode : 409 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:19
# episode : 410 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:20
# episode : 411 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:21
# episode : 412 | final step : 100 | total reward : -51.0
# 2020/10/06 16:20:22
# episode : 413 | final step : 100 | total reward : 99.0
# 2020/10/06 16:20:23
# episode : 414 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:24
# episode : 415 | final step : 97 | total reward : -51.0
# 2020/10/06 16:20:25
# episode : 416 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:26
# episode : 417 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:27
# episode : 418 | final step : 100 | total reward : -51.0
# 2020/10/06 16:20:28
# episode : 419 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:29
# episode : 420 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:30
# episode : 421 | final step : 99 | total reward : -51.0
# 2020/10/06 16:20:31
# episode : 422 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:33
# episode : 423 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:34
# episode : 424 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:35
# episode : 425 | final step : 100 | total reward : 99.0
# 2020/10/06 16:20:36
# episode : 426 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:37
# episode : 427 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:38
# episode : 428 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:39
# episode : 429 | final step : 99 | total reward : 99.0
# 2020/10/06 16:20:40
# episode : 430 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:41
# episode : 431 | final step : 100 | total reward : -51.0
# 2020/10/06 16:20:42
# episode : 432 | final step : 99 | total reward : -51.0
# 2020/10/06 16:20:43
# episode : 433 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:44
# episode : 434 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:45
# episode : 435 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:46
# episode : 436 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:47
# episode : 437 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:48
# episode : 438 | final step : 99 | total reward : -51.0
# 2020/10/06 16:20:50
# episode : 439 | final step : 101 | total reward : 99.0
# 2020/10/06 16:20:51
# episode : 440 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:52
# episode : 441 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:54
# episode : 442 | final step : 99 | total reward : 99.0
# 2020/10/06 16:20:55
# episode : 443 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:56
# episode : 444 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:57
# episode : 445 | final step : 98 | total reward : -51.0
# 2020/10/06 16:20:58
# episode : 446 | final step : 99 | total reward : -51.0
# 2020/10/06 16:20:59
# episode : 447 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:00
# episode : 448 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:01
# episode : 449 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:02
# episode : 450 | final step : 101 | total reward : 99.0
# 2020/10/06 16:21:03
# episode : 451 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:04
# episode : 452 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:05
# episode : 453 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:06
# episode : 454 | final step : 99 | total reward : -51.0
# 2020/10/06 16:21:07
# episode : 455 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:08
# episode : 456 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:09
# episode : 457 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:10
# episode : 458 | final step : 99 | total reward : -51.0
# 2020/10/06 16:21:12
# episode : 459 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:13
# episode : 460 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:14
# episode : 461 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:15
# episode : 462 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:16
# episode : 463 | final step : 97 | total reward : -51.0
# 2020/10/06 16:21:17
# episode : 464 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:18
# episode : 465 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:19
# episode : 466 | final step : 103 | total reward : 99.0
# 2020/10/06 16:21:20
# episode : 467 | final step : 101 | total reward : 99.0
# 2020/10/06 16:21:21
# episode : 468 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:22
# episode : 469 | final step : 99 | total reward : -51.0
# 2020/10/06 16:21:23
# episode : 470 | final step : 100 | total reward : 99.0
# 2020/10/06 16:21:24
# episode : 471 | final step : 97 | total reward : -51.0
# 2020/10/06 16:21:25
# episode : 472 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:26
# episode : 473 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:27
# episode : 474 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:28
# episode : 475 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:29
# episode : 476 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:30
# episode : 477 | final step : 100 | total reward : -51.0
# 2020/10/06 16:21:32
# episode : 478 | final step : 100 | total reward : 99.0
# 2020/10/06 16:21:33
# episode : 479 | final step : 99 | total reward : 99.0
# 2020/10/06 16:21:34
# episode : 480 | final step : 100 | total reward : -51.0
# 2020/10/06 16:21:35
# episode : 481 | final step : 101 | total reward : 99.0
# 2020/10/06 16:21:36
# episode : 482 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:37
# episode : 483 | final step : 101 | total reward : 99.0
# 2020/10/06 16:21:38
# episode : 484 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:39
# episode : 485 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:40
# episode : 486 | final step : 97 | total reward : -51.0
# 2020/10/06 16:21:41
# episode : 487 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:42
# episode : 488 | final step : 100 | total reward : 99.0
# 2020/10/06 16:21:43
# episode : 489 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:44
# episode : 490 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:45
# episode : 491 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:47
# episode : 492 | final step : 100 | total reward : -51.0
# 2020/10/06 16:21:48
# episode : 493 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:49
# episode : 494 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:50
# episode : 495 | final step : 99 | total reward : -51.0
# 2020/10/06 16:21:51
# episode : 496 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:52
# episode : 497 | final step : 100 | total reward : -51.0
# 2020/10/06 16:21:53
# episode : 498 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:54
# episode : 499 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:55
# episode : 500 | final step : 99 | total reward : -51.0
# 2020/10/06 16:21:56
# episode : 501 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:57
# episode : 502 | final step : 99 | total reward : -51.0
# 2020/10/06 16:21:58
# episode : 503 | final step : 98 | total reward : -51.0
# 2020/10/06 16:21:59
# episode : 504 | final step : 100 | total reward : 99.0
# 2020/10/06 16:22:00
# episode : 505 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:01
# episode : 506 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:02
# episode : 507 | final step : 98 | total reward : 99.0
# 2020/10/06 16:22:03
# episode : 508 | final step : 99 | total reward : -51.0
# 2020/10/06 16:22:04
# episode : 509 | final step : 100 | total reward : -51.0
# 2020/10/06 16:22:05
# episode : 510 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:06
# episode : 511 | final step : 99 | total reward : -51.0
# 2020/10/06 16:22:07
# episode : 512 | final step : 99 | total reward : -51.0
# 2020/10/06 16:22:08
# episode : 513 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:09
# episode : 514 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:10
# episode : 515 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:11
# episode : 516 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:12
# episode : 517 | final step : 97 | total reward : -51.0
# 2020/10/06 16:22:14
# episode : 518 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:15
# episode : 519 | final step : 99 | total reward : -51.0
# 2020/10/06 16:22:16
# episode : 520 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:17
# episode : 521 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:18
# episode : 522 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:19
# episode : 523 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:20
# episode : 524 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:22
# episode : 525 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:23
# episode : 526 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:24
# episode : 527 | final step : 97 | total reward : -51.0
# 2020/10/06 16:22:25
# episode : 528 | final step : 100 | total reward : 99.0
# 2020/10/06 16:22:26
# episode : 529 | final step : 99 | total reward : -51.0
# 2020/10/06 16:22:27
# episode : 530 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:28
# episode : 531 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:30
# episode : 532 | final step : 99 | total reward : -51.0
# 2020/10/06 16:22:31
# episode : 533 | final step : 99 | total reward : -51.0
# 2020/10/06 16:22:32
# episode : 534 | final step : 99 | total reward : -51.0
# 2020/10/06 16:22:33
# episode : 535 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:34
# episode : 536 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:35
# episode : 537 | final step : 101 | total reward : 99.0
# 2020/10/06 16:22:36
# episode : 538 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:37
# episode : 539 | final step : 97 | total reward : -51.0
# 2020/10/06 16:22:38
# episode : 540 | final step : 99 | total reward : -51.0
# 2020/10/06 16:22:40
# episode : 541 | final step : 102 | total reward : 99.0
# 2020/10/06 16:22:41
# episode : 542 | final step : 97 | total reward : -51.0
# 2020/10/06 16:22:42
# episode : 543 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:43
# episode : 544 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:44
# episode : 545 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:45
# episode : 546 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:46
# episode : 547 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:47
# episode : 548 | final step : 97 | total reward : 99.0
# 2020/10/06 16:22:48
# episode : 549 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:50
# episode : 550 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:51
# episode : 551 | final step : 99 | total reward : -51.0
# 2020/10/06 16:22:52
# episode : 552 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:54
# episode : 553 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:55
# episode : 554 | final step : 98 | total reward : 99.0
# 2020/10/06 16:22:56
# episode : 555 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:57
# episode : 556 | final step : 98 | total reward : -51.0
# 2020/10/06 16:22:58
# episode : 557 | final step : 100 | total reward : -51.0
# 2020/10/06 16:22:59
# episode : 558 | final step : 99 | total reward : 99.0
# 2020/10/06 16:23:00
# episode : 559 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:02
# episode : 560 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:03
# episode : 561 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:05
# episode : 562 | final step : 97 | total reward : -51.0
# 2020/10/06 16:23:06
# episode : 563 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:07
# episode : 564 | final step : 97 | total reward : -51.0
# 2020/10/06 16:23:08
# episode : 565 | final step : 100 | total reward : 99.0
# 2020/10/06 16:23:09
# episode : 566 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:10
# episode : 567 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:11
# episode : 568 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:12
# episode : 569 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:14
# episode : 570 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:15
# episode : 571 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:16
# episode : 572 | final step : 101 | total reward : 99.0
# 2020/10/06 16:23:17
# episode : 573 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:18
# episode : 574 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:19
# episode : 575 | final step : 101 | total reward : 99.0
# 2020/10/06 16:23:20
# episode : 576 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:21
# episode : 577 | final step : 99 | total reward : 99.0
# 2020/10/06 16:23:23
# episode : 578 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:24
# episode : 579 | final step : 99 | total reward : -51.0
# 2020/10/06 16:23:25
# episode : 580 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:27
# episode : 581 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:28
# episode : 582 | final step : 100 | total reward : -51.0
# 2020/10/06 16:23:29
# episode : 583 | final step : 99 | total reward : -51.0
# 2020/10/06 16:23:30
# episode : 584 | final step : 99 | total reward : 99.0
# 2020/10/06 16:23:31
# episode : 585 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:32
# episode : 586 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:33
# episode : 587 | final step : 99 | total reward : -51.0
# 2020/10/06 16:23:34
# episode : 588 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:35
# episode : 589 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:36
# episode : 590 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:38
# episode : 591 | final step : 97 | total reward : -51.0
# 2020/10/06 16:23:39
# episode : 592 | final step : 97 | total reward : -51.0
# 2020/10/06 16:23:40
# episode : 593 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:41
# episode : 594 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:42
# episode : 595 | final step : 99 | total reward : -51.0
# 2020/10/06 16:23:43
# episode : 596 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:44
# episode : 597 | final step : 100 | total reward : 99.0
# 2020/10/06 16:23:45
# episode : 598 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:46
# episode : 599 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:48
# episode : 600 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:49
# episode : 601 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:50
# episode : 602 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:51
# episode : 603 | final step : 99 | total reward : -51.0
# 2020/10/06 16:23:52
# episode : 604 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:53
# episode : 605 | final step : 97 | total reward : -51.0
# 2020/10/06 16:23:54
# episode : 606 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:55
# episode : 607 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:56
# episode : 608 | final step : 99 | total reward : -51.0
# 2020/10/06 16:23:57
# episode : 609 | final step : 98 | total reward : -51.0
# 2020/10/06 16:23:58
# episode : 610 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:00
# episode : 611 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:01
# episode : 612 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:02
# episode : 613 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:03
# episode : 614 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:04
# episode : 615 | final step : 99 | total reward : -51.0
# 2020/10/06 16:24:05
# episode : 616 | final step : 97 | total reward : -51.0
# 2020/10/06 16:24:06
# episode : 617 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:07
# episode : 618 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:08
# episode : 619 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:10
# episode : 620 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:11
# episode : 621 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:12
# episode : 622 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:13
# episode : 623 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:14
# episode : 624 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:15
# episode : 625 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:16
# episode : 626 | final step : 103 | total reward : 99.0
# 2020/10/06 16:24:17
# episode : 627 | final step : 97 | total reward : -51.0
# 2020/10/06 16:24:19
# episode : 628 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:20
# episode : 629 | final step : 99 | total reward : -51.0
# 2020/10/06 16:24:21
# episode : 630 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:22
# episode : 631 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:23
# episode : 632 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:25
# episode : 633 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:26
# episode : 634 | final step : 98 | total reward : -51.0
# 2020/10/06 16:24:27
# episode : 635 | final step : 102 | total reward : 99.0
# 2020/10/06 16:24:28
# ...
# 2020/10/06 16:27:17
# episode : 787 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:18
# episode : 788 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:19
# episode : 789 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:20
# episode : 790 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:22
# episode : 791 | final step : 99 | total reward : -51.0
# 2020/10/06 16:27:23
# episode : 792 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:24
# episode : 793 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:25
# episode : 794 | final step : 99 | total reward : -51.0
# 2020/10/06 16:27:26
# episode : 795 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:27
# episode : 796 | final step : 97 | total reward : -51.0
# 2020/10/06 16:27:28
# episode : 797 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:30
# episode : 798 | final step : 100 | total reward : -51.0
# 2020/10/06 16:27:31
# episode : 799 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:32
# episode : 800 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:33
# episode : 801 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:34
# episode : 802 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:35
# episode : 803 | final step : 99 | total reward : -51.0
# 2020/10/06 16:27:36
# episode : 804 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:37
# episode : 805 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:38
# episode : 806 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:40
# episode : 807 | final step : 101 | total reward : 99.0
# 2020/10/06 16:27:41
# episode : 808 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:42
# episode : 809 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:43
# episode : 810 | final step : 97 | total reward : -51.0
# 2020/10/06 16:27:44
# episode : 811 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:46
# episode : 812 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:47
# episode : 813 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:48
# episode : 814 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:49
# episode : 815 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:50
# episode : 816 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:52
# episode : 817 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:53
# episode : 818 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:54
# episode : 819 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:55
# episode : 820 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:57
# episode : 821 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:58
# episode : 822 | final step : 98 | total reward : -51.0
# 2020/10/06 16:27:59
# episode : 823 | final step : 99 | total reward : -51.0
# 2020/10/06 16:28:00
# episode : 824 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:01
# episode : 825 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:02
# episode : 826 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:03
# episode : 827 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:05
# episode : 828 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:06
# episode : 829 | final step : 100 | total reward : -51.0
# 2020/10/06 16:28:07
# episode : 830 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:08
# episode : 831 | final step : 99 | total reward : -51.0
# 2020/10/06 16:28:09
# episode : 832 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:10
# episode : 833 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:11
# episode : 834 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:12
# episode : 835 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:13
# episode : 836 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:15
# episode : 837 | final step : 99 | total reward : -51.0
# 2020/10/06 16:28:16
# episode : 838 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:18
# episode : 839 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:19
# episode : 840 | final step : 99 | total reward : 99.0
# 2020/10/06 16:28:20
# episode : 841 | final step : 99 | total reward : -51.0
# 2020/10/06 16:28:21
# episode : 842 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:22
# episode : 843 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:23
# episode : 844 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:24
# episode : 845 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:25
# episode : 846 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:27
# episode : 847 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:28
# episode : 848 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:29
# episode : 849 | final step : 97 | total reward : -51.0
# 2020/10/06 16:28:30
# episode : 850 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:31
# episode : 851 | final step : 99 | total reward : -51.0
# 2020/10/06 16:28:32
# episode : 852 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:33
# episode : 853 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:35
# episode : 854 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:36
# episode : 855 | final step : 99 | total reward : -51.0
# 2020/10/06 16:28:37
# episode : 856 | final step : 102 | total reward : 99.0
# 2020/10/06 16:28:38
# episode : 857 | final step : 101 | total reward : 99.0
# 2020/10/06 16:28:39
# episode : 858 | final step : 101 | total reward : 99.0
# 2020/10/06 16:28:41
# episode : 859 | final step : 97 | total reward : -51.0
# 2020/10/06 16:28:42
# episode : 860 | final step : 99 | total reward : -51.0
# 2020/10/06 16:28:43
# episode : 861 | final step : 99 | total reward : -51.0
# 2020/10/06 16:28:44
# episode : 862 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:45
# episode : 863 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:47
# episode : 864 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:48
# episode : 865 | final step : 98 | total reward : 99.0
# 2020/10/06 16:28:49
# episode : 866 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:50
# episode : 867 | final step : 100 | total reward : 99.0
# 2020/10/06 16:28:51
# episode : 868 | final step : 99 | total reward : -51.0
# 2020/10/06 16:28:52
# episode : 869 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:53
# episode : 870 | final step : 98 | total reward : 99.0
# 2020/10/06 16:28:55
# episode : 871 | final step : 98 | total reward : -51.0
# 2020/10/06 16:28:56
# episode : 872 | final step : 99 | total reward : -51.0
# 2020/10/06 16:28:57
# episode : 873 | final step : 99 | total reward : -51.0
# 2020/10/06 16:28:58
# episode : 874 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:00
# episode : 875 | final step : 99 | total reward : -51.0
# 2020/10/06 16:29:01
# episode : 876 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:02
# episode : 877 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:03
# episode : 878 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:04
# episode : 879 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:06
# episode : 880 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:07
# episode : 881 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:08
# episode : 882 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:10
# episode : 883 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:11
# episode : 884 | final step : 99 | total reward : -51.0
# 2020/10/06 16:29:12
# episode : 885 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:13
# episode : 886 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:14
# episode : 887 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:15
# episode : 888 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:16
# episode : 889 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:18
# episode : 890 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:19
# episode : 891 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:20
# episode : 892 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:21
# episode : 893 | final step : 97 | total reward : -51.0
# 2020/10/06 16:29:22
# episode : 894 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:23
# episode : 895 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:24
# episode : 896 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:25
# episode : 897 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:27
# episode : 898 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:28
# episode : 899 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:29
# episode : 900 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:30
# episode : 901 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:31
# episode : 902 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:32
# episode : 903 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:34
# episode : 904 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:35
# episode : 905 | final step : 101 | total reward : 99.0
# 2020/10/06 16:29:36
# episode : 906 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:37
# episode : 907 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:39
# episode : 908 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:40
# episode : 909 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:41
# episode : 910 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:42
# episode : 911 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:43
# episode : 912 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:44
# episode : 913 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:45
# episode : 914 | final step : 100 | total reward : -51.0
# 2020/10/06 16:29:46
# episode : 915 | final step : 102 | total reward : 99.0
# 2020/10/06 16:29:48
# episode : 916 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:49
# episode : 917 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:50
# episode : 918 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:52
# episode : 919 | final step : 97 | total reward : -51.0
# 2020/10/06 16:29:53
# episode : 920 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:54
# episode : 921 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:55
# episode : 922 | final step : 99 | total reward : -51.0
# 2020/10/06 16:29:56
# episode : 923 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:57
# episode : 924 | final step : 98 | total reward : -51.0
# 2020/10/06 16:29:58
# episode : 925 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:00
# episode : 926 | final step : 100 | total reward : -51.0
# 2020/10/06 16:30:01
# episode : 927 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:02
# episode : 928 | final step : 98 | total reward : 99.0
# 2020/10/06 16:30:04
# episode : 929 | final step : 104 | total reward : 99.0
# 2020/10/06 16:30:05
# episode : 930 | final step : 102 | total reward : 99.0
# 2020/10/06 16:30:06
# episode : 931 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:07
# episode : 932 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:08
# episode : 933 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:09
# episode : 934 | final step : 102 | total reward : 99.0
# 2020/10/06 16:30:10
# episode : 935 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:11
# episode : 936 | final step : 97 | total reward : -51.0
# 2020/10/06 16:30:12
# episode : 937 | final step : 97 | total reward : -51.0
# 2020/10/06 16:30:13
# episode : 938 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:14
# episode : 939 | final step : 97 | total reward : -51.0
# 2020/10/06 16:30:16
# episode : 940 | final step : 100 | total reward : -51.0
# 2020/10/06 16:30:17
# episode : 941 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:18
# episode : 942 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:19
# episode : 943 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:20
# episode : 944 | final step : 97 | total reward : -51.0
# 2020/10/06 16:30:21
# episode : 945 | final step : 97 | total reward : -51.0
# 2020/10/06 16:30:23
# episode : 946 | final step : 100 | total reward : 99.0
# 2020/10/06 16:30:24
# episode : 947 | final step : 97 | total reward : -51.0
# 2020/10/06 16:30:25
# episode : 948 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:26
# episode : 949 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:27
# episode : 950 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:28
# episode : 951 | final step : 101 | total reward : 99.0
# 2020/10/06 16:30:29
# episode : 952 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:30
# episode : 953 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:31
# episode : 954 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:32
# episode : 955 | final step : 98 | total reward : 99.0
# 2020/10/06 16:30:33
# episode : 956 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:34
# episode : 957 | final step : 97 | total reward : -51.0
# 2020/10/06 16:30:35
# episode : 958 | final step : 97 | total reward : -51.0
# 2020/10/06 16:30:37
# episode : 959 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:38
# episode : 960 | final step : 99 | total reward : -51.0
# 2020/10/06 16:30:39
# episode : 961 | final step : 99 | total reward : -51.0
# 2020/10/06 16:30:40
# episode : 962 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:41
# episode : 963 | final step : 99 | total reward : -51.0
# 2020/10/06 16:30:42
# episode : 964 | final step : 99 | total reward : -51.0
# 2020/10/06 16:30:44
# episode : 965 | final step : 97 | total reward : -51.0
# 2020/10/06 16:30:45
# episode : 966 | final step : 99 | total reward : -51.0
# 2020/10/06 16:30:46
# episode : 967 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:47
# episode : 968 | final step : 97 | total reward : -51.0
# 2020/10/06 16:30:48
# episode : 969 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:49
# episode : 970 | final step : 97 | total reward : -51.0
# 2020/10/06 16:30:51
# episode : 971 | final step : 100 | total reward : -51.0
# 2020/10/06 16:30:52
# episode : 972 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:53
# episode : 973 | final step : 99 | total reward : -51.0
# 2020/10/06 16:30:54
# episode : 974 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:55
# episode : 975 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:56
# episode : 976 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:57
# episode : 977 | final step : 98 | total reward : -51.0
# 2020/10/06 16:30:58
# episode : 978 | final step : 98 | total reward : 99.0
# 2020/10/06 16:30:59
# episode : 979 | final step : 98 | total reward : -51.0
# 2020/10/06 16:31:00
# episode : 980 | final step : 99 | total reward : -51.0
# 2020/10/06 16:31:01
# episode : 981 | final step : 100 | total reward : 99.0
# 2020/10/06 16:31:02
# episode : 982 | final step : 101 | total reward : -51.0
# 2020/10/06 16:31:03
# episode : 983 | final step : 98 | total reward : -51.0
# 2020/10/06 16:31:04
# episode : 984 | final step : 98 | total reward : -51.0
# 2020/10/06 16:31:05
# episode : 985 | final step : 98 | total reward : -51.0
# 2020/10/06 16:31:06
# episode : 986 | final step : 99 | total reward : -51.0
# 2020/10/06 16:31:07
# episode : 987 | final step : 98 | total reward : -51.0
# 2020/10/06 16:31:08
# episode : 988 | final step : 98 | total reward : -51.0
# 2020/10/06 16:31:10
# episode : 989 | final step : 99 | total reward : -51.0
# 2020/10/06 16:31:11
# episode : 990 | final step : 99 | total reward : -51.0
# 2020/10/06 16:31:12
# episode : 991 | final step : 98 | total reward : -51.0
# 2020/10/06 16:31:13
# episode : 992 | final step : 98 | total reward : -51.0
# 2020/10/06 16:31:14
# episode : 993 | final step : 103 | total reward : 99.0
# 2020/10/06 16:31:15
# episode : 994 | final step : 98 | total reward : -51.0
# 2020/10/06 16:31:16
# episode : 995 | final step : 99 | total reward : 99.0
# 2020/10/06 16:31:17
# episode : 996 | final step : 98 | total reward : -51.0
# 2020/10/06 16:31:18
# episode : 997 | final step : 99 | total reward : -51.0
# 2020/10/06 16:31:20
# episode : 998 | final step : 98 | total reward : -51.0
# 2020/10/06 16:31:21
# episode : 999 | final step : 99 | total reward : -51.0
# Complete

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(reward_list)

# %%
def moving_average(data,n):
    len_data=len(data)-n
    res_data=np.zeros(len_data)

    for i in range(len_data):
        res_data[i]=sum(data[i:i+n])/n
    return res_data

# %%
average_number=100
filtered_data=moving_average(reward_list,average_number)
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(filtered_data)

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[999]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()
