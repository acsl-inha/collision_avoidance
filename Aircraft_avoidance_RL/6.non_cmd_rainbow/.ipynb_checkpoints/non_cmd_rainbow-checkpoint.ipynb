# %%
import math, random

import gym
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd 
import torch.nn.functional as F

from common.layers import NoisyLinear
from common.replay_buffer import ReplayBuffer
import gym_Aircraft

from itertools import count
import time
import itertools
import matplotlib
import matplotlib.pyplot as plt

# %%
USE_CUDA = torch.cuda.is_available()
Variable = lambda *args, **kwargs: autograd.Variable(*args, **kwargs).cuda() if USE_CUDA else autograd.Variable(*args, **kwargs)

# %%
env_id = "acav-v0"
env = gym.make(env_id)
# Out:
# /home/jupyter-kunwoopark/.local/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
class RainbowDQN(nn.Module):
    def __init__(self, num_inputs, num_actions, num_atoms, Vmin, Vmax):
        super(RainbowDQN, self).__init__()
        
        self.num_inputs   = num_inputs
        self.num_actions  = num_actions
        self.num_atoms    = num_atoms
        self.Vmin         = Vmin
        self.Vmax         = Vmax
        
        self.linear1 = nn.Linear(num_inputs, 32)
        self.linear2 = nn.Linear(32, 64)
        
        self.noisy_value1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_value2 = NoisyLinear(64, self.num_atoms, use_cuda=USE_CUDA)
        
        self.noisy_advantage1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_advantage2 = NoisyLinear(64, self.num_atoms * self.num_actions, use_cuda=USE_CUDA)
        
    def forward(self, x):
        batch_size = x.size(0)
        
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        
        value = F.relu(self.noisy_value1(x))
        value = self.noisy_value2(value)
        
        advantage = F.relu(self.noisy_advantage1(x))
        advantage = self.noisy_advantage2(advantage)
        
        value     = value.view(batch_size, 1, self.num_atoms)
        advantage = advantage.view(batch_size, self.num_actions, self.num_atoms)
        
        x = value + advantage - advantage.mean(1, keepdim=True)
        x = F.softmax(x.view(-1, self.num_atoms)).view(-1, self.num_actions, self.num_atoms)
        
        return x
        
    def reset_noise(self):
        self.noisy_value1.reset_noise()
        self.noisy_value2.reset_noise()
        self.noisy_advantage1.reset_noise()
        self.noisy_advantage2.reset_noise()
    
    def act(self, state):
        state = Variable(torch.FloatTensor(state).unsqueeze(0), volatile=True)
        dist = self.forward(state).data.cpu()
        dist = dist * torch.linspace(self.Vmin, self.Vmax, self.num_atoms)
        action = dist.sum(2).max(1)[1].numpy()[0]
        return action

# %%
num_atoms = 51
Vmin = -10
Vmax = 10

current_model = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)
target_model  = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)

if USE_CUDA:
    current_model = current_model.cuda()
    target_model  = target_model.cuda()
    
optimizer = optim.Adam(current_model.parameters(), 0.001)

replay_buffer = ReplayBuffer(10000)

# %%
def update_target(current_model, target_model):
    target_model.load_state_dict(current_model.state_dict())
    
update_target(current_model, target_model)

# %%
def projection_distribution(next_state, rewards, dones):
    batch_size  = next_state.size(0)
    
    delta_z = float(Vmax - Vmin) / (num_atoms - 1)
    support = torch.linspace(Vmin, Vmax, num_atoms)
    
    next_dist   = target_model(next_state).data.cpu() * support
    next_action = next_dist.sum(2).max(1)[1]
    next_action = next_action.unsqueeze(1).unsqueeze(1).expand(next_dist.size(0), 1, next_dist.size(2))
    next_dist   = next_dist.gather(1, next_action).squeeze(1)
        
    rewards = rewards.unsqueeze(1).expand_as(next_dist)
    dones   = dones.unsqueeze(1).expand_as(next_dist)
    support = support.unsqueeze(0).expand_as(next_dist)
    
    Tz = rewards + (1 - dones) * 0.99 * support
    Tz = Tz.clamp(min=Vmin, max=Vmax)
    b  = (Tz - Vmin) / delta_z
    l  = b.floor().long()
    u  = b.ceil().long()
        
    offset = torch.linspace(0, (batch_size - 1) * num_atoms, batch_size).long()\
                    .unsqueeze(1).expand(batch_size, num_atoms)

    proj_dist = torch.zeros(next_dist.size())    
    proj_dist.view(-1).index_add_(0, (l + offset).view(-1), (next_dist * (u.float() - b)).view(-1))
    proj_dist.view(-1).index_add_(0, (u + offset).view(-1), (next_dist * (b - l.float())).view(-1))
        
    return proj_dist

# %%
def compute_td_loss(batch_size):
    state, action, reward, next_state, done = replay_buffer.sample(batch_size) 

    state      = Variable(torch.FloatTensor(np.float32(state)))
    next_state = Variable(torch.FloatTensor(np.float32(next_state)), volatile=True)
    action     = Variable(torch.LongTensor(action))
    reward     = torch.FloatTensor(reward)
    done       = torch.FloatTensor(np.float32(done))

    proj_dist = projection_distribution(next_state, reward, done)
    
    dist = current_model(state)
    action = action.unsqueeze(1).unsqueeze(1).expand(batch_size, 1, num_atoms)
    dist = dist.gather(1, action).squeeze(1)
    dist.data.clamp_(0.01, 0.99)
    loss = -(Variable(proj_dist) * dist.log()).sum(1)
    loss  = loss.mean()
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    current_model.reset_noise()
    target_model.reset_noise()
    
    return loss

# %%
num_episodes = 1000
batch_size = 32
gamma=0.99
TARGET_UPDATE=10

losses = []
total_res=[]
reward_list=[]
for i_episode in range(num_episodes):
    total_reward=0
    
    # 환경과 상태 초기화
    res_list=np.zeros(11)
    state = env.reset()

    for t in count():
        # 행동 선택과 수행
        
        action = current_model.act(state)
        
        next_state, reward, done, res = env.step(action)
        
        # 메모리에 변이 저장
        replay_buffer.push(state, action, reward, next_state, done)
        

        # 새로운 상태 관찰
        if not done:
            next_state = next_state
        else:
            next_state = None

        

        # 다음 상태로 이동
        state = next_state

     
        # Data save
        
        cmd_list,r_list,elev_list,azim_list,Pm_list,Pt_list,h_list=res
        Pm_list=Pm_list.tolist()
        Pt_list=Pt_list.tolist()
        merged_data=itertools.chain([cmd_list],[r_list],[elev_list],[azim_list],Pm_list,Pt_list,[h_list])
        merged_data=np.array(list(merged_data))
        res_list=np.vstack([res_list,merged_data])
        
        total_reward+=reward
        
        if done:
            res_list=np.delete(res_list,0,0)
            
            total_res.append(res_list)
            reward_list.append(total_reward)
            
            now = time.localtime()
            print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))
            print("episode : {} | final step : {} | total reward : {}".format(i_episode, t, total_reward))
            break
        if len(replay_buffer) > batch_size:
            loss = compute_td_loss(batch_size)
            losses.append(loss.item())
            
        
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        update_target(current_model, target_model)

print('Complete')
env.close()
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 2020/10/02 20:30:21
# episode : 0 | final step : 201 | total reward : -630
# 2020/10/02 20:30:22
# episode : 1 | final step : 99 | total reward : 0
# 2020/10/02 20:30:23
# episode : 2 | final step : 99 | total reward : -10
# 2020/10/02 20:30:25
# episode : 3 | final step : 201 | total reward : -10
# 2020/10/02 20:30:26
# episode : 4 | final step : 98 | total reward : -20
# 2020/10/02 20:30:27
# episode : 5 | final step : 201 | total reward : -10
# 2020/10/02 20:30:29
# episode : 6 | final step : 201 | total reward : -10
# 2020/10/02 20:30:31
# episode : 7 | final step : 201 | total reward : -30
# 2020/10/02 20:30:33
# episode : 8 | final step : 201 | total reward : -50
# 2020/10/02 20:30:35
# episode : 9 | final step : 201 | total reward : -60
# 2020/10/02 20:30:36
# episode : 10 | final step : 98 | total reward : -20
# 2020/10/02 20:30:37
# episode : 11 | final step : 201 | total reward : -20
# 2020/10/02 20:30:39
# episode : 12 | final step : 201 | total reward : -30
# 2020/10/02 20:30:40
# episode : 13 | final step : 99 | total reward : -10
# 2020/10/02 20:30:41
# episode : 14 | final step : 98 | total reward : -30
# 2020/10/02 20:30:43
# episode : 15 | final step : 201 | total reward : -80
# 2020/10/02 20:30:45
# episode : 16 | final step : 201 | total reward : -90
# 2020/10/02 20:30:47
# episode : 17 | final step : 201 | total reward : -10
# 2020/10/02 20:30:48
# episode : 18 | final step : 99 | total reward : 0
# 2020/10/02 20:30:49
# episode : 19 | final step : 201 | total reward : -30
# 2020/10/02 20:30:51
# episode : 20 | final step : 201 | total reward : -40
# 2020/10/02 20:30:53
# episode : 21 | final step : 201 | total reward : 0
# 2020/10/02 20:30:54
# episode : 22 | final step : 99 | total reward : -30
# 2020/10/02 20:30:56
# episode : 23 | final step : 201 | total reward : -10
# 2020/10/02 20:30:57
# episode : 24 | final step : 98 | total reward : 0
# 2020/10/02 20:30:58
# episode : 25 | final step : 99 | total reward : 0
# 2020/10/02 20:30:59
# episode : 26 | final step : 201 | total reward : -40
# 2020/10/02 20:31:01
# episode : 27 | final step : 201 | total reward : -20
# 2020/10/02 20:31:03
# episode : 28 | final step : 201 | total reward : 0
# 2020/10/02 20:31:05
# episode : 29 | final step : 201 | total reward : 0
# 2020/10/02 20:31:07
# episode : 30 | final step : 201 | total reward : -10
# 2020/10/02 20:31:09
# episode : 31 | final step : 201 | total reward : 0
# 2020/10/02 20:31:11
# episode : 32 | final step : 201 | total reward : 0
# 2020/10/02 20:31:13
# episode : 33 | final step : 201 | total reward : -10
# 2020/10/02 20:31:16
# episode : 34 | final step : 201 | total reward : 0
# 2020/10/02 20:31:19
# episode : 35 | final step : 201 | total reward : 0
# 2020/10/02 20:31:20
# episode : 36 | final step : 98 | total reward : 0
# 2020/10/02 20:31:23
# episode : 37 | final step : 201 | total reward : 0
# 2020/10/02 20:31:26
# episode : 38 | final step : 201 | total reward : 0
# 2020/10/02 20:31:29
# episode : 39 | final step : 201 | total reward : 0
# 2020/10/02 20:31:31
# episode : 40 | final step : 201 | total reward : 0
# 2020/10/02 20:31:34
# episode : 41 | final step : 201 | total reward : 0
# 2020/10/02 20:31:35
# episode : 42 | final step : 99 | total reward : 0
# 2020/10/02 20:31:38
# episode : 43 | final step : 201 | total reward : 0
# 2020/10/02 20:31:41
# episode : 44 | final step : 201 | total reward : 0
# 2020/10/02 20:31:42
# episode : 45 | final step : 100 | total reward : 0
# 2020/10/02 20:31:44
# episode : 46 | final step : 98 | total reward : 0
# 2020/10/02 20:31:46
# episode : 47 | final step : 201 | total reward : -10
# 2020/10/02 20:31:49
# episode : 48 | final step : 201 | total reward : 0
# 2020/10/02 20:31:51
# episode : 49 | final step : 99 | total reward : 0
# 2020/10/02 20:31:53
# episode : 50 | final step : 201 | total reward : 0
# 2020/10/02 20:31:55
# episode : 51 | final step : 99 | total reward : 0
# 2020/10/02 20:31:57
# episode : 52 | final step : 201 | total reward : 0
# 2020/10/02 20:32:00
# episode : 53 | final step : 201 | total reward : 0
# 2020/10/02 20:32:02
# episode : 54 | final step : 201 | total reward : 0
# 2020/10/02 20:32:03
# episode : 55 | final step : 98 | total reward : 0
# 2020/10/02 20:32:07
# episode : 56 | final step : 201 | total reward : 0
# 2020/10/02 20:32:09
# episode : 57 | final step : 201 | total reward : -10
# 2020/10/02 20:32:12
# episode : 58 | final step : 201 | total reward : 0
# 2020/10/02 20:32:15
# episode : 59 | final step : 201 | total reward : 0
# 2020/10/02 20:32:17
# episode : 60 | final step : 201 | total reward : 0
# 2020/10/02 20:32:20
# episode : 61 | final step : 201 | total reward : 0
# 2020/10/02 20:32:23
# episode : 62 | final step : 201 | total reward : 0
# 2020/10/02 20:32:24
# episode : 63 | final step : 99 | total reward : 0
# 2020/10/02 20:32:25
# episode : 64 | final step : 98 | total reward : 0
# 2020/10/02 20:32:28
# episode : 65 | final step : 201 | total reward : 0
# 2020/10/02 20:32:32
# episode : 66 | final step : 201 | total reward : 0
# 2020/10/02 20:32:34
# episode : 67 | final step : 201 | total reward : 0
# 2020/10/02 20:32:37
# episode : 68 | final step : 201 | total reward : 0
# 2020/10/02 20:32:39
# episode : 69 | final step : 201 | total reward : 0
# 2020/10/02 20:32:40
# episode : 70 | final step : 98 | total reward : 0
# 2020/10/02 20:32:42
# episode : 71 | final step : 99 | total reward : 0
# 2020/10/02 20:32:44
# episode : 72 | final step : 201 | total reward : 0
# 2020/10/02 20:32:47
# episode : 73 | final step : 201 | total reward : 0
# 2020/10/02 20:32:49
# episode : 74 | final step : 201 | total reward : 0
# 2020/10/02 20:32:52
# episode : 75 | final step : 201 | total reward : 0
# 2020/10/02 20:32:54
# episode : 76 | final step : 201 | total reward : 0
# 2020/10/02 20:32:57
# episode : 77 | final step : 201 | total reward : 0
# 2020/10/02 20:32:59
# episode : 78 | final step : 201 | total reward : 0
# 2020/10/02 20:33:02
# episode : 79 | final step : 201 | total reward : 0
# 2020/10/02 20:33:05
# episode : 80 | final step : 201 | total reward : -10
# 2020/10/02 20:33:08
# episode : 81 | final step : 201 | total reward : 0
# 2020/10/02 20:33:10
# episode : 82 | final step : 201 | total reward : 0
# 2020/10/02 20:33:11
# episode : 83 | final step : 98 | total reward : 0
# 2020/10/02 20:33:14
# episode : 84 | final step : 201 | total reward : 0
# 2020/10/02 20:33:16
# episode : 85 | final step : 201 | total reward : 0
# 2020/10/02 20:33:19
# episode : 86 | final step : 201 | total reward : 0
# 2020/10/02 20:33:21
# episode : 87 | final step : 201 | total reward : 0
# 2020/10/02 20:33:23
# episode : 88 | final step : 99 | total reward : 0
# 2020/10/02 20:33:24
# episode : 89 | final step : 99 | total reward : 0
# 2020/10/02 20:33:26
# episode : 90 | final step : 201 | total reward : 0
# 2020/10/02 20:33:29
# episode : 91 | final step : 201 | total reward : 0
# 2020/10/02 20:33:31
# episode : 92 | final step : 201 | total reward : 0
# 2020/10/02 20:33:34
# episode : 93 | final step : 201 | total reward : 0
# 2020/10/02 20:33:36
# episode : 94 | final step : 201 | total reward : 0
# 2020/10/02 20:33:39
# episode : 95 | final step : 201 | total reward : 0
# 2020/10/02 20:33:41
# episode : 96 | final step : 201 | total reward : 0
# 2020/10/02 20:33:43
# episode : 97 | final step : 98 | total reward : 0
# 2020/10/02 20:33:45
# episode : 98 | final step : 201 | total reward : 0
# 2020/10/02 20:33:47
# episode : 99 | final step : 201 | total reward : 0
# 2020/10/02 20:33:50
# episode : 100 | final step : 201 | total reward : 0
# 2020/10/02 20:33:53
# episode : 101 | final step : 201 | total reward : 0
# 2020/10/02 20:33:54
# episode : 102 | final step : 98 | total reward : 0
# 2020/10/02 20:33:56
# episode : 103 | final step : 201 | total reward : 0
# 2020/10/02 20:33:59
# episode : 104 | final step : 201 | total reward : 0
# 2020/10/02 20:34:00
# episode : 105 | final step : 98 | total reward : 0
# 2020/10/02 20:34:01
# episode : 106 | final step : 99 | total reward : 0
# 2020/10/02 20:34:05
# episode : 107 | final step : 201 | total reward : 0
# 2020/10/02 20:34:08
# episode : 108 | final step : 201 | total reward : 0
# 2020/10/02 20:34:10
# episode : 109 | final step : 201 | total reward : 0
# 2020/10/02 20:34:13
# episode : 110 | final step : 201 | total reward : 0
# 2020/10/02 20:34:16
# episode : 111 | final step : 201 | total reward : 0
# 2020/10/02 20:34:18
# episode : 112 | final step : 201 | total reward : 0
# 2020/10/02 20:34:21
# episode : 113 | final step : 201 | total reward : 0
# 2020/10/02 20:34:23
# episode : 114 | final step : 201 | total reward : 0
# 2020/10/02 20:34:26
# episode : 115 | final step : 201 | total reward : 0
# 2020/10/02 20:34:27
# episode : 116 | final step : 98 | total reward : 0
# 2020/10/02 20:34:29
# episode : 117 | final step : 201 | total reward : 0
# 2020/10/02 20:34:32
# episode : 118 | final step : 201 | total reward : 0
# 2020/10/02 20:34:35
# episode : 119 | final step : 201 | total reward : 0
# 2020/10/02 20:34:36
# episode : 120 | final step : 98 | total reward : 0
# 2020/10/02 20:34:38
# episode : 121 | final step : 201 | total reward : 0
# 2020/10/02 20:34:41
# episode : 122 | final step : 201 | total reward : 0
# 2020/10/02 20:34:42
# episode : 123 | final step : 98 | total reward : 0
# 2020/10/02 20:34:45
# episode : 124 | final step : 201 | total reward : 0
# 2020/10/02 20:34:47
# episode : 125 | final step : 201 | total reward : 0
# 2020/10/02 20:34:48
# episode : 126 | final step : 98 | total reward : 0
# 2020/10/02 20:34:50
# episode : 127 | final step : 98 | total reward : 0
# 2020/10/02 20:34:52
# episode : 128 | final step : 201 | total reward : 0
# 2020/10/02 20:34:55
# episode : 129 | final step : 201 | total reward : 0
# 2020/10/02 20:34:57
# episode : 130 | final step : 201 | total reward : 0
# 2020/10/02 20:35:00
# episode : 131 | final step : 201 | total reward : 0
# 2020/10/02 20:35:02
# episode : 132 | final step : 201 | total reward : 0
# 2020/10/02 20:35:05
# episode : 133 | final step : 201 | total reward : 0
# 2020/10/02 20:35:08
# episode : 134 | final step : 201 | total reward : 0
# 2020/10/02 20:35:10
# episode : 135 | final step : 201 | total reward : 0
# 2020/10/02 20:35:13
# episode : 136 | final step : 201 | total reward : 0
# 2020/10/02 20:35:16
# episode : 137 | final step : 201 | total reward : 0
# 2020/10/02 20:35:19
# episode : 138 | final step : 201 | total reward : 0
# 2020/10/02 20:35:22
# episode : 139 | final step : 201 | total reward : 0
# 2020/10/02 20:35:24
# episode : 140 | final step : 201 | total reward : 0
# 2020/10/02 20:35:27
# episode : 141 | final step : 201 | total reward : 0
# 2020/10/02 20:35:30
# episode : 142 | final step : 201 | total reward : 0
# 2020/10/02 20:35:31
# episode : 143 | final step : 98 | total reward : 0
# 2020/10/02 20:35:33
# episode : 144 | final step : 201 | total reward : 0
# 2020/10/02 20:35:36
# episode : 145 | final step : 201 | total reward : 0
# 2020/10/02 20:35:37
# episode : 146 | final step : 99 | total reward : 0
# 2020/10/02 20:35:40
# episode : 147 | final step : 201 | total reward : 0
# 2020/10/02 20:35:42
# episode : 148 | final step : 201 | total reward : 0
# 2020/10/02 20:35:45
# episode : 149 | final step : 201 | total reward : 0
# 2020/10/02 20:35:48
# episode : 150 | final step : 201 | total reward : 0
# 2020/10/02 20:35:50
# episode : 151 | final step : 201 | total reward : 0
# 2020/10/02 20:35:53
# episode : 152 | final step : 201 | total reward : 0
# 2020/10/02 20:35:55
# episode : 153 | final step : 201 | total reward : 0
# 2020/10/02 20:35:58
# episode : 154 | final step : 201 | total reward : 0
# 2020/10/02 20:35:59
# episode : 155 | final step : 98 | total reward : 0
# 2020/10/02 20:36:02
# episode : 156 | final step : 201 | total reward : 0
# 2020/10/02 20:36:04
# episode : 157 | final step : 201 | total reward : 0
# 2020/10/02 20:36:07
# episode : 158 | final step : 201 | total reward : 0
# 2020/10/02 20:36:10
# episode : 159 | final step : 201 | total reward : 0
# 2020/10/02 20:36:12
# episode : 160 | final step : 201 | total reward : 0
# 2020/10/02 20:36:15
# episode : 161 | final step : 201 | total reward : 0
# 2020/10/02 20:36:16
# episode : 162 | final step : 99 | total reward : 0
# 2020/10/02 20:36:18
# episode : 163 | final step : 201 | total reward : 0
# 2020/10/02 20:36:21
# episode : 164 | final step : 201 | total reward : 0
# 2020/10/02 20:36:24
# episode : 165 | final step : 201 | total reward : 0
# 2020/10/02 20:36:28
# episode : 166 | final step : 201 | total reward : 0
# 2020/10/02 20:36:30
# episode : 167 | final step : 201 | total reward : 0
# 2020/10/02 20:36:33
# episode : 168 | final step : 201 | total reward : 0
# 2020/10/02 20:36:34
# episode : 169 | final step : 98 | total reward : 0
# 2020/10/02 20:36:38
# episode : 170 | final step : 201 | total reward : 0
# 2020/10/02 20:36:40
# episode : 171 | final step : 201 | total reward : 0
# 2020/10/02 20:36:42
# episode : 172 | final step : 100 | total reward : 0
# 2020/10/02 20:36:43
# episode : 173 | final step : 98 | total reward : 0
# 2020/10/02 20:36:46
# episode : 174 | final step : 201 | total reward : 0
# 2020/10/02 20:36:49
# episode : 175 | final step : 201 | total reward : 0
# 2020/10/02 20:36:52
# episode : 176 | final step : 201 | total reward : 0
# 2020/10/02 20:36:54
# episode : 177 | final step : 201 | total reward : 0
# 2020/10/02 20:36:57
# episode : 178 | final step : 201 | total reward : 0
# 2020/10/02 20:37:00
# episode : 179 | final step : 201 | total reward : 0
# 2020/10/02 20:37:03
# episode : 180 | final step : 201 | total reward : 0
# 2020/10/02 20:37:06
# episode : 181 | final step : 201 | total reward : 0
# 2020/10/02 20:37:07
# episode : 182 | final step : 98 | total reward : 0
# 2020/10/02 20:37:10
# episode : 183 | final step : 201 | total reward : 0
# 2020/10/02 20:37:13
# episode : 184 | final step : 201 | total reward : 0
# 2020/10/02 20:37:15
# episode : 185 | final step : 99 | total reward : 0
# 2020/10/02 20:37:17
# episode : 186 | final step : 201 | total reward : 0
# 2020/10/02 20:37:21
# episode : 187 | final step : 201 | total reward : 0
# 2020/10/02 20:37:22
# episode : 188 | final step : 99 | total reward : 0
# 2020/10/02 20:37:25
# episode : 189 | final step : 201 | total reward : 0
# 2020/10/02 20:37:27
# episode : 190 | final step : 201 | total reward : 0
# 2020/10/02 20:37:30
# episode : 191 | final step : 201 | total reward : 0
# 2020/10/02 20:37:34
# episode : 192 | final step : 201 | total reward : 0
# 2020/10/02 20:37:35
# episode : 193 | final step : 99 | total reward : 0
# 2020/10/02 20:37:38
# episode : 194 | final step : 201 | total reward : 0
# 2020/10/02 20:37:41
# episode : 195 | final step : 201 | total reward : 0
# 2020/10/02 20:37:42
# episode : 196 | final step : 100 | total reward : 0
# 2020/10/02 20:37:45
# episode : 197 | final step : 201 | total reward : 0
# 2020/10/02 20:37:48
# episode : 198 | final step : 201 | total reward : 0
# 2020/10/02 20:37:51
# episode : 199 | final step : 201 | total reward : 0
# 2020/10/02 20:37:53
# episode : 200 | final step : 98 | total reward : 0
# 2020/10/02 20:37:54
# episode : 201 | final step : 99 | total reward : 0
# 2020/10/02 20:37:57
# episode : 202 | final step : 201 | total reward : 0
# 2020/10/02 20:37:58
# episode : 203 | final step : 98 | total reward : 0
# 2020/10/02 20:38:00
# episode : 204 | final step : 201 | total reward : 0
# 2020/10/02 20:38:04
# episode : 205 | final step : 201 | total reward : 0
# 2020/10/02 20:38:07
# episode : 206 | final step : 201 | total reward : 0
# 2020/10/02 20:38:09
# episode : 207 | final step : 201 | total reward : 0
# 2020/10/02 20:38:12
# episode : 208 | final step : 201 | total reward : 0
# 2020/10/02 20:38:15
# episode : 209 | final step : 201 | total reward : 0
# 2020/10/02 20:38:18
# episode : 210 | final step : 201 | total reward : 0
# 2020/10/02 20:38:21
# episode : 211 | final step : 201 | total reward : 0
# 2020/10/02 20:38:24
# episode : 212 | final step : 201 | total reward : 0
# 2020/10/02 20:38:26
# episode : 213 | final step : 201 | total reward : 0
# 2020/10/02 20:38:30
# episode : 214 | final step : 201 | total reward : 0
# 2020/10/02 20:38:31
# episode : 215 | final step : 98 | total reward : 0
# 2020/10/02 20:38:33
# episode : 216 | final step : 99 | total reward : 0
# 2020/10/02 20:38:35
# episode : 217 | final step : 201 | total reward : 0
# 2020/10/02 20:38:38
# episode : 218 | final step : 201 | total reward : 0
# 2020/10/02 20:38:40
# episode : 219 | final step : 201 | total reward : 0
# 2020/10/02 20:38:43
# episode : 220 | final step : 201 | total reward : 0
# 2020/10/02 20:38:46
# episode : 221 | final step : 201 | total reward : 0
# 2020/10/02 20:38:48
# episode : 222 | final step : 98 | total reward : 0
# 2020/10/02 20:38:50
# episode : 223 | final step : 201 | total reward : 0
# 2020/10/02 20:38:53
# episode : 224 | final step : 201 | total reward : 0
# 2020/10/02 20:38:56
# episode : 225 | final step : 201 | total reward : 0
# 2020/10/02 20:38:57
# episode : 226 | final step : 99 | total reward : 0
# 2020/10/02 20:38:58
# episode : 227 | final step : 99 | total reward : 0
# 2020/10/02 20:39:01
# episode : 228 | final step : 201 | total reward : 0
# 2020/10/02 20:39:03
# episode : 229 | final step : 201 | total reward : 0
# 2020/10/02 20:39:06
# episode : 230 | final step : 201 | total reward : 0
# 2020/10/02 20:39:09
# episode : 231 | final step : 201 | total reward : 0
# 2020/10/02 20:39:11
# episode : 232 | final step : 99 | total reward : 0
# 2020/10/02 20:39:13
# episode : 233 | final step : 201 | total reward : 0
# 2020/10/02 20:39:16
# episode : 234 | final step : 201 | total reward : 0
# 2020/10/02 20:39:17
# episode : 235 | final step : 99 | total reward : 0
# 2020/10/02 20:39:18
# episode : 236 | final step : 100 | total reward : 0
# 2020/10/02 20:39:21
# episode : 237 | final step : 201 | total reward : 0
# 2020/10/02 20:39:23
# episode : 238 | final step : 201 | total reward : 0
# 2020/10/02 20:39:25
# episode : 239 | final step : 98 | total reward : 0
# 2020/10/02 20:39:27
# episode : 240 | final step : 201 | total reward : 0
# 2020/10/02 20:39:30
# episode : 241 | final step : 201 | total reward : 0
# 2020/10/02 20:39:32
# episode : 242 | final step : 201 | total reward : 0
# 2020/10/02 20:39:35
# episode : 243 | final step : 201 | total reward : 0
# 2020/10/02 20:39:38
# episode : 244 | final step : 201 | total reward : 0
# 2020/10/02 20:39:40
# episode : 245 | final step : 201 | total reward : 0
# 2020/10/02 20:39:43
# episode : 246 | final step : 201 | total reward : 0
# 2020/10/02 20:39:46
# episode : 247 | final step : 201 | total reward : 0
# 2020/10/02 20:39:49
# episode : 248 | final step : 201 | total reward : 0
# 2020/10/02 20:39:50
# episode : 249 | final step : 98 | total reward : 0
# 2020/10/02 20:39:51
# episode : 250 | final step : 98 | total reward : 0
# 2020/10/02 20:39:54
# episode : 251 | final step : 201 | total reward : 0
# 2020/10/02 20:39:56
# episode : 252 | final step : 98 | total reward : 0
# 2020/10/02 20:39:59
# episode : 253 | final step : 201 | total reward : 0
# 2020/10/02 20:40:01
# episode : 254 | final step : 201 | total reward : 0
# 2020/10/02 20:40:04
# episode : 255 | final step : 201 | total reward : 0
# 2020/10/02 20:40:08
# episode : 256 | final step : 201 | total reward : 0
# 2020/10/02 20:40:10
# episode : 257 | final step : 201 | total reward : 0
# 2020/10/02 20:40:13
# episode : 258 | final step : 201 | total reward : 0
# 2020/10/02 20:40:17
# episode : 259 | final step : 201 | total reward : 0
# 2020/10/02 20:40:20
# episode : 260 | final step : 201 | total reward : 0
# 2020/10/02 20:40:22
# episode : 261 | final step : 201 | total reward : 0
# 2020/10/02 20:40:24
# episode : 262 | final step : 98 | total reward : 0
# 2020/10/02 20:40:25
# episode : 263 | final step : 98 | total reward : 0
# 2020/10/02 20:40:28
# episode : 264 | final step : 201 | total reward : 0
# 2020/10/02 20:40:30
# episode : 265 | final step : 98 | total reward : 0
# 2020/10/02 20:40:31
# episode : 266 | final step : 99 | total reward : 0
# 2020/10/02 20:40:34
# episode : 267 | final step : 201 | total reward : 0
# 2020/10/02 20:40:37
# episode : 268 | final step : 201 | total reward : 0
# 2020/10/02 20:40:40
# episode : 269 | final step : 201 | total reward : 0
# 2020/10/02 20:40:43
# episode : 270 | final step : 201 | total reward : 0
# 2020/10/02 20:40:46
# episode : 271 | final step : 201 | total reward : 0
# 2020/10/02 20:40:49
# episode : 272 | final step : 201 | total reward : 0
# 2020/10/02 20:40:52
# episode : 273 | final step : 201 | total reward : 0
# 2020/10/02 20:40:55
# episode : 274 | final step : 201 | total reward : 0
# 2020/10/02 20:40:58
# episode : 275 | final step : 201 | total reward : 0
# 2020/10/02 20:41:01
# episode : 276 | final step : 201 | total reward : 0
# 2020/10/02 20:41:04
# episode : 277 | final step : 201 | total reward : 0
# 2020/10/02 20:41:07
# episode : 278 | final step : 201 | total reward : 0
# 2020/10/02 20:41:09
# episode : 279 | final step : 201 | total reward : 0
# 2020/10/02 20:41:12
# episode : 280 | final step : 201 | total reward : 0
# 2020/10/02 20:41:15
# episode : 281 | final step : 201 | total reward : 0
# 2020/10/02 20:41:18
# episode : 282 | final step : 201 | total reward : 0
# 2020/10/02 20:41:21
# episode : 283 | final step : 201 | total reward : 0
# 2020/10/02 20:41:24
# episode : 284 | final step : 201 | total reward : 0
# 2020/10/02 20:41:27
# episode : 285 | final step : 201 | total reward : 0
# 2020/10/02 20:41:30
# episode : 286 | final step : 201 | total reward : 0
# 2020/10/02 20:41:33
# episode : 287 | final step : 201 | total reward : 0
# 2020/10/02 20:41:36
# episode : 288 | final step : 201 | total reward : 0
# 2020/10/02 20:41:37
# episode : 289 | final step : 99 | total reward : 0
# 2020/10/02 20:41:39
# episode : 290 | final step : 99 | total reward : 0
# 2020/10/02 20:41:40
# episode : 291 | final step : 99 | total reward : 0
# 2020/10/02 20:41:43
# episode : 292 | final step : 201 | total reward : 0
# 2020/10/02 20:41:46
# episode : 293 | final step : 201 | total reward : 0
# 2020/10/02 20:41:49
# episode : 294 | final step : 201 | total reward : 0
# 2020/10/02 20:41:50
# episode : 295 | final step : 99 | total reward : 0
# 2020/10/02 20:41:52
# episode : 296 | final step : 100 | total reward : 0
# 2020/10/02 20:41:53
# episode : 297 | final step : 98 | total reward : 0
# 2020/10/02 20:41:56
# episode : 298 | final step : 201 | total reward : 0
# 2020/10/02 20:41:59
# episode : 299 | final step : 201 | total reward : 0
# 2020/10/02 20:42:02
# episode : 300 | final step : 201 | total reward : 0
# 2020/10/02 20:42:03
# episode : 301 | final step : 99 | total reward : 0
# 2020/10/02 20:42:04
# episode : 302 | final step : 100 | total reward : 0
# 2020/10/02 20:42:07
# episode : 303 | final step : 201 | total reward : 0
# 2020/10/02 20:42:11
# episode : 304 | final step : 201 | total reward : 0
# 2020/10/02 20:42:14
# episode : 305 | final step : 201 | total reward : 0
# 2020/10/02 20:42:16
# episode : 306 | final step : 201 | total reward : 0
# 2020/10/02 20:42:18
# episode : 307 | final step : 98 | total reward : 0
# 2020/10/02 20:42:22
# episode : 308 | final step : 201 | total reward : 0
# 2020/10/02 20:42:24
# episode : 309 | final step : 201 | total reward : 0
# 2020/10/02 20:42:27
# episode : 310 | final step : 201 | total reward : 0
# 2020/10/02 20:42:30
# episode : 311 | final step : 201 | total reward : 0
# 2020/10/02 20:42:33
# episode : 312 | final step : 201 | total reward : 0
# 2020/10/02 20:42:36
# episode : 313 | final step : 201 | total reward : 0
# 2020/10/02 20:42:38
# episode : 314 | final step : 201 | total reward : 0
# 2020/10/02 20:42:41
# episode : 315 | final step : 201 | total reward : 0
# 2020/10/02 20:42:44
# episode : 316 | final step : 201 | total reward : 0
# 2020/10/02 20:42:46
# episode : 317 | final step : 99 | total reward : 0
# 2020/10/02 20:42:48
# episode : 318 | final step : 201 | total reward : 0
# 2020/10/02 20:42:50
# episode : 319 | final step : 100 | total reward : 0
# 2020/10/02 20:42:51
# episode : 320 | final step : 99 | total reward : 0
# 2020/10/02 20:42:54
# episode : 321 | final step : 201 | total reward : 0
# 2020/10/02 20:42:56
# episode : 322 | final step : 98 | total reward : 0
# 2020/10/02 20:42:58
# episode : 323 | final step : 201 | total reward : 0
# 2020/10/02 20:43:01
# episode : 324 | final step : 201 | total reward : 0
# 2020/10/02 20:43:04
# episode : 325 | final step : 201 | total reward : 0
# 2020/10/02 20:43:07
# episode : 326 | final step : 201 | total reward : 0
# 2020/10/02 20:43:10
# episode : 327 | final step : 201 | total reward : 0
# 2020/10/02 20:43:13
# episode : 328 | final step : 201 | total reward : 0
# 2020/10/02 20:43:14
# episode : 329 | final step : 98 | total reward : 0
# 2020/10/02 20:43:18
# episode : 330 | final step : 201 | total reward : 0
# 2020/10/02 20:43:20
# episode : 331 | final step : 201 | total reward : 0
# 2020/10/02 20:43:23
# episode : 332 | final step : 201 | total reward : 0
# 2020/10/02 20:43:25
# episode : 333 | final step : 98 | total reward : 0
# 2020/10/02 20:43:28
# episode : 334 | final step : 201 | total reward : 0
# 2020/10/02 20:43:30
# episode : 335 | final step : 201 | total reward : 0
# 2020/10/02 20:43:33
# episode : 336 | final step : 201 | total reward : 0
# 2020/10/02 20:43:36
# episode : 337 | final step : 201 | total reward : 0
# 2020/10/02 20:43:39
# episode : 338 | final step : 201 | total reward : 0
# 2020/10/02 20:43:42
# episode : 339 | final step : 201 | total reward : 0
# 2020/10/02 20:43:45
# episode : 340 | final step : 201 | total reward : 0
# 2020/10/02 20:43:48
# episode : 341 | final step : 201 | total reward : 0
# 2020/10/02 20:43:51
# episode : 342 | final step : 201 | total reward : 0
# 2020/10/02 20:43:53
# episode : 343 | final step : 201 | total reward : 0
# 2020/10/02 20:43:56
# episode : 344 | final step : 201 | total reward : 0
# 2020/10/02 20:43:59
# episode : 345 | final step : 201 | total reward : 0
# 2020/10/02 20:44:02
# episode : 346 | final step : 201 | total reward : 0
# 2020/10/02 20:44:05
# episode : 347 | final step : 201 | total reward : 0
# 2020/10/02 20:44:06
# episode : 348 | final step : 99 | total reward : 0
# 2020/10/02 20:44:09
# episode : 349 | final step : 201 | total reward : 0
# 2020/10/02 20:44:12
# episode : 350 | final step : 201 | total reward : 0
# 2020/10/02 20:44:15
# episode : 351 | final step : 201 | total reward : 0
# 2020/10/02 20:44:18
# episode : 352 | final step : 201 | total reward : 0
# 2020/10/02 20:44:21
# episode : 353 | final step : 201 | total reward : 0
# 2020/10/02 20:44:24
# episode : 354 | final step : 201 | total reward : 0
# 2020/10/02 20:44:26
# episode : 355 | final step : 201 | total reward : 0
# 2020/10/02 20:44:30
# episode : 356 | final step : 201 | total reward : 0
# 2020/10/02 20:44:36
# episode : 357 | final step : 201 | total reward : 0
# 2020/10/02 20:44:45
# episode : 358 | final step : 201 | total reward : 0
# 2020/10/02 20:44:52
# episode : 359 | final step : 201 | total reward : 0
# 2020/10/02 20:44:54
# episode : 360 | final step : 98 | total reward : 0
# 2020/10/02 20:44:57
# episode : 361 | final step : 201 | total reward : 0
# 2020/10/02 20:45:00
# episode : 362 | final step : 201 | total reward : 0
# 2020/10/02 20:45:03
# episode : 363 | final step : 201 | total reward : 0
# 2020/10/02 20:45:04
# episode : 364 | final step : 98 | total reward : 0
# 2020/10/02 20:45:07
# episode : 365 | final step : 201 | total reward : 0
# 2020/10/02 20:45:09
# episode : 366 | final step : 99 | total reward : 0
# 2020/10/02 20:45:10
# episode : 367 | final step : 99 | total reward : 0
# 2020/10/02 20:45:13
# episode : 368 | final step : 201 | total reward : 0
# 2020/10/02 20:45:14
# episode : 369 | final step : 98 | total reward : 0
# 2020/10/02 20:45:17
# episode : 370 | final step : 201 | total reward : 0
# 2020/10/02 20:45:19
# episode : 371 | final step : 99 | total reward : 0
# 2020/10/02 20:45:20
# episode : 372 | final step : 98 | total reward : 0
# 2020/10/02 20:45:22
# episode : 373 | final step : 99 | total reward : 0
# 2020/10/02 20:45:24
# episode : 374 | final step : 201 | total reward : 0
# 2020/10/02 20:45:26
# episode : 375 | final step : 99 | total reward : 0
# 2020/10/02 20:45:29
# episode : 376 | final step : 201 | total reward : 0
# 2020/10/02 20:45:32
# episode : 377 | final step : 201 | total reward : 0
# 2020/10/02 20:45:35
# episode : 378 | final step : 201 | total reward : 0
# 2020/10/02 20:45:39
# episode : 379 | final step : 201 | total reward : 0
# 2020/10/02 20:45:47
# episode : 380 | final step : 201 | total reward : 0
# 2020/10/02 20:45:55
# episode : 381 | final step : 201 | total reward : 0
# 2020/10/02 20:46:03
# episode : 382 | final step : 201 | total reward : 0
# 2020/10/02 20:46:07
# episode : 383 | final step : 98 | total reward : 0
# 2020/10/02 20:46:15
# episode : 384 | final step : 201 | total reward : 0
# 2020/10/02 20:46:19
# episode : 385 | final step : 98 | total reward : 0
# 2020/10/02 20:46:22
# episode : 386 | final step : 98 | total reward : 0
# 2020/10/02 20:46:30
# episode : 387 | final step : 201 | total reward : 0
# 2020/10/02 20:46:36
# episode : 388 | final step : 201 | total reward : 0
# 2020/10/02 20:46:39
# episode : 389 | final step : 201 | total reward : 0
# 2020/10/02 20:46:41
# episode : 390 | final step : 201 | total reward : 0
# 2020/10/02 20:46:44
# episode : 391 | final step : 201 | total reward : 0
# 2020/10/02 20:46:47
# episode : 392 | final step : 201 | total reward : 0
# 2020/10/02 20:46:50
# episode : 393 | final step : 201 | total reward : 0
# 2020/10/02 20:46:53
# episode : 394 | final step : 201 | total reward : 0
# 2020/10/02 20:46:56
# episode : 395 | final step : 201 | total reward : 0
# 2020/10/02 20:46:59
# episode : 396 | final step : 201 | total reward : 0
# 2020/10/02 20:47:00
# episode : 397 | final step : 98 | total reward : 0
# 2020/10/02 20:47:03
# episode : 398 | final step : 201 | total reward : 0
# 2020/10/02 20:47:06
# episode : 399 | final step : 201 | total reward : 0
# 2020/10/02 20:47:09
# episode : 400 | final step : 201 | total reward : 0
# 2020/10/02 20:47:10
# episode : 401 | final step : 99 | total reward : 0
# 2020/10/02 20:47:12
# episode : 402 | final step : 201 | total reward : 0
# 2020/10/02 20:47:14
# episode : 403 | final step : 98 | total reward : 0
# 2020/10/02 20:47:17
# episode : 404 | final step : 201 | total reward : 0
# 2020/10/02 20:47:20
# episode : 405 | final step : 201 | total reward : 0
# 2020/10/02 20:47:26
# episode : 406 | final step : 201 | total reward : 0
# 2020/10/02 20:47:34
# episode : 407 | final step : 201 | total reward : 0
# 2020/10/02 20:47:42
# episode : 408 | final step : 201 | total reward : 0
# 2020/10/02 20:47:49
# episode : 409 | final step : 201 | total reward : 0
# 2020/10/02 20:47:57
# episode : 410 | final step : 201 | total reward : 0
# 2020/10/02 20:48:04
# episode : 411 | final step : 201 | total reward : 0
# 2020/10/02 20:48:12
# episode : 412 | final step : 201 | total reward : 0
# 2020/10/02 20:48:19
# episode : 413 | final step : 201 | total reward : 0
# 2020/10/02 20:48:27
# episode : 414 | final step : 201 | total reward : 0
# 2020/10/02 20:48:31
# episode : 415 | final step : 100 | total reward : 0
# 2020/10/02 20:48:34
# episode : 416 | final step : 99 | total reward : 0
# 2020/10/02 20:48:43
# episode : 417 | final step : 201 | total reward : 0
# 2020/10/02 20:48:46
# episode : 418 | final step : 99 | total reward : 0
# 2020/10/02 20:48:55
# episode : 419 | final step : 201 | total reward : 0
# 2020/10/02 20:49:02
# episode : 420 | final step : 201 | total reward : 0
# 2020/10/02 20:49:10
# episode : 421 | final step : 201 | total reward : 0
# 2020/10/02 20:49:18
# episode : 422 | final step : 201 | total reward : 0
# 2020/10/02 20:49:26
# episode : 423 | final step : 201 | total reward : 0
# 2020/10/02 20:49:30
# episode : 424 | final step : 98 | total reward : 0
# 2020/10/02 20:49:37
# episode : 425 | final step : 201 | total reward : 0
# 2020/10/02 20:49:45
# episode : 426 | final step : 201 | total reward : 0
# 2020/10/02 20:49:53
# episode : 427 | final step : 201 | total reward : 0
# 2020/10/02 20:50:01
# episode : 428 | final step : 201 | total reward : 0
# 2020/10/02 20:50:09
# episode : 429 | final step : 201 | total reward : 0
# 2020/10/02 20:50:12
# episode : 430 | final step : 99 | total reward : 0
# 2020/10/02 20:50:20
# episode : 431 | final step : 201 | total reward : 0
# 2020/10/02 20:50:27
# episode : 432 | final step : 201 | total reward : 0
# 2020/10/02 20:50:35
# episode : 433 | final step : 201 | total reward : 0
# 2020/10/02 20:50:39
# episode : 434 | final step : 98 | total reward : 0
# 2020/10/02 20:50:47
# episode : 435 | final step : 201 | total reward : 0
# 2020/10/02 20:50:55
# episode : 436 | final step : 201 | total reward : 0
# 2020/10/02 20:51:02
# episode : 437 | final step : 201 | total reward : 0
# 2020/10/02 20:51:09
# episode : 438 | final step : 201 | total reward : 0
# 2020/10/02 20:51:13
# episode : 439 | final step : 98 | total reward : 0
# 2020/10/02 20:51:20
# episode : 440 | final step : 201 | total reward : 0
# 2020/10/02 20:51:28
# episode : 441 | final step : 201 | total reward : 0
# 2020/10/02 20:51:35
# episode : 442 | final step : 201 | total reward : 0
# 2020/10/02 20:51:39
# episode : 443 | final step : 98 | total reward : 0
# 2020/10/02 20:51:47
# episode : 444 | final step : 201 | total reward : 0
# 2020/10/02 20:51:50
# episode : 445 | final step : 98 | total reward : 0
# 2020/10/02 20:51:57
# episode : 446 | final step : 201 | total reward : 0
# 2020/10/02 20:52:06
# episode : 447 | final step : 201 | total reward : 0
# 2020/10/02 20:52:13
# episode : 448 | final step : 201 | total reward : 0
# 2020/10/02 20:52:20
# episode : 449 | final step : 201 | total reward : 0
# 2020/10/02 20:52:28
# episode : 450 | final step : 201 | total reward : 0
# 2020/10/02 20:52:36
# episode : 451 | final step : 201 | total reward : 0
# 2020/10/02 20:52:43
# episode : 452 | final step : 201 | total reward : 0
# 2020/10/02 20:52:47
# episode : 453 | final step : 98 | total reward : 0
# 2020/10/02 20:52:55
# episode : 454 | final step : 201 | total reward : 0
# 2020/10/02 20:52:58
# episode : 455 | final step : 99 | total reward : 0
# 2020/10/02 20:53:06
# episode : 456 | final step : 201 | total reward : 0
# 2020/10/02 20:53:10
# episode : 457 | final step : 99 | total reward : 0
# 2020/10/02 20:53:17
# episode : 458 | final step : 201 | total reward : 0
# 2020/10/02 20:53:25
# episode : 459 | final step : 201 | total reward : 0
# 2020/10/02 20:53:32
# episode : 460 | final step : 201 | total reward : 0
# 2020/10/02 20:53:39
# episode : 461 | final step : 201 | total reward : 0
# 2020/10/02 20:53:46
# episode : 462 | final step : 201 | total reward : 0
# 2020/10/02 20:53:53
# episode : 463 | final step : 201 | total reward : 0
# 2020/10/02 20:54:00
# episode : 464 | final step : 201 | total reward : 0
# 2020/10/02 20:54:03
# episode : 465 | final step : 98 | total reward : 0
# 2020/10/02 20:54:07
# episode : 466 | final step : 99 | total reward : 0
# 2020/10/02 20:54:14
# episode : 467 | final step : 201 | total reward : 0
# 2020/10/02 20:54:17
# episode : 468 | final step : 99 | total reward : 0
# 2020/10/02 20:54:23
# episode : 469 | final step : 201 | total reward : 0
# 2020/10/02 20:54:30
# episode : 470 | final step : 201 | total reward : 0
# 2020/10/02 20:54:37
# episode : 471 | final step : 201 | total reward : 0
# 2020/10/02 20:54:43
# episode : 472 | final step : 201 | total reward : 0
# 2020/10/02 20:54:49
# episode : 473 | final step : 201 | total reward : 0
# 2020/10/02 20:54:57
# episode : 474 | final step : 201 | total reward : 0
# 2020/10/02 20:55:03
# episode : 475 | final step : 201 | total reward : 0
# 2020/10/02 20:55:09
# episode : 476 | final step : 201 | total reward : 0
# 2020/10/02 20:55:12
# episode : 477 | final step : 97 | total reward : 0
# 2020/10/02 20:55:14
# episode : 478 | final step : 98 | total reward : 0
# 2020/10/02 20:55:21
# episode : 479 | final step : 201 | total reward : 0
# 2020/10/02 20:55:28
# episode : 480 | final step : 201 | total reward : 0
# 2020/10/02 20:55:31
# episode : 481 | final step : 98 | total reward : 0
# 2020/10/02 20:55:39
# episode : 482 | final step : 201 | total reward : 0
# 2020/10/02 20:55:46
# episode : 483 | final step : 201 | total reward : 0
# 2020/10/02 20:55:53
# episode : 484 | final step : 201 | total reward : 0
# 2020/10/02 20:55:56
# episode : 485 | final step : 98 | total reward : 0
# 2020/10/02 20:56:00
# episode : 486 | final step : 99 | total reward : 0
# 2020/10/02 20:56:07
# episode : 487 | final step : 201 | total reward : 0
# 2020/10/02 20:56:15
# episode : 488 | final step : 201 | total reward : 0
# 2020/10/02 20:56:18
# episode : 489 | final step : 98 | total reward : 0
# 2020/10/02 20:56:25
# episode : 490 | final step : 201 | total reward : 0
# 2020/10/02 20:56:32
# episode : 491 | final step : 201 | total reward : 0
# 2020/10/02 20:56:39
# episode : 492 | final step : 201 | total reward : 0
# 2020/10/02 20:56:42
# episode : 493 | final step : 98 | total reward : 0
# 2020/10/02 20:56:46
# episode : 494 | final step : 99 | total reward : 0
# 2020/10/02 20:56:49
# episode : 495 | final step : 98 | total reward : 0
# 2020/10/02 20:56:56
# episode : 496 | final step : 201 | total reward : 0
# 2020/10/02 20:57:00
# episode : 497 | final step : 98 | total reward : 0
# 2020/10/02 20:57:06
# episode : 498 | final step : 201 | total reward : 0
# 2020/10/02 20:57:14
# episode : 499 | final step : 201 | total reward : 0
# 2020/10/02 20:57:21
# episode : 500 | final step : 201 | total reward : 0
# 2020/10/02 20:57:25
# episode : 501 | final step : 98 | total reward : 0
# 2020/10/02 20:57:27
# episode : 502 | final step : 98 | total reward : 0
# 2020/10/02 20:57:31
# episode : 503 | final step : 98 | total reward : 0
# 2020/10/02 20:57:36
# episode : 504 | final step : 99 | total reward : 0
# 2020/10/02 20:57:43
# episode : 505 | final step : 201 | total reward : 0
# 2020/10/02 20:57:50
# episode : 506 | final step : 201 | total reward : 0
# 2020/10/02 20:57:53
# episode : 507 | final step : 97 | total reward : 0
# 2020/10/02 20:57:57
# episode : 508 | final step : 98 | total reward : 0
# 2020/10/02 20:58:01
# episode : 509 | final step : 99 | total reward : 0
# 2020/10/02 20:58:08
# episode : 510 | final step : 201 | total reward : 0
# 2020/10/02 20:58:12
# episode : 511 | final step : 98 | total reward : 0
# 2020/10/02 20:58:15
# episode : 512 | final step : 99 | total reward : 0
# 2020/10/02 20:58:22
# episode : 513 | final step : 201 | total reward : 0
# 2020/10/02 20:58:29
# episode : 514 | final step : 201 | total reward : 0
# 2020/10/02 20:58:36
# episode : 515 | final step : 201 | total reward : 0
# 2020/10/02 20:58:44
# episode : 516 | final step : 201 | total reward : 0
# 2020/10/02 20:58:47
# episode : 517 | final step : 98 | total reward : 0
# 2020/10/02 20:58:55
# episode : 518 | final step : 201 | total reward : 0
# 2020/10/02 20:59:01
# episode : 519 | final step : 201 | total reward : 0
# 2020/10/02 20:59:05
# episode : 520 | final step : 99 | total reward : 0
# 2020/10/02 20:59:08
# episode : 521 | final step : 99 | total reward : 0
# 2020/10/02 20:59:15
# episode : 522 | final step : 201 | total reward : 0
# 2020/10/02 20:59:22
# episode : 523 | final step : 201 | total reward : 0
# 2020/10/02 20:59:26
# episode : 524 | final step : 98 | total reward : 0
# 2020/10/02 20:59:29
# episode : 525 | final step : 98 | total reward : 0
# 2020/10/02 20:59:35
# episode : 526 | final step : 201 | total reward : 0
# 2020/10/02 20:59:43
# episode : 527 | final step : 201 | total reward : 0
# 2020/10/02 20:59:50
# episode : 528 | final step : 201 | total reward : 0
# 2020/10/02 20:59:57
# episode : 529 | final step : 201 | total reward : 0
# 2020/10/02 21:00:01
# episode : 530 | final step : 99 | total reward : 0
# 2020/10/02 21:00:08
# episode : 531 | final step : 201 | total reward : 0
# 2020/10/02 21:00:16
# episode : 532 | final step : 201 | total reward : 0
# 2020/10/02 21:00:23
# episode : 533 | final step : 201 | total reward : 0
# 2020/10/02 21:00:30
# episode : 534 | final step : 201 | total reward : 0
# 2020/10/02 21:00:38
# episode : 535 | final step : 201 | total reward : 0
# 2020/10/02 21:00:41
# episode : 536 | final step : 98 | total reward : 0
# 2020/10/02 21:00:48
# episode : 537 | final step : 201 | total reward : 0
# 2020/10/02 21:00:51
# episode : 538 | final step : 98 | total reward : 0
# 2020/10/02 21:00:59
# episode : 539 | final step : 201 | total reward : 0
# 2020/10/02 21:01:05
# episode : 540 | final step : 201 | total reward : 0
# 2020/10/02 21:01:13
# episode : 541 | final step : 201 | total reward : 0
# 2020/10/02 21:01:16
# episode : 542 | final step : 99 | total reward : 0
# 2020/10/02 21:01:24
# episode : 543 | final step : 201 | total reward : 0
# 2020/10/02 21:01:27
# episode : 544 | final step : 99 | total reward : 0
# 2020/10/02 21:01:34
# episode : 545 | final step : 201 | total reward : 0
# 2020/10/02 21:01:37
# episode : 546 | final step : 98 | total reward : 0
# 2020/10/02 21:01:40
# episode : 547 | final step : 99 | total reward : 0
# 2020/10/02 21:01:48
# episode : 548 | final step : 201 | total reward : 0
# 2020/10/02 21:01:51
# episode : 549 | final step : 98 | total reward : 0
# 2020/10/02 21:01:59
# episode : 550 | final step : 201 | total reward : 0
# 2020/10/02 21:02:06
# episode : 551 | final step : 201 | total reward : 0
# 2020/10/02 21:02:09
# episode : 552 | final step : 99 | total reward : 0
# 2020/10/02 21:02:12
# episode : 553 | final step : 98 | total reward : 0
# 2020/10/02 21:02:20
# episode : 554 | final step : 201 | total reward : 0
# 2020/10/02 21:02:26
# episode : 555 | final step : 201 | total reward : 0
# 2020/10/02 21:02:34
# episode : 556 | final step : 201 | total reward : 0
# 2020/10/02 21:02:41
# episode : 557 | final step : 201 | total reward : 0
# 2020/10/02 21:02:44
# episode : 558 | final step : 99 | total reward : 0
# 2020/10/02 21:02:47
# episode : 559 | final step : 98 | total reward : 0
# 2020/10/02 21:02:54
# episode : 560 | final step : 201 | total reward : 0
# 2020/10/02 21:03:01
# episode : 561 | final step : 201 | total reward : 0
# 2020/10/02 21:03:08
# episode : 562 | final step : 201 | total reward : 0
# 2020/10/02 21:03:16
# episode : 563 | final step : 201 | total reward : 0
# 2020/10/02 21:03:23
# episode : 564 | final step : 201 | total reward : 0
# 2020/10/02 21:03:27
# episode : 565 | final step : 98 | total reward : 0
# 2020/10/02 21:03:33
# episode : 566 | final step : 201 | total reward : 0
# 2020/10/02 21:03:41
# episode : 567 | final step : 201 | total reward : 0
# 2020/10/02 21:03:48
# episode : 568 | final step : 201 | total reward : 0
# 2020/10/02 21:03:55
# episode : 569 | final step : 201 | total reward : 0
# 2020/10/02 21:04:02
# episode : 570 | final step : 201 | total reward : 0
# 2020/10/02 21:04:09
# episode : 571 | final step : 201 | total reward : 0
# 2020/10/02 21:04:13
# episode : 572 | final step : 99 | total reward : 0
# 2020/10/02 21:04:16
# episode : 573 | final step : 98 | total reward : 0
# 2020/10/02 21:04:23
# episode : 574 | final step : 201 | total reward : 0
# 2020/10/02 21:04:26
# episode : 575 | final step : 98 | total reward : 0
# 2020/10/02 21:04:34
# episode : 576 | final step : 201 | total reward : 0
# 2020/10/02 21:04:37
# episode : 577 | final step : 99 | total reward : 0
# 2020/10/02 21:04:41
# episode : 578 | final step : 98 | total reward : 0
# 2020/10/02 21:04:48
# episode : 579 | final step : 201 | total reward : 0
# 2020/10/02 21:04:55
# episode : 580 | final step : 201 | total reward : 0
# 2020/10/02 21:04:58
# episode : 581 | final step : 98 | total reward : 0
# 2020/10/02 21:05:06
# episode : 582 | final step : 201 | total reward : 0
# 2020/10/02 21:05:13
# episode : 583 | final step : 201 | total reward : 0
# 2020/10/02 21:05:20
# episode : 584 | final step : 201 | total reward : 0
# 2020/10/02 21:05:23
# episode : 585 | final step : 99 | total reward : 0
# 2020/10/02 21:05:30
# episode : 586 | final step : 201 | total reward : 0
# 2020/10/02 21:05:36
# episode : 587 | final step : 201 | total reward : 0
# 2020/10/02 21:05:45
# episode : 588 | final step : 201 | total reward : 0
# 2020/10/02 21:05:52
# episode : 589 | final step : 201 | total reward : 0
# 2020/10/02 21:05:58
# episode : 590 | final step : 201 | total reward : 0
# 2020/10/02 21:06:06
# episode : 591 | final step : 201 | total reward : 0
# 2020/10/02 21:06:09
# episode : 592 | final step : 98 | total reward : 0
# 2020/10/02 21:06:12
# episode : 593 | final step : 99 | total reward : 0
# 2020/10/02 21:06:20
# episode : 594 | final step : 201 | total reward : 0
# 2020/10/02 21:06:27
# episode : 595 | final step : 201 | total reward : 0
# 2020/10/02 21:06:31
# episode : 596 | final step : 100 | total reward : 0
# 2020/10/02 21:06:38
# episode : 597 | final step : 201 | total reward : 0
# 2020/10/02 21:06:45
# episode : 598 | final step : 201 | total reward : 0
# 2020/10/02 21:06:52
# episode : 599 | final step : 201 | total reward : 0
# 2020/10/02 21:06:58
# episode : 600 | final step : 201 | total reward : 0
# 2020/10/02 21:07:06
# episode : 601 | final step : 201 | total reward : 0
# 2020/10/02 21:07:14
# episode : 602 | final step : 201 | total reward : 0
# 2020/10/02 21:07:20
# episode : 603 | final step : 201 | total reward : 0
# 2020/10/02 21:07:24
# episode : 604 | final step : 98 | total reward : 0
# 2020/10/02 21:07:30
# episode : 605 | final step : 201 | total reward : 0
# 2020/10/02 21:07:37
# episode : 606 | final step : 201 | total reward : 0
# 2020/10/02 21:07:44
# episode : 607 | final step : 201 | total reward : 0
# 2020/10/02 21:07:51
# episode : 608 | final step : 201 | total reward : 0
# 2020/10/02 21:07:59
# episode : 609 | final step : 201 | total reward : 0
# 2020/10/02 21:08:06
# episode : 610 | final step : 201 | total reward : 0
# 2020/10/02 21:08:13
# episode : 611 | final step : 201 | total reward : 0
# 2020/10/02 21:08:17
# episode : 612 | final step : 99 | total reward : 0
# 2020/10/02 21:08:25
# episode : 613 | final step : 201 | total reward : 0
# 2020/10/02 21:08:27
# episode : 614 | final step : 98 | total reward : 0
# 2020/10/02 21:08:35
# episode : 615 | final step : 201 | total reward : 0
# 2020/10/02 21:08:42
# episode : 616 | final step : 201 | total reward : 0
# 2020/10/02 21:08:49
# episode : 617 | final step : 201 | total reward : 0
# 2020/10/02 21:08:56
# episode : 618 | final step : 201 | total reward : 0
# 2020/10/02 21:09:03
# episode : 619 | final step : 201 | total reward : 0
# 2020/10/02 21:09:11
# episode : 620 | final step : 201 | total reward : 0
# 2020/10/02 21:09:18
# episode : 621 | final step : 201 | total reward : 0
# 2020/10/02 21:09:24
# episode : 622 | final step : 201 | total reward : 0
# 2020/10/02 21:09:32
# episode : 623 | final step : 201 | total reward : 0
# 2020/10/02 21:09:38
# episode : 624 | final step : 201 | total reward : 0
# 2020/10/02 21:09:46
# episode : 625 | final step : 201 | total reward : 0
# 2020/10/02 21:09:53
# episode : 626 | final step : 201 | total reward : 0
# 2020/10/02 21:09:56
# episode : 627 | final step : 99 | total reward : 0
# 2020/10/02 21:09:59
# episode : 628 | final step : 98 | total reward : 0
# 2020/10/02 21:10:06
# episode : 629 | final step : 201 | total reward : 0
# 2020/10/02 21:10:10
# episode : 630 | final step : 99 | total reward : 0
# 2020/10/02 21:10:16
# episode : 631 | final step : 201 | total reward : 0
# 2020/10/02 21:10:23
# episode : 632 | final step : 201 | total reward : 0
# 2020/10/02 21:10:30
# episode : 633 | final step : 201 | total reward : 0
# 2020/10/02 21:10:33
# episode : 634 | final step : 99 | total reward : 0
# 2020/10/02 21:10:41
# episode : 635 | final step : 201 | total reward : 0
# 2020/10/02 21:10:49
# episode : 636 | final step : 201 | total reward : 0
# 2020/10/02 21:10:56
# episode : 637 | final step : 201 | total reward : 0
# 2020/10/02 21:11:03
# episode : 638 | final step : 201 | total reward : 0
# 2020/10/02 21:11:10
# episode : 639 | final step : 201 | total reward : 0
# 2020/10/02 21:11:16
# episode : 640 | final step : 201 | total reward : 0
# 2020/10/02 21:11:24
# episode : 641 | final step : 201 | total reward : 0
# 2020/10/02 21:11:27
# episode : 642 | final step : 98 | total reward : 0
# 2020/10/02 21:11:31
# episode : 643 | final step : 98 | total reward : 0
# 2020/10/02 21:11:34
# episode : 644 | final step : 98 | total reward : 0
# 2020/10/02 21:11:37
# episode : 645 | final step : 98 | total reward : 0
# 2020/10/02 21:11:41
# episode : 646 | final step : 99 | total reward : 0
# 2020/10/02 21:11:49
# episode : 647 | final step : 201 | total reward : 0
# 2020/10/02 21:11:52
# episode : 648 | final step : 98 | total reward : 0
# 2020/10/02 21:12:00
# episode : 649 | final step : 201 | total reward : 0
# 2020/10/02 21:12:03
# episode : 650 | final step : 98 | total reward : 0
# 2020/10/02 21:12:10
# episode : 651 | final step : 201 | total reward : 0
# 2020/10/02 21:12:17
# episode : 652 | final step : 201 | total reward : 0
# 2020/10/02 21:12:20
# episode : 653 | final step : 99 | total reward : 0
# 2020/10/02 21:12:27
# episode : 654 | final step : 201 | total reward : 0
# 2020/10/02 21:12:35
# episode : 655 | final step : 201 | total reward : 0
# 2020/10/02 21:12:41
# episode : 656 | final step : 201 | total reward : 0
# 2020/10/02 21:12:45
# episode : 657 | final step : 99 | total reward : 0
# 2020/10/02 21:12:48
# episode : 658 | final step : 98 | total reward : 0
# 2020/10/02 21:12:56
# episode : 659 | final step : 201 | total reward : 0
# 2020/10/02 21:13:02
# episode : 660 | final step : 201 | total reward : 0
# 2020/10/02 21:13:09
# episode : 661 | final step : 201 | total reward : 0
# 2020/10/02 21:13:16
# episode : 662 | final step : 201 | total reward : 0
# 2020/10/02 21:13:23
# episode : 663 | final step : 201 | total reward : 0
# 2020/10/02 21:13:30
# ...
# episode : 777 | final step : 201 | total reward : 0
# 2020/10/02 21:24:50
# episode : 778 | final step : 201 | total reward : 0
# 2020/10/02 21:24:57
# episode : 779 | final step : 201 | total reward : 0
# 2020/10/02 21:25:02
# episode : 780 | final step : 201 | total reward : 0
# 2020/10/02 21:25:04
# episode : 781 | final step : 201 | total reward : 0
# 2020/10/02 21:25:06
# episode : 782 | final step : 201 | total reward : 0
# 2020/10/02 21:25:09
# episode : 783 | final step : 201 | total reward : 0
# 2020/10/02 21:25:11
# episode : 784 | final step : 201 | total reward : 0
# 2020/10/02 21:25:12
# episode : 785 | final step : 98 | total reward : 0
# 2020/10/02 21:25:13
# episode : 786 | final step : 98 | total reward : 0
# 2020/10/02 21:25:15
# episode : 787 | final step : 98 | total reward : 0
# 2020/10/02 21:25:17
# episode : 788 | final step : 201 | total reward : 0
# 2020/10/02 21:25:20
# episode : 789 | final step : 201 | total reward : 0
# 2020/10/02 21:25:22
# episode : 790 | final step : 201 | total reward : 0
# 2020/10/02 21:25:23
# episode : 791 | final step : 99 | total reward : 0
# 2020/10/02 21:25:25
# episode : 792 | final step : 201 | total reward : 0
# 2020/10/02 21:25:28
# episode : 793 | final step : 201 | total reward : 0
# 2020/10/02 21:25:30
# episode : 794 | final step : 201 | total reward : 0
# 2020/10/02 21:25:32
# episode : 795 | final step : 201 | total reward : 0
# 2020/10/02 21:25:33
# episode : 796 | final step : 98 | total reward : 0
# 2020/10/02 21:25:35
# episode : 797 | final step : 201 | total reward : 0
# 2020/10/02 21:25:38
# episode : 798 | final step : 201 | total reward : 0
# 2020/10/02 21:25:40
# episode : 799 | final step : 201 | total reward : 0
# 2020/10/02 21:25:42
# episode : 800 | final step : 201 | total reward : 0
# 2020/10/02 21:25:45
# episode : 801 | final step : 201 | total reward : 0
# 2020/10/02 21:25:46
# episode : 802 | final step : 98 | total reward : 0
# 2020/10/02 21:25:47
# episode : 803 | final step : 99 | total reward : 0
# 2020/10/02 21:25:48
# episode : 804 | final step : 100 | total reward : 0
# 2020/10/02 21:25:50
# episode : 805 | final step : 201 | total reward : 0
# 2020/10/02 21:25:53
# episode : 806 | final step : 201 | total reward : 0
# 2020/10/02 21:25:56
# episode : 807 | final step : 201 | total reward : 0
# 2020/10/02 21:25:58
# episode : 808 | final step : 201 | total reward : 0
# 2020/10/02 21:26:00
# episode : 809 | final step : 201 | total reward : 0
# 2020/10/02 21:26:03
# episode : 810 | final step : 201 | total reward : 0
# 2020/10/02 21:26:05
# episode : 811 | final step : 201 | total reward : 0
# 2020/10/02 21:26:06
# episode : 812 | final step : 99 | total reward : 0
# 2020/10/02 21:26:08
# episode : 813 | final step : 201 | total reward : 0
# 2020/10/02 21:26:09
# episode : 814 | final step : 98 | total reward : 0
# 2020/10/02 21:26:11
# episode : 815 | final step : 201 | total reward : 0
# 2020/10/02 21:26:13
# episode : 816 | final step : 201 | total reward : 0
# 2020/10/02 21:26:16
# episode : 817 | final step : 201 | total reward : 0
# 2020/10/02 21:26:18
# episode : 818 | final step : 201 | total reward : 0
# 2020/10/02 21:26:19
# episode : 819 | final step : 98 | total reward : 0
# 2020/10/02 21:26:21
# episode : 820 | final step : 201 | total reward : 0
# 2020/10/02 21:26:23
# episode : 821 | final step : 201 | total reward : 0
# 2020/10/02 21:26:26
# episode : 822 | final step : 201 | total reward : 0
# 2020/10/02 21:26:27
# episode : 823 | final step : 98 | total reward : 0
# 2020/10/02 21:26:29
# episode : 824 | final step : 201 | total reward : 0
# 2020/10/02 21:26:32
# episode : 825 | final step : 201 | total reward : 0
# 2020/10/02 21:26:33
# episode : 826 | final step : 98 | total reward : 0
# 2020/10/02 21:26:36
# episode : 827 | final step : 201 | total reward : 0
# 2020/10/02 21:26:37
# episode : 828 | final step : 99 | total reward : 0
# 2020/10/02 21:26:38
# episode : 829 | final step : 98 | total reward : 0
# 2020/10/02 21:26:40
# episode : 830 | final step : 201 | total reward : 0
# 2020/10/02 21:26:42
# episode : 831 | final step : 201 | total reward : 0
# 2020/10/02 21:26:45
# episode : 832 | final step : 201 | total reward : 0
# 2020/10/02 21:26:47
# episode : 833 | final step : 201 | total reward : 0
# 2020/10/02 21:26:50
# episode : 834 | final step : 201 | total reward : 0
# 2020/10/02 21:26:52
# episode : 835 | final step : 201 | total reward : 0
# 2020/10/02 21:26:54
# episode : 836 | final step : 201 | total reward : 0
# 2020/10/02 21:26:56
# episode : 837 | final step : 201 | total reward : 0
# 2020/10/02 21:26:57
# episode : 838 | final step : 98 | total reward : 0
# 2020/10/02 21:26:58
# episode : 839 | final step : 98 | total reward : 0
# 2020/10/02 21:27:01
# episode : 840 | final step : 201 | total reward : 0
# 2020/10/02 21:27:03
# episode : 841 | final step : 201 | total reward : 0
# 2020/10/02 21:27:05
# episode : 842 | final step : 201 | total reward : 0
# 2020/10/02 21:27:06
# episode : 843 | final step : 98 | total reward : 0
# 2020/10/02 21:27:09
# episode : 844 | final step : 201 | total reward : 0
# 2020/10/02 21:27:11
# episode : 845 | final step : 201 | total reward : 0
# 2020/10/02 21:27:14
# episode : 846 | final step : 201 | total reward : 0
# 2020/10/02 21:27:16
# episode : 847 | final step : 201 | total reward : 0
# 2020/10/02 21:27:18
# episode : 848 | final step : 201 | total reward : 0
# 2020/10/02 21:27:21
# episode : 849 | final step : 201 | total reward : 0
# 2020/10/02 21:27:24
# episode : 850 | final step : 201 | total reward : 0
# 2020/10/02 21:27:26
# episode : 851 | final step : 201 | total reward : 0
# 2020/10/02 21:27:28
# episode : 852 | final step : 201 | total reward : 0
# 2020/10/02 21:27:31
# episode : 853 | final step : 201 | total reward : 0
# 2020/10/02 21:27:33
# episode : 854 | final step : 201 | total reward : 0
# 2020/10/02 21:27:36
# episode : 855 | final step : 201 | total reward : 0
# 2020/10/02 21:27:38
# episode : 856 | final step : 201 | total reward : 0
# 2020/10/02 21:27:40
# episode : 857 | final step : 201 | total reward : 0
# 2020/10/02 21:27:43
# episode : 858 | final step : 201 | total reward : 0
# 2020/10/02 21:27:45
# episode : 859 | final step : 201 | total reward : 0
# 2020/10/02 21:27:46
# episode : 860 | final step : 99 | total reward : 0
# 2020/10/02 21:27:47
# episode : 861 | final step : 99 | total reward : 0
# 2020/10/02 21:27:49
# episode : 862 | final step : 201 | total reward : 0
# 2020/10/02 21:27:50
# episode : 863 | final step : 98 | total reward : 0
# 2020/10/02 21:27:52
# episode : 864 | final step : 100 | total reward : 0
# 2020/10/02 21:27:54
# episode : 865 | final step : 201 | total reward : 0
# 2020/10/02 21:27:57
# episode : 866 | final step : 201 | total reward : 0
# 2020/10/02 21:27:59
# episode : 867 | final step : 201 | total reward : 0
# 2020/10/02 21:28:01
# episode : 868 | final step : 201 | total reward : 0
# 2020/10/02 21:28:02
# episode : 869 | final step : 98 | total reward : 0
# 2020/10/02 21:28:05
# episode : 870 | final step : 201 | total reward : 0
# 2020/10/02 21:28:07
# episode : 871 | final step : 201 | total reward : 0
# 2020/10/02 21:28:10
# episode : 872 | final step : 201 | total reward : 0
# 2020/10/02 21:28:12
# episode : 873 | final step : 201 | total reward : 0
# 2020/10/02 21:28:15
# episode : 874 | final step : 201 | total reward : 0
# 2020/10/02 21:28:16
# episode : 875 | final step : 98 | total reward : 0
# 2020/10/02 21:28:17
# episode : 876 | final step : 98 | total reward : 0
# 2020/10/02 21:28:19
# episode : 877 | final step : 201 | total reward : 0
# 2020/10/02 21:28:20
# episode : 878 | final step : 100 | total reward : 0
# 2020/10/02 21:28:21
# episode : 879 | final step : 99 | total reward : 0
# 2020/10/02 21:28:24
# episode : 880 | final step : 201 | total reward : 0
# 2020/10/02 21:28:26
# episode : 881 | final step : 201 | total reward : 0
# 2020/10/02 21:28:27
# episode : 882 | final step : 99 | total reward : 0
# 2020/10/02 21:28:29
# episode : 883 | final step : 201 | total reward : 0
# 2020/10/02 21:28:31
# episode : 884 | final step : 201 | total reward : 0
# 2020/10/02 21:28:33
# episode : 885 | final step : 201 | total reward : 0
# 2020/10/02 21:28:35
# episode : 886 | final step : 201 | total reward : 0
# 2020/10/02 21:28:37
# episode : 887 | final step : 201 | total reward : 0
# 2020/10/02 21:28:39
# episode : 888 | final step : 99 | total reward : 0
# 2020/10/02 21:28:41
# episode : 889 | final step : 201 | total reward : 0
# 2020/10/02 21:28:43
# episode : 890 | final step : 201 | total reward : 0
# 2020/10/02 21:28:45
# episode : 891 | final step : 201 | total reward : 0
# 2020/10/02 21:28:48
# episode : 892 | final step : 201 | total reward : 0
# 2020/10/02 21:28:50
# episode : 893 | final step : 201 | total reward : 0
# 2020/10/02 21:28:51
# episode : 894 | final step : 99 | total reward : 0
# 2020/10/02 21:28:53
# episode : 895 | final step : 201 | total reward : 0
# 2020/10/02 21:28:56
# episode : 896 | final step : 201 | total reward : 0
# 2020/10/02 21:28:58
# episode : 897 | final step : 201 | total reward : 0
# 2020/10/02 21:28:59
# episode : 898 | final step : 98 | total reward : 0
# 2020/10/02 21:29:01
# episode : 899 | final step : 201 | total reward : 0
# 2020/10/02 21:29:03
# episode : 900 | final step : 201 | total reward : 0
# 2020/10/02 21:29:04
# episode : 901 | final step : 98 | total reward : 0
# 2020/10/02 21:29:06
# episode : 902 | final step : 201 | total reward : 0
# 2020/10/02 21:29:07
# episode : 903 | final step : 98 | total reward : 0
# 2020/10/02 21:29:09
# episode : 904 | final step : 201 | total reward : 0
# 2020/10/02 21:29:11
# episode : 905 | final step : 201 | total reward : 0
# 2020/10/02 21:29:13
# episode : 906 | final step : 201 | total reward : 0
# 2020/10/02 21:29:15
# episode : 907 | final step : 201 | total reward : 0
# 2020/10/02 21:29:16
# episode : 908 | final step : 99 | total reward : 0
# 2020/10/02 21:29:17
# episode : 909 | final step : 98 | total reward : 0
# 2020/10/02 21:29:18
# episode : 910 | final step : 99 | total reward : 0
# 2020/10/02 21:29:20
# episode : 911 | final step : 201 | total reward : 0
# 2020/10/02 21:29:23
# episode : 912 | final step : 201 | total reward : 0
# 2020/10/02 21:29:25
# episode : 913 | final step : 201 | total reward : 0
# 2020/10/02 21:29:27
# episode : 914 | final step : 201 | total reward : 0
# 2020/10/02 21:29:30
# episode : 915 | final step : 201 | total reward : 0
# 2020/10/02 21:29:33
# episode : 916 | final step : 201 | total reward : 0
# 2020/10/02 21:29:35
# episode : 917 | final step : 201 | total reward : 0
# 2020/10/02 21:29:37
# episode : 918 | final step : 201 | total reward : 0
# 2020/10/02 21:29:38
# episode : 919 | final step : 98 | total reward : 0
# 2020/10/02 21:29:39
# episode : 920 | final step : 97 | total reward : 0
# 2020/10/02 21:29:41
# episode : 921 | final step : 201 | total reward : 0
# 2020/10/02 21:29:42
# episode : 922 | final step : 100 | total reward : 0
# 2020/10/02 21:29:43
# episode : 923 | final step : 99 | total reward : 0
# 2020/10/02 21:29:45
# episode : 924 | final step : 201 | total reward : 0
# 2020/10/02 21:29:47
# episode : 925 | final step : 201 | total reward : 0
# 2020/10/02 21:29:49
# episode : 926 | final step : 201 | total reward : 0
# 2020/10/02 21:29:50
# episode : 927 | final step : 100 | total reward : 0
# 2020/10/02 21:29:53
# episode : 928 | final step : 201 | total reward : 0
# 2020/10/02 21:29:55
# episode : 929 | final step : 201 | total reward : 0
# 2020/10/02 21:29:57
# episode : 930 | final step : 201 | total reward : 0
# 2020/10/02 21:30:00
# episode : 931 | final step : 201 | total reward : 0
# 2020/10/02 21:30:01
# episode : 932 | final step : 100 | total reward : 0
# 2020/10/02 21:30:03
# episode : 933 | final step : 201 | total reward : 0
# 2020/10/02 21:30:04
# episode : 934 | final step : 99 | total reward : 0
# 2020/10/02 21:30:05
# episode : 935 | final step : 100 | total reward : 0
# 2020/10/02 21:30:06
# episode : 936 | final step : 99 | total reward : 0
# 2020/10/02 21:30:08
# episode : 937 | final step : 201 | total reward : 0
# 2020/10/02 21:30:10
# episode : 938 | final step : 201 | total reward : 0
# 2020/10/02 21:30:12
# episode : 939 | final step : 201 | total reward : 0
# 2020/10/02 21:30:14
# episode : 940 | final step : 201 | total reward : 0
# 2020/10/02 21:30:17
# episode : 941 | final step : 201 | total reward : 0
# 2020/10/02 21:30:19
# episode : 942 | final step : 201 | total reward : 0
# 2020/10/02 21:30:21
# episode : 943 | final step : 201 | total reward : 0
# 2020/10/02 21:30:24
# episode : 944 | final step : 201 | total reward : 0
# 2020/10/02 21:30:26
# episode : 945 | final step : 201 | total reward : 0
# 2020/10/02 21:30:29
# episode : 946 | final step : 201 | total reward : 0
# 2020/10/02 21:30:31
# episode : 947 | final step : 201 | total reward : 0
# 2020/10/02 21:30:33
# episode : 948 | final step : 201 | total reward : 0
# 2020/10/02 21:30:35
# episode : 949 | final step : 201 | total reward : 0
# 2020/10/02 21:30:36
# episode : 950 | final step : 99 | total reward : 0
# 2020/10/02 21:30:37
# episode : 951 | final step : 201 | total reward : 0
# 2020/10/02 21:30:38
# episode : 952 | final step : 98 | total reward : 0
# 2020/10/02 21:30:40
# episode : 953 | final step : 201 | total reward : 0
# 2020/10/02 21:30:41
# episode : 954 | final step : 201 | total reward : 0
# 2020/10/02 21:30:42
# episode : 955 | final step : 98 | total reward : 0
# 2020/10/02 21:30:44
# episode : 956 | final step : 201 | total reward : 0
# 2020/10/02 21:30:44
# episode : 957 | final step : 98 | total reward : 0
# 2020/10/02 21:30:46
# episode : 958 | final step : 201 | total reward : 0
# 2020/10/02 21:30:47
# episode : 959 | final step : 201 | total reward : 0
# 2020/10/02 21:30:49
# episode : 960 | final step : 201 | total reward : 0
# 2020/10/02 21:30:50
# episode : 961 | final step : 201 | total reward : 0
# 2020/10/02 21:30:52
# episode : 962 | final step : 201 | total reward : 0
# 2020/10/02 21:30:53
# episode : 963 | final step : 98 | total reward : 0
# 2020/10/02 21:30:54
# episode : 964 | final step : 98 | total reward : 0
# 2020/10/02 21:30:55
# episode : 965 | final step : 201 | total reward : 0
# 2020/10/02 21:30:57
# episode : 966 | final step : 201 | total reward : 0
# 2020/10/02 21:30:58
# episode : 967 | final step : 201 | total reward : 0
# 2020/10/02 21:31:00
# episode : 968 | final step : 201 | total reward : 0
# 2020/10/02 21:31:01
# episode : 969 | final step : 98 | total reward : 0
# 2020/10/02 21:31:02
# episode : 970 | final step : 201 | total reward : 0
# 2020/10/02 21:31:04
# episode : 971 | final step : 201 | total reward : 0
# 2020/10/02 21:31:05
# episode : 972 | final step : 201 | total reward : 0
# 2020/10/02 21:31:06
# episode : 973 | final step : 99 | total reward : 0
# 2020/10/02 21:31:08
# episode : 974 | final step : 201 | total reward : 0
# 2020/10/02 21:31:09
# episode : 975 | final step : 201 | total reward : 0
# 2020/10/02 21:31:10
# episode : 976 | final step : 98 | total reward : 0
# 2020/10/02 21:31:11
# episode : 977 | final step : 100 | total reward : 0
# 2020/10/02 21:31:12
# episode : 978 | final step : 201 | total reward : 0
# 2020/10/02 21:31:13
# episode : 979 | final step : 98 | total reward : 0
# 2020/10/02 21:31:15
# episode : 980 | final step : 201 | total reward : 0
# 2020/10/02 21:31:16
# episode : 981 | final step : 201 | total reward : 0
# 2020/10/02 21:31:17
# episode : 982 | final step : 98 | total reward : 0
# 2020/10/02 21:31:19
# episode : 983 | final step : 201 | total reward : 0
# 2020/10/02 21:31:20
# episode : 984 | final step : 99 | total reward : 0
# 2020/10/02 21:31:21
# episode : 985 | final step : 201 | total reward : 0
# 2020/10/02 21:31:23
# episode : 986 | final step : 201 | total reward : 0
# 2020/10/02 21:31:24
# episode : 987 | final step : 201 | total reward : 0
# 2020/10/02 21:31:26
# episode : 988 | final step : 201 | total reward : 0
# 2020/10/02 21:31:26
# episode : 989 | final step : 100 | total reward : 0
# 2020/10/02 21:31:28
# episode : 990 | final step : 201 | total reward : 0
# 2020/10/02 21:31:30
# episode : 991 | final step : 201 | total reward : 0
# 2020/10/02 21:31:31
# episode : 992 | final step : 201 | total reward : 0
# 2020/10/02 21:31:33
# episode : 993 | final step : 201 | total reward : 0
# 2020/10/02 21:31:34
# episode : 994 | final step : 98 | total reward : 0
# 2020/10/02 21:31:36
# episode : 995 | final step : 201 | total reward : 0
# 2020/10/02 21:31:38
# episode : 996 | final step : 201 | total reward : 0
# 2020/10/02 21:31:39
# episode : 997 | final step : 201 | total reward : 0
# 2020/10/02 21:31:40
# episode : 998 | final step : 99 | total reward : 0
# 2020/10/02 21:31:42
# episode : 999 | final step : 201 | total reward : 0
# Complete

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(reward_list)

# %%
def moving_average(data,n):
    len_data=len(data)-n
    res_data=np.zeros(len_data)

    for i in range(len_data):
        res_data[i]=sum(data[i:i+n])/n
    return res_data

# %%
average_number=10
filtered_data=moving_average(reward_list,average_number)
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(filtered_data)

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[999]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()
