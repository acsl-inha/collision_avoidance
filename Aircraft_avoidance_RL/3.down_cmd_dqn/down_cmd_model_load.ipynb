# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
import time
import itertools
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
import gym_Aircraft
num_gpus=4
batch_size=128

# %%
env = gym.make("acav-v0")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# /home/jupyter-kunwoopark/.local/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """transition 저장"""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
class DQN(torch.nn.Module):
    def __init__(self, num_inputs, num_actions):
        super(DQN, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, env.action_space.n),
            nn.LeakyReLU(0.2, inplace=True)
        )

    def forward(self, x):
        out=self.fc(x)
        return out

# %%
BATCH_SIZE = batch_size
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10

# %%
policy_net = nn.DataParallel(DQN(env.observation_space.shape[0], env.action_space.n).to(device))
target_net = nn.DataParallel(DQN(env.observation_space.shape[0], env.action_space.n).to(device))
policy_net.load_state_dict(torch.load("train_res_fin"))
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
# Out:
# DataParallel(
#   (module): DQN(
#     (fc): Sequential(
#       (0): Linear(in_features=5, out_features=40, bias=True)
#       (1): LeakyReLU(negative_slope=0.2, inplace=True)
#       (2): Linear(in_features=40, out_features=40, bias=True)
#       (3): LeakyReLU(negative_slope=0.2, inplace=True)
#       (4): Linear(in_features=40, out_features=40, bias=True)
#       (5): LeakyReLU(negative_slope=0.2, inplace=True)
#       (6): Linear(in_features=40, out_features=40, bias=True)
#       (7): LeakyReLU(negative_slope=0.2, inplace=True)
#       (8): Linear(in_features=40, out_features=40, bias=True)
#       (9): LeakyReLU(negative_slope=0.2, inplace=True)
#       (10): Linear(in_features=40, out_features=40, bias=True)
#       (11): LeakyReLU(negative_slope=0.2, inplace=True)
#       (12): Linear(in_features=40, out_features=40, bias=True)
#       (13): LeakyReLU(negative_slope=0.2, inplace=True)
#       (14): Linear(in_features=40, out_features=3, bias=True)
#       (15): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#   )
# )

# %%
n_actions = env.action_space.n

# %%
optimizer = optim.Adam(policy_net.parameters())
memory = ReplayMemory(10000)

# %%
steps_done = 0

# %%
def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max (1)은 각 행의 가장 큰 열 값을 반환합니다.
            # 최대 결과의 두번째 열은 최대 요소의 주소값이므로,
            # 기대 보상이 더 큰 행동을 선택할 수 있습니다.
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(n_actions)]], device=device, dtype=torch.long)

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)

    batch = Transition(*zip(*transitions))

    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    state_action_values = policy_net(state_batch).gather(1, action_batch)

    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    # 기대 Q 값 계산
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Huber 손실 계산
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    # 모델 최적화
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
num_episodes = 10000
total_res=[]
reward_list=[]
for i_episode in range(num_episodes):
    total_reward=0
    
    # 환경과 상태 초기화
    res_list=np.zeros(11)
    state = env.reset()
    state=torch.from_numpy(state.astype(np.float32)).unsqueeze(0).to(device)
    for t in count():
        # 행동 선택과 수행
        
        action = select_action(state)
        next_state, reward, done, res = env.step(action.item())
        reward = torch.tensor([reward], dtype=torch.float32).to(device)
        
        next_state=torch.from_numpy(next_state.astype(np.float32)).unsqueeze(0).to(device)

        # 새로운 상태 관찰
        if not done:
            next_state = next_state
        else:
            next_state = None

        # 메모리에 변이 저장
        memory.push(state, action, next_state, reward)

        # 다음 상태로 이동
        state = next_state

        # 최적화 한단계 수행(목표 네트워크에서)
        optimize_model()
        
        # Data save
        
        cmd_list,r_list,elev_list,azim_list,Pm_list,Pt_list,h_list=res
        Pm_list=Pm_list.tolist()
        Pt_list=Pt_list.tolist()
        merged_data=itertools.chain([cmd_list],[r_list],[elev_list],[azim_list],Pm_list,Pt_list,[h_list])
        merged_data=np.array(list(merged_data))
        res_list=np.vstack([res_list,merged_data])
        
        total_reward+=reward
        
        if done:
            res_list=np.delete(res_list,0,0)
            
            total_res.append(res_list)
            reward_list.append(total_reward)
            
            now = time.localtime()
            print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))
            print("episode : {} | final step : {} | total reward : {}".format(i_episode, t, total_reward.item()))
            break
            
        
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

print('Complete')
env.close()
# Out:
# 2020/10/02 00:06:00
# episode : 0 | final step : 98 | total reward : -1.0
# 2020/10/02 00:06:10
# episode : 1 | final step : 98 | total reward : -1.0
# 2020/10/02 00:06:13
# episode : 2 | final step : 99 | total reward : 0.0
# 2020/10/02 00:06:16
# episode : 3 | final step : 98 | total reward : -1.0
# 2020/10/02 00:06:19
# episode : 4 | final step : 98 | total reward : -1.0
# 2020/10/02 00:06:22
# episode : 5 | final step : 98 | total reward : -1.0
# 2020/10/02 00:06:25
# episode : 6 | final step : 99 | total reward : 0.0
# 2020/10/02 00:06:28
# episode : 7 | final step : 100 | total reward : 0.0
# 2020/10/02 00:06:31
# episode : 8 | final step : 98 | total reward : 0.0
# 2020/10/02 00:06:34
# episode : 9 | final step : 98 | total reward : -1.0
# 2020/10/02 00:06:37
# episode : 10 | final step : 98 | total reward : -1.0
# 2020/10/02 00:06:40
# episode : 11 | final step : 98 | total reward : 0.0
# 2020/10/02 00:06:43
# episode : 12 | final step : 98 | total reward : -1.0
# 2020/10/02 00:06:46
# episode : 13 | final step : 95 | total reward : 0.0
# 2020/10/02 00:06:49
# episode : 14 | final step : 98 | total reward : -1.0
# 2020/10/02 00:06:52
# episode : 15 | final step : 95 | total reward : 0.0
# 2020/10/02 00:06:55
# episode : 16 | final step : 99 | total reward : -1.0
# 2020/10/02 00:06:58
# episode : 17 | final step : 99 | total reward : -1.0
# 2020/10/02 00:07:01
# episode : 18 | final step : 98 | total reward : -1.0
# 2020/10/02 00:07:04
# episode : 19 | final step : 100 | total reward : 0.0
# 2020/10/02 00:07:07
# episode : 20 | final step : 100 | total reward : 0.0
# 2020/10/02 00:07:10
# episode : 21 | final step : 98 | total reward : -1.0
# 2020/10/02 00:07:13
# episode : 22 | final step : 98 | total reward : -1.0
# 2020/10/02 00:07:16
# episode : 23 | final step : 96 | total reward : 0.0
# 2020/10/02 00:07:19
# episode : 24 | final step : 98 | total reward : 0.0
# 2020/10/02 00:07:22
# episode : 25 | final step : 98 | total reward : -1.0
# 2020/10/02 00:07:25
# episode : 26 | final step : 97 | total reward : 0.0
# 2020/10/02 00:07:28
# episode : 27 | final step : 99 | total reward : -1.0
# 2020/10/02 00:07:31
# episode : 28 | final step : 98 | total reward : -1.0
# 2020/10/02 00:07:34
# episode : 29 | final step : 99 | total reward : -1.0
# 2020/10/02 00:07:37
# episode : 30 | final step : 98 | total reward : -1.0
# 2020/10/02 00:07:40
# episode : 31 | final step : 99 | total reward : -1.0
# 2020/10/02 00:07:44
# episode : 32 | final step : 98 | total reward : -1.0
# 2020/10/02 00:07:46
# episode : 33 | final step : 98 | total reward : -1.0
# 2020/10/02 00:07:49
# episode : 34 | final step : 97 | total reward : 0.0
# 2020/10/02 00:07:52
# episode : 35 | final step : 95 | total reward : 0.0
# 2020/10/02 00:07:56
# episode : 36 | final step : 100 | total reward : 0.0
# 2020/10/02 00:07:59
# episode : 37 | final step : 98 | total reward : -1.0
# 2020/10/02 00:08:02
# episode : 38 | final step : 98 | total reward : -1.0
# 2020/10/02 00:08:05
# episode : 39 | final step : 101 | total reward : 0.0
# 2020/10/02 00:08:08
# episode : 40 | final step : 103 | total reward : 0.0
# 2020/10/02 00:08:11
# episode : 41 | final step : 100 | total reward : 0.0
# 2020/10/02 00:08:14
# episode : 42 | final step : 99 | total reward : 0.0
# 2020/10/02 00:08:17
# episode : 43 | final step : 98 | total reward : 0.0
# 2020/10/02 00:08:20
# episode : 44 | final step : 100 | total reward : 0.0
# 2020/10/02 00:08:23
# episode : 45 | final step : 100 | total reward : 0.0
# 2020/10/02 00:08:26
# episode : 46 | final step : 98 | total reward : -1.0
# 2020/10/02 00:08:29
# episode : 47 | final step : 98 | total reward : -1.0
# 2020/10/02 00:08:32
# episode : 48 | final step : 99 | total reward : -1.0
# 2020/10/02 00:08:35
# episode : 49 | final step : 100 | total reward : 0.0
# 2020/10/02 00:08:39
# episode : 50 | final step : 99 | total reward : 0.0
# 2020/10/02 00:08:41
# episode : 51 | final step : 100 | total reward : 0.0
# 2020/10/02 00:08:44
# episode : 52 | final step : 97 | total reward : 0.0
# 2020/10/02 00:08:48
# episode : 53 | final step : 98 | total reward : -1.0
# 2020/10/02 00:08:50
# episode : 54 | final step : 97 | total reward : -1.0
# 2020/10/02 00:08:53
# episode : 55 | final step : 96 | total reward : 0.0
# 2020/10/02 00:08:56
# episode : 56 | final step : 98 | total reward : -1.0
# 2020/10/02 00:09:00
# episode : 57 | final step : 98 | total reward : 0.0
# 2020/10/02 00:09:02
# episode : 58 | final step : 98 | total reward : 0.0
# 2020/10/02 00:09:05
# episode : 59 | final step : 98 | total reward : -1.0
# 2020/10/02 00:09:08
# episode : 60 | final step : 98 | total reward : 0.0
# 2020/10/02 00:09:11
# episode : 61 | final step : 100 | total reward : 0.0
# 2020/10/02 00:09:14
# episode : 62 | final step : 99 | total reward : -1.0
# 2020/10/02 00:09:17
# episode : 63 | final step : 98 | total reward : -1.0
# 2020/10/02 00:09:20
# episode : 64 | final step : 98 | total reward : 0.0
# 2020/10/02 00:09:23
# episode : 65 | final step : 98 | total reward : -1.0
# 2020/10/02 00:09:26
# episode : 66 | final step : 98 | total reward : -1.0
# 2020/10/02 00:09:29
# episode : 67 | final step : 98 | total reward : -1.0
# 2020/10/02 00:09:32
# episode : 68 | final step : 99 | total reward : -1.0
# 2020/10/02 00:09:35
# episode : 69 | final step : 98 | total reward : 0.0
# 2020/10/02 00:09:38
# episode : 70 | final step : 98 | total reward : -1.0
# 2020/10/02 00:09:41
# episode : 71 | final step : 98 | total reward : 0.0
# 2020/10/02 00:09:44
# episode : 72 | final step : 98 | total reward : -1.0
# 2020/10/02 00:09:47
# episode : 73 | final step : 97 | total reward : 0.0
# 2020/10/02 00:09:50
# episode : 74 | final step : 98 | total reward : -1.0
# 2020/10/02 00:09:53
# episode : 75 | final step : 98 | total reward : -1.0
# 2020/10/02 00:09:56
# episode : 76 | final step : 98 | total reward : -1.0
# 2020/10/02 00:09:59
# episode : 77 | final step : 99 | total reward : -1.0
# 2020/10/02 00:10:02
# episode : 78 | final step : 100 | total reward : -1.0
# 2020/10/02 00:10:05
# episode : 79 | final step : 98 | total reward : -1.0
# 2020/10/02 00:10:08
# episode : 80 | final step : 98 | total reward : -1.0
# 2020/10/02 00:10:11
# episode : 81 | final step : 98 | total reward : -1.0
# 2020/10/02 00:10:14
# episode : 82 | final step : 97 | total reward : 0.0
# 2020/10/02 00:10:17
# episode : 83 | final step : 99 | total reward : -1.0
# 2020/10/02 00:10:21
# episode : 84 | final step : 98 | total reward : -1.0
# 2020/10/02 00:10:24
# episode : 85 | final step : 98 | total reward : 0.0
# 2020/10/02 00:10:27
# episode : 86 | final step : 98 | total reward : -1.0
# 2020/10/02 00:10:30
# episode : 87 | final step : 100 | total reward : 0.0
# 2020/10/02 00:10:33
# episode : 88 | final step : 99 | total reward : 0.0
# 2020/10/02 00:10:36
# episode : 89 | final step : 99 | total reward : -1.0
# 2020/10/02 00:10:39
# episode : 90 | final step : 99 | total reward : -1.0
# 2020/10/02 00:10:42
# episode : 91 | final step : 101 | total reward : 0.0
# 2020/10/02 00:10:45
# episode : 92 | final step : 98 | total reward : -1.0
# 2020/10/02 00:10:48
# episode : 93 | final step : 97 | total reward : 0.0
# 2020/10/02 00:10:52
# episode : 94 | final step : 100 | total reward : 0.0
# 2020/10/02 00:10:55
# episode : 95 | final step : 96 | total reward : 0.0
# 2020/10/02 00:10:58
# episode : 96 | final step : 97 | total reward : 0.0
# 2020/10/02 00:11:01
# episode : 97 | final step : 98 | total reward : -1.0
# 2020/10/02 00:11:04
# episode : 98 | final step : 99 | total reward : -1.0
# 2020/10/02 00:11:07
# episode : 99 | final step : 98 | total reward : 0.0
# 2020/10/02 00:11:10
# episode : 100 | final step : 99 | total reward : -1.0
# 2020/10/02 00:11:13
# episode : 101 | final step : 98 | total reward : 0.0
# 2020/10/02 00:11:16
# episode : 102 | final step : 99 | total reward : 0.0
# 2020/10/02 00:11:19
# episode : 103 | final step : 97 | total reward : 0.0
# 2020/10/02 00:11:22
# episode : 104 | final step : 98 | total reward : -1.0
# 2020/10/02 00:11:26
# episode : 105 | final step : 99 | total reward : -1.0
# 2020/10/02 00:11:29
# episode : 106 | final step : 99 | total reward : -1.0
# 2020/10/02 00:11:31
# episode : 107 | final step : 98 | total reward : 0.0
# 2020/10/02 00:11:35
# episode : 108 | final step : 99 | total reward : -1.0
# 2020/10/02 00:11:38
# episode : 109 | final step : 99 | total reward : 0.0
# 2020/10/02 00:11:41
# episode : 110 | final step : 100 | total reward : 0.0
# 2020/10/02 00:11:44
# episode : 111 | final step : 98 | total reward : -1.0
# 2020/10/02 00:11:47
# episode : 112 | final step : 99 | total reward : -1.0
# 2020/10/02 00:11:50
# episode : 113 | final step : 94 | total reward : 0.0
# 2020/10/02 00:11:53
# episode : 114 | final step : 98 | total reward : -1.0
# 2020/10/02 00:11:56
# episode : 115 | final step : 96 | total reward : 0.0
# 2020/10/02 00:12:00
# episode : 116 | final step : 100 | total reward : 0.0
# 2020/10/02 00:12:02
# episode : 117 | final step : 98 | total reward : 0.0
# 2020/10/02 00:12:05
# episode : 118 | final step : 95 | total reward : 0.0
# 2020/10/02 00:12:09
# episode : 119 | final step : 97 | total reward : -1.0
# 2020/10/02 00:12:12
# episode : 120 | final step : 99 | total reward : 0.0
# 2020/10/02 00:12:15
# episode : 121 | final step : 100 | total reward : -1.0
# 2020/10/02 00:12:18
# episode : 122 | final step : 98 | total reward : 0.0
# 2020/10/02 00:12:21
# episode : 123 | final step : 97 | total reward : 0.0
# 2020/10/02 00:12:25
# episode : 124 | final step : 99 | total reward : -1.0
# 2020/10/02 00:12:28
# episode : 125 | final step : 98 | total reward : -1.0
# 2020/10/02 00:12:31
# episode : 126 | final step : 98 | total reward : -1.0
# 2020/10/02 00:12:34
# episode : 127 | final step : 100 | total reward : 0.0
# 2020/10/02 00:12:37
# episode : 128 | final step : 98 | total reward : 0.0
# 2020/10/02 00:12:40
# episode : 129 | final step : 99 | total reward : 0.0
# 2020/10/02 00:12:43
# episode : 130 | final step : 97 | total reward : 0.0
# 2020/10/02 00:12:46
# episode : 131 | final step : 99 | total reward : 0.0
# 2020/10/02 00:12:50
# episode : 132 | final step : 98 | total reward : -1.0
# 2020/10/02 00:12:53
# episode : 133 | final step : 98 | total reward : -1.0
# 2020/10/02 00:12:56
# episode : 134 | final step : 98 | total reward : 0.0
# 2020/10/02 00:12:59
# episode : 135 | final step : 98 | total reward : 0.0
# 2020/10/02 00:13:02
# episode : 136 | final step : 98 | total reward : -1.0
# 2020/10/02 00:13:05
# episode : 137 | final step : 99 | total reward : -1.0
# 2020/10/02 00:13:08
# episode : 138 | final step : 101 | total reward : 0.0
# 2020/10/02 00:13:11
# episode : 139 | final step : 98 | total reward : -1.0
# 2020/10/02 00:13:15
# episode : 140 | final step : 100 | total reward : 0.0
# 2020/10/02 00:13:18
# episode : 141 | final step : 98 | total reward : -1.0
# 2020/10/02 00:13:21
# episode : 142 | final step : 98 | total reward : -1.0
# 2020/10/02 00:13:24
# episode : 143 | final step : 99 | total reward : -1.0
# 2020/10/02 00:13:27
# episode : 144 | final step : 100 | total reward : 0.0
# 2020/10/02 00:13:30
# episode : 145 | final step : 99 | total reward : -1.0
# 2020/10/02 00:13:34
# episode : 146 | final step : 98 | total reward : -1.0
# 2020/10/02 00:13:37
# episode : 147 | final step : 98 | total reward : -1.0
# 2020/10/02 00:13:40
# episode : 148 | final step : 98 | total reward : -1.0
# 2020/10/02 00:13:43
# episode : 149 | final step : 99 | total reward : 0.0
# 2020/10/02 00:13:46
# episode : 150 | final step : 95 | total reward : 0.0
# 2020/10/02 00:13:49
# episode : 151 | final step : 100 | total reward : 0.0
# 2020/10/02 00:13:52
# episode : 152 | final step : 98 | total reward : -1.0
# 2020/10/02 00:13:55
# episode : 153 | final step : 98 | total reward : -1.0
# 2020/10/02 00:13:59
# episode : 154 | final step : 100 | total reward : 0.0
# 2020/10/02 00:14:02
# episode : 155 | final step : 99 | total reward : -1.0
# 2020/10/02 00:14:05
# episode : 156 | final step : 100 | total reward : 0.0
# 2020/10/02 00:14:08
# episode : 157 | final step : 100 | total reward : 0.0
# 2020/10/02 00:14:11
# episode : 158 | final step : 95 | total reward : 0.0
# 2020/10/02 00:14:14
# episode : 159 | final step : 98 | total reward : 0.0
# 2020/10/02 00:14:18
# episode : 160 | final step : 99 | total reward : 0.0
# 2020/10/02 00:14:21
# episode : 161 | final step : 98 | total reward : -1.0
# 2020/10/02 00:14:24
# episode : 162 | final step : 98 | total reward : -1.0
# 2020/10/02 00:14:27
# episode : 163 | final step : 100 | total reward : 0.0
# 2020/10/02 00:14:30
# episode : 164 | final step : 100 | total reward : 0.0
# 2020/10/02 00:14:33
# episode : 165 | final step : 97 | total reward : 0.0
# 2020/10/02 00:14:37
# episode : 166 | final step : 98 | total reward : -1.0
# 2020/10/02 00:14:40
# episode : 167 | final step : 98 | total reward : 0.0
# 2020/10/02 00:14:43
# episode : 168 | final step : 98 | total reward : -1.0
# 2020/10/02 00:14:46
# episode : 169 | final step : 97 | total reward : 0.0
# 2020/10/02 00:14:49
# episode : 170 | final step : 97 | total reward : 0.0
# 2020/10/02 00:14:52
# episode : 171 | final step : 98 | total reward : -1.0
# 2020/10/02 00:14:55
# episode : 172 | final step : 98 | total reward : -1.0
# 2020/10/02 00:14:59
# episode : 173 | final step : 99 | total reward : 0.0
# 2020/10/02 00:15:02
# episode : 174 | final step : 100 | total reward : -1.0
# 2020/10/02 00:15:05
# episode : 175 | final step : 98 | total reward : -1.0
# 2020/10/02 00:15:08
# episode : 176 | final step : 98 | total reward : 0.0
# 2020/10/02 00:15:11
# episode : 177 | final step : 99 | total reward : -1.0
# 2020/10/02 00:15:14
# episode : 178 | final step : 99 | total reward : 0.0
# 2020/10/02 00:15:17
# episode : 179 | final step : 99 | total reward : -1.0
# 2020/10/02 00:15:20
# episode : 180 | final step : 98 | total reward : -1.0
# 2020/10/02 00:15:23
# episode : 181 | final step : 98 | total reward : 0.0
# 2020/10/02 00:15:27
# episode : 182 | final step : 102 | total reward : 0.0
# 2020/10/02 00:15:30
# episode : 183 | final step : 102 | total reward : 0.0
# 2020/10/02 00:15:33
# episode : 184 | final step : 98 | total reward : -1.0
# 2020/10/02 00:15:36
# episode : 185 | final step : 98 | total reward : -1.0
# 2020/10/02 00:15:39
# episode : 186 | final step : 98 | total reward : 0.0
# 2020/10/02 00:15:42
# episode : 187 | final step : 99 | total reward : 0.0
# 2020/10/02 00:15:46
# episode : 188 | final step : 98 | total reward : -1.0
# 2020/10/02 00:15:49
# episode : 189 | final step : 98 | total reward : -1.0
# 2020/10/02 00:15:52
# episode : 190 | final step : 99 | total reward : -1.0
# 2020/10/02 00:15:55
# episode : 191 | final step : 98 | total reward : -1.0
# 2020/10/02 00:15:58
# episode : 192 | final step : 98 | total reward : -1.0
# 2020/10/02 00:16:01
# episode : 193 | final step : 98 | total reward : -1.0
# 2020/10/02 00:16:05
# episode : 194 | final step : 100 | total reward : 0.0
# 2020/10/02 00:16:08
# episode : 195 | final step : 100 | total reward : 0.0
# 2020/10/02 00:16:11
# episode : 196 | final step : 99 | total reward : -1.0
# 2020/10/02 00:16:14
# episode : 197 | final step : 100 | total reward : 0.0
# 2020/10/02 00:16:17
# episode : 198 | final step : 99 | total reward : 0.0
# 2020/10/02 00:16:20
# episode : 199 | final step : 98 | total reward : -1.0
# 2020/10/02 00:16:23
# episode : 200 | final step : 98 | total reward : -1.0
# 2020/10/02 00:16:26
# episode : 201 | final step : 98 | total reward : -1.0
# 2020/10/02 00:16:30
# episode : 202 | final step : 97 | total reward : 0.0
# 2020/10/02 00:16:33
# episode : 203 | final step : 100 | total reward : 0.0
# 2020/10/02 00:16:36
# episode : 204 | final step : 98 | total reward : -1.0
# 2020/10/02 00:16:39
# episode : 205 | final step : 98 | total reward : -1.0
# 2020/10/02 00:16:42
# episode : 206 | final step : 98 | total reward : -1.0
# 2020/10/02 00:16:45
# episode : 207 | final step : 98 | total reward : -1.0
# 2020/10/02 00:16:48
# episode : 208 | final step : 98 | total reward : -1.0
# 2020/10/02 00:16:51
# episode : 209 | final step : 97 | total reward : 0.0
# 2020/10/02 00:16:54
# episode : 210 | final step : 98 | total reward : -1.0
# 2020/10/02 00:16:58
# episode : 211 | final step : 98 | total reward : 0.0
# 2020/10/02 00:17:01
# episode : 212 | final step : 99 | total reward : -1.0
# 2020/10/02 00:17:04
# episode : 213 | final step : 97 | total reward : 0.0
# 2020/10/02 00:17:07
# episode : 214 | final step : 99 | total reward : 0.0
# 2020/10/02 00:17:10
# episode : 215 | final step : 98 | total reward : -1.0
# 2020/10/02 00:17:13
# episode : 216 | final step : 99 | total reward : -1.0
# 2020/10/02 00:17:16
# episode : 217 | final step : 100 | total reward : 0.0
# 2020/10/02 00:17:19
# episode : 218 | final step : 98 | total reward : -1.0
# 2020/10/02 00:17:23
# episode : 219 | final step : 98 | total reward : -1.0
# 2020/10/02 00:17:26
# episode : 220 | final step : 98 | total reward : -1.0
# 2020/10/02 00:17:29
# episode : 221 | final step : 98 | total reward : 0.0
# 2020/10/02 00:17:32
# episode : 222 | final step : 98 | total reward : -1.0
# 2020/10/02 00:17:35
# episode : 223 | final step : 98 | total reward : -1.0
# 2020/10/02 00:17:38
# episode : 224 | final step : 99 | total reward : 0.0
# 2020/10/02 00:17:41
# episode : 225 | final step : 98 | total reward : 0.0
# 2020/10/02 00:17:44
# episode : 226 | final step : 100 | total reward : 0.0
# 2020/10/02 00:17:48
# episode : 227 | final step : 99 | total reward : -1.0
# 2020/10/02 00:17:51
# episode : 228 | final step : 100 | total reward : 0.0
# 2020/10/02 00:17:54
# episode : 229 | final step : 98 | total reward : -1.0
# 2020/10/02 00:17:57
# episode : 230 | final step : 98 | total reward : -1.0
# 2020/10/02 00:18:00
# episode : 231 | final step : 97 | total reward : -1.0
# 2020/10/02 00:18:03
# episode : 232 | final step : 98 | total reward : -1.0
# 2020/10/02 00:18:06
# episode : 233 | final step : 99 | total reward : 0.0
# 2020/10/02 00:18:10
# episode : 234 | final step : 98 | total reward : -1.0
# 2020/10/02 00:18:13
# episode : 235 | final step : 100 | total reward : -1.0
# 2020/10/02 00:18:16
# episode : 236 | final step : 100 | total reward : 0.0
# 2020/10/02 00:18:19
# episode : 237 | final step : 98 | total reward : -1.0
# 2020/10/02 00:18:22
# episode : 238 | final step : 98 | total reward : -1.0
# 2020/10/02 00:18:25
# episode : 239 | final step : 98 | total reward : 0.0
# 2020/10/02 00:18:28
# episode : 240 | final step : 99 | total reward : -1.0
# 2020/10/02 00:18:31
# episode : 241 | final step : 98 | total reward : 0.0
# 2020/10/02 00:18:34
# episode : 242 | final step : 98 | total reward : -1.0
# 2020/10/02 00:18:38
# episode : 243 | final step : 98 | total reward : -1.0
# 2020/10/02 00:18:41
# episode : 244 | final step : 98 | total reward : -1.0
# 2020/10/02 00:18:44
# episode : 245 | final step : 98 | total reward : -1.0
# 2020/10/02 00:18:47
# episode : 246 | final step : 99 | total reward : -1.0
# 2020/10/02 00:18:50
# episode : 247 | final step : 99 | total reward : -1.0
# 2020/10/02 00:18:53
# episode : 248 | final step : 102 | total reward : 0.0
# 2020/10/02 00:18:57
# episode : 249 | final step : 97 | total reward : 0.0
# 2020/10/02 00:18:59
# episode : 250 | final step : 98 | total reward : -1.0
# 2020/10/02 00:19:03
# episode : 251 | final step : 101 | total reward : 0.0
# 2020/10/02 00:19:06
# episode : 252 | final step : 96 | total reward : 0.0
# 2020/10/02 00:19:09
# episode : 253 | final step : 99 | total reward : -1.0
# 2020/10/02 00:19:12
# episode : 254 | final step : 100 | total reward : 0.0
# 2020/10/02 00:19:15
# episode : 255 | final step : 99 | total reward : 0.0
# 2020/10/02 00:19:18
# episode : 256 | final step : 99 | total reward : -1.0
# 2020/10/02 00:19:22
# episode : 257 | final step : 98 | total reward : -1.0
# 2020/10/02 00:19:25
# episode : 258 | final step : 100 | total reward : 0.0
# 2020/10/02 00:19:28
# episode : 259 | final step : 102 | total reward : 0.0
# 2020/10/02 00:19:31
# episode : 260 | final step : 98 | total reward : 0.0
# 2020/10/02 00:19:34
# episode : 261 | final step : 98 | total reward : -1.0
# 2020/10/02 00:19:38
# episode : 262 | final step : 99 | total reward : -1.0
# 2020/10/02 00:19:41
# episode : 263 | final step : 98 | total reward : -1.0
# 2020/10/02 00:19:44
# episode : 264 | final step : 98 | total reward : -1.0
# 2020/10/02 00:19:47
# episode : 265 | final step : 98 | total reward : -1.0
# 2020/10/02 00:19:50
# episode : 266 | final step : 98 | total reward : 0.0
# 2020/10/02 00:19:53
# episode : 267 | final step : 99 | total reward : -1.0
# 2020/10/02 00:19:56
# episode : 268 | final step : 98 | total reward : -1.0
# 2020/10/02 00:20:00
# episode : 269 | final step : 100 | total reward : 0.0
# 2020/10/02 00:20:03
# episode : 270 | final step : 98 | total reward : -1.0
# 2020/10/02 00:20:06
# episode : 271 | final step : 98 | total reward : -1.0
# 2020/10/02 00:20:09
# episode : 272 | final step : 100 | total reward : 0.0
# 2020/10/02 00:20:12
# episode : 273 | final step : 99 | total reward : 0.0
# 2020/10/02 00:20:15
# episode : 274 | final step : 99 | total reward : -1.0
# 2020/10/02 00:20:18
# episode : 275 | final step : 98 | total reward : -1.0
# 2020/10/02 00:20:22
# episode : 276 | final step : 97 | total reward : 0.0
# 2020/10/02 00:20:25
# episode : 277 | final step : 99 | total reward : -1.0
# 2020/10/02 00:20:28
# episode : 278 | final step : 94 | total reward : 0.0
# 2020/10/02 00:20:31
# episode : 279 | final step : 98 | total reward : -1.0
# 2020/10/02 00:20:34
# episode : 280 | final step : 98 | total reward : -1.0
# 2020/10/02 00:20:37
# episode : 281 | final step : 99 | total reward : 0.0
# 2020/10/02 00:20:40
# episode : 282 | final step : 98 | total reward : 0.0
# 2020/10/02 00:20:43
# episode : 283 | final step : 98 | total reward : 0.0
# 2020/10/02 00:20:46
# episode : 284 | final step : 99 | total reward : -1.0
# 2020/10/02 00:20:49
# episode : 285 | final step : 99 | total reward : -1.0
# 2020/10/02 00:20:53
# episode : 286 | final step : 100 | total reward : -1.0
# 2020/10/02 00:20:56
# episode : 287 | final step : 97 | total reward : -1.0
# 2020/10/02 00:20:59
# episode : 288 | final step : 98 | total reward : -1.0
# 2020/10/02 00:21:02
# episode : 289 | final step : 101 | total reward : 0.0
# 2020/10/02 00:21:05
# episode : 290 | final step : 99 | total reward : -1.0
# 2020/10/02 00:21:09
# episode : 291 | final step : 98 | total reward : -1.0
# 2020/10/02 00:21:12
# episode : 292 | final step : 98 | total reward : -1.0
# 2020/10/02 00:21:15
# episode : 293 | final step : 100 | total reward : 0.0
# 2020/10/02 00:21:18
# episode : 294 | final step : 96 | total reward : 0.0
# 2020/10/02 00:21:21
# episode : 295 | final step : 99 | total reward : -1.0
# 2020/10/02 00:21:24
# episode : 296 | final step : 98 | total reward : -1.0
# 2020/10/02 00:21:27
# episode : 297 | final step : 99 | total reward : -1.0
# 2020/10/02 00:21:30
# episode : 298 | final step : 98 | total reward : -1.0
# 2020/10/02 00:21:33
# episode : 299 | final step : 96 | total reward : 0.0
# 2020/10/02 00:21:36
# episode : 300 | final step : 98 | total reward : -1.0
# 2020/10/02 00:21:39
# episode : 301 | final step : 95 | total reward : 0.0
# 2020/10/02 00:21:43
# episode : 302 | final step : 99 | total reward : -1.0
# 2020/10/02 00:21:46
# episode : 303 | final step : 98 | total reward : -1.0
# 2020/10/02 00:21:49
# episode : 304 | final step : 99 | total reward : -1.0
# 2020/10/02 00:21:52
# episode : 305 | final step : 99 | total reward : -1.0
# 2020/10/02 00:21:55
# episode : 306 | final step : 98 | total reward : -1.0
# 2020/10/02 00:21:58
# episode : 307 | final step : 99 | total reward : 0.0
# 2020/10/02 00:22:02
# episode : 308 | final step : 98 | total reward : -1.0
# 2020/10/02 00:22:05
# episode : 309 | final step : 97 | total reward : 0.0
# 2020/10/02 00:22:08
# episode : 310 | final step : 98 | total reward : -1.0
# 2020/10/02 00:22:11
# episode : 311 | final step : 98 | total reward : -1.0
# 2020/10/02 00:22:14
# episode : 312 | final step : 98 | total reward : -1.0
# 2020/10/02 00:22:17
# episode : 313 | final step : 99 | total reward : 0.0
# 2020/10/02 00:22:20
# episode : 314 | final step : 97 | total reward : 0.0
# 2020/10/02 00:22:23
# episode : 315 | final step : 98 | total reward : -1.0
# 2020/10/02 00:22:26
# episode : 316 | final step : 99 | total reward : -1.0
# 2020/10/02 00:22:30
# episode : 317 | final step : 102 | total reward : 0.0
# 2020/10/02 00:22:33
# episode : 318 | final step : 98 | total reward : -1.0
# 2020/10/02 00:22:36
# episode : 319 | final step : 94 | total reward : 0.0
# 2020/10/02 00:22:39
# episode : 320 | final step : 99 | total reward : 0.0
# 2020/10/02 00:22:42
# episode : 321 | final step : 100 | total reward : 0.0
# 2020/10/02 00:22:45
# episode : 322 | final step : 99 | total reward : -1.0
# 2020/10/02 00:22:48
# episode : 323 | final step : 99 | total reward : -1.0
# 2020/10/02 00:22:52
# episode : 324 | final step : 98 | total reward : -1.0
# 2020/10/02 00:22:55
# episode : 325 | final step : 98 | total reward : -1.0
# 2020/10/02 00:22:58
# episode : 326 | final step : 100 | total reward : -1.0
# 2020/10/02 00:23:01
# episode : 327 | final step : 99 | total reward : -1.0
# 2020/10/02 00:23:04
# episode : 328 | final step : 98 | total reward : -1.0
# 2020/10/02 00:23:07
# episode : 329 | final step : 100 | total reward : 0.0
# 2020/10/02 00:23:10
# episode : 330 | final step : 98 | total reward : -1.0
# 2020/10/02 00:23:14
# episode : 331 | final step : 100 | total reward : 0.0
# 2020/10/02 00:23:17
# episode : 332 | final step : 94 | total reward : 0.0
# 2020/10/02 00:23:20
# episode : 333 | final step : 100 | total reward : 0.0
# 2020/10/02 00:23:23
# episode : 334 | final step : 98 | total reward : 0.0
# 2020/10/02 00:23:26
# episode : 335 | final step : 99 | total reward : 0.0
# 2020/10/02 00:23:29
# episode : 336 | final step : 98 | total reward : -1.0
# 2020/10/02 00:23:32
# episode : 337 | final step : 101 | total reward : 0.0
# 2020/10/02 00:23:36
# episode : 338 | final step : 100 | total reward : -1.0
# 2020/10/02 00:23:39
# episode : 339 | final step : 99 | total reward : -1.0
# 2020/10/02 00:23:42
# episode : 340 | final step : 99 | total reward : -1.0
# 2020/10/02 00:23:45
# episode : 341 | final step : 99 | total reward : 0.0
# 2020/10/02 00:23:48
# episode : 342 | final step : 98 | total reward : -1.0
# 2020/10/02 00:23:52
# episode : 343 | final step : 98 | total reward : -1.0
# 2020/10/02 00:23:55
# episode : 344 | final step : 94 | total reward : 0.0
# 2020/10/02 00:23:58
# episode : 345 | final step : 99 | total reward : 0.0
# 2020/10/02 00:24:01
# episode : 346 | final step : 100 | total reward : 0.0
# 2020/10/02 00:24:04
# episode : 347 | final step : 99 | total reward : -1.0
# 2020/10/02 00:24:07
# episode : 348 | final step : 98 | total reward : 0.0
# 2020/10/02 00:24:10
# episode : 349 | final step : 97 | total reward : 0.0
# 2020/10/02 00:24:13
# episode : 350 | final step : 100 | total reward : 0.0
# 2020/10/02 00:24:17
# episode : 351 | final step : 98 | total reward : -1.0
# 2020/10/02 00:24:20
# episode : 352 | final step : 98 | total reward : 0.0
# 2020/10/02 00:24:23
# episode : 353 | final step : 101 | total reward : 0.0
# 2020/10/02 00:24:26
# episode : 354 | final step : 98 | total reward : -1.0
# 2020/10/02 00:24:29
# episode : 355 | final step : 101 | total reward : 0.0
# 2020/10/02 00:24:32
# episode : 356 | final step : 99 | total reward : -1.0
# 2020/10/02 00:24:35
# episode : 357 | final step : 97 | total reward : 0.0
# 2020/10/02 00:24:38
# episode : 358 | final step : 98 | total reward : -1.0
# 2020/10/02 00:24:41
# episode : 359 | final step : 98 | total reward : -1.0
# 2020/10/02 00:24:45
# episode : 360 | final step : 98 | total reward : -1.0
# 2020/10/02 00:24:47
# episode : 361 | final step : 97 | total reward : -1.0
# 2020/10/02 00:24:51
# episode : 362 | final step : 98 | total reward : -1.0
# 2020/10/02 00:24:54
# episode : 363 | final step : 98 | total reward : 0.0
# 2020/10/02 00:24:57
# episode : 364 | final step : 100 | total reward : 0.0
# 2020/10/02 00:25:00
# episode : 365 | final step : 98 | total reward : -1.0
# 2020/10/02 00:25:03
# episode : 366 | final step : 98 | total reward : 0.0
# 2020/10/02 00:25:06
# episode : 367 | final step : 99 | total reward : -1.0
# 2020/10/02 00:25:10
# episode : 368 | final step : 100 | total reward : 0.0
# 2020/10/02 00:25:13
# episode : 369 | final step : 100 | total reward : -1.0
# 2020/10/02 00:25:16
# episode : 370 | final step : 97 | total reward : 0.0
# 2020/10/02 00:25:19
# episode : 371 | final step : 97 | total reward : 0.0
# 2020/10/02 00:25:22
# episode : 372 | final step : 97 | total reward : 0.0
# 2020/10/02 00:25:25
# episode : 373 | final step : 98 | total reward : 0.0
# 2020/10/02 00:25:28
# episode : 374 | final step : 98 | total reward : -1.0
# 2020/10/02 00:25:31
# episode : 375 | final step : 98 | total reward : -1.0
# 2020/10/02 00:25:35
# episode : 376 | final step : 99 | total reward : -1.0
# 2020/10/02 00:25:38
# episode : 377 | final step : 98 | total reward : -1.0
# 2020/10/02 00:25:41
# episode : 378 | final step : 98 | total reward : -1.0
# 2020/10/02 00:25:44
# episode : 379 | final step : 97 | total reward : 0.0
# 2020/10/02 00:25:47
# episode : 380 | final step : 98 | total reward : -1.0
# 2020/10/02 00:25:50
# episode : 381 | final step : 97 | total reward : 0.0
# 2020/10/02 00:25:53
# episode : 382 | final step : 97 | total reward : 0.0
# 2020/10/02 00:25:56
# episode : 383 | final step : 99 | total reward : -1.0
# 2020/10/02 00:26:00
# episode : 384 | final step : 100 | total reward : 0.0
# 2020/10/02 00:26:03
# episode : 385 | final step : 99 | total reward : -1.0
# 2020/10/02 00:26:06
# episode : 386 | final step : 94 | total reward : 0.0
# 2020/10/02 00:26:09
# episode : 387 | final step : 98 | total reward : -1.0
# 2020/10/02 00:26:12
# episode : 388 | final step : 98 | total reward : -1.0
# 2020/10/02 00:26:15
# episode : 389 | final step : 98 | total reward : -1.0
# 2020/10/02 00:26:18
# episode : 390 | final step : 100 | total reward : 0.0
# 2020/10/02 00:26:21
# episode : 391 | final step : 98 | total reward : -1.0
# 2020/10/02 00:26:24
# episode : 392 | final step : 98 | total reward : -1.0
# 2020/10/02 00:26:28
# episode : 393 | final step : 98 | total reward : -1.0
# 2020/10/02 00:26:31
# episode : 394 | final step : 98 | total reward : -1.0
# 2020/10/02 00:26:34
# episode : 395 | final step : 100 | total reward : 0.0
# 2020/10/02 00:26:37
# episode : 396 | final step : 98 | total reward : -1.0
# 2020/10/02 00:26:40
# episode : 397 | final step : 98 | total reward : 0.0
# 2020/10/02 00:26:43
# episode : 398 | final step : 99 | total reward : 0.0
# 2020/10/02 00:26:46
# episode : 399 | final step : 98 | total reward : -1.0
# 2020/10/02 00:26:49
# episode : 400 | final step : 99 | total reward : -1.0
# 2020/10/02 00:26:52
# episode : 401 | final step : 99 | total reward : -1.0
# 2020/10/02 00:26:56
# episode : 402 | final step : 98 | total reward : -1.0
# 2020/10/02 00:26:59
# episode : 403 | final step : 98 | total reward : -1.0
# 2020/10/02 00:27:02
# episode : 404 | final step : 96 | total reward : 0.0
# 2020/10/02 00:27:05
# episode : 405 | final step : 98 | total reward : -1.0
# 2020/10/02 00:27:08
# episode : 406 | final step : 98 | total reward : -1.0
# 2020/10/02 00:27:11
# episode : 407 | final step : 100 | total reward : -1.0
# 2020/10/02 00:27:14
# episode : 408 | final step : 96 | total reward : 0.0
# 2020/10/02 00:27:17
# episode : 409 | final step : 99 | total reward : 0.0
# 2020/10/02 00:27:21
# episode : 410 | final step : 99 | total reward : 0.0
# 2020/10/02 00:27:24
# episode : 411 | final step : 98 | total reward : -1.0
# 2020/10/02 00:27:27
# episode : 412 | final step : 99 | total reward : 0.0
# 2020/10/02 00:27:30
# episode : 413 | final step : 98 | total reward : -1.0
# 2020/10/02 00:27:33
# episode : 414 | final step : 99 | total reward : -1.0
# 2020/10/02 00:27:36
# episode : 415 | final step : 98 | total reward : -1.0
# 2020/10/02 00:27:39
# episode : 416 | final step : 99 | total reward : -1.0
# 2020/10/02 00:27:43
# episode : 417 | final step : 99 | total reward : -1.0
# 2020/10/02 00:27:46
# episode : 418 | final step : 99 | total reward : -1.0
# 2020/10/02 00:27:48
# episode : 419 | final step : 96 | total reward : 0.0
# 2020/10/02 00:27:52
# episode : 420 | final step : 99 | total reward : -1.0
# 2020/10/02 00:27:55
# episode : 421 | final step : 98 | total reward : -1.0
# 2020/10/02 00:27:58
# episode : 422 | final step : 99 | total reward : -1.0
# 2020/10/02 00:28:01
# episode : 423 | final step : 99 | total reward : -1.0
# 2020/10/02 00:28:04
# episode : 424 | final step : 98 | total reward : -1.0
# 2020/10/02 00:28:07
# episode : 425 | final step : 98 | total reward : -1.0
# 2020/10/02 00:28:10
# episode : 426 | final step : 98 | total reward : -1.0
# 2020/10/02 00:28:14
# episode : 427 | final step : 98 | total reward : 0.0
# 2020/10/02 00:28:17
# episode : 428 | final step : 99 | total reward : -1.0
# 2020/10/02 00:28:20
# episode : 429 | final step : 102 | total reward : 0.0
# 2020/10/02 00:28:23
# episode : 430 | final step : 98 | total reward : -1.0
# 2020/10/02 00:28:26
# episode : 431 | final step : 99 | total reward : -1.0
# 2020/10/02 00:28:29
# episode : 432 | final step : 99 | total reward : 0.0
# 2020/10/02 00:28:32
# episode : 433 | final step : 99 | total reward : -1.0
# 2020/10/02 00:28:36
# episode : 434 | final step : 99 | total reward : -1.0
# 2020/10/02 00:28:39
# episode : 435 | final step : 97 | total reward : 0.0
# 2020/10/02 00:28:42
# episode : 436 | final step : 97 | total reward : 0.0
# 2020/10/02 00:28:45
# episode : 437 | final step : 97 | total reward : 0.0
# 2020/10/02 00:28:48
# episode : 438 | final step : 98 | total reward : -1.0
# 2020/10/02 00:28:51
# episode : 439 | final step : 98 | total reward : -1.0
# 2020/10/02 00:28:54
# episode : 440 | final step : 98 | total reward : -1.0
# 2020/10/02 00:28:57
# episode : 441 | final step : 98 | total reward : 0.0
# 2020/10/02 00:29:00
# episode : 442 | final step : 98 | total reward : -1.0
# 2020/10/02 00:29:03
# episode : 443 | final step : 98 | total reward : -1.0
# 2020/10/02 00:29:07
# episode : 444 | final step : 99 | total reward : -1.0
# 2020/10/02 00:29:10
# episode : 445 | final step : 98 | total reward : -1.0
# 2020/10/02 00:29:13
# episode : 446 | final step : 97 | total reward : 0.0
# 2020/10/02 00:29:16
# episode : 447 | final step : 98 | total reward : 0.0
# 2020/10/02 00:29:19
# episode : 448 | final step : 98 | total reward : 0.0
# 2020/10/02 00:29:22
# episode : 449 | final step : 98 | total reward : -1.0
# 2020/10/02 00:29:25
# episode : 450 | final step : 98 | total reward : 0.0
# 2020/10/02 00:29:28
# episode : 451 | final step : 98 | total reward : -1.0
# 2020/10/02 00:29:32
# episode : 452 | final step : 99 | total reward : -1.0
# 2020/10/02 00:29:35
# episode : 453 | final step : 99 | total reward : -1.0
# 2020/10/02 00:29:38
# episode : 454 | final step : 98 | total reward : -1.0
# 2020/10/02 00:29:41
# episode : 455 | final step : 99 | total reward : -1.0
# 2020/10/02 00:29:44
# episode : 456 | final step : 98 | total reward : -1.0
# 2020/10/02 00:29:47
# episode : 457 | final step : 99 | total reward : 0.0
# 2020/10/02 00:29:50
# episode : 458 | final step : 98 | total reward : -1.0
# 2020/10/02 00:29:54
# episode : 459 | final step : 98 | total reward : -1.0
# 2020/10/02 00:29:57
# episode : 460 | final step : 98 | total reward : -1.0
# 2020/10/02 00:30:00
# episode : 461 | final step : 100 | total reward : 0.0
# 2020/10/02 00:30:03
# episode : 462 | final step : 99 | total reward : -1.0
# 2020/10/02 00:30:06
# episode : 463 | final step : 100 | total reward : 0.0
# 2020/10/02 00:30:10
# episode : 464 | final step : 98 | total reward : -1.0
# 2020/10/02 00:30:13
# episode : 465 | final step : 98 | total reward : -1.0
# 2020/10/02 00:30:16
# episode : 466 | final step : 100 | total reward : 0.0
# 2020/10/02 00:30:19
# episode : 467 | final step : 99 | total reward : 0.0
# 2020/10/02 00:30:22
# episode : 468 | final step : 98 | total reward : -1.0
# 2020/10/02 00:30:25
# episode : 469 | final step : 98 | total reward : 0.0
# 2020/10/02 00:30:29
# episode : 470 | final step : 99 | total reward : -1.0
# 2020/10/02 00:30:32
# episode : 471 | final step : 98 | total reward : 0.0
# 2020/10/02 00:30:35
# episode : 472 | final step : 98 | total reward : 0.0
# 2020/10/02 00:30:38
# episode : 473 | final step : 98 | total reward : -1.0
# 2020/10/02 00:30:41
# episode : 474 | final step : 97 | total reward : 0.0
# 2020/10/02 00:30:44
# episode : 475 | final step : 98 | total reward : -1.0
# 2020/10/02 00:30:47
# episode : 476 | final step : 98 | total reward : -1.0
# 2020/10/02 00:30:51
# episode : 477 | final step : 100 | total reward : -1.0
# 2020/10/02 00:30:54
# episode : 478 | final step : 99 | total reward : 0.0
# 2020/10/02 00:30:57
# episode : 479 | final step : 98 | total reward : 0.0
# 2020/10/02 00:31:00
# episode : 480 | final step : 98 | total reward : -1.0
# 2020/10/02 00:31:03
# episode : 481 | final step : 99 | total reward : -1.0
# 2020/10/02 00:31:06
# episode : 482 | final step : 99 | total reward : -1.0
# 2020/10/02 00:31:10
# episode : 483 | final step : 99 | total reward : -1.0
# 2020/10/02 00:31:13
# episode : 484 | final step : 98 | total reward : -1.0
# 2020/10/02 00:31:16
# episode : 485 | final step : 98 | total reward : -1.0
# 2020/10/02 00:31:19
# episode : 486 | final step : 100 | total reward : -1.0
# 2020/10/02 00:31:22
# episode : 487 | final step : 98 | total reward : -1.0
# 2020/10/02 00:31:25
# episode : 488 | final step : 98 | total reward : -1.0
# 2020/10/02 00:31:28
# episode : 489 | final step : 100 | total reward : 0.0
# 2020/10/02 00:31:32
# episode : 490 | final step : 99 | total reward : 0.0
# 2020/10/02 00:31:35
# episode : 491 | final step : 97 | total reward : 0.0
# 2020/10/02 00:31:38
# episode : 492 | final step : 98 | total reward : -1.0
# 2020/10/02 00:31:41
# episode : 493 | final step : 99 | total reward : -1.0
# 2020/10/02 00:31:44
# episode : 494 | final step : 98 | total reward : -1.0
# 2020/10/02 00:31:47
# episode : 495 | final step : 101 | total reward : 0.0
# 2020/10/02 00:31:50
# episode : 496 | final step : 96 | total reward : 0.0
# 2020/10/02 00:31:53
# episode : 497 | final step : 98 | total reward : -1.0
# 2020/10/02 00:31:57
# episode : 498 | final step : 100 | total reward : 0.0
# 2020/10/02 00:32:00
# episode : 499 | final step : 98 | total reward : 0.0
# 2020/10/02 00:32:03
# episode : 500 | final step : 99 | total reward : -1.0
# 2020/10/02 00:32:06
# episode : 501 | final step : 98 | total reward : -1.0
# 2020/10/02 00:32:09
# episode : 502 | final step : 95 | total reward : 0.0
# 2020/10/02 00:32:12
# episode : 503 | final step : 99 | total reward : 0.0
# 2020/10/02 00:32:15
# episode : 504 | final step : 99 | total reward : -1.0
# 2020/10/02 00:32:18
# episode : 505 | final step : 98 | total reward : -1.0
# 2020/10/02 00:32:22
# episode : 506 | final step : 97 | total reward : 0.0
# 2020/10/02 00:32:24
# episode : 507 | final step : 98 | total reward : -1.0
# 2020/10/02 00:32:28
# episode : 508 | final step : 98 | total reward : -1.0
# 2020/10/02 00:32:31
# episode : 509 | final step : 98 | total reward : -1.0
# 2020/10/02 00:32:34
# episode : 510 | final step : 99 | total reward : 0.0
# 2020/10/02 00:32:37
# episode : 511 | final step : 98 | total reward : -1.0
# 2020/10/02 00:32:40
# episode : 512 | final step : 99 | total reward : -1.0
# 2020/10/02 00:32:43
# episode : 513 | final step : 98 | total reward : -1.0
# 2020/10/02 00:32:46
# episode : 514 | final step : 100 | total reward : -1.0
# 2020/10/02 00:32:50
# episode : 515 | final step : 98 | total reward : -1.0
# 2020/10/02 00:32:53
# episode : 516 | final step : 98 | total reward : 0.0
# 2020/10/02 00:32:56
# episode : 517 | final step : 98 | total reward : -1.0
# 2020/10/02 00:32:59
# episode : 518 | final step : 100 | total reward : 0.0
# 2020/10/02 00:33:02
# episode : 519 | final step : 98 | total reward : -1.0
# 2020/10/02 00:33:05
# episode : 520 | final step : 98 | total reward : 0.0
# 2020/10/02 00:33:08
# episode : 521 | final step : 98 | total reward : -1.0
# 2020/10/02 00:33:11
# episode : 522 | final step : 98 | total reward : -1.0
# 2020/10/02 00:33:15
# episode : 523 | final step : 98 | total reward : -1.0
# 2020/10/02 00:33:18
# episode : 524 | final step : 99 | total reward : -1.0
# 2020/10/02 00:33:21
# episode : 525 | final step : 99 | total reward : -1.0
# 2020/10/02 00:33:24
# episode : 526 | final step : 98 | total reward : -1.0
# 2020/10/02 00:33:27
# episode : 527 | final step : 99 | total reward : 0.0
# 2020/10/02 00:33:30
# episode : 528 | final step : 95 | total reward : 0.0
# 2020/10/02 00:33:33
# episode : 529 | final step : 98 | total reward : -1.0
# 2020/10/02 00:33:36
# episode : 530 | final step : 98 | total reward : -1.0
# 2020/10/02 00:33:39
# episode : 531 | final step : 98 | total reward : -1.0
# 2020/10/02 00:33:43
# episode : 532 | final step : 98 | total reward : 0.0
# 2020/10/02 00:33:46
# episode : 533 | final step : 98 | total reward : -1.0
# 2020/10/02 00:33:49
# episode : 534 | final step : 97 | total reward : 0.0
# 2020/10/02 00:33:52
# episode : 535 | final step : 99 | total reward : -1.0
# 2020/10/02 00:33:56
# episode : 536 | final step : 100 | total reward : 0.0
# 2020/10/02 00:33:59
# episode : 537 | final step : 96 | total reward : 0.0
# 2020/10/02 00:34:01
# episode : 538 | final step : 97 | total reward : 0.0
# 2020/10/02 00:34:05
# episode : 539 | final step : 98 | total reward : -1.0
# 2020/10/02 00:34:08
# episode : 540 | final step : 97 | total reward : 0.0
# 2020/10/02 00:34:11
# episode : 541 | final step : 98 | total reward : -1.0
# 2020/10/02 00:34:14
# episode : 542 | final step : 98 | total reward : 0.0
# 2020/10/02 00:34:17
# episode : 543 | final step : 100 | total reward : 0.0
# 2020/10/02 00:34:20
# episode : 544 | final step : 98 | total reward : -1.0
# 2020/10/02 00:34:23
# episode : 545 | final step : 98 | total reward : -1.0
# 2020/10/02 00:34:27
# episode : 546 | final step : 98 | total reward : -1.0
# 2020/10/02 00:34:30
# episode : 547 | final step : 98 | total reward : 0.0
# 2020/10/02 00:34:33
# episode : 548 | final step : 99 | total reward : -1.0
# 2020/10/02 00:34:36
# episode : 549 | final step : 99 | total reward : -1.0
# 2020/10/02 00:34:39
# episode : 550 | final step : 99 | total reward : -1.0
# 2020/10/02 00:34:43
# episode : 551 | final step : 94 | total reward : 0.0
# 2020/10/02 00:34:46
# episode : 552 | final step : 98 | total reward : -1.0
# 2020/10/02 00:34:49
# episode : 553 | final step : 98 | total reward : -1.0
# 2020/10/02 00:34:52
# episode : 554 | final step : 99 | total reward : -1.0
# 2020/10/02 00:34:55
# episode : 555 | final step : 98 | total reward : -1.0
# 2020/10/02 00:34:58
# episode : 556 | final step : 98 | total reward : -1.0
# 2020/10/02 00:35:01
# episode : 557 | final step : 98 | total reward : -1.0
# 2020/10/02 00:35:04
# episode : 558 | final step : 98 | total reward : -1.0
# 2020/10/02 00:35:08
# episode : 559 | final step : 98 | total reward : -1.0
# 2020/10/02 00:35:11
# episode : 560 | final step : 96 | total reward : 0.0
# 2020/10/02 00:35:14
# episode : 561 | final step : 97 | total reward : 0.0
# 2020/10/02 00:35:17
# episode : 562 | final step : 98 | total reward : -1.0
# 2020/10/02 00:35:20
# episode : 563 | final step : 94 | total reward : 0.0
# 2020/10/02 00:35:23
# episode : 564 | final step : 99 | total reward : -1.0
# 2020/10/02 00:35:26
# episode : 565 | final step : 98 | total reward : -1.0
# 2020/10/02 00:35:29
# episode : 566 | final step : 98 | total reward : -1.0
# 2020/10/02 00:35:32
# episode : 567 | final step : 94 | total reward : 0.0
# 2020/10/02 00:35:35
# episode : 568 | final step : 98 | total reward : -1.0
# 2020/10/02 00:35:38
# episode : 569 | final step : 97 | total reward : 0.0
# 2020/10/02 00:35:41
# episode : 570 | final step : 99 | total reward : -1.0
# 2020/10/02 00:35:44
# episode : 571 | final step : 100 | total reward : 0.0
# 2020/10/02 00:35:48
# episode : 572 | final step : 98 | total reward : -1.0
# 2020/10/02 00:35:51
# episode : 573 | final step : 99 | total reward : -1.0
# 2020/10/02 00:35:54
# episode : 574 | final step : 100 | total reward : 0.0
# 2020/10/02 00:35:57
# episode : 575 | final step : 99 | total reward : -1.0
# 2020/10/02 00:36:00
# episode : 576 | final step : 99 | total reward : -1.0
# 2020/10/02 00:36:03
# episode : 577 | final step : 98 | total reward : -1.0
# 2020/10/02 00:36:06
# episode : 578 | final step : 99 | total reward : -1.0
# 2020/10/02 00:36:10
# episode : 579 | final step : 101 | total reward : 0.0
# 2020/10/02 00:36:13
# episode : 580 | final step : 98 | total reward : -1.0
# 2020/10/02 00:36:16
# episode : 581 | final step : 100 | total reward : -1.0
# 2020/10/02 00:36:19
# episode : 582 | final step : 99 | total reward : -1.0
# 2020/10/02 00:36:22
# episode : 583 | final step : 101 | total reward : 0.0
# 2020/10/02 00:36:25
# episode : 584 | final step : 98 | total reward : -1.0
# 2020/10/02 00:36:28
# episode : 585 | final step : 98 | total reward : -1.0
# 2020/10/02 00:36:31
# episode : 586 | final step : 98 | total reward : -1.0
# 2020/10/02 00:36:35
# episode : 587 | final step : 98 | total reward : -1.0
# 2020/10/02 00:36:38
# episode : 588 | final step : 98 | total reward : -1.0
# 2020/10/02 00:36:41
# episode : 589 | final step : 99 | total reward : -1.0
# 2020/10/02 00:36:44
# episode : 590 | final step : 98 | total reward : -1.0
# 2020/10/02 00:36:47
# episode : 591 | final step : 98 | total reward : -1.0
# 2020/10/02 00:36:50
# episode : 592 | final step : 100 | total reward : 0.0
# 2020/10/02 00:36:53
# episode : 593 | final step : 98 | total reward : 0.0
# 2020/10/02 00:36:57
# episode : 594 | final step : 98 | total reward : -1.0
# 2020/10/02 00:37:00
# episode : 595 | final step : 98 | total reward : -1.0
# 2020/10/02 00:37:03
# episode : 596 | final step : 97 | total reward : 0.0
# 2020/10/02 00:37:06
# episode : 597 | final step : 96 | total reward : 0.0
# 2020/10/02 00:37:09
# episode : 598 | final step : 98 | total reward : -1.0
# 2020/10/02 00:37:12
# episode : 599 | final step : 97 | total reward : 0.0
# 2020/10/02 00:37:15
# episode : 600 | final step : 98 | total reward : -1.0
# 2020/10/02 00:37:18
# episode : 601 | final step : 100 | total reward : -1.0
# 2020/10/02 00:37:21
# episode : 602 | final step : 99 | total reward : 0.0
# 2020/10/02 00:37:24
# episode : 603 | final step : 98 | total reward : -1.0
# 2020/10/02 00:37:27
# episode : 604 | final step : 98 | total reward : -1.0
# 2020/10/02 00:37:31
# episode : 605 | final step : 100 | total reward : -1.0
# 2020/10/02 00:37:34
# episode : 606 | final step : 100 | total reward : -1.0
# 2020/10/02 00:37:37
# episode : 607 | final step : 98 | total reward : 0.0
# 2020/10/02 00:37:40
# episode : 608 | final step : 97 | total reward : 0.0
# 2020/10/02 00:37:43
# episode : 609 | final step : 99 | total reward : 0.0
# 2020/10/02 00:37:46
# episode : 610 | final step : 100 | total reward : 0.0
# 2020/10/02 00:37:49
# episode : 611 | final step : 98 | total reward : -1.0
# 2020/10/02 00:37:53
# episode : 612 | final step : 100 | total reward : -1.0
# 2020/10/02 00:37:56
# episode : 613 | final step : 99 | total reward : -1.0
# 2020/10/02 00:37:59
# episode : 614 | final step : 98 | total reward : 0.0
# 2020/10/02 00:38:02
# episode : 615 | final step : 99 | total reward : 0.0
# 2020/10/02 00:38:05
# episode : 616 | final step : 98 | total reward : 0.0
# 2020/10/02 00:38:08
# episode : 617 | final step : 98 | total reward : -1.0
# 2020/10/02 00:38:12
# episode : 618 | final step : 98 | total reward : -1.0
# 2020/10/02 00:38:15
# episode : 619 | final step : 99 | total reward : -1.0
# 2020/10/02 00:38:18
# episode : 620 | final step : 101 | total reward : 0.0
# 2020/10/02 00:38:21
# episode : 621 | final step : 98 | total reward : -1.0
# 2020/10/02 00:38:24
# episode : 622 | final step : 98 | total reward : -1.0
# 2020/10/02 00:38:27
# episode : 623 | final step : 97 | total reward : 0.0
# 2020/10/02 00:38:31
# episode : 624 | final step : 100 | total reward : 0.0
# 2020/10/02 00:38:34
# episode : 625 | final step : 98 | total reward : -1.0
# 2020/10/02 00:38:37
# episode : 626 | final step : 98 | total reward : -1.0
# 2020/10/02 00:38:40
# episode : 627 | final step : 100 | total reward : 0.0
# 2020/10/02 00:38:43
# episode : 628 | final step : 100 | total reward : 0.0
# 2020/10/02 00:38:46
# episode : 629 | final step : 98 | total reward : 0.0
# 2020/10/02 00:38:50
# episode : 630 | final step : 98 | total reward : -1.0
# 2020/10/02 00:38:53
# episode : 631 | final step : 101 | total reward : 0.0
# 2020/10/02 00:38:56
# episode : 632 | final step : 98 | total reward : -1.0
# 2020/10/02 00:38:59
# episode : 633 | final step : 99 | total reward : 0.0
# 2020/10/02 00:39:02
# episode : 634 | final step : 98 | total reward : -1.0
# 2020/10/02 00:39:05
# episode : 635 | final step : 99 | total reward : -1.0
# 2020/10/02 00:39:08
# episode : 636 | final step : 98 | total reward : 0.0
# 2020/10/02 00:39:12
# episode : 637 | final step : 98 | total reward : -1.0
# 2020/10/02 00:39:15
# episode : 638 | final step : 99 | total reward : -1.0
# 2020/10/02 00:39:18
# episode : 639 | final step : 99 | total reward : -1.0
# 2020/10/02 00:39:21
# episode : 640 | final step : 100 | total reward : 0.0
# 2020/10/02 00:39:24
# episode : 641 | final step : 96 | total reward : 0.0
# 2020/10/02 00:39:27
# episode : 642 | final step : 94 | total reward : 0.0
# 2020/10/02 00:39:30
# episode : 643 | final step : 98 | total reward : -1.0
# 2020/10/02 00:39:34
# episode : 644 | final step : 98 | total reward : 0.0
# 2020/10/02 00:39:37
# episode : 645 | final step : 99 | total reward : -1.0
# 2020/10/02 00:39:40
# episode : 646 | final step : 98 | total reward : -1.0
# 2020/10/02 00:39:43
# episode : 647 | final step : 98 | total reward : -1.0
# 2020/10/02 00:39:46
# episode : 648 | final step : 100 | total reward : 0.0
# 2020/10/02 00:39:49
# episode : 649 | final step : 99 | total reward : 0.0
# 2020/10/02 00:39:52
# episode : 650 | final step : 99 | total reward : -1.0
# 2020/10/02 00:39:56
# episode : 651 | final step : 99 | total reward : -1.0
# 2020/10/02 00:39:59
# ...
# episode : 9786 | final step : 98 | total reward : -1.0
# 2020/10/02 09:38:51
# episode : 9787 | final step : 98 | total reward : -1.0
# 2020/10/02 09:38:54
# episode : 9788 | final step : 98 | total reward : -1.0
# 2020/10/02 09:38:57
# episode : 9789 | final step : 98 | total reward : 0.0
# 2020/10/02 09:39:01
# episode : 9790 | final step : 101 | total reward : 0.0
# 2020/10/02 09:39:04
# episode : 9791 | final step : 99 | total reward : 0.0
# 2020/10/02 09:39:07
# episode : 9792 | final step : 97 | total reward : 0.0
# 2020/10/02 09:39:10
# episode : 9793 | final step : 98 | total reward : -1.0
# 2020/10/02 09:39:13
# episode : 9794 | final step : 97 | total reward : 0.0
# 2020/10/02 09:39:16
# episode : 9795 | final step : 97 | total reward : 0.0
# 2020/10/02 09:39:20
# episode : 9796 | final step : 99 | total reward : -1.0
# 2020/10/02 09:39:23
# episode : 9797 | final step : 99 | total reward : -1.0
# 2020/10/02 09:39:26
# episode : 9798 | final step : 98 | total reward : -1.0
# 2020/10/02 09:39:29
# episode : 9799 | final step : 99 | total reward : -1.0
# 2020/10/02 09:39:33
# episode : 9800 | final step : 100 | total reward : -1.0
# 2020/10/02 09:39:36
# episode : 9801 | final step : 98 | total reward : 0.0
# 2020/10/02 09:39:39
# episode : 9802 | final step : 100 | total reward : 0.0
# 2020/10/02 09:39:42
# episode : 9803 | final step : 99 | total reward : 0.0
# 2020/10/02 09:39:45
# episode : 9804 | final step : 98 | total reward : -1.0
# 2020/10/02 09:39:49
# episode : 9805 | final step : 100 | total reward : -1.0
# 2020/10/02 09:39:52
# episode : 9806 | final step : 97 | total reward : 0.0
# 2020/10/02 09:39:55
# episode : 9807 | final step : 99 | total reward : 0.0
# 2020/10/02 09:39:58
# episode : 9808 | final step : 100 | total reward : 0.0
# 2020/10/02 09:40:02
# episode : 9809 | final step : 102 | total reward : 0.0
# 2020/10/02 09:40:05
# episode : 9810 | final step : 98 | total reward : -1.0
# 2020/10/02 09:40:08
# episode : 9811 | final step : 99 | total reward : -1.0
# 2020/10/02 09:40:11
# episode : 9812 | final step : 100 | total reward : -1.0
# 2020/10/02 09:40:14
# episode : 9813 | final step : 100 | total reward : 0.0
# 2020/10/02 09:40:17
# episode : 9814 | final step : 100 | total reward : -1.0
# 2020/10/02 09:40:21
# episode : 9815 | final step : 99 | total reward : -1.0
# 2020/10/02 09:40:24
# episode : 9816 | final step : 99 | total reward : 0.0
# 2020/10/02 09:40:27
# episode : 9817 | final step : 95 | total reward : 0.0
# 2020/10/02 09:40:30
# episode : 9818 | final step : 99 | total reward : -1.0
# 2020/10/02 09:40:34
# episode : 9819 | final step : 96 | total reward : 0.0
# 2020/10/02 09:40:37
# episode : 9820 | final step : 99 | total reward : -1.0
# 2020/10/02 09:40:40
# episode : 9821 | final step : 100 | total reward : -1.0
# 2020/10/02 09:40:43
# episode : 9822 | final step : 98 | total reward : 0.0
# 2020/10/02 09:40:46
# episode : 9823 | final step : 98 | total reward : -1.0
# 2020/10/02 09:40:49
# episode : 9824 | final step : 98 | total reward : -1.0
# 2020/10/02 09:40:52
# episode : 9825 | final step : 98 | total reward : -1.0
# 2020/10/02 09:40:55
# episode : 9826 | final step : 99 | total reward : -1.0
# 2020/10/02 09:40:59
# episode : 9827 | final step : 98 | total reward : -1.0
# 2020/10/02 09:41:02
# episode : 9828 | final step : 97 | total reward : 0.0
# 2020/10/02 09:41:05
# episode : 9829 | final step : 98 | total reward : -1.0
# 2020/10/02 09:41:08
# episode : 9830 | final step : 98 | total reward : 0.0
# 2020/10/02 09:41:11
# episode : 9831 | final step : 98 | total reward : -1.0
# 2020/10/02 09:41:15
# episode : 9832 | final step : 99 | total reward : 0.0
# 2020/10/02 09:41:18
# episode : 9833 | final step : 98 | total reward : 0.0
# 2020/10/02 09:41:21
# episode : 9834 | final step : 100 | total reward : -1.0
# 2020/10/02 09:41:24
# episode : 9835 | final step : 98 | total reward : -1.0
# 2020/10/02 09:41:27
# episode : 9836 | final step : 98 | total reward : -1.0
# 2020/10/02 09:41:30
# episode : 9837 | final step : 99 | total reward : 0.0
# 2020/10/02 09:41:33
# episode : 9838 | final step : 100 | total reward : 0.0
# 2020/10/02 09:41:36
# episode : 9839 | final step : 99 | total reward : -1.0
# 2020/10/02 09:41:39
# episode : 9840 | final step : 98 | total reward : -1.0
# 2020/10/02 09:41:42
# episode : 9841 | final step : 100 | total reward : 0.0
# 2020/10/02 09:41:45
# episode : 9842 | final step : 96 | total reward : 0.0
# 2020/10/02 09:41:49
# episode : 9843 | final step : 98 | total reward : 0.0
# 2020/10/02 09:41:52
# episode : 9844 | final step : 98 | total reward : -1.0
# 2020/10/02 09:41:55
# episode : 9845 | final step : 96 | total reward : 0.0
# 2020/10/02 09:41:58
# episode : 9846 | final step : 99 | total reward : 0.0
# 2020/10/02 09:42:01
# episode : 9847 | final step : 99 | total reward : -1.0
# 2020/10/02 09:42:04
# episode : 9848 | final step : 101 | total reward : 0.0
# 2020/10/02 09:42:08
# episode : 9849 | final step : 99 | total reward : -1.0
# 2020/10/02 09:42:11
# episode : 9850 | final step : 100 | total reward : -1.0
# 2020/10/02 09:42:14
# episode : 9851 | final step : 99 | total reward : 0.0
# 2020/10/02 09:42:17
# episode : 9852 | final step : 98 | total reward : -1.0
# 2020/10/02 09:42:20
# episode : 9853 | final step : 98 | total reward : -1.0
# 2020/10/02 09:42:24
# episode : 9854 | final step : 100 | total reward : -1.0
# 2020/10/02 09:42:27
# episode : 9855 | final step : 97 | total reward : 0.0
# 2020/10/02 09:42:30
# episode : 9856 | final step : 100 | total reward : 0.0
# 2020/10/02 09:42:33
# episode : 9857 | final step : 98 | total reward : -1.0
# 2020/10/02 09:42:36
# episode : 9858 | final step : 98 | total reward : -1.0
# 2020/10/02 09:42:39
# episode : 9859 | final step : 98 | total reward : -1.0
# 2020/10/02 09:42:42
# episode : 9860 | final step : 100 | total reward : 0.0
# 2020/10/02 09:42:46
# episode : 9861 | final step : 97 | total reward : 0.0
# 2020/10/02 09:42:49
# episode : 9862 | final step : 98 | total reward : -1.0
# 2020/10/02 09:42:52
# episode : 9863 | final step : 98 | total reward : -1.0
# 2020/10/02 09:42:55
# episode : 9864 | final step : 99 | total reward : -1.0
# 2020/10/02 09:42:58
# episode : 9865 | final step : 98 | total reward : -1.0
# 2020/10/02 09:43:01
# episode : 9866 | final step : 98 | total reward : -1.0
# 2020/10/02 09:43:05
# episode : 9867 | final step : 102 | total reward : 0.0
# 2020/10/02 09:43:08
# episode : 9868 | final step : 98 | total reward : -1.0
# 2020/10/02 09:43:11
# episode : 9869 | final step : 100 | total reward : 0.0
# 2020/10/02 09:43:14
# episode : 9870 | final step : 98 | total reward : -1.0
# 2020/10/02 09:43:17
# episode : 9871 | final step : 98 | total reward : -1.0
# 2020/10/02 09:43:21
# episode : 9872 | final step : 100 | total reward : 0.0
# 2020/10/02 09:43:24
# episode : 9873 | final step : 98 | total reward : -1.0
# 2020/10/02 09:43:27
# episode : 9874 | final step : 100 | total reward : -1.0
# 2020/10/02 09:43:30
# episode : 9875 | final step : 97 | total reward : 0.0
# 2020/10/02 09:43:33
# episode : 9876 | final step : 98 | total reward : -1.0
# 2020/10/02 09:43:37
# episode : 9877 | final step : 100 | total reward : -1.0
# 2020/10/02 09:43:40
# episode : 9878 | final step : 98 | total reward : -1.0
# 2020/10/02 09:43:43
# episode : 9879 | final step : 98 | total reward : 0.0
# 2020/10/02 09:43:46
# episode : 9880 | final step : 101 | total reward : 0.0
# 2020/10/02 09:43:50
# episode : 9881 | final step : 99 | total reward : -1.0
# 2020/10/02 09:43:52
# episode : 9882 | final step : 98 | total reward : -1.0
# 2020/10/02 09:43:56
# episode : 9883 | final step : 97 | total reward : 0.0
# 2020/10/02 09:43:59
# episode : 9884 | final step : 99 | total reward : -1.0
# 2020/10/02 09:44:02
# episode : 9885 | final step : 100 | total reward : 0.0
# 2020/10/02 09:44:05
# episode : 9886 | final step : 98 | total reward : 0.0
# 2020/10/02 09:44:08
# episode : 9887 | final step : 99 | total reward : 0.0
# 2020/10/02 09:44:12
# episode : 9888 | final step : 98 | total reward : -1.0
# 2020/10/02 09:44:15
# episode : 9889 | final step : 99 | total reward : -1.0
# 2020/10/02 09:44:18
# episode : 9890 | final step : 98 | total reward : -1.0
# 2020/10/02 09:44:21
# episode : 9891 | final step : 98 | total reward : -1.0
# 2020/10/02 09:44:24
# episode : 9892 | final step : 97 | total reward : 0.0
# 2020/10/02 09:44:27
# episode : 9893 | final step : 98 | total reward : -1.0
# 2020/10/02 09:44:30
# episode : 9894 | final step : 101 | total reward : 0.0
# 2020/10/02 09:44:33
# episode : 9895 | final step : 98 | total reward : -1.0
# 2020/10/02 09:44:36
# episode : 9896 | final step : 98 | total reward : -1.0
# 2020/10/02 09:44:39
# episode : 9897 | final step : 100 | total reward : 0.0
# 2020/10/02 09:44:42
# episode : 9898 | final step : 97 | total reward : 0.0
# 2020/10/02 09:44:45
# episode : 9899 | final step : 99 | total reward : -1.0
# 2020/10/02 09:44:48
# episode : 9900 | final step : 97 | total reward : 0.0
# 2020/10/02 09:44:51
# episode : 9901 | final step : 99 | total reward : -1.0
# 2020/10/02 09:44:54
# episode : 9902 | final step : 99 | total reward : -1.0
# 2020/10/02 09:44:57
# episode : 9903 | final step : 98 | total reward : -1.0
# 2020/10/02 09:45:00
# episode : 9904 | final step : 99 | total reward : -1.0
# 2020/10/02 09:45:04
# episode : 9905 | final step : 99 | total reward : 0.0
# 2020/10/02 09:45:07
# episode : 9906 | final step : 99 | total reward : -1.0
# 2020/10/02 09:45:10
# episode : 9907 | final step : 100 | total reward : 0.0
# 2020/10/02 09:45:13
# episode : 9908 | final step : 98 | total reward : -1.0
# 2020/10/02 09:45:16
# episode : 9909 | final step : 99 | total reward : -1.0
# 2020/10/02 09:45:19
# episode : 9910 | final step : 99 | total reward : -1.0
# 2020/10/02 09:45:22
# episode : 9911 | final step : 96 | total reward : 0.0
# 2020/10/02 09:45:25
# episode : 9912 | final step : 100 | total reward : 0.0
# 2020/10/02 09:45:28
# episode : 9913 | final step : 98 | total reward : 0.0
# 2020/10/02 09:45:31
# episode : 9914 | final step : 98 | total reward : -1.0
# 2020/10/02 09:45:34
# episode : 9915 | final step : 98 | total reward : -1.0
# 2020/10/02 09:45:38
# episode : 9916 | final step : 100 | total reward : 0.0
# 2020/10/02 09:45:40
# episode : 9917 | final step : 96 | total reward : 0.0
# 2020/10/02 09:45:44
# episode : 9918 | final step : 98 | total reward : 0.0
# 2020/10/02 09:45:47
# episode : 9919 | final step : 98 | total reward : -1.0
# 2020/10/02 09:45:50
# episode : 9920 | final step : 98 | total reward : -1.0
# 2020/10/02 09:45:53
# episode : 9921 | final step : 96 | total reward : 0.0
# 2020/10/02 09:45:56
# episode : 9922 | final step : 98 | total reward : -1.0
# 2020/10/02 09:45:59
# episode : 9923 | final step : 100 | total reward : 0.0
# 2020/10/02 09:46:02
# episode : 9924 | final step : 99 | total reward : -1.0
# 2020/10/02 09:46:05
# episode : 9925 | final step : 99 | total reward : -1.0
# 2020/10/02 09:46:08
# episode : 9926 | final step : 102 | total reward : 0.0
# 2020/10/02 09:46:12
# episode : 9927 | final step : 98 | total reward : -1.0
# 2020/10/02 09:46:15
# episode : 9928 | final step : 100 | total reward : -1.0
# 2020/10/02 09:46:18
# episode : 9929 | final step : 98 | total reward : -1.0
# 2020/10/02 09:46:21
# episode : 9930 | final step : 100 | total reward : 0.0
# 2020/10/02 09:46:24
# episode : 9931 | final step : 98 | total reward : 0.0
# 2020/10/02 09:46:27
# episode : 9932 | final step : 99 | total reward : -1.0
# 2020/10/02 09:46:30
# episode : 9933 | final step : 98 | total reward : -1.0
# 2020/10/02 09:46:33
# episode : 9934 | final step : 98 | total reward : 0.0
# 2020/10/02 09:46:36
# episode : 9935 | final step : 98 | total reward : -1.0
# 2020/10/02 09:46:39
# episode : 9936 | final step : 98 | total reward : 0.0
# 2020/10/02 09:46:42
# episode : 9937 | final step : 94 | total reward : 0.0
# 2020/10/02 09:46:45
# episode : 9938 | final step : 100 | total reward : 0.0
# 2020/10/02 09:46:48
# episode : 9939 | final step : 97 | total reward : 0.0
# 2020/10/02 09:46:51
# episode : 9940 | final step : 98 | total reward : -1.0
# 2020/10/02 09:46:54
# episode : 9941 | final step : 98 | total reward : -1.0
# 2020/10/02 09:46:57
# episode : 9942 | final step : 99 | total reward : -1.0
# 2020/10/02 09:47:00
# episode : 9943 | final step : 97 | total reward : -1.0
# 2020/10/02 09:47:03
# episode : 9944 | final step : 98 | total reward : -1.0
# 2020/10/02 09:47:06
# episode : 9945 | final step : 99 | total reward : -1.0
# 2020/10/02 09:47:09
# episode : 9946 | final step : 99 | total reward : 0.0
# 2020/10/02 09:47:12
# episode : 9947 | final step : 97 | total reward : 0.0
# 2020/10/02 09:47:15
# episode : 9948 | final step : 99 | total reward : -1.0
# 2020/10/02 09:47:18
# episode : 9949 | final step : 99 | total reward : -1.0
# 2020/10/02 09:47:21
# episode : 9950 | final step : 98 | total reward : -1.0
# 2020/10/02 09:47:24
# episode : 9951 | final step : 98 | total reward : -1.0
# 2020/10/02 09:47:27
# episode : 9952 | final step : 95 | total reward : 0.0
# 2020/10/02 09:47:30
# episode : 9953 | final step : 98 | total reward : -1.0
# 2020/10/02 09:47:33
# episode : 9954 | final step : 100 | total reward : 0.0
# 2020/10/02 09:47:36
# episode : 9955 | final step : 99 | total reward : -1.0
# 2020/10/02 09:47:39
# episode : 9956 | final step : 98 | total reward : -1.0
# 2020/10/02 09:47:42
# episode : 9957 | final step : 98 | total reward : -1.0
# 2020/10/02 09:47:45
# episode : 9958 | final step : 99 | total reward : -1.0
# 2020/10/02 09:47:48
# episode : 9959 | final step : 101 | total reward : 0.0
# 2020/10/02 09:47:51
# episode : 9960 | final step : 98 | total reward : 0.0
# 2020/10/02 09:47:54
# episode : 9961 | final step : 99 | total reward : -1.0
# 2020/10/02 09:47:57
# episode : 9962 | final step : 101 | total reward : 0.0
# 2020/10/02 09:48:00
# episode : 9963 | final step : 99 | total reward : -1.0
# 2020/10/02 09:48:03
# episode : 9964 | final step : 98 | total reward : -1.0
# 2020/10/02 09:48:06
# episode : 9965 | final step : 99 | total reward : -1.0
# 2020/10/02 09:48:09
# episode : 9966 | final step : 94 | total reward : 0.0
# 2020/10/02 09:48:12
# episode : 9967 | final step : 99 | total reward : -1.0
# 2020/10/02 09:48:15
# episode : 9968 | final step : 100 | total reward : 0.0
# 2020/10/02 09:48:18
# episode : 9969 | final step : 98 | total reward : -1.0
# 2020/10/02 09:48:21
# episode : 9970 | final step : 99 | total reward : 0.0
# 2020/10/02 09:48:25
# episode : 9971 | final step : 100 | total reward : 0.0
# 2020/10/02 09:48:27
# episode : 9972 | final step : 98 | total reward : -1.0
# 2020/10/02 09:48:31
# episode : 9973 | final step : 100 | total reward : -1.0
# 2020/10/02 09:48:34
# episode : 9974 | final step : 99 | total reward : 0.0
# 2020/10/02 09:48:37
# episode : 9975 | final step : 100 | total reward : 0.0
# 2020/10/02 09:48:40
# episode : 9976 | final step : 100 | total reward : 0.0
# 2020/10/02 09:48:43
# episode : 9977 | final step : 98 | total reward : -1.0
# 2020/10/02 09:48:46
# episode : 9978 | final step : 98 | total reward : 0.0
# 2020/10/02 09:48:49
# episode : 9979 | final step : 98 | total reward : -1.0
# 2020/10/02 09:48:51
# episode : 9980 | final step : 98 | total reward : -1.0
# 2020/10/02 09:48:55
# episode : 9981 | final step : 98 | total reward : -1.0
# 2020/10/02 09:48:58
# episode : 9982 | final step : 100 | total reward : -1.0
# 2020/10/02 09:49:01
# episode : 9983 | final step : 101 | total reward : 0.0
# 2020/10/02 09:49:04
# episode : 9984 | final step : 98 | total reward : 0.0
# 2020/10/02 09:49:07
# episode : 9985 | final step : 98 | total reward : -1.0
# 2020/10/02 09:49:10
# episode : 9986 | final step : 98 | total reward : -1.0
# 2020/10/02 09:49:13
# episode : 9987 | final step : 98 | total reward : -1.0
# 2020/10/02 09:49:16
# episode : 9988 | final step : 97 | total reward : 0.0
# 2020/10/02 09:49:19
# episode : 9989 | final step : 98 | total reward : 0.0
# 2020/10/02 09:49:21
# episode : 9990 | final step : 98 | total reward : -1.0
# 2020/10/02 09:49:24
# episode : 9991 | final step : 99 | total reward : -1.0
# 2020/10/02 09:49:27
# episode : 9992 | final step : 98 | total reward : -1.0
# 2020/10/02 09:49:31
# episode : 9993 | final step : 100 | total reward : 0.0
# 2020/10/02 09:49:33
# episode : 9994 | final step : 100 | total reward : -1.0
# 2020/10/02 09:49:36
# episode : 9995 | final step : 98 | total reward : -1.0
# 2020/10/02 09:49:40
# episode : 9996 | final step : 98 | total reward : -1.0
# 2020/10/02 09:49:43
# episode : 9997 | final step : 98 | total reward : -1.0
# 2020/10/02 09:49:46
# episode : 9998 | final step : 97 | total reward : 0.0
# 2020/10/02 09:49:49
# episode : 9999 | final step : 99 | total reward : -1.0
# Complete

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(reward_list)

# %%
def moving_average(data,n):
    len_data=len(data)-n
    res_data=np.zeros(len_data)

    for i in range(len_data):
        res_data[i]=sum(data[i:i+n])/n
    return res_data

# %%
average_number=200
filtered_data=moving_average(reward_list,average_number)
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(filtered_data)

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[0]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[10]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[100]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[1000]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[9999]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()
