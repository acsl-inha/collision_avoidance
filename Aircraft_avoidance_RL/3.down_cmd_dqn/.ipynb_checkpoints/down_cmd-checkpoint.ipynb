# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
import time
import itertools
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
import gym_Aircraft

# %%
env = gym.make("acav-v0")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# /home/jupyter-kunwoopark/.local/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """transition 저장"""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
class DQN(nn.Module):
    def __init__(self, num_inputs, num_actions):
        super(DQN, self).__init__()
        
        self.layers = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 40),
            nn.ReLU(),
            nn.Linear(40, 40),
            nn.ReLU(),
            nn.Linear(40, 40),
            nn.ReLU(),
            nn.Linear(40, 40),
            nn.ReLU(),
            nn.Linear(40, 40),
            nn.ReLU(),
            nn.Linear(40, 40),
            nn.ReLU(),
            nn.Linear(40, 40),
            nn.ReLU(),
            nn.Linear(40, env.action_space.n)
        )
        
    def forward(self, x):
        return self.layers(x)

# %%
BATCH_SIZE = 128
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10

# %%
policy_net = nn.DataParallel(DQN(env.observation_space.shape[0], env.action_space.n).to(device))
target_net = nn.DataParallel(DQN(env.observation_space.shape[0], env.action_space.n).to(device))
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
# Out:
# DataParallel(
#   (module): DQN(
#     (layers): Sequential(
#       (0): Linear(in_features=5, out_features=40, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=40, out_features=40, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=40, out_features=40, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=40, out_features=40, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=40, out_features=40, bias=True)
#       (9): ReLU()
#       (10): Linear(in_features=40, out_features=40, bias=True)
#       (11): ReLU()
#       (12): Linear(in_features=40, out_features=40, bias=True)
#       (13): ReLU()
#       (14): Linear(in_features=40, out_features=3, bias=True)
#     )
#   )
# )

# %%
n_actions = env.action_space.n

# %%
optimizer = optim.Adam(policy_net.parameters())
memory = ReplayMemory(10000)

# %%
steps_done = 0

# %%
def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max (1)은 각 행의 가장 큰 열 값을 반환합니다.
            # 최대 결과의 두번째 열은 최대 요소의 주소값이므로,
            # 기대 보상이 더 큰 행동을 선택할 수 있습니다.
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(n_actions)]], device=device, dtype=torch.long)

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)

    batch = Transition(*zip(*transitions))

    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    state_action_values = policy_net(state_batch).gather(1, action_batch)

    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    # 기대 Q 값 계산
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Huber 손실 계산
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    # 모델 최적화
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
num_episodes = 10000
total_res=[]
reward_list=[]
for i_episode in range(num_episodes):
    total_reward=0
    
    # 환경과 상태 초기화
    res_list=np.zeros(11)
    state = env.reset()
    state=torch.from_numpy(state.astype(np.float32)).unsqueeze(0).to(device)
    for t in count():
        # 행동 선택과 수행
        
        action = select_action(state)
        next_state, reward, done, res = env.step(action.item())
        reward = torch.tensor([reward], dtype=torch.float32).to(device)
        
        next_state=torch.from_numpy(next_state.astype(np.float32)).unsqueeze(0).to(device)

        # 새로운 상태 관찰
        if not done:
            next_state = next_state
        else:
            next_state = None

        # 메모리에 변이 저장
        memory.push(state, action, next_state, reward)

        # 다음 상태로 이동
        state = next_state

        # 최적화 한단계 수행(목표 네트워크에서)
        optimize_model()
        
        # Data save
        
        cmd_list,r_list,elev_list,azim_list,Pm_list,Pt_list,h_list=res
        Pm_list=Pm_list.tolist()
        Pt_list=Pt_list.tolist()
        merged_data=itertools.chain([cmd_list],[r_list],[elev_list],[azim_list],Pm_list,Pt_list,[h_list])
        merged_data=np.array(list(merged_data))
        res_list=np.vstack([res_list,merged_data])
        
        total_reward+=reward
        
        if done:
            res_list=np.delete(res_list,0,0)
            
            total_res.append(res_list)
            reward_list.append(total_reward)
            
            now = time.localtime()
            print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))
            print("episode : {} | final step : {} | total reward : {}".format(i_episode, t, total_reward.item()))
            break
            
        
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

print('Complete')
env.close()
# Out:
# 2020/10/01 22:20:10
# episode : 0 | final step : 99 | total reward : -1.0
# 2020/10/01 22:20:19
# episode : 1 | final step : 95 | total reward : 0.0
# 2020/10/01 22:20:22
# episode : 2 | final step : 98 | total reward : -1.0
# 2020/10/01 22:20:25
# episode : 3 | final step : 100 | total reward : 0.0
# 2020/10/01 22:20:28
# episode : 4 | final step : 99 | total reward : 0.0
# 2020/10/01 22:20:31
# episode : 5 | final step : 98 | total reward : 0.0
# 2020/10/01 22:20:34
# episode : 6 | final step : 98 | total reward : -1.0
# 2020/10/01 22:20:37
# episode : 7 | final step : 98 | total reward : -1.0
# 2020/10/01 22:20:40
# episode : 8 | final step : 100 | total reward : -1.0
# 2020/10/01 22:20:43
# episode : 9 | final step : 101 | total reward : 0.0
# 2020/10/01 22:20:46
# episode : 10 | final step : 97 | total reward : 0.0
# 2020/10/01 22:20:49
# episode : 11 | final step : 99 | total reward : -1.0
# 2020/10/01 22:20:52
# episode : 12 | final step : 99 | total reward : -1.0
# 2020/10/01 22:20:54
# episode : 13 | final step : 97 | total reward : 0.0
# 2020/10/01 22:20:57
# episode : 14 | final step : 98 | total reward : -1.0
# 2020/10/01 22:21:00
# episode : 15 | final step : 98 | total reward : -1.0
# 2020/10/01 22:21:03
# episode : 16 | final step : 97 | total reward : 0.0
# 2020/10/01 22:21:06
# episode : 17 | final step : 100 | total reward : 0.0
# 2020/10/01 22:21:09
# episode : 18 | final step : 98 | total reward : -1.0
# 2020/10/01 22:21:12
# episode : 19 | final step : 98 | total reward : -1.0
# 2020/10/01 22:21:15
# episode : 20 | final step : 98 | total reward : -1.0
# 2020/10/01 22:21:17
# episode : 21 | final step : 98 | total reward : -1.0
# 2020/10/01 22:21:20
# episode : 22 | final step : 98 | total reward : -1.0
# 2020/10/01 22:21:23
# episode : 23 | final step : 99 | total reward : 0.0
# 2020/10/01 22:21:26
# episode : 24 | final step : 98 | total reward : -1.0
# 2020/10/01 22:21:28
# episode : 25 | final step : 98 | total reward : -1.0
# 2020/10/01 22:21:31
# episode : 26 | final step : 98 | total reward : -1.0
# 2020/10/01 22:21:34
# episode : 27 | final step : 98 | total reward : 0.0
# 2020/10/01 22:21:37
# episode : 28 | final step : 98 | total reward : -1.0
# 2020/10/01 22:21:40
# episode : 29 | final step : 98 | total reward : -1.0
# 2020/10/01 22:21:43
# episode : 30 | final step : 99 | total reward : -1.0
# 2020/10/01 22:21:46
# episode : 31 | final step : 100 | total reward : -1.0
# 2020/10/01 22:21:49
# episode : 32 | final step : 97 | total reward : -1.0
# 2020/10/01 22:21:51
# episode : 33 | final step : 97 | total reward : 0.0
# 2020/10/01 22:21:54
# episode : 34 | final step : 98 | total reward : 0.0
# 2020/10/01 22:21:57
# episode : 35 | final step : 98 | total reward : -1.0
# 2020/10/01 22:22:00
# episode : 36 | final step : 98 | total reward : -1.0
# 2020/10/01 22:22:03
# episode : 37 | final step : 99 | total reward : -1.0
# 2020/10/01 22:22:05
# episode : 38 | final step : 95 | total reward : 0.0
# 2020/10/01 22:22:08
# episode : 39 | final step : 98 | total reward : 0.0
# 2020/10/01 22:22:11
# episode : 40 | final step : 96 | total reward : 0.0
# 2020/10/01 22:22:14
# episode : 41 | final step : 99 | total reward : 0.0
# 2020/10/01 22:22:17
# episode : 42 | final step : 96 | total reward : 0.0
# 2020/10/01 22:22:20
# episode : 43 | final step : 96 | total reward : 0.0
# 2020/10/01 22:22:23
# episode : 44 | final step : 98 | total reward : 0.0
# 2020/10/01 22:22:25
# episode : 45 | final step : 98 | total reward : -1.0
# 2020/10/01 22:22:28
# episode : 46 | final step : 98 | total reward : -1.0
# 2020/10/01 22:22:31
# episode : 47 | final step : 98 | total reward : -1.0
# 2020/10/01 22:22:34
# episode : 48 | final step : 98 | total reward : -1.0
# 2020/10/01 22:22:37
# episode : 49 | final step : 100 | total reward : 0.0
# 2020/10/01 22:22:40
# episode : 50 | final step : 98 | total reward : -1.0
# 2020/10/01 22:22:43
# episode : 51 | final step : 100 | total reward : -1.0
# 2020/10/01 22:22:46
# episode : 52 | final step : 98 | total reward : -1.0
# 2020/10/01 22:22:49
# episode : 53 | final step : 100 | total reward : 0.0
# 2020/10/01 22:22:52
# episode : 54 | final step : 98 | total reward : -1.0
# 2020/10/01 22:22:55
# episode : 55 | final step : 98 | total reward : -1.0
# 2020/10/01 22:22:58
# episode : 56 | final step : 99 | total reward : -1.0
# 2020/10/01 22:23:00
# episode : 57 | final step : 100 | total reward : -1.0
# 2020/10/01 22:23:03
# episode : 58 | final step : 100 | total reward : 0.0
# 2020/10/01 22:23:06
# episode : 59 | final step : 98 | total reward : -1.0
# 2020/10/01 22:23:09
# episode : 60 | final step : 99 | total reward : -1.0
# 2020/10/01 22:23:12
# episode : 61 | final step : 98 | total reward : -1.0
# 2020/10/01 22:23:15
# episode : 62 | final step : 93 | total reward : 0.0
# 2020/10/01 22:23:18
# episode : 63 | final step : 98 | total reward : 0.0
# 2020/10/01 22:23:20
# episode : 64 | final step : 99 | total reward : 0.0
# 2020/10/01 22:23:23
# episode : 65 | final step : 97 | total reward : 0.0
# 2020/10/01 22:23:26
# episode : 66 | final step : 99 | total reward : -1.0
# 2020/10/01 22:23:29
# episode : 67 | final step : 99 | total reward : -1.0
# 2020/10/01 22:23:32
# episode : 68 | final step : 99 | total reward : -1.0
# 2020/10/01 22:23:35
# episode : 69 | final step : 98 | total reward : -1.0
# 2020/10/01 22:23:38
# episode : 70 | final step : 98 | total reward : -1.0
# 2020/10/01 22:23:41
# episode : 71 | final step : 99 | total reward : 0.0
# 2020/10/01 22:23:44
# episode : 72 | final step : 98 | total reward : -1.0
# 2020/10/01 22:23:47
# episode : 73 | final step : 98 | total reward : -1.0
# 2020/10/01 22:23:50
# episode : 74 | final step : 98 | total reward : -1.0
# 2020/10/01 22:23:53
# episode : 75 | final step : 99 | total reward : -1.0
# 2020/10/01 22:23:56
# episode : 76 | final step : 98 | total reward : -1.0
# 2020/10/01 22:23:59
# episode : 77 | final step : 98 | total reward : -1.0
# 2020/10/01 22:24:02
# episode : 78 | final step : 97 | total reward : 0.0
# 2020/10/01 22:24:04
# episode : 79 | final step : 98 | total reward : 0.0
# 2020/10/01 22:24:07
# episode : 80 | final step : 99 | total reward : -1.0
# 2020/10/01 22:24:10
# episode : 81 | final step : 98 | total reward : 0.0
# 2020/10/01 22:24:13
# episode : 82 | final step : 101 | total reward : 0.0
# 2020/10/01 22:24:16
# episode : 83 | final step : 98 | total reward : 0.0
# 2020/10/01 22:24:19
# episode : 84 | final step : 97 | total reward : 0.0
# 2020/10/01 22:24:22
# episode : 85 | final step : 100 | total reward : 0.0
# 2020/10/01 22:24:25
# episode : 86 | final step : 100 | total reward : 0.0
# 2020/10/01 22:24:28
# episode : 87 | final step : 98 | total reward : -1.0
# 2020/10/01 22:24:31
# episode : 88 | final step : 98 | total reward : -1.0
# 2020/10/01 22:24:34
# episode : 89 | final step : 98 | total reward : -1.0
# 2020/10/01 22:24:37
# episode : 90 | final step : 98 | total reward : 0.0
# 2020/10/01 22:24:40
# episode : 91 | final step : 97 | total reward : 0.0
# 2020/10/01 22:24:43
# episode : 92 | final step : 98 | total reward : -1.0
# 2020/10/01 22:24:46
# episode : 93 | final step : 99 | total reward : -1.0
# 2020/10/01 22:24:49
# episode : 94 | final step : 98 | total reward : -1.0
# 2020/10/01 22:24:51
# episode : 95 | final step : 98 | total reward : 0.0
# 2020/10/01 22:24:54
# episode : 96 | final step : 99 | total reward : -1.0
# 2020/10/01 22:24:57
# episode : 97 | final step : 98 | total reward : -1.0
# 2020/10/01 22:25:00
# episode : 98 | final step : 97 | total reward : 0.0
# 2020/10/01 22:25:03
# episode : 99 | final step : 98 | total reward : -1.0
# 2020/10/01 22:25:06
# episode : 100 | final step : 97 | total reward : 0.0
# 2020/10/01 22:25:09
# episode : 101 | final step : 98 | total reward : -1.0
# 2020/10/01 22:25:12
# episode : 102 | final step : 99 | total reward : 0.0
# 2020/10/01 22:25:15
# episode : 103 | final step : 101 | total reward : 0.0
# 2020/10/01 22:25:18
# episode : 104 | final step : 98 | total reward : -1.0
# 2020/10/01 22:25:21
# episode : 105 | final step : 99 | total reward : 0.0
# 2020/10/01 22:25:24
# episode : 106 | final step : 99 | total reward : -1.0
# 2020/10/01 22:25:27
# episode : 107 | final step : 100 | total reward : 0.0
# 2020/10/01 22:25:30
# episode : 108 | final step : 97 | total reward : 0.0
# 2020/10/01 22:25:32
# episode : 109 | final step : 99 | total reward : -1.0
# 2020/10/01 22:25:35
# episode : 110 | final step : 99 | total reward : 0.0
# 2020/10/01 22:25:38
# episode : 111 | final step : 99 | total reward : 0.0
# 2020/10/01 22:25:41
# episode : 112 | final step : 99 | total reward : 0.0
# 2020/10/01 22:25:44
# episode : 113 | final step : 98 | total reward : -1.0
# 2020/10/01 22:25:47
# episode : 114 | final step : 98 | total reward : -1.0
# 2020/10/01 22:25:50
# episode : 115 | final step : 101 | total reward : 0.0
# 2020/10/01 22:25:53
# episode : 116 | final step : 100 | total reward : 0.0
# 2020/10/01 22:25:56
# episode : 117 | final step : 100 | total reward : 0.0
# 2020/10/01 22:25:59
# episode : 118 | final step : 98 | total reward : -1.0
# 2020/10/01 22:26:02
# episode : 119 | final step : 101 | total reward : 0.0
# 2020/10/01 22:26:05
# episode : 120 | final step : 99 | total reward : -1.0
# 2020/10/01 22:26:07
# episode : 121 | final step : 97 | total reward : 0.0
# 2020/10/01 22:26:10
# episode : 122 | final step : 97 | total reward : 0.0
# 2020/10/01 22:26:13
# episode : 123 | final step : 98 | total reward : 0.0
# 2020/10/01 22:26:16
# episode : 124 | final step : 98 | total reward : -1.0
# 2020/10/01 22:26:19
# episode : 125 | final step : 98 | total reward : 0.0
# 2020/10/01 22:26:22
# episode : 126 | final step : 100 | total reward : 0.0
# 2020/10/01 22:26:25
# episode : 127 | final step : 99 | total reward : -1.0
# 2020/10/01 22:26:28
# episode : 128 | final step : 98 | total reward : -1.0
# 2020/10/01 22:26:31
# episode : 129 | final step : 98 | total reward : -1.0
# 2020/10/01 22:26:34
# episode : 130 | final step : 102 | total reward : 0.0
# 2020/10/01 22:26:37
# episode : 131 | final step : 98 | total reward : -1.0
# 2020/10/01 22:26:40
# episode : 132 | final step : 99 | total reward : -1.0
# 2020/10/01 22:26:43
# episode : 133 | final step : 99 | total reward : -1.0
# 2020/10/01 22:26:46
# episode : 134 | final step : 101 | total reward : 0.0
# 2020/10/01 22:26:49
# episode : 135 | final step : 99 | total reward : -1.0
# 2020/10/01 22:26:51
# episode : 136 | final step : 98 | total reward : -1.0
# 2020/10/01 22:26:54
# episode : 137 | final step : 98 | total reward : -1.0
# 2020/10/01 22:26:57
# episode : 138 | final step : 98 | total reward : -1.0
# 2020/10/01 22:27:00
# episode : 139 | final step : 98 | total reward : -1.0
# 2020/10/01 22:27:03
# episode : 140 | final step : 97 | total reward : 0.0
# 2020/10/01 22:27:06
# episode : 141 | final step : 98 | total reward : -1.0
# 2020/10/01 22:27:09
# episode : 142 | final step : 98 | total reward : -1.0
# 2020/10/01 22:27:12
# episode : 143 | final step : 98 | total reward : -1.0
# 2020/10/01 22:27:15
# episode : 144 | final step : 99 | total reward : -1.0
# 2020/10/01 22:27:18
# episode : 145 | final step : 99 | total reward : 0.0
# 2020/10/01 22:27:21
# episode : 146 | final step : 98 | total reward : -1.0
# 2020/10/01 22:27:24
# episode : 147 | final step : 98 | total reward : -1.0
# 2020/10/01 22:27:27
# episode : 148 | final step : 98 | total reward : -1.0
# 2020/10/01 22:27:30
# episode : 149 | final step : 95 | total reward : 0.0
# 2020/10/01 22:27:33
# episode : 150 | final step : 97 | total reward : 0.0
# 2020/10/01 22:27:35
# episode : 151 | final step : 98 | total reward : 0.0
# 2020/10/01 22:27:39
# episode : 152 | final step : 100 | total reward : 0.0
# 2020/10/01 22:27:42
# episode : 153 | final step : 102 | total reward : 0.0
# 2020/10/01 22:27:44
# episode : 154 | final step : 98 | total reward : -1.0
# 2020/10/01 22:27:47
# episode : 155 | final step : 97 | total reward : -1.0
# 2020/10/01 22:27:50
# episode : 156 | final step : 98 | total reward : -1.0
# 2020/10/01 22:27:53
# episode : 157 | final step : 100 | total reward : -1.0
# 2020/10/01 22:27:56
# episode : 158 | final step : 99 | total reward : -1.0
# 2020/10/01 22:27:59
# episode : 159 | final step : 99 | total reward : -1.0
# 2020/10/01 22:28:02
# episode : 160 | final step : 98 | total reward : -1.0
# 2020/10/01 22:28:05
# episode : 161 | final step : 100 | total reward : 0.0
# 2020/10/01 22:28:08
# episode : 162 | final step : 99 | total reward : -1.0
# 2020/10/01 22:28:11
# episode : 163 | final step : 100 | total reward : 0.0
# 2020/10/01 22:28:14
# episode : 164 | final step : 98 | total reward : -1.0
# 2020/10/01 22:28:17
# episode : 165 | final step : 98 | total reward : -1.0
# 2020/10/01 22:28:19
# episode : 166 | final step : 98 | total reward : -1.0
# 2020/10/01 22:28:22
# episode : 167 | final step : 98 | total reward : -1.0
# 2020/10/01 22:28:25
# episode : 168 | final step : 98 | total reward : -1.0
# 2020/10/01 22:28:28
# episode : 169 | final step : 98 | total reward : -1.0
# 2020/10/01 22:28:31
# episode : 170 | final step : 99 | total reward : -1.0
# 2020/10/01 22:28:34
# episode : 171 | final step : 99 | total reward : -1.0
# 2020/10/01 22:28:37
# episode : 172 | final step : 98 | total reward : -1.0
# 2020/10/01 22:28:40
# episode : 173 | final step : 98 | total reward : -1.0
# 2020/10/01 22:28:43
# episode : 174 | final step : 99 | total reward : -1.0
# 2020/10/01 22:28:46
# episode : 175 | final step : 98 | total reward : -1.0
# 2020/10/01 22:28:49
# episode : 176 | final step : 99 | total reward : -1.0
# 2020/10/01 22:28:52
# episode : 177 | final step : 99 | total reward : -1.0
# 2020/10/01 22:28:55
# episode : 178 | final step : 98 | total reward : -1.0
# 2020/10/01 22:28:58
# episode : 179 | final step : 99 | total reward : -1.0
# 2020/10/01 22:29:01
# episode : 180 | final step : 99 | total reward : -1.0
# 2020/10/01 22:29:04
# episode : 181 | final step : 98 | total reward : 0.0
# 2020/10/01 22:29:07
# episode : 182 | final step : 99 | total reward : 0.0
# 2020/10/01 22:29:10
# episode : 183 | final step : 98 | total reward : -1.0
# 2020/10/01 22:29:12
# episode : 184 | final step : 98 | total reward : -1.0
# 2020/10/01 22:29:15
# episode : 185 | final step : 98 | total reward : 0.0
# 2020/10/01 22:29:18
# episode : 186 | final step : 98 | total reward : 0.0
# 2020/10/01 22:29:21
# episode : 187 | final step : 99 | total reward : -1.0
# 2020/10/01 22:29:24
# episode : 188 | final step : 99 | total reward : -1.0
# 2020/10/01 22:29:27
# episode : 189 | final step : 95 | total reward : 0.0
# 2020/10/01 22:29:30
# episode : 190 | final step : 98 | total reward : -1.0
# 2020/10/01 22:29:32
# episode : 191 | final step : 98 | total reward : 0.0
# 2020/10/01 22:29:35
# episode : 192 | final step : 98 | total reward : 0.0
# 2020/10/01 22:29:38
# episode : 193 | final step : 98 | total reward : -1.0
# 2020/10/01 22:29:41
# episode : 194 | final step : 98 | total reward : -1.0
# 2020/10/01 22:29:44
# episode : 195 | final step : 99 | total reward : -1.0
# 2020/10/01 22:29:47
# episode : 196 | final step : 98 | total reward : -1.0
# 2020/10/01 22:29:50
# episode : 197 | final step : 99 | total reward : 0.0
# 2020/10/01 22:29:53
# episode : 198 | final step : 98 | total reward : 0.0
# 2020/10/01 22:29:56
# episode : 199 | final step : 99 | total reward : -1.0
# 2020/10/01 22:29:59
# episode : 200 | final step : 98 | total reward : -1.0
# 2020/10/01 22:30:02
# episode : 201 | final step : 99 | total reward : -1.0
# 2020/10/01 22:30:05
# episode : 202 | final step : 98 | total reward : 0.0
# 2020/10/01 22:30:07
# episode : 203 | final step : 97 | total reward : 0.0
# 2020/10/01 22:30:10
# episode : 204 | final step : 98 | total reward : -1.0
# 2020/10/01 22:30:14
# episode : 205 | final step : 100 | total reward : 0.0
# 2020/10/01 22:30:17
# episode : 206 | final step : 99 | total reward : -1.0
# 2020/10/01 22:30:19
# episode : 207 | final step : 99 | total reward : -1.0
# 2020/10/01 22:30:22
# episode : 208 | final step : 98 | total reward : 0.0
# 2020/10/01 22:30:25
# episode : 209 | final step : 99 | total reward : 0.0
# 2020/10/01 22:30:28
# episode : 210 | final step : 97 | total reward : 0.0
# 2020/10/01 22:30:31
# episode : 211 | final step : 98 | total reward : -1.0
# 2020/10/01 22:30:34
# episode : 212 | final step : 99 | total reward : 0.0
# 2020/10/01 22:30:37
# episode : 213 | final step : 98 | total reward : -1.0
# 2020/10/01 22:30:39
# episode : 214 | final step : 99 | total reward : 0.0
# 2020/10/01 22:30:42
# episode : 215 | final step : 97 | total reward : 0.0
# 2020/10/01 22:30:45
# episode : 216 | final step : 97 | total reward : -1.0
# 2020/10/01 22:30:48
# episode : 217 | final step : 98 | total reward : -1.0
# 2020/10/01 22:30:51
# episode : 218 | final step : 98 | total reward : -1.0
# 2020/10/01 22:30:54
# episode : 219 | final step : 98 | total reward : -1.0
# 2020/10/01 22:30:57
# episode : 220 | final step : 99 | total reward : -1.0
# 2020/10/01 22:31:00
# episode : 221 | final step : 98 | total reward : -1.0
# 2020/10/01 22:31:03
# episode : 222 | final step : 98 | total reward : -1.0
# 2020/10/01 22:31:05
# episode : 223 | final step : 99 | total reward : -1.0
# 2020/10/01 22:31:08
# episode : 224 | final step : 100 | total reward : 0.0
# 2020/10/01 22:31:11
# episode : 225 | final step : 96 | total reward : 0.0
# 2020/10/01 22:31:14
# episode : 226 | final step : 100 | total reward : 0.0
# 2020/10/01 22:31:17
# episode : 227 | final step : 99 | total reward : 0.0
# 2020/10/01 22:31:20
# episode : 228 | final step : 98 | total reward : -1.0
# 2020/10/01 22:31:23
# episode : 229 | final step : 98 | total reward : -1.0
# 2020/10/01 22:31:26
# episode : 230 | final step : 98 | total reward : -1.0
# 2020/10/01 22:31:29
# episode : 231 | final step : 101 | total reward : 0.0
# 2020/10/01 22:31:32
# episode : 232 | final step : 99 | total reward : -1.0
# 2020/10/01 22:31:35
# episode : 233 | final step : 97 | total reward : 0.0
# 2020/10/01 22:31:38
# episode : 234 | final step : 100 | total reward : -1.0
# 2020/10/01 22:31:41
# episode : 235 | final step : 98 | total reward : -1.0
# 2020/10/01 22:31:44
# episode : 236 | final step : 98 | total reward : -1.0
# 2020/10/01 22:31:47
# episode : 237 | final step : 98 | total reward : 0.0
# 2020/10/01 22:31:50
# episode : 238 | final step : 99 | total reward : -1.0
# 2020/10/01 22:31:53
# episode : 239 | final step : 99 | total reward : 0.0
# 2020/10/01 22:31:56
# episode : 240 | final step : 98 | total reward : -1.0
# 2020/10/01 22:31:58
# episode : 241 | final step : 98 | total reward : -1.0
# 2020/10/01 22:32:01
# episode : 242 | final step : 98 | total reward : 0.0
# 2020/10/01 22:32:04
# episode : 243 | final step : 98 | total reward : 0.0
# 2020/10/01 22:32:07
# episode : 244 | final step : 100 | total reward : 0.0
# 2020/10/01 22:32:10
# episode : 245 | final step : 98 | total reward : 0.0
# 2020/10/01 22:32:13
# episode : 246 | final step : 98 | total reward : -1.0
# 2020/10/01 22:32:16
# episode : 247 | final step : 99 | total reward : -1.0
# 2020/10/01 22:32:19
# episode : 248 | final step : 99 | total reward : -1.0
# 2020/10/01 22:32:21
# episode : 249 | final step : 97 | total reward : 0.0
# 2020/10/01 22:32:24
# episode : 250 | final step : 99 | total reward : 0.0
# 2020/10/01 22:32:27
# episode : 251 | final step : 98 | total reward : -1.0
# 2020/10/01 22:32:30
# episode : 252 | final step : 99 | total reward : -1.0
# 2020/10/01 22:32:33
# episode : 253 | final step : 98 | total reward : -1.0
# 2020/10/01 22:32:36
# episode : 254 | final step : 99 | total reward : 0.0
# 2020/10/01 22:32:39
# episode : 255 | final step : 98 | total reward : -1.0
# 2020/10/01 22:32:42
# episode : 256 | final step : 98 | total reward : -1.0
# 2020/10/01 22:32:45
# episode : 257 | final step : 97 | total reward : 0.0
# 2020/10/01 22:32:48
# episode : 258 | final step : 102 | total reward : 0.0
# 2020/10/01 22:32:51
# episode : 259 | final step : 97 | total reward : 0.0
# 2020/10/01 22:32:54
# episode : 260 | final step : 98 | total reward : -1.0
# 2020/10/01 22:32:57
# episode : 261 | final step : 98 | total reward : 0.0
# 2020/10/01 22:33:00
# episode : 262 | final step : 98 | total reward : -1.0
# 2020/10/01 22:33:03
# episode : 263 | final step : 98 | total reward : -1.0
# 2020/10/01 22:33:06
# episode : 264 | final step : 98 | total reward : -1.0
# 2020/10/01 22:33:09
# episode : 265 | final step : 98 | total reward : -1.0
# 2020/10/01 22:33:12
# episode : 266 | final step : 100 | total reward : 0.0
# 2020/10/01 22:33:14
# episode : 267 | final step : 98 | total reward : -1.0
# 2020/10/01 22:33:17
# episode : 268 | final step : 98 | total reward : -1.0
# 2020/10/01 22:33:20
# episode : 269 | final step : 98 | total reward : -1.0
# 2020/10/01 22:33:23
# episode : 270 | final step : 100 | total reward : 0.0
# 2020/10/01 22:33:26
# episode : 271 | final step : 98 | total reward : -1.0
# 2020/10/01 22:33:29
# episode : 272 | final step : 99 | total reward : -1.0
# 2020/10/01 22:33:32
# episode : 273 | final step : 98 | total reward : -1.0
# 2020/10/01 22:33:35
# episode : 274 | final step : 99 | total reward : 0.0
# 2020/10/01 22:33:38
# episode : 275 | final step : 99 | total reward : -1.0
# 2020/10/01 22:33:41
# episode : 276 | final step : 95 | total reward : 0.0
# 2020/10/01 22:33:44
# episode : 277 | final step : 100 | total reward : -1.0
# 2020/10/01 22:33:47
# episode : 278 | final step : 99 | total reward : -1.0
# 2020/10/01 22:33:50
# episode : 279 | final step : 97 | total reward : 0.0
# 2020/10/01 22:33:53
# episode : 280 | final step : 98 | total reward : -1.0
# 2020/10/01 22:33:56
# episode : 281 | final step : 99 | total reward : 0.0
# 2020/10/01 22:33:59
# episode : 282 | final step : 98 | total reward : -1.0
# 2020/10/01 22:34:02
# episode : 283 | final step : 99 | total reward : -1.0
# 2020/10/01 22:34:05
# episode : 284 | final step : 97 | total reward : 0.0
# 2020/10/01 22:34:08
# episode : 285 | final step : 98 | total reward : -1.0
# 2020/10/01 22:34:11
# episode : 286 | final step : 98 | total reward : -1.0
# 2020/10/01 22:34:14
# episode : 287 | final step : 98 | total reward : -1.0
# 2020/10/01 22:34:17
# episode : 288 | final step : 100 | total reward : 0.0
# 2020/10/01 22:34:21
# episode : 289 | final step : 101 | total reward : 0.0
# 2020/10/01 22:34:24
# episode : 290 | final step : 97 | total reward : -1.0
# 2020/10/01 22:34:27
# episode : 291 | final step : 98 | total reward : -1.0
# 2020/10/01 22:34:30
# episode : 292 | final step : 98 | total reward : -1.0
# 2020/10/01 22:34:33
# episode : 293 | final step : 99 | total reward : 0.0
# 2020/10/01 22:34:36
# episode : 294 | final step : 98 | total reward : -1.0
# 2020/10/01 22:34:39
# episode : 295 | final step : 98 | total reward : -1.0
# 2020/10/01 22:34:42
# episode : 296 | final step : 98 | total reward : -1.0
# 2020/10/01 22:34:45
# episode : 297 | final step : 99 | total reward : -1.0
# 2020/10/01 22:34:48
# episode : 298 | final step : 97 | total reward : 0.0
# 2020/10/01 22:34:51
# episode : 299 | final step : 99 | total reward : -1.0
# 2020/10/01 22:34:54
# episode : 300 | final step : 99 | total reward : -1.0
# 2020/10/01 22:34:57
# episode : 301 | final step : 98 | total reward : -1.0
# 2020/10/01 22:35:00
# episode : 302 | final step : 98 | total reward : -1.0
# 2020/10/01 22:35:03
# episode : 303 | final step : 99 | total reward : -1.0
# 2020/10/01 22:35:06
# episode : 304 | final step : 98 | total reward : -1.0
# 2020/10/01 22:35:09
# episode : 305 | final step : 97 | total reward : 0.0
# 2020/10/01 22:35:12
# episode : 306 | final step : 100 | total reward : 0.0
# 2020/10/01 22:35:15
# episode : 307 | final step : 99 | total reward : -1.0
# 2020/10/01 22:35:18
# episode : 308 | final step : 96 | total reward : 0.0
# 2020/10/01 22:35:21
# episode : 309 | final step : 98 | total reward : 0.0
# 2020/10/01 22:35:24
# episode : 310 | final step : 98 | total reward : -1.0
# 2020/10/01 22:35:27
# episode : 311 | final step : 95 | total reward : 0.0
# 2020/10/01 22:35:30
# episode : 312 | final step : 98 | total reward : -1.0
# 2020/10/01 22:35:33
# episode : 313 | final step : 98 | total reward : -1.0
# 2020/10/01 22:35:36
# episode : 314 | final step : 98 | total reward : -1.0
# 2020/10/01 22:35:39
# episode : 315 | final step : 98 | total reward : -1.0
# 2020/10/01 22:35:42
# episode : 316 | final step : 98 | total reward : -1.0
# 2020/10/01 22:35:45
# episode : 317 | final step : 99 | total reward : -1.0
# 2020/10/01 22:35:48
# episode : 318 | final step : 98 | total reward : -1.0
# 2020/10/01 22:35:51
# episode : 319 | final step : 95 | total reward : 0.0
# 2020/10/01 22:35:54
# episode : 320 | final step : 100 | total reward : 0.0
# 2020/10/01 22:35:57
# episode : 321 | final step : 99 | total reward : -1.0
# 2020/10/01 22:36:00
# episode : 322 | final step : 98 | total reward : -1.0
# 2020/10/01 22:36:03
# episode : 323 | final step : 98 | total reward : 0.0
# 2020/10/01 22:36:06
# episode : 324 | final step : 98 | total reward : -1.0
# 2020/10/01 22:36:09
# episode : 325 | final step : 98 | total reward : -1.0
# 2020/10/01 22:36:12
# episode : 326 | final step : 98 | total reward : 0.0
# 2020/10/01 22:36:15
# episode : 327 | final step : 97 | total reward : 0.0
# 2020/10/01 22:36:18
# episode : 328 | final step : 99 | total reward : -1.0
# 2020/10/01 22:36:21
# episode : 329 | final step : 96 | total reward : 0.0
# 2020/10/01 22:36:24
# episode : 330 | final step : 100 | total reward : -1.0
# 2020/10/01 22:36:27
# episode : 331 | final step : 99 | total reward : -1.0
# 2020/10/01 22:36:30
# episode : 332 | final step : 97 | total reward : 0.0
# 2020/10/01 22:36:33
# episode : 333 | final step : 98 | total reward : -1.0
# 2020/10/01 22:36:36
# episode : 334 | final step : 98 | total reward : -1.0
# 2020/10/01 22:36:39
# episode : 335 | final step : 98 | total reward : -1.0
# 2020/10/01 22:36:42
# episode : 336 | final step : 98 | total reward : -1.0
# 2020/10/01 22:36:45
# episode : 337 | final step : 97 | total reward : 0.0
# 2020/10/01 22:36:48
# episode : 338 | final step : 98 | total reward : -1.0
# 2020/10/01 22:36:51
# episode : 339 | final step : 99 | total reward : 0.0
# 2020/10/01 22:36:55
# episode : 340 | final step : 97 | total reward : 0.0
# 2020/10/01 22:36:58
# episode : 341 | final step : 98 | total reward : -1.0
# 2020/10/01 22:37:00
# episode : 342 | final step : 97 | total reward : 0.0
# 2020/10/01 22:37:04
# episode : 343 | final step : 98 | total reward : -1.0
# 2020/10/01 22:37:07
# episode : 344 | final step : 99 | total reward : -1.0
# 2020/10/01 22:37:10
# episode : 345 | final step : 98 | total reward : -1.0
# 2020/10/01 22:37:13
# episode : 346 | final step : 99 | total reward : 0.0
# 2020/10/01 22:37:16
# episode : 347 | final step : 99 | total reward : -1.0
# 2020/10/01 22:37:19
# episode : 348 | final step : 98 | total reward : -1.0
# 2020/10/01 22:37:22
# episode : 349 | final step : 98 | total reward : -1.0
# 2020/10/01 22:37:25
# episode : 350 | final step : 99 | total reward : -1.0
# 2020/10/01 22:37:28
# episode : 351 | final step : 99 | total reward : -1.0
# 2020/10/01 22:37:31
# episode : 352 | final step : 99 | total reward : -1.0
# 2020/10/01 22:37:34
# episode : 353 | final step : 100 | total reward : 0.0
# 2020/10/01 22:37:37
# episode : 354 | final step : 98 | total reward : -1.0
# 2020/10/01 22:37:40
# episode : 355 | final step : 98 | total reward : -1.0
# 2020/10/01 22:37:42
# episode : 356 | final step : 98 | total reward : 0.0
# 2020/10/01 22:37:45
# episode : 357 | final step : 98 | total reward : -1.0
# 2020/10/01 22:37:48
# episode : 358 | final step : 98 | total reward : -1.0
# 2020/10/01 22:37:51
# episode : 359 | final step : 99 | total reward : -1.0
# 2020/10/01 22:37:54
# episode : 360 | final step : 98 | total reward : -1.0
# 2020/10/01 22:37:57
# episode : 361 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:00
# episode : 362 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:03
# episode : 363 | final step : 100 | total reward : 0.0
# 2020/10/01 22:38:06
# episode : 364 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:09
# episode : 365 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:12
# episode : 366 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:15
# episode : 367 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:17
# episode : 368 | final step : 99 | total reward : -1.0
# 2020/10/01 22:38:21
# episode : 369 | final step : 99 | total reward : 0.0
# 2020/10/01 22:38:23
# episode : 370 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:26
# episode : 371 | final step : 97 | total reward : 0.0
# 2020/10/01 22:38:29
# episode : 372 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:32
# episode : 373 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:35
# episode : 374 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:38
# episode : 375 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:41
# episode : 376 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:44
# episode : 377 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:47
# episode : 378 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:50
# episode : 379 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:52
# episode : 380 | final step : 98 | total reward : -1.0
# 2020/10/01 22:38:56
# episode : 381 | final step : 99 | total reward : 0.0
# 2020/10/01 22:38:58
# episode : 382 | final step : 99 | total reward : -1.0
# 2020/10/01 22:39:01
# episode : 383 | final step : 96 | total reward : 0.0
# 2020/10/01 22:39:04
# episode : 384 | final step : 98 | total reward : -1.0
# 2020/10/01 22:39:07
# episode : 385 | final step : 98 | total reward : -1.0
# 2020/10/01 22:39:10
# episode : 386 | final step : 100 | total reward : 0.0
# 2020/10/01 22:39:13
# episode : 387 | final step : 98 | total reward : -1.0
# 2020/10/01 22:39:16
# episode : 388 | final step : 98 | total reward : -1.0
# 2020/10/01 22:39:19
# episode : 389 | final step : 100 | total reward : 0.0
# 2020/10/01 22:39:22
# episode : 390 | final step : 98 | total reward : -1.0
# 2020/10/01 22:39:25
# episode : 391 | final step : 97 | total reward : -1.0
# 2020/10/01 22:39:28
# episode : 392 | final step : 97 | total reward : 0.0
# 2020/10/01 22:39:30
# episode : 393 | final step : 98 | total reward : -1.0
# 2020/10/01 22:39:33
# episode : 394 | final step : 99 | total reward : 0.0
# 2020/10/01 22:39:36
# episode : 395 | final step : 99 | total reward : -1.0
# 2020/10/01 22:39:39
# episode : 396 | final step : 98 | total reward : -1.0
# 2020/10/01 22:39:42
# episode : 397 | final step : 99 | total reward : 0.0
# 2020/10/01 22:39:45
# episode : 398 | final step : 98 | total reward : -1.0
# 2020/10/01 22:39:48
# episode : 399 | final step : 99 | total reward : -1.0
# 2020/10/01 22:39:51
# episode : 400 | final step : 98 | total reward : -1.0
# 2020/10/01 22:39:54
# episode : 401 | final step : 98 | total reward : -1.0
# 2020/10/01 22:39:57
# episode : 402 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:00
# episode : 403 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:03
# episode : 404 | final step : 99 | total reward : -1.0
# 2020/10/01 22:40:05
# episode : 405 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:08
# episode : 406 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:11
# episode : 407 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:14
# episode : 408 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:17
# episode : 409 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:20
# episode : 410 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:23
# episode : 411 | final step : 97 | total reward : 0.0
# 2020/10/01 22:40:26
# episode : 412 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:29
# episode : 413 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:32
# episode : 414 | final step : 100 | total reward : 0.0
# 2020/10/01 22:40:35
# episode : 415 | final step : 99 | total reward : 0.0
# 2020/10/01 22:40:38
# episode : 416 | final step : 99 | total reward : 0.0
# 2020/10/01 22:40:40
# episode : 417 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:43
# episode : 418 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:46
# episode : 419 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:49
# episode : 420 | final step : 98 | total reward : -1.0
# 2020/10/01 22:40:52
# episode : 421 | final step : 102 | total reward : 0.0
# 2020/10/01 22:40:55
# episode : 422 | final step : 98 | total reward : 0.0
# 2020/10/01 22:40:58
# episode : 423 | final step : 99 | total reward : -1.0
# 2020/10/01 22:41:01
# episode : 424 | final step : 98 | total reward : 0.0
# 2020/10/01 22:41:04
# episode : 425 | final step : 99 | total reward : -1.0
# 2020/10/01 22:41:07
# episode : 426 | final step : 98 | total reward : -1.0
# 2020/10/01 22:41:10
# episode : 427 | final step : 99 | total reward : 0.0
# 2020/10/01 22:41:13
# episode : 428 | final step : 101 | total reward : -1.0
# 2020/10/01 22:41:16
# episode : 429 | final step : 98 | total reward : -1.0
# 2020/10/01 22:41:19
# episode : 430 | final step : 98 | total reward : -1.0
# 2020/10/01 22:41:22
# episode : 431 | final step : 98 | total reward : -1.0
# 2020/10/01 22:41:25
# episode : 432 | final step : 98 | total reward : -1.0
# 2020/10/01 22:41:27
# episode : 433 | final step : 98 | total reward : -1.0
# 2020/10/01 22:41:30
# episode : 434 | final step : 99 | total reward : 0.0
# 2020/10/01 22:41:33
# episode : 435 | final step : 99 | total reward : -1.0
# 2020/10/01 22:41:36
# episode : 436 | final step : 98 | total reward : -1.0
# 2020/10/01 22:41:39
# episode : 437 | final step : 99 | total reward : 0.0
# 2020/10/01 22:41:42
# episode : 438 | final step : 99 | total reward : -1.0
# 2020/10/01 22:41:45
# episode : 439 | final step : 99 | total reward : 0.0
# 2020/10/01 22:41:48
# episode : 440 | final step : 96 | total reward : 0.0
# 2020/10/01 22:41:51
# episode : 441 | final step : 98 | total reward : -1.0
# 2020/10/01 22:41:54
# episode : 442 | final step : 98 | total reward : -1.0
# 2020/10/01 22:41:57
# episode : 443 | final step : 98 | total reward : -1.0
# 2020/10/01 22:42:00
# episode : 444 | final step : 99 | total reward : -1.0
# 2020/10/01 22:42:02
# episode : 445 | final step : 98 | total reward : -1.0
# 2020/10/01 22:42:06
# episode : 446 | final step : 99 | total reward : 0.0
# 2020/10/01 22:42:09
# episode : 447 | final step : 98 | total reward : -1.0
# 2020/10/01 22:42:11
# episode : 448 | final step : 96 | total reward : 0.0
# 2020/10/01 22:42:14
# episode : 449 | final step : 98 | total reward : -1.0
# 2020/10/01 22:42:17
# episode : 450 | final step : 98 | total reward : 0.0
# 2020/10/01 22:42:20
# episode : 451 | final step : 98 | total reward : -1.0
# 2020/10/01 22:42:23
# episode : 452 | final step : 98 | total reward : -1.0
# 2020/10/01 22:42:26
# episode : 453 | final step : 99 | total reward : -1.0
# 2020/10/01 22:42:29
# episode : 454 | final step : 98 | total reward : -1.0
# 2020/10/01 22:42:32
# episode : 455 | final step : 98 | total reward : -1.0
# 2020/10/01 22:42:35
# episode : 456 | final step : 97 | total reward : 0.0
# 2020/10/01 22:42:38
# episode : 457 | final step : 99 | total reward : -1.0
# 2020/10/01 22:42:41
# episode : 458 | final step : 98 | total reward : -1.0
# 2020/10/01 22:42:44
# episode : 459 | final step : 99 | total reward : -1.0
# 2020/10/01 22:42:47
# episode : 460 | final step : 98 | total reward : -1.0
# 2020/10/01 22:42:50
# episode : 461 | final step : 98 | total reward : -1.0
# 2020/10/01 22:42:53
# episode : 462 | final step : 98 | total reward : -1.0
# 2020/10/01 22:42:56
# episode : 463 | final step : 99 | total reward : -1.0
# 2020/10/01 22:42:59
# episode : 464 | final step : 98 | total reward : -1.0
# 2020/10/01 22:43:02
# episode : 465 | final step : 98 | total reward : -1.0
# 2020/10/01 22:43:05
# episode : 466 | final step : 98 | total reward : -1.0
# 2020/10/01 22:43:07
# episode : 467 | final step : 98 | total reward : -1.0
# 2020/10/01 22:43:10
# episode : 468 | final step : 98 | total reward : -1.0
# 2020/10/01 22:43:13
# episode : 469 | final step : 99 | total reward : -1.0
# 2020/10/01 22:43:16
# episode : 470 | final step : 100 | total reward : 0.0
# 2020/10/01 22:43:19
# episode : 471 | final step : 98 | total reward : -1.0
# 2020/10/01 22:43:22
# episode : 472 | final step : 98 | total reward : -1.0
# 2020/10/01 22:43:25
# episode : 473 | final step : 96 | total reward : 0.0
# 2020/10/01 22:43:28
# episode : 474 | final step : 99 | total reward : -1.0
# 2020/10/01 22:43:31
# episode : 475 | final step : 98 | total reward : -1.0
# 2020/10/01 22:43:33
# episode : 476 | final step : 98 | total reward : -1.0
# 2020/10/01 22:43:36
# episode : 477 | final step : 98 | total reward : -1.0
# 2020/10/01 22:43:39
# episode : 478 | final step : 101 | total reward : -1.0
# 2020/10/01 22:43:42
# episode : 479 | final step : 98 | total reward : -1.0
# 2020/10/01 22:43:45
# episode : 480 | final step : 100 | total reward : -1.0
# 2020/10/01 22:43:48
# episode : 481 | final step : 97 | total reward : 0.0
# 2020/10/01 22:43:51
# episode : 482 | final step : 97 | total reward : 0.0
# 2020/10/01 22:43:54
# episode : 483 | final step : 98 | total reward : 0.0
# 2020/10/01 22:43:57
# episode : 484 | final step : 98 | total reward : -1.0
# 2020/10/01 22:44:00
# episode : 485 | final step : 98 | total reward : 0.0
# 2020/10/01 22:44:03
# episode : 486 | final step : 98 | total reward : -1.0
# 2020/10/01 22:44:06
# episode : 487 | final step : 98 | total reward : -1.0
# 2020/10/01 22:44:09
# episode : 488 | final step : 98 | total reward : -1.0
# 2020/10/01 22:44:11
# episode : 489 | final step : 99 | total reward : -1.0
# 2020/10/01 22:44:15
# episode : 490 | final step : 99 | total reward : 0.0
# 2020/10/01 22:44:18
# episode : 491 | final step : 98 | total reward : -1.0
# 2020/10/01 22:44:20
# episode : 492 | final step : 100 | total reward : 0.0
# 2020/10/01 22:44:23
# episode : 493 | final step : 96 | total reward : 0.0
# 2020/10/01 22:44:26
# episode : 494 | final step : 96 | total reward : 0.0
# 2020/10/01 22:44:29
# episode : 495 | final step : 95 | total reward : 0.0
# 2020/10/01 22:44:32
# episode : 496 | final step : 99 | total reward : -1.0
# 2020/10/01 22:44:35
# episode : 497 | final step : 98 | total reward : -1.0
# 2020/10/01 22:44:38
# episode : 498 | final step : 98 | total reward : -1.0
# 2020/10/01 22:44:41
# episode : 499 | final step : 98 | total reward : -1.0
# 2020/10/01 22:44:43
# episode : 500 | final step : 97 | total reward : 0.0
# 2020/10/01 22:44:46
# episode : 501 | final step : 99 | total reward : -1.0
# 2020/10/01 22:44:49
# episode : 502 | final step : 98 | total reward : -1.0
# 2020/10/01 22:44:52
# episode : 503 | final step : 97 | total reward : 0.0
# 2020/10/01 22:44:55
# episode : 504 | final step : 97 | total reward : 0.0
# 2020/10/01 22:44:58
# episode : 505 | final step : 100 | total reward : -1.0
# 2020/10/01 22:45:01
# episode : 506 | final step : 98 | total reward : -1.0
# 2020/10/01 22:45:04
# episode : 507 | final step : 100 | total reward : -1.0
# 2020/10/01 22:45:07
# episode : 508 | final step : 99 | total reward : -1.0
# 2020/10/01 22:45:10
# episode : 509 | final step : 98 | total reward : 0.0
# 2020/10/01 22:45:13
# episode : 510 | final step : 100 | total reward : -1.0
# 2020/10/01 22:45:16
# episode : 511 | final step : 99 | total reward : -1.0
# 2020/10/01 22:45:19
# episode : 512 | final step : 98 | total reward : -1.0
# 2020/10/01 22:45:22
# episode : 513 | final step : 97 | total reward : 0.0
# 2020/10/01 22:45:25
# episode : 514 | final step : 98 | total reward : -1.0
# 2020/10/01 22:45:28
# episode : 515 | final step : 99 | total reward : 0.0
# 2020/10/01 22:45:31
# episode : 516 | final step : 98 | total reward : -1.0
# 2020/10/01 22:45:34
# episode : 517 | final step : 99 | total reward : -1.0
# 2020/10/01 22:45:36
# episode : 518 | final step : 97 | total reward : 0.0
# 2020/10/01 22:45:39
# episode : 519 | final step : 96 | total reward : 0.0
# 2020/10/01 22:45:42
# episode : 520 | final step : 98 | total reward : -1.0
# 2020/10/01 22:45:45
# episode : 521 | final step : 99 | total reward : -1.0
# 2020/10/01 22:45:48
# episode : 522 | final step : 98 | total reward : -1.0
# 2020/10/01 22:45:51
# episode : 523 | final step : 99 | total reward : -1.0
# 2020/10/01 22:45:54
# episode : 524 | final step : 98 | total reward : -1.0
# 2020/10/01 22:45:57
# episode : 525 | final step : 98 | total reward : 0.0
# 2020/10/01 22:46:00
# episode : 526 | final step : 98 | total reward : 0.0
# 2020/10/01 22:46:03
# episode : 527 | final step : 102 | total reward : 0.0
# 2020/10/01 22:46:06
# episode : 528 | final step : 98 | total reward : -1.0
# 2020/10/01 22:46:09
# episode : 529 | final step : 99 | total reward : 0.0
# 2020/10/01 22:46:12
# episode : 530 | final step : 98 | total reward : 0.0
# 2020/10/01 22:46:15
# episode : 531 | final step : 99 | total reward : -1.0
# 2020/10/01 22:46:18
# episode : 532 | final step : 100 | total reward : 0.0
# 2020/10/01 22:46:21
# episode : 533 | final step : 99 | total reward : -1.0
# 2020/10/01 22:46:23
# episode : 534 | final step : 98 | total reward : 0.0
# 2020/10/01 22:46:26
# episode : 535 | final step : 98 | total reward : -1.0
# 2020/10/01 22:46:29
# episode : 536 | final step : 99 | total reward : 0.0
# 2020/10/01 22:46:32
# episode : 537 | final step : 98 | total reward : -1.0
# 2020/10/01 22:46:35
# episode : 538 | final step : 98 | total reward : -1.0
# 2020/10/01 22:46:38
# episode : 539 | final step : 98 | total reward : -1.0
# 2020/10/01 22:46:41
# episode : 540 | final step : 99 | total reward : -1.0
# 2020/10/01 22:46:44
# episode : 541 | final step : 97 | total reward : 0.0
# 2020/10/01 22:46:47
# episode : 542 | final step : 98 | total reward : 0.0
# 2020/10/01 22:46:50
# episode : 543 | final step : 98 | total reward : 0.0
# 2020/10/01 22:46:53
# episode : 544 | final step : 97 | total reward : 0.0
# 2020/10/01 22:46:56
# episode : 545 | final step : 96 | total reward : 0.0
# 2020/10/01 22:46:59
# episode : 546 | final step : 99 | total reward : 0.0
# 2020/10/01 22:47:02
# episode : 547 | final step : 99 | total reward : -1.0
# 2020/10/01 22:47:05
# episode : 548 | final step : 99 | total reward : -1.0
# 2020/10/01 22:47:07
# episode : 549 | final step : 98 | total reward : -1.0
# 2020/10/01 22:47:10
# episode : 550 | final step : 99 | total reward : -1.0
# 2020/10/01 22:47:13
# episode : 551 | final step : 98 | total reward : -1.0
# 2020/10/01 22:47:16
# episode : 552 | final step : 98 | total reward : -1.0
# 2020/10/01 22:47:19
# episode : 553 | final step : 99 | total reward : -1.0
# 2020/10/01 22:47:22
# episode : 554 | final step : 98 | total reward : -1.0
# 2020/10/01 22:47:25
# episode : 555 | final step : 99 | total reward : -1.0
# 2020/10/01 22:47:28
# episode : 556 | final step : 99 | total reward : 0.0
# 2020/10/01 22:47:31
# episode : 557 | final step : 97 | total reward : 0.0
# 2020/10/01 22:47:34
# episode : 558 | final step : 100 | total reward : 0.0
# 2020/10/01 22:47:37
# episode : 559 | final step : 99 | total reward : -1.0
# 2020/10/01 22:47:39
# episode : 560 | final step : 98 | total reward : -1.0
# 2020/10/01 22:47:42
# episode : 561 | final step : 99 | total reward : 0.0
# 2020/10/01 22:47:45
# episode : 562 | final step : 99 | total reward : -1.0
# 2020/10/01 22:47:48
# episode : 563 | final step : 98 | total reward : 0.0
# 2020/10/01 22:47:51
# episode : 564 | final step : 100 | total reward : -1.0
# 2020/10/01 22:47:54
# episode : 565 | final step : 98 | total reward : -1.0
# 2020/10/01 22:47:57
# episode : 566 | final step : 99 | total reward : -1.0
# 2020/10/01 22:48:00
# episode : 567 | final step : 98 | total reward : -1.0
# 2020/10/01 22:48:03
# episode : 568 | final step : 99 | total reward : -1.0
# 2020/10/01 22:48:06
# episode : 569 | final step : 99 | total reward : -1.0
# 2020/10/01 22:48:09
# episode : 570 | final step : 102 | total reward : 0.0
# 2020/10/01 22:48:12
# episode : 571 | final step : 99 | total reward : -1.0
# 2020/10/01 22:48:15
# episode : 572 | final step : 100 | total reward : -1.0
# 2020/10/01 22:48:18
# episode : 573 | final step : 99 | total reward : 0.0
# 2020/10/01 22:48:21
# episode : 574 | final step : 98 | total reward : -1.0
# 2020/10/01 22:48:24
# episode : 575 | final step : 98 | total reward : 0.0
# 2020/10/01 22:48:26
# episode : 576 | final step : 100 | total reward : 0.0
# 2020/10/01 22:48:30
# episode : 577 | final step : 98 | total reward : -1.0
# 2020/10/01 22:48:33
# episode : 578 | final step : 98 | total reward : 0.0
# 2020/10/01 22:48:36
# episode : 579 | final step : 100 | total reward : 0.0
# 2020/10/01 22:48:38
# episode : 580 | final step : 98 | total reward : 0.0
# 2020/10/01 22:48:42
# episode : 581 | final step : 99 | total reward : 0.0
# 2020/10/01 22:48:44
# episode : 582 | final step : 99 | total reward : -1.0
# 2020/10/01 22:48:47
# episode : 583 | final step : 98 | total reward : 0.0
# 2020/10/01 22:48:50
# episode : 584 | final step : 100 | total reward : 0.0
# 2020/10/01 22:48:54
# episode : 585 | final step : 100 | total reward : -1.0
# 2020/10/01 22:48:56
# episode : 586 | final step : 98 | total reward : 0.0
# 2020/10/01 22:48:59
# episode : 587 | final step : 97 | total reward : 0.0
# 2020/10/01 22:49:02
# episode : 588 | final step : 97 | total reward : 0.0
# 2020/10/01 22:49:05
# episode : 589 | final step : 99 | total reward : -1.0
# 2020/10/01 22:49:08
# episode : 590 | final step : 100 | total reward : 0.0
# 2020/10/01 22:49:11
# episode : 591 | final step : 97 | total reward : -1.0
# 2020/10/01 22:49:14
# episode : 592 | final step : 98 | total reward : 0.0
# 2020/10/01 22:49:17
# episode : 593 | final step : 98 | total reward : -1.0
# 2020/10/01 22:49:19
# episode : 594 | final step : 99 | total reward : -1.0
# 2020/10/01 22:49:22
# episode : 595 | final step : 99 | total reward : 0.0
# 2020/10/01 22:49:25
# episode : 596 | final step : 98 | total reward : -1.0
# 2020/10/01 22:49:28
# episode : 597 | final step : 98 | total reward : -1.0
# 2020/10/01 22:49:31
# episode : 598 | final step : 97 | total reward : -1.0
# 2020/10/01 22:49:34
# episode : 599 | final step : 100 | total reward : 0.0
# 2020/10/01 22:49:37
# episode : 600 | final step : 99 | total reward : 0.0
# 2020/10/01 22:49:40
# episode : 601 | final step : 100 | total reward : 0.0
# 2020/10/01 22:49:42
# episode : 602 | final step : 99 | total reward : 0.0
# 2020/10/01 22:49:45
# episode : 603 | final step : 98 | total reward : -1.0
# 2020/10/01 22:49:48
# episode : 604 | final step : 98 | total reward : -1.0
# 2020/10/01 22:49:51
# episode : 605 | final step : 101 | total reward : -1.0
# 2020/10/01 22:49:54
# episode : 606 | final step : 95 | total reward : 0.0
# 2020/10/01 22:49:57
# episode : 607 | final step : 99 | total reward : -1.0
# 2020/10/01 22:50:00
# episode : 608 | final step : 100 | total reward : 0.0
# 2020/10/01 22:50:03
# episode : 609 | final step : 98 | total reward : -1.0
# 2020/10/01 22:50:06
# episode : 610 | final step : 98 | total reward : -1.0
# 2020/10/01 22:50:09
# episode : 611 | final step : 100 | total reward : 0.0
# 2020/10/01 22:50:12
# episode : 612 | final step : 98 | total reward : -1.0
# 2020/10/01 22:50:15
# episode : 613 | final step : 98 | total reward : -1.0
# 2020/10/01 22:50:17
# episode : 614 | final step : 98 | total reward : -1.0
# 2020/10/01 22:50:20
# episode : 615 | final step : 100 | total reward : 0.0
# 2020/10/01 22:50:23
# episode : 616 | final step : 99 | total reward : -1.0
# 2020/10/01 22:50:26
# episode : 617 | final step : 98 | total reward : 0.0
# 2020/10/01 22:50:29
# episode : 618 | final step : 99 | total reward : -1.0
# 2020/10/01 22:50:32
# episode : 619 | final step : 98 | total reward : -1.0
# 2020/10/01 22:50:35
# episode : 620 | final step : 98 | total reward : -1.0
# 2020/10/01 22:50:38
# episode : 621 | final step : 99 | total reward : -1.0
# 2020/10/01 22:50:40
# episode : 622 | final step : 98 | total reward : -1.0
# 2020/10/01 22:50:44
# episode : 623 | final step : 98 | total reward : -1.0
# 2020/10/01 22:50:47
# episode : 624 | final step : 98 | total reward : -1.0
# 2020/10/01 22:50:49
# episode : 625 | final step : 99 | total reward : 0.0
# 2020/10/01 22:50:52
# episode : 626 | final step : 99 | total reward : -1.0
# 2020/10/01 22:50:55
# episode : 627 | final step : 99 | total reward : -1.0
# 2020/10/01 22:50:58
# episode : 628 | final step : 99 | total reward : -1.0
# 2020/10/01 22:51:01
# episode : 629 | final step : 98 | total reward : -1.0
# 2020/10/01 22:51:04
# episode : 630 | final step : 97 | total reward : 0.0
# 2020/10/01 22:51:07
# episode : 631 | final step : 98 | total reward : -1.0
# 2020/10/01 22:51:10
# episode : 632 | final step : 99 | total reward : -1.0
# 2020/10/01 22:51:13
# episode : 633 | final step : 99 | total reward : 0.0
# 2020/10/01 22:51:16
# episode : 634 | final step : 100 | total reward : 0.0
# 2020/10/01 22:51:19
# episode : 635 | final step : 99 | total reward : 0.0
# 2020/10/01 22:51:22
# episode : 636 | final step : 97 | total reward : 0.0
# 2020/10/01 22:51:24
# episode : 637 | final step : 98 | total reward : -1.0
# 2020/10/01 22:51:27
# episode : 638 | final step : 98 | total reward : -1.0
# 2020/10/01 22:51:30
# episode : 639 | final step : 99 | total reward : -1.0
# 2020/10/01 22:51:33
# episode : 640 | final step : 98 | total reward : -1.0
# 2020/10/01 22:51:36
# episode : 641 | final step : 98 | total reward : 0.0
# 2020/10/01 22:51:39
# episode : 642 | final step : 98 | total reward : -1.0
# 2020/10/01 22:51:42
# episode : 643 | final step : 98 | total reward : 0.0
# 2020/10/01 22:51:45
# episode : 644 | final step : 99 | total reward : 0.0
# 2020/10/01 22:51:48
# episode : 645 | final step : 98 | total reward : -1.0
# 2020/10/01 22:51:51
# episode : 646 | final step : 99 | total reward : -1.0
# 2020/10/01 22:51:54
# episode : 647 | final step : 99 | total reward : -1.0
# 2020/10/01 22:51:56
# episode : 648 | final step : 98 | total reward : -1.0
# 2020/10/01 22:51:59
# episode : 649 | final step : 98 | total reward : -1.0
# 2020/10/01 22:52:02
# episode : 650 | final step : 99 | total reward : -1.0
# 2020/10/01 22:52:05
# episode : 651 | final step : 98 | total reward : -1.0
# 2020/10/01 22:52:08
# ...
# episode : 1741 | final step : 98 | total reward : -1.0
# 2020/10/01 23:45:46
# episode : 1742 | final step : 99 | total reward : 0.0
# 2020/10/01 23:45:49
# episode : 1743 | final step : 100 | total reward : 0.0
# 2020/10/01 23:45:52
# episode : 1744 | final step : 97 | total reward : 0.0
# 2020/10/01 23:45:55
# episode : 1745 | final step : 100 | total reward : -1.0
# 2020/10/01 23:45:58
# episode : 1746 | final step : 99 | total reward : -1.0
# 2020/10/01 23:46:01
# episode : 1747 | final step : 98 | total reward : 0.0
# 2020/10/01 23:46:04
# episode : 1748 | final step : 99 | total reward : -1.0
# 2020/10/01 23:46:07
# episode : 1749 | final step : 99 | total reward : -1.0
# 2020/10/01 23:46:10
# episode : 1750 | final step : 99 | total reward : 0.0
# 2020/10/01 23:46:12
# episode : 1751 | final step : 98 | total reward : -1.0
# 2020/10/01 23:46:15
# episode : 1752 | final step : 98 | total reward : -1.0
# 2020/10/01 23:46:18
# episode : 1753 | final step : 98 | total reward : -1.0
# 2020/10/01 23:46:21
# episode : 1754 | final step : 98 | total reward : -1.0
# 2020/10/01 23:46:24
# episode : 1755 | final step : 100 | total reward : 0.0
# 2020/10/01 23:46:27
# episode : 1756 | final step : 96 | total reward : 0.0
# 2020/10/01 23:46:30
# episode : 1757 | final step : 99 | total reward : -1.0
# 2020/10/01 23:46:33
# episode : 1758 | final step : 100 | total reward : 0.0
# 2020/10/01 23:46:36
# episode : 1759 | final step : 97 | total reward : 0.0
# 2020/10/01 23:46:39
# episode : 1760 | final step : 98 | total reward : -1.0
# 2020/10/01 23:46:42
# episode : 1761 | final step : 101 | total reward : 0.0
# 2020/10/01 23:46:45
# episode : 1762 | final step : 98 | total reward : -1.0
# 2020/10/01 23:46:48
# episode : 1763 | final step : 99 | total reward : -1.0
# 2020/10/01 23:46:51
# episode : 1764 | final step : 100 | total reward : 0.0
# 2020/10/01 23:46:54
# episode : 1765 | final step : 99 | total reward : -1.0
# 2020/10/01 23:46:57
# episode : 1766 | final step : 100 | total reward : -1.0
# 2020/10/01 23:47:00
# episode : 1767 | final step : 97 | total reward : 0.0
# 2020/10/01 23:47:03
# episode : 1768 | final step : 98 | total reward : -1.0
# 2020/10/01 23:47:06
# episode : 1769 | final step : 98 | total reward : -1.0
# 2020/10/01 23:47:09
# episode : 1770 | final step : 99 | total reward : 0.0
# 2020/10/01 23:47:12
# episode : 1771 | final step : 98 | total reward : -1.0
# 2020/10/01 23:47:15
# episode : 1772 | final step : 101 | total reward : 0.0
# 2020/10/01 23:47:18
# episode : 1773 | final step : 98 | total reward : -1.0
# 2020/10/01 23:47:20
# episode : 1774 | final step : 100 | total reward : -1.0
# 2020/10/01 23:47:24
# episode : 1775 | final step : 99 | total reward : -1.0
# 2020/10/01 23:47:27
# episode : 1776 | final step : 99 | total reward : 0.0
# 2020/10/01 23:47:30
# episode : 1777 | final step : 98 | total reward : -1.0
# 2020/10/01 23:47:32
# episode : 1778 | final step : 97 | total reward : 0.0
# 2020/10/01 23:47:35
# episode : 1779 | final step : 94 | total reward : 0.0
# 2020/10/01 23:47:38
# episode : 1780 | final step : 98 | total reward : -1.0
# 2020/10/01 23:47:41
# episode : 1781 | final step : 98 | total reward : 0.0
# 2020/10/01 23:47:44
# episode : 1782 | final step : 99 | total reward : -1.0
# 2020/10/01 23:47:47
# episode : 1783 | final step : 98 | total reward : -1.0
# 2020/10/01 23:47:50
# episode : 1784 | final step : 98 | total reward : -1.0
# 2020/10/01 23:47:53
# episode : 1785 | final step : 98 | total reward : -1.0
# 2020/10/01 23:47:56
# episode : 1786 | final step : 97 | total reward : 0.0
# 2020/10/01 23:47:59
# episode : 1787 | final step : 98 | total reward : -1.0
# 2020/10/01 23:48:02
# episode : 1788 | final step : 99 | total reward : -1.0
# 2020/10/01 23:48:05
# episode : 1789 | final step : 98 | total reward : 0.0
# 2020/10/01 23:48:08
# episode : 1790 | final step : 98 | total reward : -1.0
# 2020/10/01 23:48:11
# episode : 1791 | final step : 96 | total reward : 0.0
# 2020/10/01 23:48:14
# episode : 1792 | final step : 100 | total reward : 0.0
# 2020/10/01 23:48:16
# episode : 1793 | final step : 100 | total reward : 0.0
# 2020/10/01 23:48:19
# episode : 1794 | final step : 99 | total reward : -1.0
# 2020/10/01 23:48:22
# episode : 1795 | final step : 98 | total reward : 0.0
# 2020/10/01 23:48:25
# episode : 1796 | final step : 98 | total reward : 0.0
# 2020/10/01 23:48:28
# episode : 1797 | final step : 97 | total reward : 0.0
# 2020/10/01 23:48:31
# episode : 1798 | final step : 97 | total reward : 0.0
# 2020/10/01 23:48:34
# episode : 1799 | final step : 99 | total reward : -1.0
# 2020/10/01 23:48:37
# episode : 1800 | final step : 98 | total reward : -1.0
# 2020/10/01 23:48:39
# episode : 1801 | final step : 99 | total reward : -1.0
# 2020/10/01 23:48:42
# episode : 1802 | final step : 98 | total reward : 0.0
# 2020/10/01 23:48:45
# episode : 1803 | final step : 98 | total reward : -1.0
# 2020/10/01 23:48:48
# episode : 1804 | final step : 98 | total reward : 0.0
# 2020/10/01 23:48:51
# episode : 1805 | final step : 98 | total reward : -1.0
# 2020/10/01 23:48:54
# episode : 1806 | final step : 98 | total reward : 0.0
# 2020/10/01 23:48:57
# episode : 1807 | final step : 98 | total reward : -1.0
# 2020/10/01 23:49:00
# episode : 1808 | final step : 98 | total reward : -1.0
# 2020/10/01 23:49:03
# episode : 1809 | final step : 100 | total reward : 0.0
# 2020/10/01 23:49:06
# episode : 1810 | final step : 97 | total reward : 0.0
# 2020/10/01 23:49:09
# episode : 1811 | final step : 98 | total reward : -1.0
# 2020/10/01 23:49:12
# episode : 1812 | final step : 99 | total reward : -1.0
# 2020/10/01 23:49:15
# episode : 1813 | final step : 99 | total reward : -1.0
# 2020/10/01 23:49:18
# episode : 1814 | final step : 98 | total reward : -1.0
# 2020/10/01 23:49:21
# episode : 1815 | final step : 98 | total reward : -1.0
# 2020/10/01 23:49:24
# episode : 1816 | final step : 98 | total reward : -1.0
# 2020/10/01 23:49:27
# episode : 1817 | final step : 98 | total reward : -1.0
# 2020/10/01 23:49:30
# episode : 1818 | final step : 99 | total reward : 0.0
# 2020/10/01 23:49:33
# episode : 1819 | final step : 98 | total reward : -1.0
# 2020/10/01 23:49:36
# episode : 1820 | final step : 98 | total reward : -1.0
# 2020/10/01 23:49:39
# episode : 1821 | final step : 98 | total reward : 0.0
# 2020/10/01 23:49:42
# episode : 1822 | final step : 98 | total reward : -1.0
# 2020/10/01 23:49:44
# episode : 1823 | final step : 99 | total reward : -1.0
# 2020/10/01 23:49:47
# episode : 1824 | final step : 96 | total reward : 0.0
# 2020/10/01 23:49:50
# episode : 1825 | final step : 98 | total reward : 0.0
# 2020/10/01 23:49:53
# episode : 1826 | final step : 98 | total reward : -1.0
# 2020/10/01 23:49:56
# episode : 1827 | final step : 100 | total reward : -1.0
# 2020/10/01 23:49:59
# episode : 1828 | final step : 98 | total reward : -1.0
# 2020/10/01 23:50:02
# episode : 1829 | final step : 98 | total reward : -1.0
# 2020/10/01 23:50:05
# episode : 1830 | final step : 98 | total reward : 0.0
# 2020/10/01 23:50:08
# episode : 1831 | final step : 99 | total reward : -1.0
# 2020/10/01 23:50:11
# episode : 1832 | final step : 99 | total reward : -1.0
# 2020/10/01 23:50:14
# episode : 1833 | final step : 98 | total reward : -1.0
# 2020/10/01 23:50:17
# episode : 1834 | final step : 98 | total reward : -1.0
# 2020/10/01 23:50:20
# episode : 1835 | final step : 98 | total reward : -1.0
# 2020/10/01 23:50:23
# episode : 1836 | final step : 99 | total reward : -1.0
# 2020/10/01 23:50:26
# episode : 1837 | final step : 99 | total reward : -1.0
# 2020/10/01 23:50:29
# episode : 1838 | final step : 98 | total reward : 0.0
# 2020/10/01 23:50:32
# episode : 1839 | final step : 98 | total reward : -1.0
# 2020/10/01 23:50:35
# episode : 1840 | final step : 99 | total reward : -1.0
# 2020/10/01 23:50:38
# episode : 1841 | final step : 98 | total reward : -1.0
# 2020/10/01 23:50:40
# episode : 1842 | final step : 98 | total reward : -1.0
# 2020/10/01 23:50:43
# episode : 1843 | final step : 98 | total reward : -1.0
# 2020/10/01 23:50:46
# episode : 1844 | final step : 98 | total reward : -1.0
# 2020/10/01 23:50:49
# episode : 1845 | final step : 100 | total reward : 0.0
# 2020/10/01 23:50:52
# episode : 1846 | final step : 98 | total reward : -1.0
# 2020/10/01 23:50:55
# episode : 1847 | final step : 98 | total reward : -1.0
# 2020/10/01 23:50:58
# episode : 1848 | final step : 99 | total reward : 0.0
# 2020/10/01 23:51:01
# episode : 1849 | final step : 99 | total reward : 0.0
# 2020/10/01 23:51:04
# episode : 1850 | final step : 99 | total reward : -1.0
# 2020/10/01 23:51:07
# episode : 1851 | final step : 99 | total reward : -1.0
# 2020/10/01 23:51:10
# episode : 1852 | final step : 98 | total reward : -1.0
# 2020/10/01 23:51:13
# episode : 1853 | final step : 96 | total reward : 0.0
# 2020/10/01 23:51:16
# episode : 1854 | final step : 98 | total reward : -1.0
# 2020/10/01 23:51:19
# episode : 1855 | final step : 100 | total reward : -1.0
# 2020/10/01 23:51:22
# episode : 1856 | final step : 98 | total reward : -1.0
# 2020/10/01 23:51:24
# episode : 1857 | final step : 101 | total reward : 0.0
# 2020/10/01 23:51:27
# episode : 1858 | final step : 100 | total reward : 0.0
# 2020/10/01 23:51:30
# episode : 1859 | final step : 98 | total reward : -1.0
# 2020/10/01 23:51:33
# episode : 1860 | final step : 98 | total reward : -1.0
# 2020/10/01 23:51:36
# episode : 1861 | final step : 99 | total reward : -1.0
# 2020/10/01 23:51:39
# episode : 1862 | final step : 99 | total reward : -1.0
# 2020/10/01 23:51:42
# episode : 1863 | final step : 99 | total reward : -1.0
# 2020/10/01 23:51:45
# episode : 1864 | final step : 98 | total reward : -1.0
# 2020/10/01 23:51:48
# episode : 1865 | final step : 98 | total reward : -1.0
# 2020/10/01 23:51:51
# episode : 1866 | final step : 98 | total reward : 0.0
# 2020/10/01 23:51:54
# episode : 1867 | final step : 99 | total reward : 0.0
# 2020/10/01 23:51:57
# episode : 1868 | final step : 100 | total reward : -1.0
# 2020/10/01 23:52:00
# episode : 1869 | final step : 99 | total reward : -1.0
# 2020/10/01 23:52:03
# episode : 1870 | final step : 98 | total reward : 0.0
# 2020/10/01 23:52:06
# episode : 1871 | final step : 100 | total reward : -1.0
# 2020/10/01 23:52:09
# episode : 1872 | final step : 98 | total reward : -1.0
# 2020/10/01 23:52:12
# episode : 1873 | final step : 99 | total reward : -1.0
# 2020/10/01 23:52:15
# episode : 1874 | final step : 99 | total reward : -1.0
# 2020/10/01 23:52:18
# episode : 1875 | final step : 99 | total reward : 0.0
# 2020/10/01 23:52:21
# episode : 1876 | final step : 97 | total reward : 0.0
# 2020/10/01 23:52:24
# episode : 1877 | final step : 98 | total reward : -1.0
# 2020/10/01 23:52:27
# episode : 1878 | final step : 98 | total reward : -1.0
# 2020/10/01 23:52:30
# episode : 1879 | final step : 101 | total reward : 0.0
# 2020/10/01 23:52:32
# episode : 1880 | final step : 99 | total reward : 0.0
# 2020/10/01 23:52:35
# episode : 1881 | final step : 98 | total reward : -1.0
# 2020/10/01 23:52:39
# episode : 1882 | final step : 98 | total reward : -1.0
# 2020/10/01 23:52:42
# episode : 1883 | final step : 99 | total reward : -1.0
# 2020/10/01 23:52:44
# episode : 1884 | final step : 99 | total reward : -1.0
# 2020/10/01 23:52:48
# episode : 1885 | final step : 99 | total reward : -1.0
# 2020/10/01 23:52:51
# episode : 1886 | final step : 98 | total reward : -1.0
# 2020/10/01 23:52:53
# episode : 1887 | final step : 100 | total reward : 0.0
# 2020/10/01 23:52:56
# episode : 1888 | final step : 98 | total reward : -1.0
# 2020/10/01 23:52:59
# episode : 1889 | final step : 100 | total reward : 0.0
# 2020/10/01 23:53:02
# episode : 1890 | final step : 97 | total reward : 0.0
# 2020/10/01 23:53:05
# episode : 1891 | final step : 98 | total reward : -1.0
# 2020/10/01 23:53:08
# episode : 1892 | final step : 98 | total reward : -1.0
# 2020/10/01 23:53:11
# episode : 1893 | final step : 98 | total reward : -1.0
# 2020/10/01 23:53:14
# episode : 1894 | final step : 98 | total reward : -1.0
# 2020/10/01 23:53:17
# episode : 1895 | final step : 98 | total reward : -1.0
# 2020/10/01 23:53:20
# episode : 1896 | final step : 98 | total reward : -1.0
# 2020/10/01 23:53:23
# episode : 1897 | final step : 98 | total reward : -1.0
# 2020/10/01 23:53:26
# episode : 1898 | final step : 100 | total reward : 0.0
# 2020/10/01 23:53:29
# episode : 1899 | final step : 99 | total reward : 0.0
# 2020/10/01 23:53:32
# episode : 1900 | final step : 99 | total reward : 0.0
# 2020/10/01 23:53:35
# episode : 1901 | final step : 98 | total reward : -1.0
# 2020/10/01 23:53:38
# episode : 1902 | final step : 99 | total reward : -1.0
# 2020/10/01 23:53:41
# episode : 1903 | final step : 99 | total reward : -1.0
# 2020/10/01 23:53:43
# episode : 1904 | final step : 98 | total reward : -1.0
# 2020/10/01 23:53:46
# episode : 1905 | final step : 97 | total reward : 0.0
# 2020/10/01 23:53:49
# episode : 1906 | final step : 98 | total reward : -1.0
# 2020/10/01 23:53:52
# episode : 1907 | final step : 96 | total reward : 0.0
# 2020/10/01 23:53:55
# episode : 1908 | final step : 99 | total reward : -1.0
# 2020/10/01 23:53:58
# episode : 1909 | final step : 97 | total reward : -1.0
# 2020/10/01 23:54:01
# episode : 1910 | final step : 100 | total reward : 0.0
# 2020/10/01 23:54:04
# episode : 1911 | final step : 98 | total reward : -1.0
# 2020/10/01 23:54:07
# episode : 1912 | final step : 99 | total reward : -1.0
# 2020/10/01 23:54:10
# episode : 1913 | final step : 100 | total reward : 0.0
# 2020/10/01 23:54:13
# episode : 1914 | final step : 99 | total reward : 0.0
# 2020/10/01 23:54:16
# episode : 1915 | final step : 96 | total reward : 0.0
# 2020/10/01 23:54:19
# episode : 1916 | final step : 100 | total reward : 0.0
# 2020/10/01 23:54:22
# episode : 1917 | final step : 98 | total reward : -1.0
# 2020/10/01 23:54:25
# episode : 1918 | final step : 98 | total reward : -1.0
# 2020/10/01 23:54:28
# episode : 1919 | final step : 98 | total reward : -1.0
# 2020/10/01 23:54:31
# episode : 1920 | final step : 98 | total reward : -1.0
# 2020/10/01 23:54:34
# episode : 1921 | final step : 100 | total reward : 0.0
# 2020/10/01 23:54:37
# episode : 1922 | final step : 98 | total reward : -1.0
# 2020/10/01 23:54:40
# episode : 1923 | final step : 98 | total reward : -1.0
# 2020/10/01 23:54:43
# episode : 1924 | final step : 98 | total reward : 0.0
# 2020/10/01 23:54:46
# episode : 1925 | final step : 100 | total reward : 0.0
# 2020/10/01 23:54:49
# episode : 1926 | final step : 98 | total reward : -1.0
# 2020/10/01 23:54:52
# episode : 1927 | final step : 98 | total reward : -1.0
# 2020/10/01 23:54:55
# episode : 1928 | final step : 99 | total reward : -1.0
# 2020/10/01 23:54:58
# episode : 1929 | final step : 100 | total reward : 0.0
# 2020/10/01 23:55:01
# episode : 1930 | final step : 100 | total reward : 0.0
# 2020/10/01 23:55:04
# episode : 1931 | final step : 99 | total reward : -1.0
# 2020/10/01 23:55:07
# episode : 1932 | final step : 98 | total reward : -1.0
# 2020/10/01 23:55:11
# episode : 1933 | final step : 98 | total reward : -1.0
# 2020/10/01 23:55:14
# episode : 1934 | final step : 100 | total reward : 0.0
# 2020/10/01 23:55:17
# episode : 1935 | final step : 98 | total reward : -1.0
# 2020/10/01 23:55:20
# episode : 1936 | final step : 100 | total reward : 0.0
# 2020/10/01 23:55:23
# episode : 1937 | final step : 99 | total reward : -1.0
# 2020/10/01 23:55:26
# episode : 1938 | final step : 99 | total reward : 0.0
# 2020/10/01 23:55:29
# episode : 1939 | final step : 100 | total reward : -1.0
# 2020/10/01 23:55:32
# episode : 1940 | final step : 98 | total reward : 0.0
# 2020/10/01 23:55:34
# episode : 1941 | final step : 100 | total reward : 0.0
# 2020/10/01 23:55:37
# episode : 1942 | final step : 95 | total reward : 0.0
# 2020/10/01 23:55:40
# episode : 1943 | final step : 98 | total reward : 0.0
# 2020/10/01 23:55:43
# episode : 1944 | final step : 99 | total reward : -1.0
# 2020/10/01 23:55:46
# episode : 1945 | final step : 99 | total reward : 0.0
# 2020/10/01 23:55:49
# episode : 1946 | final step : 98 | total reward : -1.0
# 2020/10/01 23:55:52
# episode : 1947 | final step : 99 | total reward : -1.0
# 2020/10/01 23:55:55
# episode : 1948 | final step : 98 | total reward : -1.0
# 2020/10/01 23:55:58
# episode : 1949 | final step : 98 | total reward : -1.0
# 2020/10/01 23:56:01
# episode : 1950 | final step : 98 | total reward : -1.0
# 2020/10/01 23:56:04
# episode : 1951 | final step : 99 | total reward : 0.0
# 2020/10/01 23:56:07
# episode : 1952 | final step : 100 | total reward : 0.0
# 2020/10/01 23:56:09
# episode : 1953 | final step : 98 | total reward : -1.0
# 2020/10/01 23:56:13
# episode : 1954 | final step : 99 | total reward : 0.0

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(reward_list)

# %%
def moving_average(data,n):
    len_data=len(data)
    res_data=np.zeros(len_data)
    for i in range(n):
        res_data[i]=sum(data[:i])/(i+1)
    
    for i in range(n,len_data):
        res_data[i]=sum(data[i:i+n])/n
    return res_data

# %%
average_number=200
filtered_data=moving_average(reward_list,average_number)

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(filtered_data)

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[0]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[10]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[100]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[1000]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[9999]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()
