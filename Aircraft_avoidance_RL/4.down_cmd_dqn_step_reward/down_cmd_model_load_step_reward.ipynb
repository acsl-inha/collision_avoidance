# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
import time
import itertools
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
import gym_Aircraft
num_gpus=4
batch_size=128

# %%
env = gym.make("acav-v0")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# /home/jupyter-kunwoopark/.local/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """transition 저장"""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
class DQN(torch.nn.Module):
    def __init__(self, num_inputs, num_actions):
        super(DQN, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, env.action_space.n),
            nn.LeakyReLU(0.2, inplace=True)
        )

    def forward(self, x):
        out=self.fc(x)
        return out

# %%
BATCH_SIZE = batch_size
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10

# %%
policy_net = nn.DataParallel(DQN(env.observation_space.shape[0], env.action_space.n).to(device))
target_net = nn.DataParallel(DQN(env.observation_space.shape[0], env.action_space.n).to(device))
policy_net.load_state_dict(torch.load("train_res_fin"))
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
# Out:
# DataParallel(
#   (module): DQN(
#     (fc): Sequential(
#       (0): Linear(in_features=5, out_features=40, bias=True)
#       (1): LeakyReLU(negative_slope=0.2, inplace=True)
#       (2): Linear(in_features=40, out_features=40, bias=True)
#       (3): LeakyReLU(negative_slope=0.2, inplace=True)
#       (4): Linear(in_features=40, out_features=40, bias=True)
#       (5): LeakyReLU(negative_slope=0.2, inplace=True)
#       (6): Linear(in_features=40, out_features=40, bias=True)
#       (7): LeakyReLU(negative_slope=0.2, inplace=True)
#       (8): Linear(in_features=40, out_features=40, bias=True)
#       (9): LeakyReLU(negative_slope=0.2, inplace=True)
#       (10): Linear(in_features=40, out_features=40, bias=True)
#       (11): LeakyReLU(negative_slope=0.2, inplace=True)
#       (12): Linear(in_features=40, out_features=40, bias=True)
#       (13): LeakyReLU(negative_slope=0.2, inplace=True)
#       (14): Linear(in_features=40, out_features=3, bias=True)
#       (15): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#   )
# )

# %%
n_actions = env.action_space.n

# %%
optimizer = optim.Adam(policy_net.parameters())
memory = ReplayMemory(10000)

# %%
steps_done = 0

# %%
def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max (1)은 각 행의 가장 큰 열 값을 반환합니다.
            # 최대 결과의 두번째 열은 최대 요소의 주소값이므로,
            # 기대 보상이 더 큰 행동을 선택할 수 있습니다.
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(n_actions)]], device=device, dtype=torch.long)

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)

    batch = Transition(*zip(*transitions))

    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    state_action_values = policy_net(state_batch).gather(1, action_batch)

    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    # 기대 Q 값 계산
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Huber 손실 계산
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    # 모델 최적화
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
num_episodes = 10000
total_res=[]
reward_list=[]
for i_episode in range(num_episodes):
    total_reward=0
    
    # 환경과 상태 초기화
    res_list=np.zeros(11)
    state = env.reset()
    state=torch.from_numpy(state.astype(np.float32)).unsqueeze(0).to(device)
    for t in count():
        # 행동 선택과 수행
        
        action = select_action(state)
        next_state, reward, done, res = env.step(action.item())
        reward = torch.tensor([reward], dtype=torch.float32).to(device)
        
        next_state=torch.from_numpy(next_state.astype(np.float32)).unsqueeze(0).to(device)

        # 새로운 상태 관찰
        if not done:
            next_state = next_state
        else:
            next_state = None

        # 메모리에 변이 저장
        memory.push(state, action, next_state, reward)

        # 다음 상태로 이동
        state = next_state

        # 최적화 한단계 수행(목표 네트워크에서)
        optimize_model()
        
        # Data save
        
        cmd_list,r_list,elev_list,azim_list,Pm_list,Pt_list,h_list=res
        Pm_list=Pm_list.tolist()
        Pt_list=Pt_list.tolist()
        merged_data=itertools.chain([cmd_list],[r_list],[elev_list],[azim_list],Pm_list,Pt_list,[h_list])
        merged_data=np.array(list(merged_data))
        res_list=np.vstack([res_list,merged_data])
        
        total_reward+=reward
        
        if done:
            res_list=np.delete(res_list,0,0)
            
            total_res.append(res_list)
            reward_list.append(total_reward)
            
            now = time.localtime()
            print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))
            print("episode : {} | final step : {} | total reward : {}".format(i_episode, t, total_reward.item()))
            break
            
        
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

print('Complete')
env.close()
# Out:
# 2020/10/02 00:10:00
# episode : 0 | final step : 98 | total reward : -2.0
# 2020/10/02 00:10:11
# episode : 1 | final step : 99 | total reward : -1.0
# 2020/10/02 00:10:14
# episode : 2 | final step : 98 | total reward : 99.0
# 2020/10/02 00:10:17
# episode : 3 | final step : 100 | total reward : 0.0
# 2020/10/02 00:10:20
# episode : 4 | final step : 98 | total reward : -2.0
# 2020/10/02 00:10:23
# episode : 5 | final step : 98 | total reward : 99.0
# 2020/10/02 00:10:26
# episode : 6 | final step : 98 | total reward : -2.0
# 2020/10/02 00:10:30
# episode : 7 | final step : 98 | total reward : -2.0
# 2020/10/02 00:10:33
# episode : 8 | final step : 96 | total reward : 97.0
# 2020/10/02 00:10:36
# episode : 9 | final step : 98 | total reward : -2.0
# 2020/10/02 00:10:39
# episode : 10 | final step : 98 | total reward : -2.0
# 2020/10/02 00:10:42
# episode : 11 | final step : 100 | total reward : 101.0
# 2020/10/02 00:10:45
# episode : 12 | final step : 99 | total reward : -1.0
# 2020/10/02 00:10:48
# episode : 13 | final step : 98 | total reward : -2.0
# 2020/10/02 00:10:51
# episode : 14 | final step : 97 | total reward : 98.0
# 2020/10/02 00:10:54
# episode : 15 | final step : 96 | total reward : 97.0
# 2020/10/02 00:10:58
# episode : 16 | final step : 98 | total reward : 99.0
# 2020/10/02 00:11:01
# episode : 17 | final step : 98 | total reward : 99.0
# 2020/10/02 00:11:04
# episode : 18 | final step : 99 | total reward : 100.0
# 2020/10/02 00:11:07
# episode : 19 | final step : 99 | total reward : -1.0
# 2020/10/02 00:11:10
# episode : 20 | final step : 98 | total reward : -2.0
# 2020/10/02 00:11:13
# episode : 21 | final step : 98 | total reward : -2.0
# 2020/10/02 00:11:16
# episode : 22 | final step : 99 | total reward : -1.0
# 2020/10/02 00:11:19
# episode : 23 | final step : 98 | total reward : -2.0
# 2020/10/02 00:11:23
# episode : 24 | final step : 98 | total reward : 99.0
# 2020/10/02 00:11:26
# episode : 25 | final step : 100 | total reward : 0.0
# 2020/10/02 00:11:29
# episode : 26 | final step : 98 | total reward : 99.0
# 2020/10/02 00:11:32
# episode : 27 | final step : 100 | total reward : 101.0
# 2020/10/02 00:11:35
# episode : 28 | final step : 98 | total reward : -2.0
# 2020/10/02 00:11:39
# episode : 29 | final step : 100 | total reward : 0.0
# 2020/10/02 00:11:42
# episode : 30 | final step : 98 | total reward : -2.0
# 2020/10/02 00:11:45
# episode : 31 | final step : 99 | total reward : 100.0
# 2020/10/02 00:11:48
# episode : 32 | final step : 98 | total reward : -2.0
# 2020/10/02 00:11:51
# episode : 33 | final step : 100 | total reward : 101.0
# 2020/10/02 00:11:54
# episode : 34 | final step : 98 | total reward : -2.0
# 2020/10/02 00:11:58
# episode : 35 | final step : 98 | total reward : 99.0
# 2020/10/02 00:12:01
# episode : 36 | final step : 99 | total reward : -1.0
# 2020/10/02 00:12:04
# episode : 37 | final step : 97 | total reward : -3.0
# 2020/10/02 00:12:07
# episode : 38 | final step : 99 | total reward : -1.0
# 2020/10/02 00:12:11
# episode : 39 | final step : 97 | total reward : -3.0
# 2020/10/02 00:12:14
# episode : 40 | final step : 95 | total reward : 96.0
# 2020/10/02 00:12:17
# episode : 41 | final step : 98 | total reward : -2.0
# 2020/10/02 00:12:20
# episode : 42 | final step : 98 | total reward : -2.0
# 2020/10/02 00:12:23
# episode : 43 | final step : 99 | total reward : -1.0
# 2020/10/02 00:12:26
# episode : 44 | final step : 98 | total reward : -2.0
# 2020/10/02 00:12:29
# episode : 45 | final step : 96 | total reward : 97.0
# 2020/10/02 00:12:32
# episode : 46 | final step : 99 | total reward : -1.0
# 2020/10/02 00:12:36
# episode : 47 | final step : 98 | total reward : -2.0
# 2020/10/02 00:12:39
# episode : 48 | final step : 98 | total reward : -2.0
# 2020/10/02 00:12:42
# episode : 49 | final step : 98 | total reward : -2.0
# 2020/10/02 00:12:45
# episode : 50 | final step : 100 | total reward : 0.0
# 2020/10/02 00:12:48
# episode : 51 | final step : 98 | total reward : -2.0
# 2020/10/02 00:12:52
# episode : 52 | final step : 97 | total reward : 98.0
# 2020/10/02 00:12:55
# episode : 53 | final step : 98 | total reward : -2.0
# 2020/10/02 00:12:58
# episode : 54 | final step : 96 | total reward : 97.0
# 2020/10/02 00:13:01
# episode : 55 | final step : 99 | total reward : -1.0
# 2020/10/02 00:13:04
# episode : 56 | final step : 99 | total reward : -1.0
# 2020/10/02 00:13:07
# episode : 57 | final step : 97 | total reward : 98.0
# 2020/10/02 00:13:10
# episode : 58 | final step : 96 | total reward : 97.0
# 2020/10/02 00:13:13
# episode : 59 | final step : 97 | total reward : 98.0
# 2020/10/02 00:13:16
# episode : 60 | final step : 98 | total reward : -2.0
# 2020/10/02 00:13:19
# episode : 61 | final step : 97 | total reward : 98.0
# 2020/10/02 00:13:23
# episode : 62 | final step : 97 | total reward : -3.0
# 2020/10/02 00:13:26
# episode : 63 | final step : 99 | total reward : -1.0
# 2020/10/02 00:13:29
# episode : 64 | final step : 97 | total reward : 98.0
# 2020/10/02 00:13:32
# episode : 65 | final step : 100 | total reward : 101.0
# 2020/10/02 00:13:35
# episode : 66 | final step : 99 | total reward : -1.0
# 2020/10/02 00:13:38
# episode : 67 | final step : 98 | total reward : -2.0
# 2020/10/02 00:13:42
# episode : 68 | final step : 100 | total reward : 101.0
# 2020/10/02 00:13:45
# episode : 69 | final step : 95 | total reward : 96.0
# 2020/10/02 00:13:48
# episode : 70 | final step : 98 | total reward : -2.0
# 2020/10/02 00:13:51
# episode : 71 | final step : 98 | total reward : -2.0
# 2020/10/02 00:13:54
# episode : 72 | final step : 99 | total reward : -1.0
# 2020/10/02 00:13:57
# episode : 73 | final step : 99 | total reward : 100.0
# 2020/10/02 00:14:00
# episode : 74 | final step : 99 | total reward : 100.0
# 2020/10/02 00:14:03
# episode : 75 | final step : 99 | total reward : -1.0
# 2020/10/02 00:14:07
# episode : 76 | final step : 97 | total reward : 98.0
# 2020/10/02 00:14:10
# episode : 77 | final step : 99 | total reward : 100.0
# 2020/10/02 00:14:13
# episode : 78 | final step : 98 | total reward : -2.0
# 2020/10/02 00:14:16
# episode : 79 | final step : 98 | total reward : -2.0
# 2020/10/02 00:14:19
# episode : 80 | final step : 98 | total reward : -2.0
# 2020/10/02 00:14:22
# episode : 81 | final step : 98 | total reward : -2.0
# 2020/10/02 00:14:25
# episode : 82 | final step : 97 | total reward : 98.0
# 2020/10/02 00:14:29
# episode : 83 | final step : 102 | total reward : 103.0
# 2020/10/02 00:14:32
# episode : 84 | final step : 98 | total reward : -2.0
# 2020/10/02 00:14:35
# episode : 85 | final step : 102 | total reward : 103.0
# 2020/10/02 00:14:38
# episode : 86 | final step : 98 | total reward : -2.0
# 2020/10/02 00:14:41
# episode : 87 | final step : 99 | total reward : 100.0
# 2020/10/02 00:14:44
# episode : 88 | final step : 98 | total reward : -2.0
# 2020/10/02 00:14:48
# episode : 89 | final step : 99 | total reward : -1.0
# 2020/10/02 00:14:51
# episode : 90 | final step : 98 | total reward : -2.0
# 2020/10/02 00:14:54
# episode : 91 | final step : 98 | total reward : -2.0
# 2020/10/02 00:14:57
# episode : 92 | final step : 100 | total reward : 101.0
# 2020/10/02 00:15:01
# episode : 93 | final step : 102 | total reward : 103.0
# 2020/10/02 00:15:04
# episode : 94 | final step : 98 | total reward : -2.0
# 2020/10/02 00:15:07
# episode : 95 | final step : 99 | total reward : 100.0
# 2020/10/02 00:15:10
# episode : 96 | final step : 99 | total reward : -1.0
# 2020/10/02 00:15:13
# episode : 97 | final step : 98 | total reward : -2.0
# 2020/10/02 00:15:16
# episode : 98 | final step : 97 | total reward : 98.0
# 2020/10/02 00:15:19
# episode : 99 | final step : 98 | total reward : -2.0
# 2020/10/02 00:15:23
# episode : 100 | final step : 99 | total reward : -1.0
# 2020/10/02 00:15:26
# episode : 101 | final step : 100 | total reward : 0.0
# 2020/10/02 00:15:29
# episode : 102 | final step : 99 | total reward : -1.0
# 2020/10/02 00:15:32
# episode : 103 | final step : 98 | total reward : 99.0
# 2020/10/02 00:15:35
# episode : 104 | final step : 99 | total reward : -1.0
# 2020/10/02 00:15:38
# episode : 105 | final step : 99 | total reward : -1.0
# 2020/10/02 00:15:41
# episode : 106 | final step : 98 | total reward : -2.0
# 2020/10/02 00:15:45
# episode : 107 | final step : 98 | total reward : -2.0
# 2020/10/02 00:15:48
# episode : 108 | final step : 99 | total reward : 100.0
# 2020/10/02 00:15:51
# episode : 109 | final step : 96 | total reward : 97.0
# 2020/10/02 00:15:54
# episode : 110 | final step : 99 | total reward : -1.0
# 2020/10/02 00:15:57
# episode : 111 | final step : 98 | total reward : 99.0
# 2020/10/02 00:16:00
# episode : 112 | final step : 98 | total reward : 99.0
# 2020/10/02 00:16:04
# episode : 113 | final step : 98 | total reward : -2.0
# 2020/10/02 00:16:07
# episode : 114 | final step : 99 | total reward : 100.0
# 2020/10/02 00:16:10
# episode : 115 | final step : 99 | total reward : -1.0
# 2020/10/02 00:16:13
# episode : 116 | final step : 99 | total reward : -1.0
# 2020/10/02 00:16:16
# episode : 117 | final step : 99 | total reward : -1.0
# 2020/10/02 00:16:20
# episode : 118 | final step : 99 | total reward : -1.0
# 2020/10/02 00:16:23
# episode : 119 | final step : 97 | total reward : -3.0
# 2020/10/02 00:16:26
# episode : 120 | final step : 100 | total reward : 101.0
# 2020/10/02 00:16:29
# episode : 121 | final step : 99 | total reward : -1.0
# 2020/10/02 00:16:32
# episode : 122 | final step : 98 | total reward : 99.0
# 2020/10/02 00:16:35
# episode : 123 | final step : 102 | total reward : 103.0
# 2020/10/02 00:16:39
# episode : 124 | final step : 99 | total reward : 100.0
# 2020/10/02 00:16:42
# episode : 125 | final step : 98 | total reward : -2.0
# 2020/10/02 00:16:45
# episode : 126 | final step : 100 | total reward : 101.0
# 2020/10/02 00:16:48
# episode : 127 | final step : 98 | total reward : -2.0
# 2020/10/02 00:16:51
# episode : 128 | final step : 98 | total reward : -2.0
# 2020/10/02 00:16:54
# episode : 129 | final step : 99 | total reward : 100.0
# 2020/10/02 00:16:57
# episode : 130 | final step : 100 | total reward : 101.0
# 2020/10/02 00:17:01
# episode : 131 | final step : 99 | total reward : 100.0
# 2020/10/02 00:17:04
# episode : 132 | final step : 98 | total reward : -2.0
# 2020/10/02 00:17:07
# episode : 133 | final step : 98 | total reward : -2.0
# 2020/10/02 00:17:10
# episode : 134 | final step : 96 | total reward : 97.0
# 2020/10/02 00:17:13
# episode : 135 | final step : 101 | total reward : 102.0
# 2020/10/02 00:17:16
# episode : 136 | final step : 99 | total reward : -1.0
# 2020/10/02 00:17:19
# episode : 137 | final step : 99 | total reward : -1.0
# 2020/10/02 00:17:23
# episode : 138 | final step : 98 | total reward : -2.0
# 2020/10/02 00:17:26
# episode : 139 | final step : 99 | total reward : -1.0
# 2020/10/02 00:17:29
# episode : 140 | final step : 99 | total reward : -1.0
# 2020/10/02 00:17:32
# episode : 141 | final step : 102 | total reward : 103.0
# 2020/10/02 00:17:35
# episode : 142 | final step : 97 | total reward : 98.0
# 2020/10/02 00:17:38
# episode : 143 | final step : 98 | total reward : -2.0
# 2020/10/02 00:17:42
# episode : 144 | final step : 100 | total reward : 0.0
# 2020/10/02 00:17:45
# episode : 145 | final step : 98 | total reward : -2.0
# 2020/10/02 00:17:48
# episode : 146 | final step : 98 | total reward : -2.0
# 2020/10/02 00:17:51
# episode : 147 | final step : 98 | total reward : -2.0
# 2020/10/02 00:17:54
# episode : 148 | final step : 97 | total reward : -3.0
# 2020/10/02 00:17:57
# episode : 149 | final step : 98 | total reward : -2.0
# 2020/10/02 00:18:01
# episode : 150 | final step : 99 | total reward : -1.0
# 2020/10/02 00:18:04
# episode : 151 | final step : 97 | total reward : -3.0
# 2020/10/02 00:18:07
# episode : 152 | final step : 98 | total reward : -2.0
# 2020/10/02 00:18:10
# episode : 153 | final step : 99 | total reward : 100.0
# 2020/10/02 00:18:13
# episode : 154 | final step : 99 | total reward : 100.0
# 2020/10/02 00:18:16
# episode : 155 | final step : 99 | total reward : -1.0
# 2020/10/02 00:18:19
# episode : 156 | final step : 99 | total reward : 100.0
# 2020/10/02 00:18:23
# episode : 157 | final step : 99 | total reward : 100.0
# 2020/10/02 00:18:26
# episode : 158 | final step : 98 | total reward : -2.0
# 2020/10/02 00:18:29
# episode : 159 | final step : 98 | total reward : -2.0
# 2020/10/02 00:18:32
# episode : 160 | final step : 99 | total reward : -1.0
# 2020/10/02 00:18:35
# episode : 161 | final step : 100 | total reward : 101.0
# 2020/10/02 00:18:39
# episode : 162 | final step : 99 | total reward : -1.0
# 2020/10/02 00:18:42
# episode : 163 | final step : 98 | total reward : -2.0
# 2020/10/02 00:18:45
# episode : 164 | final step : 98 | total reward : -2.0
# 2020/10/02 00:18:48
# episode : 165 | final step : 99 | total reward : 100.0
# 2020/10/02 00:18:51
# episode : 166 | final step : 98 | total reward : -2.0
# 2020/10/02 00:18:55
# episode : 167 | final step : 98 | total reward : -2.0
# 2020/10/02 00:18:58
# episode : 168 | final step : 99 | total reward : 100.0
# 2020/10/02 00:19:01
# episode : 169 | final step : 99 | total reward : -1.0
# 2020/10/02 00:19:04
# episode : 170 | final step : 98 | total reward : 99.0
# 2020/10/02 00:19:07
# episode : 171 | final step : 97 | total reward : 98.0
# 2020/10/02 00:19:10
# episode : 172 | final step : 99 | total reward : -1.0
# 2020/10/02 00:19:13
# episode : 173 | final step : 98 | total reward : -2.0
# 2020/10/02 00:19:16
# episode : 174 | final step : 98 | total reward : -2.0
# 2020/10/02 00:19:20
# episode : 175 | final step : 98 | total reward : -2.0
# 2020/10/02 00:19:23
# episode : 176 | final step : 98 | total reward : -2.0
# 2020/10/02 00:19:26
# episode : 177 | final step : 97 | total reward : 98.0
# 2020/10/02 00:19:29
# episode : 178 | final step : 96 | total reward : 97.0
# 2020/10/02 00:19:32
# episode : 179 | final step : 99 | total reward : -1.0
# 2020/10/02 00:19:35
# episode : 180 | final step : 98 | total reward : 99.0
# 2020/10/02 00:19:38
# episode : 181 | final step : 98 | total reward : -2.0
# 2020/10/02 00:19:41
# episode : 182 | final step : 98 | total reward : -2.0
# 2020/10/02 00:19:44
# episode : 183 | final step : 99 | total reward : -1.0
# 2020/10/02 00:19:48
# episode : 184 | final step : 98 | total reward : -2.0
# 2020/10/02 00:19:51
# episode : 185 | final step : 99 | total reward : -1.0
# 2020/10/02 00:19:54
# episode : 186 | final step : 94 | total reward : 95.0
# 2020/10/02 00:19:57
# episode : 187 | final step : 98 | total reward : -2.0
# 2020/10/02 00:20:00
# episode : 188 | final step : 98 | total reward : -2.0
# 2020/10/02 00:20:04
# episode : 189 | final step : 99 | total reward : -1.0
# 2020/10/02 00:20:07
# episode : 190 | final step : 99 | total reward : 100.0
# 2020/10/02 00:20:10
# episode : 191 | final step : 97 | total reward : 98.0
# 2020/10/02 00:20:13
# episode : 192 | final step : 98 | total reward : -2.0
# 2020/10/02 00:20:16
# episode : 193 | final step : 100 | total reward : 101.0
# 2020/10/02 00:20:19
# episode : 194 | final step : 98 | total reward : -2.0
# 2020/10/02 00:20:23
# episode : 195 | final step : 98 | total reward : -2.0
# 2020/10/02 00:20:26
# episode : 196 | final step : 99 | total reward : 100.0
# 2020/10/02 00:20:29
# episode : 197 | final step : 98 | total reward : -2.0
# 2020/10/02 00:20:32
# episode : 198 | final step : 98 | total reward : -2.0
# 2020/10/02 00:20:35
# episode : 199 | final step : 99 | total reward : -1.0
# 2020/10/02 00:20:38
# episode : 200 | final step : 98 | total reward : -2.0
# 2020/10/02 00:20:41
# episode : 201 | final step : 98 | total reward : 99.0
# 2020/10/02 00:20:44
# episode : 202 | final step : 99 | total reward : 100.0
# 2020/10/02 00:20:48
# episode : 203 | final step : 99 | total reward : -1.0
# 2020/10/02 00:20:51
# episode : 204 | final step : 98 | total reward : -2.0
# 2020/10/02 00:20:54
# episode : 205 | final step : 98 | total reward : -2.0
# 2020/10/02 00:20:57
# episode : 206 | final step : 99 | total reward : 100.0
# 2020/10/02 00:21:00
# episode : 207 | final step : 98 | total reward : 99.0
# 2020/10/02 00:21:03
# episode : 208 | final step : 99 | total reward : -1.0
# 2020/10/02 00:21:06
# episode : 209 | final step : 99 | total reward : -1.0
# 2020/10/02 00:21:10
# episode : 210 | final step : 98 | total reward : -2.0
# 2020/10/02 00:21:13
# episode : 211 | final step : 98 | total reward : -2.0
# 2020/10/02 00:21:16
# episode : 212 | final step : 98 | total reward : -2.0
# 2020/10/02 00:21:19
# episode : 213 | final step : 98 | total reward : -2.0
# 2020/10/02 00:21:22
# episode : 214 | final step : 99 | total reward : -1.0
# 2020/10/02 00:21:25
# episode : 215 | final step : 99 | total reward : -1.0
# 2020/10/02 00:21:29
# episode : 216 | final step : 96 | total reward : 97.0
# 2020/10/02 00:21:32
# episode : 217 | final step : 98 | total reward : 99.0
# 2020/10/02 00:21:35
# episode : 218 | final step : 98 | total reward : 99.0
# 2020/10/02 00:21:38
# episode : 219 | final step : 100 | total reward : 0.0
# 2020/10/02 00:21:41
# episode : 220 | final step : 97 | total reward : 98.0
# 2020/10/02 00:21:44
# episode : 221 | final step : 99 | total reward : -1.0
# 2020/10/02 00:21:47
# episode : 222 | final step : 99 | total reward : -1.0
# 2020/10/02 00:21:51
# episode : 223 | final step : 98 | total reward : -2.0
# 2020/10/02 00:21:54
# episode : 224 | final step : 99 | total reward : 100.0
# 2020/10/02 00:21:57
# episode : 225 | final step : 101 | total reward : 102.0
# 2020/10/02 00:22:00
# episode : 226 | final step : 98 | total reward : -2.0
# 2020/10/02 00:22:03
# episode : 227 | final step : 98 | total reward : -2.0
# 2020/10/02 00:22:06
# episode : 228 | final step : 98 | total reward : -2.0
# 2020/10/02 00:22:10
# episode : 229 | final step : 98 | total reward : -2.0
# 2020/10/02 00:22:13
# episode : 230 | final step : 98 | total reward : -2.0
# 2020/10/02 00:22:16
# episode : 231 | final step : 98 | total reward : -2.0
# 2020/10/02 00:22:19
# episode : 232 | final step : 99 | total reward : -1.0
# 2020/10/02 00:22:22
# episode : 233 | final step : 98 | total reward : 99.0
# 2020/10/02 00:22:25
# episode : 234 | final step : 97 | total reward : 98.0
# 2020/10/02 00:22:29
# episode : 235 | final step : 97 | total reward : 98.0
# 2020/10/02 00:22:32
# episode : 236 | final step : 98 | total reward : -2.0
# 2020/10/02 00:22:35
# episode : 237 | final step : 99 | total reward : -1.0
# 2020/10/02 00:22:38
# episode : 238 | final step : 99 | total reward : -1.0
# 2020/10/02 00:22:41
# episode : 239 | final step : 97 | total reward : 98.0
# 2020/10/02 00:22:44
# episode : 240 | final step : 99 | total reward : 100.0
# 2020/10/02 00:22:48
# episode : 241 | final step : 99 | total reward : -1.0
# 2020/10/02 00:22:51
# episode : 242 | final step : 100 | total reward : 101.0
# 2020/10/02 00:22:54
# episode : 243 | final step : 98 | total reward : 99.0
# 2020/10/02 00:22:57
# episode : 244 | final step : 100 | total reward : 0.0
# 2020/10/02 00:23:01
# episode : 245 | final step : 97 | total reward : 98.0
# 2020/10/02 00:23:04
# episode : 246 | final step : 98 | total reward : -2.0
# 2020/10/02 00:23:07
# episode : 247 | final step : 96 | total reward : 97.0
# 2020/10/02 00:23:10
# episode : 248 | final step : 98 | total reward : -2.0
# 2020/10/02 00:23:13
# episode : 249 | final step : 95 | total reward : 96.0
# 2020/10/02 00:23:16
# episode : 250 | final step : 98 | total reward : 99.0
# 2020/10/02 00:23:19
# episode : 251 | final step : 100 | total reward : 101.0
# 2020/10/02 00:23:23
# episode : 252 | final step : 98 | total reward : -2.0
# 2020/10/02 00:23:26
# episode : 253 | final step : 98 | total reward : -2.0
# 2020/10/02 00:23:29
# episode : 254 | final step : 101 | total reward : 102.0
# 2020/10/02 00:23:32
# episode : 255 | final step : 98 | total reward : -2.0
# 2020/10/02 00:23:35
# episode : 256 | final step : 98 | total reward : -2.0
# 2020/10/02 00:23:39
# episode : 257 | final step : 98 | total reward : 99.0
# 2020/10/02 00:23:42
# episode : 258 | final step : 100 | total reward : 101.0
# 2020/10/02 00:23:45
# episode : 259 | final step : 98 | total reward : -2.0
# 2020/10/02 00:23:48
# episode : 260 | final step : 98 | total reward : -2.0
# 2020/10/02 00:23:51
# episode : 261 | final step : 98 | total reward : -2.0
# 2020/10/02 00:23:54
# episode : 262 | final step : 98 | total reward : -2.0
# 2020/10/02 00:23:58
# episode : 263 | final step : 98 | total reward : -2.0
# 2020/10/02 00:24:01
# episode : 264 | final step : 99 | total reward : -1.0
# 2020/10/02 00:24:04
# episode : 265 | final step : 97 | total reward : 98.0
# 2020/10/02 00:24:07
# episode : 266 | final step : 100 | total reward : 101.0
# 2020/10/02 00:24:10
# episode : 267 | final step : 99 | total reward : -1.0
# 2020/10/02 00:24:13
# episode : 268 | final step : 99 | total reward : 100.0
# 2020/10/02 00:24:17
# episode : 269 | final step : 98 | total reward : -2.0
# 2020/10/02 00:24:20
# episode : 270 | final step : 97 | total reward : 98.0
# 2020/10/02 00:24:23
# episode : 271 | final step : 98 | total reward : -2.0
# 2020/10/02 00:24:26
# episode : 272 | final step : 99 | total reward : -1.0
# 2020/10/02 00:24:29
# episode : 273 | final step : 98 | total reward : -2.0
# 2020/10/02 00:24:32
# episode : 274 | final step : 100 | total reward : 101.0
# 2020/10/02 00:24:35
# episode : 275 | final step : 98 | total reward : -2.0
# 2020/10/02 00:24:39
# episode : 276 | final step : 100 | total reward : 101.0
# 2020/10/02 00:24:42
# episode : 277 | final step : 99 | total reward : 100.0
# 2020/10/02 00:24:45
# episode : 278 | final step : 98 | total reward : -2.0
# 2020/10/02 00:24:48
# episode : 279 | final step : 99 | total reward : 100.0
# 2020/10/02 00:24:51
# episode : 280 | final step : 98 | total reward : -2.0
# 2020/10/02 00:24:55
# episode : 281 | final step : 98 | total reward : -2.0
# 2020/10/02 00:24:58
# episode : 282 | final step : 98 | total reward : -2.0
# 2020/10/02 00:25:01
# episode : 283 | final step : 96 | total reward : 97.0
# 2020/10/02 00:25:04
# episode : 284 | final step : 99 | total reward : 100.0
# 2020/10/02 00:25:07
# episode : 285 | final step : 98 | total reward : -2.0
# 2020/10/02 00:25:10
# episode : 286 | final step : 98 | total reward : 99.0
# 2020/10/02 00:25:14
# episode : 287 | final step : 99 | total reward : -1.0
# 2020/10/02 00:25:17
# episode : 288 | final step : 98 | total reward : -2.0
# 2020/10/02 00:25:20
# episode : 289 | final step : 98 | total reward : -2.0
# 2020/10/02 00:25:23
# episode : 290 | final step : 98 | total reward : -2.0
# 2020/10/02 00:25:26
# episode : 291 | final step : 99 | total reward : 100.0
# 2020/10/02 00:25:30
# episode : 292 | final step : 98 | total reward : -2.0
# 2020/10/02 00:25:33
# episode : 293 | final step : 97 | total reward : 98.0
# 2020/10/02 00:25:36
# episode : 294 | final step : 100 | total reward : 0.0
# 2020/10/02 00:25:39
# episode : 295 | final step : 98 | total reward : -2.0
# 2020/10/02 00:25:42
# episode : 296 | final step : 98 | total reward : -2.0
# 2020/10/02 00:25:45
# episode : 297 | final step : 98 | total reward : -2.0
# 2020/10/02 00:25:48
# episode : 298 | final step : 97 | total reward : 98.0
# 2020/10/02 00:25:52
# episode : 299 | final step : 100 | total reward : 101.0
# 2020/10/02 00:25:55
# episode : 300 | final step : 99 | total reward : -1.0
# 2020/10/02 00:25:58
# episode : 301 | final step : 98 | total reward : -2.0
# 2020/10/02 00:26:01
# episode : 302 | final step : 98 | total reward : -2.0
# 2020/10/02 00:26:04
# episode : 303 | final step : 98 | total reward : -2.0
# 2020/10/02 00:26:07
# episode : 304 | final step : 100 | total reward : 0.0
# 2020/10/02 00:26:10
# episode : 305 | final step : 96 | total reward : 97.0
# 2020/10/02 00:26:13
# episode : 306 | final step : 97 | total reward : 98.0
# 2020/10/02 00:26:17
# episode : 307 | final step : 99 | total reward : -1.0
# 2020/10/02 00:26:20
# episode : 308 | final step : 99 | total reward : -1.0
# 2020/10/02 00:26:23
# episode : 309 | final step : 98 | total reward : -2.0
# 2020/10/02 00:26:27
# episode : 310 | final step : 98 | total reward : -2.0
# 2020/10/02 00:26:30
# episode : 311 | final step : 99 | total reward : -1.0
# 2020/10/02 00:26:33
# episode : 312 | final step : 99 | total reward : 100.0
# 2020/10/02 00:26:36
# episode : 313 | final step : 99 | total reward : -1.0
# 2020/10/02 00:26:39
# episode : 314 | final step : 99 | total reward : -1.0
# 2020/10/02 00:26:42
# episode : 315 | final step : 98 | total reward : 99.0
# 2020/10/02 00:26:46
# episode : 316 | final step : 98 | total reward : -2.0
# 2020/10/02 00:26:49
# episode : 317 | final step : 98 | total reward : -2.0
# 2020/10/02 00:26:52
# episode : 318 | final step : 98 | total reward : -2.0
# 2020/10/02 00:26:55
# episode : 319 | final step : 98 | total reward : -2.0
# 2020/10/02 00:26:58
# episode : 320 | final step : 98 | total reward : -2.0
# 2020/10/02 00:27:01
# episode : 321 | final step : 100 | total reward : 101.0
# 2020/10/02 00:27:05
# episode : 322 | final step : 99 | total reward : -1.0
# 2020/10/02 00:27:08
# episode : 323 | final step : 100 | total reward : 101.0
# 2020/10/02 00:27:11
# episode : 324 | final step : 99 | total reward : -1.0
# 2020/10/02 00:27:14
# episode : 325 | final step : 98 | total reward : -2.0
# 2020/10/02 00:27:18
# episode : 326 | final step : 99 | total reward : 100.0
# 2020/10/02 00:27:21
# episode : 327 | final step : 98 | total reward : -2.0
# 2020/10/02 00:27:24
# episode : 328 | final step : 99 | total reward : -1.0
# 2020/10/02 00:27:27
# episode : 329 | final step : 101 | total reward : 102.0
# 2020/10/02 00:27:30
# episode : 330 | final step : 98 | total reward : -2.0
# 2020/10/02 00:27:33
# episode : 331 | final step : 99 | total reward : -1.0
# 2020/10/02 00:27:36
# episode : 332 | final step : 99 | total reward : -1.0
# 2020/10/02 00:27:40
# episode : 333 | final step : 98 | total reward : -2.0
# 2020/10/02 00:27:43
# episode : 334 | final step : 97 | total reward : 98.0
# 2020/10/02 00:27:46
# episode : 335 | final step : 98 | total reward : -2.0
# 2020/10/02 00:27:49
# episode : 336 | final step : 99 | total reward : -1.0
# 2020/10/02 00:27:52
# episode : 337 | final step : 98 | total reward : -2.0
# 2020/10/02 00:27:55
# episode : 338 | final step : 98 | total reward : -2.0
# 2020/10/02 00:27:58
# episode : 339 | final step : 99 | total reward : -1.0
# 2020/10/02 00:28:02
# episode : 340 | final step : 98 | total reward : -2.0
# 2020/10/02 00:28:05
# episode : 341 | final step : 99 | total reward : -1.0
# 2020/10/02 00:28:08
# episode : 342 | final step : 102 | total reward : 103.0
# 2020/10/02 00:28:11
# episode : 343 | final step : 98 | total reward : -2.0
# 2020/10/02 00:28:15
# episode : 344 | final step : 99 | total reward : 100.0
# 2020/10/02 00:28:18
# episode : 345 | final step : 98 | total reward : 99.0
# 2020/10/02 00:28:21
# episode : 346 | final step : 101 | total reward : 102.0
# 2020/10/02 00:28:24
# episode : 347 | final step : 100 | total reward : 0.0
# 2020/10/02 00:28:27
# episode : 348 | final step : 99 | total reward : -1.0
# 2020/10/02 00:28:30
# episode : 349 | final step : 98 | total reward : -2.0
# 2020/10/02 00:28:34
# episode : 350 | final step : 97 | total reward : -3.0
# 2020/10/02 00:28:37
# episode : 351 | final step : 99 | total reward : -1.0
# 2020/10/02 00:28:40
# episode : 352 | final step : 98 | total reward : 99.0
# 2020/10/02 00:28:43
# episode : 353 | final step : 100 | total reward : 101.0
# 2020/10/02 00:28:47
# episode : 354 | final step : 100 | total reward : 0.0
# 2020/10/02 00:28:50
# episode : 355 | final step : 100 | total reward : 0.0
# 2020/10/02 00:28:53
# episode : 356 | final step : 100 | total reward : 101.0
# 2020/10/02 00:28:56
# episode : 357 | final step : 97 | total reward : 98.0
# 2020/10/02 00:28:59
# episode : 358 | final step : 97 | total reward : 98.0
# 2020/10/02 00:29:02
# episode : 359 | final step : 98 | total reward : 99.0
# 2020/10/02 00:29:05
# episode : 360 | final step : 98 | total reward : -2.0
# 2020/10/02 00:29:09
# episode : 361 | final step : 99 | total reward : -1.0
# 2020/10/02 00:29:12
# episode : 362 | final step : 102 | total reward : 103.0
# 2020/10/02 00:29:15
# episode : 363 | final step : 98 | total reward : -2.0
# 2020/10/02 00:29:18
# episode : 364 | final step : 99 | total reward : -1.0
# 2020/10/02 00:29:22
# episode : 365 | final step : 98 | total reward : -2.0
# 2020/10/02 00:29:25
# episode : 366 | final step : 99 | total reward : 100.0
# 2020/10/02 00:29:28
# episode : 367 | final step : 99 | total reward : 100.0
# 2020/10/02 00:29:31
# episode : 368 | final step : 98 | total reward : -2.0
# 2020/10/02 00:29:34
# episode : 369 | final step : 98 | total reward : -2.0
# 2020/10/02 00:29:37
# episode : 370 | final step : 99 | total reward : 100.0
# 2020/10/02 00:29:40
# episode : 371 | final step : 98 | total reward : 99.0
# 2020/10/02 00:29:44
# episode : 372 | final step : 98 | total reward : 99.0
# 2020/10/02 00:29:47
# episode : 373 | final step : 100 | total reward : 101.0
# 2020/10/02 00:29:50
# episode : 374 | final step : 98 | total reward : -2.0
# 2020/10/02 00:29:53
# episode : 375 | final step : 99 | total reward : -1.0
# 2020/10/02 00:29:56
# episode : 376 | final step : 98 | total reward : -2.0
# 2020/10/02 00:29:59
# episode : 377 | final step : 98 | total reward : -2.0
# 2020/10/02 00:30:02
# episode : 378 | final step : 100 | total reward : 101.0
# 2020/10/02 00:30:06
# episode : 379 | final step : 99 | total reward : -1.0
# 2020/10/02 00:30:09
# episode : 380 | final step : 97 | total reward : 98.0
# 2020/10/02 00:30:12
# episode : 381 | final step : 98 | total reward : -2.0
# 2020/10/02 00:30:15
# episode : 382 | final step : 99 | total reward : -1.0
# 2020/10/02 00:30:18
# episode : 383 | final step : 98 | total reward : -2.0
# 2020/10/02 00:30:21
# episode : 384 | final step : 98 | total reward : -2.0
# 2020/10/02 00:30:25
# episode : 385 | final step : 100 | total reward : 101.0
# 2020/10/02 00:30:28
# episode : 386 | final step : 97 | total reward : 98.0
# 2020/10/02 00:30:31
# episode : 387 | final step : 98 | total reward : -2.0
# 2020/10/02 00:30:34
# episode : 388 | final step : 98 | total reward : -2.0
# 2020/10/02 00:30:37
# episode : 389 | final step : 99 | total reward : -1.0
# 2020/10/02 00:30:41
# episode : 390 | final step : 98 | total reward : -2.0
# 2020/10/02 00:30:44
# episode : 391 | final step : 98 | total reward : -2.0
# 2020/10/02 00:30:47
# episode : 392 | final step : 98 | total reward : -2.0
# 2020/10/02 00:30:50
# episode : 393 | final step : 98 | total reward : 99.0
# 2020/10/02 00:30:53
# episode : 394 | final step : 98 | total reward : -2.0
# 2020/10/02 00:30:56
# episode : 395 | final step : 98 | total reward : -2.0
# 2020/10/02 00:31:00
# episode : 396 | final step : 99 | total reward : -1.0
# 2020/10/02 00:31:03
# episode : 397 | final step : 99 | total reward : -1.0
# 2020/10/02 00:31:06
# episode : 398 | final step : 101 | total reward : 102.0
# 2020/10/02 00:31:09
# episode : 399 | final step : 97 | total reward : 98.0
# 2020/10/02 00:31:13
# episode : 400 | final step : 98 | total reward : -2.0
# 2020/10/02 00:31:16
# episode : 401 | final step : 98 | total reward : -2.0
# 2020/10/02 00:31:19
# episode : 402 | final step : 98 | total reward : -2.0
# 2020/10/02 00:31:22
# episode : 403 | final step : 99 | total reward : 100.0
# 2020/10/02 00:31:25
# episode : 404 | final step : 98 | total reward : -2.0
# 2020/10/02 00:31:28
# episode : 405 | final step : 98 | total reward : -2.0
# 2020/10/02 00:31:31
# episode : 406 | final step : 99 | total reward : 100.0
# 2020/10/02 00:31:35
# episode : 407 | final step : 98 | total reward : -2.0
# 2020/10/02 00:31:38
# episode : 408 | final step : 98 | total reward : -2.0
# 2020/10/02 00:31:41
# episode : 409 | final step : 101 | total reward : 102.0
# 2020/10/02 00:31:44
# episode : 410 | final step : 98 | total reward : -2.0
# 2020/10/02 00:31:47
# episode : 411 | final step : 98 | total reward : 99.0
# 2020/10/02 00:31:51
# episode : 412 | final step : 98 | total reward : -2.0
# 2020/10/02 00:31:54
# episode : 413 | final step : 98 | total reward : -2.0
# 2020/10/02 00:31:57
# episode : 414 | final step : 100 | total reward : 0.0
# 2020/10/02 00:32:00
# episode : 415 | final step : 98 | total reward : -2.0
# 2020/10/02 00:32:03
# episode : 416 | final step : 98 | total reward : -2.0
# 2020/10/02 00:32:06
# episode : 417 | final step : 98 | total reward : -2.0
# 2020/10/02 00:32:10
# episode : 418 | final step : 97 | total reward : 98.0
# 2020/10/02 00:32:13
# episode : 419 | final step : 98 | total reward : -2.0
# 2020/10/02 00:32:16
# episode : 420 | final step : 95 | total reward : 96.0
# 2020/10/02 00:32:19
# episode : 421 | final step : 98 | total reward : -2.0
# 2020/10/02 00:32:22
# episode : 422 | final step : 97 | total reward : 98.0
# 2020/10/02 00:32:25
# episode : 423 | final step : 98 | total reward : -2.0
# 2020/10/02 00:32:29
# episode : 424 | final step : 99 | total reward : 100.0
# 2020/10/02 00:32:32
# episode : 425 | final step : 98 | total reward : -2.0
# 2020/10/02 00:32:35
# episode : 426 | final step : 98 | total reward : -2.0
# 2020/10/02 00:32:38
# episode : 427 | final step : 99 | total reward : 100.0
# 2020/10/02 00:32:41
# episode : 428 | final step : 102 | total reward : 103.0
# 2020/10/02 00:32:44
# episode : 429 | final step : 100 | total reward : 101.0
# 2020/10/02 00:32:48
# episode : 430 | final step : 100 | total reward : 101.0
# 2020/10/02 00:32:51
# episode : 431 | final step : 98 | total reward : 99.0
# 2020/10/02 00:32:54
# episode : 432 | final step : 98 | total reward : 99.0
# 2020/10/02 00:32:57
# episode : 433 | final step : 98 | total reward : -2.0
# 2020/10/02 00:33:01
# episode : 434 | final step : 99 | total reward : 100.0
# 2020/10/02 00:33:03
# episode : 435 | final step : 96 | total reward : 97.0
# 2020/10/02 00:33:07
# episode : 436 | final step : 96 | total reward : 97.0
# 2020/10/02 00:33:10
# episode : 437 | final step : 98 | total reward : 99.0
# 2020/10/02 00:33:13
# episode : 438 | final step : 95 | total reward : 96.0
# 2020/10/02 00:33:16
# episode : 439 | final step : 100 | total reward : 0.0
# 2020/10/02 00:33:19
# episode : 440 | final step : 99 | total reward : 100.0
# 2020/10/02 00:33:22
# episode : 441 | final step : 98 | total reward : -2.0
# 2020/10/02 00:33:26
# episode : 442 | final step : 98 | total reward : 99.0
# 2020/10/02 00:33:29
# episode : 443 | final step : 99 | total reward : 100.0
# 2020/10/02 00:33:32
# episode : 444 | final step : 101 | total reward : 102.0
# 2020/10/02 00:33:35
# episode : 445 | final step : 98 | total reward : -2.0
# 2020/10/02 00:33:38
# episode : 446 | final step : 100 | total reward : 101.0
# 2020/10/02 00:33:42
# episode : 447 | final step : 100 | total reward : 0.0
# 2020/10/02 00:33:45
# episode : 448 | final step : 100 | total reward : 101.0
# 2020/10/02 00:33:48
# episode : 449 | final step : 96 | total reward : 97.0
# 2020/10/02 00:33:51
# episode : 450 | final step : 97 | total reward : 98.0
# 2020/10/02 00:33:54
# episode : 451 | final step : 100 | total reward : 101.0
# 2020/10/02 00:33:58
# episode : 452 | final step : 98 | total reward : 99.0
# 2020/10/02 00:34:01
# episode : 453 | final step : 98 | total reward : -2.0
# 2020/10/02 00:34:04
# episode : 454 | final step : 98 | total reward : -2.0
# 2020/10/02 00:34:07
# episode : 455 | final step : 97 | total reward : 98.0
# 2020/10/02 00:34:10
# episode : 456 | final step : 99 | total reward : 100.0
# 2020/10/02 00:34:13
# episode : 457 | final step : 97 | total reward : 98.0
# 2020/10/02 00:34:17
# episode : 458 | final step : 98 | total reward : -2.0
# 2020/10/02 00:34:20
# episode : 459 | final step : 101 | total reward : 102.0
# 2020/10/02 00:34:23
# episode : 460 | final step : 98 | total reward : 99.0
# 2020/10/02 00:34:26
# episode : 461 | final step : 98 | total reward : -2.0
# 2020/10/02 00:34:29
# episode : 462 | final step : 101 | total reward : 102.0
# 2020/10/02 00:34:33
# episode : 463 | final step : 98 | total reward : -2.0
# 2020/10/02 00:34:36
# episode : 464 | final step : 98 | total reward : -2.0
# 2020/10/02 00:34:39
# episode : 465 | final step : 99 | total reward : 100.0
# 2020/10/02 00:34:42
# episode : 466 | final step : 99 | total reward : 100.0
# 2020/10/02 00:34:45
# episode : 467 | final step : 98 | total reward : -2.0
# 2020/10/02 00:34:49
# episode : 468 | final step : 98 | total reward : -2.0
# 2020/10/02 00:34:52
# episode : 469 | final step : 98 | total reward : -2.0
# 2020/10/02 00:34:55
# episode : 470 | final step : 98 | total reward : -2.0
# 2020/10/02 00:34:58
# episode : 471 | final step : 98 | total reward : -2.0
# 2020/10/02 00:35:01
# episode : 472 | final step : 98 | total reward : -2.0
# 2020/10/02 00:35:04
# episode : 473 | final step : 99 | total reward : -1.0
# 2020/10/02 00:35:07
# episode : 474 | final step : 96 | total reward : 97.0
# 2020/10/02 00:35:10
# episode : 475 | final step : 93 | total reward : 94.0
# 2020/10/02 00:35:14
# episode : 476 | final step : 99 | total reward : -1.0
# 2020/10/02 00:35:17
# episode : 477 | final step : 100 | total reward : 101.0
# 2020/10/02 00:35:20
# episode : 478 | final step : 98 | total reward : -2.0
# 2020/10/02 00:35:23
# episode : 479 | final step : 97 | total reward : -3.0
# 2020/10/02 00:35:26
# episode : 480 | final step : 96 | total reward : 97.0
# 2020/10/02 00:35:29
# episode : 481 | final step : 99 | total reward : -1.0
# 2020/10/02 00:35:32
# episode : 482 | final step : 97 | total reward : 98.0
# 2020/10/02 00:35:36
# episode : 483 | final step : 97 | total reward : 98.0
# 2020/10/02 00:35:39
# episode : 484 | final step : 99 | total reward : 100.0
# 2020/10/02 00:35:42
# episode : 485 | final step : 98 | total reward : -2.0
# 2020/10/02 00:35:45
# episode : 486 | final step : 99 | total reward : -1.0
# 2020/10/02 00:35:49
# episode : 487 | final step : 99 | total reward : -1.0
# 2020/10/02 00:35:52
# episode : 488 | final step : 98 | total reward : -2.0
# 2020/10/02 00:35:55
# episode : 489 | final step : 98 | total reward : -2.0
# 2020/10/02 00:35:58
# episode : 490 | final step : 99 | total reward : 100.0
# 2020/10/02 00:36:01
# episode : 491 | final step : 98 | total reward : 99.0
# 2020/10/02 00:36:04
# episode : 492 | final step : 98 | total reward : -2.0
# 2020/10/02 00:36:07
# episode : 493 | final step : 97 | total reward : 98.0
# 2020/10/02 00:36:11
# episode : 494 | final step : 100 | total reward : 101.0
# 2020/10/02 00:36:14
# episode : 495 | final step : 98 | total reward : 99.0
# 2020/10/02 00:36:17
# episode : 496 | final step : 99 | total reward : -1.0
# 2020/10/02 00:36:20
# episode : 497 | final step : 99 | total reward : -1.0
# 2020/10/02 00:36:24
# episode : 498 | final step : 98 | total reward : -2.0
# 2020/10/02 00:36:27
# episode : 499 | final step : 98 | total reward : -2.0
# 2020/10/02 00:36:30
# episode : 500 | final step : 98 | total reward : -2.0
# 2020/10/02 00:36:33
# episode : 501 | final step : 99 | total reward : -1.0
# 2020/10/02 00:36:36
# episode : 502 | final step : 97 | total reward : 98.0
# 2020/10/02 00:36:39
# episode : 503 | final step : 99 | total reward : -1.0
# 2020/10/02 00:36:42
# episode : 504 | final step : 98 | total reward : -2.0
# 2020/10/02 00:36:46
# episode : 505 | final step : 98 | total reward : -2.0
# 2020/10/02 00:36:49
# episode : 506 | final step : 98 | total reward : -2.0
# 2020/10/02 00:36:52
# episode : 507 | final step : 98 | total reward : -2.0
# 2020/10/02 00:36:55
# episode : 508 | final step : 97 | total reward : 98.0
# 2020/10/02 00:36:58
# episode : 509 | final step : 98 | total reward : -2.0
# 2020/10/02 00:37:01
# episode : 510 | final step : 98 | total reward : -2.0
# 2020/10/02 00:37:05
# episode : 511 | final step : 99 | total reward : -1.0
# 2020/10/02 00:37:08
# episode : 512 | final step : 98 | total reward : 99.0
# 2020/10/02 00:37:11
# episode : 513 | final step : 98 | total reward : 99.0
# 2020/10/02 00:37:14
# episode : 514 | final step : 100 | total reward : 101.0
# 2020/10/02 00:37:18
# episode : 515 | final step : 98 | total reward : -2.0
# 2020/10/02 00:37:21
# episode : 516 | final step : 98 | total reward : 99.0
# 2020/10/02 00:37:24
# episode : 517 | final step : 99 | total reward : 100.0
# 2020/10/02 00:37:27
# episode : 518 | final step : 98 | total reward : -2.0
# 2020/10/02 00:37:30
# episode : 519 | final step : 98 | total reward : -2.0
# 2020/10/02 00:37:34
# episode : 520 | final step : 100 | total reward : 101.0
# 2020/10/02 00:37:37
# episode : 521 | final step : 99 | total reward : 100.0
# 2020/10/02 00:37:40
# episode : 522 | final step : 97 | total reward : -3.0
# 2020/10/02 00:37:43
# episode : 523 | final step : 99 | total reward : -1.0
# 2020/10/02 00:37:46
# episode : 524 | final step : 98 | total reward : -2.0
# 2020/10/02 00:37:49
# episode : 525 | final step : 99 | total reward : -1.0
# 2020/10/02 00:37:53
# episode : 526 | final step : 98 | total reward : -2.0
# 2020/10/02 00:37:56
# episode : 527 | final step : 98 | total reward : 99.0
# 2020/10/02 00:37:59
# episode : 528 | final step : 98 | total reward : -2.0
# 2020/10/02 00:38:02
# episode : 529 | final step : 99 | total reward : -1.0
# 2020/10/02 00:38:05
# episode : 530 | final step : 100 | total reward : 101.0
# 2020/10/02 00:38:08
# episode : 531 | final step : 98 | total reward : -2.0
# 2020/10/02 00:38:12
# episode : 532 | final step : 99 | total reward : -1.0
# 2020/10/02 00:38:15
# episode : 533 | final step : 98 | total reward : -2.0
# 2020/10/02 00:38:18
# episode : 534 | final step : 99 | total reward : 100.0
# 2020/10/02 00:38:21
# episode : 535 | final step : 99 | total reward : 100.0
# 2020/10/02 00:38:24
# episode : 536 | final step : 100 | total reward : 101.0
# 2020/10/02 00:38:28
# episode : 537 | final step : 98 | total reward : -2.0
# 2020/10/02 00:38:31
# episode : 538 | final step : 98 | total reward : -2.0
# 2020/10/02 00:38:34
# episode : 539 | final step : 100 | total reward : 101.0
# 2020/10/02 00:38:37
# episode : 540 | final step : 98 | total reward : -2.0
# 2020/10/02 00:38:41
# episode : 541 | final step : 99 | total reward : 100.0
# 2020/10/02 00:38:44
# episode : 542 | final step : 98 | total reward : -2.0
# 2020/10/02 00:38:47
# episode : 543 | final step : 98 | total reward : -2.0
# 2020/10/02 00:38:50
# episode : 544 | final step : 98 | total reward : -2.0
# 2020/10/02 00:38:53
# episode : 545 | final step : 100 | total reward : 101.0
# 2020/10/02 00:38:56
# episode : 546 | final step : 97 | total reward : 98.0
# 2020/10/02 00:39:00
# episode : 547 | final step : 97 | total reward : 98.0
# 2020/10/02 00:39:03
# episode : 548 | final step : 98 | total reward : -2.0
# 2020/10/02 00:39:06
# episode : 549 | final step : 98 | total reward : -2.0
# 2020/10/02 00:39:09
# episode : 550 | final step : 100 | total reward : 101.0
# 2020/10/02 00:39:12
# episode : 551 | final step : 99 | total reward : -1.0
# 2020/10/02 00:39:15
# episode : 552 | final step : 98 | total reward : -2.0
# 2020/10/02 00:39:18
# episode : 553 | final step : 98 | total reward : -2.0
# 2020/10/02 00:39:22
# episode : 554 | final step : 98 | total reward : -2.0
# 2020/10/02 00:39:25
# episode : 555 | final step : 102 | total reward : 103.0
# 2020/10/02 00:39:28
# episode : 556 | final step : 98 | total reward : -2.0
# 2020/10/02 00:39:31
# episode : 557 | final step : 98 | total reward : 99.0
# 2020/10/02 00:39:35
# episode : 558 | final step : 98 | total reward : -2.0
# 2020/10/02 00:39:38
# episode : 559 | final step : 98 | total reward : -2.0
# 2020/10/02 00:39:41
# episode : 560 | final step : 98 | total reward : -2.0
# 2020/10/02 00:39:44
# episode : 561 | final step : 98 | total reward : -2.0
# 2020/10/02 00:39:47
# episode : 562 | final step : 99 | total reward : 100.0
# 2020/10/02 00:39:51
# episode : 563 | final step : 98 | total reward : -2.0
# 2020/10/02 00:39:54
# episode : 564 | final step : 99 | total reward : -1.0
# 2020/10/02 00:39:57
# episode : 565 | final step : 98 | total reward : -2.0
# 2020/10/02 00:40:00
# episode : 566 | final step : 99 | total reward : -1.0
# 2020/10/02 00:40:03
# episode : 567 | final step : 100 | total reward : 101.0
# 2020/10/02 00:40:07
# episode : 568 | final step : 98 | total reward : -2.0
# 2020/10/02 00:40:10
# episode : 569 | final step : 98 | total reward : -2.0
# 2020/10/02 00:40:13
# episode : 570 | final step : 98 | total reward : 99.0
# 2020/10/02 00:40:16
# episode : 571 | final step : 99 | total reward : -1.0
# 2020/10/02 00:40:19
# episode : 572 | final step : 98 | total reward : -2.0
# 2020/10/02 00:40:22
# episode : 573 | final step : 99 | total reward : -1.0
# 2020/10/02 00:40:26
# episode : 574 | final step : 100 | total reward : 101.0
# 2020/10/02 00:40:29
# episode : 575 | final step : 98 | total reward : -2.0
# 2020/10/02 00:40:32
# episode : 576 | final step : 98 | total reward : -2.0
# 2020/10/02 00:40:35
# episode : 577 | final step : 99 | total reward : -1.0
# 2020/10/02 00:40:38
# episode : 578 | final step : 98 | total reward : -2.0
# 2020/10/02 00:40:42
# episode : 579 | final step : 98 | total reward : -2.0
# 2020/10/02 00:40:45
# episode : 580 | final step : 98 | total reward : -2.0
# 2020/10/02 00:40:48
# episode : 581 | final step : 99 | total reward : -1.0
# 2020/10/02 00:40:51
# episode : 582 | final step : 98 | total reward : -2.0
# 2020/10/02 00:40:54
# episode : 583 | final step : 98 | total reward : -2.0
# 2020/10/02 00:40:57
# episode : 584 | final step : 99 | total reward : -1.0
# 2020/10/02 00:41:00
# episode : 585 | final step : 98 | total reward : -2.0
# 2020/10/02 00:41:03
# episode : 586 | final step : 99 | total reward : -1.0
# 2020/10/02 00:41:07
# episode : 587 | final step : 99 | total reward : -1.0
# 2020/10/02 00:41:10
# episode : 588 | final step : 99 | total reward : -1.0
# 2020/10/02 00:41:13
# episode : 589 | final step : 98 | total reward : -2.0
# 2020/10/02 00:41:16
# episode : 590 | final step : 98 | total reward : 99.0
# 2020/10/02 00:41:19
# episode : 591 | final step : 98 | total reward : -2.0
# 2020/10/02 00:41:22
# episode : 592 | final step : 98 | total reward : -2.0
# 2020/10/02 00:41:26
# episode : 593 | final step : 99 | total reward : -1.0
# 2020/10/02 00:41:29
# episode : 594 | final step : 99 | total reward : 100.0
# 2020/10/02 00:41:32
# episode : 595 | final step : 99 | total reward : -1.0
# 2020/10/02 00:41:35
# episode : 596 | final step : 98 | total reward : -2.0
# 2020/10/02 00:41:39
# episode : 597 | final step : 99 | total reward : 100.0
# 2020/10/02 00:41:42
# episode : 598 | final step : 98 | total reward : -2.0
# 2020/10/02 00:41:45
# episode : 599 | final step : 98 | total reward : -2.0
# 2020/10/02 00:41:48
# episode : 600 | final step : 99 | total reward : -1.0
# 2020/10/02 00:41:51
# episode : 601 | final step : 98 | total reward : -2.0
# 2020/10/02 00:41:54
# episode : 602 | final step : 99 | total reward : 100.0
# 2020/10/02 00:41:58
# episode : 603 | final step : 100 | total reward : 101.0
# 2020/10/02 00:42:01
# episode : 604 | final step : 98 | total reward : -2.0
# 2020/10/02 00:42:04
# episode : 605 | final step : 98 | total reward : -2.0
# 2020/10/02 00:42:07
# episode : 606 | final step : 97 | total reward : 98.0
# 2020/10/02 00:42:10
# episode : 607 | final step : 99 | total reward : -1.0
# 2020/10/02 00:42:13
# episode : 608 | final step : 98 | total reward : -2.0
# 2020/10/02 00:42:16
# episode : 609 | final step : 97 | total reward : -3.0
# 2020/10/02 00:42:20
# episode : 610 | final step : 98 | total reward : 99.0
# 2020/10/02 00:42:23
# episode : 611 | final step : 98 | total reward : 99.0
# 2020/10/02 00:42:26
# episode : 612 | final step : 98 | total reward : -2.0
# 2020/10/02 00:42:29
# episode : 613 | final step : 98 | total reward : -2.0
# 2020/10/02 00:42:32
# episode : 614 | final step : 98 | total reward : -2.0
# 2020/10/02 00:42:35
# episode : 615 | final step : 99 | total reward : 100.0
# 2020/10/02 00:42:39
# episode : 616 | final step : 100 | total reward : 0.0
# 2020/10/02 00:42:42
# episode : 617 | final step : 99 | total reward : -1.0
# 2020/10/02 00:42:45
# episode : 618 | final step : 100 | total reward : 101.0
# 2020/10/02 00:42:48
# episode : 619 | final step : 100 | total reward : 0.0
# 2020/10/02 00:42:51
# episode : 620 | final step : 99 | total reward : 100.0
# 2020/10/02 00:42:55
# episode : 621 | final step : 98 | total reward : 99.0
# 2020/10/02 00:42:58
# episode : 622 | final step : 99 | total reward : -1.0
# 2020/10/02 00:43:01
# episode : 623 | final step : 98 | total reward : -2.0
# 2020/10/02 00:43:04
# episode : 624 | final step : 99 | total reward : -1.0
# 2020/10/02 00:43:07
# episode : 625 | final step : 98 | total reward : -2.0
# 2020/10/02 00:43:10
# episode : 626 | final step : 100 | total reward : 0.0
# 2020/10/02 00:43:13
# episode : 627 | final step : 98 | total reward : -2.0
# 2020/10/02 00:43:17
# episode : 628 | final step : 99 | total reward : -1.0
# 2020/10/02 00:43:20
# episode : 629 | final step : 100 | total reward : 0.0
# 2020/10/02 00:43:23
# episode : 630 | final step : 98 | total reward : -2.0
# 2020/10/02 00:43:26
# episode : 631 | final step : 100 | total reward : 101.0
# 2020/10/02 00:43:29
# episode : 632 | final step : 98 | total reward : -2.0
# 2020/10/02 00:43:32
# episode : 633 | final step : 98 | total reward : -2.0
# 2020/10/02 00:43:35
# episode : 634 | final step : 98 | total reward : -2.0
# 2020/10/02 00:43:39
# episode : 635 | final step : 99 | total reward : -1.0
# 2020/10/02 00:43:42
# episode : 636 | final step : 98 | total reward : -2.0
# 2020/10/02 00:43:45
# episode : 637 | final step : 98 | total reward : -2.0
# 2020/10/02 00:43:48
# episode : 638 | final step : 99 | total reward : -1.0
# 2020/10/02 00:43:52
# episode : 639 | final step : 98 | total reward : -2.0
# 2020/10/02 00:43:55
# episode : 640 | final step : 99 | total reward : -1.0
# 2020/10/02 00:43:58
# episode : 641 | final step : 98 | total reward : 99.0
# 2020/10/02 00:44:01
# episode : 642 | final step : 98 | total reward : -2.0
# 2020/10/02 00:44:04
# episode : 643 | final step : 98 | total reward : -2.0
# 2020/10/02 00:44:07
# episode : 644 | final step : 98 | total reward : -2.0
# 2020/10/02 00:44:11
# episode : 645 | final step : 98 | total reward : -2.0
# 2020/10/02 00:44:14
# episode : 646 | final step : 99 | total reward : 100.0
# 2020/10/02 00:44:17
# ...
# 2020/10/02 09:35:30
# episode : 9788 | final step : 100 | total reward : 101.0
# 2020/10/02 09:35:33
# episode : 9789 | final step : 97 | total reward : -3.0
# 2020/10/02 09:35:37
# episode : 9790 | final step : 98 | total reward : -2.0
# 2020/10/02 09:35:40
# episode : 9791 | final step : 99 | total reward : -1.0
# 2020/10/02 09:35:44
# episode : 9792 | final step : 99 | total reward : 100.0
# 2020/10/02 09:35:47
# episode : 9793 | final step : 95 | total reward : 96.0
# 2020/10/02 09:35:51
# episode : 9794 | final step : 100 | total reward : 0.0
# 2020/10/02 09:35:54
# episode : 9795 | final step : 97 | total reward : 98.0
# 2020/10/02 09:35:58
# episode : 9796 | final step : 98 | total reward : -2.0
# 2020/10/02 09:36:01
# episode : 9797 | final step : 99 | total reward : 100.0
# 2020/10/02 09:36:05
# episode : 9798 | final step : 96 | total reward : 97.0
# 2020/10/02 09:36:08
# episode : 9799 | final step : 99 | total reward : -1.0
# 2020/10/02 09:36:11
# episode : 9800 | final step : 100 | total reward : 101.0
# 2020/10/02 09:36:14
# episode : 9801 | final step : 97 | total reward : 98.0
# 2020/10/02 09:36:18
# episode : 9802 | final step : 98 | total reward : -2.0
# 2020/10/02 09:36:21
# episode : 9803 | final step : 99 | total reward : -1.0
# 2020/10/02 09:36:24
# episode : 9804 | final step : 98 | total reward : -2.0
# 2020/10/02 09:36:28
# episode : 9805 | final step : 100 | total reward : 101.0
# 2020/10/02 09:36:31
# episode : 9806 | final step : 98 | total reward : -2.0
# 2020/10/02 09:36:34
# episode : 9807 | final step : 100 | total reward : 0.0
# 2020/10/02 09:36:37
# episode : 9808 | final step : 98 | total reward : -2.0
# 2020/10/02 09:36:40
# episode : 9809 | final step : 98 | total reward : -2.0
# 2020/10/02 09:36:44
# episode : 9810 | final step : 99 | total reward : -1.0
# 2020/10/02 09:36:47
# episode : 9811 | final step : 100 | total reward : 0.0
# 2020/10/02 09:36:50
# episode : 9812 | final step : 100 | total reward : 0.0
# 2020/10/02 09:36:54
# episode : 9813 | final step : 98 | total reward : -2.0
# 2020/10/02 09:36:57
# episode : 9814 | final step : 98 | total reward : -2.0
# 2020/10/02 09:37:00
# episode : 9815 | final step : 97 | total reward : 98.0
# 2020/10/02 09:37:03
# episode : 9816 | final step : 99 | total reward : -1.0
# 2020/10/02 09:37:06
# episode : 9817 | final step : 98 | total reward : -2.0
# 2020/10/02 09:37:10
# episode : 9818 | final step : 98 | total reward : -2.0
# 2020/10/02 09:37:13
# episode : 9819 | final step : 99 | total reward : 100.0
# 2020/10/02 09:37:16
# episode : 9820 | final step : 98 | total reward : -2.0
# 2020/10/02 09:37:19
# episode : 9821 | final step : 97 | total reward : 98.0
# 2020/10/02 09:37:22
# episode : 9822 | final step : 98 | total reward : -2.0
# 2020/10/02 09:37:25
# episode : 9823 | final step : 98 | total reward : -2.0
# 2020/10/02 09:37:28
# episode : 9824 | final step : 98 | total reward : -2.0
# 2020/10/02 09:37:32
# episode : 9825 | final step : 97 | total reward : -3.0
# 2020/10/02 09:37:35
# episode : 9826 | final step : 98 | total reward : 99.0
# 2020/10/02 09:37:38
# episode : 9827 | final step : 98 | total reward : -2.0
# 2020/10/02 09:37:42
# episode : 9828 | final step : 99 | total reward : -1.0
# 2020/10/02 09:37:45
# episode : 9829 | final step : 98 | total reward : -2.0
# 2020/10/02 09:37:49
# episode : 9830 | final step : 98 | total reward : -2.0
# 2020/10/02 09:37:52
# episode : 9831 | final step : 98 | total reward : -2.0
# 2020/10/02 09:37:55
# episode : 9832 | final step : 99 | total reward : -1.0
# 2020/10/02 09:37:59
# episode : 9833 | final step : 96 | total reward : 97.0
# 2020/10/02 09:38:02
# episode : 9834 | final step : 98 | total reward : -2.0
# 2020/10/02 09:38:06
# episode : 9835 | final step : 99 | total reward : 100.0
# 2020/10/02 09:38:09
# episode : 9836 | final step : 98 | total reward : -2.0
# 2020/10/02 09:38:13
# episode : 9837 | final step : 100 | total reward : 101.0
# 2020/10/02 09:38:16
# episode : 9838 | final step : 99 | total reward : 100.0
# 2020/10/02 09:38:19
# episode : 9839 | final step : 96 | total reward : 97.0
# 2020/10/02 09:38:23
# episode : 9840 | final step : 98 | total reward : -2.0
# 2020/10/02 09:38:26
# episode : 9841 | final step : 98 | total reward : -2.0
# 2020/10/02 09:38:29
# episode : 9842 | final step : 100 | total reward : 101.0
# 2020/10/02 09:38:32
# episode : 9843 | final step : 97 | total reward : 98.0
# 2020/10/02 09:38:36
# episode : 9844 | final step : 98 | total reward : -2.0
# 2020/10/02 09:38:39
# episode : 9845 | final step : 98 | total reward : -2.0
# 2020/10/02 09:38:42
# episode : 9846 | final step : 98 | total reward : -2.0
# 2020/10/02 09:38:45
# episode : 9847 | final step : 98 | total reward : -2.0
# 2020/10/02 09:38:48
# episode : 9848 | final step : 99 | total reward : 100.0
# 2020/10/02 09:38:51
# episode : 9849 | final step : 99 | total reward : -1.0
# 2020/10/02 09:38:55
# episode : 9850 | final step : 98 | total reward : -2.0
# 2020/10/02 09:38:58
# episode : 9851 | final step : 99 | total reward : -1.0
# 2020/10/02 09:39:01
# episode : 9852 | final step : 100 | total reward : 101.0
# 2020/10/02 09:39:04
# episode : 9853 | final step : 98 | total reward : -2.0
# 2020/10/02 09:39:07
# episode : 9854 | final step : 98 | total reward : -2.0
# 2020/10/02 09:39:11
# episode : 9855 | final step : 98 | total reward : -2.0
# 2020/10/02 09:39:14
# episode : 9856 | final step : 98 | total reward : -2.0
# 2020/10/02 09:39:17
# episode : 9857 | final step : 98 | total reward : 99.0
# 2020/10/02 09:39:20
# episode : 9858 | final step : 100 | total reward : 101.0
# 2020/10/02 09:39:23
# episode : 9859 | final step : 98 | total reward : -2.0
# 2020/10/02 09:39:26
# episode : 9860 | final step : 97 | total reward : -3.0
# 2020/10/02 09:39:30
# episode : 9861 | final step : 99 | total reward : 100.0
# 2020/10/02 09:39:33
# episode : 9862 | final step : 97 | total reward : 98.0
# 2020/10/02 09:39:36
# episode : 9863 | final step : 97 | total reward : 98.0
# 2020/10/02 09:39:39
# episode : 9864 | final step : 98 | total reward : -2.0
# 2020/10/02 09:39:42
# episode : 9865 | final step : 98 | total reward : -2.0
# 2020/10/02 09:39:46
# episode : 9866 | final step : 98 | total reward : -2.0
# 2020/10/02 09:39:49
# episode : 9867 | final step : 98 | total reward : -2.0
# 2020/10/02 09:39:52
# episode : 9868 | final step : 98 | total reward : -2.0
# 2020/10/02 09:39:55
# episode : 9869 | final step : 98 | total reward : -2.0
# 2020/10/02 09:39:58
# episode : 9870 | final step : 97 | total reward : 98.0
# 2020/10/02 09:40:01
# episode : 9871 | final step : 99 | total reward : 100.0
# 2020/10/02 09:40:05
# episode : 9872 | final step : 100 | total reward : 101.0
# 2020/10/02 09:40:08
# episode : 9873 | final step : 98 | total reward : -2.0
# 2020/10/02 09:40:11
# episode : 9874 | final step : 100 | total reward : 101.0
# 2020/10/02 09:40:14
# episode : 9875 | final step : 97 | total reward : 98.0
# 2020/10/02 09:40:17
# episode : 9876 | final step : 99 | total reward : -1.0
# 2020/10/02 09:40:21
# episode : 9877 | final step : 99 | total reward : -1.0
# 2020/10/02 09:40:24
# episode : 9878 | final step : 98 | total reward : -2.0
# 2020/10/02 09:40:27
# episode : 9879 | final step : 98 | total reward : -2.0
# 2020/10/02 09:40:30
# episode : 9880 | final step : 98 | total reward : -2.0
# 2020/10/02 09:40:33
# episode : 9881 | final step : 99 | total reward : -1.0
# 2020/10/02 09:40:36
# episode : 9882 | final step : 98 | total reward : -2.0
# 2020/10/02 09:40:40
# episode : 9883 | final step : 98 | total reward : -2.0
# 2020/10/02 09:40:43
# episode : 9884 | final step : 98 | total reward : -2.0
# 2020/10/02 09:40:46
# episode : 9885 | final step : 97 | total reward : 98.0
# 2020/10/02 09:40:49
# episode : 9886 | final step : 98 | total reward : -2.0
# 2020/10/02 09:40:52
# episode : 9887 | final step : 98 | total reward : -2.0
# 2020/10/02 09:40:56
# episode : 9888 | final step : 98 | total reward : -2.0
# 2020/10/02 09:40:59
# episode : 9889 | final step : 99 | total reward : -1.0
# 2020/10/02 09:41:02
# episode : 9890 | final step : 98 | total reward : -2.0
# 2020/10/02 09:41:05
# episode : 9891 | final step : 99 | total reward : -1.0
# 2020/10/02 09:41:08
# episode : 9892 | final step : 98 | total reward : 99.0
# 2020/10/02 09:41:12
# episode : 9893 | final step : 99 | total reward : -1.0
# 2020/10/02 09:41:15
# episode : 9894 | final step : 99 | total reward : -1.0
# 2020/10/02 09:41:18
# episode : 9895 | final step : 98 | total reward : -2.0
# 2020/10/02 09:41:21
# episode : 9896 | final step : 95 | total reward : 96.0
# 2020/10/02 09:41:24
# episode : 9897 | final step : 100 | total reward : 0.0
# 2020/10/02 09:41:28
# episode : 9898 | final step : 98 | total reward : -2.0
# 2020/10/02 09:41:31
# episode : 9899 | final step : 98 | total reward : 99.0
# 2020/10/02 09:41:34
# episode : 9900 | final step : 98 | total reward : -2.0
# 2020/10/02 09:41:37
# episode : 9901 | final step : 99 | total reward : 100.0
# 2020/10/02 09:41:40
# episode : 9902 | final step : 102 | total reward : 103.0
# 2020/10/02 09:41:43
# episode : 9903 | final step : 98 | total reward : -2.0
# 2020/10/02 09:41:46
# episode : 9904 | final step : 101 | total reward : 102.0
# 2020/10/02 09:41:49
# episode : 9905 | final step : 98 | total reward : -2.0
# 2020/10/02 09:41:52
# episode : 9906 | final step : 98 | total reward : -2.0
# 2020/10/02 09:41:55
# episode : 9907 | final step : 98 | total reward : 99.0
# 2020/10/02 09:41:59
# episode : 9908 | final step : 99 | total reward : -1.0
# 2020/10/02 09:42:02
# episode : 9909 | final step : 100 | total reward : 0.0
# 2020/10/02 09:42:05
# episode : 9910 | final step : 99 | total reward : -1.0
# 2020/10/02 09:42:08
# episode : 9911 | final step : 98 | total reward : -2.0
# 2020/10/02 09:42:11
# episode : 9912 | final step : 98 | total reward : -2.0
# 2020/10/02 09:42:15
# episode : 9913 | final step : 97 | total reward : 98.0
# 2020/10/02 09:42:18
# episode : 9914 | final step : 98 | total reward : 99.0
# 2020/10/02 09:42:21
# episode : 9915 | final step : 99 | total reward : -1.0
# 2020/10/02 09:42:24
# episode : 9916 | final step : 98 | total reward : -2.0
# 2020/10/02 09:42:28
# episode : 9917 | final step : 103 | total reward : 104.0
# 2020/10/02 09:42:31
# episode : 9918 | final step : 98 | total reward : -2.0
# 2020/10/02 09:42:34
# episode : 9919 | final step : 101 | total reward : 102.0
# 2020/10/02 09:42:37
# episode : 9920 | final step : 98 | total reward : -2.0
# 2020/10/02 09:42:40
# episode : 9921 | final step : 100 | total reward : 101.0
# 2020/10/02 09:42:44
# episode : 9922 | final step : 100 | total reward : 0.0
# 2020/10/02 09:42:47
# episode : 9923 | final step : 97 | total reward : 98.0
# 2020/10/02 09:42:50
# episode : 9924 | final step : 103 | total reward : 104.0
# 2020/10/02 09:42:53
# episode : 9925 | final step : 99 | total reward : 100.0
# 2020/10/02 09:42:56
# episode : 9926 | final step : 98 | total reward : -2.0
# 2020/10/02 09:42:59
# episode : 9927 | final step : 97 | total reward : 98.0
# 2020/10/02 09:43:03
# episode : 9928 | final step : 99 | total reward : -1.0
# 2020/10/02 09:43:06
# episode : 9929 | final step : 99 | total reward : -1.0
# 2020/10/02 09:43:09
# episode : 9930 | final step : 99 | total reward : 100.0
# 2020/10/02 09:43:12
# episode : 9931 | final step : 99 | total reward : -1.0
# 2020/10/02 09:43:15
# episode : 9932 | final step : 98 | total reward : 99.0
# 2020/10/02 09:43:18
# episode : 9933 | final step : 98 | total reward : -2.0
# 2020/10/02 09:43:22
# episode : 9934 | final step : 98 | total reward : 99.0
# 2020/10/02 09:43:25
# episode : 9935 | final step : 98 | total reward : -2.0
# 2020/10/02 09:43:28
# episode : 9936 | final step : 98 | total reward : -2.0
# 2020/10/02 09:43:31
# episode : 9937 | final step : 100 | total reward : 101.0
# 2020/10/02 09:43:34
# episode : 9938 | final step : 98 | total reward : -2.0
# 2020/10/02 09:43:38
# episode : 9939 | final step : 99 | total reward : 100.0
# 2020/10/02 09:43:41
# episode : 9940 | final step : 98 | total reward : -2.0
# 2020/10/02 09:43:44
# episode : 9941 | final step : 97 | total reward : 98.0
# 2020/10/02 09:43:47
# episode : 9942 | final step : 98 | total reward : 99.0
# 2020/10/02 09:43:50
# episode : 9943 | final step : 98 | total reward : -2.0
# 2020/10/02 09:43:54
# episode : 9944 | final step : 101 | total reward : 102.0
# 2020/10/02 09:43:57
# episode : 9945 | final step : 98 | total reward : -2.0
# 2020/10/02 09:44:00
# episode : 9946 | final step : 98 | total reward : -2.0
# 2020/10/02 09:44:03
# episode : 9947 | final step : 97 | total reward : -3.0
# 2020/10/02 09:44:06
# episode : 9948 | final step : 98 | total reward : -2.0
# 2020/10/02 09:44:10
# episode : 9949 | final step : 98 | total reward : -2.0
# 2020/10/02 09:44:13
# episode : 9950 | final step : 98 | total reward : -2.0
# 2020/10/02 09:44:16
# episode : 9951 | final step : 98 | total reward : -2.0
# 2020/10/02 09:44:19
# episode : 9952 | final step : 98 | total reward : -2.0
# 2020/10/02 09:44:22
# episode : 9953 | final step : 99 | total reward : -1.0
# 2020/10/02 09:44:25
# episode : 9954 | final step : 98 | total reward : -2.0
# 2020/10/02 09:44:28
# episode : 9955 | final step : 97 | total reward : 98.0
# 2020/10/02 09:44:31
# episode : 9956 | final step : 99 | total reward : -1.0
# 2020/10/02 09:44:34
# episode : 9957 | final step : 98 | total reward : -2.0
# 2020/10/02 09:44:38
# episode : 9958 | final step : 98 | total reward : -2.0
# 2020/10/02 09:44:41
# episode : 9959 | final step : 98 | total reward : 99.0
# 2020/10/02 09:44:44
# episode : 9960 | final step : 99 | total reward : -1.0
# 2020/10/02 09:44:46
# episode : 9961 | final step : 99 | total reward : 100.0
# 2020/10/02 09:44:50
# episode : 9962 | final step : 98 | total reward : 99.0
# 2020/10/02 09:44:53
# episode : 9963 | final step : 98 | total reward : -2.0
# 2020/10/02 09:44:56
# episode : 9964 | final step : 99 | total reward : 100.0
# 2020/10/02 09:44:59
# episode : 9965 | final step : 100 | total reward : 101.0
# 2020/10/02 09:45:02
# episode : 9966 | final step : 98 | total reward : 99.0
# 2020/10/02 09:45:05
# episode : 9967 | final step : 99 | total reward : -1.0
# 2020/10/02 09:45:08
# episode : 9968 | final step : 99 | total reward : 100.0
# 2020/10/02 09:45:12
# episode : 9969 | final step : 100 | total reward : 101.0
# 2020/10/02 09:45:15
# episode : 9970 | final step : 99 | total reward : 100.0
# 2020/10/02 09:45:18
# episode : 9971 | final step : 98 | total reward : -2.0
# 2020/10/02 09:45:21
# episode : 9972 | final step : 98 | total reward : -2.0
# 2020/10/02 09:45:24
# episode : 9973 | final step : 98 | total reward : 99.0
# 2020/10/02 09:45:28
# episode : 9974 | final step : 98 | total reward : -2.0
# 2020/10/02 09:45:31
# episode : 9975 | final step : 98 | total reward : -2.0
# 2020/10/02 09:45:34
# episode : 9976 | final step : 98 | total reward : -2.0
# 2020/10/02 09:45:37
# episode : 9977 | final step : 99 | total reward : -1.0
# 2020/10/02 09:45:40
# episode : 9978 | final step : 99 | total reward : 100.0
# 2020/10/02 09:45:43
# episode : 9979 | final step : 98 | total reward : -2.0
# 2020/10/02 09:45:46
# episode : 9980 | final step : 98 | total reward : -2.0
# 2020/10/02 09:45:49
# episode : 9981 | final step : 103 | total reward : 104.0
# 2020/10/02 09:45:52
# episode : 9982 | final step : 99 | total reward : 100.0
# 2020/10/02 09:45:55
# episode : 9983 | final step : 100 | total reward : 101.0
# 2020/10/02 09:45:59
# episode : 9984 | final step : 99 | total reward : -1.0
# 2020/10/02 09:46:02
# episode : 9985 | final step : 98 | total reward : -2.0
# 2020/10/02 09:46:05
# episode : 9986 | final step : 100 | total reward : 0.0
# 2020/10/02 09:46:08
# episode : 9987 | final step : 98 | total reward : 99.0
# 2020/10/02 09:46:11
# episode : 9988 | final step : 98 | total reward : 99.0
# 2020/10/02 09:46:14
# episode : 9989 | final step : 98 | total reward : -2.0
# 2020/10/02 09:46:17
# episode : 9990 | final step : 99 | total reward : -1.0
# 2020/10/02 09:46:20
# episode : 9991 | final step : 97 | total reward : 98.0
# 2020/10/02 09:46:24
# episode : 9992 | final step : 98 | total reward : 99.0
# 2020/10/02 09:46:27
# episode : 9993 | final step : 99 | total reward : -1.0
# 2020/10/02 09:46:30
# episode : 9994 | final step : 98 | total reward : -2.0
# 2020/10/02 09:46:33
# episode : 9995 | final step : 100 | total reward : 0.0
# 2020/10/02 09:46:36
# episode : 9996 | final step : 98 | total reward : -2.0
# 2020/10/02 09:46:39
# episode : 9997 | final step : 97 | total reward : 98.0
# 2020/10/02 09:46:42
# episode : 9998 | final step : 98 | total reward : -2.0
# 2020/10/02 09:46:45
# episode : 9999 | final step : 98 | total reward : -2.0
# Complete

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(reward_list)

# %%
def moving_average(data,n):
    len_data=len(data)-n
    res_data=np.zeros(len_data)

    for i in range(len_data):
        res_data[i]=sum(data[i:i+n])/n
    return res_data

# %%
average_number=200
filtered_data=moving_average(reward_list,average_number)
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(filtered_data)

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[0]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[10]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[100]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[1000]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[9999]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()
