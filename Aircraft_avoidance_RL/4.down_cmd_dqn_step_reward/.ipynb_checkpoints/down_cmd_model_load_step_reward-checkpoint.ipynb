# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
import time
import itertools
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
import gym_Aircraft
num_gpus=4
batch_size=128

# %%
env = gym.make("acav-v0")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# /home/jupyter-kunwoopark/.local/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """transition 저장"""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
class DQN(torch.nn.Module):
    def __init__(self):
        super(DQN, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(5, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 40),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(40, 3),
            nn.LeakyReLU(0.2, inplace=True)
        )

    def forward(self, x):
        x=x.view(batch_size//num_gpus,-1)
        out=self.fc(x)
        return out

# %%
BATCH_SIZE = batch_size
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10

# %%
policy_net = nn.DataParallel(DQN(env.observation_space.shape[0], env.action_space.n).to(device))
target_net = nn.DataParallel(DQN(env.observation_space.shape[0], env.action_space.n).to(device))
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
# Out:
# DataParallel(
#   (module): DQN(
#     (layers): Sequential(
#       (0): Linear(in_features=5, out_features=40, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=40, out_features=40, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=40, out_features=40, bias=True)
#       (5): ReLU()
#       (6): Linear(in_features=40, out_features=40, bias=True)
#       (7): ReLU()
#       (8): Linear(in_features=40, out_features=40, bias=True)
#       (9): ReLU()
#       (10): Linear(in_features=40, out_features=40, bias=True)
#       (11): ReLU()
#       (12): Linear(in_features=40, out_features=40, bias=True)
#       (13): ReLU()
#       (14): Linear(in_features=40, out_features=3, bias=True)
#     )
#   )
# )

# %%
n_actions = env.action_space.n

# %%
optimizer = optim.Adam(policy_net.parameters())
memory = ReplayMemory(10000)

# %%
steps_done = 0

# %%
def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max (1)은 각 행의 가장 큰 열 값을 반환합니다.
            # 최대 결과의 두번째 열은 최대 요소의 주소값이므로,
            # 기대 보상이 더 큰 행동을 선택할 수 있습니다.
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(n_actions)]], device=device, dtype=torch.long)

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)

    batch = Transition(*zip(*transitions))

    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    state_action_values = policy_net(state_batch).gather(1, action_batch)

    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    # 기대 Q 값 계산
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Huber 손실 계산
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    # 모델 최적화
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
num_episodes = 10000
total_res=[]
reward_list=[]
for i_episode in range(num_episodes):
    total_reward=0
    
    # 환경과 상태 초기화
    res_list=np.zeros(11)
    state = env.reset()
    state=torch.from_numpy(state.astype(np.float32)).unsqueeze(0).to(device)
    for t in count():
        # 행동 선택과 수행
        
        action = select_action(state)
        next_state, reward, done, res = env.step(action.item())
        reward = torch.tensor([reward], dtype=torch.float32).to(device)
        
        next_state=torch.from_numpy(next_state.astype(np.float32)).unsqueeze(0).to(device)

        # 새로운 상태 관찰
        if not done:
            next_state = next_state
        else:
            next_state = None

        # 메모리에 변이 저장
        memory.push(state, action, next_state, reward)

        # 다음 상태로 이동
        state = next_state

        # 최적화 한단계 수행(목표 네트워크에서)
        optimize_model()
        
        # Data save
        
        cmd_list,r_list,elev_list,azim_list,Pm_list,Pt_list,h_list=res
        Pm_list=Pm_list.tolist()
        Pt_list=Pt_list.tolist()
        merged_data=itertools.chain([cmd_list],[r_list],[elev_list],[azim_list],Pm_list,Pt_list,[h_list])
        merged_data=np.array(list(merged_data))
        res_list=np.vstack([res_list,merged_data])
        
        total_reward+=reward
        
        if done:
            res_list=np.delete(res_list,0,0)
            
            total_res.append(res_list)
            reward_list.append(total_reward)
            
            now = time.localtime()
            print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))
            print("episode : {} | final step : {} | total reward : {}".format(i_episode, t, total_reward.item()))
            break
            
        
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

print('Complete')
env.close()
# Out:
# 2020/10/01 13:10:33
# episode : 0 | final step : 91 | total reward : 0.0
# 2020/10/01 13:10:42
# episode : 1 | final step : 99 | total reward : 0.0
# 2020/10/01 13:10:44
# episode : 2 | final step : 100 | total reward : 0.0
# 2020/10/01 13:10:47
# episode : 3 | final step : 98 | total reward : -1.0
# 2020/10/01 13:10:50
# episode : 4 | final step : 98 | total reward : 0.0
# 2020/10/01 13:10:52
# episode : 5 | final step : 98 | total reward : 0.0
# 2020/10/01 13:10:55
# episode : 6 | final step : 100 | total reward : 0.0
# 2020/10/01 13:10:58
# episode : 7 | final step : 100 | total reward : 0.0
# 2020/10/01 13:11:01
# episode : 8 | final step : 99 | total reward : 0.0
# 2020/10/01 13:11:04
# episode : 9 | final step : 99 | total reward : -1.0
# 2020/10/01 13:11:07
# episode : 10 | final step : 99 | total reward : 0.0
# 2020/10/01 13:11:10
# episode : 11 | final step : 100 | total reward : 0.0
# 2020/10/01 13:11:13
# episode : 12 | final step : 98 | total reward : -1.0
# 2020/10/01 13:11:16
# episode : 13 | final step : 98 | total reward : 0.0
# 2020/10/01 13:11:19
# episode : 14 | final step : 98 | total reward : -1.0
# 2020/10/01 13:11:22
# episode : 15 | final step : 100 | total reward : 0.0
# 2020/10/01 13:11:24
# episode : 16 | final step : 100 | total reward : 0.0
# 2020/10/01 13:11:27
# episode : 17 | final step : 100 | total reward : 0.0
# 2020/10/01 13:11:30
# episode : 18 | final step : 99 | total reward : -1.0
# 2020/10/01 13:11:33
# episode : 19 | final step : 100 | total reward : 0.0
# 2020/10/01 13:11:36
# episode : 20 | final step : 97 | total reward : 0.0
# 2020/10/01 13:11:38
# episode : 21 | final step : 98 | total reward : 0.0
# 2020/10/01 13:11:41
# episode : 22 | final step : 98 | total reward : 0.0
# 2020/10/01 13:11:44
# episode : 23 | final step : 100 | total reward : 0.0
# 2020/10/01 13:11:47
# episode : 24 | final step : 99 | total reward : -1.0
# 2020/10/01 13:11:50
# episode : 25 | final step : 99 | total reward : 0.0
# 2020/10/01 13:11:53
# episode : 26 | final step : 99 | total reward : 0.0
# 2020/10/01 13:11:55
# episode : 27 | final step : 98 | total reward : -1.0
# 2020/10/01 13:11:58
# episode : 28 | final step : 99 | total reward : 0.0
# 2020/10/01 13:12:01
# episode : 29 | final step : 95 | total reward : 0.0
# 2020/10/01 13:12:04
# episode : 30 | final step : 99 | total reward : 0.0
# 2020/10/01 13:12:07
# episode : 31 | final step : 99 | total reward : -1.0
# 2020/10/01 13:12:09
# episode : 32 | final step : 96 | total reward : 0.0
# 2020/10/01 13:12:12
# episode : 33 | final step : 99 | total reward : 0.0
# 2020/10/01 13:12:15
# episode : 34 | final step : 100 | total reward : 0.0
# 2020/10/01 13:12:18
# episode : 35 | final step : 99 | total reward : 0.0
# 2020/10/01 13:12:21
# episode : 36 | final step : 97 | total reward : -1.0
# 2020/10/01 13:12:24
# episode : 37 | final step : 99 | total reward : -1.0
# 2020/10/01 13:12:27
# episode : 38 | final step : 100 | total reward : 0.0
# 2020/10/01 13:12:29
# episode : 39 | final step : 98 | total reward : 0.0
# 2020/10/01 13:12:32
# episode : 40 | final step : 100 | total reward : 0.0
# 2020/10/01 13:12:34
# episode : 41 | final step : 100 | total reward : 0.0
# 2020/10/01 13:12:37
# episode : 42 | final step : 98 | total reward : 0.0
# 2020/10/01 13:12:40
# episode : 43 | final step : 95 | total reward : 0.0
# 2020/10/01 13:12:43
# episode : 44 | final step : 101 | total reward : 0.0
# 2020/10/01 13:12:46
# episode : 45 | final step : 95 | total reward : 0.0
# 2020/10/01 13:12:49
# episode : 46 | final step : 100 | total reward : 0.0
# 2020/10/01 13:12:52
# episode : 47 | final step : 98 | total reward : -1.0
# 2020/10/01 13:12:55
# episode : 48 | final step : 98 | total reward : 0.0
# 2020/10/01 13:12:57
# episode : 49 | final step : 98 | total reward : -1.0
# 2020/10/01 13:13:00
# episode : 50 | final step : 97 | total reward : 0.0
# 2020/10/01 13:13:03
# episode : 51 | final step : 100 | total reward : 0.0
# 2020/10/01 13:13:06
# episode : 52 | final step : 100 | total reward : 0.0
# 2020/10/01 13:13:09
# episode : 53 | final step : 100 | total reward : 0.0
# 2020/10/01 13:13:11
# episode : 54 | final step : 103 | total reward : 0.0
# 2020/10/01 13:13:14
# episode : 55 | final step : 100 | total reward : 0.0
# 2020/10/01 13:13:17
# episode : 56 | final step : 92 | total reward : 0.0
# 2020/10/01 13:13:20
# episode : 57 | final step : 102 | total reward : 0.0
# 2020/10/01 13:13:23
# episode : 58 | final step : 99 | total reward : 0.0
# 2020/10/01 13:13:25
# episode : 59 | final step : 97 | total reward : 0.0
# 2020/10/01 13:13:28
# episode : 60 | final step : 99 | total reward : 0.0
# 2020/10/01 13:13:31
# episode : 61 | final step : 100 | total reward : 0.0
# 2020/10/01 13:13:34
# episode : 62 | final step : 100 | total reward : 0.0
# 2020/10/01 13:13:37
# episode : 63 | final step : 98 | total reward : -1.0
# 2020/10/01 13:13:40
# episode : 64 | final step : 99 | total reward : 0.0
# 2020/10/01 13:13:43
# episode : 65 | final step : 99 | total reward : -1.0
# 2020/10/01 13:13:46
# episode : 66 | final step : 100 | total reward : 0.0
# 2020/10/01 13:13:48
# episode : 67 | final step : 100 | total reward : 0.0
# 2020/10/01 13:13:51
# episode : 68 | final step : 98 | total reward : -1.0
# 2020/10/01 13:13:54
# episode : 69 | final step : 98 | total reward : 0.0
# 2020/10/01 13:13:57
# episode : 70 | final step : 100 | total reward : 0.0
# 2020/10/01 13:14:00
# episode : 71 | final step : 99 | total reward : 0.0
# 2020/10/01 13:14:02
# episode : 72 | final step : 100 | total reward : 0.0
# 2020/10/01 13:14:05
# episode : 73 | final step : 99 | total reward : -1.0
# 2020/10/01 13:14:08
# episode : 74 | final step : 99 | total reward : 0.0
# 2020/10/01 13:14:11
# episode : 75 | final step : 100 | total reward : 0.0
# 2020/10/01 13:14:14
# episode : 76 | final step : 100 | total reward : 0.0
# 2020/10/01 13:14:17
# episode : 77 | final step : 98 | total reward : -1.0
# 2020/10/01 13:14:20
# episode : 78 | final step : 100 | total reward : 0.0
# 2020/10/01 13:14:22
# episode : 79 | final step : 99 | total reward : 0.0
# 2020/10/01 13:14:25
# episode : 80 | final step : 100 | total reward : 0.0
# 2020/10/01 13:14:28
# episode : 81 | final step : 100 | total reward : 0.0
# 2020/10/01 13:14:31
# episode : 82 | final step : 98 | total reward : 0.0
# 2020/10/01 13:14:34
# episode : 83 | final step : 99 | total reward : 0.0
# 2020/10/01 13:14:37
# episode : 84 | final step : 101 | total reward : 0.0
# 2020/10/01 13:14:40
# episode : 85 | final step : 100 | total reward : 0.0
# 2020/10/01 13:14:42
# episode : 86 | final step : 96 | total reward : 0.0
# 2020/10/01 13:14:45
# episode : 87 | final step : 99 | total reward : -1.0
# 2020/10/01 13:14:48
# episode : 88 | final step : 97 | total reward : 0.0
# 2020/10/01 13:14:51
# episode : 89 | final step : 100 | total reward : -1.0
# 2020/10/01 13:14:54
# episode : 90 | final step : 98 | total reward : -1.0
# 2020/10/01 13:14:57
# episode : 91 | final step : 98 | total reward : -1.0
# 2020/10/01 13:14:59
# episode : 92 | final step : 99 | total reward : 0.0
# 2020/10/01 13:15:02
# episode : 93 | final step : 100 | total reward : 0.0
# 2020/10/01 13:15:05
# episode : 94 | final step : 98 | total reward : -1.0
# 2020/10/01 13:15:08
# episode : 95 | final step : 98 | total reward : -1.0
# 2020/10/01 13:15:11
# episode : 96 | final step : 99 | total reward : 0.0
# 2020/10/01 13:15:14
# episode : 97 | final step : 99 | total reward : 0.0
# 2020/10/01 13:15:17
# episode : 98 | final step : 95 | total reward : 0.0
# 2020/10/01 13:15:19
# episode : 99 | final step : 98 | total reward : -1.0
# 2020/10/01 13:15:22
# episode : 100 | final step : 98 | total reward : -1.0
# 2020/10/01 13:15:25
# episode : 101 | final step : 97 | total reward : 0.0
# 2020/10/01 13:15:28
# episode : 102 | final step : 96 | total reward : 0.0
# 2020/10/01 13:15:31
# episode : 103 | final step : 97 | total reward : -1.0
# 2020/10/01 13:15:33
# episode : 104 | final step : 97 | total reward : 0.0
# 2020/10/01 13:15:36
# episode : 105 | final step : 100 | total reward : 0.0
# 2020/10/01 13:15:39
# episode : 106 | final step : 96 | total reward : 0.0
# 2020/10/01 13:15:42
# episode : 107 | final step : 99 | total reward : 0.0
# 2020/10/01 13:15:45
# episode : 108 | final step : 100 | total reward : 0.0
# 2020/10/01 13:15:48
# episode : 109 | final step : 99 | total reward : 0.0
# 2020/10/01 13:15:51
# episode : 110 | final step : 104 | total reward : 0.0
# 2020/10/01 13:15:54
# episode : 111 | final step : 100 | total reward : 0.0
# 2020/10/01 13:15:56
# episode : 112 | final step : 95 | total reward : 0.0
# 2020/10/01 13:15:59
# episode : 113 | final step : 98 | total reward : -1.0
# 2020/10/01 13:16:02
# episode : 114 | final step : 99 | total reward : 0.0
# 2020/10/01 13:16:05
# episode : 115 | final step : 98 | total reward : 0.0
# 2020/10/01 13:16:08
# episode : 116 | final step : 99 | total reward : 0.0
# 2020/10/01 13:16:11
# episode : 117 | final step : 98 | total reward : -1.0
# 2020/10/01 13:16:14
# episode : 118 | final step : 100 | total reward : 0.0
# 2020/10/01 13:16:16
# episode : 119 | final step : 97 | total reward : 0.0
# 2020/10/01 13:16:19
# episode : 120 | final step : 99 | total reward : -1.0
# 2020/10/01 13:16:22
# episode : 121 | final step : 98 | total reward : 0.0
# 2020/10/01 13:16:25
# episode : 122 | final step : 98 | total reward : -1.0
# 2020/10/01 13:16:27
# episode : 123 | final step : 100 | total reward : 0.0
# 2020/10/01 13:16:30
# episode : 124 | final step : 100 | total reward : 0.0
# 2020/10/01 13:16:33
# episode : 125 | final step : 99 | total reward : 0.0
# 2020/10/01 13:16:36
# episode : 126 | final step : 98 | total reward : -1.0
# 2020/10/01 13:16:39
# episode : 127 | final step : 96 | total reward : 0.0
# 2020/10/01 13:16:42
# episode : 128 | final step : 96 | total reward : 0.0
# 2020/10/01 13:16:44
# episode : 129 | final step : 94 | total reward : 0.0
# 2020/10/01 13:16:47
# episode : 130 | final step : 101 | total reward : 0.0
# 2020/10/01 13:16:50
# episode : 131 | final step : 99 | total reward : 0.0
# 2020/10/01 13:16:53
# episode : 132 | final step : 101 | total reward : 0.0
# 2020/10/01 13:16:56
# episode : 133 | final step : 98 | total reward : -1.0
# 2020/10/01 13:16:59
# episode : 134 | final step : 97 | total reward : 0.0
# 2020/10/01 13:17:02
# episode : 135 | final step : 98 | total reward : 0.0
# 2020/10/01 13:17:05
# episode : 136 | final step : 100 | total reward : 0.0
# 2020/10/01 13:17:08
# episode : 137 | final step : 99 | total reward : -1.0
# 2020/10/01 13:17:10
# episode : 138 | final step : 100 | total reward : 0.0
# 2020/10/01 13:17:13
# episode : 139 | final step : 99 | total reward : 0.0
# 2020/10/01 13:17:16
# episode : 140 | final step : 99 | total reward : 0.0
# 2020/10/01 13:17:19
# episode : 141 | final step : 99 | total reward : -1.0
# 2020/10/01 13:17:22
# episode : 142 | final step : 99 | total reward : 0.0
# 2020/10/01 13:17:25
# episode : 143 | final step : 98 | total reward : 0.0
# 2020/10/01 13:17:28
# episode : 144 | final step : 98 | total reward : 0.0
# 2020/10/01 13:17:30
# episode : 145 | final step : 96 | total reward : 0.0
# 2020/10/01 13:17:33
# episode : 146 | final step : 100 | total reward : 0.0
# 2020/10/01 13:17:36
# episode : 147 | final step : 99 | total reward : 0.0
# 2020/10/01 13:17:39
# episode : 148 | final step : 100 | total reward : 0.0
# 2020/10/01 13:17:42
# episode : 149 | final step : 100 | total reward : 0.0
# 2020/10/01 13:17:45
# episode : 150 | final step : 99 | total reward : 0.0
# 2020/10/01 13:17:48
# episode : 151 | final step : 96 | total reward : 0.0
# 2020/10/01 13:17:51
# episode : 152 | final step : 98 | total reward : 0.0
# 2020/10/01 13:17:53
# episode : 153 | final step : 100 | total reward : 0.0
# 2020/10/01 13:17:56
# episode : 154 | final step : 99 | total reward : -1.0
# 2020/10/01 13:17:59
# episode : 155 | final step : 97 | total reward : 0.0
# 2020/10/01 13:18:02
# episode : 156 | final step : 100 | total reward : 0.0
# 2020/10/01 13:18:05
# episode : 157 | final step : 99 | total reward : -1.0
# 2020/10/01 13:18:08
# episode : 158 | final step : 101 | total reward : 0.0
# 2020/10/01 13:18:11
# episode : 159 | final step : 100 | total reward : 0.0
# 2020/10/01 13:18:13
# episode : 160 | final step : 99 | total reward : 0.0
# 2020/10/01 13:18:16
# episode : 161 | final step : 96 | total reward : 0.0
# 2020/10/01 13:18:19
# episode : 162 | final step : 100 | total reward : 0.0
# 2020/10/01 13:18:22
# episode : 163 | final step : 100 | total reward : 0.0
# 2020/10/01 13:18:25
# episode : 164 | final step : 100 | total reward : -1.0
# 2020/10/01 13:18:28
# episode : 165 | final step : 100 | total reward : 0.0
# 2020/10/01 13:18:31
# episode : 166 | final step : 99 | total reward : 0.0
# 2020/10/01 13:18:34
# episode : 167 | final step : 99 | total reward : 0.0
# 2020/10/01 13:18:37
# episode : 168 | final step : 98 | total reward : -1.0
# 2020/10/01 13:18:39
# episode : 169 | final step : 98 | total reward : -1.0
# 2020/10/01 13:18:42
# episode : 170 | final step : 101 | total reward : 0.0
# 2020/10/01 13:18:45
# episode : 171 | final step : 99 | total reward : 0.0
# 2020/10/01 13:18:48
# episode : 172 | final step : 99 | total reward : -1.0
# 2020/10/01 13:18:51
# episode : 173 | final step : 99 | total reward : 0.0
# 2020/10/01 13:18:54
# episode : 174 | final step : 98 | total reward : -1.0
# 2020/10/01 13:18:56
# episode : 175 | final step : 98 | total reward : 0.0
# 2020/10/01 13:18:59
# episode : 176 | final step : 99 | total reward : 0.0
# 2020/10/01 13:19:02
# episode : 177 | final step : 96 | total reward : 0.0
# 2020/10/01 13:19:05
# episode : 178 | final step : 100 | total reward : 0.0
# 2020/10/01 13:19:08
# episode : 179 | final step : 100 | total reward : 0.0
# 2020/10/01 13:19:10
# episode : 180 | final step : 97 | total reward : 0.0
# 2020/10/01 13:19:13
# episode : 181 | final step : 98 | total reward : 0.0
# 2020/10/01 13:19:16
# episode : 182 | final step : 100 | total reward : 0.0
# 2020/10/01 13:19:19
# episode : 183 | final step : 100 | total reward : 0.0
# 2020/10/01 13:19:22
# episode : 184 | final step : 97 | total reward : 0.0
# 2020/10/01 13:19:25
# episode : 185 | final step : 99 | total reward : 0.0
# 2020/10/01 13:19:27
# episode : 186 | final step : 98 | total reward : -1.0
# 2020/10/01 13:19:30
# episode : 187 | final step : 94 | total reward : 0.0
# 2020/10/01 13:19:33
# episode : 188 | final step : 100 | total reward : 0.0
# 2020/10/01 13:19:36
# episode : 189 | final step : 100 | total reward : 0.0
# 2020/10/01 13:19:39
# episode : 190 | final step : 96 | total reward : 0.0
# 2020/10/01 13:19:42
# episode : 191 | final step : 100 | total reward : 0.0
# 2020/10/01 13:19:44
# episode : 192 | final step : 97 | total reward : 0.0
# 2020/10/01 13:19:47
# episode : 193 | final step : 100 | total reward : 0.0
# 2020/10/01 13:19:50
# episode : 194 | final step : 97 | total reward : 0.0
# 2020/10/01 13:19:53
# episode : 195 | final step : 98 | total reward : -1.0
# 2020/10/01 13:19:55
# episode : 196 | final step : 98 | total reward : 0.0
# 2020/10/01 13:19:59
# episode : 197 | final step : 99 | total reward : 0.0
# 2020/10/01 13:20:01
# episode : 198 | final step : 100 | total reward : 0.0
# 2020/10/01 13:20:04
# episode : 199 | final step : 98 | total reward : -1.0
# 2020/10/01 13:20:07
# episode : 200 | final step : 97 | total reward : 0.0
# 2020/10/01 13:20:10
# episode : 201 | final step : 99 | total reward : -1.0
# 2020/10/01 13:20:13
# episode : 202 | final step : 98 | total reward : -1.0
# 2020/10/01 13:20:15
# episode : 203 | final step : 101 | total reward : 0.0
# 2020/10/01 13:20:18
# episode : 204 | final step : 100 | total reward : 0.0
# 2020/10/01 13:20:21
# episode : 205 | final step : 99 | total reward : 0.0
# 2020/10/01 13:20:24
# episode : 206 | final step : 98 | total reward : 0.0
# 2020/10/01 13:20:27
# episode : 207 | final step : 100 | total reward : 0.0
# 2020/10/01 13:20:30
# episode : 208 | final step : 100 | total reward : 0.0
# 2020/10/01 13:20:33
# episode : 209 | final step : 97 | total reward : 0.0
# 2020/10/01 13:20:35
# episode : 210 | final step : 97 | total reward : 0.0
# 2020/10/01 13:20:38
# episode : 211 | final step : 98 | total reward : -1.0
# 2020/10/01 13:20:41
# episode : 212 | final step : 100 | total reward : 0.0
# 2020/10/01 13:20:44
# episode : 213 | final step : 100 | total reward : 0.0
# 2020/10/01 13:20:46
# episode : 214 | final step : 98 | total reward : -1.0
# 2020/10/01 13:20:49
# episode : 215 | final step : 98 | total reward : 0.0
# 2020/10/01 13:20:52
# episode : 216 | final step : 96 | total reward : 0.0
# 2020/10/01 13:20:55
# episode : 217 | final step : 98 | total reward : 0.0
# 2020/10/01 13:20:58
# episode : 218 | final step : 98 | total reward : 0.0
# 2020/10/01 13:21:01
# episode : 219 | final step : 99 | total reward : 0.0
# 2020/10/01 13:21:04
# episode : 220 | final step : 99 | total reward : 0.0
# 2020/10/01 13:21:07
# episode : 221 | final step : 99 | total reward : -1.0
# 2020/10/01 13:21:09
# episode : 222 | final step : 99 | total reward : 0.0
# 2020/10/01 13:21:12
# episode : 223 | final step : 98 | total reward : 0.0
# 2020/10/01 13:21:15
# episode : 224 | final step : 96 | total reward : 0.0
# 2020/10/01 13:21:18
# episode : 225 | final step : 96 | total reward : 0.0
# 2020/10/01 13:21:21
# episode : 226 | final step : 99 | total reward : 0.0
# 2020/10/01 13:21:23
# episode : 227 | final step : 97 | total reward : 0.0
# 2020/10/01 13:21:26
# episode : 228 | final step : 98 | total reward : 0.0
# 2020/10/01 13:21:29
# episode : 229 | final step : 100 | total reward : 0.0
# 2020/10/01 13:21:32
# episode : 230 | final step : 100 | total reward : 0.0
# 2020/10/01 13:21:35
# episode : 231 | final step : 101 | total reward : 0.0
# 2020/10/01 13:21:38
# episode : 232 | final step : 100 | total reward : 0.0
# 2020/10/01 13:21:41
# episode : 233 | final step : 98 | total reward : 0.0
# 2020/10/01 13:21:43
# episode : 234 | final step : 98 | total reward : -1.0
# 2020/10/01 13:21:46
# episode : 235 | final step : 99 | total reward : -1.0
# 2020/10/01 13:21:49
# episode : 236 | final step : 100 | total reward : 0.0
# 2020/10/01 13:21:52
# episode : 237 | final step : 99 | total reward : 0.0
# 2020/10/01 13:21:55
# episode : 238 | final step : 100 | total reward : 0.0
# 2020/10/01 13:21:58
# episode : 239 | final step : 98 | total reward : -1.0
# 2020/10/01 13:22:01
# episode : 240 | final step : 100 | total reward : 0.0
# 2020/10/01 13:22:03
# episode : 241 | final step : 98 | total reward : -1.0
# 2020/10/01 13:22:06
# episode : 242 | final step : 100 | total reward : 0.0
# 2020/10/01 13:22:09
# episode : 243 | final step : 99 | total reward : 0.0
# 2020/10/01 13:22:12
# episode : 244 | final step : 100 | total reward : 0.0
# 2020/10/01 13:22:15
# episode : 245 | final step : 94 | total reward : 0.0
# 2020/10/01 13:22:18
# episode : 246 | final step : 98 | total reward : -1.0
# 2020/10/01 13:22:21
# episode : 247 | final step : 99 | total reward : -1.0
# 2020/10/01 13:22:23
# episode : 248 | final step : 99 | total reward : 0.0
# 2020/10/01 13:22:26
# episode : 249 | final step : 99 | total reward : 0.0
# 2020/10/01 13:22:29
# episode : 250 | final step : 98 | total reward : -1.0
# 2020/10/01 13:22:32
# episode : 251 | final step : 90 | total reward : 0.0
# 2020/10/01 13:22:35
# episode : 252 | final step : 100 | total reward : 0.0
# 2020/10/01 13:22:38
# episode : 253 | final step : 97 | total reward : 0.0
# 2020/10/01 13:22:41
# episode : 254 | final step : 98 | total reward : -1.0
# 2020/10/01 13:22:43
# episode : 255 | final step : 98 | total reward : -1.0
# 2020/10/01 13:22:46
# episode : 256 | final step : 98 | total reward : -1.0
# 2020/10/01 13:22:49
# episode : 257 | final step : 97 | total reward : 0.0
# 2020/10/01 13:22:52
# episode : 258 | final step : 98 | total reward : -1.0
# 2020/10/01 13:22:55
# episode : 259 | final step : 96 | total reward : 0.0
# 2020/10/01 13:22:58
# episode : 260 | final step : 100 | total reward : 0.0
# 2020/10/01 13:23:00
# episode : 261 | final step : 96 | total reward : 0.0
# 2020/10/01 13:23:03
# episode : 262 | final step : 103 | total reward : 0.0
# 2020/10/01 13:23:06
# episode : 263 | final step : 99 | total reward : 0.0
# 2020/10/01 13:23:09
# episode : 264 | final step : 99 | total reward : 0.0
# 2020/10/01 13:23:12
# episode : 265 | final step : 103 | total reward : 0.0
# 2020/10/01 13:23:15
# episode : 266 | final step : 99 | total reward : -1.0
# 2020/10/01 13:23:18
# episode : 267 | final step : 98 | total reward : -1.0
# 2020/10/01 13:23:21
# episode : 268 | final step : 99 | total reward : -1.0
# 2020/10/01 13:23:23
# episode : 269 | final step : 99 | total reward : 0.0
# 2020/10/01 13:23:26
# episode : 270 | final step : 99 | total reward : 0.0
# 2020/10/01 13:23:29
# episode : 271 | final step : 98 | total reward : -1.0
# 2020/10/01 13:23:31
# episode : 272 | final step : 98 | total reward : 0.0
# 2020/10/01 13:23:35
# episode : 273 | final step : 98 | total reward : -1.0
# 2020/10/01 13:23:37
# episode : 274 | final step : 99 | total reward : 0.0
# 2020/10/01 13:23:40
# episode : 275 | final step : 94 | total reward : 0.0
# 2020/10/01 13:23:43
# episode : 276 | final step : 100 | total reward : 0.0
# 2020/10/01 13:23:46
# episode : 277 | final step : 99 | total reward : -1.0
# 2020/10/01 13:23:48
# episode : 278 | final step : 99 | total reward : 0.0
# 2020/10/01 13:23:51
# episode : 279 | final step : 100 | total reward : 0.0
# 2020/10/01 13:23:54
# episode : 280 | final step : 100 | total reward : 0.0
# 2020/10/01 13:23:57
# episode : 281 | final step : 99 | total reward : -1.0
# 2020/10/01 13:24:00
# episode : 282 | final step : 96 | total reward : 0.0
# 2020/10/01 13:24:03
# episode : 283 | final step : 99 | total reward : -1.0
# 2020/10/01 13:24:06
# episode : 284 | final step : 99 | total reward : 0.0
# 2020/10/01 13:24:08
# episode : 285 | final step : 100 | total reward : 0.0
# 2020/10/01 13:24:11
# episode : 286 | final step : 100 | total reward : 0.0
# 2020/10/01 13:24:14
# episode : 287 | final step : 99 | total reward : 0.0
# 2020/10/01 13:24:17
# episode : 288 | final step : 101 | total reward : 0.0
# 2020/10/01 13:24:20
# episode : 289 | final step : 98 | total reward : -1.0
# 2020/10/01 13:24:23
# episode : 290 | final step : 100 | total reward : 0.0
# 2020/10/01 13:24:26
# episode : 291 | final step : 98 | total reward : -1.0
# 2020/10/01 13:24:29
# episode : 292 | final step : 100 | total reward : 0.0
# 2020/10/01 13:24:32
# episode : 293 | final step : 97 | total reward : 0.0
# 2020/10/01 13:24:34
# episode : 294 | final step : 99 | total reward : 0.0
# 2020/10/01 13:24:37
# episode : 295 | final step : 98 | total reward : 0.0
# 2020/10/01 13:24:40
# episode : 296 | final step : 98 | total reward : 0.0
# 2020/10/01 13:24:43
# episode : 297 | final step : 99 | total reward : 0.0
# 2020/10/01 13:24:46
# episode : 298 | final step : 99 | total reward : 0.0
# 2020/10/01 13:24:49
# episode : 299 | final step : 97 | total reward : 0.0
# 2020/10/01 13:24:52
# episode : 300 | final step : 99 | total reward : -1.0
# 2020/10/01 13:24:55
# episode : 301 | final step : 99 | total reward : 0.0
# 2020/10/01 13:24:57
# episode : 302 | final step : 99 | total reward : 0.0
# 2020/10/01 13:25:00
# episode : 303 | final step : 99 | total reward : 0.0
# 2020/10/01 13:25:03
# episode : 304 | final step : 95 | total reward : 0.0
# 2020/10/01 13:25:06
# episode : 305 | final step : 98 | total reward : 0.0
# 2020/10/01 13:25:09
# episode : 306 | final step : 98 | total reward : -1.0
# 2020/10/01 13:25:12
# episode : 307 | final step : 98 | total reward : -1.0
# 2020/10/01 13:25:15
# episode : 308 | final step : 98 | total reward : -1.0
# 2020/10/01 13:25:17
# episode : 309 | final step : 93 | total reward : 0.0
# 2020/10/01 13:25:20
# episode : 310 | final step : 99 | total reward : -1.0
# 2020/10/01 13:25:23
# episode : 311 | final step : 99 | total reward : 0.0
# 2020/10/01 13:25:26
# episode : 312 | final step : 99 | total reward : 0.0
# 2020/10/01 13:25:29
# episode : 313 | final step : 98 | total reward : 0.0
# 2020/10/01 13:25:31
# episode : 314 | final step : 98 | total reward : 0.0
# 2020/10/01 13:25:34
# episode : 315 | final step : 96 | total reward : 0.0
# 2020/10/01 13:25:37
# episode : 316 | final step : 98 | total reward : 0.0
# 2020/10/01 13:25:40
# episode : 317 | final step : 97 | total reward : 0.0
# 2020/10/01 13:25:42
# episode : 318 | final step : 96 | total reward : 0.0
# 2020/10/01 13:25:45
# episode : 319 | final step : 96 | total reward : 0.0
# 2020/10/01 13:25:48
# episode : 320 | final step : 93 | total reward : 0.0
# 2020/10/01 13:25:51
# episode : 321 | final step : 100 | total reward : -1.0
# 2020/10/01 13:25:53
# episode : 322 | final step : 91 | total reward : 0.0
# 2020/10/01 13:25:56
# episode : 323 | final step : 100 | total reward : 0.0
# 2020/10/01 13:25:59
# episode : 324 | final step : 98 | total reward : -1.0
# 2020/10/01 13:26:02
# episode : 325 | final step : 99 | total reward : -1.0
# 2020/10/01 13:26:05
# episode : 326 | final step : 100 | total reward : 0.0
# 2020/10/01 13:26:08
# episode : 327 | final step : 96 | total reward : 0.0
# 2020/10/01 13:26:11
# episode : 328 | final step : 99 | total reward : 0.0
# 2020/10/01 13:26:13
# episode : 329 | final step : 98 | total reward : -1.0
# 2020/10/01 13:26:16
# episode : 330 | final step : 98 | total reward : 0.0
# 2020/10/01 13:26:19
# episode : 331 | final step : 98 | total reward : -1.0
# 2020/10/01 13:26:22
# episode : 332 | final step : 97 | total reward : 0.0
# 2020/10/01 13:26:24
# episode : 333 | final step : 96 | total reward : 0.0
# 2020/10/01 13:26:27
# episode : 334 | final step : 100 | total reward : 0.0
# 2020/10/01 13:26:30
# episode : 335 | final step : 99 | total reward : 0.0
# 2020/10/01 13:26:33
# episode : 336 | final step : 97 | total reward : 0.0
# 2020/10/01 13:26:36
# episode : 337 | final step : 99 | total reward : 0.0
# 2020/10/01 13:26:39
# episode : 338 | final step : 99 | total reward : -1.0
# 2020/10/01 13:26:42
# episode : 339 | final step : 98 | total reward : 0.0
# 2020/10/01 13:26:44
# episode : 340 | final step : 100 | total reward : 0.0
# 2020/10/01 13:26:47
# episode : 341 | final step : 99 | total reward : 0.0
# 2020/10/01 13:26:50
# episode : 342 | final step : 100 | total reward : 0.0
# 2020/10/01 13:26:53
# episode : 343 | final step : 99 | total reward : 0.0
# 2020/10/01 13:26:56
# episode : 344 | final step : 96 | total reward : 0.0
# 2020/10/01 13:26:58
# episode : 345 | final step : 100 | total reward : 0.0
# 2020/10/01 13:27:01
# episode : 346 | final step : 99 | total reward : 0.0
# 2020/10/01 13:27:04
# episode : 347 | final step : 97 | total reward : 0.0
# 2020/10/01 13:27:06
# episode : 348 | final step : 94 | total reward : 0.0
# 2020/10/01 13:27:09
# episode : 349 | final step : 98 | total reward : -1.0
# 2020/10/01 13:27:12
# episode : 350 | final step : 100 | total reward : 0.0
# 2020/10/01 13:27:15
# episode : 351 | final step : 96 | total reward : 0.0
# 2020/10/01 13:27:18
# episode : 352 | final step : 98 | total reward : -1.0
# 2020/10/01 13:27:20
# episode : 353 | final step : 98 | total reward : 0.0
# 2020/10/01 13:27:23
# episode : 354 | final step : 91 | total reward : 0.0
# 2020/10/01 13:27:26
# episode : 355 | final step : 95 | total reward : 0.0
# 2020/10/01 13:27:28
# episode : 356 | final step : 99 | total reward : 0.0
# 2020/10/01 13:27:31
# episode : 357 | final step : 99 | total reward : 0.0
# 2020/10/01 13:27:34
# episode : 358 | final step : 97 | total reward : 0.0
# 2020/10/01 13:27:37
# episode : 359 | final step : 99 | total reward : 0.0
# 2020/10/01 13:27:40
# episode : 360 | final step : 97 | total reward : 0.0
# 2020/10/01 13:27:43
# episode : 361 | final step : 97 | total reward : 0.0
# 2020/10/01 13:27:46
# episode : 362 | final step : 99 | total reward : -1.0
# 2020/10/01 13:27:48
# episode : 363 | final step : 95 | total reward : 0.0
# 2020/10/01 13:27:51
# episode : 364 | final step : 99 | total reward : 0.0
# 2020/10/01 13:27:54
# episode : 365 | final step : 98 | total reward : 0.0
# 2020/10/01 13:27:57
# episode : 366 | final step : 98 | total reward : -1.0
# 2020/10/01 13:27:59
# episode : 367 | final step : 100 | total reward : 0.0
# 2020/10/01 13:28:02
# episode : 368 | final step : 99 | total reward : -1.0
# 2020/10/01 13:28:05
# episode : 369 | final step : 100 | total reward : 0.0
# 2020/10/01 13:28:08
# episode : 370 | final step : 97 | total reward : 0.0
# 2020/10/01 13:28:11
# episode : 371 | final step : 97 | total reward : 0.0
# 2020/10/01 13:28:13
# episode : 372 | final step : 98 | total reward : -1.0
# 2020/10/01 13:28:16
# episode : 373 | final step : 100 | total reward : 0.0
# 2020/10/01 13:28:19
# episode : 374 | final step : 99 | total reward : 0.0
# 2020/10/01 13:28:22
# episode : 375 | final step : 96 | total reward : 0.0
# 2020/10/01 13:28:25
# episode : 376 | final step : 96 | total reward : 0.0
# 2020/10/01 13:28:28
# episode : 377 | final step : 100 | total reward : 0.0
# 2020/10/01 13:28:31
# episode : 378 | final step : 100 | total reward : 0.0
# 2020/10/01 13:28:33
# episode : 379 | final step : 95 | total reward : 0.0
# 2020/10/01 13:28:36
# episode : 380 | final step : 97 | total reward : 0.0
# 2020/10/01 13:28:39
# episode : 381 | final step : 97 | total reward : 0.0
# 2020/10/01 13:28:42
# episode : 382 | final step : 98 | total reward : -1.0
# 2020/10/01 13:28:45
# episode : 383 | final step : 97 | total reward : 0.0
# 2020/10/01 13:28:47
# episode : 384 | final step : 97 | total reward : 0.0
# 2020/10/01 13:28:50
# episode : 385 | final step : 96 | total reward : 0.0
# 2020/10/01 13:28:53
# episode : 386 | final step : 100 | total reward : 0.0
# 2020/10/01 13:28:56
# episode : 387 | final step : 94 | total reward : 0.0
# 2020/10/01 13:28:59
# episode : 388 | final step : 99 | total reward : 0.0
# 2020/10/01 13:29:02
# episode : 389 | final step : 98 | total reward : 0.0
# 2020/10/01 13:29:04
# episode : 390 | final step : 98 | total reward : -1.0
# 2020/10/01 13:29:07
# episode : 391 | final step : 95 | total reward : 0.0
# 2020/10/01 13:29:10
# episode : 392 | final step : 98 | total reward : -1.0
# 2020/10/01 13:29:13
# episode : 393 | final step : 99 | total reward : -1.0
# 2020/10/01 13:29:16
# episode : 394 | final step : 99 | total reward : -1.0
# 2020/10/01 13:29:19
# episode : 395 | final step : 100 | total reward : 0.0
# 2020/10/01 13:29:21
# episode : 396 | final step : 96 | total reward : 0.0
# 2020/10/01 13:29:24
# episode : 397 | final step : 98 | total reward : 0.0
# 2020/10/01 13:29:27
# episode : 398 | final step : 100 | total reward : 0.0
# 2020/10/01 13:29:30
# episode : 399 | final step : 97 | total reward : 0.0
# 2020/10/01 13:29:32
# episode : 400 | final step : 98 | total reward : -1.0
# 2020/10/01 13:29:35
# episode : 401 | final step : 98 | total reward : -1.0
# 2020/10/01 13:29:38
# episode : 402 | final step : 99 | total reward : 0.0
# 2020/10/01 13:29:41
# episode : 403 | final step : 98 | total reward : -1.0
# 2020/10/01 13:29:44
# episode : 404 | final step : 99 | total reward : 0.0
# 2020/10/01 13:29:47
# episode : 405 | final step : 96 | total reward : 0.0
# 2020/10/01 13:29:49
# episode : 406 | final step : 100 | total reward : -1.0
# 2020/10/01 13:29:52
# episode : 407 | final step : 100 | total reward : 0.0
# 2020/10/01 13:29:55
# episode : 408 | final step : 96 | total reward : 0.0
# 2020/10/01 13:29:58
# episode : 409 | final step : 100 | total reward : 0.0
# 2020/10/01 13:30:01
# episode : 410 | final step : 98 | total reward : 0.0
# 2020/10/01 13:30:04
# episode : 411 | final step : 98 | total reward : 0.0
# 2020/10/01 13:30:07
# episode : 412 | final step : 99 | total reward : 0.0
# 2020/10/01 13:30:10
# episode : 413 | final step : 99 | total reward : -1.0
# 2020/10/01 13:30:12
# episode : 414 | final step : 99 | total reward : 0.0
# 2020/10/01 13:30:15
# episode : 415 | final step : 101 | total reward : 0.0
# 2020/10/01 13:30:18
# episode : 416 | final step : 99 | total reward : 0.0
# 2020/10/01 13:30:21
# episode : 417 | final step : 99 | total reward : 0.0
# 2020/10/01 13:30:24
# episode : 418 | final step : 98 | total reward : 0.0
# 2020/10/01 13:30:27
# episode : 419 | final step : 101 | total reward : 0.0
# 2020/10/01 13:30:30
# episode : 420 | final step : 98 | total reward : -1.0
# 2020/10/01 13:30:33
# episode : 421 | final step : 100 | total reward : 0.0
# 2020/10/01 13:30:35
# episode : 422 | final step : 100 | total reward : -1.0
# 2020/10/01 13:30:38
# episode : 423 | final step : 100 | total reward : 0.0
# 2020/10/01 13:30:41
# episode : 424 | final step : 99 | total reward : 0.0
# 2020/10/01 13:30:44
# episode : 425 | final step : 98 | total reward : -1.0
# 2020/10/01 13:30:46
# episode : 426 | final step : 96 | total reward : 0.0
# 2020/10/01 13:30:49
# episode : 427 | final step : 99 | total reward : 0.0
# 2020/10/01 13:30:52
# episode : 428 | final step : 100 | total reward : 0.0
# 2020/10/01 13:30:55
# episode : 429 | final step : 101 | total reward : 0.0
# 2020/10/01 13:30:58
# episode : 430 | final step : 99 | total reward : 0.0
# 2020/10/01 13:31:01
# episode : 431 | final step : 98 | total reward : -1.0
# 2020/10/01 13:31:04
# episode : 432 | final step : 98 | total reward : -1.0
# 2020/10/01 13:31:06
# episode : 433 | final step : 95 | total reward : 0.0
# 2020/10/01 13:31:09
# episode : 434 | final step : 100 | total reward : 0.0
# 2020/10/01 13:31:12
# episode : 435 | final step : 98 | total reward : 0.0
# 2020/10/01 13:31:15
# episode : 436 | final step : 101 | total reward : 0.0
# 2020/10/01 13:31:18
# episode : 437 | final step : 100 | total reward : 0.0
# 2020/10/01 13:31:21
# episode : 438 | final step : 100 | total reward : 0.0
# 2020/10/01 13:31:24
# episode : 439 | final step : 95 | total reward : 0.0
# 2020/10/01 13:31:26
# episode : 440 | final step : 98 | total reward : -1.0
# 2020/10/01 13:31:29
# episode : 441 | final step : 98 | total reward : -1.0
# 2020/10/01 13:31:32
# episode : 442 | final step : 98 | total reward : 0.0
# 2020/10/01 13:31:35
# episode : 443 | final step : 98 | total reward : -1.0
# 2020/10/01 13:31:37
# episode : 444 | final step : 92 | total reward : 0.0
# 2020/10/01 13:31:40
# episode : 445 | final step : 96 | total reward : 0.0
# 2020/10/01 13:31:43
# episode : 446 | final step : 100 | total reward : 0.0
# 2020/10/01 13:31:46
# episode : 447 | final step : 94 | total reward : 0.0
# 2020/10/01 13:31:48
# episode : 448 | final step : 94 | total reward : 0.0
# 2020/10/01 13:31:51
# episode : 449 | final step : 100 | total reward : 0.0
# 2020/10/01 13:31:53
# episode : 450 | final step : 89 | total reward : 0.0
# 2020/10/01 13:31:56
# episode : 451 | final step : 100 | total reward : 0.0
# 2020/10/01 13:31:59
# episode : 452 | final step : 93 | total reward : 0.0
# 2020/10/01 13:32:02
# episode : 453 | final step : 100 | total reward : 0.0
# 2020/10/01 13:32:05
# episode : 454 | final step : 98 | total reward : -1.0
# 2020/10/01 13:32:08
# episode : 455 | final step : 99 | total reward : 0.0
# 2020/10/01 13:32:10
# episode : 456 | final step : 98 | total reward : 0.0
# 2020/10/01 13:32:13
# episode : 457 | final step : 99 | total reward : 0.0
# 2020/10/01 13:32:16
# episode : 458 | final step : 99 | total reward : -1.0
# 2020/10/01 13:32:19
# episode : 459 | final step : 98 | total reward : -1.0
# 2020/10/01 13:32:22
# episode : 460 | final step : 99 | total reward : -1.0
# 2020/10/01 13:32:25
# episode : 461 | final step : 100 | total reward : 0.0
# 2020/10/01 13:32:28
# episode : 462 | final step : 99 | total reward : -1.0
# 2020/10/01 13:32:31
# episode : 463 | final step : 99 | total reward : 0.0
# 2020/10/01 13:32:34
# episode : 464 | final step : 98 | total reward : -1.0
# 2020/10/01 13:32:36
# episode : 465 | final step : 98 | total reward : -1.0
# 2020/10/01 13:32:39
# episode : 466 | final step : 98 | total reward : -1.0
# 2020/10/01 13:32:42
# episode : 467 | final step : 100 | total reward : 0.0
# 2020/10/01 13:32:45
# episode : 468 | final step : 100 | total reward : 0.0
# 2020/10/01 13:32:48
# episode : 469 | final step : 96 | total reward : 0.0
# 2020/10/01 13:32:51
# episode : 470 | final step : 99 | total reward : 0.0
# 2020/10/01 13:32:54
# episode : 471 | final step : 98 | total reward : -1.0
# 2020/10/01 13:32:57
# episode : 472 | final step : 99 | total reward : 0.0
# 2020/10/01 13:33:00
# episode : 473 | final step : 95 | total reward : 0.0
# 2020/10/01 13:33:02
# episode : 474 | final step : 99 | total reward : 0.0
# 2020/10/01 13:33:05
# episode : 475 | final step : 99 | total reward : 0.0
# 2020/10/01 13:33:08
# episode : 476 | final step : 96 | total reward : 0.0
# 2020/10/01 13:33:11
# episode : 477 | final step : 95 | total reward : 0.0
# 2020/10/01 13:33:14
# episode : 478 | final step : 98 | total reward : 0.0
# 2020/10/01 13:33:16
# episode : 479 | final step : 99 | total reward : -1.0
# 2020/10/01 13:33:19
# episode : 480 | final step : 99 | total reward : -1.0
# 2020/10/01 13:33:23
# episode : 481 | final step : 100 | total reward : 0.0
# 2020/10/01 13:33:25
# episode : 482 | final step : 99 | total reward : 0.0
# 2020/10/01 13:33:28
# episode : 483 | final step : 100 | total reward : 0.0
# 2020/10/01 13:33:31
# episode : 484 | final step : 97 | total reward : 0.0
# 2020/10/01 13:33:34
# episode : 485 | final step : 98 | total reward : 0.0
# 2020/10/01 13:33:37
# episode : 486 | final step : 95 | total reward : 0.0
# 2020/10/01 13:33:39
# episode : 487 | final step : 99 | total reward : -1.0
# 2020/10/01 13:33:42
# episode : 488 | final step : 99 | total reward : 0.0
# 2020/10/01 13:33:45
# episode : 489 | final step : 100 | total reward : 0.0
# 2020/10/01 13:33:48
# episode : 490 | final step : 99 | total reward : 0.0
# 2020/10/01 13:33:51
# episode : 491 | final step : 96 | total reward : 0.0
# 2020/10/01 13:33:54
# episode : 492 | final step : 95 | total reward : 0.0
# 2020/10/01 13:33:57
# episode : 493 | final step : 99 | total reward : 0.0
# 2020/10/01 13:33:59
# episode : 494 | final step : 99 | total reward : -1.0
# 2020/10/01 13:34:02
# episode : 495 | final step : 100 | total reward : 0.0
# 2020/10/01 13:34:05
# episode : 496 | final step : 98 | total reward : 0.0
# 2020/10/01 13:34:08
# episode : 497 | final step : 98 | total reward : 0.0
# 2020/10/01 13:34:11
# episode : 498 | final step : 97 | total reward : -1.0
# 2020/10/01 13:34:13
# episode : 499 | final step : 99 | total reward : -1.0
# 2020/10/01 13:34:16
# episode : 500 | final step : 100 | total reward : 0.0
# 2020/10/01 13:34:19
# episode : 501 | final step : 100 | total reward : 0.0
# 2020/10/01 13:34:22
# episode : 502 | final step : 100 | total reward : 0.0
# 2020/10/01 13:34:25
# episode : 503 | final step : 98 | total reward : 0.0
# 2020/10/01 13:34:28
# episode : 504 | final step : 98 | total reward : 0.0
# 2020/10/01 13:34:31
# episode : 505 | final step : 100 | total reward : 0.0
# 2020/10/01 13:34:34
# episode : 506 | final step : 100 | total reward : 0.0
# 2020/10/01 13:34:37
# episode : 507 | final step : 99 | total reward : 0.0
# 2020/10/01 13:34:40
# episode : 508 | final step : 98 | total reward : 0.0
# 2020/10/01 13:34:42
# episode : 509 | final step : 100 | total reward : 0.0
# 2020/10/01 13:34:45
# episode : 510 | final step : 98 | total reward : -1.0
# 2020/10/01 13:34:48
# episode : 511 | final step : 99 | total reward : -1.0
# 2020/10/01 13:34:51
# episode : 512 | final step : 94 | total reward : 0.0
# 2020/10/01 13:34:54
# episode : 513 | final step : 98 | total reward : -1.0
# 2020/10/01 13:34:56
# episode : 514 | final step : 98 | total reward : -1.0
# 2020/10/01 13:34:59
# episode : 515 | final step : 99 | total reward : -1.0
# 2020/10/01 13:35:03
# episode : 516 | final step : 100 | total reward : 0.0
# 2020/10/01 13:35:05
# episode : 517 | final step : 100 | total reward : 0.0
# 2020/10/01 13:35:08
# episode : 518 | final step : 99 | total reward : 0.0
# 2020/10/01 13:35:11
# episode : 519 | final step : 98 | total reward : 0.0
# 2020/10/01 13:35:14
# episode : 520 | final step : 98 | total reward : -1.0
# 2020/10/01 13:35:17
# episode : 521 | final step : 98 | total reward : -1.0
# 2020/10/01 13:35:20
# episode : 522 | final step : 97 | total reward : 0.0
# 2020/10/01 13:35:22
# episode : 523 | final step : 100 | total reward : 0.0
# 2020/10/01 13:35:25
# episode : 524 | final step : 98 | total reward : -1.0
# 2020/10/01 13:35:28
# episode : 525 | final step : 99 | total reward : 0.0
# 2020/10/01 13:35:31
# episode : 526 | final step : 93 | total reward : 0.0
# 2020/10/01 13:35:33
# episode : 527 | final step : 98 | total reward : 0.0
# 2020/10/01 13:35:36
# episode : 528 | final step : 99 | total reward : 0.0
# 2020/10/01 13:35:39
# episode : 529 | final step : 99 | total reward : 0.0
# 2020/10/01 13:35:42
# episode : 530 | final step : 100 | total reward : 0.0
# 2020/10/01 13:35:45
# episode : 531 | final step : 100 | total reward : 0.0
# 2020/10/01 13:35:48
# episode : 532 | final step : 98 | total reward : 0.0
# 2020/10/01 13:35:51
# episode : 533 | final step : 99 | total reward : 0.0
# 2020/10/01 13:35:54
# episode : 534 | final step : 99 | total reward : 0.0
# 2020/10/01 13:35:57
# episode : 535 | final step : 99 | total reward : 0.0
# 2020/10/01 13:36:00
# episode : 536 | final step : 98 | total reward : 0.0
# 2020/10/01 13:36:03
# episode : 537 | final step : 97 | total reward : 0.0
# 2020/10/01 13:36:05
# episode : 538 | final step : 97 | total reward : 0.0
# 2020/10/01 13:36:08
# episode : 539 | final step : 100 | total reward : 0.0
# 2020/10/01 13:36:11
# episode : 540 | final step : 99 | total reward : 0.0
# 2020/10/01 13:36:14
# episode : 541 | final step : 98 | total reward : 0.0
# 2020/10/01 13:36:17
# episode : 542 | final step : 99 | total reward : 0.0
# 2020/10/01 13:36:19
# episode : 543 | final step : 98 | total reward : -1.0
# 2020/10/01 13:36:22
# episode : 544 | final step : 99 | total reward : 0.0
# 2020/10/01 13:36:25
# episode : 545 | final step : 98 | total reward : 0.0
# 2020/10/01 13:36:28
# episode : 546 | final step : 100 | total reward : 0.0
# 2020/10/01 13:36:31
# episode : 547 | final step : 96 | total reward : 0.0
# 2020/10/01 13:36:34
# episode : 548 | final step : 98 | total reward : -1.0
# 2020/10/01 13:36:36
# episode : 549 | final step : 96 | total reward : 0.0
# 2020/10/01 13:36:39
# episode : 550 | final step : 99 | total reward : 0.0
# 2020/10/01 13:36:42
# episode : 551 | final step : 98 | total reward : -1.0
# 2020/10/01 13:36:45
# episode : 552 | final step : 97 | total reward : 0.0
# 2020/10/01 13:36:48
# episode : 553 | final step : 100 | total reward : 0.0
# 2020/10/01 13:36:50
# episode : 554 | final step : 98 | total reward : -1.0
# 2020/10/01 13:36:53
# episode : 555 | final step : 99 | total reward : 0.0
# 2020/10/01 13:36:56
# episode : 556 | final step : 94 | total reward : 0.0
# 2020/10/01 13:36:59
# episode : 557 | final step : 97 | total reward : -1.0
# 2020/10/01 13:37:01
# episode : 558 | final step : 95 | total reward : 0.0
# 2020/10/01 13:37:04
# episode : 559 | final step : 99 | total reward : 0.0
# 2020/10/01 13:37:07
# episode : 560 | final step : 100 | total reward : 0.0
# 2020/10/01 13:37:10
# episode : 561 | final step : 99 | total reward : -1.0
# 2020/10/01 13:37:12
# episode : 562 | final step : 97 | total reward : 0.0
# 2020/10/01 13:37:15
# episode : 563 | final step : 94 | total reward : 0.0
# 2020/10/01 13:37:18
# episode : 564 | final step : 99 | total reward : 0.0
# 2020/10/01 13:37:21
# episode : 565 | final step : 98 | total reward : 0.0
# 2020/10/01 13:37:23
# episode : 566 | final step : 98 | total reward : 0.0
# 2020/10/01 13:37:26
# episode : 567 | final step : 98 | total reward : 0.0
# 2020/10/01 13:37:29
# episode : 568 | final step : 100 | total reward : -1.0
# 2020/10/01 13:37:32
# episode : 569 | final step : 97 | total reward : 0.0
# 2020/10/01 13:37:35
# episode : 570 | final step : 99 | total reward : 0.0
# 2020/10/01 13:37:37
# episode : 571 | final step : 99 | total reward : 0.0
# 2020/10/01 13:37:40
# episode : 572 | final step : 100 | total reward : -1.0
# 2020/10/01 13:37:43
# episode : 573 | final step : 100 | total reward : 0.0
# 2020/10/01 13:37:46
# episode : 574 | final step : 99 | total reward : 0.0
# 2020/10/01 13:37:49
# episode : 575 | final step : 100 | total reward : 0.0
# 2020/10/01 13:37:52
# episode : 576 | final step : 98 | total reward : -1.0
# 2020/10/01 13:37:55
# episode : 577 | final step : 95 | total reward : 0.0
# 2020/10/01 13:37:57
# episode : 578 | final step : 100 | total reward : 0.0
# 2020/10/01 13:38:00
# episode : 579 | final step : 101 | total reward : 0.0
# 2020/10/01 13:38:03
# episode : 580 | final step : 98 | total reward : -1.0
# 2020/10/01 13:38:06
# episode : 581 | final step : 98 | total reward : 0.0
# 2020/10/01 13:38:09
# episode : 582 | final step : 100 | total reward : -1.0
# 2020/10/01 13:38:12
# episode : 583 | final step : 99 | total reward : 0.0
# 2020/10/01 13:38:15
# episode : 584 | final step : 95 | total reward : 0.0
# 2020/10/01 13:38:17
# episode : 585 | final step : 100 | total reward : 0.0
# 2020/10/01 13:38:20
# episode : 586 | final step : 100 | total reward : 0.0
# 2020/10/01 13:38:23
# episode : 587 | final step : 99 | total reward : -1.0
# 2020/10/01 13:38:26
# episode : 588 | final step : 99 | total reward : 0.0
# 2020/10/01 13:38:29
# episode : 589 | final step : 99 | total reward : 0.0
# 2020/10/01 13:38:32
# episode : 590 | final step : 100 | total reward : 0.0
# 2020/10/01 13:38:34
# episode : 591 | final step : 98 | total reward : 0.0
# 2020/10/01 13:38:37
# episode : 592 | final step : 95 | total reward : 0.0
# 2020/10/01 13:38:40
# episode : 593 | final step : 100 | total reward : 0.0
# 2020/10/01 13:38:43
# episode : 594 | final step : 98 | total reward : 0.0
# 2020/10/01 13:38:46
# episode : 595 | final step : 100 | total reward : 0.0
# 2020/10/01 13:38:48
# episode : 596 | final step : 101 | total reward : 0.0
# 2020/10/01 13:38:51
# episode : 597 | final step : 99 | total reward : 0.0
# 2020/10/01 13:38:54
# episode : 598 | final step : 98 | total reward : -1.0
# 2020/10/01 13:38:57
# episode : 599 | final step : 96 | total reward : 0.0
# 2020/10/01 13:39:00
# episode : 600 | final step : 98 | total reward : -1.0
# 2020/10/01 13:39:03
# episode : 601 | final step : 99 | total reward : -1.0
# 2020/10/01 13:39:05
# episode : 602 | final step : 98 | total reward : -1.0
# 2020/10/01 13:39:08
# episode : 603 | final step : 95 | total reward : 0.0
# 2020/10/01 13:39:11
# episode : 604 | final step : 98 | total reward : -1.0
# 2020/10/01 13:39:14
# episode : 605 | final step : 99 | total reward : -1.0
# 2020/10/01 13:39:17
# episode : 606 | final step : 99 | total reward : 0.0
# 2020/10/01 13:39:19
# episode : 607 | final step : 95 | total reward : 0.0
# 2020/10/01 13:39:22
# episode : 608 | final step : 92 | total reward : 0.0
# 2020/10/01 13:39:25
# episode : 609 | final step : 99 | total reward : -1.0
# 2020/10/01 13:39:28
# episode : 610 | final step : 98 | total reward : -1.0
# 2020/10/01 13:39:31
# episode : 611 | final step : 100 | total reward : 0.0
# 2020/10/01 13:39:33
# episode : 612 | final step : 93 | total reward : 0.0
# 2020/10/01 13:39:36
# episode : 613 | final step : 100 | total reward : 0.0
# 2020/10/01 13:39:39
# episode : 614 | final step : 99 | total reward : 0.0
# 2020/10/01 13:39:42
# episode : 615 | final step : 100 | total reward : 0.0
# 2020/10/01 13:39:45
# episode : 616 | final step : 98 | total reward : 0.0
# 2020/10/01 13:39:48
# episode : 617 | final step : 101 | total reward : 0.0
# 2020/10/01 13:39:50
# episode : 618 | final step : 97 | total reward : 0.0
# 2020/10/01 13:39:53
# episode : 619 | final step : 99 | total reward : -1.0
# 2020/10/01 13:39:56
# episode : 620 | final step : 98 | total reward : 0.0
# 2020/10/01 13:39:59
# episode : 621 | final step : 96 | total reward : 0.0
# 2020/10/01 13:40:02
# episode : 622 | final step : 99 | total reward : 0.0
# 2020/10/01 13:40:04
# episode : 623 | final step : 97 | total reward : 0.0
# 2020/10/01 13:40:07
# episode : 624 | final step : 100 | total reward : 0.0
# 2020/10/01 13:40:10
# episode : 625 | final step : 100 | total reward : 0.0
# 2020/10/01 13:40:13
# episode : 626 | final step : 99 | total reward : 0.0
# 2020/10/01 13:40:16
# episode : 627 | final step : 99 | total reward : -1.0
# 2020/10/01 13:40:19
# episode : 628 | final step : 95 | total reward : 0.0
# 2020/10/01 13:40:21
# episode : 629 | final step : 100 | total reward : 0.0
# 2020/10/01 13:40:24
# episode : 630 | final step : 98 | total reward : -1.0
# 2020/10/01 13:40:27
# episode : 631 | final step : 98 | total reward : -1.0
# 2020/10/01 13:40:30
# episode : 632 | final step : 100 | total reward : 0.0
# 2020/10/01 13:40:33
# episode : 633 | final step : 99 | total reward : -1.0
# 2020/10/01 13:40:35
# episode : 634 | final step : 95 | total reward : 0.0
# 2020/10/01 13:40:38
# episode : 635 | final step : 98 | total reward : 0.0
# 2020/10/01 13:40:41
# episode : 636 | final step : 101 | total reward : 0.0
# 2020/10/01 13:40:44
# episode : 637 | final step : 98 | total reward : -1.0
# 2020/10/01 13:40:47
# episode : 638 | final step : 100 | total reward : 0.0
# 2020/10/01 13:40:50
# episode : 639 | final step : 97 | total reward : 0.0
# 2020/10/01 13:40:52
# episode : 640 | final step : 99 | total reward : -1.0
# 2020/10/01 13:40:55
# episode : 641 | final step : 100 | total reward : 0.0
# 2020/10/01 13:40:58
# episode : 642 | final step : 99 | total reward : 0.0
# 2020/10/01 13:41:01
# episode : 643 | final step : 100 | total reward : 0.0
# 2020/10/01 13:41:04
# episode : 644 | final step : 98 | total reward : -1.0
# 2020/10/01 13:41:07
# episode : 645 | final step : 95 | total reward : 0.0
# 2020/10/01 13:41:09
# episode : 646 | final step : 99 | total reward : 0.0
# 2020/10/01 13:41:12
# episode : 647 | final step : 99 | total reward : 0.0
# 2020/10/01 13:41:15
# episode : 648 | final step : 99 | total reward : 0.0
# 2020/10/01 13:41:18
# episode : 649 | final step : 99 | total reward : -1.0
# 2020/10/01 13:41:21
# episode : 650 | final step : 99 | total reward : 0.0
# 2020/10/01 13:41:24
# episode : 651 | final step : 99 | total reward : 0.0
# 2020/10/01 13:41:26
# episode : 652 | final step : 96 | total reward : 0.0
# 2020/10/01 13:41:29
# episode : 653 | final step : 99 | total reward : 0.0
# 2020/10/01 13:41:32
# ...
# 2020/10/01 17:41:45
# episode : 5673 | final step : 97 | total reward : 0.0
# 2020/10/01 17:41:48
# episode : 5674 | final step : 99 | total reward : -1.0
# 2020/10/01 17:41:51
# episode : 5675 | final step : 100 | total reward : 0.0
# 2020/10/01 17:41:54
# episode : 5676 | final step : 98 | total reward : -1.0
# 2020/10/01 17:41:57
# episode : 5677 | final step : 100 | total reward : 0.0
# 2020/10/01 17:41:59
# episode : 5678 | final step : 94 | total reward : 0.0
# 2020/10/01 17:42:03
# episode : 5679 | final step : 98 | total reward : -1.0
# 2020/10/01 17:42:05
# episode : 5680 | final step : 100 | total reward : 0.0
# 2020/10/01 17:42:09
# episode : 5681 | final step : 101 | total reward : 0.0
# 2020/10/01 17:42:12
# episode : 5682 | final step : 98 | total reward : 0.0
# 2020/10/01 17:42:15
# episode : 5683 | final step : 100 | total reward : 0.0
# 2020/10/01 17:42:18
# episode : 5684 | final step : 100 | total reward : 0.0
# 2020/10/01 17:42:21
# episode : 5685 | final step : 100 | total reward : 0.0
# 2020/10/01 17:42:24
# episode : 5686 | final step : 99 | total reward : 0.0
# 2020/10/01 17:42:27
# episode : 5687 | final step : 99 | total reward : 0.0
# 2020/10/01 17:42:30
# episode : 5688 | final step : 100 | total reward : 0.0
# 2020/10/01 17:42:32
# episode : 5689 | final step : 92 | total reward : 0.0
# 2020/10/01 17:42:35
# episode : 5690 | final step : 100 | total reward : 0.0
# 2020/10/01 17:42:38
# episode : 5691 | final step : 100 | total reward : 0.0
# 2020/10/01 17:42:41
# episode : 5692 | final step : 97 | total reward : 0.0
# 2020/10/01 17:42:44
# episode : 5693 | final step : 98 | total reward : -1.0
# 2020/10/01 17:42:47
# episode : 5694 | final step : 96 | total reward : 0.0
# 2020/10/01 17:42:50
# episode : 5695 | final step : 97 | total reward : 0.0
# 2020/10/01 17:42:53
# episode : 5696 | final step : 98 | total reward : -1.0
# 2020/10/01 17:42:56
# episode : 5697 | final step : 98 | total reward : 0.0
# 2020/10/01 17:42:59
# episode : 5698 | final step : 98 | total reward : -1.0
# 2020/10/01 17:43:02
# episode : 5699 | final step : 103 | total reward : 0.0
# 2020/10/01 17:43:05
# episode : 5700 | final step : 98 | total reward : -1.0
# 2020/10/01 17:43:08
# episode : 5701 | final step : 100 | total reward : 0.0
# 2020/10/01 17:43:11
# episode : 5702 | final step : 99 | total reward : 0.0
# 2020/10/01 17:43:14
# episode : 5703 | final step : 97 | total reward : 0.0
# 2020/10/01 17:43:17
# episode : 5704 | final step : 99 | total reward : -1.0
# 2020/10/01 17:43:20
# episode : 5705 | final step : 97 | total reward : 0.0
# 2020/10/01 17:43:23
# episode : 5706 | final step : 98 | total reward : 0.0
# 2020/10/01 17:43:26
# episode : 5707 | final step : 95 | total reward : 0.0
# 2020/10/01 17:43:29
# episode : 5708 | final step : 99 | total reward : 0.0
# 2020/10/01 17:43:31
# episode : 5709 | final step : 99 | total reward : 0.0
# 2020/10/01 17:43:34
# episode : 5710 | final step : 100 | total reward : 0.0
# 2020/10/01 17:43:37
# episode : 5711 | final step : 98 | total reward : -1.0
# 2020/10/01 17:43:40
# episode : 5712 | final step : 100 | total reward : 0.0
# 2020/10/01 17:43:43
# episode : 5713 | final step : 100 | total reward : 0.0
# 2020/10/01 17:43:46
# episode : 5714 | final step : 99 | total reward : 0.0
# 2020/10/01 17:43:49
# episode : 5715 | final step : 98 | total reward : 0.0
# 2020/10/01 17:43:52
# episode : 5716 | final step : 100 | total reward : 0.0
# 2020/10/01 17:43:55
# episode : 5717 | final step : 99 | total reward : -1.0
# 2020/10/01 17:43:58
# episode : 5718 | final step : 101 | total reward : 0.0
# 2020/10/01 17:44:01
# episode : 5719 | final step : 98 | total reward : -1.0
# 2020/10/01 17:44:03
# episode : 5720 | final step : 98 | total reward : 0.0
# 2020/10/01 17:44:06
# episode : 5721 | final step : 100 | total reward : 0.0
# 2020/10/01 17:44:10
# episode : 5722 | final step : 100 | total reward : 0.0
# 2020/10/01 17:44:12
# episode : 5723 | final step : 96 | total reward : 0.0
# 2020/10/01 17:44:15
# episode : 5724 | final step : 99 | total reward : -1.0
# 2020/10/01 17:44:18
# episode : 5725 | final step : 99 | total reward : -1.0
# 2020/10/01 17:44:21
# episode : 5726 | final step : 100 | total reward : 0.0
# 2020/10/01 17:44:24
# episode : 5727 | final step : 99 | total reward : 0.0
# 2020/10/01 17:44:27
# episode : 5728 | final step : 99 | total reward : 0.0
# 2020/10/01 17:44:30
# episode : 5729 | final step : 99 | total reward : 0.0
# 2020/10/01 17:44:33
# episode : 5730 | final step : 100 | total reward : 0.0
# 2020/10/01 17:44:36
# episode : 5731 | final step : 98 | total reward : 0.0
# 2020/10/01 17:44:39
# episode : 5732 | final step : 100 | total reward : 0.0
# 2020/10/01 17:44:42
# episode : 5733 | final step : 99 | total reward : 0.0
# 2020/10/01 17:44:45
# episode : 5734 | final step : 96 | total reward : 0.0
# 2020/10/01 17:44:48
# episode : 5735 | final step : 100 | total reward : 0.0
# 2020/10/01 17:44:51
# episode : 5736 | final step : 98 | total reward : -1.0
# 2020/10/01 17:44:54
# episode : 5737 | final step : 98 | total reward : -1.0
# 2020/10/01 17:44:57
# episode : 5738 | final step : 101 | total reward : 0.0
# 2020/10/01 17:45:00
# episode : 5739 | final step : 98 | total reward : 0.0
# 2020/10/01 17:45:03
# episode : 5740 | final step : 100 | total reward : 0.0
# 2020/10/01 17:45:06
# episode : 5741 | final step : 100 | total reward : 0.0
# 2020/10/01 17:45:09
# episode : 5742 | final step : 100 | total reward : 0.0
# 2020/10/01 17:45:12
# episode : 5743 | final step : 99 | total reward : 0.0
# 2020/10/01 17:45:15
# episode : 5744 | final step : 100 | total reward : 0.0
# 2020/10/01 17:45:17
# episode : 5745 | final step : 96 | total reward : 0.0
# 2020/10/01 17:45:20
# episode : 5746 | final step : 99 | total reward : 0.0
# 2020/10/01 17:45:23
# episode : 5747 | final step : 99 | total reward : 0.0
# 2020/10/01 17:45:26
# episode : 5748 | final step : 99 | total reward : 0.0
# 2020/10/01 17:45:29
# episode : 5749 | final step : 100 | total reward : 0.0
# 2020/10/01 17:45:32
# episode : 5750 | final step : 99 | total reward : 0.0
# 2020/10/01 17:45:35
# episode : 5751 | final step : 97 | total reward : 0.0
# 2020/10/01 17:45:38
# episode : 5752 | final step : 99 | total reward : 0.0
# 2020/10/01 17:45:41
# episode : 5753 | final step : 97 | total reward : 0.0
# 2020/10/01 17:45:44
# episode : 5754 | final step : 97 | total reward : 0.0
# 2020/10/01 17:45:47
# episode : 5755 | final step : 97 | total reward : 0.0
# 2020/10/01 17:45:50
# episode : 5756 | final step : 100 | total reward : 0.0
# 2020/10/01 17:45:53
# episode : 5757 | final step : 98 | total reward : -1.0
# 2020/10/01 17:45:56
# episode : 5758 | final step : 98 | total reward : -1.0
# 2020/10/01 17:45:59
# episode : 5759 | final step : 100 | total reward : 0.0
# 2020/10/01 17:46:01
# episode : 5760 | final step : 99 | total reward : 0.0
# 2020/10/01 17:46:04
# episode : 5761 | final step : 98 | total reward : 0.0
# 2020/10/01 17:46:07
# episode : 5762 | final step : 99 | total reward : -1.0
# 2020/10/01 17:46:10
# episode : 5763 | final step : 98 | total reward : -1.0
# 2020/10/01 17:46:13
# episode : 5764 | final step : 99 | total reward : 0.0
# 2020/10/01 17:46:16
# episode : 5765 | final step : 100 | total reward : 0.0
# 2020/10/01 17:46:19
# episode : 5766 | final step : 99 | total reward : -1.0
# 2020/10/01 17:46:22
# episode : 5767 | final step : 97 | total reward : 0.0
# 2020/10/01 17:46:25
# episode : 5768 | final step : 99 | total reward : -1.0
# 2020/10/01 17:46:28
# episode : 5769 | final step : 100 | total reward : 0.0
# 2020/10/01 17:46:31
# episode : 5770 | final step : 98 | total reward : 0.0
# 2020/10/01 17:46:33
# episode : 5771 | final step : 97 | total reward : 0.0
# 2020/10/01 17:46:36
# episode : 5772 | final step : 100 | total reward : -1.0
# 2020/10/01 17:46:39
# episode : 5773 | final step : 98 | total reward : -1.0
# 2020/10/01 17:46:42
# episode : 5774 | final step : 98 | total reward : 0.0
# 2020/10/01 17:46:45
# episode : 5775 | final step : 100 | total reward : 0.0
# 2020/10/01 17:46:48
# episode : 5776 | final step : 96 | total reward : 0.0
# 2020/10/01 17:46:51
# episode : 5777 | final step : 98 | total reward : 0.0
# 2020/10/01 17:46:54
# episode : 5778 | final step : 97 | total reward : 0.0
# 2020/10/01 17:46:57
# episode : 5779 | final step : 100 | total reward : 0.0
# 2020/10/01 17:47:00
# episode : 5780 | final step : 100 | total reward : 0.0
# 2020/10/01 17:47:02
# episode : 5781 | final step : 99 | total reward : 0.0
# 2020/10/01 17:47:05
# episode : 5782 | final step : 99 | total reward : 0.0
# 2020/10/01 17:47:08
# episode : 5783 | final step : 95 | total reward : 0.0
# 2020/10/01 17:47:11
# episode : 5784 | final step : 103 | total reward : 0.0
# 2020/10/01 17:47:14
# episode : 5785 | final step : 100 | total reward : -1.0
# 2020/10/01 17:47:17
# episode : 5786 | final step : 100 | total reward : 0.0
# 2020/10/01 17:47:20
# episode : 5787 | final step : 100 | total reward : 0.0
# 2020/10/01 17:47:23
# episode : 5788 | final step : 100 | total reward : 0.0
# 2020/10/01 17:47:26
# episode : 5789 | final step : 99 | total reward : 0.0
# 2020/10/01 17:47:29
# episode : 5790 | final step : 99 | total reward : -1.0
# 2020/10/01 17:47:32
# episode : 5791 | final step : 97 | total reward : 0.0
# 2020/10/01 17:47:35
# episode : 5792 | final step : 98 | total reward : -1.0
# 2020/10/01 17:47:38
# episode : 5793 | final step : 100 | total reward : -1.0
# 2020/10/01 17:47:41
# episode : 5794 | final step : 101 | total reward : 0.0
# 2020/10/01 17:47:44
# episode : 5795 | final step : 99 | total reward : 0.0
# 2020/10/01 17:47:47
# episode : 5796 | final step : 98 | total reward : -1.0
# 2020/10/01 17:47:50
# episode : 5797 | final step : 97 | total reward : 0.0
# 2020/10/01 17:47:53
# episode : 5798 | final step : 100 | total reward : 0.0
# 2020/10/01 17:47:56
# episode : 5799 | final step : 98 | total reward : -1.0
# 2020/10/01 17:47:58
# episode : 5800 | final step : 100 | total reward : 0.0
# 2020/10/01 17:48:01
# episode : 5801 | final step : 99 | total reward : -1.0
# 2020/10/01 17:48:04
# episode : 5802 | final step : 100 | total reward : 0.0
# 2020/10/01 17:48:07
# episode : 5803 | final step : 101 | total reward : 0.0
# 2020/10/01 17:48:11
# episode : 5804 | final step : 98 | total reward : -1.0
# 2020/10/01 17:48:14
# episode : 5805 | final step : 100 | total reward : 0.0
# 2020/10/01 17:48:16
# episode : 5806 | final step : 99 | total reward : -1.0
# 2020/10/01 17:48:19
# episode : 5807 | final step : 93 | total reward : 0.0
# 2020/10/01 17:48:22
# episode : 5808 | final step : 99 | total reward : 0.0
# 2020/10/01 17:48:25
# episode : 5809 | final step : 97 | total reward : 0.0
# 2020/10/01 17:48:28
# episode : 5810 | final step : 97 | total reward : 0.0
# 2020/10/01 17:48:31
# episode : 5811 | final step : 98 | total reward : 0.0
# 2020/10/01 17:48:34
# episode : 5812 | final step : 99 | total reward : -1.0
# 2020/10/01 17:48:37
# episode : 5813 | final step : 100 | total reward : 0.0
# 2020/10/01 17:48:40
# episode : 5814 | final step : 100 | total reward : 0.0
# 2020/10/01 17:48:43
# episode : 5815 | final step : 100 | total reward : 0.0
# 2020/10/01 17:48:46
# episode : 5816 | final step : 100 | total reward : 0.0
# 2020/10/01 17:48:49
# episode : 5817 | final step : 100 | total reward : 0.0
# 2020/10/01 17:48:52
# episode : 5818 | final step : 100 | total reward : 0.0
# 2020/10/01 17:48:55
# episode : 5819 | final step : 98 | total reward : -1.0
# 2020/10/01 17:48:58
# episode : 5820 | final step : 99 | total reward : -1.0
# 2020/10/01 17:49:00
# episode : 5821 | final step : 95 | total reward : 0.0
# 2020/10/01 17:49:03
# episode : 5822 | final step : 99 | total reward : 0.0
# 2020/10/01 17:49:06
# episode : 5823 | final step : 99 | total reward : 0.0
# 2020/10/01 17:49:09
# episode : 5824 | final step : 94 | total reward : 0.0
# 2020/10/01 17:49:12
# episode : 5825 | final step : 93 | total reward : 0.0
# 2020/10/01 17:49:15
# episode : 5826 | final step : 92 | total reward : 0.0
# 2020/10/01 17:49:18
# episode : 5827 | final step : 96 | total reward : 0.0
# 2020/10/01 17:49:21
# episode : 5828 | final step : 98 | total reward : -1.0
# 2020/10/01 17:49:24
# episode : 5829 | final step : 98 | total reward : -1.0
# 2020/10/01 17:49:26
# episode : 5830 | final step : 98 | total reward : -1.0
# 2020/10/01 17:49:29
# episode : 5831 | final step : 95 | total reward : 0.0
# 2020/10/01 17:49:32
# episode : 5832 | final step : 97 | total reward : 0.0
# 2020/10/01 17:49:35
# episode : 5833 | final step : 99 | total reward : 0.0
# 2020/10/01 17:49:38
# episode : 5834 | final step : 99 | total reward : 0.0
# 2020/10/01 17:49:41
# episode : 5835 | final step : 100 | total reward : 0.0
# 2020/10/01 17:49:44
# episode : 5836 | final step : 100 | total reward : 0.0
# 2020/10/01 17:49:47
# episode : 5837 | final step : 99 | total reward : 0.0
# 2020/10/01 17:49:50
# episode : 5838 | final step : 100 | total reward : 0.0
# 2020/10/01 17:49:53
# episode : 5839 | final step : 93 | total reward : 0.0
# 2020/10/01 17:49:56
# episode : 5840 | final step : 98 | total reward : 0.0
# 2020/10/01 17:49:59
# episode : 5841 | final step : 100 | total reward : 0.0
# 2020/10/01 17:50:02
# episode : 5842 | final step : 97 | total reward : 0.0
# 2020/10/01 17:50:05
# episode : 5843 | final step : 100 | total reward : 0.0
# 2020/10/01 17:50:08
# episode : 5844 | final step : 98 | total reward : 0.0
# 2020/10/01 17:50:10
# episode : 5845 | final step : 98 | total reward : -1.0
# 2020/10/01 17:50:14
# episode : 5846 | final step : 98 | total reward : 0.0
# 2020/10/01 17:50:16
# episode : 5847 | final step : 99 | total reward : 0.0
# 2020/10/01 17:50:19
# episode : 5848 | final step : 99 | total reward : -1.0
# 2020/10/01 17:50:22
# episode : 5849 | final step : 99 | total reward : 0.0
# 2020/10/01 17:50:25
# episode : 5850 | final step : 100 | total reward : 0.0
# 2020/10/01 17:50:28
# episode : 5851 | final step : 100 | total reward : 0.0
# 2020/10/01 17:50:31
# episode : 5852 | final step : 100 | total reward : 0.0
# 2020/10/01 17:50:34
# episode : 5853 | final step : 100 | total reward : 0.0
# 2020/10/01 17:50:37
# episode : 5854 | final step : 96 | total reward : 0.0
# 2020/10/01 17:50:40
# episode : 5855 | final step : 98 | total reward : 0.0
# 2020/10/01 17:50:43
# episode : 5856 | final step : 100 | total reward : 0.0
# 2020/10/01 17:50:46
# episode : 5857 | final step : 100 | total reward : 0.0
# 2020/10/01 17:50:49
# episode : 5858 | final step : 94 | total reward : 0.0
# 2020/10/01 17:50:52
# episode : 5859 | final step : 100 | total reward : 0.0
# 2020/10/01 17:50:55
# episode : 5860 | final step : 97 | total reward : -1.0
# 2020/10/01 17:50:58
# episode : 5861 | final step : 100 | total reward : 0.0
# 2020/10/01 17:51:01
# episode : 5862 | final step : 101 | total reward : 0.0
# 2020/10/01 17:51:04
# episode : 5863 | final step : 98 | total reward : -1.0
# 2020/10/01 17:51:07
# episode : 5864 | final step : 100 | total reward : -1.0
# 2020/10/01 17:51:10
# episode : 5865 | final step : 94 | total reward : 0.0
# 2020/10/01 17:51:12
# episode : 5866 | final step : 96 | total reward : 0.0
# 2020/10/01 17:51:15
# episode : 5867 | final step : 99 | total reward : 0.0
# 2020/10/01 17:51:18
# episode : 5868 | final step : 99 | total reward : 0.0
# 2020/10/01 17:51:21
# episode : 5869 | final step : 101 | total reward : 0.0
# 2020/10/01 17:51:24
# episode : 5870 | final step : 98 | total reward : 0.0
# 2020/10/01 17:51:27
# episode : 5871 | final step : 99 | total reward : -1.0
# 2020/10/01 17:51:30
# episode : 5872 | final step : 92 | total reward : 0.0
# 2020/10/01 17:51:33
# episode : 5873 | final step : 98 | total reward : -1.0
# 2020/10/01 17:51:36
# episode : 5874 | final step : 100 | total reward : 0.0
# 2020/10/01 17:51:39
# episode : 5875 | final step : 99 | total reward : 0.0
# 2020/10/01 17:51:42
# episode : 5876 | final step : 98 | total reward : -1.0
# 2020/10/01 17:51:45
# episode : 5877 | final step : 98 | total reward : -1.0
# 2020/10/01 17:51:47
# episode : 5878 | final step : 99 | total reward : -1.0
# 2020/10/01 17:51:50
# episode : 5879 | final step : 97 | total reward : 0.0
# 2020/10/01 17:51:53
# episode : 5880 | final step : 99 | total reward : -1.0
# 2020/10/01 17:51:56
# episode : 5881 | final step : 98 | total reward : 0.0
# 2020/10/01 17:51:59
# episode : 5882 | final step : 99 | total reward : 0.0
# 2020/10/01 17:52:02
# episode : 5883 | final step : 100 | total reward : 0.0
# 2020/10/01 17:52:05
# episode : 5884 | final step : 98 | total reward : -1.0
# 2020/10/01 17:52:08
# episode : 5885 | final step : 95 | total reward : 0.0
# 2020/10/01 17:52:11
# episode : 5886 | final step : 99 | total reward : 0.0

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(reward_list)

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[0]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[10]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[100]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[1000]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
# trajectory plots

from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()
