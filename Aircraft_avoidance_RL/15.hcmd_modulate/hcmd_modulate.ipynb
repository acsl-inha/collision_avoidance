# %%
import math, random

import gym
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd 
import torch.nn.functional as F

from common.layers import NoisyLinear
from common.replay_buffer import ReplayBuffer
import gym_Aircraft

from itertools import count
import time
import itertools
import matplotlib
import matplotlib.pyplot as plt

# %%
USE_CUDA = torch.cuda.is_available()
Variable = lambda *args, **kwargs: autograd.Variable(*args, **kwargs).cuda() if USE_CUDA else autograd.Variable(*args, **kwargs)

# %%
env_id = "acav-v0"
env = gym.make(env_id)
# Out:
# /home/jupyter-kunwoopark/.local/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
class RainbowDQN(nn.Module):
    def __init__(self, num_inputs, num_actions, num_atoms, Vmin, Vmax):
        super(RainbowDQN, self).__init__()
        
        self.num_inputs   = num_inputs
        self.num_actions  = num_actions
        self.num_atoms    = num_atoms
        self.Vmin         = Vmin
        self.Vmax         = Vmax
        
        self.linear1 = nn.Linear(num_inputs, 32)
        self.linear2 = nn.Linear(32, 64)
        
        self.noisy_value1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_value2 = NoisyLinear(64, self.num_atoms, use_cuda=USE_CUDA)
        
        self.noisy_advantage1 = NoisyLinear(64, 64, use_cuda=USE_CUDA)
        self.noisy_advantage2 = NoisyLinear(64, self.num_atoms * self.num_actions, use_cuda=USE_CUDA)
        
    def forward(self, x):
        batch_size = x.size(0)
        
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        
        value = F.relu(self.noisy_value1(x))
        value = self.noisy_value2(value)
        
        advantage = F.relu(self.noisy_advantage1(x))
        advantage = self.noisy_advantage2(advantage)
        
        value     = value.view(batch_size, 1, self.num_atoms)
        advantage = advantage.view(batch_size, self.num_actions, self.num_atoms)
        
        x = value + advantage - advantage.mean(1, keepdim=True)
        x = F.softmax(x.view(-1, self.num_atoms)).view(-1, self.num_actions, self.num_atoms)
        
        return x
        
    def reset_noise(self):
        self.noisy_value1.reset_noise()
        self.noisy_value2.reset_noise()
        self.noisy_advantage1.reset_noise()
        self.noisy_advantage2.reset_noise()
    
    def act(self, state):
        state = Variable(torch.FloatTensor(state).unsqueeze(0), volatile=True)
        dist = self.forward(state).data.cpu()
        dist = dist * torch.linspace(self.Vmin, self.Vmax, self.num_atoms)
        action = dist.sum(2).max(1)[1].numpy()[0]
        return action

# %%
num_atoms = 51
Vmin = -10
Vmax = 10

current_model = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)
target_model  = RainbowDQN(env.observation_space.shape[0], env.action_space.n, num_atoms, Vmin, Vmax)

if USE_CUDA:
    current_model = current_model.cuda()
    target_model  = target_model.cuda()
    
optimizer = optim.Adam(current_model.parameters(), 0.001)

replay_buffer = ReplayBuffer(10000)

# %%
def update_target(current_model, target_model):
    target_model.load_state_dict(current_model.state_dict())
    
update_target(current_model, target_model)

# %%
def projection_distribution(next_state, rewards, dones):
    batch_size  = next_state.size(0)
    
    delta_z = float(Vmax - Vmin) / (num_atoms - 1)
    support = torch.linspace(Vmin, Vmax, num_atoms)
    
    next_dist   = target_model(next_state).data.cpu() * support
    next_action = next_dist.sum(2).max(1)[1]
    next_action = next_action.unsqueeze(1).unsqueeze(1).expand(next_dist.size(0), 1, next_dist.size(2))
    next_dist   = next_dist.gather(1, next_action).squeeze(1)
        
    rewards = rewards.unsqueeze(1).expand_as(next_dist)
    dones   = dones.unsqueeze(1).expand_as(next_dist)
    support = support.unsqueeze(0).expand_as(next_dist)
    
    Tz = rewards + (1 - dones) * 0.99 * support
    Tz = Tz.clamp(min=Vmin, max=Vmax)
    b  = (Tz - Vmin) / delta_z
    l  = b.floor().long()
    u  = b.ceil().long()
        
    offset = torch.linspace(0, (batch_size - 1) * num_atoms, batch_size).long()\
                    .unsqueeze(1).expand(batch_size, num_atoms)

    proj_dist = torch.zeros(next_dist.size())    
    proj_dist.view(-1).index_add_(0, (l + offset).view(-1), (next_dist * (u.float() - b)).view(-1))
    proj_dist.view(-1).index_add_(0, (u + offset).view(-1), (next_dist * (b - l.float())).view(-1))
        
    return proj_dist

# %%
def compute_td_loss(batch_size):
    state, action, reward, next_state, done = replay_buffer.sample(batch_size) 

    state      = Variable(torch.FloatTensor(np.float32(state)))
    next_state = Variable(torch.FloatTensor(np.float32(next_state)), volatile=True)
    action     = Variable(torch.LongTensor(action))
    reward     = torch.FloatTensor(reward)
    done       = torch.FloatTensor(np.float32(done))

    proj_dist = projection_distribution(next_state, reward, done)
    
    dist = current_model(state)
    action = action.unsqueeze(1).unsqueeze(1).expand(batch_size, 1, num_atoms)
    dist = dist.gather(1, action).squeeze(1)
    dist.data.clamp_(0.01, 0.99)
    loss = -(Variable(proj_dist) * dist.log()).sum(1)
    loss  = loss.mean()
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    current_model.reset_noise()
    target_model.reset_noise()
    
    return loss

# %%
num_episodes = 1000
batch_size = 32
gamma=0.99
TARGET_UPDATE=10
hcmd_coef=0.001

losses = []
total_res=[]
reward_list=[]
for i_episode in range(num_episodes):
    total_reward=0
    
    # 환경과 상태 초기화
    res_list=np.zeros(11)
    state = env.reset(hcmd_coef)

    for t in count():
        # 행동 선택과 수행
        
        action = current_model.act(state)
        
        next_state, reward, done, res = env.step(action)
        
        # 메모리에 변이 저장
        replay_buffer.push(state, action, reward, next_state, done)
        

        # 새로운 상태 관찰
        if not done:
            next_state = next_state
        else:
            next_state = None

        

        # 다음 상태로 이동
        state = next_state

     
        # Data save
        
        cmd_list,r_list,elev_list,azim_list,Pm_list,Pt_list,h_list=res
        Pm_list=Pm_list.tolist()
        Pt_list=Pt_list.tolist()
        merged_data=itertools.chain([cmd_list],[r_list],[elev_list],[azim_list],Pm_list,Pt_list,[h_list])
        merged_data=np.array(list(merged_data))
        res_list=np.vstack([res_list,merged_data])
        
        total_reward+=reward
        
        if done:
            res_list=np.delete(res_list,0,0)
            
            total_res.append(res_list)
            reward_list.append(total_reward)
            
            now = time.localtime()
            print ("%04d/%02d/%02d %02d:%02d:%02d" % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec))
            print("episode : {} | final step : {} | total reward : {}".format(i_episode, t, total_reward))
            break
        if len(replay_buffer) > batch_size:
            loss = compute_td_loss(batch_size)
            losses.append(loss.item())
            
        
    #목표 네트워크 업데이트, 모든 웨이트와 바이어스 복사
    if i_episode % TARGET_UPDATE == 0:
        update_target(current_model, target_model)

print('Complete')
env.close()
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:36: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 2020/10/06 16:48:43
# episode : 0 | final step : 97 | total reward : 39.650000000000006
# 2020/10/06 16:48:44
# episode : 1 | final step : 99 | total reward : -19.575000000000003
# 2020/10/06 16:48:46
# episode : 2 | final step : 100 | total reward : 94.7
# 2020/10/06 16:48:47
# episode : 3 | final step : 100 | total reward : 97.175
# 2020/10/06 16:48:48
# episode : 4 | final step : 98 | total reward : 75.625
# 2020/10/06 16:48:49
# episode : 5 | final step : 98 | total reward : -22.35
# 2020/10/06 16:48:50
# episode : 6 | final step : 98 | total reward : 77.45
# 2020/10/06 16:48:51
# episode : 7 | final step : 99 | total reward : -0.025
# 2020/10/06 16:48:52
# episode : 8 | final step : 98 | total reward : -0.025
# 2020/10/06 16:48:53
# episode : 9 | final step : 101 | total reward : 99.975
# 2020/10/06 16:48:54
# episode : 10 | final step : 98 | total reward : 99.975
# 2020/10/06 16:48:56
# episode : 11 | final step : 96 | total reward : 99.975
# 2020/10/06 16:48:57
# episode : 12 | final step : 99 | total reward : -0.47500000000000003
# 2020/10/06 16:48:58
# episode : 13 | final step : 98 | total reward : -1.775
# 2020/10/06 16:48:59
# episode : 14 | final step : 98 | total reward : -2.375
# 2020/10/06 16:49:00
# episode : 15 | final step : 98 | total reward : -84.72500000000001
# 2020/10/06 16:49:01
# episode : 16 | final step : 99 | total reward : -123.75
# 2020/10/06 16:49:02
# episode : 17 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:03
# episode : 18 | final step : 99 | total reward : -123.75
# 2020/10/06 16:49:04
# episode : 19 | final step : 99 | total reward : -23.75
# 2020/10/06 16:49:05
# episode : 20 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:49:06
# episode : 21 | final step : 99 | total reward : -123.75
# 2020/10/06 16:49:07
# episode : 22 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:09
# episode : 23 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:10
# episode : 24 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:11
# episode : 25 | final step : 99 | total reward : -123.75
# 2020/10/06 16:49:12
# episode : 26 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:49:13
# episode : 27 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:14
# episode : 28 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:15
# episode : 29 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:16
# episode : 30 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 16:49:17
# episode : 31 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:18
# episode : 32 | final step : 97 | total reward : -118.825
# 2020/10/06 16:49:19
# episode : 33 | final step : 99 | total reward : -123.75
# 2020/10/06 16:49:21
# episode : 34 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:22
# episode : 35 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:23
# episode : 36 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 16:49:24
# episode : 37 | final step : 99 | total reward : -123.75
# 2020/10/06 16:49:25
# episode : 38 | final step : 100 | total reward : -126.25
# 2020/10/06 16:49:26
# episode : 39 | final step : 99 | total reward : -23.75
# 2020/10/06 16:49:27
# episode : 40 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:28
# episode : 41 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:29
# episode : 42 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:30
# episode : 43 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:31
# episode : 44 | final step : 100 | total reward : -26.25
# 2020/10/06 16:49:32
# episode : 45 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:34
# episode : 46 | final step : 99 | total reward : -123.75
# 2020/10/06 16:49:35
# episode : 47 | final step : 99 | total reward : -123.75
# 2020/10/06 16:49:36
# episode : 48 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:49:37
# episode : 49 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:38
# episode : 50 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:39
# episode : 51 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:40
# episode : 52 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:43
# episode : 53 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:47
# episode : 54 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:50
# episode : 55 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:53
# episode : 56 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:56
# episode : 57 | final step : 98 | total reward : -121.275
# 2020/10/06 16:49:59
# episode : 58 | final step : 99 | total reward : -123.75
# 2020/10/06 16:50:01
# episode : 59 | final step : 98 | total reward : -121.275
# 2020/10/06 16:50:04
# episode : 60 | final step : 98 | total reward : -121.275
# 2020/10/06 16:50:07
# episode : 61 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:50:11
# episode : 62 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 16:50:14
# episode : 63 | final step : 95 | total reward : -14.0
# 2020/10/06 16:50:17
# episode : 64 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:50:20
# episode : 65 | final step : 98 | total reward : -121.275
# 2020/10/06 16:50:24
# episode : 66 | final step : 99 | total reward : -123.75
# 2020/10/06 16:50:27
# episode : 67 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 16:50:30
# episode : 68 | final step : 100 | total reward : -26.25
# 2020/10/06 16:50:34
# episode : 69 | final step : 98 | total reward : -121.275
# 2020/10/06 16:50:37
# episode : 70 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 16:50:40
# episode : 71 | final step : 99 | total reward : -23.75
# 2020/10/06 16:50:44
# episode : 72 | final step : 98 | total reward : -121.275
# 2020/10/06 16:50:47
# episode : 73 | final step : 98 | total reward : -121.275
# 2020/10/06 16:50:50
# episode : 74 | final step : 99 | total reward : -123.75
# 2020/10/06 16:50:53
# episode : 75 | final step : 98 | total reward : -121.275
# 2020/10/06 16:50:57
# episode : 76 | final step : 93 | total reward : -9.275000000000006
# 2020/10/06 16:51:00
# episode : 77 | final step : 97 | total reward : -118.825
# 2020/10/06 16:51:03
# episode : 78 | final step : 100 | total reward : -126.25
# 2020/10/06 16:51:06
# episode : 79 | final step : 98 | total reward : -121.275
# 2020/10/06 16:51:10
# episode : 80 | final step : 98 | total reward : -121.275
# 2020/10/06 16:51:13
# episode : 81 | final step : 99 | total reward : -23.75
# 2020/10/06 16:51:16
# episode : 82 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 16:51:20
# episode : 83 | final step : 99 | total reward : -123.75
# 2020/10/06 16:51:24
# episode : 84 | final step : 99 | total reward : -123.75
# 2020/10/06 16:51:27
# episode : 85 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 16:51:30
# episode : 86 | final step : 99 | total reward : -123.75
# 2020/10/06 16:51:33
# episode : 87 | final step : 98 | total reward : -121.275
# 2020/10/06 16:51:36
# episode : 88 | final step : 98 | total reward : -121.275
# 2020/10/06 16:51:39
# episode : 89 | final step : 99 | total reward : -23.75
# 2020/10/06 16:51:43
# episode : 90 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 16:51:46
# episode : 91 | final step : 99 | total reward : -123.75
# 2020/10/06 16:51:49
# episode : 92 | final step : 98 | total reward : -121.275
# 2020/10/06 16:51:53
# episode : 93 | final step : 98 | total reward : -121.275
# 2020/10/06 16:51:57
# episode : 94 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:52:00
# episode : 95 | final step : 98 | total reward : -121.275
# 2020/10/06 16:52:03
# episode : 96 | final step : 99 | total reward : -123.75
# 2020/10/06 16:52:07
# episode : 97 | final step : 99 | total reward : -123.75
# 2020/10/06 16:52:10
# episode : 98 | final step : 98 | total reward : -121.275
# 2020/10/06 16:52:13
# episode : 99 | final step : 99 | total reward : -123.75
# 2020/10/06 16:52:17
# episode : 100 | final step : 98 | total reward : -121.275
# 2020/10/06 16:52:20
# episode : 101 | final step : 99 | total reward : -123.75
# 2020/10/06 16:52:23
# episode : 102 | final step : 99 | total reward : -123.75
# 2020/10/06 16:52:27
# episode : 103 | final step : 97 | total reward : -118.825
# 2020/10/06 16:52:31
# episode : 104 | final step : 98 | total reward : -121.275
# 2020/10/06 16:52:34
# episode : 105 | final step : 98 | total reward : -121.275
# 2020/10/06 16:52:37
# episode : 106 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 16:52:40
# episode : 107 | final step : 95 | total reward : -14.0
# 2020/10/06 16:52:43
# episode : 108 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:52:46
# episode : 109 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:52:50
# episode : 110 | final step : 98 | total reward : -121.275
# 2020/10/06 16:52:53
# episode : 111 | final step : 98 | total reward : -121.275
# 2020/10/06 16:52:56
# episode : 112 | final step : 99 | total reward : -123.75
# 2020/10/06 16:52:59
# episode : 113 | final step : 99 | total reward : -123.75
# 2020/10/06 16:53:03
# episode : 114 | final step : 98 | total reward : -121.275
# 2020/10/06 16:53:06
# episode : 115 | final step : 101 | total reward : -28.775000000000006
# 2020/10/06 16:53:09
# episode : 116 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 16:53:13
# episode : 117 | final step : 98 | total reward : -121.275
# 2020/10/06 16:53:17
# episode : 118 | final step : 100 | total reward : -26.25
# 2020/10/06 16:53:19
# episode : 119 | final step : 98 | total reward : -121.275
# 2020/10/06 16:53:23
# episode : 120 | final step : 99 | total reward : -123.75
# 2020/10/06 16:53:27
# episode : 121 | final step : 98 | total reward : -121.275
# 2020/10/06 16:53:30
# episode : 122 | final step : 98 | total reward : -121.275
# 2020/10/06 16:53:33
# episode : 123 | final step : 98 | total reward : -121.275
# 2020/10/06 16:53:37
# episode : 124 | final step : 99 | total reward : -23.75
# 2020/10/06 16:53:40
# episode : 125 | final step : 98 | total reward : -121.275
# 2020/10/06 16:53:43
# episode : 126 | final step : 99 | total reward : -123.75
# 2020/10/06 16:53:47
# episode : 127 | final step : 98 | total reward : -121.275
# 2020/10/06 16:53:50
# episode : 128 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:53:53
# episode : 129 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 16:53:57
# episode : 130 | final step : 98 | total reward : -121.275
# 2020/10/06 16:54:00
# episode : 131 | final step : 98 | total reward : -121.275
# 2020/10/06 16:54:03
# episode : 132 | final step : 99 | total reward : -23.75
# 2020/10/06 16:54:06
# episode : 133 | final step : 98 | total reward : -121.275
# 2020/10/06 16:54:10
# episode : 134 | final step : 99 | total reward : -123.75
# 2020/10/06 16:54:13
# episode : 135 | final step : 99 | total reward : -123.75
# 2020/10/06 16:54:16
# episode : 136 | final step : 98 | total reward : -121.275
# 2020/10/06 16:54:20
# episode : 137 | final step : 99 | total reward : -123.75
# 2020/10/06 16:54:23
# episode : 138 | final step : 99 | total reward : -123.75
# 2020/10/06 16:54:26
# episode : 139 | final step : 99 | total reward : -23.75
# 2020/10/06 16:54:29
# episode : 140 | final step : 98 | total reward : -121.275
# 2020/10/06 16:54:34
# episode : 141 | final step : 99 | total reward : -23.75
# 2020/10/06 16:54:37
# episode : 142 | final step : 99 | total reward : -123.75
# 2020/10/06 16:54:40
# episode : 143 | final step : 100 | total reward : -126.25
# 2020/10/06 16:54:43
# episode : 144 | final step : 98 | total reward : -121.275
# 2020/10/06 16:54:47
# episode : 145 | final step : 99 | total reward : -23.75
# 2020/10/06 16:54:50
# episode : 146 | final step : 98 | total reward : -121.275
# 2020/10/06 16:54:53
# episode : 147 | final step : 99 | total reward : -123.75
# 2020/10/06 16:54:57
# episode : 148 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 16:55:00
# episode : 149 | final step : 100 | total reward : -26.25
# 2020/10/06 16:55:03
# episode : 150 | final step : 98 | total reward : -121.275
# 2020/10/06 16:55:07
# episode : 151 | final step : 99 | total reward : -123.75
# 2020/10/06 16:55:10
# episode : 152 | final step : 99 | total reward : -123.75
# 2020/10/06 16:55:13
# episode : 153 | final step : 98 | total reward : -121.275
# 2020/10/06 16:55:17
# episode : 154 | final step : 95 | total reward : -14.0
# 2020/10/06 16:55:20
# episode : 155 | final step : 98 | total reward : -121.275
# 2020/10/06 16:55:23
# episode : 156 | final step : 98 | total reward : -121.275
# 2020/10/06 16:55:27
# episode : 157 | final step : 98 | total reward : -121.275
# 2020/10/06 16:55:30
# episode : 158 | final step : 98 | total reward : -121.275
# 2020/10/06 16:55:33
# episode : 159 | final step : 99 | total reward : -23.75
# 2020/10/06 16:55:36
# episode : 160 | final step : 97 | total reward : -118.825
# 2020/10/06 16:55:40
# episode : 161 | final step : 98 | total reward : -121.275
# 2020/10/06 16:55:43
# episode : 162 | final step : 98 | total reward : -121.275
# 2020/10/06 16:55:46
# episode : 163 | final step : 98 | total reward : -121.275
# 2020/10/06 16:55:50
# episode : 164 | final step : 99 | total reward : -123.75
# 2020/10/06 16:55:54
# episode : 165 | final step : 98 | total reward : -121.275
# 2020/10/06 16:55:57
# episode : 166 | final step : 98 | total reward : -121.275
# 2020/10/06 16:56:00
# episode : 167 | final step : 99 | total reward : -123.75
# 2020/10/06 16:56:03
# episode : 168 | final step : 99 | total reward : -23.75
# 2020/10/06 16:56:07
# episode : 169 | final step : 98 | total reward : -121.275
# 2020/10/06 16:56:10
# episode : 170 | final step : 98 | total reward : -121.275
# 2020/10/06 16:56:13
# episode : 171 | final step : 99 | total reward : -123.75
# 2020/10/06 16:56:17
# episode : 172 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 16:56:20
# episode : 173 | final step : 98 | total reward : -121.275
# 2020/10/06 16:56:23
# episode : 174 | final step : 98 | total reward : -121.275
# 2020/10/06 16:56:27
# episode : 175 | final step : 98 | total reward : -121.275
# 2020/10/06 16:56:30
# episode : 176 | final step : 98 | total reward : -121.275
# 2020/10/06 16:56:32
# episode : 177 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 16:56:36
# episode : 178 | final step : 98 | total reward : -121.275
# 2020/10/06 16:56:39
# episode : 179 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 16:56:42
# episode : 180 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 16:56:45
# episode : 181 | final step : 99 | total reward : -123.75
# 2020/10/06 16:56:49
# episode : 182 | final step : 98 | total reward : -121.275
# 2020/10/06 16:56:52
# episode : 183 | final step : 97 | total reward : -118.825
# 2020/10/06 16:56:55
# episode : 184 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 16:56:58
# episode : 185 | final step : 99 | total reward : -23.75
# 2020/10/06 16:57:02
# episode : 186 | final step : 101 | total reward : -28.775000000000006
# 2020/10/06 16:57:05
# episode : 187 | final step : 99 | total reward : -123.75
# 2020/10/06 16:57:08
# episode : 188 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:57:12
# episode : 189 | final step : 100 | total reward : -126.25
# 2020/10/06 16:57:15
# episode : 190 | final step : 99 | total reward : -23.75
# 2020/10/06 16:57:18
# episode : 191 | final step : 98 | total reward : -121.275
# 2020/10/06 16:57:22
# episode : 192 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:57:25
# episode : 193 | final step : 99 | total reward : -23.75
# 2020/10/06 16:57:29
# episode : 194 | final step : 99 | total reward : -23.75
# 2020/10/06 16:57:31
# episode : 195 | final step : 98 | total reward : -121.275
# 2020/10/06 16:57:35
# episode : 196 | final step : 99 | total reward : -123.75
# 2020/10/06 16:57:39
# episode : 197 | final step : 98 | total reward : -121.275
# 2020/10/06 16:57:42
# episode : 198 | final step : 98 | total reward : -121.275
# 2020/10/06 16:57:45
# episode : 199 | final step : 99 | total reward : -123.75
# 2020/10/06 16:57:49
# episode : 200 | final step : 98 | total reward : -121.275
# 2020/10/06 16:57:52
# episode : 201 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 16:57:55
# episode : 202 | final step : 101 | total reward : -28.775000000000006
# 2020/10/06 16:57:59
# episode : 203 | final step : 99 | total reward : -123.75
# 2020/10/06 16:58:02
# episode : 204 | final step : 99 | total reward : -123.75
# 2020/10/06 16:58:05
# episode : 205 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:58:08
# episode : 206 | final step : 98 | total reward : -121.275
# 2020/10/06 16:58:12
# episode : 207 | final step : 99 | total reward : -23.75
# 2020/10/06 16:58:15
# episode : 208 | final step : 99 | total reward : -23.75
# 2020/10/06 16:58:18
# episode : 209 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 16:58:22
# episode : 210 | final step : 99 | total reward : -123.75
# 2020/10/06 16:58:25
# episode : 211 | final step : 99 | total reward : -23.75
# 2020/10/06 16:58:28
# episode : 212 | final step : 100 | total reward : -26.25
# 2020/10/06 16:58:32
# episode : 213 | final step : 99 | total reward : -23.75
# 2020/10/06 16:58:36
# episode : 214 | final step : 98 | total reward : -121.275
# 2020/10/06 16:58:39
# episode : 215 | final step : 98 | total reward : -121.275
# 2020/10/06 16:58:42
# episode : 216 | final step : 98 | total reward : -121.275
# 2020/10/06 16:58:45
# episode : 217 | final step : 98 | total reward : -121.275
# 2020/10/06 16:58:49
# episode : 218 | final step : 98 | total reward : -121.275
# 2020/10/06 16:58:52
# episode : 219 | final step : 98 | total reward : -121.275
# 2020/10/06 16:58:56
# episode : 220 | final step : 98 | total reward : -121.275
# 2020/10/06 16:59:00
# episode : 221 | final step : 100 | total reward : -26.25
# 2020/10/06 16:59:03
# episode : 222 | final step : 99 | total reward : -123.75
# 2020/10/06 16:59:06
# episode : 223 | final step : 98 | total reward : -121.275
# 2020/10/06 16:59:09
# episode : 224 | final step : 98 | total reward : -121.275
# 2020/10/06 16:59:12
# episode : 225 | final step : 99 | total reward : -23.75
# 2020/10/06 16:59:15
# episode : 226 | final step : 98 | total reward : -121.275
# 2020/10/06 16:59:19
# episode : 227 | final step : 98 | total reward : -121.275
# 2020/10/06 16:59:23
# episode : 228 | final step : 99 | total reward : -23.75
# 2020/10/06 16:59:25
# episode : 229 | final step : 99 | total reward : -23.75
# 2020/10/06 16:59:29
# episode : 230 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:59:33
# episode : 231 | final step : 100 | total reward : -123.775
# 2020/10/06 16:59:36
# episode : 232 | final step : 100 | total reward : -26.25
# 2020/10/06 16:59:39
# episode : 233 | final step : 98 | total reward : -121.275
# 2020/10/06 16:59:43
# episode : 234 | final step : 98 | total reward : -121.275
# 2020/10/06 16:59:46
# episode : 235 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 16:59:49
# episode : 236 | final step : 98 | total reward : -121.275
# 2020/10/06 16:59:53
# episode : 237 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 16:59:56
# episode : 238 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 16:59:59
# episode : 239 | final step : 100 | total reward : -26.25
# 2020/10/06 17:00:02
# episode : 240 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:00:06
# episode : 241 | final step : 99 | total reward : -123.75
# 2020/10/06 17:00:09
# episode : 242 | final step : 98 | total reward : -121.275
# 2020/10/06 17:00:12
# episode : 243 | final step : 98 | total reward : -121.275
# 2020/10/06 17:00:16
# episode : 244 | final step : 97 | total reward : -118.825
# 2020/10/06 17:00:19
# episode : 245 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:00:22
# episode : 246 | final step : 98 | total reward : -121.275
# 2020/10/06 17:00:25
# episode : 247 | final step : 99 | total reward : -23.75
# 2020/10/06 17:00:29
# episode : 248 | final step : 98 | total reward : -121.275
# 2020/10/06 17:00:33
# episode : 249 | final step : 98 | total reward : -121.275
# 2020/10/06 17:00:36
# episode : 250 | final step : 98 | total reward : -121.275
# 2020/10/06 17:00:39
# episode : 251 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 17:00:43
# episode : 252 | final step : 100 | total reward : -26.25
# 2020/10/06 17:00:46
# episode : 253 | final step : 98 | total reward : -121.275
# 2020/10/06 17:00:50
# episode : 254 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 17:00:53
# episode : 255 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:00:56
# episode : 256 | final step : 99 | total reward : -123.75
# 2020/10/06 17:00:59
# episode : 257 | final step : 98 | total reward : -121.275
# 2020/10/06 17:01:03
# episode : 258 | final step : 98 | total reward : -121.275
# 2020/10/06 17:01:07
# episode : 259 | final step : 99 | total reward : -123.75
# 2020/10/06 17:01:10
# episode : 260 | final step : 98 | total reward : -121.275
# 2020/10/06 17:01:13
# episode : 261 | final step : 100 | total reward : -26.25
# 2020/10/06 17:01:17
# episode : 262 | final step : 100 | total reward : -126.25
# 2020/10/06 17:01:20
# episode : 263 | final step : 98 | total reward : -121.275
# 2020/10/06 17:01:23
# episode : 264 | final step : 99 | total reward : -123.75
# 2020/10/06 17:01:27
# episode : 265 | final step : 100 | total reward : -26.25
# 2020/10/06 17:01:30
# episode : 266 | final step : 97 | total reward : -118.825
# 2020/10/06 17:01:33
# episode : 267 | final step : 100 | total reward : -26.25
# 2020/10/06 17:01:37
# episode : 268 | final step : 99 | total reward : -123.75
# 2020/10/06 17:01:41
# episode : 269 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:01:44
# episode : 270 | final step : 100 | total reward : -126.25
# 2020/10/06 17:01:47
# episode : 271 | final step : 98 | total reward : -121.275
# 2020/10/06 17:01:51
# episode : 272 | final step : 98 | total reward : -121.275
# 2020/10/06 17:01:54
# episode : 273 | final step : 99 | total reward : -123.75
# 2020/10/06 17:01:57
# episode : 274 | final step : 98 | total reward : -121.275
# 2020/10/06 17:02:00
# episode : 275 | final step : 98 | total reward : -121.275
# 2020/10/06 17:02:04
# episode : 276 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:02:07
# episode : 277 | final step : 99 | total reward : -123.75
# 2020/10/06 17:02:11
# episode : 278 | final step : 99 | total reward : -123.75
# 2020/10/06 17:02:15
# episode : 279 | final step : 98 | total reward : -121.275
# 2020/10/06 17:02:18
# episode : 280 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:02:21
# episode : 281 | final step : 98 | total reward : -121.275
# 2020/10/06 17:02:25
# episode : 282 | final step : 99 | total reward : -123.75
# 2020/10/06 17:02:28
# episode : 283 | final step : 98 | total reward : -121.275
# 2020/10/06 17:02:31
# episode : 284 | final step : 99 | total reward : -23.75
# 2020/10/06 17:02:35
# episode : 285 | final step : 99 | total reward : -123.75
# 2020/10/06 17:02:38
# episode : 286 | final step : 98 | total reward : -121.275
# 2020/10/06 17:02:41
# episode : 287 | final step : 100 | total reward : -126.25
# 2020/10/06 17:02:45
# episode : 288 | final step : 98 | total reward : -121.275
# 2020/10/06 17:02:49
# episode : 289 | final step : 98 | total reward : -121.275
# 2020/10/06 17:02:52
# episode : 290 | final step : 98 | total reward : -121.275
# 2020/10/06 17:02:55
# episode : 291 | final step : 98 | total reward : -121.275
# 2020/10/06 17:02:59
# episode : 292 | final step : 99 | total reward : -23.75
# 2020/10/06 17:03:02
# episode : 293 | final step : 101 | total reward : -28.775000000000006
# 2020/10/06 17:03:05
# episode : 294 | final step : 98 | total reward : -121.275
# 2020/10/06 17:03:09
# episode : 295 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:03:12
# episode : 296 | final step : 98 | total reward : -121.275
# 2020/10/06 17:03:15
# episode : 297 | final step : 98 | total reward : -121.275
# 2020/10/06 17:03:18
# episode : 298 | final step : 99 | total reward : -123.75
# 2020/10/06 17:03:22
# episode : 299 | final step : 98 | total reward : -121.275
# 2020/10/06 17:03:25
# episode : 300 | final step : 98 | total reward : -121.275
# 2020/10/06 17:03:28
# episode : 301 | final step : 98 | total reward : -121.275
# 2020/10/06 17:03:32
# episode : 302 | final step : 98 | total reward : -121.275
# 2020/10/06 17:03:35
# episode : 303 | final step : 98 | total reward : -121.275
# 2020/10/06 17:03:38
# episode : 304 | final step : 99 | total reward : -123.75
# 2020/10/06 17:03:42
# episode : 305 | final step : 98 | total reward : -121.275
# 2020/10/06 17:03:46
# episode : 306 | final step : 99 | total reward : -123.75
# 2020/10/06 17:03:49
# episode : 307 | final step : 99 | total reward : -123.75
# 2020/10/06 17:03:52
# episode : 308 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 17:03:56
# episode : 309 | final step : 98 | total reward : -121.275
# 2020/10/06 17:03:59
# episode : 310 | final step : 98 | total reward : -121.275
# 2020/10/06 17:04:02
# episode : 311 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:04:06
# episode : 312 | final step : 98 | total reward : -121.275
# 2020/10/06 17:04:09
# episode : 313 | final step : 99 | total reward : -123.75
# 2020/10/06 17:04:12
# episode : 314 | final step : 100 | total reward : -26.25
# 2020/10/06 17:04:16
# episode : 315 | final step : 100 | total reward : -126.25
# 2020/10/06 17:04:19
# episode : 316 | final step : 98 | total reward : -121.275
# 2020/10/06 17:04:22
# episode : 317 | final step : 98 | total reward : -121.275
# 2020/10/06 17:04:25
# episode : 318 | final step : 98 | total reward : -121.275
# 2020/10/06 17:04:29
# episode : 319 | final step : 99 | total reward : -123.75
# 2020/10/06 17:04:32
# episode : 320 | final step : 99 | total reward : -123.75
# 2020/10/06 17:04:35
# episode : 321 | final step : 98 | total reward : -121.275
# 2020/10/06 17:04:39
# episode : 322 | final step : 98 | total reward : -121.275
# 2020/10/06 17:04:42
# episode : 323 | final step : 99 | total reward : -23.75
# 2020/10/06 17:04:45
# episode : 324 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:04:49
# episode : 325 | final step : 99 | total reward : -123.75
# 2020/10/06 17:04:53
# episode : 326 | final step : 99 | total reward : -23.75
# 2020/10/06 17:04:55
# episode : 327 | final step : 100 | total reward : -26.25
# 2020/10/06 17:04:59
# episode : 328 | final step : 101 | total reward : -128.775
# 2020/10/06 17:05:02
# episode : 329 | final step : 95 | total reward : -14.0
# 2020/10/06 17:05:06
# episode : 330 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:05:08
# episode : 331 | final step : 98 | total reward : -121.275
# 2020/10/06 17:05:12
# episode : 332 | final step : 99 | total reward : -23.75
# 2020/10/06 17:05:16
# episode : 333 | final step : 98 | total reward : -121.275
# 2020/10/06 17:05:19
# episode : 334 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:05:22
# episode : 335 | final step : 98 | total reward : -121.275
# 2020/10/06 17:05:26
# episode : 336 | final step : 98 | total reward : -121.275
# 2020/10/06 17:05:29
# episode : 337 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:05:32
# episode : 338 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:05:35
# episode : 339 | final step : 98 | total reward : -121.275
# 2020/10/06 17:05:39
# episode : 340 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:05:42
# episode : 341 | final step : 98 | total reward : -121.275
# 2020/10/06 17:05:45
# episode : 342 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:05:49
# episode : 343 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:05:52
# episode : 344 | final step : 98 | total reward : -121.275
# 2020/10/06 17:05:55
# episode : 345 | final step : 98 | total reward : -121.275
# 2020/10/06 17:05:59
# episode : 346 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:06:02
# episode : 347 | final step : 98 | total reward : -121.275
# 2020/10/06 17:06:05
# episode : 348 | final step : 98 | total reward : -121.275
# 2020/10/06 17:06:09
# episode : 349 | final step : 98 | total reward : -121.275
# 2020/10/06 17:06:12
# episode : 350 | final step : 98 | total reward : -121.275
# 2020/10/06 17:06:15
# episode : 351 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:06:18
# episode : 352 | final step : 98 | total reward : -121.275
# 2020/10/06 17:06:22
# episode : 353 | final step : 98 | total reward : -121.275
# 2020/10/06 17:06:25
# episode : 354 | final step : 98 | total reward : -121.275
# 2020/10/06 17:06:28
# episode : 355 | final step : 99 | total reward : -123.75
# 2020/10/06 17:06:32
# episode : 356 | final step : 98 | total reward : -121.275
# 2020/10/06 17:06:36
# episode : 357 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:06:38
# episode : 358 | final step : 98 | total reward : -121.275
# 2020/10/06 17:06:42
# episode : 359 | final step : 98 | total reward : -121.275
# 2020/10/06 17:06:46
# episode : 360 | final step : 100 | total reward : -126.25
# 2020/10/06 17:06:49
# episode : 361 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:06:52
# episode : 362 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:06:55
# episode : 363 | final step : 97 | total reward : -118.825
# 2020/10/06 17:06:59
# episode : 364 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:07:02
# episode : 365 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:07:05
# episode : 366 | final step : 99 | total reward : -23.75
# 2020/10/06 17:07:09
# episode : 367 | final step : 98 | total reward : -121.275
# 2020/10/06 17:07:12
# episode : 368 | final step : 99 | total reward : -23.75
# 2020/10/06 17:07:15
# episode : 369 | final step : 98 | total reward : -121.275
# 2020/10/06 17:07:19
# episode : 370 | final step : 100 | total reward : -26.25
# 2020/10/06 17:07:22
# episode : 371 | final step : 98 | total reward : -121.275
# 2020/10/06 17:07:26
# episode : 372 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 17:07:30
# episode : 373 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:07:33
# episode : 374 | final step : 98 | total reward : -121.275
# 2020/10/06 17:07:36
# episode : 375 | final step : 98 | total reward : -121.275
# 2020/10/06 17:07:39
# episode : 376 | final step : 98 | total reward : -121.275
# 2020/10/06 17:07:43
# episode : 377 | final step : 99 | total reward : -123.75
# 2020/10/06 17:07:45
# episode : 378 | final step : 99 | total reward : -123.75
# 2020/10/06 17:07:49
# episode : 379 | final step : 98 | total reward : -121.275
# 2020/10/06 17:07:53
# episode : 380 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:07:56
# episode : 381 | final step : 100 | total reward : -26.25
# 2020/10/06 17:07:59
# episode : 382 | final step : 98 | total reward : -121.275
# 2020/10/06 17:08:03
# episode : 383 | final step : 99 | total reward : -123.75
# 2020/10/06 17:08:06
# episode : 384 | final step : 99 | total reward : -123.75
# 2020/10/06 17:08:09
# episode : 385 | final step : 98 | total reward : -121.275
# 2020/10/06 17:08:13
# episode : 386 | final step : 98 | total reward : -121.275
# 2020/10/06 17:08:17
# episode : 387 | final step : 98 | total reward : -121.275
# 2020/10/06 17:08:20
# episode : 388 | final step : 98 | total reward : -121.275
# 2020/10/06 17:08:23
# episode : 389 | final step : 98 | total reward : -121.275
# 2020/10/06 17:08:27
# episode : 390 | final step : 99 | total reward : -123.75
# 2020/10/06 17:08:30
# episode : 391 | final step : 98 | total reward : -121.275
# 2020/10/06 17:08:34
# episode : 392 | final step : 98 | total reward : -121.275
# 2020/10/06 17:08:37
# episode : 393 | final step : 98 | total reward : -121.275
# 2020/10/06 17:08:40
# episode : 394 | final step : 100 | total reward : -26.25
# 2020/10/06 17:08:43
# episode : 395 | final step : 98 | total reward : -121.275
# 2020/10/06 17:08:47
# episode : 396 | final step : 98 | total reward : -121.275
# 2020/10/06 17:08:50
# episode : 397 | final step : 99 | total reward : -123.75
# 2020/10/06 17:08:53
# episode : 398 | final step : 98 | total reward : -121.275
# 2020/10/06 17:08:57
# episode : 399 | final step : 99 | total reward : -123.75
# 2020/10/06 17:09:01
# episode : 400 | final step : 98 | total reward : -121.275
# 2020/10/06 17:09:04
# episode : 401 | final step : 98 | total reward : -121.275
# 2020/10/06 17:09:07
# episode : 402 | final step : 98 | total reward : -121.275
# 2020/10/06 17:09:11
# episode : 403 | final step : 98 | total reward : -121.275
# 2020/10/06 17:09:14
# episode : 404 | final step : 99 | total reward : -123.75
# 2020/10/06 17:09:17
# episode : 405 | final step : 101 | total reward : -28.775000000000006
# 2020/10/06 17:09:21
# episode : 406 | final step : 100 | total reward : -26.25
# 2020/10/06 17:09:24
# episode : 407 | final step : 100 | total reward : -26.25
# 2020/10/06 17:09:27
# episode : 408 | final step : 100 | total reward : -26.25
# 2020/10/06 17:09:30
# episode : 409 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:09:34
# episode : 410 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:09:37
# episode : 411 | final step : 100 | total reward : -126.25
# 2020/10/06 17:09:40
# episode : 412 | final step : 98 | total reward : -121.275
# 2020/10/06 17:09:44
# episode : 413 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:09:47
# episode : 414 | final step : 98 | total reward : -121.275
# 2020/10/06 17:09:49
# episode : 415 | final step : 98 | total reward : -121.275
# 2020/10/06 17:09:53
# episode : 416 | final step : 98 | total reward : -121.275
# 2020/10/06 17:09:57
# episode : 417 | final step : 100 | total reward : -26.25
# 2020/10/06 17:10:00
# episode : 418 | final step : 98 | total reward : -121.275
# 2020/10/06 17:10:03
# episode : 419 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:10:07
# episode : 420 | final step : 98 | total reward : -121.275
# 2020/10/06 17:10:10
# episode : 421 | final step : 98 | total reward : -121.275
# 2020/10/06 17:10:13
# episode : 422 | final step : 99 | total reward : -123.75
# 2020/10/06 17:10:16
# episode : 423 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:10:20
# episode : 424 | final step : 99 | total reward : -123.75
# 2020/10/06 17:10:23
# episode : 425 | final step : 98 | total reward : -121.275
# 2020/10/06 17:10:26
# episode : 426 | final step : 99 | total reward : -123.75
# 2020/10/06 17:10:30
# episode : 427 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 17:10:33
# episode : 428 | final step : 98 | total reward : -121.275
# 2020/10/06 17:10:37
# episode : 429 | final step : 99 | total reward : -123.75
# 2020/10/06 17:10:40
# episode : 430 | final step : 98 | total reward : -121.275
# 2020/10/06 17:10:44
# episode : 431 | final step : 99 | total reward : -123.75
# 2020/10/06 17:10:47
# episode : 432 | final step : 98 | total reward : -121.275
# 2020/10/06 17:10:50
# episode : 433 | final step : 99 | total reward : -123.75
# 2020/10/06 17:10:53
# episode : 434 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:10:57
# episode : 435 | final step : 99 | total reward : -23.75
# 2020/10/06 17:11:00
# episode : 436 | final step : 98 | total reward : -121.275
# 2020/10/06 17:11:03
# episode : 437 | final step : 98 | total reward : -121.275
# 2020/10/06 17:11:07
# episode : 438 | final step : 100 | total reward : -126.25
# 2020/10/06 17:11:10
# episode : 439 | final step : 98 | total reward : -121.275
# 2020/10/06 17:11:13
# episode : 440 | final step : 99 | total reward : -123.75
# 2020/10/06 17:11:17
# episode : 441 | final step : 98 | total reward : -121.275
# 2020/10/06 17:11:21
# episode : 442 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:11:24
# episode : 443 | final step : 99 | total reward : -123.75
# 2020/10/06 17:11:27
# episode : 444 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:11:31
# episode : 445 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:11:33
# episode : 446 | final step : 98 | total reward : -121.275
# 2020/10/06 17:11:37
# episode : 447 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:11:41
# episode : 448 | final step : 99 | total reward : -123.75
# 2020/10/06 17:11:44
# episode : 449 | final step : 98 | total reward : -121.275
# 2020/10/06 17:11:47
# episode : 450 | final step : 99 | total reward : -123.75
# 2020/10/06 17:11:51
# episode : 451 | final step : 99 | total reward : -23.75
# 2020/10/06 17:11:55
# episode : 452 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:11:57
# episode : 453 | final step : 99 | total reward : -23.75
# 2020/10/06 17:12:01
# episode : 454 | final step : 99 | total reward : -123.75
# 2020/10/06 17:12:05
# episode : 455 | final step : 99 | total reward : -123.75
# 2020/10/06 17:12:08
# episode : 456 | final step : 98 | total reward : -121.275
# 2020/10/06 17:12:12
# episode : 457 | final step : 99 | total reward : -123.75
# 2020/10/06 17:12:15
# episode : 458 | final step : 98 | total reward : -121.275
# 2020/10/06 17:12:18
# episode : 459 | final step : 99 | total reward : -123.75
# 2020/10/06 17:12:22
# episode : 460 | final step : 99 | total reward : -123.75
# 2020/10/06 17:12:25
# episode : 461 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:12:28
# episode : 462 | final step : 98 | total reward : -121.275
# 2020/10/06 17:12:31
# episode : 463 | final step : 98 | total reward : -121.275
# 2020/10/06 17:12:35
# episode : 464 | final step : 98 | total reward : -121.275
# 2020/10/06 17:12:39
# episode : 465 | final step : 99 | total reward : -123.75
# 2020/10/06 17:12:42
# episode : 466 | final step : 98 | total reward : -121.275
# 2020/10/06 17:12:45
# episode : 467 | final step : 99 | total reward : -123.75
# 2020/10/06 17:12:48
# episode : 468 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:12:52
# episode : 469 | final step : 98 | total reward : -121.275
# 2020/10/06 17:12:55
# episode : 470 | final step : 100 | total reward : -126.25
# 2020/10/06 17:12:58
# episode : 471 | final step : 98 | total reward : -121.275
# 2020/10/06 17:13:02
# episode : 472 | final step : 99 | total reward : -123.75
# 2020/10/06 17:13:05
# episode : 473 | final step : 98 | total reward : -121.275
# 2020/10/06 17:13:08
# episode : 474 | final step : 99 | total reward : -123.75
# 2020/10/06 17:13:12
# episode : 475 | final step : 98 | total reward : -121.275
# 2020/10/06 17:13:15
# episode : 476 | final step : 99 | total reward : -123.75
# 2020/10/06 17:13:18
# episode : 477 | final step : 98 | total reward : -121.275
# 2020/10/06 17:13:22
# episode : 478 | final step : 98 | total reward : -121.275
# 2020/10/06 17:13:25
# episode : 479 | final step : 98 | total reward : -121.275
# 2020/10/06 17:13:28
# episode : 480 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:13:32
# episode : 481 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 17:13:35
# episode : 482 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:13:38
# episode : 483 | final step : 99 | total reward : -123.75
# 2020/10/06 17:13:41
# episode : 484 | final step : 98 | total reward : -121.275
# 2020/10/06 17:13:45
# episode : 485 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:13:49
# episode : 486 | final step : 99 | total reward : -123.75
# 2020/10/06 17:13:52
# episode : 487 | final step : 97 | total reward : -118.825
# 2020/10/06 17:13:55
# episode : 488 | final step : 98 | total reward : -121.275
# 2020/10/06 17:13:59
# episode : 489 | final step : 98 | total reward : -121.275
# 2020/10/06 17:14:02
# episode : 490 | final step : 99 | total reward : -123.75
# 2020/10/06 17:14:06
# episode : 491 | final step : 98 | total reward : -121.275
# 2020/10/06 17:14:09
# episode : 492 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:14:13
# episode : 493 | final step : 100 | total reward : -26.25
# 2020/10/06 17:14:16
# episode : 494 | final step : 98 | total reward : -121.275
# 2020/10/06 17:14:20
# episode : 495 | final step : 99 | total reward : -123.75
# 2020/10/06 17:14:23
# episode : 496 | final step : 99 | total reward : -23.75
# 2020/10/06 17:14:26
# episode : 497 | final step : 98 | total reward : -121.275
# 2020/10/06 17:14:29
# episode : 498 | final step : 98 | total reward : -121.275
# 2020/10/06 17:14:33
# episode : 499 | final step : 98 | total reward : -121.275
# 2020/10/06 17:14:36
# episode : 500 | final step : 98 | total reward : -121.275
# 2020/10/06 17:14:39
# episode : 501 | final step : 100 | total reward : -26.25
# 2020/10/06 17:14:43
# episode : 502 | final step : 98 | total reward : -121.275
# 2020/10/06 17:14:46
# episode : 503 | final step : 99 | total reward : -23.75
# 2020/10/06 17:14:49
# episode : 504 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:14:53
# episode : 505 | final step : 100 | total reward : -126.25
# 2020/10/06 17:14:56
# episode : 506 | final step : 100 | total reward : -126.25
# 2020/10/06 17:14:59
# episode : 507 | final step : 99 | total reward : -123.75
# 2020/10/06 17:15:03
# episode : 508 | final step : 99 | total reward : -123.75
# 2020/10/06 17:15:06
# episode : 509 | final step : 98 | total reward : -121.275
# 2020/10/06 17:15:10
# episode : 510 | final step : 98 | total reward : -121.275
# 2020/10/06 17:15:13
# episode : 511 | final step : 99 | total reward : -123.75
# 2020/10/06 17:15:16
# episode : 512 | final step : 98 | total reward : -121.275
# 2020/10/06 17:15:20
# episode : 513 | final step : 100 | total reward : -126.25
# 2020/10/06 17:15:23
# episode : 514 | final step : 98 | total reward : -121.275
# 2020/10/06 17:15:26
# episode : 515 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:15:30
# episode : 516 | final step : 101 | total reward : -28.775000000000006
# 2020/10/06 17:15:33
# episode : 517 | final step : 98 | total reward : -121.275
# 2020/10/06 17:15:36
# episode : 518 | final step : 99 | total reward : -23.75
# 2020/10/06 17:15:40
# episode : 519 | final step : 95 | total reward : -14.0
# 2020/10/06 17:15:43
# episode : 520 | final step : 98 | total reward : -121.275
# 2020/10/06 17:15:46
# episode : 521 | final step : 99 | total reward : -123.75
# 2020/10/06 17:15:49
# episode : 522 | final step : 98 | total reward : -121.275
# 2020/10/06 17:15:53
# episode : 523 | final step : 98 | total reward : -121.275
# 2020/10/06 17:15:56
# episode : 524 | final step : 98 | total reward : -121.275
# 2020/10/06 17:15:59
# episode : 525 | final step : 98 | total reward : -121.275
# 2020/10/06 17:16:03
# episode : 526 | final step : 98 | total reward : -121.275
# 2020/10/06 17:16:06
# episode : 527 | final step : 100 | total reward : -26.25
# 2020/10/06 17:16:09
# episode : 528 | final step : 98 | total reward : -121.275
# 2020/10/06 17:16:12
# episode : 529 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:16:16
# episode : 530 | final step : 98 | total reward : -121.275
# 2020/10/06 17:16:19
# episode : 531 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:16:22
# episode : 532 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:16:26
# episode : 533 | final step : 98 | total reward : -121.275
# 2020/10/06 17:16:29
# episode : 534 | final step : 98 | total reward : -121.275
# 2020/10/06 17:16:32
# episode : 535 | final step : 99 | total reward : -123.75
# 2020/10/06 17:16:36
# episode : 536 | final step : 100 | total reward : -126.25
# 2020/10/06 17:16:40
# episode : 537 | final step : 98 | total reward : -121.275
# 2020/10/06 17:16:42
# episode : 538 | final step : 98 | total reward : -121.275
# 2020/10/06 17:16:46
# episode : 539 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:16:50
# episode : 540 | final step : 98 | total reward : -121.275
# 2020/10/06 17:16:52
# episode : 541 | final step : 99 | total reward : -123.75
# 2020/10/06 17:16:56
# episode : 542 | final step : 99 | total reward : -123.75
# 2020/10/06 17:17:00
# episode : 543 | final step : 98 | total reward : -121.275
# 2020/10/06 17:17:03
# episode : 544 | final step : 99 | total reward : -123.75
# 2020/10/06 17:17:06
# episode : 545 | final step : 99 | total reward : -123.75
# 2020/10/06 17:17:10
# episode : 546 | final step : 99 | total reward : -123.75
# 2020/10/06 17:17:14
# episode : 547 | final step : 98 | total reward : -121.275
# 2020/10/06 17:17:16
# episode : 548 | final step : 97 | total reward : -118.825
# 2020/10/06 17:17:20
# episode : 549 | final step : 98 | total reward : -121.275
# 2020/10/06 17:17:24
# episode : 550 | final step : 98 | total reward : -121.275
# 2020/10/06 17:17:27
# episode : 551 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:17:30
# episode : 552 | final step : 99 | total reward : -123.75
# 2020/10/06 17:17:34
# episode : 553 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:17:37
# episode : 554 | final step : 98 | total reward : -121.275
# 2020/10/06 17:17:40
# episode : 555 | final step : 100 | total reward : -26.25
# 2020/10/06 17:17:44
# episode : 556 | final step : 99 | total reward : -123.75
# 2020/10/06 17:17:48
# episode : 557 | final step : 98 | total reward : -121.275
# 2020/10/06 17:17:51
# episode : 558 | final step : 98 | total reward : -121.275
# 2020/10/06 17:17:55
# episode : 559 | final step : 99 | total reward : -23.75
# 2020/10/06 17:17:59
# episode : 560 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:18:02
# episode : 561 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:18:05
# episode : 562 | final step : 99 | total reward : -123.75
# 2020/10/06 17:18:09
# episode : 563 | final step : 99 | total reward : -123.75
# 2020/10/06 17:18:12
# episode : 564 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:18:15
# episode : 565 | final step : 99 | total reward : -123.75
# 2020/10/06 17:18:19
# episode : 566 | final step : 99 | total reward : -23.75
# 2020/10/06 17:18:22
# episode : 567 | final step : 98 | total reward : -121.275
# 2020/10/06 17:18:25
# episode : 568 | final step : 98 | total reward : -121.275
# 2020/10/06 17:18:29
# episode : 569 | final step : 99 | total reward : -23.75
# 2020/10/06 17:18:32
# episode : 570 | final step : 100 | total reward : -126.25
# 2020/10/06 17:18:35
# episode : 571 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:18:39
# episode : 572 | final step : 99 | total reward : -23.75
# 2020/10/06 17:18:42
# episode : 573 | final step : 98 | total reward : -121.275
# 2020/10/06 17:18:45
# episode : 574 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:18:48
# episode : 575 | final step : 98 | total reward : -121.275
# 2020/10/06 17:18:52
# episode : 576 | final step : 100 | total reward : -126.25
# 2020/10/06 17:18:55
# episode : 577 | final step : 98 | total reward : -121.275
# 2020/10/06 17:18:58
# episode : 578 | final step : 98 | total reward : -121.275
# 2020/10/06 17:19:02
# episode : 579 | final step : 98 | total reward : -121.275
# 2020/10/06 17:19:06
# episode : 580 | final step : 99 | total reward : -23.75
# 2020/10/06 17:19:09
# episode : 581 | final step : 98 | total reward : -121.275
# 2020/10/06 17:19:12
# episode : 582 | final step : 100 | total reward : -26.25
# 2020/10/06 17:19:15
# episode : 583 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:19:19
# episode : 584 | final step : 98 | total reward : -121.275
# 2020/10/06 17:19:22
# episode : 585 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:19:25
# episode : 586 | final step : 98 | total reward : -121.275
# 2020/10/06 17:19:29
# episode : 587 | final step : 101 | total reward : -28.775000000000006
# 2020/10/06 17:19:32
# episode : 588 | final step : 99 | total reward : -123.75
# 2020/10/06 17:19:35
# episode : 589 | final step : 99 | total reward : -123.75
# 2020/10/06 17:19:39
# episode : 590 | final step : 98 | total reward : -121.275
# 2020/10/06 17:19:43
# episode : 591 | final step : 98 | total reward : -121.275
# 2020/10/06 17:19:45
# episode : 592 | final step : 98 | total reward : -121.275
# 2020/10/06 17:19:49
# episode : 593 | final step : 99 | total reward : -123.75
# 2020/10/06 17:19:53
# episode : 594 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:19:56
# episode : 595 | final step : 98 | total reward : -121.275
# 2020/10/06 17:19:59
# episode : 596 | final step : 99 | total reward : -123.75
# 2020/10/06 17:20:03
# episode : 597 | final step : 98 | total reward : -121.275
# 2020/10/06 17:20:06
# episode : 598 | final step : 99 | total reward : -23.75
# 2020/10/06 17:20:09
# ...
# 2020/10/06 17:31:27
# episode : 800 | final step : 99 | total reward : -123.75
# 2020/10/06 17:31:31
# episode : 801 | final step : 98 | total reward : -121.275
# 2020/10/06 17:31:34
# episode : 802 | final step : 98 | total reward : -121.275
# 2020/10/06 17:31:37
# episode : 803 | final step : 99 | total reward : -123.75
# 2020/10/06 17:31:41
# episode : 804 | final step : 99 | total reward : -123.75
# 2020/10/06 17:31:44
# episode : 805 | final step : 98 | total reward : -121.275
# 2020/10/06 17:31:47
# episode : 806 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:31:51
# episode : 807 | final step : 98 | total reward : -121.275
# 2020/10/06 17:31:54
# episode : 808 | final step : 99 | total reward : -123.75
# 2020/10/06 17:31:58
# episode : 809 | final step : 99 | total reward : -123.75
# 2020/10/06 17:32:02
# episode : 810 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 17:32:05
# episode : 811 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 17:32:08
# episode : 812 | final step : 99 | total reward : -123.75
# 2020/10/06 17:32:11
# episode : 813 | final step : 98 | total reward : -121.275
# 2020/10/06 17:32:15
# episode : 814 | final step : 98 | total reward : -121.275
# 2020/10/06 17:32:18
# episode : 815 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:32:21
# episode : 816 | final step : 100 | total reward : -26.25
# 2020/10/06 17:32:25
# episode : 817 | final step : 98 | total reward : -121.275
# 2020/10/06 17:32:28
# episode : 818 | final step : 98 | total reward : -121.275
# 2020/10/06 17:32:31
# episode : 819 | final step : 98 | total reward : -121.275
# 2020/10/06 17:32:33
# episode : 820 | final step : 99 | total reward : -123.75
# 2020/10/06 17:32:37
# episode : 821 | final step : 99 | total reward : -123.75
# 2020/10/06 17:32:40
# episode : 822 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:32:43
# episode : 823 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:32:46
# episode : 824 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:32:49
# episode : 825 | final step : 99 | total reward : -123.75
# 2020/10/06 17:32:53
# episode : 826 | final step : 98 | total reward : -121.275
# 2020/10/06 17:32:56
# episode : 827 | final step : 98 | total reward : -121.275
# 2020/10/06 17:32:59
# episode : 828 | final step : 98 | total reward : -121.275
# 2020/10/06 17:33:02
# episode : 829 | final step : 98 | total reward : -121.275
# 2020/10/06 17:33:05
# episode : 830 | final step : 99 | total reward : -23.75
# 2020/10/06 17:33:08
# episode : 831 | final step : 99 | total reward : -123.75
# 2020/10/06 17:33:11
# episode : 832 | final step : 98 | total reward : -121.275
# 2020/10/06 17:33:14
# episode : 833 | final step : 98 | total reward : -121.275
# 2020/10/06 17:33:17
# episode : 834 | final step : 99 | total reward : -123.75
# 2020/10/06 17:33:21
# episode : 835 | final step : 98 | total reward : -121.275
# 2020/10/06 17:33:24
# episode : 836 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:33:27
# episode : 837 | final step : 98 | total reward : -121.275
# 2020/10/06 17:33:31
# episode : 838 | final step : 98 | total reward : -121.275
# 2020/10/06 17:33:35
# episode : 839 | final step : 100 | total reward : -126.25
# 2020/10/06 17:33:38
# episode : 840 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:33:42
# episode : 841 | final step : 98 | total reward : -121.275
# 2020/10/06 17:33:45
# episode : 842 | final step : 99 | total reward : -123.75
# 2020/10/06 17:33:48
# episode : 843 | final step : 98 | total reward : -121.275
# 2020/10/06 17:33:52
# episode : 844 | final step : 99 | total reward : -123.75
# 2020/10/06 17:33:55
# episode : 845 | final step : 99 | total reward : -123.75
# 2020/10/06 17:33:58
# episode : 846 | final step : 99 | total reward : -123.75
# 2020/10/06 17:34:02
# episode : 847 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:34:05
# episode : 848 | final step : 97 | total reward : -118.825
# 2020/10/06 17:34:08
# episode : 849 | final step : 99 | total reward : -123.75
# 2020/10/06 17:34:11
# episode : 850 | final step : 99 | total reward : -123.75
# 2020/10/06 17:34:15
# episode : 851 | final step : 95 | total reward : -14.0
# 2020/10/06 17:34:19
# episode : 852 | final step : 99 | total reward : -123.75
# 2020/10/06 17:34:22
# episode : 853 | final step : 98 | total reward : -121.275
# 2020/10/06 17:34:25
# episode : 854 | final step : 98 | total reward : -121.275
# 2020/10/06 17:34:29
# episode : 855 | final step : 98 | total reward : -121.275
# 2020/10/06 17:34:32
# episode : 856 | final step : 99 | total reward : -123.75
# 2020/10/06 17:34:35
# episode : 857 | final step : 100 | total reward : -26.25
# 2020/10/06 17:34:39
# episode : 858 | final step : 98 | total reward : -121.275
# 2020/10/06 17:34:43
# episode : 859 | final step : 98 | total reward : -121.275
# 2020/10/06 17:34:46
# episode : 860 | final step : 99 | total reward : -123.75
# 2020/10/06 17:34:49
# episode : 861 | final step : 98 | total reward : -121.275
# 2020/10/06 17:34:53
# episode : 862 | final step : 98 | total reward : -121.275
# 2020/10/06 17:34:56
# episode : 863 | final step : 100 | total reward : -126.25
# 2020/10/06 17:34:59
# episode : 864 | final step : 98 | total reward : -121.275
# 2020/10/06 17:35:03
# episode : 865 | final step : 98 | total reward : -121.275
# 2020/10/06 17:35:06
# episode : 866 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:35:09
# episode : 867 | final step : 98 | total reward : -121.275
# 2020/10/06 17:35:13
# episode : 868 | final step : 99 | total reward : -23.75
# 2020/10/06 17:35:16
# episode : 869 | final step : 100 | total reward : -126.25
# 2020/10/06 17:35:20
# episode : 870 | final step : 100 | total reward : -26.25
# 2020/10/06 17:35:23
# episode : 871 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:35:26
# episode : 872 | final step : 98 | total reward : -121.275
# 2020/10/06 17:35:29
# episode : 873 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:35:33
# episode : 874 | final step : 99 | total reward : -23.75
# 2020/10/06 17:35:36
# episode : 875 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:35:39
# episode : 876 | final step : 98 | total reward : -121.275
# 2020/10/06 17:35:43
# episode : 877 | final step : 98 | total reward : -121.275
# 2020/10/06 17:35:46
# episode : 878 | final step : 98 | total reward : -121.275
# 2020/10/06 17:35:49
# episode : 879 | final step : 98 | total reward : -121.275
# 2020/10/06 17:35:52
# episode : 880 | final step : 99 | total reward : -123.75
# 2020/10/06 17:35:55
# episode : 881 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:35:59
# episode : 882 | final step : 99 | total reward : -23.75
# 2020/10/06 17:36:02
# episode : 883 | final step : 98 | total reward : -121.275
# 2020/10/06 17:36:05
# episode : 884 | final step : 98 | total reward : -121.275
# 2020/10/06 17:36:09
# episode : 885 | final step : 99 | total reward : -23.75
# 2020/10/06 17:36:13
# episode : 886 | final step : 100 | total reward : -126.25
# 2020/10/06 17:36:16
# episode : 887 | final step : 98 | total reward : -121.275
# 2020/10/06 17:36:19
# episode : 888 | final step : 99 | total reward : -123.75
# 2020/10/06 17:36:22
# episode : 889 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:36:25
# episode : 890 | final step : 98 | total reward : -121.275
# 2020/10/06 17:36:28
# episode : 891 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:36:32
# episode : 892 | final step : 98 | total reward : -121.275
# 2020/10/06 17:36:35
# episode : 893 | final step : 98 | total reward : -121.275
# 2020/10/06 17:36:38
# episode : 894 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:36:42
# episode : 895 | final step : 99 | total reward : -23.75
# 2020/10/06 17:36:45
# episode : 896 | final step : 100 | total reward : -26.25
# 2020/10/06 17:36:49
# episode : 897 | final step : 98 | total reward : -121.275
# 2020/10/06 17:36:52
# episode : 898 | final step : 98 | total reward : -121.275
# 2020/10/06 17:36:55
# episode : 899 | final step : 99 | total reward : -123.75
# 2020/10/06 17:36:59
# episode : 900 | final step : 98 | total reward : -121.275
# 2020/10/06 17:37:02
# episode : 901 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:37:06
# episode : 902 | final step : 98 | total reward : -121.275
# 2020/10/06 17:37:09
# episode : 903 | final step : 98 | total reward : -121.275
# 2020/10/06 17:37:12
# episode : 904 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:37:16
# episode : 905 | final step : 98 | total reward : -121.275
# 2020/10/06 17:37:19
# episode : 906 | final step : 98 | total reward : -121.275
# 2020/10/06 17:37:23
# episode : 907 | final step : 98 | total reward : -121.275
# 2020/10/06 17:37:26
# episode : 908 | final step : 99 | total reward : -123.75
# 2020/10/06 17:37:29
# episode : 909 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:37:32
# episode : 910 | final step : 99 | total reward : -123.75
# 2020/10/06 17:37:36
# episode : 911 | final step : 100 | total reward : -26.25
# 2020/10/06 17:37:38
# episode : 912 | final step : 99 | total reward : -23.75
# 2020/10/06 17:37:41
# episode : 913 | final step : 98 | total reward : -121.275
# 2020/10/06 17:37:45
# episode : 914 | final step : 98 | total reward : -121.275
# 2020/10/06 17:37:48
# episode : 915 | final step : 98 | total reward : -121.275
# 2020/10/06 17:37:51
# episode : 916 | final step : 98 | total reward : -121.275
# 2020/10/06 17:37:55
# episode : 917 | final step : 98 | total reward : -121.275
# 2020/10/06 17:37:59
# episode : 918 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:38:02
# episode : 919 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:38:05
# episode : 920 | final step : 99 | total reward : -123.75
# 2020/10/06 17:38:09
# episode : 921 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:38:12
# episode : 922 | final step : 98 | total reward : -121.275
# 2020/10/06 17:38:15
# episode : 923 | final step : 98 | total reward : -121.275
# 2020/10/06 17:38:20
# episode : 924 | final step : 100 | total reward : -26.25
# 2020/10/06 17:38:23
# episode : 925 | final step : 98 | total reward : -121.275
# 2020/10/06 17:38:26
# episode : 926 | final step : 98 | total reward : -121.275
# 2020/10/06 17:38:30
# episode : 927 | final step : 98 | total reward : -121.275
# 2020/10/06 17:38:33
# episode : 928 | final step : 98 | total reward : -121.275
# 2020/10/06 17:38:36
# episode : 929 | final step : 99 | total reward : -23.75
# 2020/10/06 17:38:39
# episode : 930 | final step : 99 | total reward : -123.75
# 2020/10/06 17:38:43
# episode : 931 | final step : 98 | total reward : -121.275
# 2020/10/06 17:38:47
# episode : 932 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:38:50
# episode : 933 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:38:53
# episode : 934 | final step : 99 | total reward : -123.75
# 2020/10/06 17:38:57
# episode : 935 | final step : 99 | total reward : -123.75
# 2020/10/06 17:39:00
# episode : 936 | final step : 99 | total reward : -123.75
# 2020/10/06 17:39:04
# episode : 937 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:39:07
# episode : 938 | final step : 99 | total reward : -123.75
# 2020/10/06 17:39:10
# episode : 939 | final step : 99 | total reward : -123.75
# 2020/10/06 17:39:13
# episode : 940 | final step : 99 | total reward : -123.75
# 2020/10/06 17:39:17
# episode : 941 | final step : 98 | total reward : -121.275
# 2020/10/06 17:39:20
# episode : 942 | final step : 99 | total reward : -123.75
# 2020/10/06 17:39:23
# episode : 943 | final step : 99 | total reward : -123.75
# 2020/10/06 17:39:27
# episode : 944 | final step : 98 | total reward : -121.275
# 2020/10/06 17:39:31
# episode : 945 | final step : 98 | total reward : -121.275
# 2020/10/06 17:39:33
# episode : 946 | final step : 99 | total reward : -123.75
# 2020/10/06 17:39:37
# episode : 947 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:39:41
# episode : 948 | final step : 98 | total reward : -121.275
# 2020/10/06 17:39:44
# episode : 949 | final step : 98 | total reward : -121.275
# 2020/10/06 17:39:47
# episode : 950 | final step : 98 | total reward : -121.275
# 2020/10/06 17:39:51
# episode : 951 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:39:54
# episode : 952 | final step : 100 | total reward : -26.25
# 2020/10/06 17:39:57
# episode : 953 | final step : 99 | total reward : -123.75
# 2020/10/06 17:40:01
# episode : 954 | final step : 98 | total reward : -121.275
# 2020/10/06 17:40:04
# episode : 955 | final step : 99 | total reward : -123.75
# 2020/10/06 17:40:07
# episode : 956 | final step : 99 | total reward : -123.75
# 2020/10/06 17:40:11
# episode : 957 | final step : 98 | total reward : -121.275
# 2020/10/06 17:40:15
# episode : 958 | final step : 98 | total reward : -121.275
# 2020/10/06 17:40:18
# episode : 959 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:40:21
# episode : 960 | final step : 98 | total reward : -121.275
# 2020/10/06 17:40:25
# episode : 961 | final step : 98 | total reward : -121.275
# 2020/10/06 17:40:28
# episode : 962 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:40:31
# episode : 963 | final step : 99 | total reward : -123.75
# 2020/10/06 17:40:35
# episode : 964 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:40:39
# episode : 965 | final step : 98 | total reward : -121.275
# 2020/10/06 17:40:42
# episode : 966 | final step : 99 | total reward : -123.75
# 2020/10/06 17:40:45
# episode : 967 | final step : 98 | total reward : -121.275
# 2020/10/06 17:40:48
# episode : 968 | final step : 98 | total reward : -121.275
# 2020/10/06 17:40:52
# episode : 969 | final step : 98 | total reward : -121.275
# 2020/10/06 17:40:55
# episode : 970 | final step : 98 | total reward : -121.275
# 2020/10/06 17:40:59
# episode : 971 | final step : 98 | total reward : -121.275
# 2020/10/06 17:41:02
# episode : 972 | final step : 99 | total reward : -123.75
# 2020/10/06 17:41:05
# episode : 973 | final step : 102 | total reward : -31.325000000000017
# 2020/10/06 17:41:10
# episode : 974 | final step : 100 | total reward : -26.25
# 2020/10/06 17:41:13
# episode : 975 | final step : 98 | total reward : -121.275
# 2020/10/06 17:41:16
# episode : 976 | final step : 98 | total reward : -121.275
# 2020/10/06 17:41:20
# episode : 977 | final step : 98 | total reward : -121.275
# 2020/10/06 17:41:23
# episode : 978 | final step : 99 | total reward : -23.75
# 2020/10/06 17:41:26
# episode : 979 | final step : 97 | total reward : -18.825000000000003
# 2020/10/06 17:41:30
# episode : 980 | final step : 99 | total reward : -123.75
# 2020/10/06 17:41:33
# episode : 981 | final step : 99 | total reward : -123.75
# 2020/10/06 17:41:36
# episode : 982 | final step : 98 | total reward : -121.275
# 2020/10/06 17:41:40
# episode : 983 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:41:43
# episode : 984 | final step : 98 | total reward : -121.275
# 2020/10/06 17:41:47
# episode : 985 | final step : 98 | total reward : -121.275
# 2020/10/06 17:41:50
# episode : 986 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:41:53
# episode : 987 | final step : 99 | total reward : -123.75
# 2020/10/06 17:41:57
# episode : 988 | final step : 99 | total reward : -23.75
# 2020/10/06 17:42:00
# episode : 989 | final step : 98 | total reward : -121.275
# 2020/10/06 17:42:03
# episode : 990 | final step : 99 | total reward : -123.75
# 2020/10/06 17:42:08
# episode : 991 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:42:11
# episode : 992 | final step : 98 | total reward : -21.275000000000006
# 2020/10/06 17:42:14
# episode : 993 | final step : 96 | total reward : -16.400000000000006
# 2020/10/06 17:42:18
# episode : 994 | final step : 98 | total reward : -121.275
# 2020/10/06 17:42:21
# episode : 995 | final step : 98 | total reward : -121.275
# 2020/10/06 17:42:24
# episode : 996 | final step : 98 | total reward : -121.275
# 2020/10/06 17:42:27
# episode : 997 | final step : 98 | total reward : -121.275
# 2020/10/06 17:42:29
# episode : 998 | final step : 100 | total reward : -26.25
# 2020/10/06 17:42:30
# episode : 999 | final step : 99 | total reward : -123.75
# Complete

# %%
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(reward_list)

# %%
def moving_average(data,n):
    len_data=len(data)-n
    res_data=np.zeros(len_data)

    for i in range(len_data):
        res_data[i]=sum(data[i:i+n])/n
    return res_data

# %%
average_number=100
filtered_data=moving_average(reward_list,average_number)
plt.figure(figsize=(15,10))
plt.xlabel("Episode")
plt.ylabel("Total rewards")
plt.plot(filtered_data)

# %%
# plots
Deg2Rad = np.pi/180
Rad2Deg = 1/Deg2Rad

plt_res=total_res[999]


plt.figure(figsize=(15,9), dpi=100)

plt.subplot(511)
plt.plot(plt_res[:,0], label=r'$\dot{h}_{cmd}$')
plt.ylabel(r'$\dot{h}_{cmd}$ ($m/s$)'), plt.grid()

plt.subplot(512)
plt.plot(plt_res[:,10],label=r'$\{h}$')
plt.ylabel(r'$h$ (m)'), plt.grid()

plt.subplot(513)
plt.plot(plt_res[:,1],label=r'$\{r}$')
plt.ylabel(r'$r$ (m)'), plt.grid()

plt.subplot(514)
plt.plot(plt_res[:,2]*Rad2Deg, label='elevation')
plt.ylabel('elevation (deg)'), plt.grid()

plt.subplot(515)
plt.plot(plt_res[:,3]*Rad2Deg, label='azimuth')
plt.ylabel('azimuth (deg)'), plt.grid()

plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

plt.figure(figsize=(12,9), dpi=100)
plt.gca(projection='3d')
plt.plot(plt_res[:,5], plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.xlim(-2000,2000)
plt.ylim(0,4000)
plt.legend()
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,5], plt_res[:,4], label='player', linewidth=3)
plt.plot(plt_res[:,8], plt_res[:,7], label='target', linewidth=3)
plt.xlabel('East')
plt.ylabel('North')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()

plt.figure(figsize=(12,9), dpi=100)
plt.plot(plt_res[:,4], -plt_res[:,6], label='player', linewidth=3)
plt.plot(plt_res[:,7], -plt_res[:,9], label='target', linewidth=3)
plt.xlabel('North')
plt.ylabel('Up')
plt.grid(), plt.legend(), plt.axis('equal')
plt.show()
