# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sc = 8000
cc = -2000
cos_start = 90

# %%
x_p = np.arange(105, 200, 0.1)
x_c = np.arange(cos_start, 105, 0.1)
x_n = np.arange(-100, cos_start, 0.1)

# %%
y_p = np.full((len(x_p)), sc)
y_c = (sc - cc) / 2 * np.sin(np.pi / (105 - cos_start) * (x_c - (105 + cos_start) / 2)) \
        + (sc + cc) / 2
y_n = np.full((len(x_n)), cc)

# %%
y_plot = np.concatenate([y_n, y_c ,y_p])
x_plot = np.concatenate([x_n, x_c, x_p])

# %%
plt.figure(figsize = (15, 15))
plt.plot(x_plot, y_plot)
plt.grid()
# plt.xlim(90, 200)
