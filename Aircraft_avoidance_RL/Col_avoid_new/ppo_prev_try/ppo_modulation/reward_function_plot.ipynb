# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_p = np.arange(105,200,0.1)
x_n = np.arange(0,105,0.1)

# %%
max_reward = 900000
# y_p = max_reward * np.log((x_p - 90) / 10 * np.exp(1)) / (10 * (x_p - 90))
y_p = (10000 * 0.02 * (10000 * np.log((x_p - 95) / 10 * np.exp(1))/(10 * (x_p - 95)) - 10000 * 0.009) - 2000) + max_reward * 0.01
y_n = (10000 * 0.02 * (10000 * np.log(( - x_n + 115) / 10 * np.exp(1))/(10 * ( - x_n + 115)) - 10000 * 0.009) - 2000) + max_reward * 0.01

# %%
y_plot = np.concatenate([y_n, y_p])
x_plot = np.concatenate([x_n, x_p])

# %%
plt.figure(figsize = (15, 15))
plt.plot(x_plot, y_plot)
plt.grid()
